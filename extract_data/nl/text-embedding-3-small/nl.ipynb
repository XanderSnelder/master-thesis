# %% [markdown]
# ### **0. Set-up**

# %%
# Import libraries and utils
# %run '../../utils.ipynb'

# %%
#  Get api key
load_dotenv()
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

# Set client
client = OpenAI()

# %%
# Load dataframe
cleaned_nl_simlex = pd.read_csv("../../../data/dataset/cleaned-nl-simlex-999.csv")

# Select subset
# cleaned_nl_simlex = cleaned_nl_simlex.head(5)

# Convert to tuple
word_pairs = list(zip(cleaned_nl_simlex['word1'], cleaned_nl_simlex['word2']))

# %%
cleaned_nl_simlex
# Out:
#            word1        word2  SimLex999 POS
# 0            oud        nieuw       1.94   A
# 1           slim  intelligent       8.19   A
# 2           hard     moeilijk       4.46   A
# 3       gelukkig      vrolijk       6.49   A
# 4           hard        stoer       5.69   A
# ..           ...          ...        ...  ..
# 992  samenvoegen    verwerven       3.89   V
# 993       sturen     bijwonen       1.85   V
# 994   verzamelen     bijwonen       1.06   V
# 995      opnemen    intrekken       2.29   V
# 996     bijwonen     aankomen       1.32   V
#
# [997 rows x 4 columns]

# %% [markdown]
# ### **1. Process and Extract Data**

# %%
# Define model
model = "text-embedding-3-small"

# Delay between individual API calls
delay = 3.0

# %%
# Extract word embeddings and calculate scaled cosine similarity scores
# response = get_responses_embeddings(word_pairs, model, delay)

# Show results
response
# Out:
# Calculating Cosine Similarities: 100%|██████████| 997/997 [59:28<00:00,  3.58s/pair]
# Total time taken: 3568.93 seconds
# [('oud', 'nieuw', 0.29928531607608866),
#  ('slim', 'intelligent', 0.2749992547511264),
#  ('hard', 'moeilijk', 0.4674973865920079),
#  ('gelukkig', 'vrolijk', 0.5709924457001788),
#  ('hard', 'stoer', 0.2404189113708845),
#  ('snel', 'razendsnel', 0.7236735252177695),
#  ('gelukkig', 'blij', 0.709284964717873),
#  ('kort', 'lang', 0.3467201126972418),
#  ('dom', 'stom', 0.350701342303405),
#  ('vreemd', 'eigenaardig', 0.6997553879753116),
#  ('breed', 'smal', 0.23228419781167634),
#  ('makkelijk', 'moeilijk', 0.6632028642008962),
#  ('moeilijk', 'gemakkelijk', 0.6307372684514351),
#  ('slim', 'dom', 0.2805028239364556),
#  ('krankzinnig', 'gek', 0.4045253010138435),
#  ('gelukkig', 'kwaad', 0.37618038812554966),
#  ('uitgebreid', 'groot', 0.5257078145278744),
#  ('moeilijk', 'simpel', 0.371028849027604),
#  ('nieuw', 'vers', 0.309271639713104),
#  ('scherp', 'saai', 0.29776687268016605),
#  ('vlug', 'snel', 0.41180921987693236),
#  ('dom', 'dwaas', 0.27667441566978085),
#  ('prachtig', 'fantastisch', 0.649504356174818),
#  ('eigenaardig', 'vreemd', 0.6997553879753116),
#  ('gelukkig', 'boos', 0.16971498710137378),
#  ('smal', 'breed', 0.23228419781167634),
#  ('eenvoudig', 'gemakkelijk', 0.7335799911814803),
#  ('oud', 'vers', 0.405098817412351),
#  ('kennelijk', 'duidelijk', 0.6157580504473417),
#  ('betaalbaar', 'goedkoop', 0.5708959243646616),
#  ('leuk', 'grootmoedig', 0.27190563961526),
#  ('raar', 'vreemd', 0.40784063227867556),
#  ('vreemd', 'normaal', 0.5169330877163009),
#  ('slecht', 'immoreel', 0.4157891728953128),
#  ('verdrietig', 'grappig', 0.5039132296726184),
#  ('prachtig', 'geweldig', 0.7363233366633788),
#  ('schuldig', 'beschaamd', 0.5321729991537021),
#  ('mooi', 'prachtig', 0.6811043900506109),
#  ('zelfverzekerd', 'zeker', 0.6512520865743255),
#  ('dom', 'onderontwikkeld', 0.16871380635464917),
#  ('groot', 'flexibel', 0.39483349402237367),
#  ('aardig', 'wreed', 0.2431171346282443),
#  ('ongeduldig', 'nerveus', 0.3769688363592572),
#  ('groot', 'breed', 0.2857238948629844),
#  ('sterk', 'trots', 0.22643599544940435),
#  ('onnodig', 'noodzakelijk', 0.5952422310482265),
#  ('onrustig', 'jong', 0.22977740453542905),
#  ('dom', 'intelligent', 0.20184700616281645),
#  ('slecht', 'geweldig', 0.45033179656632283),
#  ('moeilijk', 'eenvoudig', 0.569987588664268),
#  ('noodzakelijk', 'belangrijk', 0.6129751957443288),
#  ('slecht', 'verschrikkelijk', 0.5717414800589409),
#  ('boos', 'blij', 0.1953905296391313),
#  ('eerlijk', 'schuldig', 0.4506115804298223),
#  ('makkelijk', 'zwaar', 0.5234599331190072),
#  ('makkelijk', 'flexibel', 0.5287008094657082),
#  ('stellig', 'zeker', 0.31968239995142317),
#  ('essentieel', 'noodzakelijk', 0.7403455352222479),
#  ('anders', 'normaal', 0.20765957653334227),
#  ('sluw', 'slim', 0.5061976436556708),
#  ('cruciaal', 'belangrijk', 0.5366392950629253),
#  ('hard', 'wreed', 0.28512761770350226),
#  ('kinderachtig', 'dwaas', 0.4975130785134727),
#  ('zelden', 'zeldzaam', 0.626865726277408),
#  ('vriendelijk', 'vrijgevig', 0.5618415309539924),
#  ('breekbaar', 'kil', 0.17386961971427792),
#  ('lang', 'smal', 0.28480640486081066),
#  ('groot', 'zwaar', 0.4890504901138304),
#  ('ruw', 'koel', 0.25670519151118926),
#  ('bizar', 'vreemd', 0.5013925776929365),
#  ('illegaal', 'immoreel', 0.48508628953615657),
#  ('slecht', 'schuldig', 0.47802928817486817),
#  ('modern', 'oud', 0.3522233202877029),
#  ('nieuw', 'oud', 0.29928531607608866),
#  ('saai', 'grappig', 0.25402823390516066),
#  ('gelukkig', 'jong', 0.3040325727984324),
#  ('makkelijk', 'groot', 0.4374654739826025),
#  ('geweldig', 'vreselijk', 0.644978104849475),
#  ('klein', 'enorm', 0.22561497221763405),
#  ('beleefd', 'gepast', 0.3779314931234025),
#  ('bescheiden', 'beschaamd', 0.5539462909669959),
#  ('exotisch', 'zeldzaam', 0.5319670478660289),
#  ('dom', 'slim', 0.2805028239364556),
#  ('heerlijk', 'prachtig', 0.649248231136215),
#  ('opvallend', 'duidelijk', 0.5999700850273588),
#  ('angstig', 'bang', 0.2629211683287415),
#  ('formeel', 'juist', 0.46176713528474056),
#  ('somber', 'saai', 0.24085853936375026),
#  ('heerlijk', 'vrolijk', 0.550911081815391),
#  ('ongelukkig', 'kwaad', 0.4339470772285895),
#  ('verdrietig', 'vreselijk', 0.4993048222320164),
#  ('ziek', 'gek', 0.532690903516634),
#  ('gewelddadig', 'boos', 0.18739764043087848),
#  ('beladen', 'zwaar', 0.5590725870647228),
#  ('vuil', 'goedkoop', 0.4580779391363093),
#  ('elastisch', 'flexibel', 0.6408188319585462),
#  ('hard', 'dicht', 0.29136862394528396),
#  ('onlangs', 'nieuw', 0.5710005751915728),
#  ('brutaal', 'trots', 0.1918586596742041),
#  ('sluw', 'vreemd', 0.4586345422119537),
#  ('vreemd', 'sluw', 0.45863180363468853),
#  ('dom', 'zeldzaam', 0.20675739516948421),
#  ('sluw', 'koppig', 0.3710221679926397),
#  ('fantastisch', 'kwaad', 0.3438812760299094),
#  ('bescheiden', 'flexibel', 0.4531796068759336),
#  ('vers', 'breed', 0.3178470292443944),
#  ('enorm', 'sprakeloos', 0.20650013254631042),
#  ('groot', 'enorm', 0.444974643697018),
#  ('vuil', 'smal', 0.35374480492947036),
#  ('echtgenote', 'echtgenoot', 0.8450785424215816),
#  ('boek', 'tekst', 0.3809049835047618),
#  ('bruidegom', 'bruid', 0.7422623033432243),
#  ('nacht', 'dag', 0.3830000239315369),
#  ('zuid', 'noord', 0.7274180534694522),
#  ('vliegtuig', 'luchthaven', 0.5232856852693534),
#  ('oom', 'tante', 0.3506131627756759),
#  ('paard', 'merrie', 0.2880902250750618),
#  ('onderkant', 'bovenkant', 0.73979504686416),
#  ('vriend', 'maat', 0.4285035987916321),
#  ('student', 'leerling', 0.5082938065880905),
#  ('wereld', 'wereldbol', 0.7288081825254329),
#  ('been', 'arm', 0.36823469275501436),
#  ('vliegtuig', 'straalvliegtuig', 0.7776721342581231),
#  ('vrouw', 'man', 0.38236948311131747),
#  ('paard', 'veulen', 0.464116004630712),
#  ('actrice', 'acteur', 0.8681142250947133),
#  ('leraar', 'instructeur', 0.6370848928093132),
#  ('film', 'filmrol', 0.6003729281683086),
#  ('vogel', 'havik', 0.41737480619043255),
#  ('woord', 'woordenboek', 0.5012711291516945),
#  ('geld', 'salaris', 0.42527491125114025),
#  ('hond', 'kat', 0.27181853971046877),
#  ('gebied', 'regio', 0.6250426602135941),
#  ('marine', 'leger', 0.27130361344849174),
#  ('boek', 'literatuur', 0.5971641203044938),
#  ('kleding', 'kast', 0.4075841392373024),
#  ('zonsondergang', 'zonsopgang', 0.759826276409219),
#  ('kind', 'volwassen', 0.29561662664800575),
#  ('koe', 'vee', 0.3688151790066193),
#  ('boek', 'verhaal', 0.49190357711199467),
#  ('winter', 'zomer', 0.550430980145146),
#  ('taxi', 'taxis', 0.8320187634013024),
#  ('boom', 'esdoorn', 0.29372153139791285),
#  ('bed', 'slaapkamer', 0.5140637964771556),
#  ('dak', 'plafond', 0.324198029792056),
#  ('ziekte', 'infectie', 0.590696439734944),
#  ('arm', 'schouder', 0.3313274233764381),
#  ('schaap', 'lam', 0.23708696502801524),
#  ('dame', 'meneer', 0.3550846663572409),
#  ('boot', 'anker', 0.4255877145021284),
#  ('priester', 'monnik', 0.6251892099802255),
#  ('teen', 'vinger', 0.32168112442169705),
#  ('rivier', 'stroom', 0.4728434888523363),
#  ('boosheid', 'woede', 0.4072956523820517),
#  ('datum', 'kalender', 0.4137748387129352),
#  ('zee', 'oceaan', 0.3202832723499604),
#  ('seconde', 'minuut', 0.5072787696457992),
#  ('hand', 'duim', 0.36119022746744683),
#  ('hout', 'stam', 0.4002039044818313),
#  ('modder', 'vuil', 0.32651884485054505),
#  ('hal', 'gang', 0.3613735969625306),
#  ('weg', 'manier', 0.44032395899858523),
#  ('muis', 'kat', 0.24955730099661305),
#  ('politieagent', 'sheriff', 0.35528421304864966),
#  ('dood', 'begrafenis', 0.5391949317399051),
#  ('muziek', 'melodie', 0.4902506313565227),
#  ('bier', 'alcohol', 0.4752356109651286),
#  ('mond', 'lip', 0.26350876627232833),
#  ('storm', 'orkaan', 0.24113827616085762),
#  ('belasting', 'inkomen', 0.5668117051178111),
#  ('bloem', 'viooltjes', 0.4541512816212084),
#  ('papier', 'karton', 0.5400094763100579),
#  ('vloer', 'plafond', 0.5891518003934648),
#  ('strand', 'kust', 0.4364920807297181),
#  ('staaf', 'gordijn', 0.4295282003345842),
#  ('jachthond', 'vos', 0.22316531048665442),
#  ('straat', 'auto', 0.25362800234587535),
#  ('boot', 'dek', 0.3988421254619302),
#  ('auto', 'toeter', 0.3107190312145699),
#  ('vriend', 'gast', 0.43566936423981434),
#  ('werkgever', 'werknemer', 0.7259790934145242),
#  ('hand', 'pols', 0.3698930222176616),
#  ('bal', 'kostuum', 0.2510244427364585),
#  ('alcohol', 'brandewijn', 0.25131198575858094),
#  ('overwinning', 'zege', 0.29174003190081454),
#  ('telefoon', 'cel', 0.342097177150913),
#  ('deur', 'ingang', 0.36628627735681485),
#  ('motel', 'herberg', 0.5805227126472252),
#  ('kleding', 'stof', 0.47168514686037866),
#  ('steak', 'vlees', 0.43090278241171615),
#  ('nagel', 'duim', 0.35622725276689726),
#  ('muziekgroep', 'orkest', 0.5570331811464517),
#  ('boek', 'bijbel', 0.6438885610341508),
#  ('bedrijf', 'industrie', 0.5826612235618644),
#  ('winter', 'seizoen', 0.41661146022617823),
#  ('decennium', 'eeuw', 0.5908654445782199),
#  ('alcohol', 'jenever', 0.4504758156023023),
#  ('hoed', 'jas', 0.23031191551603525),
#  ('raam', 'deur', 0.4432203656959395),
#  ('arm', 'pols', 0.3609704599982939),
#  ('huis', 'appartement', 0.5931377339431652),
#  ('glas', 'kristal', 0.3732270298786092),
#  ('wijn', 'brandewijn', 0.5120308606840842),
#  ('maker', 'producent', 0.46582331055336806),
#  ('diner', 'ontbijt', 0.47528183313248995),
#  ('arm', 'spier', 0.304457451937918),
#  ('bubbel', 'schuim', 0.5528163150955308),
#  ('brood', 'meel', 0.4663116664842152),
#  ('dood', 'tragedie', 0.4266801804036952),
#  ('afwezigheid', 'aanwezigheid', 0.9247366838623222),
#  ('pistool', 'kanon', 0.2577706134480908),
#  ('gras', 'stro', 0.35523263878022787),
#  ('bal', 'mand', 0.3570100243634408),
#  ('slang', 'tuin', 0.30083726090645396),
#  ('jongen', 'kind', 0.4386201114729432),
#  ('kerk', 'koor', 0.30395432382202464),
#  ('kleding', 'lade', 0.2531705194997258),
#  ('toren', 'bel', 0.2873639140323116),
#  ('vader', 'ouder', 0.30303466858013545),
#  ('school', 'cijfer', 0.216020146676092),
#  ('ouder', 'volwassene', 0.5186065515710726),
#  ('balk', 'gevangenis', 0.29431085685037317),
#  ('auto', 'snelweg', 0.32471357925650307),
#  ('woordenboek', 'definitie', 0.48723093276652857),
#  ('deur', 'kelder', 0.4661013223000083),
#  ('leger', 'legioen', 0.5473551761941031),
#  ('metaal', 'aluminium', 0.5282458109284118),
#  ('stoel', 'bank', 0.2579359724073643),
#  ('wolk', 'mist', 0.3185419815488907),
#  ('jongen', 'zoon', 0.29640376173269617),
#  ('water', 'ijs', 0.32763968444034836),
#  ('bed', 'deken', 0.4530137089652441),
#  ('officier van justitie', 'advocaat', 0.6075238914934636),
#  ('gebied', 'zone', 0.4084012107245839),
#  ('bedrijf', 'onderneming', 0.7497114008678946),
#  ('kleding', 'textiel', 0.5897277984266917),
#  ('trui', 'jas', 0.27183002664713257),
#  ('geld', 'vermogen', 0.42337372414584995),
#  ('hand', 'voet', 0.3478619471033719),
#  ('alcohol', 'cocktail', 0.33631153897767274),
#  ('decimeter', 'centimeter', 0.7835804585240228),
#  ('molecuul', 'atoom', 0.4960330294596633),
#  ('lens', 'camera', 0.512368968594145),
#  ('maaltijd', 'diner', 0.47581742550661077),
#  ('oog', 'traan', 0.357190929324758),
#  ('god', 'duivel', 0.3489089912436971),
#  ('lus', 'riem', 0.38278210223220394),
#  ('rat', 'muis', 0.33230206675711926),
#  ('motor', 'aandrijving', 0.4555601668599867),
#  ('auto', 'taxi', 0.34256534947810574),
#  ('kat', 'leeuw', 0.196885400669865),
#  ('maat', 'omvang', 0.4840583032803978),
#  ('werkelijkheid', 'verbeelding', 0.5745560444601976),
#  ('deur', 'poort', 0.6207729114795688),
#  ('kat', 'huisdier', 0.25891383356415876),
#  ('blik', 'aluminium', 0.3306135563024829),
#  ('botten', 'kaak', 0.39062048154197176),
#  ('graan', 'tarwe', 0.6348007413596612),
#  ('huis', 'sleutel', 0.44233053862437754),
#  ('bloed', 'vlees', 0.5166947892270892),
#  ('deur', 'gang', 0.257382976520775),
#  ('god', 'geest', 0.37529563839625224),
#  ('vermogen', 'competentie', 0.6872575012345762),
#  ('uitbundigheid', 'overvloed', 0.5972184404245979),
#  ('bank', 'stoel', 0.2579359724073643),
#  ('muur', 'baksteen', 0.42754053649034646),
#  ('hoorn', 'trommel', 0.389799720790678),
#  ('orgaan', 'lever', 0.31634599776230987),
#  ('kracht', 'macht', 0.6294948704299203),
#  ('zin', 'woord', 0.4677495124393126),
#  ('muziekgroep', 'parade', 0.19606308581925475),
#  ('buik', 'taille', 0.36983722391706786),
#  ('wolk', 'storm', 0.4414196448173415),
#  ('vreugde', 'trots', 0.28947786996328834),
#  ('lawaai', 'gerammel', 0.19994438188841798),
#  ('regen', 'mist', 0.3085718481388424),
#  ('bier', 'drank', 0.6247877963651837),
#  ('man', 'oom', 0.41501385180023465),
#  ('appel', 'sap', 0.35310517831587107),
#  ('intelligentie', 'logica', 0.3071153650672808),
#  ('communicatie', 'taal', 0.48813480127031095),
#  ('nerts', 'bont', 0.3546295198168335),
#  ('bende', 'menigte', 0.32210754847334044),
#  ('oever', 'kust', 0.40997311616142584),
#  ('pijpleiding', 'kabel', 0.3162134537570303),
#  ('vogel', 'kalkoen', 0.40936186854320555),
#  ('bed', 'wieg', 0.31521916913406056),
#  ('competentie', 'vermogen', 0.6872575012345762),
#  ('wolk', 'nevel', 0.3644453414957018),
#  ('avondeten', 'maaltijd', 0.6668609357939893),
#  ('balk', 'kooi', 0.3581001035830582),
#  ('water', 'zout', 0.30756065404725513),
#  ('gevoel', 'intuïtie', 0.5481191524187209),
#  ('situatie', 'omstandigheid', 0.7319377164509442),
#  ('misdaad', 'diefstal', 0.5736829003729174),
#  ('stijl', 'mode', 0.3580273309197533),
#  ('rand', 'grens', 0.3006400752865039),
#  ('arm', 'lichaam', 0.28798271135877057),
#  ('boot', 'auto', 0.4479717906028342),
#  ('broodje', 'lunch', 0.382905794432883),
#  ('bruid', 'prinses', 0.48601434307268837),
#  ('heldin', 'held', 0.5376840578520533),
#  ('auto', 'meter', 0.3399491158375562),
#  ('insect', 'bij', 0.29072456461533946),
#  ('kinderbed', 'wieg', 0.40207219159110824),
#  ('dier', 'persoon', 0.48920087665542983),
#  ('marihuana', 'kruid', 0.3388005071066398),
#  ('bed', 'ziekenhuis', 0.3282067117856878),
#  ('wang', 'tong', 0.37576927613809474),
#  ('cd', 'computer', 0.416516368956452),
#  ('bocht', 'hoek', 0.5265140458383795),
#  ('gras', 'mos', 0.32275019865138455),
#  ('school', 'wet', 0.28808169549044277),
#  ('voet', 'hoofd', 0.5274443518991794),
#  ('moeder', 'beschermer', 0.38155008226692627),
#  ('orthodontist', 'tandarts', 0.515138806151195),
#  ('alcohol', 'whisky', 0.48996148906433484),
#  ('mond', 'tand', 0.31002062364700206),
#  ('ontbijt', 'spek', 0.30413405888564554),
#  ('badkamer', 'slaapkamer', 0.6326251488415652),
#  ('bord', 'kom', 0.3265726147655582),
#  ('vlees', 'brood', 0.45942045749438465),
#  ('lucht', 'helium', 0.43457857591970583),
#  ('arbeider', 'werkgever', 0.5213521814016648),
#  ('lichaam', 'borst', 0.38005890129092973),
#  ('zoon', 'vader', 0.24955128729651174),
#  ('hart', 'operatie', 0.14551143369290723),
#  ('vrouw', 'secretaresse', 0.4689785131392686),
#  ('man', 'vader', 0.3508204947756973),
#  ('strand', 'eiland', 0.3541529345221612),
#  ('verhaal', 'onderwerp', 0.5513240306678829),
#  ('spel', 'plezier', 0.323694767724203),
#  ('weekend', 'week', 0.6037428566741136),
#  ('koppel', 'paar', 0.5343128444766505),
#  ('vrouw', 'echtgenote', 0.41745523461139233),
#  ('schaap', 'vee', 0.28970482294480465),
#  ('portemonnee', 'tas', 0.27516433278334157),
#  ('dak', 'kathedraal', 0.25650665099553904),
#  ('boon', 'koffie', 0.24090371668024468),
#  ('hout', 'papier', 0.4621664034618297),
#  ('bovenkant', 'zijkant', 0.6413263803807233),
#  ('misdaad', 'fraude', 0.4868221899998479),
#  ('pijn', 'schade', 0.5558741266902849),
#  ('minnaar', 'partner', 0.2681512947558723),
#  ('avond', 'schemering', 0.29241672627305065),
#  ('vader', 'dochter', 0.2439118768343727),
#  ('wijn', 'likeur', 0.29570885689963267),
#  ('koe', 'geit', 0.39070570706187463),
#  ('geloof', 'mening', 0.24528743905322659),
#  ('werkelijkheid', 'illusie', 0.40036555410620894),
#  ('overeenkomst', 'voorwaarde', 0.5558472331262917),
#  ('rijkdom', 'armoede', 0.4302354386726606),
#  ('ongeval', 'noodgeval', 0.42477330921845324),
#  ('strijd', 'verovering', 0.4402087165684214),
#  ('vriend', 'leraar', 0.5294965529811716),
#  ('ziekte', 'besmetting', 0.5741085329692707),
#  ('spel', 'truc', 0.3469335882981967),
#  ('broer', 'zoon', 0.27266108776585596),
#  ('tante', 'neef', 0.2958823488118613),
#  ('arbeider', 'monteur', 0.37204195508077487),
#  ('dokter', 'orthodontist', 0.39354470908155503),
#  ('eikenboom', 'esdoorn', 0.6068456170377943),
#  ('bij', 'koningin', 0.39332174485940946),
#  ('auto', 'fiets', 0.2887509536416177),
#  ('doelwit', 'zoektocht', 0.44468826062933486),
#  ('augustus', 'maand', 0.27930125208848405),
#  ('leger', 'ploeg', 0.4270742012764509),
#  ('wolk', 'weer', 0.4570292605755941),
#  ('arts', 'dokter', 0.21411922492820923),
#  ('ravijn', 'vallei', 0.4628122057877886),
#  ('rivier', 'vallei', 0.46566352088936125),
#  ('zon', 'lucht', 0.23302295149985755),
#  ('doel', 'pijl', 0.3923351668779309),
#  ('chocolade', 'taart', 0.4815578065902492),
#  ('omstandigheid', 'situatie', 0.7319377164509442),
#  ('mening', 'keuze', 0.244216911461096),
#  ('ritme', 'melodie', 0.4441232303820121),
#  ('darm', 'zenuw', 0.42668595413311067),
#  ('dag', 'dageraad', 0.5464501382567242),
#  ('vee', 'rundvlees', 0.2914746742662005),
#  ('dokter', 'professor', 0.40252371935121223),
#  ('arm', 'ader', 0.540356325570937),
#  ('kamer', 'bad', 0.22399471521192005),
#  ('onderneming', 'bedrijf', 0.7497114008678946),
#  ('plezier', 'voetbal', 0.21160177636323332),
#  ('heuvel', 'cliff', 0.41084258573646915),
#  ('botten', 'enkel', 0.33499933162706896),
#  ('appel', 'snoep', 0.3293714196209674),
#  ('helper', 'huishulp', 0.48306842569666153),
#  ('leider', 'manager', 0.27756884969690293),
#  ('citroen', 'thee', 0.23970906389995286),
#  ('bij', 'mier', 0.3204685643266248),
#  ('basketbal', 'honkbal', 0.4849054862191627),
#  ('rijst', 'boon', 0.203690071519823),
#  ('bed', 'meubels', 0.3268807754503997),
#  ('emotie', 'passie', 0.48358467561358814),
#  ('anarchie', 'chaos', 0.45503306517579295),
#  ('misdaad', 'overtreding', 0.586746124238241),
#  ('machine', 'aandrijving', 0.3736283763713516),
#  ('strand', 'zee', 0.30164231238650835),
#  ('steeg', 'kom', 0.26778323448314717),
#  ('pot', 'fles', 0.30906331972460027),
#  ('kracht', 'vermogen', 0.564563713172877),
#  ('zaad', 'mosterd', 0.4817307445654643),
#  ('gitaar', 'drumstel', 0.4526492752291769),
#  ('mening', 'idee', 0.17059565181161776),
#  ('noord', 'west', 0.42873201852818216),
#  ('dieet', 'salade', 0.36991499569844005),
#  ('moeder', 'vrouw', 0.6687496531623731),
#  ('vader', 'moeder', 0.3355564253258107),
#  ('kapitein', 'matroos', 0.41468230007257856),
#  ('meter', 'decimeter', 0.5577427397907145),
#  ('bier', 'champagne', 0.4560747343491304),
#  ('motor', 'boot', 0.4160932523473241),
#  ('kaart', 'brug', 0.37358644926730694),
#  ('wetenschap', 'psychologie', 0.5534107205881972),
#  ('zondaar', 'heilige', 0.2658450358258906),
#  ('vernietiging', 'constructie', 0.4695271671042391),
#  ('menigte', 'massa', 0.41126397310506435),
#  ('strand', 'rif', 0.41583251155692236),
#  ('man', 'kind', 0.498749897479237),
#  ('brood', 'kaas', 0.3620235428714131),
#  ('kampioen', 'winnaar', 0.599914932787842),
#  ('feest', 'ceremonie', 0.5649633049744524),
#  ('menu', 'bestelling', 0.2733171985606657),
#  ('koning', 'prinses', 0.5404238554815279),
#  ('rijkdom', 'aanzien', 0.4179539531597478),
#  ('uithoudingsvermogen', 'kracht', 0.419529407911496),
#  ('gevaar', 'bedreiging', 0.566761809080017),
#  ('god', 'priester', 0.2722033575553119),
#  ('mannen', 'broederschap', 0.4191877125856445),
#  ('vriend', 'partner', 0.5009279094504031),
#  ('leraar', 'helper', 0.3697516569789829),
#  ('lichaam', 'buik', 0.4727258336382338),
#  ('tong', 'keel', 0.3764721983701548),
#  ('huis', 'tapijt', 0.4221531597640341),
#  ('intelligentie', 'vaardigheid', 0.605862657165226),
#  ('reis', 'verovering', 0.2975453066107794),
#  ('god', 'prooi', 0.20373418473136126),
#  ('broer', 'ziel', 0.2628258712452341),
#  ('tegenstander', 'rivaal', 0.4927181238385919),
#  ('dood', 'ramp', 0.2767623713105343),
#  ('monster', 'demon', 0.46161853649526413),
#  ('dag', 'ochtend', 0.354700015157928),
#  ('man', 'winnaar', 0.2702035578008171),
#  ('vriend', 'jongen', 0.3985040149583878),
#  ('lied', 'verhaal', 0.35222601400952563),
#  ('straal', 'zonneschijn', 0.4273235453527374),
#  ('kerel', 'hengst', 0.30431301483124606),
#  ('kip', 'rijst', 0.2649434213237431),
#  ('doos', 'lift', 0.24670807002064465),
#  ('boter', 'aardappel', 0.3973200660028166),
#  ('appartement', 'meubels', 0.4770746818671376),
#  ('meer', 'moeras', 0.5445063248484096),
#  ('sla', 'azijn', 0.20927514437338218),
#  ('bloem', 'bol', 0.3573138863301686),
#  ('wolk', 'waas', 0.5242623853151974),
#  ('chauffeur', 'piloot', 0.5110760711150648),
#  ('suiker', 'honing', 0.2262800212074145),
#  ('lichaam', 'schouder', 0.4410558540879018),
#  ('idee', 'beeld', 0.4566669167069411),
#  ('vader', 'broer', 0.2796679726930882),
#  ('maan', 'planeet', 0.37927822752537904),
#  ('bal', 'handschoen', 0.27282783742179334),
#  ('rails', 'hek', 0.2892306223403554),
#  ('kamer', 'bed', 0.41538420184467895),
#  ('bloem', 'struik', 0.4559867889135168),
#  ('botten', 'knie', 0.4398037039045056),
#  ('arm', 'knie', 0.33872440000581927),
#  ('onderkant', 'zijkant', 0.7438252762643014),
#  ('vat', 'ader', 0.42101223988892056),
#  ('kat', 'konijn', 0.38907983831946746),
#  ('vlees', 'spek', 0.29171663726307645),
#  ('geloof', 'begrip', 0.4853935599248456),
#  ('intelligentie', 'inzicht', 0.5162468593789882),
#  ('aandacht', 'interesse', 0.42334779282921653),
#  ('houding', 'zelfvertrouwen', 0.4766995953890134),
#  ('recht', 'rechtvaardigheid', 0.5133756497139285),
#  ('argument', 'overeenkomst', 0.283505915975639),
#  ('diepte', 'omvang', 0.5589042055633304),
#  ('medium', 'nieuws', 0.20914900558378585),
#  ('winnaar', 'kandidaat', 0.46329135617489964),
#  ('verjaardag', 'datum', 0.3132326486196506),
#  ('vergoeding', 'betaling', 0.6150249061037797),
#  ('bijbel', 'psalm', 0.3831774800450855),
#  ('uitgang', 'deuropening', 0.43292757588388736),
#  ('man', 'schildwacht', 0.20331674502846814),
#  ('gangpad', 'hal', 0.29385693718360506),
#  ('whisky', 'jenever', 0.48143829029977886),
#  ('bloed', 'merg', 0.3263202126069226),
#  ('olie', 'nerts', 0.1653682946163396),
#  ('vloer', 'dek', 0.41619829405644754),
#  ('dak', 'vloer', 0.3551555096439194),
#  ('deur', 'vloer', 0.5625820173454922),
#  ('schouder', 'hoofd', 0.4664943506514867),
#  ('wagen', 'rijtuig', 0.38998190359815454),
#  ('auto', 'rijtuig', 0.25226732442542593),
#  ('elleboog', 'enkel', 0.382983818134712),
#  ('rijkdom', 'bekendheid', 0.5077884995929441),
#  ('verdriet', 'schaamte', 0.4867689194780171),
#  ('administratie', 'management', 0.4580965688843722),
#  ('communicatie', 'gesprek', 0.5530371895827424),
#  ('vervuiling', 'atmosfeer', 0.5144965680971514),
#  ('anatomie', 'biologie', 0.5801218200111788),
#  ('hogeschool', 'beroep', 0.4933593197483027),
#  ('boek', 'onderwerp', 0.45904631843055893),
#  ('formule', 'vergelijking', 0.38919724018987256),
#  ('boek', 'informatie', 0.42590396973570094),
#  ('jongen', 'partner', 0.35545469117168355),
#  ('hemel', 'universum', 0.3402743884779688),
#  ('bevolking', 'mensen', 0.540704385810112),
#  ('hogeschool', 'klas', 0.39802424432124056),
#  ('leider', 'burgemeester', 0.31416045282268934),
#  ('rabbijn', 'geestelijke', 0.45195616377195186),
#  ('meter', 'centimeter', 0.4862970008565416),
#  ('polyester', 'katoen', 0.24626384610824423),
#  ('advocaat', 'bankier', 0.38175231258508896),
#  ('viool', 'instrument', 0.28778603152523374),
#  ('opslagplaats', 'hut', 0.25139013106160124),
#  ('pot', 'huishoudelijk apparaat', 0.26389720695126456),
#  ('linnen', 'stof', 0.4034398554868857),
#  ('whisky', 'champagne', 0.4347546125341278),
#  ('meisje', 'kind', 0.38025364358553204),
#  ('hut', 'huisje', 0.46949014203936085),
#  ('vogel', 'kip', 0.2843954776322611),
#  ('raket', 'lawaai', 0.2649152994937357),
#  ('zonsondergang', 'avond', 0.6187377061574106),
#  ('motregen', 'regen', 0.49360086489783334),
#  ('volwassene', 'baby', 0.2734019854729106),
#  ('houtskool', 'kool', 0.3252514816415243),
#  ('lichaam', 'ruggengraat', 0.292820284475557),
#  ('hoofd', 'nagel', 0.35813355151153214),
#  ('boomstam', 'hout', 0.4046644420651885),
#  ('lepel', 'beker', 0.4227249245751624),
#  ('lichaam', 'zenuw', 0.4675366499285503),
#  ('man', 'echtgenoot', 0.29565954624207286),
#  ('botten', 'nek', 0.31428930073315725),
#  ('frustratie', 'woede', 0.4359369833064345),
#  ('rivier', 'zee', 0.32390666760518094),
#  ('taak', 'beroep', 0.3703798774741089),
#  ('vereniging', 'maatschappij', 0.6415298650495478),
#  ('reflectie', 'afbeelding', 0.545700713730697),
#  ('prins', 'koning', 0.5449971632784565),
#  ('sneeuw', 'weer', 0.40416064020602444),
#  ('mensen', 'partij', 0.45752466193564445),
#  ('jongen', 'broer', 0.43634135149894643),
#  ('wortel', 'gras', 0.3201070048092844),
#  ('wenkbrauw', 'oog', 0.34766693342075516),
#  ('geld', 'parel', 0.3286844344609123),
#  ('geld', 'diamant', 0.379732570600718),
#  ('voertuig', 'bus', 0.3746691184976236),
#  ('taxi', 'bus', 0.48550521264383123),
#  ('huis', 'schuur', 0.46423157493462885),
#  ('vinger', 'handpalm', 0.3467942795998336),
#  ('auto', 'brug', 0.3141541248013865),
#  ('inspanning', 'moeilijkheid', 0.3023623985475661),
#  ('feit', 'inzicht', 0.2630634602444398),
#  ('beroep', 'management', 0.1749985276550602),
#  ('kanker', 'ziekte', 0.46241837130272695),
#  ('woord', 'krant', 0.43501755615501364),
#  ('componist', 'schrijver', 0.5172832247428073),
#  ('acteur', 'zanger', 0.5107592783586621),
#  ('schuilplaats', 'hut', 0.34480549831114643),
#  ('badkamer', 'keuken', 0.5891882107807859),
#  ('cabine', 'hut', 0.3869464789424361),
#  ('deur', 'keuken', 0.540785907322511),
#  ('waarde', 'geloof', 0.4634536371300748),
#  ('wijsheid', 'intelligentie', 0.6376166538113511),
#  ('onwetendheid', 'intelligentie', 0.5375894502278502),
#  ('gelukkigheid', 'geluk', 0.837031169260805),
#  ('idee', 'plan', 0.3595133347144682),
#  ('humeur', 'emotie', 0.4674352202112542),
#  ('gelukkigheid', 'vrede', 0.5038827749178888),
#  ('wanhoop', 'ongeluk', 0.27200329071137475),
#  ('logica', 'rekenkunde', 0.2823831087837985),
#  ('ontkenning', 'bekentenis', 0.5871526329681415),
#  ('argument', 'kritiek', 0.3426760558810654),
#  ('agressie', 'vijandigheid', 0.5696306622789837),
#  ('hysterie', 'verwarring', 0.4213309876109534),
#  ('scheikunde', 'theorie', 0.5089194891868869),
#  ('juridische procedures', 'oordeel', 0.4574209383617129),
#  ('comfort', 'veiligheid', 0.33463411012751704),
#  ('zelfvertrouwen', 'zelf', 0.395016602803042),
#  ('visie', 'perceptie', 0.5453411546156377),
#  ('tijdperk', 'decennium', 0.44053550088367854),
#  ('biografie', 'fictie', 0.4994744262002727),
#  ('discussie', 'argument', 0.42427506476946114),
#  ('code', 'symbool', 0.3862369650277788),
#  ('gevaar', 'ziekte', 0.4923856994137352),
#  ('ongeval', 'ramp', 0.2402806255343136),
#  ('reis', 'excursie', 0.3956748223384469),
#  ('activiteit', 'beweging', 0.6087157342050589),
#  ('roddel', 'nieuws', 0.2564051619776639),
#  ('vader', 'god', 0.3629519303938191),
#  ('actie', 'cursus', 0.3774680308574482),
#  ('koorts', 'ziekte', 0.4703458186728557),
#  ('luchtvaart', 'vlucht', 0.6436535447964742),
#  ('spel', 'actie', 0.3516229559029377),
#  ('molecuul', 'lucht', 0.34177910809124595),
#  ('huis', 'toestand', 0.4527249016445915),
#  ('woord', 'literatuur', 0.4148840317202837),
#  ('volwassene', 'voogd', 0.4371950014951811),
#  ('krant', 'informatie', 0.34907719297742923),
#  ('communicatie', 'televisie', 0.543616557934895),
#  ('neef', 'oom', 0.24558025093485567),
#  ('auteur', 'lezer', 0.3602055486763997),
#  ('kerel', 'partner', 0.34853795100719687),
#  ('gebied', 'hoek', 0.42163377997474405),
#  ('ballade', 'lied', 0.4211940638566607),
#  ('muur', 'decoratie', 0.44552677801819085),
#  ('woord', 'pagina', 0.4159441088077017),
#  ('verpleegster', 'wetenschapper', 0.42663070115027274),
#  ('politicus', 'president', 0.38150395306378204),
#  ('president', 'burgemeester', 0.3836023960391472),
#  ('boek', 'essay', 0.3260394781495357),
#  ('man', 'strijder', 0.2927940674270966),
#  ('artikel', 'tijdschrift', 0.4461354541468998),
#  ('ontbijt', 'avondeten', 0.6155313556377666),
#  ('menigte', 'parade', 0.35053658343194366),
#  ('gangpad', 'gang', 0.5072110561703796),
#  ('leraar', 'rabbijn', 0.5525983966252926),
#  ('heup', 'lip', 0.3735413384036246),
#  ('boek', 'artikel', 0.4376342165233981),
#  ('kamer', 'gevangeniscel', 0.4209862434177954),
#  ('doos', 'kraampje', 0.308479518597432),
#  ('dochter', 'kind', 0.3679079532985829),
#  ('ledemaat', 'been', 0.32512917697405996),
#  ('lever', 'long', 0.3715974150444017),
#  ('klaslokaal', 'gang', 0.1741213409848193),
#  ('berg', 'richel', 0.365215932615415),
#  ('auto', 'lift', 0.3858293042050162),
#  ('bed', 'bank', 0.41177081842806995),
#  ('kleding', 'knoop', 0.3696535843690278),
#  ('kleding', 'jas', 0.1783890506265249),
#  ('nier', 'orgaan', 0.31180867060207135),
#  ('appel', 'saus', 0.2757766112249726),
#  ('kip', 'steak', 0.2621026004698999),
#  ('auto', 'slang', 0.21617002138905506),
#  ('tabak', 'sigaret', 0.5905014680522268),
#  ('student', 'professor', 0.4325103839595872),
#  ('baby', 'dochter', 0.36774846817546814),
#  ('pijp', 'sigaar', 0.3270517227159093),
#  ('melk', 'sap', 0.2371599661014953),
#  ('doos', 'sigaar', 0.23207641565869674),
#  ('appartement', 'hotel', 0.4200409159375901),
#  ('beker', 'wafel', 0.43081003337672613),
#  ('paard', 'os', 0.20404477312212044),
#  ('keel', 'neus', 0.3511443630179197),
#  ('botten', 'tanden', 0.41506546203108996),
#  ('botten', 'elleboog', 0.39556142738390276),
#  ('spek', 'boon', 0.24278448200507868),
#  ('beker', 'pot', 0.3835633325580398),
#  ('bewijs', 'feit', 0.33167962162587267),
#  ('overeenkomst', 'afspraak', 0.7114228229284555),
#  ('verjaardag', 'jaar', 0.5176128257000426),
#  ('woord', 'referentie', 0.47537465678252255),
#  ('auteur', 'maker', 0.3430185103631529),
#  ('atoom', 'koolstof', 0.43705371279251803),
#  ('aartsbisschop', 'bisschop', 0.7548567320120444),
#  ('brief', 'paragraaf', 0.33596938688349626),
#  ('pagina', 'paragraaf', 0.4482959165484686),
#  ('kerktoren', 'kapel', 0.4765612585023825),
#  ('spier', 'botten', 0.32040823953870806),
#  ('spier', 'tong', 0.34474046493812316),
#  ('jongen', 'soldaat', 0.36803907119798906),
#  ('buik', 'onderbuik', 0.7167193133433282),
#  ('kerel', 'meisje', 0.33745185277032574),
#  ('bed', 'stoel', 0.3987016253882813),
#  ('kleding', 'mantel', 0.47294464015379234),
#  ('pistool', 'mes', 0.2165974817009324),
#  ('blik', 'metaal', 0.38726975837153216),
#  ('fles', 'container', 0.27316723688989036),
#  ('kip', 'kalkoen', 0.3435644940414133),
#  ('vlees', 'broodje', 0.49427085485285677),
#  ('arm', 'botten', 0.31125509930530393),
#  ('hals', 'ruggengraat', 0.21449320301768038),
#  ('appel', 'citroen', 0.2644974471096697),
#  ('lijden', 'verdriet', 0.47312446509259004),
#  ('opdracht', 'taak', 0.3923055816030318),
#  ('nacht', 'dageraad', 0.4741069244580173),
#  ('diner', 'soep', 0.3763157851106519),
#  ('kalf', 'stier', 0.38419041806592164),
#  ('sneeuw', 'storm', 0.3161814925141671),
#  ('nagel', 'hand', 0.28822081994550386),
#  ('hond', 'paard', 0.5781823755039178),
#  ('arm', 'hals', 0.37770208460010907),
#  ('kogel', 'kanon', 0.21506390137249032),
#  ('griep', 'koorts', 0.492189028057049),
#  ('vergoeding', 'salaris', 0.5568705204475198),
#  ('zenuw', 'hersenen', 0.5528530920209948),
#  ('beest', 'dier', 0.4772259944938102),
#  ('diner', 'kip', 0.2702687989182384),
#  ('meisje', 'dienstmeisje', 0.5666090881244873),
#  ('kind', 'jongen', 0.4386201114729432),
#  ('alcohol', 'wijn', 0.48594745282954616),
#  ('neus', 'mond', 0.2253935839918137),
#  ('weg', 'steeg', 0.4820268930327996),
#  ('bel', 'deur', 0.3270623327255857),
#  ('doos', 'hoed', 0.3585547044191422),
#  ('geloof', 'indruk', 0.40029600921114084),
#  ('vooroordeel', 'mening', 0.18588204928306845),
#  ('aandacht', 'bewustzijn', 0.5625258314902265),
#  ('woede', 'stemming', 0.22569438709849565),
#  ('elegantie', 'stijl', 0.5050696871174977),
#  ('schoonheid', 'leeftijd', 0.35778556948457463),
#  ('boek', 'thema', 0.38564258403159607),
#  ('vriend', 'moeder', 0.5228455821970042),
#  ('vitamine', 'ijzer', 0.4828059666690126),
#  ('auto', 'fabriek', 0.2543050065091824),
#  ('verdrag', 'overeenkomst', 0.732432742499546),
#  ('hoofdstuk', 'keuze', 0.36942697725083223),
#  ('rekenkunde', 'ritme', 0.2867316393517029),
#  ('winnaar', 'aanwezigheid', 0.30494823442335744),
#  ('geloof', 'bloem', 0.3549457031850106),
#  ('winnaar', 'doel', 0.40985044266665427),
#  ('truc', 'maat', 0.4013433847752719),
#  ('keuze', 'neiging', 0.4916041458172372),
#  ('volkslied', 'verovering', 0.3246698896202347),
#  ('uithoudingsvermogen', 'muziekgroep', 0.2804855433902755),
#  ('gevangenis', 'keuze', 0.3141655582750243),
#  ('conditie', 'jongen', 0.27914060038475047),
#  ('bloem', 'volharding', 0.3492069110590851),
#  ('gat', 'overeenkomst', 0.2554892752006799),
#  ('dokter', 'temperament', 0.16070456871799801),
#  ('broederschap', 'deur', 0.3798782481643406),
#  ('taak', 'vrouw', 0.34555866976540317),
#  ('broederschap', 'honkbal', 0.31410353019684606),
#  ('cent', 'maat', 0.24870497572175904),
#  ('aanwezigheid', 'deur', 0.3748920916297351),
#  ('muis', 'beheer', 0.35263470234343763),
#  ('taak', 'snelweg', 0.38463024748524055),
#  ('likeur', 'eeuw', 0.2727008406885103),
#  ('taak', 'rietje', 0.35012143259925965),
#  ('eiland', 'taak', 0.26233165944447007),
#  ('nacht', 'hoofdstuk', 0.38169460860890375),
#  ('vervuiling', 'president', 0.1131765556489451),
#  ('pistool', 'truc', 0.3678140943772181),
#  ('bad', 'truc', 0.31524280591442116),
#  ('dieet', 'appel', 0.22699057343106),
#  ('cent', 'vrouw', 0.2207851624384148),
#  ('hoofdstuk', 'staart', 0.42720747724042),
#  ('cursus', 'buik', 0.3196836780768384),
#  ('volkslied', 'rietje', 0.3234102069309536),
#  ('tandarts', 'kolonel', 0.2815088374848457),
#  ('echtgenote', 'rietje', 0.36267351342355675),
#  ('gat', 'vrouw', 0.24068317234999462),
#  ('student', 'president', 0.2670878695281151),
#  ('bad', 'vrouw', 0.153901913129534),
#  ('mensen', 'cent', 0.25391072953520666),
#  ('formule', 'logaritme', 0.38082938475444106),
#  ('vrouw', 'bont', 0.34413472547312646),
#  ('appel', 'zonneschijn', 0.21104269087692276),
#  ('pistool', 'dageraad', 0.2722149896367689),
#  ('maaltijd', 'staart', 0.3755319542853616),
#  ('camera', 'president', 0.2788622975786155),
#  ('likeur', 'muziekgroep', 0.2258741659516063),
#  ('buik', 'ader', 0.2615347629960897),
#  ('pistool', 'bont', 0.3302071728422849),
#  ('bank', 'honkbal', 0.280901671935304),
#  ('arbeider', 'camera', 0.14339211176610692),
#  ('dek', 'muis', 0.32719337314247804),
#  ('rijst', 'jongen', 0.276762158984603),
#  ('mensen', 'pistool', 0.3175078142258564),
#  ('klif', 'staart', 0.233540394320775),
#  ('enkel', 'raam', 0.32083198187557427),
#  ('prinses', 'eiland', 0.2672952537069799),
#  ('container', 'muis', 0.2657210046485357),
#  ('wagen', 'container', 0.34243466563883385),
#  ('mensen', 'ballon', 0.2122515596201788),
#  ('dollar', 'mensen', 0.2758124563709972),
#  ('bad', 'ballon', 0.20678092139770993),
#  ('buik', 'slaapkamer', 0.36125644037094856),
#  ('fiets', 'slaapkamer', 0.35074393768549444),
#  ('boomstam', 'bad', 0.23296567136462154),
#  ('kom', 'staart', 0.26175514233939684),
#  ('gaan', 'toestaan', 0.42006892711362326),
#  ('nemen', 'stelen', 0.4215775563974895),
#  ('luisteren', 'horen', 0.8228027810250004),
#  ('denken', 'rationaliseren', 0.4403346848497924),
#  ('plaatsvinden', 'voorkomen', 0.5398681939983129),
#  ('voorbijgaan', 'verdwijnen', 0.46369711573670386),
#  ('vermenigvuldigen', 'delen', 0.5268293957915056),
#  ('pleiten', 'bedelen', 0.5766195931935985),
#  ('beginnen', 'ontstaan', 0.5647613403089319),
#  ('beschermen', 'verdedigen', 0.6070284297439867),
#  ('doden', 'vernietigen', 0.5601316788140094),
#  ('creëren', 'maken', 0.6438864295996798),
#  ('accepteren', 'weigeren', 0.6296027105655512),
#  ('negeren', 'vermijden', 0.343987047532344),
#  ('dragen', 'brengen', 0.5943332184320997),
#  ('vertrekken', 'binnenkomen', 0.5044597162798002),
#  ('kiezen', 'stemmen op', 0.5248903972111214),
#  ('verliezen', 'falen', 0.6391318443827884),
#  ('aanmoedigen', 'ontmoedigen', 0.8137411234569478),
#  ('bereiken', 'volbrengen', 0.6397836706886206),
#  ('maken', 'opbouwen', 0.5193576621691279),
#  ('luisteren', 'gehoorzamen', 0.5808429943577945),
#  ('delen', 'melden', 0.4649029501091761),
#  ('ontvangen', 'geven', 0.5338169511881253),
#  ('lenen', 'smeken', 0.41241735267612206),
#  ('nemen', 'verkrijgen', 0.5352231256139687),
#  ('adviseren', 'aanbevelen', 0.6492524093474838),
#  ('imiteren', 'uitbeelden', 0.3861704001616534),
#  ('winnen', 'slagen', 0.5076563770021436),
#  ('denken', 'besluiten', 0.5681177631951903),
#  ('groeten', 'ontmoeten', 0.5308001366475575),
#  ('akkoord gaan', 'argumenteren', 0.5196832051982208),
#  ('genieten', 'vermaken', 0.6400578294420385),
#  ('vernietigen', 'maken', 0.4147233725921911),
#  ('redden', 'beschermen', 0.24107731994570625),
#  ('geven', 'lenen', 0.49099205848514615),
#  ('begrijpen', 'weten', 0.6978607173875825),
#  ('nemen', 'ontvangen', 0.5793332676150107),
#  ('accepteren', 'erkennen', 0.48703196395198234),
#  ('beslissen', 'kiezen', 0.6279091764815138),
#  ('accepteren', 'geloven', 0.6205722746414398),
#  ('houden', 'bezitten', 0.5946751855350801),
#  ('rondzwerven', 'dwalen', 0.534673821311585),
#  ('slagen', 'falen', 0.5731556095905945),
#  ('besteden', 'redden', 0.28236053755824736),
#  ('vertrekken', 'gaan', 0.5349509207976145),
#  ('komen', 'bijwonen', 0.5074974537618276),
#  ('weten', 'geloven', 0.650492857836347),
#  ('verzamelen', 'ontmoeten', 0.5777915881563775),
#  ('maken', 'verdienen', 0.5657139386523901),
#  ('vergeten', 'negeren', 0.4300359173562057),
#  ('vermenigvuldigen', 'toevoegen', 0.4658057857297714),
#  ('krimpen', 'groeien', 0.3665089243563158),
#  ('aankomen', 'komen', 0.7016135239405146),
#  ('slagen', 'proberen', 0.4529538716231327),
#  ('accepteren', 'ontkennen', 0.624580493515046),
#  ('aankomen', 'vertrekken', 0.5207349002068025),
#  ('akkoord gaan', 'afwijken', 0.4914569511201784),
#  ('sturen', 'ontvangen', 0.47715636304636927),
#  ('winnen', 'domineren', 0.5656983293742496),
#  ('toevoegen', 'verdelen', 0.4286921736198455),
#  ('doden', 'wurgen', 0.4191419712963491),
#  ('verwerven', 'krijgen', 0.6105896636786021),
#  ('deelnemen', 'meedoen', 0.8305640354526868),
#  ('vertrekken', 'achterblijven', 0.567711019423216),
#  ('gaan', 'komen', 0.5977361610654317),
#  ('nemen', 'dragen', 0.6186358650024109),
#  ('vergeten', 'leren', 0.47683592897027377),
#  ('benoemen', 'kiezen', 0.4589221667741608),
#  ('verloven', 'trouwen', 0.507234339735705),
#  ('vragen', 'bidden', 0.27052859755584496),
#  ('gaan', 'sturen', 0.4930166669703974),
#  ('nemen', 'leveren', 0.5806196287960416),
#  ('spreken', 'luisteren', 0.5854438374228597),
#  ('analyseren', 'evalueren', 0.6176542798839768),
#  ('argumenteren', 'rationaliseren', 0.5432389654292455),
#  ('verliezen', 'houden', 0.4795674844721959),
#  ('vergelijken', 'analyseren', 0.5320064797307099),
#  ('desorganiseren', 'organiseren', 0.7187517213645708),
#  ('gaan', 'verkopen', 0.4325377070737919),
#  ('nemen', 'bezitten', 0.5664197121730162),
#  ('leren', 'luisteren', 0.6372325788587686),
#  ('vernietigen', 'bouwen', 0.4410370797678059),
#  ('creëren', 'bouwen', 0.6194057783378123),
#  ('stelen', 'kopen', 0.43475898881785263),
#  ('doden', 'ophangen', 0.40182578612260855),
#  ('vergeten', 'weten', 0.5135788519076517),
#  ('creëren', 'voorstellen', 0.4985722632317115),
#  ('doen', 'gebeuren', 0.5328419783063222),
#  ('winnen', 'bereiken', 0.5051469402833885),
#  ('geven', 'weigeren', 0.3787959312184323),
#  ('verdienen', 'nemen', 0.5160477041432534),
#  ('krijgen', 'zetten', 0.4751913273924587),
#  ('lokaliseren', 'vinden', 0.39962484993830033),
#  ('verschijnen', 'bijwonen', 0.4742396001895857),
#  ('weten', 'begrijpen', 0.6978607173875825),
#  ('doen alsof', 'voorstellen', 0.37679394350274),
#  ('tevredenstellen', 'voldoen', 0.5551790802239984),
#  ('koesteren', 'houden', 0.4736515644337433),
#  ('argumenteren', 'verschillen', 0.4691772060473112),
#  ('overwinnen', 'domineren', 0.595379446712875),
#  ('zich gedragen', 'gehoorzamen', 0.5041377150026061),
#  ('samenwerken', 'deelnemen', 0.6064919108958355),
#  ('bereiken', 'proberen', 0.5511581330964828),
#  ('falen', 'ontmoedigen', 0.4368082058178864),
#  ('beginnen', 'stoppen', 0.5638411734870571),
#  ('zeggen', 'deelnemen', 0.4843996298763397),
#  ('komen', 'brengen', 0.571393878615203),
#  ('bekendmaken', 'aankondigen', 0.7453493126577291),
#  ('lezen', 'begrijpen', 0.5825090541653936),
#  ('nemen', 'achterlaten', 0.470687764017032),
#  ('verkondigen', 'aankondigen', 0.8315796696668659),
#  ('verwerven', 'verkrijgen', 0.7248307794920387),
#  ('concluderen', 'beslissen', 0.590801762576792),
#  ('tevredenstellen', 'pleiten', 0.42613259691283045),
#  ('argumenteren', 'bewijzen', 0.6895582941823956),
#  ('vragen', 'pleiten', 0.4396451714034473),
#  ('vinden', 'verdwijnen', 0.4544463865196169),
#  ('inspecteren', 'examineren', 0.79735741631827),
#  ('controleren', 'rechtvaardigen', 0.45566816936692767),
#  ('vermoeden', 'voorspellen', 0.5180669060108941),
#  ('leren', 'evalueren', 0.4819670071702229),
#  ('argumenteren', 'rechtvaardigen', 0.6581929350649373),
#  ('maken', 'worden', 0.5975763728830629),
#  ('ontdekken', 'ontstaan', 0.5824434151531503),
#  ('bereiken', 'slagen', 0.4719085898771086),
#  ('geven', 'plaatsen', 0.44953272508500575),
#  ('begrijpen', 'luisteren', 0.646538864401317),
#  ('uitbreiden', 'groeien', 0.6638793167149434),
#  ('lenen', 'verkopen', 0.5016281499385971),
#  ('houden', 'beschermen', 0.5239956539722387),
#  ('uitleggen', 'bewijzen', 0.5493927921422418),
#  ('vermoeden', 'doen alsof', 0.42461970391616594),
#  ('akkoord gaan', 'voldoen', 0.6148101660230181),
#  ('vergeven', 'vergeten', 0.5331383914880706),
#  ('verklaren', 'uitleggen', 0.6907410523916433),
#  ('begrijpen', 'vergeven', 0.5222038511301028),
#  ('herinneren', 'vergeten', 0.6558476592534966),
#  ('krijgen', 'achterblijven', 0.4206296138738341),
#  ('realiseren', 'ontdekken', 0.6084081214187739),
#  ('nodig hebben', 'vragen', 0.5772892798504373),
#  ('negeren', 'vragen', 0.39765062883787666),
#  ('denken', 'informeren', 0.42771821041189073),
#  ('afwijzen', 'vermijden', 0.6786361179399372),
#  ('argumenteren', 'overtuigen', 0.6582081921326683),
#  ('najagen', 'overtuigen', 0.3056102618845605),
#  ('accepteren', 'vergeven', 0.5194686566327414),
#  ('doen', 'stoppen', 0.518260198735818),
#  ('onderzoeken', 'herzien', 0.38384760017995795),
#  ('discussiëren', 'uitleggen', 0.5122859256707861),
#  ('verschuldigd zijn', 'lenen', 0.42744423531160014),
#  ('verkennen', 'ontdekken', 0.6759831566501674),
#  ('klagen', 'argumenteren', 0.5102144168133297),
#  ('terugtrekken', 'afwijzen', 0.5888782614777894),
#  ('houden', 'lenen', 0.42452267077967626),
#  ('smeken', 'vragen', 0.4801933631328742),
#  ('regelen', 'organiseren', 0.6947865926229825),
#  ('verminderen', 'krimpen', 0.3752215474151718),
#  ('spreken', 'erkennen', 0.35759555111310243),
#  ('geven', 'uitlenen', 0.4641665426074242),
#  ('doden', 'verdedigen', 0.4919553296847437),
#  ('verdwijnen', 'krimpen', 0.37927140925454816),
#  ('leveren', 'dragen', 0.6023471217348092),
#  ('ademen', 'verstikken', 0.2713861225611548),
#  ('erkennen', 'melden', 0.440597046514074),
#  ('worden', 'verschijnen', 0.5317630614042248),
#  ('doen alsof', 'lijken', 0.5569740658776247),
#  ('bereiken', 'worden', 0.513565081206986),
#  ('overnadenken', 'denken', 0.536503455307145),
#  ('bepalen', 'voorspellen', 0.4771947554228483),
#  ('tevredenstellen', 'vermaken', 0.5762432928752581),
#  ('blijven', 'behouden', 0.5265024285735121),
#  ('doen alsof', 'uitbeelden', 0.4253121955493514),
#  ('vergeten', 'onderhouden', 0.4597497672510407),
#  ('willen', 'kiezen', 0.5015110186627623),
#  ('verliezen', 'krijgen', 0.5502534160527899),
#  ('proberen', 'denken', 0.4830211179926692),
#  ('worden', 'lijken', 0.5218455992361912),
#  ('vertrekken', 'negeren', 0.38193942151790794),
#  ('accepteren', 'aanbevelen', 0.5498619386879892),
#  ('vertrekken', 'zwerven', 0.4357341464353043),
#  ('houden', 'geven', 0.4978710573162086),
#  ('geven', 'toestaan', 0.44581654576002216),
#  ('brengen', 'sturen', 0.5976403487914989),
#  ('opnemen', 'leren', 0.46242056854131225),
#  ('verwerven', 'vinden', 0.4963541088003897),
#  ('vertrekken', 'verschijnen', 0.46804587070060494),
#  ('creëren', 'vernietigen', 0.49311053563391705),
#  ('beginnen', 'gaan', 0.5260947901786398),
#  ('krijgen', 'kopen', 0.6404181307830775),
#  ('verzamelen', 'opslaan', 0.5790849620717445),
#  ('vervangen', 'herstellen', 0.3987443284503482),
#  ('samenvoegen', 'toevoegen', 0.5938659023088083),
#  ('samenvoegen', 'trouwen', 0.4939841431817445),
#  ('accepteren', 'bezorgen', 0.5284556012390214),
#  ('bijvoegen', 'samenvoegen', 0.6504642597921368),
#  ('plaatsen', 'ophangen', 0.4632853559480925),
#  ('gaan', 'binnenkomen', 0.4721787794119805),
#  ('communiceren', 'bidden', 0.20482227093170774),
#  ('geven', 'stelen', 0.32305694441314137),
#  ('toevoegen', 'bouwen', 0.5126266688292438),
#  ('brengen', 'herstellen', 0.363401006256217),
#  ('begrijpen', 'voldoen', 0.6132613918409083),
#  ('belichamen', 'beslissen', 0.41946507123064075),
#  ('organiseren', 'worden', 0.4966456109422472),
#  ('geven', 'weten', 0.4850905360522876),
#  ('zeggen', 'verifiëren', 0.4912029009537677),
#  ('samenwerken', 'aansluiten bij', 0.5635022391741514),
#  ('regelen', 'vereisen', 0.33451774422591785),
#  ('lenen', 'willen', 0.4268825074837138),
#  ('onderzoeken', 'streven', 0.5073375389055963),
#  ('negeren', 'verkennen', 0.36039431838667707),
#  ('brengen', 'klagen', 0.3995771504984333),
#  ('binnentreden', 'verschuldigd zijn', 0.34052368221322205),
#  ('belichamen', 'melden', 0.3900919602943801),
#  ('herinneren', 'verkopen', 0.45109361343232063),
#  ('opnemen', 'bezitten', 0.48901568880280105),
#  ('samenvoegen', 'verwerven', 0.5141243186363931),
#  ('sturen', 'bijwonen', 0.4905802934864731),
#  ('verzamelen', 'bijwonen', 0.5208547083479739),
#  ('opnemen', 'intrekken', 0.5673069854935715),
#  ('bijwonen', 'aankomen', 0.5319656780221755)]

# %%
# Store results in DataFrame and round 2 decimals
df = process_responses_embeddings(response)

# Show results
df
# Out:
#            word1        word2  similarity_score
# 0            oud        nieuw              0.30
# 1           slim  intelligent              0.27
# 2           hard     moeilijk              0.47
# 3       gelukkig      vrolijk              0.57
# 4           hard        stoer              0.24
# ..           ...          ...               ...
# 992  samenvoegen    verwerven              0.51
# 993       sturen     bijwonen              0.49
# 994   verzamelen     bijwonen              0.52
# 995      opnemen    intrekken              0.57
# 996     bijwonen     aankomen              0.53
#
# [997 rows x 3 columns]

# %% [markdown]
# Note that this shows the cosine similarity score on the scale [-1; 1]. The similarity_score will be normalized to the SimLex questionnaire scale [0; 10] in the evaluation notebook.

# %%
# Define file_path
file_path = '../../../data/text-embedding-3-small/nl.csv'

# Check if the file already exists
if not os.path.exists(file_path):
    df.to_csv(file_path, index=False)
    print("File saved successfully.")
else:
    print("File already exists. Dataframe was not saved to prevent overwriting.")
# Out:
# File saved successfully.
