# %% [markdown]
# ### **0. Set-up**

# %%
# Import libraries and utils
# %run '../../utils.ipynb'

# %%
# Get api key
load_dotenv()
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

# Set client
client = OpenAI()

# %%
# Load dataframe
en_simlex = pd.read_csv("../../../data/dataset/en-simlex-999.txt", delimiter='\t')

# Select subset
# en_simlex = en_simlex.head(5)

# Convert to tuple
word_pairs = list(zip(en_simlex['word1'], en_simlex['word2']))

# %%
# Show results
word_pairs
# Out:
# [('old', 'new'),
#  ('smart', 'intelligent'),
#  ('hard', 'difficult'),
#  ('happy', 'cheerful'),
#  ('hard', 'easy'),
#  ('fast', 'rapid'),
#  ('happy', 'glad'),
#  ('short', 'long'),
#  ('stupid', 'dumb'),
#  ('weird', 'strange'),
#  ('wide', 'narrow'),
#  ('bad', 'awful'),
#  ('easy', 'difficult'),
#  ('bad', 'terrible'),
#  ('hard', 'simple'),
#  ('smart', 'dumb'),
#  ('insane', 'crazy'),
#  ('happy', 'mad'),
#  ('large', 'huge'),
#  ('hard', 'tough'),
#  ('new', 'fresh'),
#  ('sharp', 'dull'),
#  ('quick', 'rapid'),
#  ('dumb', 'foolish'),
#  ('wonderful', 'terrific'),
#  ('strange', 'odd'),
#  ('happy', 'angry'),
#  ('narrow', 'broad'),
#  ('simple', 'easy'),
#  ('old', 'fresh'),
#  ('apparent', 'obvious'),
#  ('inexpensive', 'cheap'),
#  ('nice', 'generous'),
#  ('weird', 'normal'),
#  ('weird', 'odd'),
#  ('bad', 'immoral'),
#  ('sad', 'funny'),
#  ('wonderful', 'great'),
#  ('guilty', 'ashamed'),
#  ('beautiful', 'wonderful'),
#  ('confident', 'sure'),
#  ('dumb', 'dense'),
#  ('large', 'big'),
#  ('nice', 'cruel'),
#  ('impatient', 'anxious'),
#  ('big', 'broad'),
#  ('strong', 'proud'),
#  ('unnecessary', 'necessary'),
#  ('restless', 'young'),
#  ('dumb', 'intelligent'),
#  ('bad', 'great'),
#  ('difficult', 'simple'),
#  ('necessary', 'important'),
#  ('bad', 'terrific'),
#  ('mad', 'glad'),
#  ('honest', 'guilty'),
#  ('easy', 'tough'),
#  ('easy', 'flexible'),
#  ('certain', 'sure'),
#  ('essential', 'necessary'),
#  ('different', 'normal'),
#  ('sly', 'clever'),
#  ('crucial', 'important'),
#  ('harsh', 'cruel'),
#  ('childish', 'foolish'),
#  ('scarce', 'rare'),
#  ('friendly', 'generous'),
#  ('fragile', 'frigid'),
#  ('long', 'narrow'),
#  ('big', 'heavy'),
#  ('rough', 'frigid'),
#  ('bizarre', 'strange'),
#  ('illegal', 'immoral'),
#  ('bad', 'guilty'),
#  ('modern', 'ancient'),
#  ('new', 'ancient'),
#  ('dull', 'funny'),
#  ('happy', 'young'),
#  ('easy', 'big'),
#  ('great', 'awful'),
#  ('tiny', 'huge'),
#  ('polite', 'proper'),
#  ('modest', 'ashamed'),
#  ('exotic', 'rare'),
#  ('dumb', 'clever'),
#  ('delightful', 'wonderful'),
#  ('noticeable', 'obvious'),
#  ('afraid', 'anxious'),
#  ('formal', 'proper'),
#  ('dreary', 'dull'),
#  ('delightful', 'cheerful'),
#  ('unhappy', 'mad'),
#  ('sad', 'terrible'),
#  ('sick', 'crazy'),
#  ('violent', 'angry'),
#  ('laden', 'heavy'),
#  ('dirty', 'cheap'),
#  ('elastic', 'flexible'),
#  ('hard', 'dense'),
#  ('recent', 'new'),
#  ('bold', 'proud'),
#  ('sly', 'strange'),
#  ('strange', 'sly'),
#  ('dumb', 'rare'),
#  ('sly', 'tough'),
#  ('terrific', 'mad'),
#  ('modest', 'flexible'),
#  ('fresh', 'wide'),
#  ('huge', 'dumb'),
#  ('large', 'flexible'),
#  ('dirty', 'narrow'),
#  ('wife', 'husband'),
#  ('book', 'text'),
#  ('groom', 'bride'),
#  ('night', 'day'),
#  ('south', 'north'),
#  ('plane', 'airport'),
#  ('uncle', 'aunt'),
#  ('horse', 'mare'),
#  ('bottom', 'top'),
#  ('friend', 'buddy'),
#  ('student', 'pupil'),
#  ('world', 'globe'),
#  ('leg', 'arm'),
#  ('plane', 'jet'),
#  ('woman', 'man'),
#  ('horse', 'colt'),
#  ('actress', 'actor'),
#  ('teacher', 'instructor'),
#  ('movie', 'film'),
#  ('bird', 'hawk'),
#  ('word', 'dictionary'),
#  ('money', 'salary'),
#  ('dog', 'cat'),
#  ('area', 'region'),
#  ('navy', 'army'),
#  ('book', 'literature'),
#  ('clothes', 'closet'),
#  ('sunset', 'sunrise'),
#  ('child', 'adult'),
#  ('cow', 'cattle'),
#  ('book', 'story'),
#  ('winter', 'summer'),
#  ('taxi', 'cab'),
#  ('tree', 'maple'),
#  ('bed', 'bedroom'),
#  ('roof', 'ceiling'),
#  ('disease', 'infection'),
#  ('arm', 'shoulder'),
#  ('sheep', 'lamb'),
#  ('lady', 'gentleman'),
#  ('boat', 'anchor'),
#  ('priest', 'monk'),
#  ('toe', 'finger'),
#  ('river', 'stream'),
#  ('anger', 'fury'),
#  ('date', 'calendar'),
#  ('sea', 'ocean'),
#  ('second', 'minute'),
#  ('hand', 'thumb'),
#  ('wood', 'log'),
#  ('mud', 'dirt'),
#  ('hallway', 'corridor'),
#  ('way', 'manner'),
#  ('mouse', 'cat'),
#  ('cop', 'sheriff'),
#  ('death', 'burial'),
#  ('music', 'melody'),
#  ('beer', 'alcohol'),
#  ('mouth', 'lip'),
#  ('storm', 'hurricane'),
#  ('tax', 'income'),
#  ('flower', 'violet'),
#  ('paper', 'cardboard'),
#  ('floor', 'ceiling'),
#  ('beach', 'seashore'),
#  ('rod', 'curtain'),
#  ('hound', 'fox'),
#  ('street', 'alley'),
#  ('boat', 'deck'),
#  ('car', 'horn'),
#  ('friend', 'guest'),
#  ('employer', 'employee'),
#  ('hand', 'wrist'),
#  ('ball', 'cannon'),
#  ('alcohol', 'brandy'),
#  ('victory', 'triumph'),
#  ('telephone', 'booth'),
#  ('door', 'doorway'),
#  ('motel', 'inn'),
#  ('clothes', 'cloth'),
#  ('steak', 'meat'),
#  ('nail', 'thumb'),
#  ('band', 'orchestra'),
#  ('book', 'bible'),
#  ('business', 'industry'),
#  ('winter', 'season'),
#  ('decade', 'century'),
#  ('alcohol', 'gin'),
#  ('hat', 'coat'),
#  ('window', 'door'),
#  ('arm', 'wrist'),
#  ('house', 'apartment'),
#  ('glass', 'crystal'),
#  ('wine', 'brandy'),
#  ('creator', 'maker'),
#  ('dinner', 'breakfast'),
#  ('arm', 'muscle'),
#  ('bubble', 'suds'),
#  ('bread', 'flour'),
#  ('death', 'tragedy'),
#  ('absence', 'presence'),
#  ('gun', 'cannon'),
#  ('grass', 'blade'),
#  ('ball', 'basket'),
#  ('hose', 'garden'),
#  ('boy', 'kid'),
#  ('church', 'choir'),
#  ('clothes', 'drawer'),
#  ('tower', 'bell'),
#  ('father', 'parent'),
#  ('school', 'grade'),
#  ('parent', 'adult'),
#  ('bar', 'jail'),
#  ('car', 'highway'),
#  ('dictionary', 'definition'),
#  ('door', 'cellar'),
#  ('army', 'legion'),
#  ('metal', 'aluminum'),
#  ('chair', 'bench'),
#  ('cloud', 'fog'),
#  ('boy', 'son'),
#  ('water', 'ice'),
#  ('bed', 'blanket'),
#  ('attorney', 'lawyer'),
#  ('area', 'zone'),
#  ('business', 'company'),
#  ('clothes', 'fabric'),
#  ('sweater', 'jacket'),
#  ('money', 'capital'),
#  ('hand', 'foot'),
#  ('alcohol', 'cocktail'),
#  ('yard', 'inch'),
#  ('molecule', 'atom'),
#  ('lens', 'camera'),
#  ('meal', 'dinner'),
#  ('eye', 'tear'),
#  ('god', 'devil'),
#  ('loop', 'belt'),
#  ('rat', 'mouse'),
#  ('motor', 'engine'),
#  ('car', 'cab'),
#  ('cat', 'lion'),
#  ('size', 'magnitude'),
#  ('reality', 'fantasy'),
#  ('door', 'gate'),
#  ('cat', 'pet'),
#  ('tin', 'aluminum'),
#  ('bone', 'jaw'),
#  ('cereal', 'wheat'),
#  ('house', 'key'),
#  ('blood', 'flesh'),
#  ('door', 'corridor'),
#  ('god', 'spirit'),
#  ('capability', 'competence'),
#  ('abundance', 'plenty'),
#  ('sofa', 'chair'),
#  ('wall', 'brick'),
#  ('horn', 'drum'),
#  ('organ', 'liver'),
#  ('strength', 'might'),
#  ('phrase', 'word'),
#  ('band', 'parade'),
#  ('stomach', 'waist'),
#  ('cloud', 'storm'),
#  ('joy', 'pride'),
#  ('noise', 'rattle'),
#  ('rain', 'mist'),
#  ('beer', 'beverage'),
#  ('man', 'uncle'),
#  ('apple', 'juice'),
#  ('intelligence', 'logic'),
#  ('communication', 'language'),
#  ('mink', 'fur'),
#  ('mob', 'crowd'),
#  ('shore', 'coast'),
#  ('wire', 'cord'),
#  ('bird', 'turkey'),
#  ('bed', 'crib'),
#  ('competence', 'ability'),
#  ('cloud', 'haze'),
#  ('supper', 'meal'),
#  ('bar', 'cage'),
#  ('water', 'salt'),
#  ('sense', 'intuition'),
#  ('situation', 'condition'),
#  ('crime', 'theft'),
#  ('style', 'fashion'),
#  ('boundary', 'border'),
#  ('arm', 'body'),
#  ('boat', 'car'),
#  ('sandwich', 'lunch'),
#  ('bride', 'princess'),
#  ('heroine', 'hero'),
#  ('car', 'gauge'),
#  ('insect', 'bee'),
#  ('crib', 'cradle'),
#  ('animal', 'person'),
#  ('marijuana', 'herb'),
#  ('bed', 'hospital'),
#  ('cheek', 'tongue'),
#  ('disc', 'computer'),
#  ('curve', 'angle'),
#  ('grass', 'moss'),
#  ('school', 'law'),
#  ('foot', 'head'),
#  ('mother', 'guardian'),
#  ('orthodontist', 'dentist'),
#  ('alcohol', 'whiskey'),
#  ('mouth', 'tooth'),
#  ('breakfast', 'bacon'),
#  ('bathroom', 'bedroom'),
#  ('plate', 'bowl'),
#  ('meat', 'bacon'),
#  ('air', 'helium'),
#  ('worker', 'employer'),
#  ('body', 'chest'),
#  ('son', 'father'),
#  ('heart', 'surgery'),
#  ('woman', 'secretary'),
#  ('man', 'father'),
#  ('beach', 'island'),
#  ('story', 'topic'),
#  ('game', 'fun'),
#  ('weekend', 'week'),
#  ('couple', 'pair'),
#  ('woman', 'wife'),
#  ('sheep', 'cattle'),
#  ('purse', 'bag'),
#  ('ceiling', 'cathedral'),
#  ('bean', 'coffee'),
#  ('wood', 'paper'),
#  ('top', 'side'),
#  ('crime', 'fraud'),
#  ('pain', 'harm'),
#  ('lover', 'companion'),
#  ('evening', 'dusk'),
#  ('father', 'daughter'),
#  ('wine', 'liquor'),
#  ('cow', 'goat'),
#  ('belief', 'opinion'),
#  ('reality', 'illusion'),
#  ('pact', 'agreement'),
#  ('wealth', 'poverty'),
#  ('accident', 'emergency'),
#  ('battle', 'conquest'),
#  ('friend', 'teacher'),
#  ('illness', 'infection'),
#  ('game', 'trick'),
#  ('brother', 'son'),
#  ('aunt', 'nephew'),
#  ('worker', 'mechanic'),
#  ('doctor', 'orthodontist'),
#  ('oak', 'maple'),
#  ('bee', 'queen'),
#  ('car', 'bicycle'),
#  ('goal', 'quest'),
#  ('august', 'month'),
#  ('army', 'squad'),
#  ('cloud', 'weather'),
#  ('physician', 'doctor'),
#  ('canyon', 'valley'),
#  ('river', 'valley'),
#  ('sun', 'sky'),
#  ('target', 'arrow'),
#  ('chocolate', 'pie'),
#  ('circumstance', 'situation'),
#  ('opinion', 'choice'),
#  ('rhythm', 'melody'),
#  ('gut', 'nerve'),
#  ('day', 'dawn'),
#  ('cattle', 'beef'),
#  ('doctor', 'professor'),
#  ('arm', 'vein'),
#  ('room', 'bath'),
#  ('corporation', 'business'),
#  ('fun', 'football'),
#  ('hill', 'cliff'),
#  ('bone', 'ankle'),
#  ('apple', 'candy'),
#  ('helper', 'maid'),
#  ('leader', 'manager'),
#  ('lemon', 'tea'),
#  ('bee', 'ant'),
#  ('basketball', 'baseball'),
#  ('rice', 'bean'),
#  ('bed', 'furniture'),
#  ('emotion', 'passion'),
#  ('anarchy', 'chaos'),
#  ('crime', 'violation'),
#  ('machine', 'engine'),
#  ('beach', 'sea'),
#  ('alley', 'bowl'),
#  ('jar', 'bottle'),
#  ('strength', 'capability'),
#  ('seed', 'mustard'),
#  ('guitar', 'drum'),
#  ('opinion', 'idea'),
#  ('north', 'west'),
#  ('diet', 'salad'),
#  ('mother', 'wife'),
#  ('dad', 'mother'),
#  ('captain', 'sailor'),
#  ('meter', 'yard'),
#  ('beer', 'champagne'),
#  ('motor', 'boat'),
#  ('card', 'bridge'),
#  ('science', 'psychology'),
#  ('sinner', 'saint'),
#  ('destruction', 'construction'),
#  ('crowd', 'bunch'),
#  ('beach', 'reef'),
#  ('man', 'child'),
#  ('bread', 'cheese'),
#  ('champion', 'winner'),
#  ('celebration', 'ceremony'),
#  ('menu', 'order'),
#  ('king', 'princess'),
#  ('wealth', 'prestige'),
#  ('endurance', 'strength'),
#  ('danger', 'threat'),
#  ('god', 'priest'),
#  ('men', 'fraternity'),
#  ('buddy', 'companion'),
#  ('teacher', 'helper'),
#  ('body', 'stomach'),
#  ('tongue', 'throat'),
#  ('house', 'carpet'),
#  ('intelligence', 'skill'),
#  ('journey', 'conquest'),
#  ('god', 'prey'),
#  ('brother', 'soul'),
#  ('adversary', 'opponent'),
#  ('death', 'catastrophe'),
#  ('monster', 'demon'),
#  ('day', 'morning'),
#  ('man', 'victor'),
#  ('friend', 'guy'),
#  ('song', 'story'),
#  ('ray', 'sunshine'),
#  ('guy', 'stud'),
#  ('chicken', 'rice'),
#  ('box', 'elevator'),
#  ('butter', 'potato'),
#  ('apartment', 'furniture'),
#  ('lake', 'swamp'),
#  ('salad', 'vinegar'),
#  ('flower', 'bulb'),
#  ('cloud', 'mist'),
#  ('driver', 'pilot'),
#  ('sugar', 'honey'),
#  ('body', 'shoulder'),
#  ('idea', 'image'),
#  ('father', 'brother'),
#  ('moon', 'planet'),
#  ('ball', 'costume'),
#  ('rail', 'fence'),
#  ('room', 'bed'),
#  ('flower', 'bush'),
#  ('bone', 'knee'),
#  ('arm', 'knee'),
#  ('bottom', 'side'),
#  ('vessel', 'vein'),
#  ('cat', 'rabbit'),
#  ('meat', 'sandwich'),
#  ('belief', 'concept'),
#  ('intelligence', 'insight'),
#  ('attention', 'interest'),
#  ('attitude', 'confidence'),
#  ('right', 'justice'),
#  ('argument', 'agreement'),
#  ('depth', 'magnitude'),
#  ('medium', 'news'),
#  ('winner', 'candidate'),
#  ('birthday', 'date'),
#  ('fee', 'payment'),
#  ('bible', 'hymn'),
#  ('exit', 'doorway'),
#  ('man', 'sentry'),
#  ('aisle', 'hall'),
#  ('whiskey', 'gin'),
#  ('blood', 'marrow'),
#  ('oil', 'mink'),
#  ('floor', 'deck'),
#  ('roof', 'floor'),
#  ('door', 'floor'),
#  ('shoulder', 'head'),
#  ('wagon', 'carriage'),
#  ('car', 'carriage'),
#  ('elbow', 'ankle'),
#  ('wealth', 'fame'),
#  ('sorrow', 'shame'),
#  ('administration', 'management'),
#  ('communication', 'conversation'),
#  ('pollution', 'atmosphere'),
#  ('anatomy', 'biology'),
#  ('college', 'profession'),
#  ('book', 'topic'),
#  ('formula', 'equation'),
#  ('book', 'information'),
#  ('boy', 'partner'),
#  ('sky', 'universe'),
#  ('population', 'people'),
#  ('college', 'class'),
#  ('chief', 'mayor'),
#  ('rabbi', 'minister'),
#  ('meter', 'inch'),
#  ('polyester', 'cotton'),
#  ('lawyer', 'banker'),
#  ('violin', 'instrument'),
#  ('camp', 'cabin'),
#  ('pot', 'appliance'),
#  ('linen', 'fabric'),
#  ('whiskey', 'champagne'),
#  ('girl', 'child'),
#  ('cottage', 'cabin'),
#  ('bird', 'hen'),
#  ('racket', 'noise'),
#  ('sunset', 'evening'),
#  ('drizzle', 'rain'),
#  ('adult', 'baby'),
#  ('charcoal', 'coal'),
#  ('body', 'spine'),
#  ('head', 'nail'),
#  ('log', 'timber'),
#  ('spoon', 'cup'),
#  ('body', 'nerve'),
#  ('man', 'husband'),
#  ('bone', 'neck'),
#  ('frustration', 'anger'),
#  ('river', 'sea'),
#  ('task', 'job'),
#  ('club', 'society'),
#  ('reflection', 'image'),
#  ('prince', 'king'),
#  ('snow', 'weather'),
#  ('people', 'party'),
#  ('boy', 'brother'),
#  ('root', 'grass'),
#  ('brow', 'eye'),
#  ('money', 'pearl'),
#  ('money', 'diamond'),
#  ('vehicle', 'bus'),
#  ('cab', 'bus'),
#  ('house', 'barn'),
#  ('finger', 'palm'),
#  ('car', 'bridge'),
#  ('effort', 'difficulty'),
#  ('fact', 'insight'),
#  ('job', 'management'),
#  ('cancer', 'sickness'),
#  ('word', 'newspaper'),
#  ('composer', 'writer'),
#  ('actor', 'singer'),
#  ('shelter', 'hut'),
#  ('bathroom', 'kitchen'),
#  ('cabin', 'hut'),
#  ('door', 'kitchen'),
#  ('value', 'belief'),
#  ('wisdom', 'intelligence'),
#  ('ignorance', 'intelligence'),
#  ('happiness', 'luck'),
#  ('idea', 'scheme'),
#  ('mood', 'emotion'),
#  ('happiness', 'peace'),
#  ('despair', 'misery'),
#  ('logic', 'arithmetic'),
#  ('denial', 'confession'),
#  ('argument', 'criticism'),
#  ('aggression', 'hostility'),
#  ('hysteria', 'confusion'),
#  ('chemistry', 'theory'),
#  ('trial', 'verdict'),
#  ('comfort', 'safety'),
#  ('confidence', 'self'),
#  ('vision', 'perception'),
#  ('era', 'decade'),
#  ('biography', 'fiction'),
#  ('discussion', 'argument'),
#  ('code', 'symbol'),
#  ('danger', 'disease'),
#  ('accident', 'catastrophe'),
#  ('journey', 'trip'),
#  ('activity', 'movement'),
#  ('gossip', 'news'),
#  ('father', 'god'),
#  ('action', 'course'),
#  ('fever', 'illness'),
#  ('aviation', 'flight'),
#  ('game', 'action'),
#  ('molecule', 'air'),
#  ('home', 'state'),
#  ('word', 'literature'),
#  ('adult', 'guardian'),
#  ('newspaper', 'information'),
#  ('communication', 'television'),
#  ('cousin', 'uncle'),
#  ('author', 'reader'),
#  ('guy', 'partner'),
#  ('area', 'corner'),
#  ('ballad', 'song'),
#  ('wall', 'decoration'),
#  ('word', 'page'),
#  ('nurse', 'scientist'),
#  ('politician', 'president'),
#  ('president', 'mayor'),
#  ('book', 'essay'),
#  ('man', 'warrior'),
#  ('article', 'journal'),
#  ('breakfast', 'supper'),
#  ('crowd', 'parade'),
#  ('aisle', 'hallway'),
#  ('teacher', 'rabbi'),
#  ('hip', 'lip'),
#  ('book', 'article'),
#  ('room', 'cell'),
#  ('box', 'booth'),
#  ('daughter', 'kid'),
#  ('limb', 'leg'),
#  ('liver', 'lung'),
#  ('classroom', 'hallway'),
#  ('mountain', 'ledge'),
#  ('car', 'elevator'),
#  ('bed', 'couch'),
#  ('clothes', 'button'),
#  ('clothes', 'coat'),
#  ('kidney', 'organ'),
#  ('apple', 'sauce'),
#  ('chicken', 'steak'),
#  ('car', 'hose'),
#  ('tobacco', 'cigarette'),
#  ('student', 'professor'),
#  ('baby', 'daughter'),
#  ('pipe', 'cigar'),
#  ('milk', 'juice'),
#  ('box', 'cigar'),
#  ('apartment', 'hotel'),
#  ('cup', 'cone'),
#  ('horse', 'ox'),
#  ('throat', 'nose'),
#  ('bone', 'teeth'),
#  ('bone', 'elbow'),
#  ('bacon', 'bean'),
#  ('cup', 'jar'),
#  ('proof', 'fact'),
#  ('appointment', 'engagement'),
#  ('birthday', 'year'),
#  ('word', 'clue'),
#  ('author', 'creator'),
#  ('atom', 'carbon'),
#  ('archbishop', 'bishop'),
#  ('letter', 'paragraph'),
#  ('page', 'paragraph'),
#  ('steeple', 'chapel'),
#  ('muscle', 'bone'),
#  ('muscle', 'tongue'),
#  ('boy', 'soldier'),
#  ('belly', 'abdomen'),
#  ('guy', 'girl'),
#  ('bed', 'chair'),
#  ('clothes', 'jacket'),
#  ('gun', 'knife'),
#  ('tin', 'metal'),
#  ('bottle', 'container'),
#  ('hen', 'turkey'),
#  ('meat', 'bread'),
#  ('arm', 'bone'),
#  ('neck', 'spine'),
#  ('apple', 'lemon'),
#  ('agony', 'grief'),
#  ('assignment', 'task'),
#  ('night', 'dawn'),
#  ('dinner', 'soup'),
#  ('calf', 'bull'),
#  ('snow', 'storm'),
#  ('nail', 'hand'),
#  ('dog', 'horse'),
#  ('arm', 'neck'),
#  ('ball', 'glove'),
#  ('flu', 'fever'),
#  ('fee', 'salary'),
#  ('nerve', 'brain'),
#  ('beast', 'animal'),
#  ('dinner', 'chicken'),
#  ('girl', 'maid'),
#  ('child', 'boy'),
#  ('alcohol', 'wine'),
#  ('nose', 'mouth'),
#  ('street', 'car'),
#  ('bell', 'door'),
#  ('box', 'hat'),
#  ('belief', 'impression'),
#  ('bias', 'opinion'),
#  ('attention', 'awareness'),
#  ('anger', 'mood'),
#  ('elegance', 'style'),
#  ('beauty', 'age'),
#  ('book', 'theme'),
#  ('friend', 'mother'),
#  ('vitamin', 'iron'),
#  ('car', 'factory'),
#  ('pact', 'condition'),
#  ('chapter', 'choice'),
#  ('arithmetic', 'rhythm'),
#  ('winner', 'presence'),
#  ('belief', 'flower'),
#  ('winner', 'goal'),
#  ('trick', 'size'),
#  ('choice', 'vein'),
#  ('hymn', 'conquest'),
#  ('endurance', 'band'),
#  ('jail', 'choice'),
#  ('condition', 'boy'),
#  ('flower', 'endurance'),
#  ('hole', 'agreement'),
#  ('doctor', 'temper'),
#  ('fraternity', 'door'),
#  ('task', 'woman'),
#  ('fraternity', 'baseball'),
#  ('cent', 'size'),
#  ('presence', 'door'),
#  ('mouse', 'management'),
#  ('task', 'highway'),
#  ('liquor', 'century'),
#  ('task', 'straw'),
#  ('island', 'task'),
#  ('night', 'chapter'),
#  ('pollution', 'president'),
#  ('gun', 'trick'),
#  ('bath', 'trick'),
#  ('diet', 'apple'),
#  ('cent', 'wife'),
#  ('chapter', 'tail'),
#  ('course', 'stomach'),
#  ('hymn', 'straw'),
#  ('dentist', 'colonel'),
#  ('wife', 'straw'),
#  ('hole', 'wife'),
#  ('pupil', 'president'),
#  ('bath', 'wife'),
#  ('people', 'cent'),
#  ('formula', 'log'),
#  ('woman', 'fur'),
#  ('apple', 'sunshine'),
#  ('gun', 'dawn'),
#  ('meal', 'waist'),
#  ('camera', 'president'),
#  ('liquor', 'band'),
#  ('stomach', 'vein'),
#  ('gun', 'fur'),
#  ('couch', 'baseball'),
#  ('worker', 'camera'),
#  ('deck', 'mouse'),
#  ('rice', 'boy'),
#  ('people', 'gun'),
#  ('cliff', 'tail'),
#  ('ankle', 'window'),
#  ('princess', 'island'),
#  ('container', 'mouse'),
#  ('wagon', 'container'),
#  ('people', 'balloon'),
#  ('dollar', 'people'),
#  ('bath', 'balloon'),
#  ('stomach', 'bedroom'),
#  ('bicycle', 'bedroom'),
#  ('log', 'bath'),
#  ('bowl', 'tail'),
#  ('go', 'come'),
#  ('take', 'steal'),
#  ('listen', 'hear'),
#  ('think', 'rationalize'),
#  ('occur', 'happen'),
#  ('vanish', 'disappear'),
#  ('multiply', 'divide'),
#  ('plead', 'beg'),
#  ('begin', 'originate'),
#  ('protect', 'defend'),
#  ('kill', 'destroy'),
#  ('create', 'make'),
#  ('accept', 'reject'),
#  ('ignore', 'avoid'),
#  ('carry', 'bring'),
#  ('leave', 'enter'),
#  ('choose', 'elect'),
#  ('lose', 'fail'),
#  ('encourage', 'discourage'),
#  ('achieve', 'accomplish'),
#  ('make', 'construct'),
#  ('listen', 'obey'),
#  ('inform', 'notify'),
#  ('receive', 'give'),
#  ('borrow', 'beg'),
#  ('take', 'obtain'),
#  ('advise', 'recommend'),
#  ('imitate', 'portray'),
#  ('win', 'succeed'),
#  ('think', 'decide'),
#  ('greet', 'meet'),
#  ('agree', 'argue'),
#  ('enjoy', 'entertain'),
#  ('destroy', 'make'),
#  ('save', 'protect'),
#  ('give', 'lend'),
#  ('understand', 'know'),
#  ('take', 'receive'),
#  ('accept', 'acknowledge'),
#  ('decide', 'choose'),
#  ('accept', 'believe'),
#  ('keep', 'possess'),
#  ('roam', 'wander'),
#  ('succeed', 'fail'),
#  ('spend', 'save'),
#  ('leave', 'go'),
#  ('come', 'attend'),
#  ('know', 'believe'),
#  ('gather', 'meet'),
#  ('make', 'earn'),
#  ('forget', 'ignore'),
#  ('multiply', 'add'),
#  ('shrink', 'grow'),
#  ('arrive', 'leave'),
#  ('succeed', 'try'),
#  ('accept', 'deny'),
#  ('arrive', 'come'),
#  ('agree', 'differ'),
#  ('send', 'receive'),
#  ('win', 'dominate'),
#  ('add', 'divide'),
#  ('kill', 'choke'),
#  ('acquire', 'get'),
#  ('participate', 'join'),
#  ('leave', 'remain'),
#  ('go', 'enter'),
#  ('take', 'carry'),
#  ('forget', 'learn'),
#  ('appoint', 'elect'),
#  ('engage', 'marry'),
#  ('ask', 'pray'),
#  ('go', 'send'),
#  ('take', 'deliver'),
#  ('speak', 'hear'),
#  ('analyze', 'evaluate'),
#  ('argue', 'rationalize'),
#  ('lose', 'keep'),
#  ('compare', 'analyze'),
#  ('disorganize', 'organize'),
#  ('go', 'allow'),
#  ('take', 'possess'),
#  ('learn', 'listen'),
#  ('destroy', 'construct'),
#  ('create', 'build'),
#  ('steal', 'buy'),
#  ('kill', 'hang'),
#  ('forget', 'know'),
#  ('create', 'imagine'),
#  ('do', 'happen'),
#  ('win', 'accomplish'),
#  ('give', 'deny'),
#  ('deserve', 'earn'),
#  ('get', 'put'),
#  ('locate', 'find'),
#  ('appear', 'attend'),
#  ('know', 'comprehend'),
#  ('pretend', 'imagine'),
#  ('satisfy', 'please'),
#  ('cherish', 'keep'),
#  ('argue', 'differ'),
#  ('overcome', 'dominate'),
#  ('behave', 'obey'),
#  ('cooperate', 'participate'),
#  ('achieve', 'try'),
#  ('fail', 'discourage'),
#  ('begin', 'quit'),
#  ('say', 'participate'),
#  ('come', 'bring'),
#  ('declare', 'announce'),
#  ('read', 'comprehend'),
#  ('take', 'leave'),
#  ('proclaim', 'announce'),
#  ('acquire', 'obtain'),
#  ('conclude', 'decide'),
#  ('please', 'plead'),
#  ('argue', 'prove'),
#  ('ask', 'plead'),
#  ('find', 'disappear'),
#  ('inspect', 'examine'),
#  ('verify', 'justify'),
#  ('assume', 'predict'),
#  ('learn', 'evaluate'),
#  ('argue', 'justify'),
#  ('make', 'become'),
#  ('discover', 'originate'),
#  ('achieve', 'succeed'),
#  ('give', 'put'),
#  ('understand', 'listen'),
#  ('expand', 'grow'),
#  ('borrow', 'sell'),
#  ('keep', 'protect'),
#  ('explain', 'prove'),
#  ('assume', 'pretend'),
#  ('agree', 'please'),
#  ('forgive', 'forget'),
#  ('clarify', 'explain'),
#  ('understand', 'forgive'),
#  ('remind', 'forget'),
#  ('get', 'remain'),
#  ('realize', 'discover'),
#  ('require', 'inquire'),
#  ('ignore', 'ask'),
#  ('think', 'inquire'),
#  ('reject', 'avoid'),
#  ('argue', 'persuade'),
#  ('pursue', 'persuade'),
#  ('accept', 'forgive'),
#  ('do', 'quit'),
#  ('investigate', 'examine'),
#  ('discuss', 'explain'),
#  ('owe', 'lend'),
#  ('explore', 'discover'),
#  ('complain', 'argue'),
#  ('withdraw', 'reject'),
#  ('keep', 'borrow'),
#  ('beg', 'ask'),
#  ('arrange', 'organize'),
#  ('reduce', 'shrink'),
#  ('speak', 'acknowledge'),
#  ('give', 'borrow'),
#  ('kill', 'defend'),
#  ('disappear', 'shrink'),
#  ('deliver', 'carry'),
#  ('breathe', 'choke'),
#  ('acknowledge', 'notify'),
#  ('become', 'seem'),
#  ('pretend', 'seem'),
#  ('accomplish', 'become'),
#  ('contemplate', 'think'),
#  ('determine', 'predict'),
#  ('please', 'entertain'),
#  ('remain', 'retain'),
#  ('pretend', 'portray'),
#  ('forget', 'retain'),
#  ('want', 'choose'),
#  ('lose', 'get'),
#  ('try', 'think'),
#  ('become', 'appear'),
#  ('leave', 'ignore'),
#  ('accept', 'recommend'),
#  ('leave', 'wander'),
#  ('keep', 'give'),
#  ('give', 'allow'),
#  ('bring', 'send'),
#  ('absorb', 'learn'),
#  ('acquire', 'find'),
#  ('leave', 'appear'),
#  ('create', 'destroy'),
#  ('begin', 'go'),
#  ('get', 'buy'),
#  ('collect', 'save'),
#  ('replace', 'restore'),
#  ('join', 'add'),
#  ('join', 'marry'),
#  ('accept', 'deliver'),
#  ('attach', 'join'),
#  ('put', 'hang'),
#  ('go', 'sell'),
#  ('communicate', 'pray'),
#  ('give', 'steal'),
#  ('add', 'build'),
#  ('bring', 'restore'),
#  ('comprehend', 'satisfy'),
#  ('portray', 'decide'),
#  ('organize', 'become'),
#  ('give', 'know'),
#  ('say', 'verify'),
#  ('cooperate', 'join'),
#  ('arrange', 'require'),
#  ('borrow', 'want'),
#  ('investigate', 'pursue'),
#  ('ignore', 'explore'),
#  ('bring', 'complain'),
#  ('enter', 'owe'),
#  ('portray', 'notify'),
#  ('remind', 'sell'),
#  ('absorb', 'possess'),
#  ('join', 'acquire'),
#  ('send', 'attend'),
#  ('gather', 'attend'),
#  ('absorb', 'withdraw'),
#  ('attend', 'arrive')]

# %% [markdown]
# ### **1. Process and Extract Data**

# %%
# Define model
model = "text-embedding-3-large"

# Delay between individual API calls
delay = 3.0

# %%
# Get results from API
# response = get_responses_embeddings(word_pairs, model, delay)

# Show results
response
# Out:
# Calculating Cosine Similarities: 100%|██████████| 999/999 [1:03:21<00:00,  3.81s/pair]
# Total time taken: 3801.79 seconds
# [('old', 'new', 0.5727325047238871),
#  ('smart', 'intelligent', 0.6109043222475181),
#  ('hard', 'difficult', 0.5191292880681387),
#  ('happy', 'cheerful', 0.5654338037135132),
#  ('hard', 'easy', 0.5244146816725317),
#  ('fast', 'rapid', 0.6603570017942237),
#  ('happy', 'glad', 0.5996389404593285),
#  ('short', 'long', 0.6295935171135506),
#  ('stupid', 'dumb', 0.7463821191605035),
#  ('weird', 'strange', 0.7933142337200995),
#  ('wide', 'narrow', 0.5127004010883189),
#  ('bad', 'awful', 0.5419656363238606),
#  ('easy', 'difficult', 0.49974980311241657),
#  ('bad', 'terrible', 0.549762671432255),
#  ('hard', 'simple', 0.4214993118437916),
#  ('smart', 'dumb', 0.4390647088832033),
#  ('insane', 'crazy', 0.807867016241174),
#  ('happy', 'mad', 0.43940851314461266),
#  ('large', 'huge', 0.6973598956387915),
#  ('hard', 'tough', 0.5953778176744661),
#  ('new', 'fresh', 0.686870434507237),
#  ('sharp', 'dull', 0.38418169955759235),
#  ('quick', 'rapid', 0.6609621089869352),
#  ('dumb', 'foolish', 0.5549091743426631),
#  ('wonderful', 'terrific', 0.5784505441311544),
#  ('strange', 'odd', 0.5721918199046875),
#  ('happy', 'angry', 0.46096723004703294),
#  ('narrow', 'broad', 0.5145336827378982),
#  ('simple', 'easy', 0.7526219701050616),
#  ('old', 'fresh', 0.47952578431735415),
#  ('apparent', 'obvious', 0.5922468566549223),
#  ('inexpensive', 'cheap', 0.659272370851668),
#  ('nice', 'generous', 0.4077573875757178),
#  ('weird', 'normal', 0.45238197753083587),
#  ('weird', 'odd', 0.5799190350367195),
#  ('bad', 'immoral', 0.3808144090730008),
#  ('sad', 'funny', 0.41332229152214234),
#  ('wonderful', 'great', 0.5872849175396918),
#  ('guilty', 'ashamed', 0.5437062795082319),
#  ('beautiful', 'wonderful', 0.5779127880339913),
#  ('confident', 'sure', 0.38274464538188036),
#  ('dumb', 'dense', 0.38274601448522777),
#  ('large', 'big', 0.7457861619493371),
#  ('nice', 'cruel', 0.3408005203455482),
#  ('impatient', 'anxious', 0.5383361429740533),
#  ('big', 'broad', 0.48865733046387655),
#  ('strong', 'proud', 0.4651497920195002),
#  ('unnecessary', 'necessary', 0.6202947393003863),
#  ('restless', 'young', 0.29422403512994594),
#  ('dumb', 'intelligent', 0.36596320468333904),
#  ('bad', 'great', 0.5698889064049779),
#  ('difficult', 'simple', 0.4022745537140523),
#  ('necessary', 'important', 0.5023586068664504),
#  ('bad', 'terrific', 0.4128253324830017),
#  ('mad', 'glad', 0.41518238614997127),
#  ('honest', 'guilty', 0.36667443759617435),
#  ('easy', 'tough', 0.4442474040012767),
#  ('easy', 'flexible', 0.44515412886034444),
#  ('certain', 'sure', 0.47738088273857926),
#  ('essential', 'necessary', 0.6735373647799133),
#  ('different', 'normal', 0.4188603531592097),
#  ('sly', 'clever', 0.5718588475730363),
#  ('crucial', 'important', 0.5350618836085679),
#  ('harsh', 'cruel', 0.5802342871954014),
#  ('childish', 'foolish', 0.5518818846647445),
#  ('scarce', 'rare', 0.639864686191907),
#  ('friendly', 'generous', 0.4678599149452005),
#  ('fragile', 'frigid', 0.39880805838571426),
#  ('long', 'narrow', 0.38610899634904816),
#  ('big', 'heavy', 0.5641049963691237),
#  ('rough', 'frigid', 0.2523672793177363),
#  ('bizarre', 'strange', 0.7232351484217239),
#  ('illegal', 'immoral', 0.4905603802612037),
#  ('bad', 'guilty', 0.36424745562739347),
#  ('modern', 'ancient', 0.3846123413121435),
#  ('new', 'ancient', 0.319913743311038),
#  ('dull', 'funny', 0.3360301519833264),
#  ('happy', 'young', 0.35151743389159984),
#  ('easy', 'big', 0.45294252002252855),
#  ('great', 'awful', 0.4268501885145189),
#  ('tiny', 'huge', 0.48859337573316464),
#  ('polite', 'proper', 0.4380266031208036),
#  ('modest', 'ashamed', 0.40107129638351774),
#  ('exotic', 'rare', 0.4833532421379968),
#  ('dumb', 'clever', 0.40669720230449247),
#  ('delightful', 'wonderful', 0.6350941513940664),
#  ('noticeable', 'obvious', 0.5719349515762412),
#  ('afraid', 'anxious', 0.5790218905089863),
#  ('formal', 'proper', 0.5544606635285537),
#  ('dreary', 'dull', 0.6210299574218849),
#  ('delightful', 'cheerful', 0.5546137694544518),
#  ('unhappy', 'mad', 0.33297654294255713),
#  ('sad', 'terrible', 0.3760615091489568),
#  ('sick', 'crazy', 0.5107871771624679),
#  ('violent', 'angry', 0.444200549371871),
#  ('laden', 'heavy', 0.4546403781872601),
#  ('dirty', 'cheap', 0.43176406545606594),
#  ('elastic', 'flexible', 0.5027367800732391),
#  ('hard', 'dense', 0.45316058866237097),
#  ('recent', 'new', 0.5903281121617384),
#  ('bold', 'proud', 0.42155152966391823),
#  ('sly', 'strange', 0.3871489256693292),
#  ('strange', 'sly', 0.3871489256693292),
#  ('dumb', 'rare', 0.3042334873754844),
#  ('sly', 'tough', 0.3586948852335237),
#  ('terrific', 'mad', 0.30863567106351647),
#  ('modest', 'flexible', 0.3768226322451865),
#  ('fresh', 'wide', 0.34865194844914155),
#  ('huge', 'dumb', 0.336005360311753),
#  ('large', 'flexible', 0.3484985433661637),
#  ('dirty', 'narrow', 0.2719672948468062),
#  ('wife', 'husband', 0.6252542934778087),
#  ('book', 'text', 0.42610557121754083),
#  ('groom', 'bride', 0.6338037929853698),
#  ('night', 'day', 0.5229461220301139),
#  ('south', 'north', 0.7186508361908622),
#  ('plane', 'airport', 0.5290851970811252),
#  ('uncle', 'aunt', 0.6894857550860216),
#  ('horse', 'mare', 0.4290228814842932),
#  ('bottom', 'top', 0.7210362565827712),
#  ('friend', 'buddy', 0.6746062677550259),
#  ('student', 'pupil', 0.5216289893168408),
#  ('world', 'globe', 0.5371803653848328),
#  ('leg', 'arm', 0.44036676710246725),
#  ('plane', 'jet', 0.5621835090385684),
#  ('woman', 'man', 0.5712979948848655),
#  ('horse', 'colt', 0.4655673011049937),
#  ('actress', 'actor', 0.6919886168409978),
#  ('teacher', 'instructor', 0.6090717882464575),
#  ('movie', 'film', 0.7685156118059753),
#  ('bird', 'hawk', 0.5536479536350062),
#  ('word', 'dictionary', 0.564801425348038),
#  ('money', 'salary', 0.4424675750049823),
#  ('dog', 'cat', 0.5906886999946556),
#  ('area', 'region', 0.6871984271419403),
#  ('navy', 'army', 0.6098960636871562),
#  ('book', 'literature', 0.4267172042920655),
#  ('clothes', 'closet', 0.5046640810203099),
#  ('sunset', 'sunrise', 0.7551916774006252),
#  ('child', 'adult', 0.5319790731855265),
#  ('cow', 'cattle', 0.6051097011451102),
#  ('book', 'story', 0.4646985560025859),
#  ('winter', 'summer', 0.6480488959607551),
#  ('taxi', 'cab', 0.496501670715445),
#  ('tree', 'maple', 0.42329950029763747),
#  ('bed', 'bedroom', 0.5578964842751054),
#  ('roof', 'ceiling', 0.5410820220044182),
#  ('disease', 'infection', 0.5831715959371183),
#  ('arm', 'shoulder', 0.4317688267460625),
#  ('sheep', 'lamb', 0.6359950127627811),
#  ('lady', 'gentleman', 0.5826469597997715),
#  ('boat', 'anchor', 0.43519836697235914),
#  ('priest', 'monk', 0.5634108718498273),
#  ('toe', 'finger', 0.49890645838016184),
#  ('river', 'stream', 0.5781828174484139),
#  ('anger', 'fury', 0.5606328828967614),
#  ('date', 'calendar', 0.5435158844834668),
#  ('sea', 'ocean', 0.5760085823697454),
#  ('second', 'minute', 0.6132020930903673),
#  ('hand', 'thumb', 0.47029557883651696),
#  ('wood', 'log', 0.36778830197988943),
#  ('mud', 'dirt', 0.6301593333193205),
#  ('hallway', 'corridor', 0.728407515517723),
#  ('way', 'manner', 0.4805819079148247),
#  ('mouse', 'cat', 0.45318442713927126),
#  ('cop', 'sheriff', 0.4234832213481247),
#  ('death', 'burial', 0.44107292892688005),
#  ('music', 'melody', 0.44190430355334737),
#  ('beer', 'alcohol', 0.486915810600482),
#  ('mouth', 'lip', 0.4384504011768649),
#  ('storm', 'hurricane', 0.5078984914220315),
#  ('tax', 'income', 0.44645216998209364),
#  ('flower', 'violet', 0.4327361866878063),
#  ('paper', 'cardboard', 0.5159324469847524),
#  ('floor', 'ceiling', 0.5438897286725559),
#  ('beach', 'seashore', 0.658123837729091),
#  ('rod', 'curtain', 0.33490890727491157),
#  ('hound', 'fox', 0.42998250159075735),
#  ('street', 'alley', 0.42153881520294856),
#  ('boat', 'deck', 0.47266732006293266),
#  ('car', 'horn', 0.31115475623415967),
#  ('friend', 'guest', 0.4182226318701553),
#  ('employer', 'employee', 0.7822312323947408),
#  ('hand', 'wrist', 0.4550581534103456),
#  ('ball', 'cannon', 0.3884857652750028),
#  ('alcohol', 'brandy', 0.45061150498196867),
#  ('victory', 'triumph', 0.7281958874434986),
#  ('telephone', 'booth', 0.39024865806869735),
#  ('door', 'doorway', 0.7284403031771298),
#  ('motel', 'inn', 0.3413217267090595),
#  ('clothes', 'cloth', 0.6088028486744469),
#  ('steak', 'meat', 0.5996261204959564),
#  ('nail', 'thumb', 0.4269204352148225),
#  ('band', 'orchestra', 0.4301219716494937),
#  ('book', 'bible', 0.4825663861352869),
#  ('business', 'industry', 0.6106989140938966),
#  ('winter', 'season', 0.5892758182521968),
#  ('decade', 'century', 0.5804554802793719),
#  ('alcohol', 'gin', 0.32364548975251073),
#  ('hat', 'coat', 0.4526772816125321),
#  ('window', 'door', 0.49934972170334135),
#  ('arm', 'wrist', 0.41997836421127255),
#  ('house', 'apartment', 0.4190224576027711),
#  ('glass', 'crystal', 0.520344341354699),
#  ('wine', 'brandy', 0.47262312524324795),
#  ('creator', 'maker', 0.7034383001104384),
#  ('dinner', 'breakfast', 0.5907729989217453),
#  ('arm', 'muscle', 0.363623553415224),
#  ('bubble', 'suds', 0.3919259770988278),
#  ('bread', 'flour', 0.5056405034489648),
#  ('death', 'tragedy', 0.38281761452253976),
#  ('absence', 'presence', 0.4603900471401338),
#  ('gun', 'cannon', 0.526472683624468),
#  ('grass', 'blade', 0.2741860882275501),
#  ('ball', 'basket', 0.54022825670824),
#  ('hose', 'garden', 0.34996397275333607),
#  ('boy', 'kid', 0.5171735232765874),
#  ('church', 'choir', 0.4916029177060309),
#  ('clothes', 'drawer', 0.36112284280012336),
#  ('tower', 'bell', 0.4324164130228842),
#  ('father', 'parent', 0.6049789027679234),
#  ('school', 'grade', 0.4839675151755331),
#  ('parent', 'adult', 0.4594498661284663),
#  ('bar', 'jail', 0.3595248846764789),
#  ('car', 'highway', 0.34754380741970786),
#  ('dictionary', 'definition', 0.6423936613200107),
#  ('door', 'cellar', 0.38816703926246005),
#  ('army', 'legion', 0.47236735033432314),
#  ('metal', 'aluminum', 0.5001739758629619),
#  ('chair', 'bench', 0.49378640104505156),
#  ('cloud', 'fog', 0.4953811924280722),
#  ('boy', 'son', 0.48373724857057454),
#  ('water', 'ice', 0.5012824590795655),
#  ('bed', 'blanket', 0.415131966297825),
#  ('attorney', 'lawyer', 0.7333953743360897),
#  ('area', 'zone', 0.5510500757474931),
#  ('business', 'company', 0.6037612576963077),
#  ('clothes', 'fabric', 0.46905944571927605),
#  ('sweater', 'jacket', 0.5499620259016036),
#  ('money', 'capital', 0.41634150520289176),
#  ('hand', 'foot', 0.38010105933119076),
#  ('alcohol', 'cocktail', 0.4186331447706691),
#  ('yard', 'inch', 0.3602704129692556),
#  ('molecule', 'atom', 0.4638784689012092),
#  ('lens', 'camera', 0.49705350789657204),
#  ('meal', 'dinner', 0.5192655837129478),
#  ('eye', 'tear', 0.42732243066769265),
#  ('god', 'devil', 0.4379529536797198),
#  ('loop', 'belt', 0.373608783744173),
#  ('rat', 'mouse', 0.522750917066364),
#  ('motor', 'engine', 0.6166222611930674),
#  ('car', 'cab', 0.6249056903384808),
#  ('cat', 'lion', 0.35676772427576253),
#  ('size', 'magnitude', 0.5497341012023091),
#  ('reality', 'fantasy', 0.5091162441221851),
#  ('door', 'gate', 0.6056032819957878),
#  ('cat', 'pet', 0.629298757472007),
#  ('tin', 'aluminum', 0.4755552207325384),
#  ('bone', 'jaw', 0.4709802247695996),
#  ('cereal', 'wheat', 0.5348792005742244),
#  ('house', 'key', 0.3122641065433925),
#  ('blood', 'flesh', 0.44310165479408087),
#  ('door', 'corridor', 0.42822460533547113),
#  ('god', 'spirit', 0.39306631172183004),
#  ('capability', 'competence', 0.5384702912813784),
#  ('abundance', 'plenty', 0.6459242735104477),
#  ('sofa', 'chair', 0.5032094553524156),
#  ('wall', 'brick', 0.4912892117859669),
#  ('horn', 'drum', 0.3739575749067313),
#  ('organ', 'liver', 0.4530929728596001),
#  ('strength', 'might', 0.4327271988238645),
#  ('phrase', 'word', 0.5425411414520205),
#  ('band', 'parade', 0.301197402772289),
#  ('stomach', 'waist', 0.42105052428633805),
#  ('cloud', 'storm', 0.44680355511351943),
#  ('joy', 'pride', 0.3612901228036486),
#  ('noise', 'rattle', 0.41016855867437924),
#  ('rain', 'mist', 0.42379962522381387),
#  ('beer', 'beverage', 0.5334969242454477),
#  ('man', 'uncle', 0.37180573801595335),
#  ('apple', 'juice', 0.4031997277932815),
#  ('intelligence', 'logic', 0.5051409689271652),
#  ('communication', 'language', 0.4723917400718645),
#  ('mink', 'fur', 0.479800812392286),
#  ('mob', 'crowd', 0.4201670128937401),
#  ('shore', 'coast', 0.5944197130153778),
#  ('wire', 'cord', 0.5477474591556605),
#  ('bird', 'turkey', 0.3858326918797395),
#  ('bed', 'crib', 0.5525695726744394),
#  ('competence', 'ability', 0.5361436731616022),
#  ('cloud', 'haze', 0.4507455905865849),
#  ('supper', 'meal', 0.487842869698071),
#  ('bar', 'cage', 0.36527969131423266),
#  ('water', 'salt', 0.4344936141874018),
#  ('sense', 'intuition', 0.45065898072841587),
#  ('situation', 'condition', 0.524186776358258),
#  ('crime', 'theft', 0.5132766752124932),
#  ('style', 'fashion', 0.5766239482745892),
#  ('boundary', 'border', 0.7204098165117212),
#  ('arm', 'body', 0.36104096501488064),
#  ('boat', 'car', 0.5048662416983941),
#  ('sandwich', 'lunch', 0.5061482911921633),
#  ('bride', 'princess', 0.46620315667564777),
#  ('heroine', 'hero', 0.6128050308510168),
#  ('car', 'gauge', 0.2362108304010507),
#  ('insect', 'bee', 0.4394414507197147),
#  ('crib', 'cradle', 0.6985915293174396),
#  ('animal', 'person', 0.4670462065362246),
#  ('marijuana', 'herb', 0.5272776040765071),
#  ('bed', 'hospital', 0.41452158368998376),
#  ('cheek', 'tongue', 0.4764227678610087),
#  ('disc', 'computer', 0.4128924521806196),
#  ('curve', 'angle', 0.49509766792522164),
#  ('grass', 'moss', 0.47630950574816733),
#  ('school', 'law', 0.38867037616784655),
#  ('foot', 'head', 0.4710540420786537),
#  ('mother', 'guardian', 0.3934855930415121),
#  ('orthodontist', 'dentist', 0.7086838581401712),
#  ('alcohol', 'whiskey', 0.559422651566256),
#  ('mouth', 'tooth', 0.44288846148800026),
#  ('breakfast', 'bacon', 0.467633057248567),
#  ('bathroom', 'bedroom', 0.6606160157464647),
#  ('plate', 'bowl', 0.4658823080339922),
#  ('meat', 'bacon', 0.4795901111289453),
#  ('air', 'helium', 0.4482074022375786),
#  ('worker', 'employer', 0.5824624224678734),
#  ('body', 'chest', 0.43417862695298104),
#  ('son', 'father', 0.4688343776817459),
#  ('heart', 'surgery', 0.2557154784229318),
#  ('woman', 'secretary', 0.3153154932172594),
#  ('man', 'father', 0.47711079284232594),
#  ('beach', 'island', 0.448890276667745),
#  ('story', 'topic', 0.4189458434457876),
#  ('game', 'fun', 0.5296578268292862),
#  ('weekend', 'week', 0.5988080654272225),
#  ('couple', 'pair', 0.5364859855196736),
#  ('woman', 'wife', 0.5769368326286475),
#  ('sheep', 'cattle', 0.6037636306992513),
#  ('purse', 'bag', 0.5712900227933103),
#  ('ceiling', 'cathedral', 0.3846123704785285),
#  ('bean', 'coffee', 0.38419161658938955),
#  ('wood', 'paper', 0.39641708094593564),
#  ('top', 'side', 0.4532568075128981),
#  ('crime', 'fraud', 0.5260441571766631),
#  ('pain', 'harm', 0.4104383132076967),
#  ('lover', 'companion', 0.43271878827998284),
#  ('evening', 'dusk', 0.5764778767199031),
#  ('father', 'daughter', 0.5057580634676901),
#  ('wine', 'liquor', 0.5034509008080721),
#  ('cow', 'goat', 0.5148480368509801),
#  ('belief', 'opinion', 0.4424634232946075),
#  ('reality', 'illusion', 0.4406471293783399),
#  ('pact', 'agreement', 0.5942604615352787),
#  ('wealth', 'poverty', 0.4086791418529481),
#  ('accident', 'emergency', 0.40978231930911),
#  ('battle', 'conquest', 0.40979129420012456),
#  ('friend', 'teacher', 0.39380070845848003),
#  ('illness', 'infection', 0.566626985727843),
#  ('game', 'trick', 0.38750525199255537),
#  ('brother', 'son', 0.42125503771056055),
#  ('aunt', 'nephew', 0.5731235552407694),
#  ('worker', 'mechanic', 0.4182679582262952),
#  ('doctor', 'orthodontist', 0.43078393282316535),
#  ('oak', 'maple', 0.5476959075552249),
#  ('bee', 'queen', 0.3928649468595481),
#  ('car', 'bicycle', 0.3914864346275653),
#  ('goal', 'quest', 0.36029859627623895),
#  ('august', 'month', 0.43546028898990674),
#  ('army', 'squad', 0.4830181376473363),
#  ('cloud', 'weather', 0.41666723647941445),
#  ('physician', 'doctor', 0.6390951432874135),
#  ('canyon', 'valley', 0.5533367125287232),
#  ('river', 'valley', 0.4870921072004666),
#  ('sun', 'sky', 0.4460789664684753),
#  ('target', 'arrow', 0.3833248565146868),
#  ('chocolate', 'pie', 0.2709720934281907),
#  ('circumstance', 'situation', 0.6838135402719638),
#  ('opinion', 'choice', 0.3940850456394235),
#  ('rhythm', 'melody', 0.5230022107779505),
#  ('gut', 'nerve', 0.38626736468701867),
#  ('day', 'dawn', 0.49863101091071593),
#  ('cattle', 'beef', 0.6076632878251631),
#  ('doctor', 'professor', 0.5331643876630899),
#  ('arm', 'vein', 0.25778938934703377),
#  ('room', 'bath', 0.3591071626713888),
#  ('corporation', 'business', 0.4446445446437812),
#  ('fun', 'football', 0.4238277399098268),
#  ('hill', 'cliff', 0.4670524721414617),
#  ('bone', 'ankle', 0.34543923654252817),
#  ('apple', 'candy', 0.37603500907121723),
#  ('helper', 'maid', 0.38534282621875315),
#  ('leader', 'manager', 0.5467666479554855),
#  ('lemon', 'tea', 0.3520980361182402),
#  ('bee', 'ant', 0.512341990375966),
#  ('basketball', 'baseball', 0.6566057995525083),
#  ('rice', 'bean', 0.4163824238082365),
#  ('bed', 'furniture', 0.4127169399316509),
#  ('emotion', 'passion', 0.4500713400879929),
#  ('anarchy', 'chaos', 0.6328677306680467),
#  ('crime', 'violation', 0.4091293951213587),
#  ('machine', 'engine', 0.5541858658282652),
#  ('beach', 'sea', 0.4782862775822881),
#  ('alley', 'bowl', 0.3132897478916614),
#  ('jar', 'bottle', 0.38977756616407777),
#  ('strength', 'capability', 0.45278211320034195),
#  ('seed', 'mustard', 0.3998885056757516),
#  ('guitar', 'drum', 0.5198729158925678),
#  ('opinion', 'idea', 0.4150340091603069),
#  ('north', 'west', 0.6025786296591094),
#  ('diet', 'salad', 0.40757855354092415),
#  ('mother', 'wife', 0.5605886496446392),
#  ('dad', 'mother', 0.508272804595656),
#  ('captain', 'sailor', 0.4874999977740852),
#  ('meter', 'yard', 0.3755893019816167),
#  ('beer', 'champagne', 0.422638721455738),
#  ('motor', 'boat', 0.46463774919393663),
#  ('card', 'bridge', 0.2966574839187623),
#  ('science', 'psychology', 0.4801011518364036),
#  ('sinner', 'saint', 0.5295637271117536),
#  ('destruction', 'construction', 0.38569588290947104),
#  ('crowd', 'bunch', 0.5090936925197721),
#  ('beach', 'reef', 0.4891000264276514),
#  ('man', 'child', 0.31816843710949766),
#  ('bread', 'cheese', 0.45168404450158506),
#  ('champion', 'winner', 0.5276824373038831),
#  ('celebration', 'ceremony', 0.5597549060434265),
#  ('menu', 'order', 0.41750070909781356),
#  ('king', 'princess', 0.3959777894956368),
#  ('wealth', 'prestige', 0.36624323155151106),
#  ('endurance', 'strength', 0.4594331575551229),
#  ('danger', 'threat', 0.5905103913960698),
#  ('god', 'priest', 0.3649113491718631),
#  ('men', 'fraternity', 0.2785282450770077),
#  ('buddy', 'companion', 0.5416021900203408),
#  ('teacher', 'helper', 0.4203557091348479),
#  ('body', 'stomach', 0.3960374019715646),
#  ('tongue', 'throat', 0.4755657676237236),
#  ('house', 'carpet', 0.2817537808678595),
#  ('intelligence', 'skill', 0.4300469413937795),
#  ('journey', 'conquest', 0.3180994221057673),
#  ('god', 'prey', 0.2751803139045624),
#  ('brother', 'soul', 0.36658658163701585),
#  ('adversary', 'opponent', 0.6440448937592118),
#  ('death', 'catastrophe', 0.3741204701022726),
#  ('monster', 'demon', 0.5086966329485995),
#  ('day', 'morning', 0.4601298913807178),
#  ('man', 'victor', 0.3764032698491103),
#  ('friend', 'guy', 0.4613711150008192),
#  ('song', 'story', 0.38838936769049687),
#  ('ray', 'sunshine', 0.35454774287341767),
#  ('guy', 'stud', 0.3473992812599205),
#  ('chicken', 'rice', 0.35092344024923017),
#  ('box', 'elevator', 0.2817425093433793),
#  ('butter', 'potato', 0.42417929683153827),
#  ('apartment', 'furniture', 0.43240368496247555),
#  ('lake', 'swamp', 0.3476304572724475),
#  ('salad', 'vinegar', 0.39801219231896173),
#  ('flower', 'bulb', 0.39707491756598395),
#  ('cloud', 'mist', 0.3921609983419847),
#  ('driver', 'pilot', 0.49336198225683875),
#  ('sugar', 'honey', 0.565681091515939),
#  ('body', 'shoulder', 0.3586890553593837),
#  ('idea', 'image', 0.49168662560075777),
#  ('father', 'brother', 0.5239742831947382),
#  ('moon', 'planet', 0.44920241301437186),
#  ('ball', 'costume', 0.23699573669699847),
#  ('rail', 'fence', 0.44544717802000366),
#  ('room', 'bed', 0.4321518269295564),
#  ('flower', 'bush', 0.3427826223644436),
#  ('bone', 'knee', 0.4054229711042254),
#  ('arm', 'knee', 0.33900301427378376),
#  ('bottom', 'side', 0.4756112419365603),
#  ('vessel', 'vein', 0.5305636229152602),
#  ('cat', 'rabbit', 0.45883920963779107),
#  ('meat', 'sandwich', 0.39515989406533586),
#  ('belief', 'concept', 0.44178871191417257),
#  ('intelligence', 'insight', 0.42760970164980616),
#  ('attention', 'interest', 0.5655909348909866),
#  ('attitude', 'confidence', 0.4061528848391332),
#  ('right', 'justice', 0.38211298235332725),
#  ('argument', 'agreement', 0.3537640226987553),
#  ('depth', 'magnitude', 0.46686644992373305),
#  ('medium', 'news', 0.34928302872812483),
#  ('winner', 'candidate', 0.46025594651840934),
#  ('birthday', 'date', 0.5461458057303359),
#  ('fee', 'payment', 0.5108933632452318),
#  ('bible', 'hymn', 0.3678286567456536),
#  ('exit', 'doorway', 0.3231992789953651),
#  ('man', 'sentry', 0.29454265899521526),
#  ('aisle', 'hall', 0.38508285557153904),
#  ('whiskey', 'gin', 0.34723098994437723),
#  ('blood', 'marrow', 0.3445826076930964),
#  ('oil', 'mink', 0.29887926326779074),
#  ('floor', 'deck', 0.46152648302541577),
#  ('roof', 'floor', 0.5099399017929385),
#  ('door', 'floor', 0.43968146180745027),
#  ('shoulder', 'head', 0.3892516012127192),
#  ('wagon', 'carriage', 0.544080933911733),
#  ('car', 'carriage', 0.523605937665724),
#  ('elbow', 'ankle', 0.5473981172422816),
#  ('wealth', 'fame', 0.39492510359130456),
#  ('sorrow', 'shame', 0.46527283461893687),
#  ('administration', 'management', 0.6632741425902001),
#  ('communication', 'conversation', 0.5654352856815209),
#  ('pollution', 'atmosphere', 0.3726266668164911),
#  ('anatomy', 'biology', 0.4654138721728255),
#  ('college', 'profession', 0.44536088817348063),
#  ('book', 'topic', 0.3922375371518818),
#  ('formula', 'equation', 0.5375951187853446),
#  ('book', 'information', 0.389614667470202),
#  ('boy', 'partner', 0.32495445858113103),
#  ('sky', 'universe', 0.3234852337362785),
#  ('population', 'people', 0.5390708706257809),
#  ('college', 'class', 0.4456575871076828),
#  ('chief', 'mayor', 0.4552874505090549),
#  ('rabbi', 'minister', 0.40885932697026944),
#  ('meter', 'inch', 0.4549222534199113),
#  ('polyester', 'cotton', 0.5260835066116387),
#  ('lawyer', 'banker', 0.4851780739138634),
#  ('violin', 'instrument', 0.46299363942557087),
#  ('camp', 'cabin', 0.4337288638459348),
#  ('pot', 'appliance', 0.2640508570941592),
#  ('linen', 'fabric', 0.5465313350372918),
#  ('whiskey', 'champagne', 0.49334847670155907),
#  ('girl', 'child', 0.4816078620910977),
#  ('cottage', 'cabin', 0.6328538177378428),
#  ('bird', 'hen', 0.40120290044914536),
#  ('racket', 'noise', 0.3795107248248904),
#  ('sunset', 'evening', 0.5558346955664988),
#  ('drizzle', 'rain', 0.5157243377577226),
#  ('adult', 'baby', 0.5321957884700401),
#  ('charcoal', 'coal', 0.5250969077315841),
#  ('body', 'spine', 0.4017409845785763),
#  ('head', 'nail', 0.3235174050848931),
#  ('log', 'timber', 0.3627984777218699),
#  ('spoon', 'cup', 0.48232166624063244),
#  ('body', 'nerve', 0.3172356767711084),
#  ('man', 'husband', 0.43283011813061256),
#  ('bone', 'neck', 0.37188731868703345),
#  ('frustration', 'anger', 0.4437941166201361),
#  ('river', 'sea', 0.4554028243383879),
#  ('task', 'job', 0.5667828884142291),
#  ('club', 'society', 0.3675350527672603),
#  ('reflection', 'image', 0.4575000685894921),
#  ('prince', 'king', 0.5030771734225811),
#  ('snow', 'weather', 0.48334497371403423),
#  ('people', 'party', 0.457408204022432),
#  ('boy', 'brother', 0.441670112114799),
#  ('root', 'grass', 0.32537499945423065),
#  ('brow', 'eye', 0.4474121923794787),
#  ('money', 'pearl', 0.3127394895841523),
#  ('money', 'diamond', 0.3305881446741488),
#  ('vehicle', 'bus', 0.5123750770367339),
#  ('cab', 'bus', 0.5119331272787454),
#  ('house', 'barn', 0.40541009537961603),
#  ('finger', 'palm', 0.44589174070928556),
#  ('car', 'bridge', 0.32421493685015346),
#  ('effort', 'difficulty', 0.43354478419098114),
#  ('fact', 'insight', 0.23478023758650113),
#  ('job', 'management', 0.37897493046319625),
#  ('cancer', 'sickness', 0.4529541608366362),
#  ('word', 'newspaper', 0.3238395965575955),
#  ('composer', 'writer', 0.5076497505802896),
#  ('actor', 'singer', 0.5492144557637639),
#  ('shelter', 'hut', 0.5293529090744863),
#  ('bathroom', 'kitchen', 0.6232083598460445),
#  ('cabin', 'hut', 0.5481879223592565),
#  ('door', 'kitchen', 0.3891267268043011),
#  ('value', 'belief', 0.4297372257111499),
#  ('wisdom', 'intelligence', 0.44744530793161247),
#  ('ignorance', 'intelligence', 0.3291777623548063),
#  ('happiness', 'luck', 0.43166620885559875),
#  ('idea', 'scheme', 0.5478820421410223),
#  ('mood', 'emotion', 0.5806369261106257),
#  ('happiness', 'peace', 0.4209584678227974),
#  ('despair', 'misery', 0.528352983048152),
#  ('logic', 'arithmetic', 0.4446488348919471),
#  ('denial', 'confession', 0.42994946070081985),
#  ('argument', 'criticism', 0.38637239453732475),
#  ('aggression', 'hostility', 0.6638458785010423),
#  ('hysteria', 'confusion', 0.43448327104578494),
#  ('chemistry', 'theory', 0.43950897437146835),
#  ('trial', 'verdict', 0.4388522254573632),
#  ('comfort', 'safety', 0.4280929967063901),
#  ('confidence', 'self', 0.45005212848960535),
#  ('vision', 'perception', 0.44835526144672744),
#  ('era', 'decade', 0.3323709183694097),
#  ('biography', 'fiction', 0.444072310742486),
#  ('discussion', 'argument', 0.47829194327903),
#  ('code', 'symbol', 0.4600443832598657),
#  ('danger', 'disease', 0.3801073903795182),
#  ('accident', 'catastrophe', 0.546438262878408),
#  ('journey', 'trip', 0.5221429177131944),
#  ('activity', 'movement', 0.5690400024680177),
#  ('gossip', 'news', 0.4510270330517423),
#  ('father', 'god', 0.4466170646728047),
#  ('action', 'course', 0.30971589172619923),
#  ('fever', 'illness', 0.4356010548481283),
#  ('aviation', 'flight', 0.522017724873336),
#  ('game', 'action', 0.41428755733110906),
#  ('molecule', 'air', 0.2912092713721),
#  ('home', 'state', 0.3573683160127757),
#  ('word', 'literature', 0.3157486575307594),
#  ('adult', 'guardian', 0.3352719586718547),
#  ('newspaper', 'information', 0.3105367489660569),
#  ('communication', 'television', 0.40614761800999094),
#  ('cousin', 'uncle', 0.5762766428524884),
#  ('author', 'reader', 0.4940630918873364),
#  ('guy', 'partner', 0.35659253635339155),
#  ('area', 'corner', 0.4427111363480139),
#  ('ballad', 'song', 0.5049686952667668),
#  ('wall', 'decoration', 0.31725140303740024),
#  ('word', 'page', 0.3282474145218608),
#  ('nurse', 'scientist', 0.39330552650564965),
#  ('politician', 'president', 0.4499431720682072),
#  ('president', 'mayor', 0.47417953663324575),
#  ('book', 'essay', 0.48494152440052785),
#  ('man', 'warrior', 0.42572774145356096),
#  ('article', 'journal', 0.5708743423895237),
#  ('breakfast', 'supper', 0.4952114562907533),
#  ('crowd', 'parade', 0.4213171707232239),
#  ('aisle', 'hallway', 0.5766697034620004),
#  ('teacher', 'rabbi', 0.41207711869647423),
#  ('hip', 'lip', 0.5138643836792022),
#  ('book', 'article', 0.5241333917666119),
#  ('room', 'cell', 0.4311781212610046),
#  ('box', 'booth', 0.46842774205958965),
#  ('daughter', 'kid', 0.4263562527280598),
#  ('limb', 'leg', 0.4741551621322931),
#  ('liver', 'lung', 0.4657901999708484),
#  ('classroom', 'hallway', 0.4514301702614172),
#  ('mountain', 'ledge', 0.2962598337435173),
#  ('car', 'elevator', 0.3675815203274098),
#  ('bed', 'couch', 0.5045916407626131),
#  ('clothes', 'button', 0.2972060706976703),
#  ('clothes', 'coat', 0.4387889283629566),
#  ('kidney', 'organ', 0.4279719601087331),
#  ('apple', 'sauce', 0.3406366712436477),
#  ('chicken', 'steak', 0.5169706748320977),
#  ('car', 'hose', 0.3228192114986753),
#  ('tobacco', 'cigarette', 0.607243477269735),
#  ('student', 'professor', 0.471324533604867),
#  ('baby', 'daughter', 0.48597841244666323),
#  ('pipe', 'cigar', 0.40983597977280994),
#  ('milk', 'juice', 0.5248467300990799),
#  ('box', 'cigar', 0.32860021534062417),
#  ('apartment', 'hotel', 0.46222047778923325),
#  ('cup', 'cone', 0.4725767396721646),
#  ('horse', 'ox', 0.3596162188726379),
#  ('throat', 'nose', 0.3842104860566665),
#  ('bone', 'teeth', 0.3746750623960978),
#  ('bone', 'elbow', 0.3651569177811302),
#  ('bacon', 'bean', 0.3437803991254718),
#  ('cup', 'jar', 0.43652368092146737),
#  ('proof', 'fact', 0.3992757349334365),
#  ('appointment', 'engagement', 0.3801570065170041),
#  ('birthday', 'year', 0.48678570973956703),
#  ('word', 'clue', 0.34120940745609724),
#  ('author', 'creator', 0.5961873316786676),
#  ('atom', 'carbon', 0.4952512152106781),
#  ('archbishop', 'bishop', 0.6003135802010306),
#  ('letter', 'paragraph', 0.5334295818587728),
#  ('page', 'paragraph', 0.5165063266181175),
#  ('steeple', 'chapel', 0.5225149703440831),
#  ('muscle', 'bone', 0.42493390677914195),
#  ('muscle', 'tongue', 0.3920288077482829),
#  ('boy', 'soldier', 0.40531955702123296),
#  ('belly', 'abdomen', 0.5973870786328521),
#  ('guy', 'girl', 0.552640315543569),
#  ('bed', 'chair', 0.4011284175949588),
#  ('clothes', 'jacket', 0.4872104801962009),
#  ('gun', 'knife', 0.46315415161772705),
#  ('tin', 'metal', 0.4626405495411325),
#  ('bottle', 'container', 0.4712876265018567),
#  ('hen', 'turkey', 0.3313927525611549),
#  ('meat', 'bread', 0.416047191309022),
#  ('arm', 'bone', 0.30335268550888284),
#  ('neck', 'spine', 0.459074905634578),
#  ('apple', 'lemon', 0.41849130138729146),
#  ('agony', 'grief', 0.4870779528497308),
#  ('assignment', 'task', 0.5833809519032913),
#  ('night', 'dawn', 0.461461398965074),
#  ('dinner', 'soup', 0.41625565606124476),
#  ('calf', 'bull', 0.4076014911991345),
#  ('snow', 'storm', 0.4754309691825937),
#  ('nail', 'hand', 0.3508481182224687),
#  ('dog', 'horse', 0.4775374981539347),
#  ('arm', 'neck', 0.3319761499999418),
#  ('ball', 'glove', 0.4047428363289356),
#  ('flu', 'fever', 0.36140587211635034),
#  ('fee', 'salary', 0.40467939264080593),
#  ('nerve', 'brain', 0.450197538053304),
#  ('beast', 'animal', 0.6004246886767023),
#  ('dinner', 'chicken', 0.447276629516757),
#  ('girl', 'maid', 0.3511545028690608),
#  ('child', 'boy', 0.5048875768830026),
#  ('alcohol', 'wine', 0.4837849858647667),
#  ('nose', 'mouth', 0.36459453709539824),
#  ('street', 'car', 0.3618183687443906),
#  ('bell', 'door', 0.36506973607336446),
#  ('box', 'hat', 0.3435697241732668),
#  ('belief', 'impression', 0.3907805702307977),
#  ('bias', 'opinion', 0.34928170752537835),
#  ('attention', 'awareness', 0.5648567611520189),
#  ('anger', 'mood', 0.4314577436560457),
#  ('elegance', 'style', 0.5310574290110356),
#  ('beauty', 'age', 0.2651140809222637),
#  ('book', 'theme', 0.36051892347201747),
#  ('friend', 'mother', 0.3987028341218755),
#  ('vitamin', 'iron', 0.3613804901976727),
#  ('car', 'factory', 0.3561304339135342),
#  ('pact', 'condition', 0.38398966965199033),
#  ('chapter', 'choice', 0.39900360831311044),
#  ('arithmetic', 'rhythm', 0.33632178035592347),
#  ('winner', 'presence', 0.282176522394516),
#  ('belief', 'flower', 0.27810875268717267),
#  ('winner', 'goal', 0.37881731569489996),
#  ('trick', 'size', 0.25989382769020036),
#  ('choice', 'vein', 0.2295966058813154),
#  ('hymn', 'conquest', 0.18676841703184394),
#  ('endurance', 'band', 0.19022849904620945),
#  ('jail', 'choice', 0.30815783548347175),
#  ('condition', 'boy', 0.33371412080748053),
#  ('flower', 'endurance', 0.17708119805792433),
#  ('hole', 'agreement', 0.23800418184511668),
#  ('doctor', 'temper', 0.20434499544423967),
#  ('fraternity', 'door', 0.2384228323855364),
#  ('task', 'woman', 0.2324455160389538),
#  ('fraternity', 'baseball', 0.2298901384221309),
#  ('cent', 'size', 0.30116055023072535),
#  ('presence', 'door', 0.3124348708869681),
#  ('mouse', 'management', 0.31282189121409504),
#  ('task', 'highway', 0.1858793810506973),
#  ('liquor', 'century', 0.1708696828456797),
#  ('task', 'straw', 0.25045887230360603),
#  ('island', 'task', 0.22274269865528082),
#  ('night', 'chapter', 0.32270937573354025),
#  ('pollution', 'president', 0.17404309524695277),
#  ('gun', 'trick', 0.3153141381399546),
#  ('bath', 'trick', 0.2733993842244944),
#  ('diet', 'apple', 0.2903038352034392),
#  ('cent', 'wife', 0.17129886740665215),
#  ('chapter', 'tail', 0.27846460754287294),
#  ('course', 'stomach', 0.22602120523093033),
#  ('hymn', 'straw', 0.20530017375979553),
#  ('dentist', 'colonel', 0.26615681692037196),
#  ('wife', 'straw', 0.2266900819518004),
#  ('hole', 'wife', 0.2580109093231949),
#  ('pupil', 'president', 0.28521086606231405),
#  ('bath', 'wife', 0.2195660122185153),
#  ('people', 'cent', 0.2889665975599795),
#  ('formula', 'log', 0.3988239445543337),
#  ('woman', 'fur', 0.27272314146183146),
#  ('apple', 'sunshine', 0.2668718470980752),
#  ('gun', 'dawn', 0.2517513470155048),
#  ('meal', 'waist', 0.2221798082033602),
#  ('camera', 'president', 0.22948149133419385),
#  ('liquor', 'band', 0.21707078483491682),
#  ('stomach', 'vein', 0.2915819644555588),
#  ('gun', 'fur', 0.34734288010082476),
#  ('couch', 'baseball', 0.2877031711547506),
#  ('worker', 'camera', 0.3040549836628635),
#  ('deck', 'mouse', 0.3476368582034023),
#  ('rice', 'boy', 0.27401900129163614),
#  ('people', 'gun', 0.2642835700796762),
#  ('cliff', 'tail', 0.28079176455218524),
#  ('ankle', 'window', 0.28018118367226913),
#  ('princess', 'island', 0.2855984901869597),
#  ('container', 'mouse', 0.34790702101852),
#  ('wagon', 'container', 0.5382805826413866),
#  ('people', 'balloon', 0.24637513010887985),
#  ('dollar', 'people', 0.28393939454550765),
#  ('bath', 'balloon', 0.37196766598904474),
#  ('stomach', 'bedroom', 0.3287535188762752),
#  ('bicycle', 'bedroom', 0.30626037867731587),
#  ('log', 'bath', 0.27763349754346023),
#  ('bowl', 'tail', 0.323250507344425),
#  ('go', 'come', 0.5039741699521793),
#  ('take', 'steal', 0.49252596746942023),
#  ('listen', 'hear', 0.6091895816428962),
#  ('think', 'rationalize', 0.32708682462167193),
#  ('occur', 'happen', 0.7281565908518381),
#  ('vanish', 'disappear', 0.8534396298576653),
#  ('multiply', 'divide', 0.5451582701355131),
#  ('plead', 'beg', 0.42039996136553515),
#  ('begin', 'originate', 0.37406010369187176),
#  ('protect', 'defend', 0.6231542689659629),
#  ('kill', 'destroy', 0.592542566491272),
#  ('create', 'make', 0.659539243843174),
#  ('accept', 'reject', 0.5879334885113481),
#  ('ignore', 'avoid', 0.5880961642243365),
#  ('carry', 'bring', 0.6206564905712432),
#  ('leave', 'enter', 0.4134058638357421),
#  ('choose', 'elect', 0.45528047341929173),
#  ('lose', 'fail', 0.4500096529014296),
#  ('encourage', 'discourage', 0.6395083712820675),
#  ('achieve', 'accomplish', 0.7886955217921692),
#  ('make', 'construct', 0.5771893440129138),
#  ('listen', 'obey', 0.42651522786500606),
#  ('inform', 'notify', 0.6247819028292477),
#  ('receive', 'give', 0.4887237568100242),
#  ('borrow', 'beg', 0.43944843286113966),
#  ('take', 'obtain', 0.42713717937387913),
#  ('advise', 'recommend', 0.5748644889856549),
#  ('imitate', 'portray', 0.41715937291100014),
#  ('win', 'succeed', 0.4389482977407971),
#  ('think', 'decide', 0.41619323004915626),
#  ('greet', 'meet', 0.5186534521392445),
#  ('agree', 'argue', 0.4203256603505655),
#  ('enjoy', 'entertain', 0.47248090590361463),
#  ('destroy', 'make', 0.44383661288617615),
#  ('save', 'protect', 0.5219691359413932),
#  ('give', 'lend', 0.4979701025207281),
#  ('understand', 'know', 0.5207349098062547),
#  ('take', 'receive', 0.48147144025257865),
#  ('accept', 'acknowledge', 0.5952743160623556),
#  ('decide', 'choose', 0.5910286625240396),
#  ('accept', 'believe', 0.42452152967876655),
#  ('keep', 'possess', 0.40231071280201963),
#  ('roam', 'wander', 0.6500578121947471),
#  ('succeed', 'fail', 0.4438196585569425),
#  ('spend', 'save', 0.3496645671204003),
#  ('leave', 'go', 0.4735776381592586),
#  ('come', 'attend', 0.39563561622821364),
#  ('know', 'believe', 0.4378245267230323),
#  ('gather', 'meet', 0.5006436036026609),
#  ('make', 'earn', 0.3996246394309369),
#  ('forget', 'ignore', 0.5491656697769853),
#  ('multiply', 'add', 0.3920644098683385),
#  ('shrink', 'grow', 0.412485287875659),
#  ('arrive', 'leave', 0.4024752636772104),
#  ('succeed', 'try', 0.3830856170497319),
#  ('accept', 'deny', 0.49135974374806346),
#  ('arrive', 'come', 0.43098694441811863),
#  ('agree', 'differ', 0.3337981344407585),
#  ('send', 'receive', 0.5180231462202866),
#  ('win', 'dominate', 0.40049273541611885),
#  ('add', 'divide', 0.36337802216037324),
#  ('kill', 'choke', 0.3987287326350919),
#  ('acquire', 'get', 0.3504148153975811),
#  ('participate', 'join', 0.45735372196812746),
#  ('leave', 'remain', 0.5326645970831184),
#  ('go', 'enter', 0.4319948026895783),
#  ('take', 'carry', 0.4554059637005737),
#  ('forget', 'learn', 0.402084196661289),
#  ('appoint', 'elect', 0.42634382054681613),
#  ('engage', 'marry', 0.388866533604085),
#  ('ask', 'pray', 0.42400019278141515),
#  ('go', 'send', 0.4463450230760855),
#  ('take', 'deliver', 0.419732534973053),
#  ('speak', 'hear', 0.45159237877751),
#  ('analyze', 'evaluate', 0.7295902919574019),
#  ('argue', 'rationalize', 0.33799999342921483),
#  ('lose', 'keep', 0.40233054940852936),
#  ('compare', 'analyze', 0.5931330167878187),
#  ('disorganize', 'organize', 0.5845458300076862),
#  ('go', 'allow', 0.3872846650511148),
#  ('take', 'possess', 0.4121296069787064),
#  ('learn', 'listen', 0.48977770380717617),
#  ('destroy', 'construct', 0.49727939844001795),
#  ('create', 'build', 0.6083200755775353),
#  ('steal', 'buy', 0.39911669568452424),
#  ('kill', 'hang', 0.4174708451814289),
#  ('forget', 'know', 0.40530529602785675),
#  ('create', 'imagine', 0.42526121353169455),
#  ('do', 'happen', 0.39821090168603746),
#  ('win', 'accomplish', 0.3235164965929075),
#  ('give', 'deny', 0.3293978714869805),
#  ('deserve', 'earn', 0.45866157821826437),
#  ('get', 'put', 0.49219496650666567),
#  ('locate', 'find', 0.6045313573400453),
#  ('appear', 'attend', 0.47627982702750155),
#  ('know', 'comprehend', 0.37643204430482813),
#  ('pretend', 'imagine', 0.5947056316368213),
#  ('satisfy', 'please', 0.33840045780050787),
#  ('cherish', 'keep', 0.42415282543497385),
#  ('argue', 'differ', 0.40132853652685374),
#  ('overcome', 'dominate', 0.45131440154576014),
#  ('behave', 'obey', 0.5152374996903919),
#  ('cooperate', 'participate', 0.5237401153491813),
#  ('achieve', 'try', 0.3124666642994206),
#  ('fail', 'discourage', 0.2665858449689075),
#  ('begin', 'quit', 0.42953489885232593),
#  ('say', 'participate', 0.2586494584749869),
#  ('come', 'bring', 0.4742899401224953),
#  ('declare', 'announce', 0.5534942286154932),
#  ('read', 'comprehend', 0.38486333317310234),
#  ('take', 'leave', 0.42016812823632105),
#  ('proclaim', 'announce', 0.5189550184341299),
#  ('acquire', 'obtain', 0.7270375895134292),
#  ('conclude', 'decide', 0.4726957422668599),
#  ('please', 'plead', 0.436189019118782),
#  ('argue', 'prove', 0.4405033526494274),
#  ('ask', 'plead', 0.3702655735234832),
#  ('find', 'disappear', 0.22033052814967657),
#  ('inspect', 'examine', 0.5965676969318704),
#  ('verify', 'justify', 0.628740693607898),
#  ('assume', 'predict', 0.43691997191208654),
#  ('learn', 'evaluate', 0.4135884080689475),
#  ('argue', 'justify', 0.4417676884190317),
#  ('make', 'become', 0.376976596116475),
#  ('discover', 'originate', 0.3476622525806412),
#  ('achieve', 'succeed', 0.5847562464746785),
#  ('give', 'put', 0.4244773564702973),
#  ('understand', 'listen', 0.41350191351660287),
#  ('expand', 'grow', 0.6110603550509518),
#  ('borrow', 'sell', 0.40308604402234016),
#  ('keep', 'protect', 0.5726191805585147),
#  ('explain', 'prove', 0.4736640180185006),
#  ('assume', 'pretend', 0.45801123955263856),
#  ('agree', 'please', 0.3775625623686667),
#  ('forgive', 'forget', 0.508246408205199),
#  ('clarify', 'explain', 0.48088656017225584),
#  ('understand', 'forgive', 0.4428181817918515),
#  ('remind', 'forget', 0.5201666126677511),
#  ('get', 'remain', 0.26974587411570705),
#  ('realize', 'discover', 0.47285114124120053),
#  ('require', 'inquire', 0.3553840304270434),
#  ('ignore', 'ask', 0.353878412616275),
#  ('think', 'inquire', 0.3173494731438649),
#  ('reject', 'avoid', 0.48330022177206344),
#  ('argue', 'persuade', 0.4614394158156451),
#  ('pursue', 'persuade', 0.43264723265639504),
#  ('accept', 'forgive', 0.41508817180689056),
#  ('do', 'quit', 0.3774659149032835),
#  ('investigate', 'examine', 0.6628259362413508),
#  ('discuss', 'explain', 0.4775854056882735),
#  ('owe', 'lend', 0.36166455452728413),
#  ('explore', 'discover', 0.6227619041280669),
#  ('complain', 'argue', 0.5012979672547319),
#  ('withdraw', 'reject', 0.5751469871619581),
#  ('keep', 'borrow', 0.3854709246424557),
#  ('beg', 'ask', 0.48324795130112463),
#  ('arrange', 'organize', 0.6786178843689338),
#  ('reduce', 'shrink', 0.520094276643343),
#  ('speak', 'acknowledge', 0.3576840574143008),
#  ('give', 'borrow', 0.4132579179290953),
#  ('kill', 'defend', 0.3690545587666059),
#  ('disappear', 'shrink', 0.4787484355347981),
#  ('deliver', 'carry', 0.5344954021159501),
#  ('breathe', 'choke', 0.40247853623674),
#  ('acknowledge', 'notify', 0.3865093267784091),
#  ('become', 'seem', 0.41112275847680185),
#  ('pretend', 'seem', 0.4408053262061986),
#  ('accomplish', 'become', 0.3752366152039267),
#  ('contemplate', 'think', 0.48089793434580763),
#  ('determine', 'predict', 0.4230748465744323),
#  ('please', 'entertain', 0.2861313398526456),
#  ('remain', 'retain', 0.6922378999601871),
#  ('pretend', 'portray', 0.4494157651684384),
#  ('forget', 'retain', 0.41692655305739873),
#  ('want', 'choose', 0.520218476395153),
#  ('lose', 'get', 0.27683244770520166),
#  ('try', 'think', 0.40444035984088084),
#  ('become', 'appear', 0.3876855921218713),
#  ('leave', 'ignore', 0.41121499794534844),
#  ('accept', 'recommend', 0.42885266061290367),
#  ('leave', 'wander', 0.42431700183558135),
#  ('keep', 'give', 0.44380990483552196),
#  ('give', 'allow', 0.509043143173674),
#  ('bring', 'send', 0.4550901846824219),
#  ('absorb', 'learn', 0.378536251658758),
#  ('acquire', 'find', 0.31025074759888704),
#  ('leave', 'appear', 0.3549379001397125),
#  ('create', 'destroy', 0.5256646431104679),
#  ('begin', 'go', 0.44813630526396736),
#  ('get', 'buy', 0.3403051641526093),
#  ('collect', 'save', 0.42963382465401445),
#  ('replace', 'restore', 0.508268783808879),
#  ('join', 'add', 0.48537528037288574),
#  ('join', 'marry', 0.38812613145444064),
#  ('accept', 'deliver', 0.379215294527457),
#  ('attach', 'join', 0.5053791434472354),
#  ('put', 'hang', 0.40201215834248555),
#  ('go', 'sell', 0.37820506596602205),
#  ('communicate', 'pray', 0.30592616875278583),
#  ('give', 'steal', 0.3615456114430222),
#  ('add', 'build', 0.43708380666429925),
#  ('bring', 'restore', 0.35051902752515535),
#  ('comprehend', 'satisfy', 0.3410839839572512),
#  ('portray', 'decide', 0.21383521308758652),
#  ('organize', 'become', 0.32902523661345845),
#  ('give', 'know', 0.39783232521252493),
#  ('say', 'verify', 0.2909182349950539),
#  ('cooperate', 'join', 0.3719824280361618),
#  ('arrange', 'require', 0.3701146176109016),
#  ('borrow', 'want', 0.400723298116821),
#  ('investigate', 'pursue', 0.49580160071709456),
#  ('ignore', 'explore', 0.32236662879748085),
#  ('bring', 'complain', 0.2984974507344796),
#  ('enter', 'owe', 0.29312787686819064),
#  ('portray', 'notify', 0.19269537097429187),
#  ('remind', 'sell', 0.26983758117911755),
#  ('absorb', 'possess', 0.37332204963663623),
#  ('join', 'acquire', 0.30467783276378196),
#  ('send', 'attend', 0.378200844738553),
#  ('gather', 'attend', 0.5177677674488335),
#  ('absorb', 'withdraw', 0.34380986667042235),
#  ('attend', 'arrive', 0.4138098752820838)]

# %%
# Store results in DataFrame and round 2 decimals
df = process_responses_embeddings(response)

# Show results
df
# Out:
#       word1        word2  similarity_score
# 0       old          new              0.57
# 1     smart  intelligent              0.61
# 2      hard    difficult              0.52
# 3     happy     cheerful              0.57
# 4      hard         easy              0.52
# ..      ...          ...               ...
# 994    join      acquire              0.30
# 995    send       attend              0.38
# 996  gather       attend              0.52
# 997  absorb     withdraw              0.34
# 998  attend       arrive              0.41
#
# [999 rows x 3 columns]

# %% [markdown]
# Note that this shows the cosine similarity score on the scale [-1; 1]. The similarity_score will be normalized to the SimLex questionnaire scale [0; 10] in the evaluation notebook.

# %%
# Define file_path
file_path = '../../../data/text-embedding-3-large/en.csv'

# Check if the file already exists
if not os.path.exists(file_path):
    df.to_csv(file_path, index=False)
    print("File saved successfully.")
else:
    print("File already exists. Dataframe was not saved to prevent overwriting.")
# Out:
# File saved successfully.
