# %% [markdown]
# ### **0. Set-up**

# %%
# Import libraries and utils
# %run '../../utils.ipynb'

# %%
# Get api key
load_dotenv()
OPENROUTER_API_KEY = os.getenv('OPENROUTER_API_KEY')

# Set client
client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=OPENROUTER_API_KEY,
)

# %%
# Load predicted
f9_1 = pd.read_csv("../../../data/gpt-oss-20b/processed/en/f9-1.csv")
f9_2 = pd.read_csv("../../../data/gpt-oss-20b/processed/en/f9-2.csv")
f9_3 = pd.read_csv("../../../data/gpt-oss-20b/processed/en/f9-3.csv")

# Combine the dataframes
raw_predicted = pd.concat([f9_1, f9_2, f9_3], ignore_index=True)

# Load actual
raw_actual = pd.read_csv("../../../data/dataset/cleaned-en-simlex-999.csv")

# %%
# Show results
raw_predicted
# Out:
#       word1        word2  similarity_score_1  similarity_score_2  \
# 0       old          new                0.00                0.00
# 1     smart  intelligent                9.00                8.75
# 2      hard    difficult                9.00                9.50
# 3     happy     cheerful                8.75                9.00
# 4      hard         easy                0.00                0.00
# ..      ...          ...                 ...                 ...
# 935    join      acquire                4.00                2.75
# 936    send       attend                1.00                0.15
# 937  gather       attend                5.50                6.00
# 938  absorb     withdraw                2.50                0.20
# 939  attend       arrive                6.50                4.25
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                  0.75                2.00                0.00
# 1                  9.50                9.50                9.50
# 2                  9.75                8.75                9.50
# 3                  9.20                8.00                9.00
# 4                  0.00                0.05                0.00
# ..                  ...                 ...                 ...
# 935                4.50                6.50                4.00
# 936                1.30                0.10                0.75
# 937                7.50                5.00                5.00
# 938                0.10                0.20                0.05
# 939                6.50                4.50                5.50
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                   0.0                0.10                0.05
# 1                   9.5                9.20                8.50
# 2                   9.0                9.50                9.75
# 3                   9.5                9.30                9.80
# 4                   0.0                0.00                0.00
# ..                  ...                 ...                 ...
# 935                 4.5                6.25                3.50
# 936                 1.5                2.50                0.20
# 937                 4.5                4.50                7.50
# 938                 0.0                1.50                1.50
# 939                 6.0                5.67                6.00
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                  1.00                 0.00                  0.0
# 1                  9.50                 9.75                  9.5
# 2                  8.75                 9.20                  9.8
# 3                  9.00                 8.75                  8.5
# 4                  0.10                 0.00                  0.1
# ..                  ...                  ...                  ...
# 935                3.50                 4.00                  6.5
# 936                1.50                 1.00                  2.0
# 937                7.00                 6.25                  5.5
# 938                0.10                 0.10                  0.1
# 939                5.00                 5.40                  6.3
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                   0.00                 0.10                 0.00
# 1                   9.00                 8.50                 9.00
# 2                   9.50                 9.00                 9.50
# 3                   9.45                 8.50                 9.00
# 4                   0.00                 0.00                 0.00
# ..                   ...                  ...                  ...
# 935                 4.00                 2.50                 2.50
# 936                 0.05                 0.05                 0.00
# 937                 7.20                 7.50                 6.50
# 938                 1.00                 0.00                 0.50
# 939                 6.00                 3.50                 5.25
#
#      similarity_score_15
# 0                   0.00
# 1                   9.00
# 2                   9.50
# 3                   8.50
# 4                   0.00
# ..                   ...
# 935                 7.50
# 936                 2.50
# 937                 6.50
# 938                 1.00
# 939                 6.25
#
# [940 rows x 17 columns]

# %% [markdown]
# ### **1. Get all the missing word pairs**

# %%
# Create a set of word pairs from raw_actual
actual_pairs = set(zip(raw_actual['word1'], raw_actual['word2']))

# Filter raw_predicted to only keep word pairs that exist in raw_actual
mask = raw_predicted.apply(lambda row: (row['word1'], row['word2']) in actual_pairs, axis=1)
predicted_filtered = raw_predicted[mask].copy()

print(f"Dropped {(~mask).sum()} invalid word pairs from raw_predicted")
# Out:
# Dropped 0 invalid word pairs from raw_predicted

# %%
# Get all the missing word pairs (in raw_actual but NOT in raw_predicted)
predicted_pairs = set(zip(predicted_filtered['word1'], predicted_filtered['word2']))

# Find missing pairs
mask_missing = raw_actual.apply(lambda row: (row['word1'], row['word2']) not in predicted_pairs, axis=1)
missing_pairs_df = raw_actual[mask_missing].copy()

# Convert to list of tuples
missing_word_pairs = list(zip(missing_pairs_df['word1'], missing_pairs_df['word2']))

print(f"Found {len(missing_word_pairs)} missing word pairs in raw_predicted")
missing_word_pairs
# Out:
# Found 59 missing word pairs in raw_predicted
# [('new', 'fresh'),
#  ('sad', 'funny'),
#  ('harsh', 'cruel'),
#  ('rough', 'frigid'),
#  ('bad', 'guilty'),
#  ('bottom', 'top'),
#  ('student', 'pupil'),
#  ('leg', 'arm'),
#  ('actress', 'actor'),
#  ('sunset', 'sunrise'),
#  ('roof', 'ceiling'),
#  ('date', 'calendar'),
#  ('mud', 'dirt'),
#  ('steak', 'meat'),
#  ('dictionary', 'definition'),
#  ('boy', 'son'),
#  ('loop', 'belt'),
#  ('cereal', 'wheat'),
#  ('intelligence', 'logic'),
#  ('bride', 'princess'),
#  ('curve', 'angle'),
#  ('mouth', 'tooth'),
#  ('wood', 'paper'),
#  ('doctor', 'professor'),
#  ('bee', 'ant'),
#  ('alley', 'bowl'),
#  ('sinner', 'saint'),
#  ('men', 'fraternity'),
#  ('apartment', 'furniture'),
#  ('fee', 'payment'),
#  ('elbow', 'ankle'),
#  ('effort', 'difficulty'),
#  ('biography', 'fiction'),
#  ('home', 'state'),
#  ('president', 'mayor'),
#  ('limb', 'leg'),
#  ('box', 'cigar'),
#  ('night', 'dawn'),
#  ('beast', 'animal'),
#  ('jail', 'choice'),
#  ('task', 'woman'),
#  ('hole', 'wife'),
#  ('deck', 'mouse'),
#  ('princess', 'island'),
#  ('inform', 'notify'),
#  ('enjoy', 'entertain'),
#  ('roam', 'wander'),
#  ('come', 'attend'),
#  ('succeed', 'try'),
#  ('appoint', 'elect'),
#  ('take', 'leave'),
#  ('verify', 'justify'),
#  ('give', 'put'),
#  ('discuss', 'explain'),
#  ('accomplish', 'become'),
#  ('bring', 'send'),
#  ('leave', 'appear'),
#  ('portray', 'decide'),
#  ('absorb', 'possess')]

# %% [markdown]
# ### **2. Extract data for missing word pairs**

# %%
prompt = ("Rate the semantic similarity of the word pair: [('{word1}'), ('{word2}')] on a scale from 0 to 10, "
          "where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. "
          "Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. "
          "Do not provide additional explanations or context.")

# %%
# Define model
model = "openai/gpt-oss-20b"

# Set sample size
missing_sample_size = 15

# Delay between individual API calls
missing_delay = 1.0

# %%
# Define number of sublists
missing_n_sublists = len(missing_word_pairs)

# Split list
missing_chunks = split_into_n_lists(missing_word_pairs, missing_n_sublists)

# Count number of lists
print(len(missing_chunks))
# Out:
# 59

# %%
# Print prompts for each chunk
print_prompts_single(missing_chunks, missing_sample_size, prompt)
# Out:
# Rate the semantic similarity of the word pair: [('new'), ('fresh')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('new'), ('fresh')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('new'), ('fresh')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('new'), ('fresh')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('new'), ('fresh')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('new'), ('fresh')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('new'), ('fresh')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('new'), ('fresh')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('new'), ('fresh')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('new'), ('fresh')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('new'), ('fresh')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('new'), ('fresh')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('new'), ('fresh')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('new'), ('fresh')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('new'), ('fresh')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('sad'), ('funny')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('sad'), ('funny')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('sad'), ('funny')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('sad'), ('funny')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('sad'), ('funny')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('sad'), ('funny')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('sad'), ('funny')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('sad'), ('funny')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('sad'), ('funny')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('sad'), ('funny')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('sad'), ('funny')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('sad'), ('funny')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('sad'), ('funny')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('sad'), ('funny')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('sad'), ('funny')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('harsh'), ('cruel')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('harsh'), ('cruel')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('harsh'), ('cruel')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('harsh'), ('cruel')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('harsh'), ('cruel')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('harsh'), ('cruel')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('harsh'), ('cruel')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('harsh'), ('cruel')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('harsh'), ('cruel')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('harsh'), ('cruel')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('harsh'), ('cruel')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('harsh'), ('cruel')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('harsh'), ('cruel')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('harsh'), ('cruel')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('harsh'), ('cruel')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('rough'), ('frigid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('rough'), ('frigid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('rough'), ('frigid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('rough'), ('frigid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('rough'), ('frigid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('rough'), ('frigid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('rough'), ('frigid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('rough'), ('frigid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('rough'), ('frigid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('rough'), ('frigid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('rough'), ('frigid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('rough'), ('frigid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('rough'), ('frigid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('rough'), ('frigid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('rough'), ('frigid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bad'), ('guilty')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bad'), ('guilty')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bad'), ('guilty')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bad'), ('guilty')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bad'), ('guilty')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bad'), ('guilty')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bad'), ('guilty')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bad'), ('guilty')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bad'), ('guilty')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bad'), ('guilty')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bad'), ('guilty')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bad'), ('guilty')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bad'), ('guilty')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bad'), ('guilty')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bad'), ('guilty')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bottom'), ('top')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bottom'), ('top')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bottom'), ('top')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bottom'), ('top')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bottom'), ('top')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bottom'), ('top')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bottom'), ('top')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bottom'), ('top')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bottom'), ('top')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bottom'), ('top')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bottom'), ('top')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bottom'), ('top')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bottom'), ('top')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bottom'), ('top')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('bottom'), ('top')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('student'), ('pupil')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('student'), ('pupil')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('student'), ('pupil')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('student'), ('pupil')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('student'), ('pupil')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('student'), ('pupil')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('student'), ('pupil')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('student'), ('pupil')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('student'), ('pupil')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('student'), ('pupil')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('student'), ('pupil')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('student'), ('pupil')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('student'), ('pupil')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('student'), ('pupil')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('student'), ('pupil')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leg'), ('arm')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leg'), ('arm')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leg'), ('arm')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leg'), ('arm')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leg'), ('arm')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leg'), ('arm')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leg'), ('arm')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leg'), ('arm')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leg'), ('arm')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leg'), ('arm')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leg'), ('arm')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leg'), ('arm')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leg'), ('arm')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leg'), ('arm')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leg'), ('arm')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('actress'), ('actor')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('actress'), ('actor')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('actress'), ('actor')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('actress'), ('actor')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('actress'), ('actor')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('actress'), ('actor')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('actress'), ('actor')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('actress'), ('actor')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('actress'), ('actor')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('actress'), ('actor')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('actress'), ('actor')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('actress'), ('actor')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('actress'), ('actor')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('actress'), ('actor')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('actress'), ('actor')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('sunset'), ('sunrise')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('sunset'), ('sunrise')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('sunset'), ('sunrise')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('sunset'), ('sunrise')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('sunset'), ('sunrise')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('sunset'), ('sunrise')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# ...
# Rate the semantic similarity of the word pair: [('bring'), ('send')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leave'), ('appear')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leave'), ('appear')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leave'), ('appear')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leave'), ('appear')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leave'), ('appear')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leave'), ('appear')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leave'), ('appear')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leave'), ('appear')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leave'), ('appear')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leave'), ('appear')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leave'), ('appear')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leave'), ('appear')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leave'), ('appear')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leave'), ('appear')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('leave'), ('appear')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('portray'), ('decide')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('portray'), ('decide')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('portray'), ('decide')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('portray'), ('decide')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('portray'), ('decide')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('portray'), ('decide')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('portray'), ('decide')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('portray'), ('decide')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('portray'), ('decide')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('portray'), ('decide')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('portray'), ('decide')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('portray'), ('decide')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('portray'), ('decide')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('portray'), ('decide')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('portray'), ('decide')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('absorb'), ('possess')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('absorb'), ('possess')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('absorb'), ('possess')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('absorb'), ('possess')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('absorb'), ('possess')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('absorb'), ('possess')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('absorb'), ('possess')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('absorb'), ('possess')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('absorb'), ('possess')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('absorb'), ('possess')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('absorb'), ('possess')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('absorb'), ('possess')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('absorb'), ('possess')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('absorb'), ('possess')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('absorb'), ('possess')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.

# %%
# Get results from API
missing_response = get_responses_single(prompt, missing_chunks, model, missing_sample_size, missing_delay)
# Out:
# Processing: 100%|██████████| 885/885 [43:46<00:00,  2.97s/chunk]
# Total time taken: 2626.36 seconds

# %%
# Define filepath
file_path = '../../../data/gpt-oss-20b/response/en/f9-post.json'

# Ensure directory exists
os.makedirs(os.path.dirname(file_path), exist_ok=True)

# Check if file already exists
if not os.path.exists(file_path):
    with open(file_path, 'w') as f:
        json.dump(missing_response, f)
        print("File saved successfully.")
else:
    print("File already exists. JSON was not saved to prevent overwriting.")
# Out:
# File already exists. JSON was not saved to prevent overwriting.

# %% [markdown]
# ### **3. Inspect Missing Word Pairs**

# %%
# Process data into dictionary
missing_data_dict = process_responses(missing_response)

# Check for values higher/lower then sample size
missing_higher_lower_samples = {key: value for key, value in missing_data_dict.items() if len(value) < missing_sample_size or len(value) > missing_sample_size}

# Show results
print(missing_higher_lower_samples)
# Out:
# {('accomplish', 'become'): [2.0, 3.75, 2.7, 2.0, 3.0, 2.0, 2.5, 0.15, 1.5, 3.0, 2.5, 3.5, 3.5, 1.75], ('acish', 'become'): [2.5]}

# %%
# Convert dict to Pandas DataFrame
missing_df = create_dataframe(missing_data_dict)

# Show results
missing_df
# Out:
#            word1       word2  similarity_score_1  similarity_score_2  \
# 0            new       fresh                8.00                6.50
# 1            sad       funny                2.00                2.00
# 2          harsh       cruel                8.50                9.00
# 3          rough      frigid                0.20                0.10
# 4            bad      guilty                6.50                6.50
# 5         bottom         top                0.00                0.00
# 6        student       pupil                9.75                9.50
# 7            leg         arm                6.00                5.50
# 8        actress       actor                9.00                7.00
# 9         sunset     sunrise                5.50                7.50
# 10          roof     ceiling                8.00                4.50
# 11          date    calendar                7.20                5.75
# 12           mud        dirt                9.75                8.50
# 13         steak        meat                8.50                9.00
# 14    dictionary  definition                8.00                7.50
# 15           boy         son                8.50                7.50
# 16          loop        belt                1.75                2.50
# 17        cereal       wheat                8.50                7.50
# 18  intelligence       logic                7.50                7.50
# 19         bride    princess                3.50                3.50
# 20         curve       angle                5.00                5.50
# 21         mouth       tooth                3.00                3.50
# 22          wood       paper                4.00                4.50
# 23        doctor   professor                4.50                6.50
# 24           bee         ant                6.50                7.50
# 25         alley        bowl                0.05                0.10
# 26        sinner       saint                1.50                2.50
# 27           men  fraternity                6.00                3.50
# 28     apartment   furniture                4.25                3.00
# 29           fee     payment                7.50                8.00
# 30         elbow       ankle                7.50                6.50
# 31        effort  difficulty                4.50                4.00
# 32     biography     fiction                1.50                2.00
# 33          home       state                1.50                2.00
# 34     president       mayor                5.00                6.00
# 35          limb         leg                8.50                8.80
# 36           box       cigar                2.50                2.00
# 37         night        dawn                2.00                3.00
# 38         beast      animal                8.50                8.25
# 39          jail      choice                0.20                0.10
# 40          task       woman                0.50                0.05
# 41          hole        wife                0.00                0.00
# 42          deck       mouse                0.00                0.00
# 43      princess      island                0.00                0.00
# 44        inform      notify                8.50                8.80
# 45         enjoy   entertain                7.50                7.50
# 46          roam      wander                8.50                9.50
# 47          come      attend                3.50                7.25
# 48       succeed         try                5.25                4.50
# 49       appoint       elect                7.50                7.50
# 50          take       leave                2.50                2.00
# 51        verify     justify                5.50                2.50
# 52          give         put                3.50                3.50
# 53       discuss     explain                6.50                6.50
# 54    accomplish      become                2.00                3.75
# 55         acish      become                2.50                 NaN
# 56         bring        send                7.50                7.50
# 57         leave      appear                2.00                2.00
# 58       portray      decide                1.50                0.10
# 59        absorb     possess                4.00                5.00
#
#     similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                 8.50                7.50                7.00
# 1                 0.00                0.05                0.00
# 2                 7.30                7.40                7.50
# 3                 0.00                0.10                0.10
# 4                 7.50                7.50                6.50
# 5                 0.10                0.10                0.00
# 6                 9.50                9.70                9.25
# 7                 5.50                8.50                6.00
# 8                 8.50                8.50                8.50
# 9                 7.50                7.75                8.50
# 10                7.50                6.25                6.50
# 11                6.00                5.50                7.50
# 12                9.00                8.50                8.50
# 13                8.50                8.50                8.00
# 14                7.50                7.50                7.00
# 15                7.20                6.50                7.50
# 16                2.50                0.05                2.00
# 17                7.00                8.00                8.50
# 18                7.50                6.50                8.50
# 19                4.00                4.50                3.50
# 20                4.75                2.50                4.50
# 21                7.50                5.50                3.75
# 22                6.00                4.50                5.60
# 23                5.00                7.50                4.50
# 24                7.50                7.50                7.50
# 25                0.05                0.00                0.05
# 26                0.00                0.10                0.10
# 27                4.50                4.00                3.00
# 28                3.50                4.00                3.50
# 29                8.00                7.30                8.50
# 30                6.50                7.50                5.00
# 31                5.20                4.20                5.50
# 32                2.00                0.30                3.00
# 33                3.00                2.00                2.00
# 34                5.40                6.50                6.30
# 35                8.50                8.50                8.50
# 36                2.63                1.00                0.05
# 37                2.50                2.00                1.80
# 38                8.50                7.50                8.20
# 39                1.00                0.05                1.20
# 40                0.00                0.05                0.00
# 41                0.00                0.00                0.00
# 42                0.00                0.00                0.10
# 43                0.00                0.10                0.00
# 44                8.75                9.00                8.50
# 45                7.50                7.25                6.80
# 46                9.25                9.00                9.50
# 47                4.50                5.75                7.20
# 48                4.50                3.50                5.20
# 49                6.50                7.20                8.25
# 50                0.10                0.15                2.50
# 51                1.50                4.00                5.30
# 52                1.50                3.00                4.50
# 53                7.25                7.50                7.50
# 54                2.70                2.00                3.00
# 55                 NaN                 NaN                 NaN
# 56                6.25                4.50                7.50
# 57                2.00                2.50                1.70
# 58                0.10                0.00                2.00
# 59                3.20                2.00                4.50
#
#     similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                 8.50                8.50                8.50
# 1                 0.10                0.15                0.10
# 2                 8.00                7.50                8.00
# 3                 1.00                0.05                2.40
# 4                 3.50                5.50                6.30
# 5                 1.00                0.00                0.00
# 6                 9.00                9.50                9.00
# 7                 6.50                8.00                8.00
# 8                 9.00                9.00                9.80
# 9                 5.20                6.50                5.00
# 10                5.00                5.30                7.50
# 11                6.50                5.50                7.50
# 12                8.50                8.50                8.75
# 13                8.75                8.70                8.70
# 14                7.50                6.50                8.50
# 15                7.50                8.70                8.50
# 16                1.25                1.50                2.50
# 17                6.50                7.85                8.50
# 18                7.50                7.30                7.75
# 19                5.50                4.00                3.00
# 20                3.25                3.00                3.00
# 21                5.50                6.00                7.25
# 22                4.50                4.50                7.50
# 23                4.00                5.50                4.50
# 24                6.50                7.00                7.50
# 25                0.20                0.00                0.00
# 26                0.00                0.25                0.05
# 27                2.50                4.50                4.25
# 28                3.50                2.00                2.50
# 29                8.00                9.00                8.50
# 30                7.50                6.50                7.50
# 31                4.00                5.50                5.00
# 32                1.20                2.00                3.00
# 33                1.75                2.00                3.80
# 34                5.50                6.00                5.50
# 35                8.50                9.50                8.00
# 36                2.00                1.00                1.50
# 37                3.50                3.00                2.00
# 38                8.33                8.50                9.00
# 39                0.10                0.20                0.00
# 40                0.00                0.00                0.00
# 41                0.05                0.00                0.00
# 42                0.10                0.10                0.00
# 43                0.02                0.00                0.00
# 44                7.50                8.50                9.00
# 45                5.50                7.00                7.50
# 46                8.50                9.30                9.50
# 47                5.00                7.00                5.75
# 48                4.50                7.00                4.50
# 49                7.50                7.50                7.30
# 50                2.00                1.50                1.00
# 51                3.00                3.50                4.30
# 52                3.50                4.00                4.50
# 53                7.50                6.50                7.00
# 54                2.00                2.50                0.15
# 55                 NaN                 NaN                 NaN
# 56                6.50                3.50                6.50
# 57                1.50                1.50                2.50
# 58                0.12                0.20                0.10
# 59                4.00                3.50                5.80
#
#     similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                 7.50                 8.50                 8.50
# 1                 0.10                 0.00                 2.00
# 2                 7.50                 8.50                 7.25
# 3                 0.38                 0.10                 0.50
# 4                 6.50                 6.50                 3.00
# 5                 0.05                 0.00                 0.00
# 6                 9.20                 8.50                 9.50
# 7                 7.50                 7.50                 4.50
# 8                 8.50                 9.00                 8.50
# 9                 7.50                 7.50                 5.50
# 10                8.00               700.00                 6.50
# 11                6.50                 7.50                 7.50
# 12                8.70                 8.50                 8.50
# 13                8.00                 8.50                 8.50
# 14                8.00                 6.50                 5.50
# 15                7.50                 8.50                 7.50
# 16                0.20                 1.50                 2.50
# 17                7.50                 7.50                 4.50
# 18                7.50                 7.50                 6.75
# 19                5.20                 5.70                 3.75
# 20                4.25                 5.75                 2.00
# 21                4.50                 4.75                 4.75
# 22                4.50                 4.50                 5.00
# 23                4.50                 4.50                 4.00
# 24                6.80                 7.50                 7.50
# 25                0.10                 0.10                 0.00
# 26                0.10                 0.10                 0.10
# 27                6.50                 4.50                 4.00
# 28                4.33                 3.50                 4.00
# 29                8.50                 8.70                 8.00
# 30                7.50                 6.00                 5.50
# 31                5.50                 5.12                 4.50
# 32                2.50                 1.50                 1.50
# 33                2.50                 4.00                 1.20
# 34                5.00                 6.25                 6.25
# 35                9.00                 9.50                 9.00
# 36                0.10                 0.20                 1.50
# 37                2.00                 1.50                 3.50
# 38                8.50                 8.50                 7.80
# 39                1.20                 0.10                 0.00
# 40                0.00                 0.00                 0.10
# 41                0.00                 0.00                 0.00
# 42                0.00                 0.10                 0.00
# 43                0.10                 0.20                 0.20
# 44                8.50                 8.50                 8.75
# 45                6.50                 7.40                 6.70
# 46                8.75                 8.70                 8.50
# 47                7.00                 7.50                 7.50
# 48                4.50                 4.00                 4.50
# 49                8.00                 7.50                 7.50
# 50                1.00                 2.50                 1.50
# 51                5.50                 6.30                 3.00
# 52                4.50                 4.50                 0.30
# 53                7.50                 7.75                 7.50
# 54                1.50                 3.00                 2.50
# 55                 NaN                  NaN                  NaN
# 56                7.50                 7.50                 5.50
# 57                2.00                 1.80                 2.50
# 58                1.50                 0.00                 0.20
# 59                2.50                 5.50                 3.00
#
#     similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                  7.50                 7.50                 8.50
# 1                  1.50                 0.00                 1.00
# 2                  8.50                 7.50                 7.50
# 3                  0.10                 1.00                 1.00
# 4                  6.75                 6.50                 5.00
# 5                  0.10                 0.05                 0.20
# 6                  9.50                 9.20                 9.25
# 7                  6.75                 7.00                 6.80
# 8                  8.50                 8.75                 8.50
# 9                  5.00                 8.00                 7.50
# 10                 6.00                 7.50                 7.50
# 11                 7.40                 8.50                 7.25
# 12                 9.00                 8.75                 8.50
# 13                 9.50                 9.00                 8.00
# 14                 6.50                 7.50                 8.25
# 15                 7.50                 7.50                 8.50
# 16                 1.20                 3.50                 2.50
# 17                 7.20                 8.00                 8.75
# 18                 7.50                 7.50                 7.50
# 19                 4.50                 5.00                 5.20
# 20                 2.50                 3.50                 4.25
# 21                 2.50                 4.30                 4.50
# 22                 7.50                 5.25                 5.50
# 23                 4.50                 4.50                 6.50
# 24                 8.30                 7.50                 7.20
# 25                 0.01                 1.00                 0.00
# 26                 0.20                 1.00                 0.20
# 27                 5.00                 5.00                 4.00
# 28                 3.75                 3.50                 4.00
# 29                 7.50                 7.50                 8.00
# 30                 6.75                 6.00                 7.50
# 31                 5.75                 5.50                 5.50
# 32                 1.00                 2.00                 2.50
# 33                 3.00                 1.20                 2.00
# 34                 5.75                 7.00                 6.50
# 35                 8.25                 8.33                 9.00
# 36                 0.20                 2.00                 0.10
# 37                 3.00                 2.50                 3.00
# 38                 8.50                 8.00                 8.50
# 39                 0.00                 1.50                 1.50
# 40                 0.01                 0.00                 0.05
# 41                 0.00                 0.00                 0.10
# 42                 0.00                 0.10                 0.00
# 43                 0.10                 0.00                 0.00
# 44                 8.50                 8.75                 8.50
# 45                 5.00                 6.50                 6.00
# 46                 8.50                 9.50                 8.80
# 47                 6.75                 3.50                 7.50
# 48                 4.50                 4.25                 4.00
# 49                 7.50                 7.85                 7.50
# 50                 1.50                 2.00                 1.75
# 51                 3.50                 4.50                 4.50
# 52                 3.50                 4.20                 4.00
# 53                 7.50                 8.50                 6.50
# 54                 3.50                 3.50                 1.75
# 55                  NaN                  NaN                  NaN
# 56                 7.00                 4.50                 4.50
# 57                 2.50                 2.50                 1.20
# 58                 0.10                 0.10                 0.20
# 59                 3.50                 4.00                 4.50
#
#     similarity_score_15
# 0                  8.75
# 1                  0.10
# 2                  7.80
# 3                  0.50
# 4                  6.50
# 5                  0.00
# 6                  9.80
# 7                  7.50
# 8                  9.00
# 9                  7.80
# 10                 7.67
# 11                 7.00
# 12                 9.00
# 13                 9.00
# 14                 7.75
# 15                 7.50
# 16                 1.20
# 17                 8.00
# 18                 7.50
# 19                 4.25
# 20                 5.00
# 21                 6.50
# 22                 6.75
# 23                 6.50
# 24                 7.50
# 25                 0.00
# 26                 2.00
# 27                 5.00
# 28                 3.50
# 29                 6.50
# 30                 6.50
# 31                 5.50
# 32                 1.00
# 33                 2.50
# 34                 6.00
# 35                 8.00
# 36                 1.00
# 37                 1.50
# 38                 8.50
# 39                 0.00
# 40                 0.10
# 41                 0.00
# 42                 0.10
# 43                 0.00
# 44                 8.70
# 45                 3.50
# 46                 8.70
# 47                 6.20
# 48                 4.50
# 49                 7.00
# 50                 2.50
# 51                 4.50
# 52                 3.50
# 53                 6.50
# 54                  NaN
# 55                  NaN
# 56                 7.00
# 57                 1.20
# 58                 0.00
# 59                 4.50

# %%
# Count null values
count_null_values = missing_df.isnull().sum()

# Show results
print("Null value counts per column:", count_null_values)
# Out:
# Null value counts per column: word1                  0
# word2                  0
# similarity_score_1     0
# similarity_score_2     1
# similarity_score_3     1
# similarity_score_4     1
# similarity_score_5     1
# similarity_score_6     1
# similarity_score_7     1
# similarity_score_8     1
# similarity_score_9     1
# similarity_score_10    1
# similarity_score_11    1
# similarity_score_12    1
# similarity_score_13    1
# similarity_score_14    1
# similarity_score_15    2
# dtype: int64

# %%
# Check for rows with at least one null value
rows_with_null = missing_df[missing_df.isnull().any(axis=1)]

# Show results
rows_with_null
# Out:
#          word1   word2  similarity_score_1  similarity_score_2  \
# 54  accomplish  become                 2.0                3.75
# 55       acish  become                 2.5                 NaN
#
#     similarity_score_3  similarity_score_4  similarity_score_5  \
# 54                 2.7                 2.0                 3.0
# 55                 NaN                 NaN                 NaN
#
#     similarity_score_6  similarity_score_7  similarity_score_8  \
# 54                 2.0                 2.5                0.15
# 55                 NaN                 NaN                 NaN
#
#     similarity_score_9  similarity_score_10  similarity_score_11  \
# 54                 1.5                  3.0                  2.5
# 55                 NaN                  NaN                  NaN
#
#     similarity_score_12  similarity_score_13  similarity_score_14  \
# 54                  3.5                  3.5                 1.75
# 55                  NaN                  NaN                  NaN
#
#     similarity_score_15
# 54                  NaN
# 55                  NaN

# %% [markdown]
# ### **4. Add Missing Word Pairs for Missing Word Pairs**

# %%
# Extract missing word pairs
missing_missing_word_pair_list = list(zip(rows_with_null['word1'], rows_with_null['word2']))

# Show results
missing_missing_word_pair_list
# Out:
# [('accomplish', 'become'), ('acish', 'become')]

# %%
# Drop unknown word pair
missing_missing_word_pair_list = [
    pair for pair in missing_missing_word_pair_list 
    if pair != ('acish', 'become')
]

# Show results
missing_missing_word_pair_list
# Out:
# [('accomplish', 'become')]

# %%
# Set sample size
missing_missing_sample_size = 15

# Delay between individual API calls
missing_missing_delay = 1.0

# %%
# Define number of sublists
missing_missing_n_sublists = len(missing_missing_word_pair_list)

# Split list
missing_missing_chunks = split_into_n_lists(missing_missing_word_pair_list, missing_missing_n_sublists)

# Count number of lists
print(len(missing_missing_chunks))
# Out:
# 1

# %%
# Print prompts for each chunk
print_prompts_single(missing_missing_chunks, missing_missing_sample_size, prompt)
# Out:
# Rate the semantic similarity of the word pair: [('accomplish'), ('become')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('accomplish'), ('become')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('accomplish'), ('become')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('accomplish'), ('become')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('accomplish'), ('become')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('accomplish'), ('become')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('accomplish'), ('become')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('accomplish'), ('become')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('accomplish'), ('become')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('accomplish'), ('become')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('accomplish'), ('become')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('accomplish'), ('become')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('accomplish'), ('become')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('accomplish'), ('become')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('accomplish'), ('become')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.

# %%
# Get results from API
missing_missing_response = get_responses_single(prompt, missing_missing_chunks, model, missing_missing_sample_size, missing_missing_delay)
# Out:
# Processing: 100%|██████████| 15/15 [00:43<00:00,  2.88s/chunk]
# Total time taken: 43.19 seconds

# %%
# Process data into dictionary
missing_missing_data_dict = process_responses(missing_missing_response)

# Show results
missing_missing_data_dict
# Out:
# {('accomplish', 'become'): [2.5,
#   2.5,
#   2.5,
#   2.5,
#   2.5,
#   4.0,
#   2.5,
#   2.5,
#   2.5,
#   3.0,
#   2.0,
#   4.5,
#   2.5,
#   2.5,
#   3.0]}

# %%
# Convert dict to Pandas DataFrame
missing_missing_df = create_dataframe(missing_missing_data_dict)

# Show results
missing_missing_df
# Out:
#         word1   word2  similarity_score_1  similarity_score_2  \
# 0  accomplish  become                 2.5                 2.5
#
#    similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                 2.5                 2.5                 2.5
#
#    similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                 4.0                 2.5                 2.5
#
#    similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                 2.5                  3.0                  2.0
#
#    similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                  4.5                  2.5                  2.5
#
#    similarity_score_15
# 0                  3.0

# %%
# Count null values
count_null_values = missing_missing_df.isnull().sum()

# Show results
print("Null value counts per column:", count_null_values)
# Out:
# Null value counts per column: word1                  0
# word2                  0
# similarity_score_1     0
# similarity_score_2     0
# similarity_score_3     0
# similarity_score_4     0
# similarity_score_5     0
# similarity_score_6     0
# similarity_score_7     0
# similarity_score_8     0
# similarity_score_9     0
# similarity_score_10    0
# similarity_score_11    0
# similarity_score_12    0
# similarity_score_13    0
# similarity_score_14    0
# similarity_score_15    0
# dtype: int64

# %%
# Check for rows with at least one null value
rows_with_null = missing_missing_df[missing_missing_df.isnull().any(axis=1)]

# Show results
rows_with_null
# Out:
# Empty DataFrame
# Columns: [word1, word2, similarity_score_1, similarity_score_2, similarity_score_3, similarity_score_4, similarity_score_5, similarity_score_6, similarity_score_7, similarity_score_8, similarity_score_9, similarity_score_10, similarity_score_11, similarity_score_12, similarity_score_13, similarity_score_14, similarity_score_15]
# Index: []

# %% [markdown]
# ### **4. Add Missing Word Pairs raw_predicted**

# %%
# Concatenate raw_predicted with missing_df
raw_predicted_complete = pd.concat([raw_predicted, missing_df], ignore_index=True)

print(f"Original raw_predicted: {len(raw_predicted)} rows")
print(f"Missing pairs: {len(missing_df)} rows")
print(f"Complete raw_predicted: {len(raw_predicted_complete)} rows")

# Sort by word1 and word2 for better organization
raw_predicted_complete = raw_predicted_complete.sort_values(['word1', 'word2']).reset_index(drop=True)
# Out:
# Original raw_predicted: 940 rows
# Missing pairs: 60 rows
# Complete raw_predicted: 1000 rows

# %%
# Create a mapping of word pairs to their order in raw_actual
raw_actual['order'] = range(len(raw_actual))
order_map = dict(zip(zip(raw_actual['word1'], raw_actual['word2']), raw_actual['order']))

# Map the order to raw_predicted_complete
raw_predicted_complete['order'] = raw_predicted_complete.apply(
    lambda row: order_map.get((row['word1'], row['word2']), float('inf')), 
    axis=1
)

# Sort by the order from raw_actual
raw_predicted_complete = raw_predicted_complete.sort_values('order').drop('order', axis=1).reset_index(drop=True)

# Show results
raw_predicted_complete
# Out:
#       word1        word2  similarity_score_1  similarity_score_2  \
# 0       old          new                0.00                0.00
# 1     smart  intelligent                9.00                8.75
# 2      hard    difficult                9.00                9.50
# 3     happy     cheerful                8.75                9.00
# 4      hard         easy                0.00                0.00
# ..      ...          ...                 ...                 ...
# 995    send       attend                1.00                0.15
# 996  gather       attend                5.50                6.00
# 997  absorb     withdraw                2.50                0.20
# 998  attend       arrive                6.50                4.25
# 999   acish       become                2.50                 NaN
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                  0.75                2.00                0.00
# 1                  9.50                9.50                9.50
# 2                  9.75                8.75                9.50
# 3                  9.20                8.00                9.00
# 4                  0.00                0.05                0.00
# ..                  ...                 ...                 ...
# 995                1.30                0.10                0.75
# 996                7.50                5.00                5.00
# 997                0.10                0.20                0.05
# 998                6.50                4.50                5.50
# 999                 NaN                 NaN                 NaN
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                   0.0                0.10                0.05
# 1                   9.5                9.20                8.50
# 2                   9.0                9.50                9.75
# 3                   9.5                9.30                9.80
# 4                   0.0                0.00                0.00
# ..                  ...                 ...                 ...
# 995                 1.5                2.50                0.20
# 996                 4.5                4.50                7.50
# 997                 0.0                1.50                1.50
# 998                 6.0                5.67                6.00
# 999                 NaN                 NaN                 NaN
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                  1.00                 0.00                  0.0
# 1                  9.50                 9.75                  9.5
# 2                  8.75                 9.20                  9.8
# 3                  9.00                 8.75                  8.5
# 4                  0.10                 0.00                  0.1
# ..                  ...                  ...                  ...
# 995                1.50                 1.00                  2.0
# 996                7.00                 6.25                  5.5
# 997                0.10                 0.10                  0.1
# 998                5.00                 5.40                  6.3
# 999                 NaN                  NaN                  NaN
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                   0.00                 0.10                 0.00
# 1                   9.00                 8.50                 9.00
# 2                   9.50                 9.00                 9.50
# 3                   9.45                 8.50                 9.00
# 4                   0.00                 0.00                 0.00
# ..                   ...                  ...                  ...
# 995                 0.05                 0.05                 0.00
# 996                 7.20                 7.50                 6.50
# 997                 1.00                 0.00                 0.50
# 998                 6.00                 3.50                 5.25
# 999                  NaN                  NaN                  NaN
#
#      similarity_score_15
# 0                   0.00
# 1                   9.00
# 2                   9.50
# 3                   8.50
# 4                   0.00
# ..                   ...
# 995                 2.50
# 996                 6.50
# 997                 1.00
# 998                 6.25
# 999                  NaN
#
# [1000 rows x 17 columns]

# %%
# Drop unknown word pair
raw_predicted_complete = raw_predicted_complete[:-1]

# Show results
raw_predicted_complete
# Out:
#       word1        word2  similarity_score_1  similarity_score_2  \
# 0       old          new                0.00                0.00
# 1     smart  intelligent                9.00                8.75
# 2      hard    difficult                9.00                9.50
# 3     happy     cheerful                8.75                9.00
# 4      hard         easy                0.00                0.00
# ..      ...          ...                 ...                 ...
# 994    join      acquire                4.00                2.75
# 995    send       attend                1.00                0.15
# 996  gather       attend                5.50                6.00
# 997  absorb     withdraw                2.50                0.20
# 998  attend       arrive                6.50                4.25
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                  0.75                2.00                0.00
# 1                  9.50                9.50                9.50
# 2                  9.75                8.75                9.50
# 3                  9.20                8.00                9.00
# 4                  0.00                0.05                0.00
# ..                  ...                 ...                 ...
# 994                4.50                6.50                4.00
# 995                1.30                0.10                0.75
# 996                7.50                5.00                5.00
# 997                0.10                0.20                0.05
# 998                6.50                4.50                5.50
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                   0.0                0.10                0.05
# 1                   9.5                9.20                8.50
# 2                   9.0                9.50                9.75
# 3                   9.5                9.30                9.80
# 4                   0.0                0.00                0.00
# ..                  ...                 ...                 ...
# 994                 4.5                6.25                3.50
# 995                 1.5                2.50                0.20
# 996                 4.5                4.50                7.50
# 997                 0.0                1.50                1.50
# 998                 6.0                5.67                6.00
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                  1.00                 0.00                  0.0
# 1                  9.50                 9.75                  9.5
# 2                  8.75                 9.20                  9.8
# 3                  9.00                 8.75                  8.5
# 4                  0.10                 0.00                  0.1
# ..                  ...                  ...                  ...
# 994                3.50                 4.00                  6.5
# 995                1.50                 1.00                  2.0
# 996                7.00                 6.25                  5.5
# 997                0.10                 0.10                  0.1
# 998                5.00                 5.40                  6.3
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                   0.00                 0.10                 0.00
# 1                   9.00                 8.50                 9.00
# 2                   9.50                 9.00                 9.50
# 3                   9.45                 8.50                 9.00
# 4                   0.00                 0.00                 0.00
# ..                   ...                  ...                  ...
# 994                 4.00                 2.50                 2.50
# 995                 0.05                 0.05                 0.00
# 996                 7.20                 7.50                 6.50
# 997                 1.00                 0.00                 0.50
# 998                 6.00                 3.50                 5.25
#
#      similarity_score_15
# 0                   0.00
# 1                   9.00
# 2                   9.50
# 3                   8.50
# 4                   0.00
# ..                   ...
# 994                 7.50
# 995                 2.50
# 996                 6.50
# 997                 1.00
# 998                 6.25
#
# [999 rows x 17 columns]

# %% [markdown]
# ### **5. Export Data**

# %%
# Define file_path
file_path = '../../../data/gpt-oss-20b/processed/en/f9-post.csv'

# Ensure directory exists
os.makedirs(os.path.dirname(file_path), exist_ok=True)

# Check if file already exists
if not os.path.exists(file_path):
    raw_predicted_complete.to_csv(file_path, index=False)
    print("File saved successfully.")
else:
    print("File already exists. DataFrame was not saved to prevent overwriting.")
# Out:
# File saved successfully.
