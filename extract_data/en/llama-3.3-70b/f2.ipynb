# %% [markdown]
# ### **0. Set-up**

# %%
# Import libraries and utils
# %run '../../utils.ipynb'

# %%
# Get api key
load_dotenv()
OPENROUTER_API_KEY = os.getenv('OPENROUTER_API_KEY')

# Set client
client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=OPENROUTER_API_KEY,
)

# %%
# Load dataframe
en_simlex = pd.read_csv("../../../data/dataset/cleaned-en-simlex-999.csv")

# Remove first word pair
en_simlex = en_simlex.iloc[1:]

# Select subset
# en_simlex = en_simlex.head(100)

# Convert to tuple
tuples_list = list(zip(en_simlex['word1'], en_simlex['word2']))

# %%
# Show results
tuples_list
# Out:
# [('smart', 'intelligent'),
#  ('hard', 'difficult'),
#  ('happy', 'cheerful'),
#  ('hard', 'easy'),
#  ('fast', 'rapid'),
#  ('happy', 'glad'),
#  ('short', 'long'),
#  ('stupid', 'dumb'),
#  ('weird', 'strange'),
#  ('wide', 'narrow'),
#  ('bad', 'awful'),
#  ('easy', 'difficult'),
#  ('bad', 'terrible'),
#  ('hard', 'simple'),
#  ('smart', 'dumb'),
#  ('insane', 'crazy'),
#  ('happy', 'mad'),
#  ('large', 'huge'),
#  ('hard', 'tough'),
#  ('new', 'fresh'),
#  ('sharp', 'dull'),
#  ('quick', 'rapid'),
#  ('dumb', 'foolish'),
#  ('wonderful', 'terrific'),
#  ('strange', 'odd'),
#  ('happy', 'angry'),
#  ('narrow', 'broad'),
#  ('simple', 'easy'),
#  ('old', 'fresh'),
#  ('apparent', 'obvious'),
#  ('inexpensive', 'cheap'),
#  ('nice', 'generous'),
#  ('weird', 'normal'),
#  ('weird', 'odd'),
#  ('bad', 'immoral'),
#  ('sad', 'funny'),
#  ('wonderful', 'great'),
#  ('guilty', 'ashamed'),
#  ('beautiful', 'wonderful'),
#  ('confident', 'sure'),
#  ('dumb', 'dense'),
#  ('large', 'big'),
#  ('nice', 'cruel'),
#  ('impatient', 'anxious'),
#  ('big', 'broad'),
#  ('strong', 'proud'),
#  ('unnecessary', 'necessary'),
#  ('restless', 'young'),
#  ('dumb', 'intelligent'),
#  ('bad', 'great'),
#  ('difficult', 'simple'),
#  ('necessary', 'important'),
#  ('bad', 'terrific'),
#  ('mad', 'glad'),
#  ('honest', 'guilty'),
#  ('easy', 'tough'),
#  ('easy', 'flexible'),
#  ('certain', 'sure'),
#  ('essential', 'necessary'),
#  ('different', 'normal'),
#  ('sly', 'clever'),
#  ('crucial', 'important'),
#  ('harsh', 'cruel'),
#  ('childish', 'foolish'),
#  ('scarce', 'rare'),
#  ('friendly', 'generous'),
#  ('fragile', 'frigid'),
#  ('long', 'narrow'),
#  ('big', 'heavy'),
#  ('rough', 'frigid'),
#  ('bizarre', 'strange'),
#  ('illegal', 'immoral'),
#  ('bad', 'guilty'),
#  ('modern', 'ancient'),
#  ('new', 'ancient'),
#  ('dull', 'funny'),
#  ('happy', 'young'),
#  ('easy', 'big'),
#  ('great', 'awful'),
#  ('tiny', 'huge'),
#  ('polite', 'proper'),
#  ('modest', 'ashamed'),
#  ('exotic', 'rare'),
#  ('dumb', 'clever'),
#  ('delightful', 'wonderful'),
#  ('noticeable', 'obvious'),
#  ('afraid', 'anxious'),
#  ('formal', 'proper'),
#  ('dreary', 'dull'),
#  ('delightful', 'cheerful'),
#  ('unhappy', 'mad'),
#  ('sad', 'terrible'),
#  ('sick', 'crazy'),
#  ('violent', 'angry'),
#  ('laden', 'heavy'),
#  ('dirty', 'cheap'),
#  ('elastic', 'flexible'),
#  ('hard', 'dense'),
#  ('recent', 'new'),
#  ('bold', 'proud'),
#  ('sly', 'strange'),
#  ('strange', 'sly'),
#  ('dumb', 'rare'),
#  ('sly', 'tough'),
#  ('terrific', 'mad'),
#  ('modest', 'flexible'),
#  ('fresh', 'wide'),
#  ('huge', 'dumb'),
#  ('large', 'flexible'),
#  ('dirty', 'narrow'),
#  ('wife', 'husband'),
#  ('book', 'text'),
#  ('groom', 'bride'),
#  ('night', 'day'),
#  ('south', 'north'),
#  ('plane', 'airport'),
#  ('uncle', 'aunt'),
#  ('horse', 'mare'),
#  ('bottom', 'top'),
#  ('friend', 'buddy'),
#  ('student', 'pupil'),
#  ('world', 'globe'),
#  ('leg', 'arm'),
#  ('plane', 'jet'),
#  ('woman', 'man'),
#  ('horse', 'colt'),
#  ('actress', 'actor'),
#  ('teacher', 'instructor'),
#  ('movie', 'film'),
#  ('bird', 'hawk'),
#  ('word', 'dictionary'),
#  ('money', 'salary'),
#  ('dog', 'cat'),
#  ('area', 'region'),
#  ('navy', 'army'),
#  ('book', 'literature'),
#  ('clothes', 'closet'),
#  ('sunset', 'sunrise'),
#  ('child', 'adult'),
#  ('cow', 'cattle'),
#  ('book', 'story'),
#  ('winter', 'summer'),
#  ('taxi', 'cab'),
#  ('tree', 'maple'),
#  ('bed', 'bedroom'),
#  ('roof', 'ceiling'),
#  ('disease', 'infection'),
#  ('arm', 'shoulder'),
#  ('sheep', 'lamb'),
#  ('lady', 'gentleman'),
#  ('boat', 'anchor'),
#  ('priest', 'monk'),
#  ('toe', 'finger'),
#  ('river', 'stream'),
#  ('anger', 'fury'),
#  ('date', 'calendar'),
#  ('sea', 'ocean'),
#  ('second', 'minute'),
#  ('hand', 'thumb'),
#  ('wood', 'log'),
#  ('mud', 'dirt'),
#  ('hallway', 'corridor'),
#  ('way', 'manner'),
#  ('mouse', 'cat'),
#  ('cop', 'sheriff'),
#  ('death', 'burial'),
#  ('music', 'melody'),
#  ('beer', 'alcohol'),
#  ('mouth', 'lip'),
#  ('storm', 'hurricane'),
#  ('tax', 'income'),
#  ('flower', 'violet'),
#  ('paper', 'cardboard'),
#  ('floor', 'ceiling'),
#  ('beach', 'seashore'),
#  ('rod', 'curtain'),
#  ('hound', 'fox'),
#  ('street', 'alley'),
#  ('boat', 'deck'),
#  ('car', 'horn'),
#  ('friend', 'guest'),
#  ('employer', 'employee'),
#  ('hand', 'wrist'),
#  ('ball', 'cannon'),
#  ('alcohol', 'brandy'),
#  ('victory', 'triumph'),
#  ('telephone', 'booth'),
#  ('door', 'doorway'),
#  ('motel', 'inn'),
#  ('clothes', 'cloth'),
#  ('steak', 'meat'),
#  ('nail', 'thumb'),
#  ('band', 'orchestra'),
#  ('book', 'bible'),
#  ('business', 'industry'),
#  ('winter', 'season'),
#  ('decade', 'century'),
#  ('alcohol', 'gin'),
#  ('hat', 'coat'),
#  ('window', 'door'),
#  ('arm', 'wrist'),
#  ('house', 'apartment'),
#  ('glass', 'crystal'),
#  ('wine', 'brandy'),
#  ('creator', 'maker'),
#  ('dinner', 'breakfast'),
#  ('arm', 'muscle'),
#  ('bubble', 'suds'),
#  ('bread', 'flour'),
#  ('death', 'tragedy'),
#  ('absence', 'presence'),
#  ('gun', 'cannon'),
#  ('grass', 'blade'),
#  ('ball', 'basket'),
#  ('hose', 'garden'),
#  ('boy', 'kid'),
#  ('church', 'choir'),
#  ('clothes', 'drawer'),
#  ('tower', 'bell'),
#  ('father', 'parent'),
#  ('school', 'grade'),
#  ('parent', 'adult'),
#  ('bar', 'jail'),
#  ('car', 'highway'),
#  ('dictionary', 'definition'),
#  ('door', 'cellar'),
#  ('army', 'legion'),
#  ('metal', 'aluminum'),
#  ('chair', 'bench'),
#  ('cloud', 'fog'),
#  ('boy', 'son'),
#  ('water', 'ice'),
#  ('bed', 'blanket'),
#  ('attorney', 'lawyer'),
#  ('area', 'zone'),
#  ('business', 'company'),
#  ('clothes', 'fabric'),
#  ('sweater', 'jacket'),
#  ('money', 'capital'),
#  ('hand', 'foot'),
#  ('alcohol', 'cocktail'),
#  ('yard', 'inch'),
#  ('molecule', 'atom'),
#  ('lens', 'camera'),
#  ('meal', 'dinner'),
#  ('eye', 'tear'),
#  ('god', 'devil'),
#  ('loop', 'belt'),
#  ('rat', 'mouse'),
#  ('motor', 'engine'),
#  ('car', 'cab'),
#  ('cat', 'lion'),
#  ('size', 'magnitude'),
#  ('reality', 'fantasy'),
#  ('door', 'gate'),
#  ('cat', 'pet'),
#  ('tin', 'aluminum'),
#  ('bone', 'jaw'),
#  ('cereal', 'wheat'),
#  ('house', 'key'),
#  ('blood', 'flesh'),
#  ('door', 'corridor'),
#  ('god', 'spirit'),
#  ('capability', 'competence'),
#  ('abundance', 'plenty'),
#  ('sofa', 'chair'),
#  ('wall', 'brick'),
#  ('horn', 'drum'),
#  ('organ', 'liver'),
#  ('strength', 'might'),
#  ('phrase', 'word'),
#  ('band', 'parade'),
#  ('stomach', 'waist'),
#  ('cloud', 'storm'),
#  ('joy', 'pride'),
#  ('noise', 'rattle'),
#  ('rain', 'mist'),
#  ('beer', 'beverage'),
#  ('man', 'uncle'),
#  ('apple', 'juice'),
#  ('intelligence', 'logic'),
#  ('communication', 'language'),
#  ('mink', 'fur'),
#  ('mob', 'crowd'),
#  ('shore', 'coast'),
#  ('wire', 'cord'),
#  ('bird', 'turkey'),
#  ('bed', 'crib'),
#  ('competence', 'ability'),
#  ('cloud', 'haze'),
#  ('supper', 'meal'),
#  ('bar', 'cage'),
#  ('water', 'salt'),
#  ('sense', 'intuition'),
#  ('situation', 'condition'),
#  ('crime', 'theft'),
#  ('style', 'fashion'),
#  ('boundary', 'border'),
#  ('arm', 'body'),
#  ('boat', 'car'),
#  ('sandwich', 'lunch'),
#  ('bride', 'princess'),
#  ('heroine', 'hero'),
#  ('car', 'gauge'),
#  ('insect', 'bee'),
#  ('crib', 'cradle'),
#  ('animal', 'person'),
#  ('marijuana', 'herb'),
#  ('bed', 'hospital'),
#  ('cheek', 'tongue'),
#  ('disc', 'computer'),
#  ('curve', 'angle'),
#  ('grass', 'moss'),
#  ('school', 'law'),
#  ('foot', 'head'),
#  ('mother', 'guardian'),
#  ('orthodontist', 'dentist'),
#  ('alcohol', 'whiskey'),
#  ('mouth', 'tooth'),
#  ('breakfast', 'bacon'),
#  ('bathroom', 'bedroom'),
#  ('plate', 'bowl'),
#  ('meat', 'bacon'),
#  ('air', 'helium'),
#  ('worker', 'employer'),
#  ('body', 'chest'),
#  ('son', 'father'),
#  ('heart', 'surgery'),
#  ('woman', 'secretary'),
#  ('man', 'father'),
#  ('beach', 'island'),
#  ('story', 'topic'),
#  ('game', 'fun'),
#  ('weekend', 'week'),
#  ('couple', 'pair'),
#  ('woman', 'wife'),
#  ('sheep', 'cattle'),
#  ('purse', 'bag'),
#  ('ceiling', 'cathedral'),
#  ('bean', 'coffee'),
#  ('wood', 'paper'),
#  ('top', 'side'),
#  ('crime', 'fraud'),
#  ('pain', 'harm'),
#  ('lover', 'companion'),
#  ('evening', 'dusk'),
#  ('father', 'daughter'),
#  ('wine', 'liquor'),
#  ('cow', 'goat'),
#  ('belief', 'opinion'),
#  ('reality', 'illusion'),
#  ('pact', 'agreement'),
#  ('wealth', 'poverty'),
#  ('accident', 'emergency'),
#  ('battle', 'conquest'),
#  ('friend', 'teacher'),
#  ('illness', 'infection'),
#  ('game', 'trick'),
#  ('brother', 'son'),
#  ('aunt', 'nephew'),
#  ('worker', 'mechanic'),
#  ('doctor', 'orthodontist'),
#  ('oak', 'maple'),
#  ('bee', 'queen'),
#  ('car', 'bicycle'),
#  ('goal', 'quest'),
#  ('august', 'month'),
#  ('army', 'squad'),
#  ('cloud', 'weather'),
#  ('physician', 'doctor'),
#  ('canyon', 'valley'),
#  ('river', 'valley'),
#  ('sun', 'sky'),
#  ('target', 'arrow'),
#  ('chocolate', 'pie'),
#  ('circumstance', 'situation'),
#  ('opinion', 'choice'),
#  ('rhythm', 'melody'),
#  ('gut', 'nerve'),
#  ('day', 'dawn'),
#  ('cattle', 'beef'),
#  ('doctor', 'professor'),
#  ('arm', 'vein'),
#  ('room', 'bath'),
#  ('corporation', 'business'),
#  ('fun', 'football'),
#  ('hill', 'cliff'),
#  ('bone', 'ankle'),
#  ('apple', 'candy'),
#  ('helper', 'maid'),
#  ('leader', 'manager'),
#  ('lemon', 'tea'),
#  ('bee', 'ant'),
#  ('basketball', 'baseball'),
#  ('rice', 'bean'),
#  ('bed', 'furniture'),
#  ('emotion', 'passion'),
#  ('anarchy', 'chaos'),
#  ('crime', 'violation'),
#  ('machine', 'engine'),
#  ('beach', 'sea'),
#  ('alley', 'bowl'),
#  ('jar', 'bottle'),
#  ('strength', 'capability'),
#  ('seed', 'mustard'),
#  ('guitar', 'drum'),
#  ('opinion', 'idea'),
#  ('north', 'west'),
#  ('diet', 'salad'),
#  ('mother', 'wife'),
#  ('dad', 'mother'),
#  ('captain', 'sailor'),
#  ('meter', 'yard'),
#  ('beer', 'champagne'),
#  ('motor', 'boat'),
#  ('card', 'bridge'),
#  ('science', 'psychology'),
#  ('sinner', 'saint'),
#  ('destruction', 'construction'),
#  ('crowd', 'bunch'),
#  ('beach', 'reef'),
#  ('man', 'child'),
#  ('bread', 'cheese'),
#  ('champion', 'winner'),
#  ('celebration', 'ceremony'),
#  ('menu', 'order'),
#  ('king', 'princess'),
#  ('wealth', 'prestige'),
#  ('endurance', 'strength'),
#  ('danger', 'threat'),
#  ('god', 'priest'),
#  ('men', 'fraternity'),
#  ('buddy', 'companion'),
#  ('teacher', 'helper'),
#  ('body', 'stomach'),
#  ('tongue', 'throat'),
#  ('house', 'carpet'),
#  ('intelligence', 'skill'),
#  ('journey', 'conquest'),
#  ('god', 'prey'),
#  ('brother', 'soul'),
#  ('adversary', 'opponent'),
#  ('death', 'catastrophe'),
#  ('monster', 'demon'),
#  ('day', 'morning'),
#  ('man', 'victor'),
#  ('friend', 'guy'),
#  ('song', 'story'),
#  ('ray', 'sunshine'),
#  ('guy', 'stud'),
#  ('chicken', 'rice'),
#  ('box', 'elevator'),
#  ('butter', 'potato'),
#  ('apartment', 'furniture'),
#  ('lake', 'swamp'),
#  ('salad', 'vinegar'),
#  ('flower', 'bulb'),
#  ('cloud', 'mist'),
#  ('driver', 'pilot'),
#  ('sugar', 'honey'),
#  ('body', 'shoulder'),
#  ('idea', 'image'),
#  ('father', 'brother'),
#  ('moon', 'planet'),
#  ('ball', 'costume'),
#  ('rail', 'fence'),
#  ('room', 'bed'),
#  ('flower', 'bush'),
#  ('bone', 'knee'),
#  ('arm', 'knee'),
#  ('bottom', 'side'),
#  ('vessel', 'vein'),
#  ('cat', 'rabbit'),
#  ('meat', 'sandwich'),
#  ('belief', 'concept'),
#  ('intelligence', 'insight'),
#  ('attention', 'interest'),
#  ('attitude', 'confidence'),
#  ('right', 'justice'),
#  ('argument', 'agreement'),
#  ('depth', 'magnitude'),
#  ('medium', 'news'),
#  ('winner', 'candidate'),
#  ('birthday', 'date'),
#  ('fee', 'payment'),
#  ('bible', 'hymn'),
#  ('exit', 'doorway'),
#  ('man', 'sentry'),
#  ('aisle', 'hall'),
#  ('whiskey', 'gin'),
#  ('blood', 'marrow'),
#  ('oil', 'mink'),
#  ('floor', 'deck'),
#  ('roof', 'floor'),
#  ('door', 'floor'),
#  ('shoulder', 'head'),
#  ('wagon', 'carriage'),
#  ('car', 'carriage'),
#  ('elbow', 'ankle'),
#  ('wealth', 'fame'),
#  ('sorrow', 'shame'),
#  ('administration', 'management'),
#  ('communication', 'conversation'),
#  ('pollution', 'atmosphere'),
#  ('anatomy', 'biology'),
#  ('college', 'profession'),
#  ('book', 'topic'),
#  ('formula', 'equation'),
#  ('book', 'information'),
#  ('boy', 'partner'),
#  ('sky', 'universe'),
#  ('population', 'people'),
#  ('college', 'class'),
#  ('chief', 'mayor'),
#  ('rabbi', 'minister'),
#  ('meter', 'inch'),
#  ('polyester', 'cotton'),
#  ('lawyer', 'banker'),
#  ('violin', 'instrument'),
#  ('camp', 'cabin'),
#  ('pot', 'appliance'),
#  ('linen', 'fabric'),
#  ('whiskey', 'champagne'),
#  ('girl', 'child'),
#  ('cottage', 'cabin'),
#  ('bird', 'hen'),
#  ('racket', 'noise'),
#  ('sunset', 'evening'),
#  ('drizzle', 'rain'),
#  ('adult', 'baby'),
#  ('charcoal', 'coal'),
#  ('body', 'spine'),
#  ('head', 'nail'),
#  ('log', 'timber'),
#  ('spoon', 'cup'),
#  ('body', 'nerve'),
#  ('man', 'husband'),
#  ('bone', 'neck'),
#  ('frustration', 'anger'),
#  ('river', 'sea'),
#  ('task', 'job'),
#  ('club', 'society'),
#  ('reflection', 'image'),
#  ('prince', 'king'),
#  ('snow', 'weather'),
#  ('people', 'party'),
#  ('boy', 'brother'),
#  ('root', 'grass'),
#  ('brow', 'eye'),
#  ('money', 'pearl'),
#  ('money', 'diamond'),
#  ('vehicle', 'bus'),
#  ('cab', 'bus'),
#  ('house', 'barn'),
#  ('finger', 'palm'),
#  ('car', 'bridge'),
#  ('effort', 'difficulty'),
#  ('fact', 'insight'),
#  ('job', 'management'),
#  ('cancer', 'sickness'),
#  ('word', 'newspaper'),
#  ('composer', 'writer'),
#  ('actor', 'singer'),
#  ('shelter', 'hut'),
#  ('bathroom', 'kitchen'),
#  ('cabin', 'hut'),
#  ('door', 'kitchen'),
#  ('value', 'belief'),
#  ('wisdom', 'intelligence'),
#  ('ignorance', 'intelligence'),
#  ('happiness', 'luck'),
#  ('idea', 'scheme'),
#  ('mood', 'emotion'),
#  ('happiness', 'peace'),
#  ('despair', 'misery'),
#  ('logic', 'arithmetic'),
#  ('denial', 'confession'),
#  ('argument', 'criticism'),
#  ('aggression', 'hostility'),
#  ('hysteria', 'confusion'),
#  ('chemistry', 'theory'),
#  ('trial', 'verdict'),
#  ('comfort', 'safety'),
#  ('confidence', 'self'),
#  ('vision', 'perception'),
#  ('era', 'decade'),
#  ('biography', 'fiction'),
#  ('discussion', 'argument'),
#  ('code', 'symbol'),
#  ('danger', 'disease'),
#  ('accident', 'catastrophe'),
#  ('journey', 'trip'),
#  ('activity', 'movement'),
#  ('gossip', 'news'),
#  ('father', 'god'),
#  ('action', 'course'),
#  ('fever', 'illness'),
#  ('aviation', 'flight'),
#  ('game', 'action'),
#  ('molecule', 'air'),
#  ('home', 'state'),
#  ('word', 'literature'),
#  ('adult', 'guardian'),
#  ('newspaper', 'information'),
#  ('communication', 'television'),
#  ('cousin', 'uncle'),
#  ('author', 'reader'),
#  ('guy', 'partner'),
#  ('area', 'corner'),
#  ('ballad', 'song'),
#  ('wall', 'decoration'),
#  ('word', 'page'),
#  ('nurse', 'scientist'),
#  ('politician', 'president'),
#  ('president', 'mayor'),
#  ('book', 'essay'),
#  ('man', 'warrior'),
#  ('article', 'journal'),
#  ('breakfast', 'supper'),
#  ('crowd', 'parade'),
#  ('aisle', 'hallway'),
#  ('teacher', 'rabbi'),
#  ('hip', 'lip'),
#  ('book', 'article'),
#  ('room', 'cell'),
#  ('box', 'booth'),
#  ('daughter', 'kid'),
#  ('limb', 'leg'),
#  ('liver', 'lung'),
#  ('classroom', 'hallway'),
#  ('mountain', 'ledge'),
#  ('car', 'elevator'),
#  ('bed', 'couch'),
#  ('clothes', 'button'),
#  ('clothes', 'coat'),
#  ('kidney', 'organ'),
#  ('apple', 'sauce'),
#  ('chicken', 'steak'),
#  ('car', 'hose'),
#  ('tobacco', 'cigarette'),
#  ('student', 'professor'),
#  ('baby', 'daughter'),
#  ('pipe', 'cigar'),
#  ('milk', 'juice'),
#  ('box', 'cigar'),
#  ('apartment', 'hotel'),
#  ('cup', 'cone'),
#  ('horse', 'ox'),
#  ('throat', 'nose'),
#  ('bone', 'teeth'),
#  ('bone', 'elbow'),
#  ('bacon', 'bean'),
#  ('cup', 'jar'),
#  ('proof', 'fact'),
#  ('appointment', 'engagement'),
#  ('birthday', 'year'),
#  ('word', 'clue'),
#  ('author', 'creator'),
#  ('atom', 'carbon'),
#  ('archbishop', 'bishop'),
#  ('letter', 'paragraph'),
#  ('page', 'paragraph'),
#  ('steeple', 'chapel'),
#  ('muscle', 'bone'),
#  ('muscle', 'tongue'),
#  ('boy', 'soldier'),
#  ('belly', 'abdomen'),
#  ('guy', 'girl'),
#  ('bed', 'chair'),
#  ('clothes', 'jacket'),
#  ('gun', 'knife'),
#  ('tin', 'metal'),
#  ('bottle', 'container'),
#  ('hen', 'turkey'),
#  ('meat', 'bread'),
#  ('arm', 'bone'),
#  ('neck', 'spine'),
#  ('apple', 'lemon'),
#  ('agony', 'grief'),
#  ('assignment', 'task'),
#  ('night', 'dawn'),
#  ('dinner', 'soup'),
#  ('calf', 'bull'),
#  ('snow', 'storm'),
#  ('nail', 'hand'),
#  ('dog', 'horse'),
#  ('arm', 'neck'),
#  ('ball', 'glove'),
#  ('flu', 'fever'),
#  ('fee', 'salary'),
#  ('nerve', 'brain'),
#  ('beast', 'animal'),
#  ('dinner', 'chicken'),
#  ('girl', 'maid'),
#  ('child', 'boy'),
#  ('alcohol', 'wine'),
#  ('nose', 'mouth'),
#  ('street', 'car'),
#  ('bell', 'door'),
#  ('box', 'hat'),
#  ('belief', 'impression'),
#  ('bias', 'opinion'),
#  ('attention', 'awareness'),
#  ('anger', 'mood'),
#  ('elegance', 'style'),
#  ('beauty', 'age'),
#  ('book', 'theme'),
#  ('friend', 'mother'),
#  ('vitamin', 'iron'),
#  ('car', 'factory'),
#  ('pact', 'condition'),
#  ('chapter', 'choice'),
#  ('arithmetic', 'rhythm'),
#  ('winner', 'presence'),
#  ('belief', 'flower'),
#  ('winner', 'goal'),
#  ('trick', 'size'),
#  ('choice', 'vein'),
#  ('hymn', 'conquest'),
#  ('endurance', 'band'),
#  ('jail', 'choice'),
#  ('condition', 'boy'),
#  ('flower', 'endurance'),
#  ('hole', 'agreement'),
#  ('doctor', 'temper'),
#  ('fraternity', 'door'),
#  ('task', 'woman'),
#  ('fraternity', 'baseball'),
#  ('cent', 'size'),
#  ('presence', 'door'),
#  ('mouse', 'management'),
#  ('task', 'highway'),
#  ('liquor', 'century'),
#  ('task', 'straw'),
#  ('island', 'task'),
#  ('night', 'chapter'),
#  ('pollution', 'president'),
#  ('gun', 'trick'),
#  ('bath', 'trick'),
#  ('diet', 'apple'),
#  ('cent', 'wife'),
#  ('chapter', 'tail'),
#  ('course', 'stomach'),
#  ('hymn', 'straw'),
#  ('dentist', 'colonel'),
#  ('wife', 'straw'),
#  ('hole', 'wife'),
#  ('pupil', 'president'),
#  ('bath', 'wife'),
#  ('people', 'cent'),
#  ('formula', 'log'),
#  ('woman', 'fur'),
#  ('apple', 'sunshine'),
#  ('gun', 'dawn'),
#  ('meal', 'waist'),
#  ('camera', 'president'),
#  ('liquor', 'band'),
#  ('stomach', 'vein'),
#  ('gun', 'fur'),
#  ('couch', 'baseball'),
#  ('worker', 'camera'),
#  ('deck', 'mouse'),
#  ('rice', 'boy'),
#  ('people', 'gun'),
#  ('cliff', 'tail'),
#  ('ankle', 'window'),
#  ('princess', 'island'),
#  ('container', 'mouse'),
#  ('wagon', 'container'),
#  ('people', 'balloon'),
#  ('dollar', 'people'),
#  ('bath', 'balloon'),
#  ('stomach', 'bedroom'),
#  ('bicycle', 'bedroom'),
#  ('log', 'bath'),
#  ('bowl', 'tail'),
#  ('go', 'come'),
#  ('take', 'steal'),
#  ('listen', 'hear'),
#  ('think', 'rationalize'),
#  ('occur', 'happen'),
#  ('vanish', 'disappear'),
#  ('multiply', 'divide'),
#  ('plead', 'beg'),
#  ('begin', 'originate'),
#  ('protect', 'defend'),
#  ('kill', 'destroy'),
#  ('create', 'make'),
#  ('accept', 'reject'),
#  ('ignore', 'avoid'),
#  ('carry', 'bring'),
#  ('leave', 'enter'),
#  ('choose', 'elect'),
#  ('lose', 'fail'),
#  ('encourage', 'discourage'),
#  ('achieve', 'accomplish'),
#  ('make', 'construct'),
#  ('listen', 'obey'),
#  ('inform', 'notify'),
#  ('receive', 'give'),
#  ('borrow', 'beg'),
#  ('take', 'obtain'),
#  ('advise', 'recommend'),
#  ('imitate', 'portray'),
#  ('win', 'succeed'),
#  ('think', 'decide'),
#  ('greet', 'meet'),
#  ('agree', 'argue'),
#  ('enjoy', 'entertain'),
#  ('destroy', 'make'),
#  ('save', 'protect'),
#  ('give', 'lend'),
#  ('understand', 'know'),
#  ('take', 'receive'),
#  ('accept', 'acknowledge'),
#  ('decide', 'choose'),
#  ('accept', 'believe'),
#  ('keep', 'possess'),
#  ('roam', 'wander'),
#  ('succeed', 'fail'),
#  ('spend', 'save'),
#  ('leave', 'go'),
#  ('come', 'attend'),
#  ('know', 'believe'),
#  ('gather', 'meet'),
#  ('make', 'earn'),
#  ('forget', 'ignore'),
#  ('multiply', 'add'),
#  ('shrink', 'grow'),
#  ('arrive', 'leave'),
#  ('succeed', 'try'),
#  ('accept', 'deny'),
#  ('arrive', 'come'),
#  ('agree', 'differ'),
#  ('send', 'receive'),
#  ('win', 'dominate'),
#  ('add', 'divide'),
#  ('kill', 'choke'),
#  ('acquire', 'get'),
#  ('participate', 'join'),
#  ('leave', 'remain'),
#  ('go', 'enter'),
#  ('take', 'carry'),
#  ('forget', 'learn'),
#  ('appoint', 'elect'),
#  ('engage', 'marry'),
#  ('ask', 'pray'),
#  ('go', 'send'),
#  ('take', 'deliver'),
#  ('speak', 'hear'),
#  ('analyze', 'evaluate'),
#  ('argue', 'rationalize'),
#  ('lose', 'keep'),
#  ('compare', 'analyze'),
#  ('disorganize', 'organize'),
#  ('go', 'allow'),
#  ('take', 'possess'),
#  ('learn', 'listen'),
#  ('destroy', 'construct'),
#  ('create', 'build'),
#  ('steal', 'buy'),
#  ('kill', 'hang'),
#  ('forget', 'know'),
#  ('create', 'imagine'),
#  ('do', 'happen'),
#  ('win', 'accomplish'),
#  ('give', 'deny'),
#  ('deserve', 'earn'),
#  ('get', 'put'),
#  ('locate', 'find'),
#  ('appear', 'attend'),
#  ('know', 'comprehend'),
#  ('pretend', 'imagine'),
#  ('satisfy', 'please'),
#  ('cherish', 'keep'),
#  ('argue', 'differ'),
#  ('overcome', 'dominate'),
#  ('behave', 'obey'),
#  ('cooperate', 'participate'),
#  ('achieve', 'try'),
#  ('fail', 'discourage'),
#  ('begin', 'quit'),
#  ('say', 'participate'),
#  ('come', 'bring'),
#  ('declare', 'announce'),
#  ('read', 'comprehend'),
#  ('take', 'leave'),
#  ('proclaim', 'announce'),
#  ('acquire', 'obtain'),
#  ('conclude', 'decide'),
#  ('please', 'plead'),
#  ('argue', 'prove'),
#  ('ask', 'plead'),
#  ('find', 'disappear'),
#  ('inspect', 'examine'),
#  ('verify', 'justify'),
#  ('assume', 'predict'),
#  ('learn', 'evaluate'),
#  ('argue', 'justify'),
#  ('make', 'become'),
#  ('discover', 'originate'),
#  ('achieve', 'succeed'),
#  ('give', 'put'),
#  ('understand', 'listen'),
#  ('expand', 'grow'),
#  ('borrow', 'sell'),
#  ('keep', 'protect'),
#  ('explain', 'prove'),
#  ('assume', 'pretend'),
#  ('agree', 'please'),
#  ('forgive', 'forget'),
#  ('clarify', 'explain'),
#  ('understand', 'forgive'),
#  ('remind', 'forget'),
#  ('get', 'remain'),
#  ('realize', 'discover'),
#  ('require', 'inquire'),
#  ('ignore', 'ask'),
#  ('think', 'inquire'),
#  ('reject', 'avoid'),
#  ('argue', 'persuade'),
#  ('pursue', 'persuade'),
#  ('accept', 'forgive'),
#  ('do', 'quit'),
#  ('investigate', 'examine'),
#  ('discuss', 'explain'),
#  ('owe', 'lend'),
#  ('explore', 'discover'),
#  ('complain', 'argue'),
#  ('withdraw', 'reject'),
#  ('keep', 'borrow'),
#  ('beg', 'ask'),
#  ('arrange', 'organize'),
#  ('reduce', 'shrink'),
#  ('speak', 'acknowledge'),
#  ('give', 'borrow'),
#  ('kill', 'defend'),
#  ('disappear', 'shrink'),
#  ('deliver', 'carry'),
#  ('breathe', 'choke'),
#  ('acknowledge', 'notify'),
#  ('become', 'seem'),
#  ('pretend', 'seem'),
#  ('accomplish', 'become'),
#  ('contemplate', 'think'),
#  ('determine', 'predict'),
#  ('please', 'entertain'),
#  ('remain', 'retain'),
#  ('pretend', 'portray'),
#  ('forget', 'retain'),
#  ('want', 'choose'),
#  ('lose', 'get'),
#  ('try', 'think'),
#  ('become', 'appear'),
#  ('leave', 'ignore'),
#  ('accept', 'recommend'),
#  ('leave', 'wander'),
#  ('keep', 'give'),
#  ('give', 'allow'),
#  ('bring', 'send'),
#  ('absorb', 'learn'),
#  ('acquire', 'find'),
#  ('leave', 'appear'),
#  ('create', 'destroy'),
#  ('begin', 'go'),
#  ('get', 'buy'),
#  ('collect', 'save'),
#  ('replace', 'restore'),
#  ('join', 'add'),
#  ('join', 'marry'),
#  ('accept', 'deliver'),
#  ('attach', 'join'),
#  ('put', 'hang'),
#  ('go', 'sell'),
#  ('communicate', 'pray'),
#  ('give', 'steal'),
#  ('add', 'build'),
#  ('bring', 'restore'),
#  ('comprehend', 'satisfy'),
#  ('portray', 'decide'),
#  ('organize', 'become'),
#  ('give', 'know'),
#  ('say', 'verify'),
#  ('cooperate', 'join'),
#  ('arrange', 'require'),
#  ('borrow', 'want'),
#  ('investigate', 'pursue'),
#  ('ignore', 'explore'),
#  ('bring', 'complain'),
#  ('enter', 'owe'),
#  ('portray', 'notify'),
#  ('remind', 'sell'),
#  ('absorb', 'possess'),
#  ('join', 'acquire'),
#  ('send', 'attend'),
#  ('gather', 'attend'),
#  ('absorb', 'withdraw'),
#  ('attend', 'arrive')]

# %% [markdown]
# ### **1. Define and Evaluate Parameters**

# %%
# Define prompt
prompt = ("Rate the semantic similarity of each word pair on a scale from 0 to 10, "
          "where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. "
          "Use two decimals. The response should strictly adhere to the structure: "
          "[('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. "
          "Do not provide additional explanations or context. "
          "An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)]")

# %%
# Define model
model = "meta-llama/llama-3.3-70b-instruct"

# Set sample size
sample_size = 15

# Delay between individual API calls
delay = 15.0

# Define number of sublists
n_sublists = 25

# %%
# Split list
chunks = split_into_n_lists(tuples_list, n_sublists)

# Count the number of lists
print(len(chunks))
# Out:
# 25

# %%
# Print prompts for each chunk
print_prompts(chunks, prompt)
# Out:
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('smart', 'intelligent'), ('hard', 'difficult'), ('happy', 'cheerful'), ('hard', 'easy'), ('fast', 'rapid'), ('happy', 'glad'), ('short', 'long'), ('stupid', 'dumb'), ('weird', 'strange'), ('wide', 'narrow'), ('bad', 'awful'), ('easy', 'difficult'), ('bad', 'terrible'), ('hard', 'simple'), ('smart', 'dumb'), ('insane', 'crazy'), ('happy', 'mad'), ('large', 'huge'), ('hard', 'tough'), ('new', 'fresh'), ('sharp', 'dull'), ('quick', 'rapid'), ('dumb', 'foolish'), ('wonderful', 'terrific'), ('strange', 'odd'), ('happy', 'angry'), ('narrow', 'broad'), ('simple', 'easy'), ('old', 'fresh'), ('apparent', 'obvious'), ('inexpensive', 'cheap'), ('nice', 'generous'), ('weird', 'normal'), ('weird', 'odd'), ('bad', 'immoral'), ('sad', 'funny'), ('wonderful', 'great'), ('guilty', 'ashamed'), ('beautiful', 'wonderful'), ('confident', 'sure')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('dumb', 'dense'), ('large', 'big'), ('nice', 'cruel'), ('impatient', 'anxious'), ('big', 'broad'), ('strong', 'proud'), ('unnecessary', 'necessary'), ('restless', 'young'), ('dumb', 'intelligent'), ('bad', 'great'), ('difficult', 'simple'), ('necessary', 'important'), ('bad', 'terrific'), ('mad', 'glad'), ('honest', 'guilty'), ('easy', 'tough'), ('easy', 'flexible'), ('certain', 'sure'), ('essential', 'necessary'), ('different', 'normal'), ('sly', 'clever'), ('crucial', 'important'), ('harsh', 'cruel'), ('childish', 'foolish'), ('scarce', 'rare'), ('friendly', 'generous'), ('fragile', 'frigid'), ('long', 'narrow'), ('big', 'heavy'), ('rough', 'frigid'), ('bizarre', 'strange'), ('illegal', 'immoral'), ('bad', 'guilty'), ('modern', 'ancient'), ('new', 'ancient'), ('dull', 'funny'), ('happy', 'young'), ('easy', 'big'), ('great', 'awful'), ('tiny', 'huge')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('polite', 'proper'), ('modest', 'ashamed'), ('exotic', 'rare'), ('dumb', 'clever'), ('delightful', 'wonderful'), ('noticeable', 'obvious'), ('afraid', 'anxious'), ('formal', 'proper'), ('dreary', 'dull'), ('delightful', 'cheerful'), ('unhappy', 'mad'), ('sad', 'terrible'), ('sick', 'crazy'), ('violent', 'angry'), ('laden', 'heavy'), ('dirty', 'cheap'), ('elastic', 'flexible'), ('hard', 'dense'), ('recent', 'new'), ('bold', 'proud'), ('sly', 'strange'), ('strange', 'sly'), ('dumb', 'rare'), ('sly', 'tough'), ('terrific', 'mad'), ('modest', 'flexible'), ('fresh', 'wide'), ('huge', 'dumb'), ('large', 'flexible'), ('dirty', 'narrow'), ('wife', 'husband'), ('book', 'text'), ('groom', 'bride'), ('night', 'day'), ('south', 'north'), ('plane', 'airport'), ('uncle', 'aunt'), ('horse', 'mare'), ('bottom', 'top'), ('friend', 'buddy')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('student', 'pupil'), ('world', 'globe'), ('leg', 'arm'), ('plane', 'jet'), ('woman', 'man'), ('horse', 'colt'), ('actress', 'actor'), ('teacher', 'instructor'), ('movie', 'film'), ('bird', 'hawk'), ('word', 'dictionary'), ('money', 'salary'), ('dog', 'cat'), ('area', 'region'), ('navy', 'army'), ('book', 'literature'), ('clothes', 'closet'), ('sunset', 'sunrise'), ('child', 'adult'), ('cow', 'cattle'), ('book', 'story'), ('winter', 'summer'), ('taxi', 'cab'), ('tree', 'maple'), ('bed', 'bedroom'), ('roof', 'ceiling'), ('disease', 'infection'), ('arm', 'shoulder'), ('sheep', 'lamb'), ('lady', 'gentleman'), ('boat', 'anchor'), ('priest', 'monk'), ('toe', 'finger'), ('river', 'stream'), ('anger', 'fury'), ('date', 'calendar'), ('sea', 'ocean'), ('second', 'minute'), ('hand', 'thumb'), ('wood', 'log')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('mud', 'dirt'), ('hallway', 'corridor'), ('way', 'manner'), ('mouse', 'cat'), ('cop', 'sheriff'), ('death', 'burial'), ('music', 'melody'), ('beer', 'alcohol'), ('mouth', 'lip'), ('storm', 'hurricane'), ('tax', 'income'), ('flower', 'violet'), ('paper', 'cardboard'), ('floor', 'ceiling'), ('beach', 'seashore'), ('rod', 'curtain'), ('hound', 'fox'), ('street', 'alley'), ('boat', 'deck'), ('car', 'horn'), ('friend', 'guest'), ('employer', 'employee'), ('hand', 'wrist'), ('ball', 'cannon'), ('alcohol', 'brandy'), ('victory', 'triumph'), ('telephone', 'booth'), ('door', 'doorway'), ('motel', 'inn'), ('clothes', 'cloth'), ('steak', 'meat'), ('nail', 'thumb'), ('band', 'orchestra'), ('book', 'bible'), ('business', 'industry'), ('winter', 'season'), ('decade', 'century'), ('alcohol', 'gin'), ('hat', 'coat'), ('window', 'door')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('arm', 'wrist'), ('house', 'apartment'), ('glass', 'crystal'), ('wine', 'brandy'), ('creator', 'maker'), ('dinner', 'breakfast'), ('arm', 'muscle'), ('bubble', 'suds'), ('bread', 'flour'), ('death', 'tragedy'), ('absence', 'presence'), ('gun', 'cannon'), ('grass', 'blade'), ('ball', 'basket'), ('hose', 'garden'), ('boy', 'kid'), ('church', 'choir'), ('clothes', 'drawer'), ('tower', 'bell'), ('father', 'parent'), ('school', 'grade'), ('parent', 'adult'), ('bar', 'jail'), ('car', 'highway'), ('dictionary', 'definition'), ('door', 'cellar'), ('army', 'legion'), ('metal', 'aluminum'), ('chair', 'bench'), ('cloud', 'fog'), ('boy', 'son'), ('water', 'ice'), ('bed', 'blanket'), ('attorney', 'lawyer'), ('area', 'zone'), ('business', 'company'), ('clothes', 'fabric'), ('sweater', 'jacket'), ('money', 'capital'), ('hand', 'foot')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('alcohol', 'cocktail'), ('yard', 'inch'), ('molecule', 'atom'), ('lens', 'camera'), ('meal', 'dinner'), ('eye', 'tear'), ('god', 'devil'), ('loop', 'belt'), ('rat', 'mouse'), ('motor', 'engine'), ('car', 'cab'), ('cat', 'lion'), ('size', 'magnitude'), ('reality', 'fantasy'), ('door', 'gate'), ('cat', 'pet'), ('tin', 'aluminum'), ('bone', 'jaw'), ('cereal', 'wheat'), ('house', 'key'), ('blood', 'flesh'), ('door', 'corridor'), ('god', 'spirit'), ('capability', 'competence'), ('abundance', 'plenty'), ('sofa', 'chair'), ('wall', 'brick'), ('horn', 'drum'), ('organ', 'liver'), ('strength', 'might'), ('phrase', 'word'), ('band', 'parade'), ('stomach', 'waist'), ('cloud', 'storm'), ('joy', 'pride'), ('noise', 'rattle'), ('rain', 'mist'), ('beer', 'beverage'), ('man', 'uncle'), ('apple', 'juice')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('intelligence', 'logic'), ('communication', 'language'), ('mink', 'fur'), ('mob', 'crowd'), ('shore', 'coast'), ('wire', 'cord'), ('bird', 'turkey'), ('bed', 'crib'), ('competence', 'ability'), ('cloud', 'haze'), ('supper', 'meal'), ('bar', 'cage'), ('water', 'salt'), ('sense', 'intuition'), ('situation', 'condition'), ('crime', 'theft'), ('style', 'fashion'), ('boundary', 'border'), ('arm', 'body'), ('boat', 'car'), ('sandwich', 'lunch'), ('bride', 'princess'), ('heroine', 'hero'), ('car', 'gauge'), ('insect', 'bee'), ('crib', 'cradle'), ('animal', 'person'), ('marijuana', 'herb'), ('bed', 'hospital'), ('cheek', 'tongue'), ('disc', 'computer'), ('curve', 'angle'), ('grass', 'moss'), ('school', 'law'), ('foot', 'head'), ('mother', 'guardian'), ('orthodontist', 'dentist'), ('alcohol', 'whiskey'), ('mouth', 'tooth'), ('breakfast', 'bacon')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('bathroom', 'bedroom'), ('plate', 'bowl'), ('meat', 'bacon'), ('air', 'helium'), ('worker', 'employer'), ('body', 'chest'), ('son', 'father'), ('heart', 'surgery'), ('woman', 'secretary'), ('man', 'father'), ('beach', 'island'), ('story', 'topic'), ('game', 'fun'), ('weekend', 'week'), ('couple', 'pair'), ('woman', 'wife'), ('sheep', 'cattle'), ('purse', 'bag'), ('ceiling', 'cathedral'), ('bean', 'coffee'), ('wood', 'paper'), ('top', 'side'), ('crime', 'fraud'), ('pain', 'harm'), ('lover', 'companion'), ('evening', 'dusk'), ('father', 'daughter'), ('wine', 'liquor'), ('cow', 'goat'), ('belief', 'opinion'), ('reality', 'illusion'), ('pact', 'agreement'), ('wealth', 'poverty'), ('accident', 'emergency'), ('battle', 'conquest'), ('friend', 'teacher'), ('illness', 'infection'), ('game', 'trick'), ('brother', 'son'), ('aunt', 'nephew')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('worker', 'mechanic'), ('doctor', 'orthodontist'), ('oak', 'maple'), ('bee', 'queen'), ('car', 'bicycle'), ('goal', 'quest'), ('august', 'month'), ('army', 'squad'), ('cloud', 'weather'), ('physician', 'doctor'), ('canyon', 'valley'), ('river', 'valley'), ('sun', 'sky'), ('target', 'arrow'), ('chocolate', 'pie'), ('circumstance', 'situation'), ('opinion', 'choice'), ('rhythm', 'melody'), ('gut', 'nerve'), ('day', 'dawn'), ('cattle', 'beef'), ('doctor', 'professor'), ('arm', 'vein'), ('room', 'bath'), ('corporation', 'business'), ('fun', 'football'), ('hill', 'cliff'), ('bone', 'ankle'), ('apple', 'candy'), ('helper', 'maid'), ('leader', 'manager'), ('lemon', 'tea'), ('bee', 'ant'), ('basketball', 'baseball'), ('rice', 'bean'), ('bed', 'furniture'), ('emotion', 'passion'), ('anarchy', 'chaos'), ('crime', 'violation'), ('machine', 'engine')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('beach', 'sea'), ('alley', 'bowl'), ('jar', 'bottle'), ('strength', 'capability'), ('seed', 'mustard'), ('guitar', 'drum'), ('opinion', 'idea'), ('north', 'west'), ('diet', 'salad'), ('mother', 'wife'), ('dad', 'mother'), ('captain', 'sailor'), ('meter', 'yard'), ('beer', 'champagne'), ('motor', 'boat'), ('card', 'bridge'), ('science', 'psychology'), ('sinner', 'saint'), ('destruction', 'construction'), ('crowd', 'bunch'), ('beach', 'reef'), ('man', 'child'), ('bread', 'cheese'), ('champion', 'winner'), ('celebration', 'ceremony'), ('menu', 'order'), ('king', 'princess'), ('wealth', 'prestige'), ('endurance', 'strength'), ('danger', 'threat'), ('god', 'priest'), ('men', 'fraternity'), ('buddy', 'companion'), ('teacher', 'helper'), ('body', 'stomach'), ('tongue', 'throat'), ('house', 'carpet'), ('intelligence', 'skill'), ('journey', 'conquest'), ('god', 'prey')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('brother', 'soul'), ('adversary', 'opponent'), ('death', 'catastrophe'), ('monster', 'demon'), ('day', 'morning'), ('man', 'victor'), ('friend', 'guy'), ('song', 'story'), ('ray', 'sunshine'), ('guy', 'stud'), ('chicken', 'rice'), ('box', 'elevator'), ('butter', 'potato'), ('apartment', 'furniture'), ('lake', 'swamp'), ('salad', 'vinegar'), ('flower', 'bulb'), ('cloud', 'mist'), ('driver', 'pilot'), ('sugar', 'honey'), ('body', 'shoulder'), ('idea', 'image'), ('father', 'brother'), ('moon', 'planet'), ('ball', 'costume'), ('rail', 'fence'), ('room', 'bed'), ('flower', 'bush'), ('bone', 'knee'), ('arm', 'knee'), ('bottom', 'side'), ('vessel', 'vein'), ('cat', 'rabbit'), ('meat', 'sandwich'), ('belief', 'concept'), ('intelligence', 'insight'), ('attention', 'interest'), ('attitude', 'confidence'), ('right', 'justice'), ('argument', 'agreement')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('depth', 'magnitude'), ('medium', 'news'), ('winner', 'candidate'), ('birthday', 'date'), ('fee', 'payment'), ('bible', 'hymn'), ('exit', 'doorway'), ('man', 'sentry'), ('aisle', 'hall'), ('whiskey', 'gin'), ('blood', 'marrow'), ('oil', 'mink'), ('floor', 'deck'), ('roof', 'floor'), ('door', 'floor'), ('shoulder', 'head'), ('wagon', 'carriage'), ('car', 'carriage'), ('elbow', 'ankle'), ('wealth', 'fame'), ('sorrow', 'shame'), ('administration', 'management'), ('communication', 'conversation'), ('pollution', 'atmosphere'), ('anatomy', 'biology'), ('college', 'profession'), ('book', 'topic'), ('formula', 'equation'), ('book', 'information'), ('boy', 'partner'), ('sky', 'universe'), ('population', 'people'), ('college', 'class'), ('chief', 'mayor'), ('rabbi', 'minister'), ('meter', 'inch'), ('polyester', 'cotton'), ('lawyer', 'banker'), ('violin', 'instrument'), ('camp', 'cabin')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('pot', 'appliance'), ('linen', 'fabric'), ('whiskey', 'champagne'), ('girl', 'child'), ('cottage', 'cabin'), ('bird', 'hen'), ('racket', 'noise'), ('sunset', 'evening'), ('drizzle', 'rain'), ('adult', 'baby'), ('charcoal', 'coal'), ('body', 'spine'), ('head', 'nail'), ('log', 'timber'), ('spoon', 'cup'), ('body', 'nerve'), ('man', 'husband'), ('bone', 'neck'), ('frustration', 'anger'), ('river', 'sea'), ('task', 'job'), ('club', 'society'), ('reflection', 'image'), ('prince', 'king'), ('snow', 'weather'), ('people', 'party'), ('boy', 'brother'), ('root', 'grass'), ('brow', 'eye'), ('money', 'pearl'), ('money', 'diamond'), ('vehicle', 'bus'), ('cab', 'bus'), ('house', 'barn'), ('finger', 'palm'), ('car', 'bridge'), ('effort', 'difficulty'), ('fact', 'insight'), ('job', 'management'), ('cancer', 'sickness')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('word', 'newspaper'), ('composer', 'writer'), ('actor', 'singer'), ('shelter', 'hut'), ('bathroom', 'kitchen'), ('cabin', 'hut'), ('door', 'kitchen'), ('value', 'belief'), ('wisdom', 'intelligence'), ('ignorance', 'intelligence'), ('happiness', 'luck'), ('idea', 'scheme'), ('mood', 'emotion'), ('happiness', 'peace'), ('despair', 'misery'), ('logic', 'arithmetic'), ('denial', 'confession'), ('argument', 'criticism'), ('aggression', 'hostility'), ('hysteria', 'confusion'), ('chemistry', 'theory'), ('trial', 'verdict'), ('comfort', 'safety'), ('confidence', 'self'), ('vision', 'perception'), ('era', 'decade'), ('biography', 'fiction'), ('discussion', 'argument'), ('code', 'symbol'), ('danger', 'disease'), ('accident', 'catastrophe'), ('journey', 'trip'), ('activity', 'movement'), ('gossip', 'news'), ('father', 'god'), ('action', 'course'), ('fever', 'illness'), ('aviation', 'flight'), ('game', 'action'), ('molecule', 'air')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('home', 'state'), ('word', 'literature'), ('adult', 'guardian'), ('newspaper', 'information'), ('communication', 'television'), ('cousin', 'uncle'), ('author', 'reader'), ('guy', 'partner'), ('area', 'corner'), ('ballad', 'song'), ('wall', 'decoration'), ('word', 'page'), ('nurse', 'scientist'), ('politician', 'president'), ('president', 'mayor'), ('book', 'essay'), ('man', 'warrior'), ('article', 'journal'), ('breakfast', 'supper'), ('crowd', 'parade'), ('aisle', 'hallway'), ('teacher', 'rabbi'), ('hip', 'lip'), ('book', 'article'), ('room', 'cell'), ('box', 'booth'), ('daughter', 'kid'), ('limb', 'leg'), ('liver', 'lung'), ('classroom', 'hallway'), ('mountain', 'ledge'), ('car', 'elevator'), ('bed', 'couch'), ('clothes', 'button'), ('clothes', 'coat'), ('kidney', 'organ'), ('apple', 'sauce'), ('chicken', 'steak'), ('car', 'hose'), ('tobacco', 'cigarette')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('student', 'professor'), ('baby', 'daughter'), ('pipe', 'cigar'), ('milk', 'juice'), ('box', 'cigar'), ('apartment', 'hotel'), ('cup', 'cone'), ('horse', 'ox'), ('throat', 'nose'), ('bone', 'teeth'), ('bone', 'elbow'), ('bacon', 'bean'), ('cup', 'jar'), ('proof', 'fact'), ('appointment', 'engagement'), ('birthday', 'year'), ('word', 'clue'), ('author', 'creator'), ('atom', 'carbon'), ('archbishop', 'bishop'), ('letter', 'paragraph'), ('page', 'paragraph'), ('steeple', 'chapel'), ('muscle', 'bone'), ('muscle', 'tongue'), ('boy', 'soldier'), ('belly', 'abdomen'), ('guy', 'girl'), ('bed', 'chair'), ('clothes', 'jacket'), ('gun', 'knife'), ('tin', 'metal'), ('bottle', 'container'), ('hen', 'turkey'), ('meat', 'bread'), ('arm', 'bone'), ('neck', 'spine'), ('apple', 'lemon'), ('agony', 'grief'), ('assignment', 'task')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('night', 'dawn'), ('dinner', 'soup'), ('calf', 'bull'), ('snow', 'storm'), ('nail', 'hand'), ('dog', 'horse'), ('arm', 'neck'), ('ball', 'glove'), ('flu', 'fever'), ('fee', 'salary'), ('nerve', 'brain'), ('beast', 'animal'), ('dinner', 'chicken'), ('girl', 'maid'), ('child', 'boy'), ('alcohol', 'wine'), ('nose', 'mouth'), ('street', 'car'), ('bell', 'door'), ('box', 'hat'), ('belief', 'impression'), ('bias', 'opinion'), ('attention', 'awareness'), ('anger', 'mood'), ('elegance', 'style'), ('beauty', 'age'), ('book', 'theme'), ('friend', 'mother'), ('vitamin', 'iron'), ('car', 'factory'), ('pact', 'condition'), ('chapter', 'choice'), ('arithmetic', 'rhythm'), ('winner', 'presence'), ('belief', 'flower'), ('winner', 'goal'), ('trick', 'size'), ('choice', 'vein'), ('hymn', 'conquest'), ('endurance', 'band')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('jail', 'choice'), ('condition', 'boy'), ('flower', 'endurance'), ('hole', 'agreement'), ('doctor', 'temper'), ('fraternity', 'door'), ('task', 'woman'), ('fraternity', 'baseball'), ('cent', 'size'), ('presence', 'door'), ('mouse', 'management'), ('task', 'highway'), ('liquor', 'century'), ('task', 'straw'), ('island', 'task'), ('night', 'chapter'), ('pollution', 'president'), ('gun', 'trick'), ('bath', 'trick'), ('diet', 'apple'), ('cent', 'wife'), ('chapter', 'tail'), ('course', 'stomach'), ('hymn', 'straw'), ('dentist', 'colonel'), ('wife', 'straw'), ('hole', 'wife'), ('pupil', 'president'), ('bath', 'wife'), ('people', 'cent'), ('formula', 'log'), ('woman', 'fur'), ('apple', 'sunshine'), ('gun', 'dawn'), ('meal', 'waist'), ('camera', 'president'), ('liquor', 'band'), ('stomach', 'vein'), ('gun', 'fur'), ('couch', 'baseball')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('worker', 'camera'), ('deck', 'mouse'), ('rice', 'boy'), ('people', 'gun'), ('cliff', 'tail'), ('ankle', 'window'), ('princess', 'island'), ('container', 'mouse'), ('wagon', 'container'), ('people', 'balloon'), ('dollar', 'people'), ('bath', 'balloon'), ('stomach', 'bedroom'), ('bicycle', 'bedroom'), ('log', 'bath'), ('bowl', 'tail'), ('go', 'come'), ('take', 'steal'), ('listen', 'hear'), ('think', 'rationalize'), ('occur', 'happen'), ('vanish', 'disappear'), ('multiply', 'divide'), ('plead', 'beg'), ('begin', 'originate'), ('protect', 'defend'), ('kill', 'destroy'), ('create', 'make'), ('accept', 'reject'), ('ignore', 'avoid'), ('carry', 'bring'), ('leave', 'enter'), ('choose', 'elect'), ('lose', 'fail'), ('encourage', 'discourage'), ('achieve', 'accomplish'), ('make', 'construct'), ('listen', 'obey'), ('inform', 'notify'), ('receive', 'give')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('borrow', 'beg'), ('take', 'obtain'), ('advise', 'recommend'), ('imitate', 'portray'), ('win', 'succeed'), ('think', 'decide'), ('greet', 'meet'), ('agree', 'argue'), ('enjoy', 'entertain'), ('destroy', 'make'), ('save', 'protect'), ('give', 'lend'), ('understand', 'know'), ('take', 'receive'), ('accept', 'acknowledge'), ('decide', 'choose'), ('accept', 'believe'), ('keep', 'possess'), ('roam', 'wander'), ('succeed', 'fail'), ('spend', 'save'), ('leave', 'go'), ('come', 'attend'), ('know', 'believe'), ('gather', 'meet'), ('make', 'earn'), ('forget', 'ignore'), ('multiply', 'add'), ('shrink', 'grow'), ('arrive', 'leave'), ('succeed', 'try'), ('accept', 'deny'), ('arrive', 'come'), ('agree', 'differ'), ('send', 'receive'), ('win', 'dominate'), ('add', 'divide'), ('kill', 'choke'), ('acquire', 'get'), ('participate', 'join')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('leave', 'remain'), ('go', 'enter'), ('take', 'carry'), ('forget', 'learn'), ('appoint', 'elect'), ('engage', 'marry'), ('ask', 'pray'), ('go', 'send'), ('take', 'deliver'), ('speak', 'hear'), ('analyze', 'evaluate'), ('argue', 'rationalize'), ('lose', 'keep'), ('compare', 'analyze'), ('disorganize', 'organize'), ('go', 'allow'), ('take', 'possess'), ('learn', 'listen'), ('destroy', 'construct'), ('create', 'build'), ('steal', 'buy'), ('kill', 'hang'), ('forget', 'know'), ('create', 'imagine'), ('do', 'happen'), ('win', 'accomplish'), ('give', 'deny'), ('deserve', 'earn'), ('get', 'put'), ('locate', 'find'), ('appear', 'attend'), ('know', 'comprehend'), ('pretend', 'imagine'), ('satisfy', 'please'), ('cherish', 'keep'), ('argue', 'differ'), ('overcome', 'dominate'), ('behave', 'obey'), ('cooperate', 'participate'), ('achieve', 'try')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('fail', 'discourage'), ('begin', 'quit'), ('say', 'participate'), ('come', 'bring'), ('declare', 'announce'), ('read', 'comprehend'), ('take', 'leave'), ('proclaim', 'announce'), ('acquire', 'obtain'), ('conclude', 'decide'), ('please', 'plead'), ('argue', 'prove'), ('ask', 'plead'), ('find', 'disappear'), ('inspect', 'examine'), ('verify', 'justify'), ('assume', 'predict'), ('learn', 'evaluate'), ('argue', 'justify'), ('make', 'become'), ('discover', 'originate'), ('achieve', 'succeed'), ('give', 'put'), ('understand', 'listen'), ('expand', 'grow'), ('borrow', 'sell'), ('keep', 'protect'), ('explain', 'prove'), ('assume', 'pretend'), ('agree', 'please'), ('forgive', 'forget'), ('clarify', 'explain'), ('understand', 'forgive'), ('remind', 'forget'), ('get', 'remain'), ('realize', 'discover'), ('require', 'inquire'), ('ignore', 'ask'), ('think', 'inquire'), ('reject', 'avoid')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('argue', 'persuade'), ('pursue', 'persuade'), ('accept', 'forgive'), ('do', 'quit'), ('investigate', 'examine'), ('discuss', 'explain'), ('owe', 'lend'), ('explore', 'discover'), ('complain', 'argue'), ('withdraw', 'reject'), ('keep', 'borrow'), ('beg', 'ask'), ('arrange', 'organize'), ('reduce', 'shrink'), ('speak', 'acknowledge'), ('give', 'borrow'), ('kill', 'defend'), ('disappear', 'shrink'), ('deliver', 'carry'), ('breathe', 'choke'), ('acknowledge', 'notify'), ('become', 'seem'), ('pretend', 'seem'), ('accomplish', 'become'), ('contemplate', 'think'), ('determine', 'predict'), ('please', 'entertain'), ('remain', 'retain'), ('pretend', 'portray'), ('forget', 'retain'), ('want', 'choose'), ('lose', 'get'), ('try', 'think'), ('become', 'appear'), ('leave', 'ignore'), ('accept', 'recommend'), ('leave', 'wander'), ('keep', 'give'), ('give', 'allow')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('bring', 'send'), ('absorb', 'learn'), ('acquire', 'find'), ('leave', 'appear'), ('create', 'destroy'), ('begin', 'go'), ('get', 'buy'), ('collect', 'save'), ('replace', 'restore'), ('join', 'add'), ('join', 'marry'), ('accept', 'deliver'), ('attach', 'join'), ('put', 'hang'), ('go', 'sell'), ('communicate', 'pray'), ('give', 'steal'), ('add', 'build'), ('bring', 'restore'), ('comprehend', 'satisfy'), ('portray', 'decide'), ('organize', 'become'), ('give', 'know'), ('say', 'verify'), ('cooperate', 'join'), ('arrange', 'require'), ('borrow', 'want'), ('investigate', 'pursue'), ('ignore', 'explore'), ('bring', 'complain'), ('enter', 'owe'), ('portray', 'notify'), ('remind', 'sell'), ('absorb', 'possess'), ('join', 'acquire'), ('send', 'attend'), ('gather', 'attend'), ('absorb', 'withdraw'), ('attend', 'arrive')"]

# %%
# Load encoding
encoding = tiktoken.get_encoding("cl100k_base")

# Count tokens per chunk
token_counts = count_tokens_with_tiktoken(chunks, prompt)

# Show results
print("Token counts for each formatted prompt:", token_counts)
# Out:
# Token counts for each formatted prompt: [392, 393, 397, 378, 386, 379, 376, 386, 387, 391, 390, 390, 380, 379, 391, 392, 382, 377, 386, 379, 379, 380, 378, 383, 369]

# %% [markdown]
# ### **2. Extract and Process Data**

# %%
# Get results from API
response = get_responses(chunks, prompt, model, sample_size, delay)
# Out:
# Processing: 100%|██████████| 375/375 [3:15:23<00:00, 31.26s/chunk]
# Total time taken: 11723.88 seconds

# %%
# Define filepath
file_path = '../../../data/llama-3.3-70b/response/en/f2.json'

# Check if file already exists
if not os.path.exists(file_path):
    with open(file_path, 'w') as f:
        json.dump(response, f)
        print("File saved successfully.")
else:
    print("File already exists. JSON was not saved to prevent overwriting.")
# Out:
# File saved successfully.

# %%
# Process data into dictionary
data_dict = process_responses(response)

# Check for values higher/lower then sample size
higher_lower_samples = {key: value for key, value in data_dict.items() if len(value) < sample_size or len(value) > sample_size}

# Show results
print(higher_lower_samples)
# Out:
# {('hard', 'difficult'): [9.23, 9.25, 8.97, 9.25, 9.23, 8.92, 9.28, 8.95, 9.23, 8.45, 8.92, 9.15, 8.5, 8.42], ('bad', 'awful'): [8.95, 9.45, 8.95, 9.15, 8.58, 9.13, 9.55, 8.9, 8.85, 8.85, 9.29, 9.51, 8.8, 8.15], ('happy', 'angry'): [2.11, 1.85, 1.41, 1.6, 1.67, 2.15, 1.51, 1.8, 1.85, 1.85, 1.86, 1.49, 1.2, 1.25], ('bad', 'immoral'): [8.73, 9.25, 9.27, 8.8, 8.76, 8.69, 9.17, 8.25, 8.69, 8.65, 8.85, 9.17, 8.6, 8.48], ('confident', 'sure'): [9.24, 9.85, 9.51, 9.4, 9.43, 9.17, 9.39, 9.15, 9.49, 9.08, 9.01, 9.13, 9.1, 9.05], ('steak', 'meat'): [8.36, 8.46, 8.93, 8.95, 9.11, 8.85, 8.83, 8.96, 9.24, 9.4, 9.0, 8.93, 9.21, 8.76], ('nail', 'thumb'): [4.58, 3.98, 4.86, 5.26, 4.59, 4.91, 3.69, 4.67, 5.18, 4.8, 4.5, 3.68, 4.38, 3.92], ('band', 'orchestra'): [8.99, 8.65, 9.13, 8.83, 8.69, 9.04, 8.55, 8.53, 9.14, 9.1, 8.25, 9.02, 9.14, 8.65], ('book', 'bible'): [7.49, 7.68, 7.65, 7.56, 7.83, 8.26, 7.65, 7.71, 8.56, 8.2, 7.5, 7.44, 8.85, 7.57], ('business', 'industry'): [9.01, 8.91, 9.04, 9.07, 9.21, 9.13, 9.24, 9.03, 9.45, 9.0, 9.3, 9.11, 9.46, 9.03], ('winter', 'season'): [6.65, 6.73, 6.71, 6.9, 7.44, 7.46, 7.41, 6.82, 7.63, 7.4, 6.5, 6.95, 7.93, 6.93], ('decade', 'century'): [5.19, 5.41, 5.43, 7.42, 6.95, 6.93, 6.93, 5.45, 6.94, 6.1, 5.4, 5.38, 6.51, 5.21], ('alcohol', 'gin'): [9.53, 9.65, 9.53, 9.28, 9.49, 9.21, 9.21, 9.44, 9.59, 9.3, 9.45, 9.42, 9.78, 9.39], ('hat', 'coat'): [6.38, 4.38, 5.29, 6.48, 5.92, 6.44, 5.62, 5.19, 6.28, 6.9, 5.8, 5.61, 5.31, 4.67], ('window', 'door'): [6.21, 5.29, 6.45, 6.19, 6.71, 6.75, 5.19, 6.17, 7.19, 6.5, 5.1, 5.27, 6.85, 5.93], ('house', 'apartment'): [9.15, 9.23, 9.23, 9.21, 9.23, 9.23, 9.23, 8.93, 8.92, 8.92, 9.23, 8.92, 9.23], ('bread', 'flour'): [8.14, 7.85, 7.85, 8.5, 7.92, 7.39, 7.85, 8.17, 7.95, 7.24, 7.85, 7.92, 8.15], ('church', 'choir'): [8.46, 8.42, 8.58, 8.95, 8.93, 8.59, 8.59, 8.28, 8.15, 7.83, 8.95, 8.19, 8.52], ('metal', 'aluminum'): [9.35, 8.75, 9.17, 9.1, 9.18, 8.79, 8.76, 9.41, 0.15, 8.93, 8.49, 8.97, 8.69, 9.13], ('cloud', 'fog'): [8.56, 8.22, 8.59, 8.4, 8.59, 8.53, 8.16, 8.53, 8.22, 7.65, 8.73, 8.22, 8.78], ('bed', 'blanket'): [7.93, 7.4, 7.41, 7.5, 7.44, 7.61, 7.93, 7.91, 8.56, 7.71, 6.83, 7.61, 7.38, 7.51], ('clothes', 'fabric'): [8.63, 8.2, 8.78, 8.8, 8.48, 8.22, 8.51, 8.82, 0.91, 8.13, 7.93, 8.39, 8.45, 8.59], ('communication', 'language'): [9.18, 9.45, 9.15, 9.15, 9.15, 9.15, 9.15, 9.2, 9.15, 9.15, 9.15, 9.21, 9.15, 9.15], ('shore', 'coast'): [9.38, 9.58, 9.51, 9.4, 9.51, 9.51, 9.58, 9.58, 9.51, 9.58, 9.51, 9.81, 9.51, 9.81], ('bed', 'crib'): [8.14, 8.92, 8.69, 8.51, 8.19, 8.13, 8.11, 8.42, 8.11, 8.19, 8.16, 8.51, 8.56, 8.56], ('competence', 'ability'): [9.45, 9.42, 9.38, 9.24, 9.41, 9.43, 9.03, 9.1, 9.43, 9.45, 9.41, 9.42, 9.43, 9.45], ('cloud', 'haze'): [8.56, 8.49, 8.56, 7.93, 8.67, 8.59, 8.66, 8.69, 8.67, 8.51, 8.69, 8.14, 8.19, 8.93], ('grass', 'moss'): [8.29, 8.46, 8.49, 8.14, 8.45, 8.54, 8.25, 8.63, 8.76, 8.63, 8.27, 8.46, 8.51, 8.39], ('newspaper', 'magazine'): [8.42, 8.42, 8.42], ('word', 'newspaper'): [4.24, 2.39, 2.15, 2.45, 0.0, 0.0, 2.15, 0.0], ('newspaper', 'journal'): [8.42], ('newspaper', 'writer'): [2.45], ('newspaper', 'news'): [6.25, 8.45], ('cent', 'size'): [6.82, 4.8, 5.67, 6.42, 2.14, 3.45, 6.38, 5.19, 6.32, 1.89, 3.45, 2.48, 6.23, 5.17], ('mouse', 'management'): [3.95, 2.4, 1.94, 3.14, 2.85, 1.67, 2.93, 2.67, 3.41, 1.46, 1.89, 0.88, 4.52, 1.85], ('task', 'straw'): [2.81, 1.5, 1.11, 2.35, 1.62, 1.42, 2.46, 1.42, 2.36, 0.69, 1.56, 0.69, 3.61, 0.69], ('course', 'stomach'): [4.85, 3.4, 2.49, 5.14, 4.25, 2.81, 4.34, 3.51, 5.49, 1.29, 2.78, 1.18, 5.15, 2.15], ('hymn', 'straw'): [2.94, 1.9, 1.23, 2.77, 2.41, 1.93, 2.83, 2.19, 2.67, 0.79, 1.9, 0.89, 3.99, 0.98], ('wife', 'straw'): [2.39, 1.3, 1.01, 2.19, 2.19, 1.49, 2.51, 1.93, 2.44, 0.41, 1.45, 0.62, 4.07, 0.65], ('apple', 'sunshine'): [6.54, 4.9, 3.94, 6.21, 5.95, 3.19, 6.74, 4.67, 6.49, 2.93, 4.23, 4.58, 6.81, 3.79], ('stomach', 'vein'): [7.26, 6.5, 5.42, 7.13, 6.92, 6.52, 6.58, 7.13, 7.56, 4.19, 6.78, 4.29, 7.39,  ...

# %%
# Print duplicate word pairs
print_duplicate_word_pairs(en_simlex, data_dict)
# Out:
# Empty DataFrame
# Columns: [Combined_Columns]
# Index: []
# Empty DataFrame
# Columns: [Combined_Columns]
# Index: []

# %%
# Convert dict to Pandas DataFrame
df = create_dataframe(data_dict)

# Show results
df
# Out:
#        word1        word2  similarity_score_1  similarity_score_2  \
# 0      smart  intelligent                9.45                9.85
# 1       hard    difficult                9.23                9.25
# 2      happy     cheerful                9.81                9.40
# 3       hard         easy                1.25                1.20
# 4       fast        rapid                9.58                9.80
# ...      ...          ...                 ...                 ...
# 1005    join      acquire                8.51                8.59
# 1006    send       attend                7.67                6.49
# 1007  gather       attend                8.23                7.39
# 1008  absorb     withdraw                5.29                4.11
# 1009  attend       arrive                9.05                8.13
#
#       similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                   9.45                8.95                8.95
# 1                   8.97                9.25                9.23
# 2                   9.21                9.50                9.45
# 3                   1.29                1.20                1.21
# 4                   9.56                9.80                9.67
# ...                  ...                 ...                 ...
# 1005                8.46                8.23                8.72
# 1006                6.67                6.59                6.49
# 1007                8.19                7.85                7.94
# 1008                3.85                4.17                5.11
# 1009                8.59                8.51                8.13
#
#       similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                   9.45                9.45                0.45
# 1                   8.92                9.28                8.95
# 2                   9.21                9.81                9.00
# 3                   1.23                1.22                1.23
# 4                   9.56                9.63                9.56
# ...                  ...                 ...                 ...
# 1005                8.16                8.26                8.56
# 1006                6.94                5.83                7.34
# 1007                8.49                7.42                8.23
# 1008                3.19                3.19                3.15
# 1009                9.38                8.51                8.91
#
#       similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                   9.45                 8.95                 8.92
# 1                   9.23                 8.45                 8.92
# 2                   9.20                 9.41                 9.21
# 3                   1.40                 1.29                 1.17
# 4                   9.50                 9.58                 9.50
# ...                  ...                  ...                  ...
# 1005                8.46                 7.91                 7.85
# 1006                6.93                 5.74                 5.67
# 1007                8.19                 7.43                 7.19
# 1008                4.67                 3.59                 3.56
# 1009                8.57                 8.17                 8.25
#
#       similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                    9.45                 9.42                 9.20
# 1                    9.15                 8.50                 8.42
# 2                    9.21                 9.28                 9.80
# 3                    1.23                 1.05                 1.20
# 4                    9.56                 9.58                 9.50
# ...                   ...                  ...                  ...
# 1005                 7.90                 7.93                 8.46
# 1006                 6.00                 6.26                 6.81
# 1007                 7.50                 7.18                 8.19
# 1008                 4.60                 4.21                 4.13
# 1009                 8.40                 8.19                 8.58
#
#       similarity_score_15
# 0                    8.95
# 1                     NaN
# 2                    9.21
# 3                    1.39
# 4                    9.50
# ...                   ...
# 1005                 8.46
# 1006                 6.75
# 1007                 8.13
# 1008                 3.51
# 1009                 8.85
#
# [1010 rows x 17 columns]

# %%
# Count null values
count_null_values = df.isnull().sum()

# Show results
print("Null value counts per column:", count_null_values)
# Out:
# Null value counts per column: word1                   0
# word2                   0
# similarity_score_1      0
# similarity_score_2     10
# similarity_score_3     11
# similarity_score_4     12
# similarity_score_5     12
# similarity_score_6     12
# similarity_score_7     12
# similarity_score_8     12
# similarity_score_9     13
# similarity_score_10    13
# similarity_score_11    13
# similarity_score_12    13
# similarity_score_13    13
# similarity_score_14    17
# similarity_score_15    88
# dtype: int64

# %%
# Check for rows with at least one null value
rows_with_null = df[df.isnull().any(axis=1)]

# Show results
rows_with_null
# Out:
#          word1      word2  similarity_score_1  similarity_score_2  \
# 1         hard  difficult                9.23                9.25
# 10         bad      awful                8.95                9.45
# 25       happy      angry                2.11                1.85
# 34         bad    immoral                8.73                9.25
# 39   confident       sure                9.24                9.85
# ..         ...        ...                 ...                 ...
# 966      leave     ignore                5.17                5.48
# 967     accept  recommend                7.41                7.44
# 968      leave     wander                6.28                6.17
# 969       keep       give                5.53                5.92
# 970       give      allow                7.18                7.26
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 1                  8.97                9.25                9.23
# 10                 8.95                9.15                8.58
# 25                 1.41                1.60                1.67
# 34                 9.27                8.80                8.76
# 39                 9.51                9.40                9.43
# ..                  ...                 ...                 ...
# 966                6.19                5.91                6.49
# 967                7.94                7.85                8.58
# 968                6.67                6.49                6.95
# 969                5.49                5.63                5.93
# 970                8.04                8.25                8.11
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 1                  8.92                9.28                8.95
# 10                 9.13                9.55                8.90
# 25                 2.15                1.51                1.80
# 34                 8.69                9.17                8.25
# 39                 9.17                9.39                9.15
# ..                  ...                 ...                 ...
# 966                5.64                5.35                5.67
# 967                7.26                7.29                7.22
# 968                6.18                6.49                6.34
# 969                5.49                5.92                5.92
# 970                7.83                7.69                7.14
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 1                  9.23                 8.45                 8.92
# 10                 8.85                 8.85                 9.29
# 25                 1.85                 1.85                 1.86
# 34                 8.69                 8.65                 8.85
# 39                 9.49                 9.08                 9.01
# ..                  ...                  ...                  ...
# 966                6.43                 5.83                 5.46
# 967                8.11                 7.85                 7.35
# 968                6.89                 6.45                 6.17
# 969                5.39                 5.19                 5.69
# 970                8.75                 8.17                 7.25
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 1                   9.15                 8.50                 8.42
# 10                  9.51                 8.80                 8.15
# 25                  1.49                 1.20                 1.25
# 34                  9.17                 8.60                 8.48
# 39                  9.13                 9.10                 9.05
# ..                   ...                  ...                  ...
# 966                 6.53                 5.43                 5.83
# 967                 8.13                 7.67                 7.19
# 968                 6.85                 6.35                 6.67
# 969                 5.93                 5.91                 5.46
# 970                 8.27                 7.13                 7.72
#
#      similarity_score_15
# 1                    NaN
# 10                   NaN
# 25                   NaN
# 34                   NaN
# 39                   NaN
# ..                   ...
# 966                  NaN
# 967                  NaN
# 968                  NaN
# 969                  NaN
# 970                  NaN
#
# [88 rows x 17 columns]

# %%
# Extract missing word pairs
missing_word_pair_list = list(zip(rows_with_null['word1'], rows_with_null['word2']))

# Show results
missing_word_pair_list
# Out:
# [('hard', 'difficult'),
#  ('bad', 'awful'),
#  ('happy', 'angry'),
#  ('bad', 'immoral'),
#  ('confident', 'sure'),
#  ('steak', 'meat'),
#  ('nail', 'thumb'),
#  ('band', 'orchestra'),
#  ('book', 'bible'),
#  ('business', 'industry'),
#  ('winter', 'season'),
#  ('decade', 'century'),
#  ('alcohol', 'gin'),
#  ('hat', 'coat'),
#  ('window', 'door'),
#  ('house', 'apartment'),
#  ('bread', 'flour'),
#  ('church', 'choir'),
#  ('metal', 'aluminum'),
#  ('cloud', 'fog'),
#  ('bed', 'blanket'),
#  ('clothes', 'fabric'),
#  ('communication', 'language'),
#  ('shore', 'coast'),
#  ('bed', 'crib'),
#  ('competence', 'ability'),
#  ('cloud', 'haze'),
#  ('grass', 'moss'),
#  ('newspaper', 'magazine'),
#  ('word', 'newspaper'),
#  ('newspaper', 'journal'),
#  ('newspaper', 'writer'),
#  ('newspaper', 'news'),
#  ('cent', 'size'),
#  ('mouse', 'management'),
#  ('task', 'straw'),
#  ('course', 'stomach'),
#  ('hymn', 'straw'),
#  ('wife', 'straw'),
#  ('apple', 'sunshine'),
#  ('stomach', 'vein'),
#  ('cent', 'ize'),
#  ('mouse', 'anagement'),
#  ('task', 'traw'),
#  ('course', 'tomach'),
#  ('hymn', 'traw'),
#  ('wife', 'traw'),
#  ('apple', 'unshine'),
#  ('stomach', 'ein'),
#  ('argue', 'persuade'),
#  ('pursue', 'persuade'),
#  ('accept', 'forgive'),
#  ('do', 'quit'),
#  ('investigate', 'examine'),
#  ('discuss', 'explain'),
#  ('owe', 'lend'),
#  ('explore', 'discover'),
#  ('complain', 'argue'),
#  ('withdraw', 'reject'),
#  ('keep', 'borrow'),
#  ('beg', 'ask'),
#  ('arrange', 'organize'),
#  ('reduce', 'shrink'),
#  ('speak', 'acknowledge'),
#  ('give', 'borrow'),
#  ('kill', 'defend'),
#  ('disappear', 'shrink'),
#  ('deliver', 'carry'),
#  ('breathe', 'choke'),
#  ('acknowledge', 'notify'),
#  ('become', 'seem'),
#  ('pretend', 'seem'),
#  ('accomplish', 'become'),
#  ('contemplate', 'think'),
#  ('determine', 'predict'),
#  ('please', 'entertain'),
#  ('remain', 'retain'),
#  ('pretend', 'portray'),
#  ('forget', 'retain'),
#  ('want', 'choose'),
#  ('lose', 'get'),
#  ('try', 'think'),
#  ('become', 'appear'),
#  ('leave', 'ignore'),
#  ('accept', 'recommend'),
#  ('leave', 'wander'),
#  ('keep', 'give'),
#  ('give', 'allow')]

# %%
# Define file_path
file_path = '../../../data/prompt/en/llama-3.3-70b/f2.csv'

# Check if file already exists
if not os.path.exists(file_path):
    df.to_csv(file_path, index=False)
    print("File saved successfully.")
else:
    print("File already exists. Dataframe was not saved to prevent overwriting.")
