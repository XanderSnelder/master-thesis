# %% [markdown]
# ### **0. Set-up**

# %%
# Import libraries and utils
# %run '../../utils.ipynb'

# %%
# Get api key
load_dotenv()
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

# Set client
client = OpenAI()

# %%
# Load dataframe
en_simlex = pd.read_csv("../../../data/dataset/cleaned-en-simlex-999.csv")

# Remove first three word pairs
en_simlex = en_simlex.iloc[3:]

# Select subset
# en_simlex = en_simlex.head(70)

# Convert to tuple
tuples_list = list(zip(en_simlex['word1'], en_simlex['word2']))

# %%
# Show results
tuples_list
# Out:
# [('happy', 'cheerful'),
#  ('hard', 'easy'),
#  ('fast', 'rapid'),
#  ('happy', 'glad'),
#  ('short', 'long'),
#  ('stupid', 'dumb'),
#  ('weird', 'strange'),
#  ('wide', 'narrow'),
#  ('bad', 'awful'),
#  ('easy', 'difficult'),
#  ('bad', 'terrible'),
#  ('hard', 'simple'),
#  ('smart', 'dumb'),
#  ('insane', 'crazy'),
#  ('happy', 'mad'),
#  ('large', 'huge'),
#  ('hard', 'tough'),
#  ('new', 'fresh'),
#  ('sharp', 'dull'),
#  ('quick', 'rapid'),
#  ('dumb', 'foolish'),
#  ('wonderful', 'terrific'),
#  ('strange', 'odd'),
#  ('happy', 'angry'),
#  ('narrow', 'broad'),
#  ('simple', 'easy'),
#  ('old', 'fresh'),
#  ('apparent', 'obvious'),
#  ('inexpensive', 'cheap'),
#  ('nice', 'generous'),
#  ('weird', 'normal'),
#  ('weird', 'odd'),
#  ('bad', 'immoral'),
#  ('sad', 'funny'),
#  ('wonderful', 'great'),
#  ('guilty', 'ashamed'),
#  ('beautiful', 'wonderful'),
#  ('confident', 'sure'),
#  ('dumb', 'dense'),
#  ('large', 'big'),
#  ('nice', 'cruel'),
#  ('impatient', 'anxious'),
#  ('big', 'broad'),
#  ('strong', 'proud'),
#  ('unnecessary', 'necessary'),
#  ('restless', 'young'),
#  ('dumb', 'intelligent'),
#  ('bad', 'great'),
#  ('difficult', 'simple'),
#  ('necessary', 'important'),
#  ('bad', 'terrific'),
#  ('mad', 'glad'),
#  ('honest', 'guilty'),
#  ('easy', 'tough'),
#  ('easy', 'flexible'),
#  ('certain', 'sure'),
#  ('essential', 'necessary'),
#  ('different', 'normal'),
#  ('sly', 'clever'),
#  ('crucial', 'important'),
#  ('harsh', 'cruel'),
#  ('childish', 'foolish'),
#  ('scarce', 'rare'),
#  ('friendly', 'generous'),
#  ('fragile', 'frigid'),
#  ('long', 'narrow'),
#  ('big', 'heavy'),
#  ('rough', 'frigid'),
#  ('bizarre', 'strange'),
#  ('illegal', 'immoral'),
#  ('bad', 'guilty'),
#  ('modern', 'ancient'),
#  ('new', 'ancient'),
#  ('dull', 'funny'),
#  ('happy', 'young'),
#  ('easy', 'big'),
#  ('great', 'awful'),
#  ('tiny', 'huge'),
#  ('polite', 'proper'),
#  ('modest', 'ashamed'),
#  ('exotic', 'rare'),
#  ('dumb', 'clever'),
#  ('delightful', 'wonderful'),
#  ('noticeable', 'obvious'),
#  ('afraid', 'anxious'),
#  ('formal', 'proper'),
#  ('dreary', 'dull'),
#  ('delightful', 'cheerful'),
#  ('unhappy', 'mad'),
#  ('sad', 'terrible'),
#  ('sick', 'crazy'),
#  ('violent', 'angry'),
#  ('laden', 'heavy'),
#  ('dirty', 'cheap'),
#  ('elastic', 'flexible'),
#  ('hard', 'dense'),
#  ('recent', 'new'),
#  ('bold', 'proud'),
#  ('sly', 'strange'),
#  ('strange', 'sly'),
#  ('dumb', 'rare'),
#  ('sly', 'tough'),
#  ('terrific', 'mad'),
#  ('modest', 'flexible'),
#  ('fresh', 'wide'),
#  ('huge', 'dumb'),
#  ('large', 'flexible'),
#  ('dirty', 'narrow'),
#  ('wife', 'husband'),
#  ('book', 'text'),
#  ('groom', 'bride'),
#  ('night', 'day'),
#  ('south', 'north'),
#  ('plane', 'airport'),
#  ('uncle', 'aunt'),
#  ('horse', 'mare'),
#  ('bottom', 'top'),
#  ('friend', 'buddy'),
#  ('student', 'pupil'),
#  ('world', 'globe'),
#  ('leg', 'arm'),
#  ('plane', 'jet'),
#  ('woman', 'man'),
#  ('horse', 'colt'),
#  ('actress', 'actor'),
#  ('teacher', 'instructor'),
#  ('movie', 'film'),
#  ('bird', 'hawk'),
#  ('word', 'dictionary'),
#  ('money', 'salary'),
#  ('dog', 'cat'),
#  ('area', 'region'),
#  ('navy', 'army'),
#  ('book', 'literature'),
#  ('clothes', 'closet'),
#  ('sunset', 'sunrise'),
#  ('child', 'adult'),
#  ('cow', 'cattle'),
#  ('book', 'story'),
#  ('winter', 'summer'),
#  ('taxi', 'cab'),
#  ('tree', 'maple'),
#  ('bed', 'bedroom'),
#  ('roof', 'ceiling'),
#  ('disease', 'infection'),
#  ('arm', 'shoulder'),
#  ('sheep', 'lamb'),
#  ('lady', 'gentleman'),
#  ('boat', 'anchor'),
#  ('priest', 'monk'),
#  ('toe', 'finger'),
#  ('river', 'stream'),
#  ('anger', 'fury'),
#  ('date', 'calendar'),
#  ('sea', 'ocean'),
#  ('second', 'minute'),
#  ('hand', 'thumb'),
#  ('wood', 'log'),
#  ('mud', 'dirt'),
#  ('hallway', 'corridor'),
#  ('way', 'manner'),
#  ('mouse', 'cat'),
#  ('cop', 'sheriff'),
#  ('death', 'burial'),
#  ('music', 'melody'),
#  ('beer', 'alcohol'),
#  ('mouth', 'lip'),
#  ('storm', 'hurricane'),
#  ('tax', 'income'),
#  ('flower', 'violet'),
#  ('paper', 'cardboard'),
#  ('floor', 'ceiling'),
#  ('beach', 'seashore'),
#  ('rod', 'curtain'),
#  ('hound', 'fox'),
#  ('street', 'alley'),
#  ('boat', 'deck'),
#  ('car', 'horn'),
#  ('friend', 'guest'),
#  ('employer', 'employee'),
#  ('hand', 'wrist'),
#  ('ball', 'cannon'),
#  ('alcohol', 'brandy'),
#  ('victory', 'triumph'),
#  ('telephone', 'booth'),
#  ('door', 'doorway'),
#  ('motel', 'inn'),
#  ('clothes', 'cloth'),
#  ('steak', 'meat'),
#  ('nail', 'thumb'),
#  ('band', 'orchestra'),
#  ('book', 'bible'),
#  ('business', 'industry'),
#  ('winter', 'season'),
#  ('decade', 'century'),
#  ('alcohol', 'gin'),
#  ('hat', 'coat'),
#  ('window', 'door'),
#  ('arm', 'wrist'),
#  ('house', 'apartment'),
#  ('glass', 'crystal'),
#  ('wine', 'brandy'),
#  ('creator', 'maker'),
#  ('dinner', 'breakfast'),
#  ('arm', 'muscle'),
#  ('bubble', 'suds'),
#  ('bread', 'flour'),
#  ('death', 'tragedy'),
#  ('absence', 'presence'),
#  ('gun', 'cannon'),
#  ('grass', 'blade'),
#  ('ball', 'basket'),
#  ('hose', 'garden'),
#  ('boy', 'kid'),
#  ('church', 'choir'),
#  ('clothes', 'drawer'),
#  ('tower', 'bell'),
#  ('father', 'parent'),
#  ('school', 'grade'),
#  ('parent', 'adult'),
#  ('bar', 'jail'),
#  ('car', 'highway'),
#  ('dictionary', 'definition'),
#  ('door', 'cellar'),
#  ('army', 'legion'),
#  ('metal', 'aluminum'),
#  ('chair', 'bench'),
#  ('cloud', 'fog'),
#  ('boy', 'son'),
#  ('water', 'ice'),
#  ('bed', 'blanket'),
#  ('attorney', 'lawyer'),
#  ('area', 'zone'),
#  ('business', 'company'),
#  ('clothes', 'fabric'),
#  ('sweater', 'jacket'),
#  ('money', 'capital'),
#  ('hand', 'foot'),
#  ('alcohol', 'cocktail'),
#  ('yard', 'inch'),
#  ('molecule', 'atom'),
#  ('lens', 'camera'),
#  ('meal', 'dinner'),
#  ('eye', 'tear'),
#  ('god', 'devil'),
#  ('loop', 'belt'),
#  ('rat', 'mouse'),
#  ('motor', 'engine'),
#  ('car', 'cab'),
#  ('cat', 'lion'),
#  ('size', 'magnitude'),
#  ('reality', 'fantasy'),
#  ('door', 'gate'),
#  ('cat', 'pet'),
#  ('tin', 'aluminum'),
#  ('bone', 'jaw'),
#  ('cereal', 'wheat'),
#  ('house', 'key'),
#  ('blood', 'flesh'),
#  ('door', 'corridor'),
#  ('god', 'spirit'),
#  ('capability', 'competence'),
#  ('abundance', 'plenty'),
#  ('sofa', 'chair'),
#  ('wall', 'brick'),
#  ('horn', 'drum'),
#  ('organ', 'liver'),
#  ('strength', 'might'),
#  ('phrase', 'word'),
#  ('band', 'parade'),
#  ('stomach', 'waist'),
#  ('cloud', 'storm'),
#  ('joy', 'pride'),
#  ('noise', 'rattle'),
#  ('rain', 'mist'),
#  ('beer', 'beverage'),
#  ('man', 'uncle'),
#  ('apple', 'juice'),
#  ('intelligence', 'logic'),
#  ('communication', 'language'),
#  ('mink', 'fur'),
#  ('mob', 'crowd'),
#  ('shore', 'coast'),
#  ('wire', 'cord'),
#  ('bird', 'turkey'),
#  ('bed', 'crib'),
#  ('competence', 'ability'),
#  ('cloud', 'haze'),
#  ('supper', 'meal'),
#  ('bar', 'cage'),
#  ('water', 'salt'),
#  ('sense', 'intuition'),
#  ('situation', 'condition'),
#  ('crime', 'theft'),
#  ('style', 'fashion'),
#  ('boundary', 'border'),
#  ('arm', 'body'),
#  ('boat', 'car'),
#  ('sandwich', 'lunch'),
#  ('bride', 'princess'),
#  ('heroine', 'hero'),
#  ('car', 'gauge'),
#  ('insect', 'bee'),
#  ('crib', 'cradle'),
#  ('animal', 'person'),
#  ('marijuana', 'herb'),
#  ('bed', 'hospital'),
#  ('cheek', 'tongue'),
#  ('disc', 'computer'),
#  ('curve', 'angle'),
#  ('grass', 'moss'),
#  ('school', 'law'),
#  ('foot', 'head'),
#  ('mother', 'guardian'),
#  ('orthodontist', 'dentist'),
#  ('alcohol', 'whiskey'),
#  ('mouth', 'tooth'),
#  ('breakfast', 'bacon'),
#  ('bathroom', 'bedroom'),
#  ('plate', 'bowl'),
#  ('meat', 'bacon'),
#  ('air', 'helium'),
#  ('worker', 'employer'),
#  ('body', 'chest'),
#  ('son', 'father'),
#  ('heart', 'surgery'),
#  ('woman', 'secretary'),
#  ('man', 'father'),
#  ('beach', 'island'),
#  ('story', 'topic'),
#  ('game', 'fun'),
#  ('weekend', 'week'),
#  ('couple', 'pair'),
#  ('woman', 'wife'),
#  ('sheep', 'cattle'),
#  ('purse', 'bag'),
#  ('ceiling', 'cathedral'),
#  ('bean', 'coffee'),
#  ('wood', 'paper'),
#  ('top', 'side'),
#  ('crime', 'fraud'),
#  ('pain', 'harm'),
#  ('lover', 'companion'),
#  ('evening', 'dusk'),
#  ('father', 'daughter'),
#  ('wine', 'liquor'),
#  ('cow', 'goat'),
#  ('belief', 'opinion'),
#  ('reality', 'illusion'),
#  ('pact', 'agreement'),
#  ('wealth', 'poverty'),
#  ('accident', 'emergency'),
#  ('battle', 'conquest'),
#  ('friend', 'teacher'),
#  ('illness', 'infection'),
#  ('game', 'trick'),
#  ('brother', 'son'),
#  ('aunt', 'nephew'),
#  ('worker', 'mechanic'),
#  ('doctor', 'orthodontist'),
#  ('oak', 'maple'),
#  ('bee', 'queen'),
#  ('car', 'bicycle'),
#  ('goal', 'quest'),
#  ('august', 'month'),
#  ('army', 'squad'),
#  ('cloud', 'weather'),
#  ('physician', 'doctor'),
#  ('canyon', 'valley'),
#  ('river', 'valley'),
#  ('sun', 'sky'),
#  ('target', 'arrow'),
#  ('chocolate', 'pie'),
#  ('circumstance', 'situation'),
#  ('opinion', 'choice'),
#  ('rhythm', 'melody'),
#  ('gut', 'nerve'),
#  ('day', 'dawn'),
#  ('cattle', 'beef'),
#  ('doctor', 'professor'),
#  ('arm', 'vein'),
#  ('room', 'bath'),
#  ('corporation', 'business'),
#  ('fun', 'football'),
#  ('hill', 'cliff'),
#  ('bone', 'ankle'),
#  ('apple', 'candy'),
#  ('helper', 'maid'),
#  ('leader', 'manager'),
#  ('lemon', 'tea'),
#  ('bee', 'ant'),
#  ('basketball', 'baseball'),
#  ('rice', 'bean'),
#  ('bed', 'furniture'),
#  ('emotion', 'passion'),
#  ('anarchy', 'chaos'),
#  ('crime', 'violation'),
#  ('machine', 'engine'),
#  ('beach', 'sea'),
#  ('alley', 'bowl'),
#  ('jar', 'bottle'),
#  ('strength', 'capability'),
#  ('seed', 'mustard'),
#  ('guitar', 'drum'),
#  ('opinion', 'idea'),
#  ('north', 'west'),
#  ('diet', 'salad'),
#  ('mother', 'wife'),
#  ('dad', 'mother'),
#  ('captain', 'sailor'),
#  ('meter', 'yard'),
#  ('beer', 'champagne'),
#  ('motor', 'boat'),
#  ('card', 'bridge'),
#  ('science', 'psychology'),
#  ('sinner', 'saint'),
#  ('destruction', 'construction'),
#  ('crowd', 'bunch'),
#  ('beach', 'reef'),
#  ('man', 'child'),
#  ('bread', 'cheese'),
#  ('champion', 'winner'),
#  ('celebration', 'ceremony'),
#  ('menu', 'order'),
#  ('king', 'princess'),
#  ('wealth', 'prestige'),
#  ('endurance', 'strength'),
#  ('danger', 'threat'),
#  ('god', 'priest'),
#  ('men', 'fraternity'),
#  ('buddy', 'companion'),
#  ('teacher', 'helper'),
#  ('body', 'stomach'),
#  ('tongue', 'throat'),
#  ('house', 'carpet'),
#  ('intelligence', 'skill'),
#  ('journey', 'conquest'),
#  ('god', 'prey'),
#  ('brother', 'soul'),
#  ('adversary', 'opponent'),
#  ('death', 'catastrophe'),
#  ('monster', 'demon'),
#  ('day', 'morning'),
#  ('man', 'victor'),
#  ('friend', 'guy'),
#  ('song', 'story'),
#  ('ray', 'sunshine'),
#  ('guy', 'stud'),
#  ('chicken', 'rice'),
#  ('box', 'elevator'),
#  ('butter', 'potato'),
#  ('apartment', 'furniture'),
#  ('lake', 'swamp'),
#  ('salad', 'vinegar'),
#  ('flower', 'bulb'),
#  ('cloud', 'mist'),
#  ('driver', 'pilot'),
#  ('sugar', 'honey'),
#  ('body', 'shoulder'),
#  ('idea', 'image'),
#  ('father', 'brother'),
#  ('moon', 'planet'),
#  ('ball', 'costume'),
#  ('rail', 'fence'),
#  ('room', 'bed'),
#  ('flower', 'bush'),
#  ('bone', 'knee'),
#  ('arm', 'knee'),
#  ('bottom', 'side'),
#  ('vessel', 'vein'),
#  ('cat', 'rabbit'),
#  ('meat', 'sandwich'),
#  ('belief', 'concept'),
#  ('intelligence', 'insight'),
#  ('attention', 'interest'),
#  ('attitude', 'confidence'),
#  ('right', 'justice'),
#  ('argument', 'agreement'),
#  ('depth', 'magnitude'),
#  ('medium', 'news'),
#  ('winner', 'candidate'),
#  ('birthday', 'date'),
#  ('fee', 'payment'),
#  ('bible', 'hymn'),
#  ('exit', 'doorway'),
#  ('man', 'sentry'),
#  ('aisle', 'hall'),
#  ('whiskey', 'gin'),
#  ('blood', 'marrow'),
#  ('oil', 'mink'),
#  ('floor', 'deck'),
#  ('roof', 'floor'),
#  ('door', 'floor'),
#  ('shoulder', 'head'),
#  ('wagon', 'carriage'),
#  ('car', 'carriage'),
#  ('elbow', 'ankle'),
#  ('wealth', 'fame'),
#  ('sorrow', 'shame'),
#  ('administration', 'management'),
#  ('communication', 'conversation'),
#  ('pollution', 'atmosphere'),
#  ('anatomy', 'biology'),
#  ('college', 'profession'),
#  ('book', 'topic'),
#  ('formula', 'equation'),
#  ('book', 'information'),
#  ('boy', 'partner'),
#  ('sky', 'universe'),
#  ('population', 'people'),
#  ('college', 'class'),
#  ('chief', 'mayor'),
#  ('rabbi', 'minister'),
#  ('meter', 'inch'),
#  ('polyester', 'cotton'),
#  ('lawyer', 'banker'),
#  ('violin', 'instrument'),
#  ('camp', 'cabin'),
#  ('pot', 'appliance'),
#  ('linen', 'fabric'),
#  ('whiskey', 'champagne'),
#  ('girl', 'child'),
#  ('cottage', 'cabin'),
#  ('bird', 'hen'),
#  ('racket', 'noise'),
#  ('sunset', 'evening'),
#  ('drizzle', 'rain'),
#  ('adult', 'baby'),
#  ('charcoal', 'coal'),
#  ('body', 'spine'),
#  ('head', 'nail'),
#  ('log', 'timber'),
#  ('spoon', 'cup'),
#  ('body', 'nerve'),
#  ('man', 'husband'),
#  ('bone', 'neck'),
#  ('frustration', 'anger'),
#  ('river', 'sea'),
#  ('task', 'job'),
#  ('club', 'society'),
#  ('reflection', 'image'),
#  ('prince', 'king'),
#  ('snow', 'weather'),
#  ('people', 'party'),
#  ('boy', 'brother'),
#  ('root', 'grass'),
#  ('brow', 'eye'),
#  ('money', 'pearl'),
#  ('money', 'diamond'),
#  ('vehicle', 'bus'),
#  ('cab', 'bus'),
#  ('house', 'barn'),
#  ('finger', 'palm'),
#  ('car', 'bridge'),
#  ('effort', 'difficulty'),
#  ('fact', 'insight'),
#  ('job', 'management'),
#  ('cancer', 'sickness'),
#  ('word', 'newspaper'),
#  ('composer', 'writer'),
#  ('actor', 'singer'),
#  ('shelter', 'hut'),
#  ('bathroom', 'kitchen'),
#  ('cabin', 'hut'),
#  ('door', 'kitchen'),
#  ('value', 'belief'),
#  ('wisdom', 'intelligence'),
#  ('ignorance', 'intelligence'),
#  ('happiness', 'luck'),
#  ('idea', 'scheme'),
#  ('mood', 'emotion'),
#  ('happiness', 'peace'),
#  ('despair', 'misery'),
#  ('logic', 'arithmetic'),
#  ('denial', 'confession'),
#  ('argument', 'criticism'),
#  ('aggression', 'hostility'),
#  ('hysteria', 'confusion'),
#  ('chemistry', 'theory'),
#  ('trial', 'verdict'),
#  ('comfort', 'safety'),
#  ('confidence', 'self'),
#  ('vision', 'perception'),
#  ('era', 'decade'),
#  ('biography', 'fiction'),
#  ('discussion', 'argument'),
#  ('code', 'symbol'),
#  ('danger', 'disease'),
#  ('accident', 'catastrophe'),
#  ('journey', 'trip'),
#  ('activity', 'movement'),
#  ('gossip', 'news'),
#  ('father', 'god'),
#  ('action', 'course'),
#  ('fever', 'illness'),
#  ('aviation', 'flight'),
#  ('game', 'action'),
#  ('molecule', 'air'),
#  ('home', 'state'),
#  ('word', 'literature'),
#  ('adult', 'guardian'),
#  ('newspaper', 'information'),
#  ('communication', 'television'),
#  ('cousin', 'uncle'),
#  ('author', 'reader'),
#  ('guy', 'partner'),
#  ('area', 'corner'),
#  ('ballad', 'song'),
#  ('wall', 'decoration'),
#  ('word', 'page'),
#  ('nurse', 'scientist'),
#  ('politician', 'president'),
#  ('president', 'mayor'),
#  ('book', 'essay'),
#  ('man', 'warrior'),
#  ('article', 'journal'),
#  ('breakfast', 'supper'),
#  ('crowd', 'parade'),
#  ('aisle', 'hallway'),
#  ('teacher', 'rabbi'),
#  ('hip', 'lip'),
#  ('book', 'article'),
#  ('room', 'cell'),
#  ('box', 'booth'),
#  ('daughter', 'kid'),
#  ('limb', 'leg'),
#  ('liver', 'lung'),
#  ('classroom', 'hallway'),
#  ('mountain', 'ledge'),
#  ('car', 'elevator'),
#  ('bed', 'couch'),
#  ('clothes', 'button'),
#  ('clothes', 'coat'),
#  ('kidney', 'organ'),
#  ('apple', 'sauce'),
#  ('chicken', 'steak'),
#  ('car', 'hose'),
#  ('tobacco', 'cigarette'),
#  ('student', 'professor'),
#  ('baby', 'daughter'),
#  ('pipe', 'cigar'),
#  ('milk', 'juice'),
#  ('box', 'cigar'),
#  ('apartment', 'hotel'),
#  ('cup', 'cone'),
#  ('horse', 'ox'),
#  ('throat', 'nose'),
#  ('bone', 'teeth'),
#  ('bone', 'elbow'),
#  ('bacon', 'bean'),
#  ('cup', 'jar'),
#  ('proof', 'fact'),
#  ('appointment', 'engagement'),
#  ('birthday', 'year'),
#  ('word', 'clue'),
#  ('author', 'creator'),
#  ('atom', 'carbon'),
#  ('archbishop', 'bishop'),
#  ('letter', 'paragraph'),
#  ('page', 'paragraph'),
#  ('steeple', 'chapel'),
#  ('muscle', 'bone'),
#  ('muscle', 'tongue'),
#  ('boy', 'soldier'),
#  ('belly', 'abdomen'),
#  ('guy', 'girl'),
#  ('bed', 'chair'),
#  ('clothes', 'jacket'),
#  ('gun', 'knife'),
#  ('tin', 'metal'),
#  ('bottle', 'container'),
#  ('hen', 'turkey'),
#  ('meat', 'bread'),
#  ('arm', 'bone'),
#  ('neck', 'spine'),
#  ('apple', 'lemon'),
#  ('agony', 'grief'),
#  ('assignment', 'task'),
#  ('night', 'dawn'),
#  ('dinner', 'soup'),
#  ('calf', 'bull'),
#  ('snow', 'storm'),
#  ('nail', 'hand'),
#  ('dog', 'horse'),
#  ('arm', 'neck'),
#  ('ball', 'glove'),
#  ('flu', 'fever'),
#  ('fee', 'salary'),
#  ('nerve', 'brain'),
#  ('beast', 'animal'),
#  ('dinner', 'chicken'),
#  ('girl', 'maid'),
#  ('child', 'boy'),
#  ('alcohol', 'wine'),
#  ('nose', 'mouth'),
#  ('street', 'car'),
#  ('bell', 'door'),
#  ('box', 'hat'),
#  ('belief', 'impression'),
#  ('bias', 'opinion'),
#  ('attention', 'awareness'),
#  ('anger', 'mood'),
#  ('elegance', 'style'),
#  ('beauty', 'age'),
#  ('book', 'theme'),
#  ('friend', 'mother'),
#  ('vitamin', 'iron'),
#  ('car', 'factory'),
#  ('pact', 'condition'),
#  ('chapter', 'choice'),
#  ('arithmetic', 'rhythm'),
#  ('winner', 'presence'),
#  ('belief', 'flower'),
#  ('winner', 'goal'),
#  ('trick', 'size'),
#  ('choice', 'vein'),
#  ('hymn', 'conquest'),
#  ('endurance', 'band'),
#  ('jail', 'choice'),
#  ('condition', 'boy'),
#  ('flower', 'endurance'),
#  ('hole', 'agreement'),
#  ('doctor', 'temper'),
#  ('fraternity', 'door'),
#  ('task', 'woman'),
#  ('fraternity', 'baseball'),
#  ('cent', 'size'),
#  ('presence', 'door'),
#  ('mouse', 'management'),
#  ('task', 'highway'),
#  ('liquor', 'century'),
#  ('task', 'straw'),
#  ('island', 'task'),
#  ('night', 'chapter'),
#  ('pollution', 'president'),
#  ('gun', 'trick'),
#  ('bath', 'trick'),
#  ('diet', 'apple'),
#  ('cent', 'wife'),
#  ('chapter', 'tail'),
#  ('course', 'stomach'),
#  ('hymn', 'straw'),
#  ('dentist', 'colonel'),
#  ('wife', 'straw'),
#  ('hole', 'wife'),
#  ('pupil', 'president'),
#  ('bath', 'wife'),
#  ('people', 'cent'),
#  ('formula', 'log'),
#  ('woman', 'fur'),
#  ('apple', 'sunshine'),
#  ('gun', 'dawn'),
#  ('meal', 'waist'),
#  ('camera', 'president'),
#  ('liquor', 'band'),
#  ('stomach', 'vein'),
#  ('gun', 'fur'),
#  ('couch', 'baseball'),
#  ('worker', 'camera'),
#  ('deck', 'mouse'),
#  ('rice', 'boy'),
#  ('people', 'gun'),
#  ('cliff', 'tail'),
#  ('ankle', 'window'),
#  ('princess', 'island'),
#  ('container', 'mouse'),
#  ('wagon', 'container'),
#  ('people', 'balloon'),
#  ('dollar', 'people'),
#  ('bath', 'balloon'),
#  ('stomach', 'bedroom'),
#  ('bicycle', 'bedroom'),
#  ('log', 'bath'),
#  ('bowl', 'tail'),
#  ('go', 'come'),
#  ('take', 'steal'),
#  ('listen', 'hear'),
#  ('think', 'rationalize'),
#  ('occur', 'happen'),
#  ('vanish', 'disappear'),
#  ('multiply', 'divide'),
#  ('plead', 'beg'),
#  ('begin', 'originate'),
#  ('protect', 'defend'),
#  ('kill', 'destroy'),
#  ('create', 'make'),
#  ('accept', 'reject'),
#  ('ignore', 'avoid'),
#  ('carry', 'bring'),
#  ('leave', 'enter'),
#  ('choose', 'elect'),
#  ('lose', 'fail'),
#  ('encourage', 'discourage'),
#  ('achieve', 'accomplish'),
#  ('make', 'construct'),
#  ('listen', 'obey'),
#  ('inform', 'notify'),
#  ('receive', 'give'),
#  ('borrow', 'beg'),
#  ('take', 'obtain'),
#  ('advise', 'recommend'),
#  ('imitate', 'portray'),
#  ('win', 'succeed'),
#  ('think', 'decide'),
#  ('greet', 'meet'),
#  ('agree', 'argue'),
#  ('enjoy', 'entertain'),
#  ('destroy', 'make'),
#  ('save', 'protect'),
#  ('give', 'lend'),
#  ('understand', 'know'),
#  ('take', 'receive'),
#  ('accept', 'acknowledge'),
#  ('decide', 'choose'),
#  ('accept', 'believe'),
#  ('keep', 'possess'),
#  ('roam', 'wander'),
#  ('succeed', 'fail'),
#  ('spend', 'save'),
#  ('leave', 'go'),
#  ('come', 'attend'),
#  ('know', 'believe'),
#  ('gather', 'meet'),
#  ('make', 'earn'),
#  ('forget', 'ignore'),
#  ('multiply', 'add'),
#  ('shrink', 'grow'),
#  ('arrive', 'leave'),
#  ('succeed', 'try'),
#  ('accept', 'deny'),
#  ('arrive', 'come'),
#  ('agree', 'differ'),
#  ('send', 'receive'),
#  ('win', 'dominate'),
#  ('add', 'divide'),
#  ('kill', 'choke'),
#  ('acquire', 'get'),
#  ('participate', 'join'),
#  ('leave', 'remain'),
#  ('go', 'enter'),
#  ('take', 'carry'),
#  ('forget', 'learn'),
#  ('appoint', 'elect'),
#  ('engage', 'marry'),
#  ('ask', 'pray'),
#  ('go', 'send'),
#  ('take', 'deliver'),
#  ('speak', 'hear'),
#  ('analyze', 'evaluate'),
#  ('argue', 'rationalize'),
#  ('lose', 'keep'),
#  ('compare', 'analyze'),
#  ('disorganize', 'organize'),
#  ('go', 'allow'),
#  ('take', 'possess'),
#  ('learn', 'listen'),
#  ('destroy', 'construct'),
#  ('create', 'build'),
#  ('steal', 'buy'),
#  ('kill', 'hang'),
#  ('forget', 'know'),
#  ('create', 'imagine'),
#  ('do', 'happen'),
#  ('win', 'accomplish'),
#  ('give', 'deny'),
#  ('deserve', 'earn'),
#  ('get', 'put'),
#  ('locate', 'find'),
#  ('appear', 'attend'),
#  ('know', 'comprehend'),
#  ('pretend', 'imagine'),
#  ('satisfy', 'please'),
#  ('cherish', 'keep'),
#  ('argue', 'differ'),
#  ('overcome', 'dominate'),
#  ('behave', 'obey'),
#  ('cooperate', 'participate'),
#  ('achieve', 'try'),
#  ('fail', 'discourage'),
#  ('begin', 'quit'),
#  ('say', 'participate'),
#  ('come', 'bring'),
#  ('declare', 'announce'),
#  ('read', 'comprehend'),
#  ('take', 'leave'),
#  ('proclaim', 'announce'),
#  ('acquire', 'obtain'),
#  ('conclude', 'decide'),
#  ('please', 'plead'),
#  ('argue', 'prove'),
#  ('ask', 'plead'),
#  ('find', 'disappear'),
#  ('inspect', 'examine'),
#  ('verify', 'justify'),
#  ('assume', 'predict'),
#  ('learn', 'evaluate'),
#  ('argue', 'justify'),
#  ('make', 'become'),
#  ('discover', 'originate'),
#  ('achieve', 'succeed'),
#  ('give', 'put'),
#  ('understand', 'listen'),
#  ('expand', 'grow'),
#  ('borrow', 'sell'),
#  ('keep', 'protect'),
#  ('explain', 'prove'),
#  ('assume', 'pretend'),
#  ('agree', 'please'),
#  ('forgive', 'forget'),
#  ('clarify', 'explain'),
#  ('understand', 'forgive'),
#  ('remind', 'forget'),
#  ('get', 'remain'),
#  ('realize', 'discover'),
#  ('require', 'inquire'),
#  ('ignore', 'ask'),
#  ('think', 'inquire'),
#  ('reject', 'avoid'),
#  ('argue', 'persuade'),
#  ('pursue', 'persuade'),
#  ('accept', 'forgive'),
#  ('do', 'quit'),
#  ('investigate', 'examine'),
#  ('discuss', 'explain'),
#  ('owe', 'lend'),
#  ('explore', 'discover'),
#  ('complain', 'argue'),
#  ('withdraw', 'reject'),
#  ('keep', 'borrow'),
#  ('beg', 'ask'),
#  ('arrange', 'organize'),
#  ('reduce', 'shrink'),
#  ('speak', 'acknowledge'),
#  ('give', 'borrow'),
#  ('kill', 'defend'),
#  ('disappear', 'shrink'),
#  ('deliver', 'carry'),
#  ('breathe', 'choke'),
#  ('acknowledge', 'notify'),
#  ('become', 'seem'),
#  ('pretend', 'seem'),
#  ('accomplish', 'become'),
#  ('contemplate', 'think'),
#  ('determine', 'predict'),
#  ('please', 'entertain'),
#  ('remain', 'retain'),
#  ('pretend', 'portray'),
#  ('forget', 'retain'),
#  ('want', 'choose'),
#  ('lose', 'get'),
#  ('try', 'think'),
#  ('become', 'appear'),
#  ('leave', 'ignore'),
#  ('accept', 'recommend'),
#  ('leave', 'wander'),
#  ('keep', 'give'),
#  ('give', 'allow'),
#  ('bring', 'send'),
#  ('absorb', 'learn'),
#  ('acquire', 'find'),
#  ('leave', 'appear'),
#  ('create', 'destroy'),
#  ('begin', 'go'),
#  ('get', 'buy'),
#  ('collect', 'save'),
#  ('replace', 'restore'),
#  ('join', 'add'),
#  ('join', 'marry'),
#  ('accept', 'deliver'),
#  ('attach', 'join'),
#  ('put', 'hang'),
#  ('go', 'sell'),
#  ('communicate', 'pray'),
#  ('give', 'steal'),
#  ('add', 'build'),
#  ('bring', 'restore'),
#  ('comprehend', 'satisfy'),
#  ('portray', 'decide'),
#  ('organize', 'become'),
#  ('give', 'know'),
#  ('say', 'verify'),
#  ('cooperate', 'join'),
#  ('arrange', 'require'),
#  ('borrow', 'want'),
#  ('investigate', 'pursue'),
#  ('ignore', 'explore'),
#  ('bring', 'complain'),
#  ('enter', 'owe'),
#  ('portray', 'notify'),
#  ('remind', 'sell'),
#  ('absorb', 'possess'),
#  ('join', 'acquire'),
#  ('send', 'attend'),
#  ('gather', 'attend'),
#  ('absorb', 'withdraw'),
#  ('attend', 'arrive')]

# %% [markdown]
# ### **1. Define and Evaluate Parameters**

# %%
# Define prompt
prompt = ("Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity.")
user_content = ("[('old', 'new'), ('smart', 'intelligent'), ('hard', 'difficult)']")
assistant_content = ("[('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]")

# %%
# Define model
model = "gpt-3.5-turbo-0125"

# Set sample size
sample_size = 15

# Delay between individual API calls
delay = 3.0

# Define number of sublists
n_sublists = 20

# %%
# Split list
chunks = split_into_n_lists(tuples_list, n_sublists)

# Count number of lists
print(len(chunks))
# Out:
# 20

# %%
# Print prompts for each chunk
print_prompts(chunks, prompt)
# Out:
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. --- ["('happy', 'cheerful'), ('hard', 'easy'), ('fast', 'rapid'), ('happy', 'glad'), ('short', 'long'), ('stupid', 'dumb'), ('weird', 'strange'), ('wide', 'narrow'), ('bad', 'awful'), ('easy', 'difficult'), ('bad', 'terrible'), ('hard', 'simple'), ('smart', 'dumb'), ('insane', 'crazy'), ('happy', 'mad'), ('large', 'huge'), ('hard', 'tough'), ('new', 'fresh'), ('sharp', 'dull'), ('quick', 'rapid'), ('dumb', 'foolish'), ('wonderful', 'terrific'), ('strange', 'odd'), ('happy', 'angry'), ('narrow', 'broad'), ('simple', 'easy'), ('old', 'fresh'), ('apparent', 'obvious'), ('inexpensive', 'cheap'), ('nice', 'generous'), ('weird', 'normal'), ('weird', 'odd'), ('bad', 'immoral'), ('sad', 'funny'), ('wonderful', 'great'), ('guilty', 'ashamed'), ('beautiful', 'wonderful'), ('confident', 'sure'), ('dumb', 'dense'), ('large', 'big'), ('nice', 'cruel'), ('impatient', 'anxious'), ('big', 'broad'), ('strong', 'proud'), ('unnecessary', 'necessary'), ('restless', 'young'), ('dumb', 'intelligent'), ('bad', 'great'), ('difficult', 'simple'), ('necessary', 'important')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. --- ["('bad', 'terrific'), ('mad', 'glad'), ('honest', 'guilty'), ('easy', 'tough'), ('easy', 'flexible'), ('certain', 'sure'), ('essential', 'necessary'), ('different', 'normal'), ('sly', 'clever'), ('crucial', 'important'), ('harsh', 'cruel'), ('childish', 'foolish'), ('scarce', 'rare'), ('friendly', 'generous'), ('fragile', 'frigid'), ('long', 'narrow'), ('big', 'heavy'), ('rough', 'frigid'), ('bizarre', 'strange'), ('illegal', 'immoral'), ('bad', 'guilty'), ('modern', 'ancient'), ('new', 'ancient'), ('dull', 'funny'), ('happy', 'young'), ('easy', 'big'), ('great', 'awful'), ('tiny', 'huge'), ('polite', 'proper'), ('modest', 'ashamed'), ('exotic', 'rare'), ('dumb', 'clever'), ('delightful', 'wonderful'), ('noticeable', 'obvious'), ('afraid', 'anxious'), ('formal', 'proper'), ('dreary', 'dull'), ('delightful', 'cheerful'), ('unhappy', 'mad'), ('sad', 'terrible'), ('sick', 'crazy'), ('violent', 'angry'), ('laden', 'heavy'), ('dirty', 'cheap'), ('elastic', 'flexible'), ('hard', 'dense'), ('recent', 'new'), ('bold', 'proud'), ('sly', 'strange'), ('strange', 'sly')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. --- ["('dumb', 'rare'), ('sly', 'tough'), ('terrific', 'mad'), ('modest', 'flexible'), ('fresh', 'wide'), ('huge', 'dumb'), ('large', 'flexible'), ('dirty', 'narrow'), ('wife', 'husband'), ('book', 'text'), ('groom', 'bride'), ('night', 'day'), ('south', 'north'), ('plane', 'airport'), ('uncle', 'aunt'), ('horse', 'mare'), ('bottom', 'top'), ('friend', 'buddy'), ('student', 'pupil'), ('world', 'globe'), ('leg', 'arm'), ('plane', 'jet'), ('woman', 'man'), ('horse', 'colt'), ('actress', 'actor'), ('teacher', 'instructor'), ('movie', 'film'), ('bird', 'hawk'), ('word', 'dictionary'), ('money', 'salary'), ('dog', 'cat'), ('area', 'region'), ('navy', 'army'), ('book', 'literature'), ('clothes', 'closet'), ('sunset', 'sunrise'), ('child', 'adult'), ('cow', 'cattle'), ('book', 'story'), ('winter', 'summer'), ('taxi', 'cab'), ('tree', 'maple'), ('bed', 'bedroom'), ('roof', 'ceiling'), ('disease', 'infection'), ('arm', 'shoulder'), ('sheep', 'lamb'), ('lady', 'gentleman'), ('boat', 'anchor'), ('priest', 'monk')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. --- ["('toe', 'finger'), ('river', 'stream'), ('anger', 'fury'), ('date', 'calendar'), ('sea', 'ocean'), ('second', 'minute'), ('hand', 'thumb'), ('wood', 'log'), ('mud', 'dirt'), ('hallway', 'corridor'), ('way', 'manner'), ('mouse', 'cat'), ('cop', 'sheriff'), ('death', 'burial'), ('music', 'melody'), ('beer', 'alcohol'), ('mouth', 'lip'), ('storm', 'hurricane'), ('tax', 'income'), ('flower', 'violet'), ('paper', 'cardboard'), ('floor', 'ceiling'), ('beach', 'seashore'), ('rod', 'curtain'), ('hound', 'fox'), ('street', 'alley'), ('boat', 'deck'), ('car', 'horn'), ('friend', 'guest'), ('employer', 'employee'), ('hand', 'wrist'), ('ball', 'cannon'), ('alcohol', 'brandy'), ('victory', 'triumph'), ('telephone', 'booth'), ('door', 'doorway'), ('motel', 'inn'), ('clothes', 'cloth'), ('steak', 'meat'), ('nail', 'thumb'), ('band', 'orchestra'), ('book', 'bible'), ('business', 'industry'), ('winter', 'season'), ('decade', 'century'), ('alcohol', 'gin'), ('hat', 'coat'), ('window', 'door'), ('arm', 'wrist'), ('house', 'apartment')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. --- ["('glass', 'crystal'), ('wine', 'brandy'), ('creator', 'maker'), ('dinner', 'breakfast'), ('arm', 'muscle'), ('bubble', 'suds'), ('bread', 'flour'), ('death', 'tragedy'), ('absence', 'presence'), ('gun', 'cannon'), ('grass', 'blade'), ('ball', 'basket'), ('hose', 'garden'), ('boy', 'kid'), ('church', 'choir'), ('clothes', 'drawer'), ('tower', 'bell'), ('father', 'parent'), ('school', 'grade'), ('parent', 'adult'), ('bar', 'jail'), ('car', 'highway'), ('dictionary', 'definition'), ('door', 'cellar'), ('army', 'legion'), ('metal', 'aluminum'), ('chair', 'bench'), ('cloud', 'fog'), ('boy', 'son'), ('water', 'ice'), ('bed', 'blanket'), ('attorney', 'lawyer'), ('area', 'zone'), ('business', 'company'), ('clothes', 'fabric'), ('sweater', 'jacket'), ('money', 'capital'), ('hand', 'foot'), ('alcohol', 'cocktail'), ('yard', 'inch'), ('molecule', 'atom'), ('lens', 'camera'), ('meal', 'dinner'), ('eye', 'tear'), ('god', 'devil'), ('loop', 'belt'), ('rat', 'mouse'), ('motor', 'engine'), ('car', 'cab'), ('cat', 'lion')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. --- ["('size', 'magnitude'), ('reality', 'fantasy'), ('door', 'gate'), ('cat', 'pet'), ('tin', 'aluminum'), ('bone', 'jaw'), ('cereal', 'wheat'), ('house', 'key'), ('blood', 'flesh'), ('door', 'corridor'), ('god', 'spirit'), ('capability', 'competence'), ('abundance', 'plenty'), ('sofa', 'chair'), ('wall', 'brick'), ('horn', 'drum'), ('organ', 'liver'), ('strength', 'might'), ('phrase', 'word'), ('band', 'parade'), ('stomach', 'waist'), ('cloud', 'storm'), ('joy', 'pride'), ('noise', 'rattle'), ('rain', 'mist'), ('beer', 'beverage'), ('man', 'uncle'), ('apple', 'juice'), ('intelligence', 'logic'), ('communication', 'language'), ('mink', 'fur'), ('mob', 'crowd'), ('shore', 'coast'), ('wire', 'cord'), ('bird', 'turkey'), ('bed', 'crib'), ('competence', 'ability'), ('cloud', 'haze'), ('supper', 'meal'), ('bar', 'cage'), ('water', 'salt'), ('sense', 'intuition'), ('situation', 'condition'), ('crime', 'theft'), ('style', 'fashion'), ('boundary', 'border'), ('arm', 'body'), ('boat', 'car'), ('sandwich', 'lunch'), ('bride', 'princess')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. --- ["('heroine', 'hero'), ('car', 'gauge'), ('insect', 'bee'), ('crib', 'cradle'), ('animal', 'person'), ('marijuana', 'herb'), ('bed', 'hospital'), ('cheek', 'tongue'), ('disc', 'computer'), ('curve', 'angle'), ('grass', 'moss'), ('school', 'law'), ('foot', 'head'), ('mother', 'guardian'), ('orthodontist', 'dentist'), ('alcohol', 'whiskey'), ('mouth', 'tooth'), ('breakfast', 'bacon'), ('bathroom', 'bedroom'), ('plate', 'bowl'), ('meat', 'bacon'), ('air', 'helium'), ('worker', 'employer'), ('body', 'chest'), ('son', 'father'), ('heart', 'surgery'), ('woman', 'secretary'), ('man', 'father'), ('beach', 'island'), ('story', 'topic'), ('game', 'fun'), ('weekend', 'week'), ('couple', 'pair'), ('woman', 'wife'), ('sheep', 'cattle'), ('purse', 'bag'), ('ceiling', 'cathedral'), ('bean', 'coffee'), ('wood', 'paper'), ('top', 'side'), ('crime', 'fraud'), ('pain', 'harm'), ('lover', 'companion'), ('evening', 'dusk'), ('father', 'daughter'), ('wine', 'liquor'), ('cow', 'goat'), ('belief', 'opinion'), ('reality', 'illusion'), ('pact', 'agreement')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. --- ["('wealth', 'poverty'), ('accident', 'emergency'), ('battle', 'conquest'), ('friend', 'teacher'), ('illness', 'infection'), ('game', 'trick'), ('brother', 'son'), ('aunt', 'nephew'), ('worker', 'mechanic'), ('doctor', 'orthodontist'), ('oak', 'maple'), ('bee', 'queen'), ('car', 'bicycle'), ('goal', 'quest'), ('august', 'month'), ('army', 'squad'), ('cloud', 'weather'), ('physician', 'doctor'), ('canyon', 'valley'), ('river', 'valley'), ('sun', 'sky'), ('target', 'arrow'), ('chocolate', 'pie'), ('circumstance', 'situation'), ('opinion', 'choice'), ('rhythm', 'melody'), ('gut', 'nerve'), ('day', 'dawn'), ('cattle', 'beef'), ('doctor', 'professor'), ('arm', 'vein'), ('room', 'bath'), ('corporation', 'business'), ('fun', 'football'), ('hill', 'cliff'), ('bone', 'ankle'), ('apple', 'candy'), ('helper', 'maid'), ('leader', 'manager'), ('lemon', 'tea'), ('bee', 'ant'), ('basketball', 'baseball'), ('rice', 'bean'), ('bed', 'furniture'), ('emotion', 'passion'), ('anarchy', 'chaos'), ('crime', 'violation'), ('machine', 'engine'), ('beach', 'sea'), ('alley', 'bowl')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. --- ["('jar', 'bottle'), ('strength', 'capability'), ('seed', 'mustard'), ('guitar', 'drum'), ('opinion', 'idea'), ('north', 'west'), ('diet', 'salad'), ('mother', 'wife'), ('dad', 'mother'), ('captain', 'sailor'), ('meter', 'yard'), ('beer', 'champagne'), ('motor', 'boat'), ('card', 'bridge'), ('science', 'psychology'), ('sinner', 'saint'), ('destruction', 'construction'), ('crowd', 'bunch'), ('beach', 'reef'), ('man', 'child'), ('bread', 'cheese'), ('champion', 'winner'), ('celebration', 'ceremony'), ('menu', 'order'), ('king', 'princess'), ('wealth', 'prestige'), ('endurance', 'strength'), ('danger', 'threat'), ('god', 'priest'), ('men', 'fraternity'), ('buddy', 'companion'), ('teacher', 'helper'), ('body', 'stomach'), ('tongue', 'throat'), ('house', 'carpet'), ('intelligence', 'skill'), ('journey', 'conquest'), ('god', 'prey'), ('brother', 'soul'), ('adversary', 'opponent'), ('death', 'catastrophe'), ('monster', 'demon'), ('day', 'morning'), ('man', 'victor'), ('friend', 'guy'), ('song', 'story'), ('ray', 'sunshine'), ('guy', 'stud'), ('chicken', 'rice'), ('box', 'elevator')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. --- ["('butter', 'potato'), ('apartment', 'furniture'), ('lake', 'swamp'), ('salad', 'vinegar'), ('flower', 'bulb'), ('cloud', 'mist'), ('driver', 'pilot'), ('sugar', 'honey'), ('body', 'shoulder'), ('idea', 'image'), ('father', 'brother'), ('moon', 'planet'), ('ball', 'costume'), ('rail', 'fence'), ('room', 'bed'), ('flower', 'bush'), ('bone', 'knee'), ('arm', 'knee'), ('bottom', 'side'), ('vessel', 'vein'), ('cat', 'rabbit'), ('meat', 'sandwich'), ('belief', 'concept'), ('intelligence', 'insight'), ('attention', 'interest'), ('attitude', 'confidence'), ('right', 'justice'), ('argument', 'agreement'), ('depth', 'magnitude'), ('medium', 'news'), ('winner', 'candidate'), ('birthday', 'date'), ('fee', 'payment'), ('bible', 'hymn'), ('exit', 'doorway'), ('man', 'sentry'), ('aisle', 'hall'), ('whiskey', 'gin'), ('blood', 'marrow'), ('oil', 'mink'), ('floor', 'deck'), ('roof', 'floor'), ('door', 'floor'), ('shoulder', 'head'), ('wagon', 'carriage'), ('car', 'carriage'), ('elbow', 'ankle'), ('wealth', 'fame'), ('sorrow', 'shame'), ('administration', 'management')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. --- ["('communication', 'conversation'), ('pollution', 'atmosphere'), ('anatomy', 'biology'), ('college', 'profession'), ('book', 'topic'), ('formula', 'equation'), ('book', 'information'), ('boy', 'partner'), ('sky', 'universe'), ('population', 'people'), ('college', 'class'), ('chief', 'mayor'), ('rabbi', 'minister'), ('meter', 'inch'), ('polyester', 'cotton'), ('lawyer', 'banker'), ('violin', 'instrument'), ('camp', 'cabin'), ('pot', 'appliance'), ('linen', 'fabric'), ('whiskey', 'champagne'), ('girl', 'child'), ('cottage', 'cabin'), ('bird', 'hen'), ('racket', 'noise'), ('sunset', 'evening'), ('drizzle', 'rain'), ('adult', 'baby'), ('charcoal', 'coal'), ('body', 'spine'), ('head', 'nail'), ('log', 'timber'), ('spoon', 'cup'), ('body', 'nerve'), ('man', 'husband'), ('bone', 'neck'), ('frustration', 'anger'), ('river', 'sea'), ('task', 'job'), ('club', 'society'), ('reflection', 'image'), ('prince', 'king'), ('snow', 'weather'), ('people', 'party'), ('boy', 'brother'), ('root', 'grass'), ('brow', 'eye'), ('money', 'pearl'), ('money', 'diamond'), ('vehicle', 'bus')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. --- ["('cab', 'bus'), ('house', 'barn'), ('finger', 'palm'), ('car', 'bridge'), ('effort', 'difficulty'), ('fact', 'insight'), ('job', 'management'), ('cancer', 'sickness'), ('word', 'newspaper'), ('composer', 'writer'), ('actor', 'singer'), ('shelter', 'hut'), ('bathroom', 'kitchen'), ('cabin', 'hut'), ('door', 'kitchen'), ('value', 'belief'), ('wisdom', 'intelligence'), ('ignorance', 'intelligence'), ('happiness', 'luck'), ('idea', 'scheme'), ('mood', 'emotion'), ('happiness', 'peace'), ('despair', 'misery'), ('logic', 'arithmetic'), ('denial', 'confession'), ('argument', 'criticism'), ('aggression', 'hostility'), ('hysteria', 'confusion'), ('chemistry', 'theory'), ('trial', 'verdict'), ('comfort', 'safety'), ('confidence', 'self'), ('vision', 'perception'), ('era', 'decade'), ('biography', 'fiction'), ('discussion', 'argument'), ('code', 'symbol'), ('danger', 'disease'), ('accident', 'catastrophe'), ('journey', 'trip'), ('activity', 'movement'), ('gossip', 'news'), ('father', 'god'), ('action', 'course'), ('fever', 'illness'), ('aviation', 'flight'), ('game', 'action'), ('molecule', 'air'), ('home', 'state'), ('word', 'literature')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. --- ["('adult', 'guardian'), ('newspaper', 'information'), ('communication', 'television'), ('cousin', 'uncle'), ('author', 'reader'), ('guy', 'partner'), ('area', 'corner'), ('ballad', 'song'), ('wall', 'decoration'), ('word', 'page'), ('nurse', 'scientist'), ('politician', 'president'), ('president', 'mayor'), ('book', 'essay'), ('man', 'warrior'), ('article', 'journal'), ('breakfast', 'supper'), ('crowd', 'parade'), ('aisle', 'hallway'), ('teacher', 'rabbi'), ('hip', 'lip'), ('book', 'article'), ('room', 'cell'), ('box', 'booth'), ('daughter', 'kid'), ('limb', 'leg'), ('liver', 'lung'), ('classroom', 'hallway'), ('mountain', 'ledge'), ('car', 'elevator'), ('bed', 'couch'), ('clothes', 'button'), ('clothes', 'coat'), ('kidney', 'organ'), ('apple', 'sauce'), ('chicken', 'steak'), ('car', 'hose'), ('tobacco', 'cigarette'), ('student', 'professor'), ('baby', 'daughter'), ('pipe', 'cigar'), ('milk', 'juice'), ('box', 'cigar'), ('apartment', 'hotel'), ('cup', 'cone'), ('horse', 'ox'), ('throat', 'nose'), ('bone', 'teeth'), ('bone', 'elbow'), ('bacon', 'bean')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. --- ["('cup', 'jar'), ('proof', 'fact'), ('appointment', 'engagement'), ('birthday', 'year'), ('word', 'clue'), ('author', 'creator'), ('atom', 'carbon'), ('archbishop', 'bishop'), ('letter', 'paragraph'), ('page', 'paragraph'), ('steeple', 'chapel'), ('muscle', 'bone'), ('muscle', 'tongue'), ('boy', 'soldier'), ('belly', 'abdomen'), ('guy', 'girl'), ('bed', 'chair'), ('clothes', 'jacket'), ('gun', 'knife'), ('tin', 'metal'), ('bottle', 'container'), ('hen', 'turkey'), ('meat', 'bread'), ('arm', 'bone'), ('neck', 'spine'), ('apple', 'lemon'), ('agony', 'grief'), ('assignment', 'task'), ('night', 'dawn'), ('dinner', 'soup'), ('calf', 'bull'), ('snow', 'storm'), ('nail', 'hand'), ('dog', 'horse'), ('arm', 'neck'), ('ball', 'glove'), ('flu', 'fever'), ('fee', 'salary'), ('nerve', 'brain'), ('beast', 'animal'), ('dinner', 'chicken'), ('girl', 'maid'), ('child', 'boy'), ('alcohol', 'wine'), ('nose', 'mouth'), ('street', 'car'), ('bell', 'door'), ('box', 'hat'), ('belief', 'impression'), ('bias', 'opinion')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. --- ["('attention', 'awareness'), ('anger', 'mood'), ('elegance', 'style'), ('beauty', 'age'), ('book', 'theme'), ('friend', 'mother'), ('vitamin', 'iron'), ('car', 'factory'), ('pact', 'condition'), ('chapter', 'choice'), ('arithmetic', 'rhythm'), ('winner', 'presence'), ('belief', 'flower'), ('winner', 'goal'), ('trick', 'size'), ('choice', 'vein'), ('hymn', 'conquest'), ('endurance', 'band'), ('jail', 'choice'), ('condition', 'boy'), ('flower', 'endurance'), ('hole', 'agreement'), ('doctor', 'temper'), ('fraternity', 'door'), ('task', 'woman'), ('fraternity', 'baseball'), ('cent', 'size'), ('presence', 'door'), ('mouse', 'management'), ('task', 'highway'), ('liquor', 'century'), ('task', 'straw'), ('island', 'task'), ('night', 'chapter'), ('pollution', 'president'), ('gun', 'trick'), ('bath', 'trick'), ('diet', 'apple'), ('cent', 'wife'), ('chapter', 'tail'), ('course', 'stomach'), ('hymn', 'straw'), ('dentist', 'colonel'), ('wife', 'straw'), ('hole', 'wife'), ('pupil', 'president'), ('bath', 'wife'), ('people', 'cent'), ('formula', 'log'), ('woman', 'fur')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. --- ["('apple', 'sunshine'), ('gun', 'dawn'), ('meal', 'waist'), ('camera', 'president'), ('liquor', 'band'), ('stomach', 'vein'), ('gun', 'fur'), ('couch', 'baseball'), ('worker', 'camera'), ('deck', 'mouse'), ('rice', 'boy'), ('people', 'gun'), ('cliff', 'tail'), ('ankle', 'window'), ('princess', 'island'), ('container', 'mouse'), ('wagon', 'container'), ('people', 'balloon'), ('dollar', 'people'), ('bath', 'balloon'), ('stomach', 'bedroom'), ('bicycle', 'bedroom'), ('log', 'bath'), ('bowl', 'tail'), ('go', 'come'), ('take', 'steal'), ('listen', 'hear'), ('think', 'rationalize'), ('occur', 'happen'), ('vanish', 'disappear'), ('multiply', 'divide'), ('plead', 'beg'), ('begin', 'originate'), ('protect', 'defend'), ('kill', 'destroy'), ('create', 'make'), ('accept', 'reject'), ('ignore', 'avoid'), ('carry', 'bring'), ('leave', 'enter'), ('choose', 'elect'), ('lose', 'fail'), ('encourage', 'discourage'), ('achieve', 'accomplish'), ('make', 'construct'), ('listen', 'obey'), ('inform', 'notify'), ('receive', 'give'), ('borrow', 'beg'), ('take', 'obtain')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. --- ["('advise', 'recommend'), ('imitate', 'portray'), ('win', 'succeed'), ('think', 'decide'), ('greet', 'meet'), ('agree', 'argue'), ('enjoy', 'entertain'), ('destroy', 'make'), ('save', 'protect'), ('give', 'lend'), ('understand', 'know'), ('take', 'receive'), ('accept', 'acknowledge'), ('decide', 'choose'), ('accept', 'believe'), ('keep', 'possess'), ('roam', 'wander'), ('succeed', 'fail'), ('spend', 'save'), ('leave', 'go'), ('come', 'attend'), ('know', 'believe'), ('gather', 'meet'), ('make', 'earn'), ('forget', 'ignore'), ('multiply', 'add'), ('shrink', 'grow'), ('arrive', 'leave'), ('succeed', 'try'), ('accept', 'deny'), ('arrive', 'come'), ('agree', 'differ'), ('send', 'receive'), ('win', 'dominate'), ('add', 'divide'), ('kill', 'choke'), ('acquire', 'get'), ('participate', 'join'), ('leave', 'remain'), ('go', 'enter'), ('take', 'carry'), ('forget', 'learn'), ('appoint', 'elect'), ('engage', 'marry'), ('ask', 'pray'), ('go', 'send'), ('take', 'deliver'), ('speak', 'hear'), ('analyze', 'evaluate')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. --- ["('argue', 'rationalize'), ('lose', 'keep'), ('compare', 'analyze'), ('disorganize', 'organize'), ('go', 'allow'), ('take', 'possess'), ('learn', 'listen'), ('destroy', 'construct'), ('create', 'build'), ('steal', 'buy'), ('kill', 'hang'), ('forget', 'know'), ('create', 'imagine'), ('do', 'happen'), ('win', 'accomplish'), ('give', 'deny'), ('deserve', 'earn'), ('get', 'put'), ('locate', 'find'), ('appear', 'attend'), ('know', 'comprehend'), ('pretend', 'imagine'), ('satisfy', 'please'), ('cherish', 'keep'), ('argue', 'differ'), ('overcome', 'dominate'), ('behave', 'obey'), ('cooperate', 'participate'), ('achieve', 'try'), ('fail', 'discourage'), ('begin', 'quit'), ('say', 'participate'), ('come', 'bring'), ('declare', 'announce'), ('read', 'comprehend'), ('take', 'leave'), ('proclaim', 'announce'), ('acquire', 'obtain'), ('conclude', 'decide'), ('please', 'plead'), ('argue', 'prove'), ('ask', 'plead'), ('find', 'disappear'), ('inspect', 'examine'), ('verify', 'justify'), ('assume', 'predict'), ('learn', 'evaluate'), ('argue', 'justify'), ('make', 'become')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. --- ["('discover', 'originate'), ('achieve', 'succeed'), ('give', 'put'), ('understand', 'listen'), ('expand', 'grow'), ('borrow', 'sell'), ('keep', 'protect'), ('explain', 'prove'), ('assume', 'pretend'), ('agree', 'please'), ('forgive', 'forget'), ('clarify', 'explain'), ('understand', 'forgive'), ('remind', 'forget'), ('get', 'remain'), ('realize', 'discover'), ('require', 'inquire'), ('ignore', 'ask'), ('think', 'inquire'), ('reject', 'avoid'), ('argue', 'persuade'), ('pursue', 'persuade'), ('accept', 'forgive'), ('do', 'quit'), ('investigate', 'examine'), ('discuss', 'explain'), ('owe', 'lend'), ('explore', 'discover'), ('complain', 'argue'), ('withdraw', 'reject'), ('keep', 'borrow'), ('beg', 'ask'), ('arrange', 'organize'), ('reduce', 'shrink'), ('speak', 'acknowledge'), ('give', 'borrow'), ('kill', 'defend'), ('disappear', 'shrink'), ('deliver', 'carry'), ('breathe', 'choke'), ('acknowledge', 'notify'), ('become', 'seem'), ('pretend', 'seem'), ('accomplish', 'become'), ('contemplate', 'think'), ('determine', 'predict'), ('please', 'entertain'), ('remain', 'retain'), ('pretend', 'portray')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. --- ["('forget', 'retain'), ('want', 'choose'), ('lose', 'get'), ('try', 'think'), ('become', 'appear'), ('leave', 'ignore'), ('accept', 'recommend'), ('leave', 'wander'), ('keep', 'give'), ('give', 'allow'), ('bring', 'send'), ('absorb', 'learn'), ('acquire', 'find'), ('leave', 'appear'), ('create', 'destroy'), ('begin', 'go'), ('get', 'buy'), ('collect', 'save'), ('replace', 'restore'), ('join', 'add'), ('join', 'marry'), ('accept', 'deliver'), ('attach', 'join'), ('put', 'hang'), ('go', 'sell'), ('communicate', 'pray'), ('give', 'steal'), ('add', 'build'), ('bring', 'restore'), ('comprehend', 'satisfy'), ('portray', 'decide'), ('organize', 'become'), ('give', 'know'), ('say', 'verify'), ('cooperate', 'join'), ('arrange', 'require'), ('borrow', 'want'), ('investigate', 'pursue'), ('ignore', 'explore'), ('bring', 'complain'), ('enter', 'owe'), ('portray', 'notify'), ('remind', 'sell'), ('absorb', 'possess'), ('join', 'acquire'), ('send', 'attend'), ('gather', 'attend'), ('absorb', 'withdraw'), ('attend', 'arrive')"]

# %%
# Load encoding
encoding = tiktoken.get_encoding("cl100k_base")

# Count tokens per chunk
token_counts = count_tokens_with_tiktoken(chunks, prompt)

# Show results
print("Token counts for each formatted prompt:", token_counts)
# Out:
# Token counts for each formatted prompt: [391, 403, 380, 380, 372, 376, 387, 392, 394, 379, 377, 387, 390, 375, 380, 379, 363, 378, 383, 360]

# %% [markdown]
# ### **2. Extract and Process Data**

# %%
# Get results from API
# response = get_responses_conversational(chunks, prompt, user_content, assistant_content, model, sample_size, delay)
# Out:
# Processing: 100%|██████████| 300/300 [2:09:29<00:00, 25.90s/chunk]
# Total time taken: 7769.52 seconds

# %%
# Define filepath
file_path = '../../../data/response/en/gpt-3.5-turbo-0125/f8.json'

# Check if file already exists
if not os.path.exists(file_path):
    with open(file_path, 'w') as f:
        json.dump(response, f)
        print("File saved successfully.")
else:
    print("File already exists. JSON was not saved to prevent overwriting.")
# Out:
# File saved successfully.

# %%
# Process data into dictionary
data_dict = process_responses(response)

# Check for values higher/lower then sample size
higher_lower_samples = {key: value for key, value in data_dict.items() if len(value) < sample_size or len(value) > sample_size}

# Show results
print(higher_lower_samples)
# Out:
# {('bad', 'guilty'): [3.0, 2.55, 3.0, 2.0, 4.0, 2.76, 2.1, 2.0, 0.58, 1.0, 0.0, 0.93, 3.21], ('leg', 'arm'): [8.33, 4.88, 7.9, 4.1, 0.71, 8.96, 8.66, 6.18, 7.07, 8.0, 8.74, 5.0, 0.03, 6.71], ('plane', 'jet'): [6.13, 3.63, 5.18, 2.2, 0.58, 5.47, 5.82, 4.07, 5.19, 6.0, 5.61, 6.5, 0.07, 4.0], ('woman', 'man'): [9.73, 6.97, 9.52, 7.88, 0.77, 9.8, 8.77, 7.38, 8.87, 9.0, 9.74, 9.0, 0.08, 7.93], ('horse', 'colt'): [7.95, 6.45, 6.4, 3.7, 0.69, 6.63, 7.73, 5.62, 6.79, 2.0, 6.17, 7.0, 0.05, 3.21], ('actress', 'actor'): [9.53, 8.9, 9.45, 7.88, 0.82, 9.6, 9.68, 8.47, 8.62, 9.0, 9.25, 9.0, 0.08, 7.67], ('teacher', 'instructor'): [5.73, 7.38, 7.53, 6.25, 0.79, 8.53, 9.68, 8.72, 7.31, 9.0, 9.61, 7.0, 0.05, 6.0], ('movie', 'film'): [8.05, 8.03, 8.73, 7.5, 0.78, 9.47, 9.2, 6.46, 8.07, 8.0, 9.69, 5.0, 0.1, 6.79], ('sheep', 'lamb'): [8.22, 5.95, 7.6, 6.0, 0.82, 9.1, 7.16, 6.19, 6.56, 2.0, 7.74, 8.0, 0.05, 3.43], ('lady', 'gentleman'): [8.9, 7.22, 8.8, 7.75, 0.79, 9.57, 9.2, 7.27, 7.94, 9.0, 0.79, 9.0, 0.1, 7.57], ('stomach', 'waist'): [7.0, 6.0, 7.2, 7.0, 6.04, 7.1, 4.3, 5.5, 8.0, 7.77, 7.65, 7.5, 6.8, 6.0], ('cloud', 'storm'): [4.5, 3.5, 3.5, 4.25, 4.44, 5.5, 3.3, 3.3, 8.38, 7.44, 5.12, 4.63, 5.25, 4.0], ('joy', 'pride'): [7.5, 4.5, 6.6, 4.0, 6.88, 8.0, 7.0, 8.75, 8.34, 5.95, 8.1, 6.52, 6.0], ('noise', 'rattle'): [3.0, 2.0, 5.2, 5.0, 2.0, 6.55, 5.0, 5.0, 8.75, 6.03, 6.69, 5.08, 6.15, 4.0], ('rain', 'mist'): [6.0, 3.5, 3.1, 3.25, 4.83, 6.75, 3.4, 1.8, 8.12, 6.53, 5.65, 4.85, 5.0, 3.0], ('beer', 'beverage'): [5.5, 6.5, 8.9, 4.0, 6.52, 8.1, 6.2, 7.3, 8.5, 8.54, 6.58, 9.0, 7.9, 6.0], ('man', 'uncle'): [4.0, 2.0, 3.7, 4.5, 3.2, 5.2, 3.0, 5.0, 7.5, 7.26, 6.2, 6.0, 5.52, 5.0], ('apple', 'juice'): [6.5, 5.8, 6.8, 4.0, 4.29, 7.1, 4.0, 7.0, 9.0, 8.78, 6.88, 8.15, 7.25, 6.0], ('intelligence', 'logic'): [8.0, 7.5, 8.2, 8.0, 7.32, 7.3, 6.5, 7.0, 8.25, 7.95, 7.65, 7.2, 7.9, 6.0], ('communication', 'language'): [8.5, 7.0, 8.4, 7.0, 7.44, 7.4, 7.2, 7.7, 8.62, 8.48, 8.27, 8.55, 8.8, 6.0], ('mink', 'fur'): [4.0, 4.0, 8.4, 5.0, 7.24, 6.6, 5.5, 7.8, 8.75, 7.64, 6.48, 8.25, 8.35, 7.0], ('mob', 'crowd'): [6.5, 5.0, 6.1, 5.25, 6.08, 7.95, 5.9, 3.8, 8.25, 8.35, 6.62, 7.75, 7.0, 5.0], ('shore', 'coast'): [7.5, 7.0, 8.3, 7.5, 6.52, 8.2, 8.0, 7.5, 8.88, 8.46, 7.68, 7.3, 7.65, 7.0], ('wire', 'cord'): [7.5, 6.5, 7.2, 6.0, 7.6, 7.85, 6.1, 6.3, 9.0, 8.57, 8.02, 7.25, 8.35, 7.0], ('bird', 'turkey'): [4.5, 1.5, 3.8, 4.0, 2.6, 5.1, 3.7, 5.8, 8.0, 7.17, 4.58, 7.15, 5.45, 4.0], ('bed', 'crib'): [6.0, 5.5, 5.2, 5.0, 6.28, 6.85, 4.9, 3.0, 9.0, 7.9, 6.19, 6.4, 7.0, 6.0], ('competence', 'ability'): [8.0, 8.2, 8.1, 8.75, 8.57, 8.5, 8.8, 8.5, 9.25, 8.27, 9.05, 8.55, 8.55, 7.0], ('cloud', 'haze'): [5.0, 1.0, 5.0, 6.25, 4.41, 6.85, 6.1, 5.3, 8.25, 7.43, 6.52, 6.3, 5.15, 4.0], ('supper', 'meal'): [7.5, 6.5, 5.9, 6.0, 6.88, 8.6, 6.0, 5.6, 9.0, 8.35, 8.15, 7.75, 7.25, 6.0], ('bar', 'cage'): [5.0, 3.5, 4.9, 5.0, 3.0, 8.25, 5.0, 2.1, 8.25, 7.73, 5.39, 6.13, 6.1, 5.0], ('water', 'salt'): [3.0, 4.0, 7.9, 3.5, 2.78, 6.6, 2.5, 2.7, 8.38, 6.49, 3.7, 5.93, 5.0, 4.0], ('sense', 'intuition'): [7.5, 4.0, 7.1, 7.0, 8.72, 7.75, 6.2, 6.5, 9.25, 8.51, 7.95, 8.35, 6.9, 6.0], ('situation', 'condition'): [7.5, 7.2, 7.1, 7.75, 7.4, 8.3, 7.2, 6.8, 8.75, 8.6, 8.0, 8.3, 6.25, 5.0], ('crime', 'theft'): [5.0, 3.3, 6.2, 4.0, 4.08, 6.85, 6.0, 3.0, 8.12, 6.69, 5.55, 5.43, 6.25, 4.0], ('style', 'fashion'): [7.5, 6.0, 7.2, 6.5, 8.12, 7.5, 6.5, 6.3, 8.5, 8.22, 8.15, 7.0, 7.25, 6.0], ('boundary', 'border'): [7.5, 7.8, 7.8, 7.5, 7.24, 8.15, 7.7, 7.4, 9.0, 8.16, 8.78, 6.55, 7.85, 6.0], ('arm', 'body'): [6.5, 6.8, 6.8, 5.5, 6.94, 7.05, 4.0, 3.0, 8.0, 7.85, 5.35, 6.25, 6.4, 5.0], ('boat', 'car'): [6.5, 4.2, 6.9, 5.0, 6.28, 6.3, 3.5, 6.8, 8.0, 7.08, 6.45, 6.75, 6.5, 5.0], ('sandwich', 'lunch'): [6.5, 7.0, 5.9, 6.0, 6.08, 8.75, 5.8, 3.6, 9.0, 8.14, 8.48, 7.73, 6.75, 6.0], ('bride', 'princess'): [6.0, 3.0, 7.2, 6.0, 6.8, 8.8, 5.0, 6.0, 9.12, 8.7, 6.3, 5.8, 6.25, 3.0], ('doctor', 'professor'): [2.29, 3.52, 1.46, 3.8, 1.34, 2.67,  ...

# %%
# Print duplicate word pairs
print_duplicate_word_pairs(en_simlex, data_dict)
# Out:
# Empty DataFrame
# Columns: [Combined_Columns]
# Index: []
# Empty DataFrame
# Columns: [Combined_Columns]
# Index: []

# %%
# Convert dict to Pandas DataFrame
df = create_dataframe(data_dict)

# Show results
df
# Out:
#       word1     word2  similarity_score_1  similarity_score_2  \
# 0     happy  cheerful                8.75                9.20
# 1      hard      easy                4.10                1.73
# 2      fast     rapid                9.50                9.60
# 3     happy      glad                8.50                8.60
# 4     short      long                7.25                7.50
# ..      ...       ...                 ...                 ...
# 991    join   acquire                7.35                6.60
# 992    send    attend                5.30                6.60
# 993  gather    attend                6.97                6.00
# 994  absorb  withdraw                3.41                3.20
# 995  attend    arrive                6.33                7.60
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                  7.76                5.26                9.50
# 1                  0.81                3.00                1.67
# 2                  9.34                9.75                9.80
# 3                  8.47                7.50                9.40
# 4                  0.71                5.50                9.60
# ..                  ...                 ...                 ...
# 991                4.00                3.00                5.12
# 992                2.40                1.00                3.44
# 993                3.00                1.00                4.20
# 994                1.80                1.00                2.60
# 995                4.00                1.00                5.60
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                  9.60                8.66                8.50
# 1                  3.50                4.52                1.14
# 2                  8.50                9.68                9.21
# 3                  8.80                7.90                8.09
# 4                  5.50                6.42                7.80
# ..                  ...                 ...                 ...
# 991                0.25                6.27                4.38
# 992                0.25                4.44                3.33
# 993                0.25                5.36                3.33
# 994                0.25                3.37                2.08
# 995                0.25                4.17                2.87
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                  9.15                 8.57                 8.90
# 1                  1.98                 2.14                 5.65
# 2                  8.90                 9.29                 9.50
# 3                  8.00                 8.57                 7.80
# 4                  7.34                 8.57                 8.20
# ..                  ...                  ...                  ...
# 991                6.23                 6.12                 3.93
# 992                4.28                 4.65                 4.44
# 993                4.56                 4.94                 4.21
# 994                2.67                 3.12                 2.19
# 995                4.78                 6.03                 4.16
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                   8.20                 9.80                 8.90
# 1                   3.20                 6.00                 2.33
# 2                   9.80                 9.70                 8.20
# 3                   7.60                 9.70                 8.50
# 4                   8.80                 9.20                 7.50
# ..                   ...                  ...                  ...
# 991                 4.30                 3.44                 4.00
# 992                 4.35                 2.09                 2.17
# 993                 3.90                 2.53                 3.52
# 994                 3.40                 1.36                 5.75
# 995                 4.50                 2.18                 6.20
#
#      similarity_score_15
# 0                   8.89
# 1                   5.00
# 2                   9.17
# 3                   8.89
# 4                   6.33
# ..                   ...
# 991                 4.00
# 992                 3.00
# 993                 2.50
# 994                 3.00
# 995                 3.50
#
# [996 rows x 17 columns]

# %%
# Count null values
count_null_values = df.isnull().sum()

# Show results
print("Null value counts per column:", count_null_values)
# Out:
# Null value counts per column: word1                   0
# word2                   0
# similarity_score_1      0
# similarity_score_2      0
# similarity_score_3      0
# similarity_score_4      0
# similarity_score_5      0
# similarity_score_6      0
# similarity_score_7      0
# similarity_score_8      0
# similarity_score_9      0
# similarity_score_10     0
# similarity_score_11     0
# similarity_score_12     0
# similarity_score_13     0
# similarity_score_14     4
# similarity_score_15    94
# dtype: int64

# %%
# Check for rows with at least one null value
rows_with_null = df[df.isnull().any(axis=1)]

# Show results
rows_with_null
# Out:
#       word1   word2  similarity_score_1  similarity_score_2  \
# 99      bad  guilty                3.00                2.55
# 120     leg     arm                8.33                4.88
# 121   plane     jet                6.13                3.63
# 122   woman     man                9.73                6.97
# 123   horse    colt                7.95                6.45
# ..      ...     ...                 ...                 ...
# 647    bone   teeth                7.50                5.11
# 648    bone   elbow                4.00                1.67
# 649   bacon    bean                2.78                1.36
# 713  winner    goal                3.00                3.81
# 845      go    send                7.30                4.80
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 99                 3.00                2.00                4.00
# 120                7.90                4.10                0.71
# 121                5.18                2.20                0.58
# 122                9.52                7.88                0.77
# 123                6.40                3.70                0.69
# ..                  ...                 ...                 ...
# 647                2.05                4.68                4.24
# 648                1.90                2.47                1.76
# 649                1.85                3.82                2.21
# 713                6.91                4.50                5.30
# 845                6.70                6.63                7.10
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 99                 2.76                2.10                2.00
# 120                8.96                8.66                6.18
# 121                5.47                5.82                4.07
# 122                9.80                8.77                7.38
# 123                6.63                7.73                5.62
# ..                  ...                 ...                 ...
# 647                4.95                3.88                2.88
# 648                2.33                0.42                1.78
# 649                4.02                0.49                1.43
# 713                5.60                5.00                7.00
# 845                7.00                4.67                6.29
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 99                 0.58                 1.00                 0.00
# 120                7.07                 8.00                 8.74
# 121                5.19                 6.00                 5.61
# 122                8.87                 9.00                 9.74
# 123                6.79                 2.00                 6.17
# ..                  ...                  ...                  ...
# 647                4.90                 5.44                 4.11
# 648                2.25                 2.61                 2.22
# 649                4.47                 3.10                 3.11
# 713                5.30                 5.28                 5.35
# 845                3.85                 7.45                 6.41
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 99                  0.93                 3.21                  NaN
# 120                 5.00                 0.03                 6.71
# 121                 6.50                 0.07                 4.00
# 122                 9.00                 0.08                 7.93
# 123                 7.00                 0.05                 3.21
# ..                   ...                  ...                  ...
# 647                 0.50                 2.64                 3.90
# 648                 0.20                 2.31                 1.60
# 649                 0.25                 0.50                 1.80
# 713                 4.00                 7.66                 7.65
# 845                 7.89                 2.00                 5.14
#
#      similarity_score_15
# 99                   NaN
# 120                  NaN
# 121                  NaN
# 122                  NaN
# 123                  NaN
# ..                   ...
# 647                  NaN
# 648                  NaN
# 649                  NaN
# 713                  NaN
# 845                  NaN
#
# [94 rows x 17 columns]

# %%
# Show results
df[df['similarity_score_14'].isna()][['word1', 'word2']]
# Out:
#     word1    word2
# 99    bad   guilty
# 272   joy    pride
# 621  book  article
# 642   box    cigar

# %%
# Define prompt
prompt = ("Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity.")
user_content_1 = ("[(old, new), (smart, intelligent), (hard, difficult)]")
assistant_content = ("[(old, new, 1.58), (smart, intelligent, 9.20), (hard, difficult, 8.77)]")
user_content_2 = "[('bad', 'guilty'), ('joy', 'pride'), ('book', 'article'), ('box', 'cigar')]"

# Define message
messages = [
    {"role": "system", "content": prompt},
    {"role": "user", "content": user_content_1},
    {"role": "assistant", "content": assistant_content},
    {"role": "user", "content": user_content_2},
    ]

# Call the API
# completion = client.chat.completions.create(
#     model=model,
#     messages=messages,
#     n=1,
#     stop=None)

# Show results
# print(completion.choices[0].message.content)

# %%
# Manually fix inconsistencies
df.loc[(df['word1'] == 'bad') & (df['word2'] == 'guilty'), 'similarity_score_14'] = 2.60

# Show results
df.loc[(df['word1'] == 'bad') & (df['word2'] == 'guilty')]
# Out:
#    word1   word2  similarity_score_1  similarity_score_2  similarity_score_3  \
# 99   bad  guilty                 3.0                2.55                 3.0
#
#     similarity_score_4  similarity_score_5  similarity_score_6  \
# 99                 2.0                 4.0                2.76
#
#     similarity_score_7  similarity_score_8  similarity_score_9  \
# 99                 2.1                 2.0                0.58
#
#     similarity_score_10  similarity_score_11  similarity_score_12  \
# 99                  1.0                  0.0                 0.93
#
#     similarity_score_13  similarity_score_14  similarity_score_15
# 99                 3.21                  2.6                  NaN

# %%
# Manually fix inconsistencies
df.loc[(df['word1'] == 'joy') & (df['word2'] == 'pride'), 'similarity_score_14'] = 6.50

# Show results
df.loc[(df['word1'] == 'joy') & (df['word2'] == 'pride')]
# Out:
#     word1  word2  similarity_score_1  similarity_score_2  similarity_score_3  \
# 272   joy  pride                 7.5                 4.5                 6.6
#
#      similarity_score_4  similarity_score_5  similarity_score_6  \
# 272                 4.0                6.88                 8.0
#
#      similarity_score_7  similarity_score_8  similarity_score_9  \
# 272                 7.0                8.75                8.34
#
#      similarity_score_10  similarity_score_11  similarity_score_12  \
# 272                 5.95                  8.1                 6.52
#
#      similarity_score_13  similarity_score_14  similarity_score_15
# 272                  6.0                  6.5                  NaN

# %%
# Manually fix inconsistencies
df.loc[(df['word1'] == 'book') & (df['word2'] == 'article'), 'similarity_score_14'] = 2.50

# Show results
df.loc[(df['word1'] == 'book') & (df['word2'] == 'article')]
# Out:
#     word1    word2  similarity_score_1  similarity_score_2  \
# 621  book  article                 2.5                1.67
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 621                 1.7                6.73                1.13
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 621                0.14                1.94                1.82
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 621                3.75                 3.89                 0.15
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 621                 0.41                  2.7                  2.5
#
#      similarity_score_15
# 621                  NaN

# %%
# Manually fix inconsistencies
df.loc[(df['word1'] == 'box') & (df['word2'] == 'cigar'), 'similarity_score_14'] = 2.00

# Show results
df.loc[(df['word1'] == 'box') & (df['word2'] == 'cigar')]
# Out:
#     word1  word2  similarity_score_1  similarity_score_2  similarity_score_3  \
# 642   box  cigar                3.33                 0.0                 2.0
#
#      similarity_score_4  similarity_score_5  similarity_score_6  \
# 642                2.38                1.13                4.39
#
#      similarity_score_7  similarity_score_8  similarity_score_9  \
# 642                0.12                1.33                1.88
#
#      similarity_score_10  similarity_score_11  similarity_score_12  \
# 642                 2.75                 1.44                 0.05
#
#      similarity_score_13  similarity_score_14  similarity_score_15
# 642                  1.9                  2.0                  NaN

# %%
# Check for rows with at least one null value
rows_with_null = df[df.isnull().any(axis=1)]

# Show results
rows_with_null
# Out:
#       word1   word2  similarity_score_1  similarity_score_2  \
# 99      bad  guilty                3.00                2.55
# 120     leg     arm                8.33                4.88
# 121   plane     jet                6.13                3.63
# 122   woman     man                9.73                6.97
# 123   horse    colt                7.95                6.45
# ..      ...     ...                 ...                 ...
# 647    bone   teeth                7.50                5.11
# 648    bone   elbow                4.00                1.67
# 649   bacon    bean                2.78                1.36
# 713  winner    goal                3.00                3.81
# 845      go    send                7.30                4.80
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 99                 3.00                2.00                4.00
# 120                7.90                4.10                0.71
# 121                5.18                2.20                0.58
# 122                9.52                7.88                0.77
# 123                6.40                3.70                0.69
# ..                  ...                 ...                 ...
# 647                2.05                4.68                4.24
# 648                1.90                2.47                1.76
# 649                1.85                3.82                2.21
# 713                6.91                4.50                5.30
# 845                6.70                6.63                7.10
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 99                 2.76                2.10                2.00
# 120                8.96                8.66                6.18
# 121                5.47                5.82                4.07
# 122                9.80                8.77                7.38
# 123                6.63                7.73                5.62
# ..                  ...                 ...                 ...
# 647                4.95                3.88                2.88
# 648                2.33                0.42                1.78
# 649                4.02                0.49                1.43
# 713                5.60                5.00                7.00
# 845                7.00                4.67                6.29
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 99                 0.58                 1.00                 0.00
# 120                7.07                 8.00                 8.74
# 121                5.19                 6.00                 5.61
# 122                8.87                 9.00                 9.74
# 123                6.79                 2.00                 6.17
# ..                  ...                  ...                  ...
# 647                4.90                 5.44                 4.11
# 648                2.25                 2.61                 2.22
# 649                4.47                 3.10                 3.11
# 713                5.30                 5.28                 5.35
# 845                3.85                 7.45                 6.41
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 99                  0.93                 3.21                 2.60
# 120                 5.00                 0.03                 6.71
# 121                 6.50                 0.07                 4.00
# 122                 9.00                 0.08                 7.93
# 123                 7.00                 0.05                 3.21
# ..                   ...                  ...                  ...
# 647                 0.50                 2.64                 3.90
# 648                 0.20                 2.31                 1.60
# 649                 0.25                 0.50                 1.80
# 713                 4.00                 7.66                 7.65
# 845                 7.89                 2.00                 5.14
#
#      similarity_score_15
# 99                   NaN
# 120                  NaN
# 121                  NaN
# 122                  NaN
# 123                  NaN
# ..                   ...
# 647                  NaN
# 648                  NaN
# 649                  NaN
# 713                  NaN
# 845                  NaN
#
# [94 rows x 17 columns]

# %%
# Count null values
count_null_values = df.isnull().sum()

# Show results
print("Null value counts per column:", count_null_values)
# Out:
# Null value counts per column: word1                   0
# word2                   0
# similarity_score_1      0
# similarity_score_2      0
# similarity_score_3      0
# similarity_score_4      0
# similarity_score_5      0
# similarity_score_6      0
# similarity_score_7      0
# similarity_score_8      0
# similarity_score_9      0
# similarity_score_10     0
# similarity_score_11     0
# similarity_score_12     0
# similarity_score_13     0
# similarity_score_14     0
# similarity_score_15    94
# dtype: int64

# %%
# Extract missing word pairs
missing_word_pair_list = list(zip(rows_with_null['word1'], rows_with_null['word2']))

# Show results
missing_word_pair_list
# Out:
# [('bad', 'guilty'),
#  ('leg', 'arm'),
#  ('plane', 'jet'),
#  ('woman', 'man'),
#  ('horse', 'colt'),
#  ('actress', 'actor'),
#  ('teacher', 'instructor'),
#  ('movie', 'film'),
#  ('sheep', 'lamb'),
#  ('lady', 'gentleman'),
#  ('stomach', 'waist'),
#  ('cloud', 'storm'),
#  ('joy', 'pride'),
#  ('noise', 'rattle'),
#  ('rain', 'mist'),
#  ('beer', 'beverage'),
#  ('man', 'uncle'),
#  ('apple', 'juice'),
#  ('intelligence', 'logic'),
#  ('communication', 'language'),
#  ('mink', 'fur'),
#  ('mob', 'crowd'),
#  ('shore', 'coast'),
#  ('wire', 'cord'),
#  ('bird', 'turkey'),
#  ('bed', 'crib'),
#  ('competence', 'ability'),
#  ('cloud', 'haze'),
#  ('supper', 'meal'),
#  ('bar', 'cage'),
#  ('water', 'salt'),
#  ('sense', 'intuition'),
#  ('situation', 'condition'),
#  ('crime', 'theft'),
#  ('style', 'fashion'),
#  ('boundary', 'border'),
#  ('arm', 'body'),
#  ('boat', 'car'),
#  ('sandwich', 'lunch'),
#  ('bride', 'princess'),
#  ('doctor', 'professor'),
#  ('arm', 'vein'),
#  ('adult', 'guardian'),
#  ('newspaper', 'information'),
#  ('communication', 'television'),
#  ('cousin', 'uncle'),
#  ('author', 'reader'),
#  ('guy', 'partner'),
#  ('area', 'corner'),
#  ('ballad', 'song'),
#  ('wall', 'decoration'),
#  ('word', 'page'),
#  ('nurse', 'scientist'),
#  ('politician', 'president'),
#  ('president', 'mayor'),
#  ('book', 'essay'),
#  ('man', 'warrior'),
#  ('article', 'journal'),
#  ('breakfast', 'supper'),
#  ('crowd', 'parade'),
#  ('aisle', 'hallway'),
#  ('teacher', 'rabbi'),
#  ('hip', 'lip'),
#  ('book', 'article'),
#  ('room', 'cell'),
#  ('box', 'booth'),
#  ('daughter', 'kid'),
#  ('limb', 'leg'),
#  ('liver', 'lung'),
#  ('classroom', 'hallway'),
#  ('mountain', 'ledge'),
#  ('car', 'elevator'),
#  ('bed', 'couch'),
#  ('clothes', 'button'),
#  ('clothes', 'coat'),
#  ('kidney', 'organ'),
#  ('apple', 'sauce'),
#  ('chicken', 'steak'),
#  ('car', 'hose'),
#  ('tobacco', 'cigarette'),
#  ('student', 'professor'),
#  ('baby', 'daughter'),
#  ('pipe', 'cigar'),
#  ('milk', 'juice'),
#  ('box', 'cigar'),
#  ('apartment', 'hotel'),
#  ('cup', 'cone'),
#  ('horse', 'ox'),
#  ('throat', 'nose'),
#  ('bone', 'teeth'),
#  ('bone', 'elbow'),
#  ('bacon', 'bean'),
#  ('winner', 'goal'),
#  ('go', 'send')]

# %%
# Define prompt
prompt = ("Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity.")
user_content_1 = ("[(old, new), (smart, intelligent), (hard, difficult)]")
assistant_content = ("[(old, new, 1.58), (smart, intelligent, 9.20), (hard, difficult, 8.77)]")
user_content_2 = f'"{missing_word_pair_list}"'

# %%
# Define message
messages = [
    {"role": "system", "content": prompt},
    {"role": "user", "content": user_content_1},
    {"role": "assistant", "content": assistant_content},
    {"role": "user", "content": user_content_2},
    ]

# Make API call
# completion = client.chat.completions.create(
#     model=model,
#     messages=messages,
#     n=1,
#     stop=None)

# Store response content
missing_word_pairs_response = [completion.choices[0].message.content]

# %%
# Extract data with regular expressions into dictionary
missing_word_pairs_dict = process_responses(missing_word_pairs_response)

# Show results
missing_word_pairs_dict
# Out:
# {('bad', 'guilty'): [2.83],
#  ('leg', 'arm'): [7.9],
#  ('plane', 'jet'): [7.6],
#  ('woman', 'man'): [8.77],
#  ('horse', 'colt'): [7.0],
#  ('actress', 'actor'): [9.3],
#  ('teacher', 'instructor'): [8.0],
#  ('movie', 'film'): [9.86],
#  ('sheep', 'lamb'): [6.5],
#  ('lady', 'gentleman'): [8.7],
#  ('stomach', 'waist'): [7.7],
#  ('cloud', 'storm'): [7.69],
#  ('joy', 'pride'): [6.1],
#  ('noise', 'rattle'): [4.4],
#  ('rain', 'mist'): [6.5],
#  ('beer', 'beverage'): [4.3],
#  ('man', 'uncle'): [6.2],
#  ('apple', 'juice'): [7.8],
#  ('intelligence', 'logic'): [7.8],
#  ('communication', 'language'): [7.3],
#  ('mink', 'fur'): [4.6],
#  ('mob', 'crowd'): [7.1],
#  ('shore', 'coast'): [7.8],
#  ('wire', 'cord'): [7.0],
#  ('bird', 'turkey'): [5.4],
#  ('bed', 'crib'): [7.9],
#  ('competence', 'ability'): [7.8],
#  ('cloud', 'haze'): [5.7],
#  ('supper', 'meal'): [8.3],
#  ('bar', 'cage'): [4.3],
#  ('water', 'salt'): [4.4],
#  ('sense', 'intuition'): [8.1],
#  ('situation', 'condition'): [7.9],
#  ('crime', 'theft'): [6.2],
#  ('style', 'fashion'): [8.7],
#  ('boundary', 'border'): [8.2],
#  ('arm', 'body'): [7.3],
#  ('boat', 'car'): [8.0],
#  ('sandwich', 'lunch'): [8.5],
#  ('bride', 'princess'): [7.6],
#  ('doctor', 'professor'): [7.2],
#  ('arm', 'vein'): [4.3],
#  ('adult', 'guardian'): [6.3],
#  ('newspaper', 'information'): [6.4],
#  ('communication', 'television'): [6.2],
#  ('cousin', 'uncle'): [7.0],
#  ('author', 'reader'): [6.6],
#  ('guy', 'partner'): [6.7],
#  ('area', 'corner'): [4.8],
#  ('ballad', 'song'): [8.7],
#  ('wall', 'decoration'): [4.3],
#  ('word', 'page'): [6.4],
#  ('nurse', 'scientist'): [6.5],
#  ('politician', 'president'): [8.9],
#  ('president', 'mayor'): [8.6],
#  ('book', 'essay'): [6.9],
#  ('man', 'warrior'): [6.7],
#  ('article', 'journal'): [6.4],
#  ('breakfast', 'supper'): [8.2],
#  ('crowd', 'parade'): [7.4],
#  ('aisle', 'hallway'): [7.6],
#  ('teacher', 'rabbi'): [6.4],
#  ('hip', 'lip'): [6.0],
#  ('book', 'article'): [6.9],
#  ('room', 'cell'): [5.3],
#  ('box', 'booth'): [5.6],
#  ('daughter', 'kid'): [6.8],
#  ('limb', 'leg'): [7.8],
#  ('liver', 'lung'): [6.6],
#  ('classroom', 'hallway'): [7.0],
#  ('mountain', 'ledge'): [7.9],
#  ('car', 'elevator'): [5.7],
#  ('bed', 'couch'): [7.2],
#  ('clothes', 'button'): [3.9],
#  ('clothes', 'coat'): [6.0],
#  ('kidney', 'organ'): [6.4],
#  ('apple', 'sauce'): [6.3],
#  ('chicken', 'steak'): [6.8],
#  ('car', 'hose'): [4.7],
#  ('tobacco', 'cigarette'): [3.7],
#  ('student', 'professor'): [8.8],
#  ('baby', 'daughter'): [6.8],
#  ('pipe', 'cigar'): [4.7],
#  ('milk', 'juice'): [6.8],
#  ('box', 'cigar'): [3.5],
#  ('apartment', 'hotel'): [7.3],
#  ('cup', 'cone'): [4.7],
#  ('horse', 'ox'): [5.6],
#  ('throat', 'nose'): [6.8],
#  ('bone', 'teeth'): [7.1],
#  ('bone', 'elbow'): [5.3],
#  ('bacon', 'bean'): [4.5],
#  ('winner', 'goal'): [5.9],
#  ('go', 'send'): [6.7]}

# %%
# Iterate over DataFrame and replace missing values
for index, row in df.iterrows():
    word_pair = (row['word1'], row['word2'])

    # Check if current value is NaN
    if pd.isna(row['similarity_score_15']):
        if word_pair in missing_word_pairs_dict:

            # Extract first element from list
            df.at[index, 'similarity_score_15'] = missing_word_pairs_dict[word_pair][0]

# Check if any NaN values left
print(df[df['similarity_score_15'].isna()])
# Out:
# Empty DataFrame
# Columns: [word1, word2, similarity_score_1, similarity_score_2, similarity_score_3, similarity_score_4, similarity_score_5, similarity_score_6, similarity_score_7, similarity_score_8, similarity_score_9, similarity_score_10, similarity_score_11, similarity_score_12, similarity_score_13, similarity_score_14, similarity_score_15]
# Index: []

# %%
# Filter the DataFrame based on pairs
filtered_df = df[df.apply(lambda row: (row['word1'], row['word2']) in missing_word_pair_list, axis=1)]

# Select only the similarity_score_15 column
result = filtered_df[['word1', 'word2', 'similarity_score_15']]

# Show results
print(result)
# Out:
#       word1   word2  similarity_score_15
# 99      bad  guilty                 2.83
# 120     leg     arm                 7.90
# 121   plane     jet                 7.60
# 122   woman     man                 8.77
# 123   horse    colt                 7.00
# ..      ...     ...                  ...
# 647    bone   teeth                 7.10
# 648    bone   elbow                 5.30
# 649   bacon    bean                 4.50
# 713  winner    goal                 5.90
# 845      go    send                 6.70
#
# [94 rows x 3 columns]

# %%
# Check for rows with at least one null value
rows_with_null = df[df.isnull().any(axis=1)]

# Show results
rows_with_null
# Out:
# Empty DataFrame
# Columns: [word1, word2, similarity_score_1, similarity_score_2, similarity_score_3, similarity_score_4, similarity_score_5, similarity_score_6, similarity_score_7, similarity_score_8, similarity_score_9, similarity_score_10, similarity_score_11, similarity_score_12, similarity_score_13, similarity_score_14, similarity_score_15]
# Index: []

# %%
# Count null values
count_null_values = df.isnull().sum()

# Show results
print("Null value counts per column:", count_null_values)
# Out:
# Null value counts per column: word1                  0
# word2                  0
# similarity_score_1     0
# similarity_score_2     0
# similarity_score_3     0
# similarity_score_4     0
# similarity_score_5     0
# similarity_score_6     0
# similarity_score_7     0
# similarity_score_8     0
# similarity_score_9     0
# similarity_score_10    0
# similarity_score_11    0
# similarity_score_12    0
# similarity_score_13    0
# similarity_score_14    0
# similarity_score_15    0
# dtype: int64

# %%
# Show results
df
# Out:
#       word1     word2  similarity_score_1  similarity_score_2  \
# 0     happy  cheerful                8.75                9.20
# 1      hard      easy                4.10                1.73
# 2      fast     rapid                9.50                9.60
# 3     happy      glad                8.50                8.60
# 4     short      long                7.25                7.50
# ..      ...       ...                 ...                 ...
# 991    join   acquire                7.35                6.60
# 992    send    attend                5.30                6.60
# 993  gather    attend                6.97                6.00
# 994  absorb  withdraw                3.41                3.20
# 995  attend    arrive                6.33                7.60
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                  7.76                5.26                9.50
# 1                  0.81                3.00                1.67
# 2                  9.34                9.75                9.80
# 3                  8.47                7.50                9.40
# 4                  0.71                5.50                9.60
# ..                  ...                 ...                 ...
# 991                4.00                3.00                5.12
# 992                2.40                1.00                3.44
# 993                3.00                1.00                4.20
# 994                1.80                1.00                2.60
# 995                4.00                1.00                5.60
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                  9.60                8.66                8.50
# 1                  3.50                4.52                1.14
# 2                  8.50                9.68                9.21
# 3                  8.80                7.90                8.09
# 4                  5.50                6.42                7.80
# ..                  ...                 ...                 ...
# 991                0.25                6.27                4.38
# 992                0.25                4.44                3.33
# 993                0.25                5.36                3.33
# 994                0.25                3.37                2.08
# 995                0.25                4.17                2.87
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                  9.15                 8.57                 8.90
# 1                  1.98                 2.14                 5.65
# 2                  8.90                 9.29                 9.50
# 3                  8.00                 8.57                 7.80
# 4                  7.34                 8.57                 8.20
# ..                  ...                  ...                  ...
# 991                6.23                 6.12                 3.93
# 992                4.28                 4.65                 4.44
# 993                4.56                 4.94                 4.21
# 994                2.67                 3.12                 2.19
# 995                4.78                 6.03                 4.16
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                   8.20                 9.80                 8.90
# 1                   3.20                 6.00                 2.33
# 2                   9.80                 9.70                 8.20
# 3                   7.60                 9.70                 8.50
# 4                   8.80                 9.20                 7.50
# ..                   ...                  ...                  ...
# 991                 4.30                 3.44                 4.00
# 992                 4.35                 2.09                 2.17
# 993                 3.90                 2.53                 3.52
# 994                 3.40                 1.36                 5.75
# 995                 4.50                 2.18                 6.20
#
#      similarity_score_15
# 0                   8.89
# 1                   5.00
# 2                   9.17
# 3                   8.89
# 4                   6.33
# ..                   ...
# 991                 4.00
# 992                 3.00
# 993                 2.50
# 994                 3.00
# 995                 3.50
#
# [996 rows x 17 columns]

# %%
# Define file_path
file_path = '../../../data/gpt-3.5-turbo-0125/processed/en/f8.csv'

# Check if file already exists
if not os.path.exists(file_path):
    df.to_csv(file_path, index=False)
    print("File saved successfully.")
else:
    print("File already exists. Dataframe was not saved to prevent overwriting.")
# Out:
# File saved successfully.
