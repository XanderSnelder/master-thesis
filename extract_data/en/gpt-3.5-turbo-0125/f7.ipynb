# %% [markdown]
# ### **0. Set-up**

# %%
# Import libraries and utils
# %run '../../utils.ipynb'

# %%
#  Get api key
load_dotenv()
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

# Set client
client = OpenAI()

# %%
# Load dataframe
en_simlex = pd.read_csv("../../../data/dataset/en-simlex-999.txt", delimiter='\t')

# Select subset
# en_simlex = en_simlex.head(150)

# Convert to tuple
tuples_list = list(zip(en_simlex['word1'], en_simlex['word2']))

# %%
# Show results
en_simlex
# Out:
#       word1        word2 POS  SimLex999  conc(w1)  conc(w2)  concQ  \
# 0       old          new   A       1.58      2.72      2.81      2
# 1     smart  intelligent   A       9.20      1.75      2.46      1
# 2      hard    difficult   A       8.77      3.76      2.21      2
# 3     happy     cheerful   A       9.55      2.56      2.34      1
# 4      hard         easy   A       0.95      3.76      2.07      2
# ..      ...          ...  ..        ...       ...       ...    ...
# 994    join      acquire   V       2.85      2.86      2.93      2
# 995    send       attend   V       1.67      2.70      3.17      2
# 996  gather       attend   V       4.80      2.75      3.17      2
# 997  absorb     withdraw   V       2.97      3.11      3.04      2
# 998  attend       arrive   V       6.08      3.17      3.22      2
#
#      Assoc(USF)  SimAssoc333  SD(SimLex)
# 0          7.25            1        0.41
# 1          7.11            1        0.67
# 2          5.94            1        1.19
# 3          5.85            1        2.18
# 4          5.82            1        0.93
# ..          ...          ...         ...
# 994        0.00            0        0.99
# 995        0.00            0        1.44
# 996        0.00            0        1.97
# 997        0.00            0        1.75
# 998        0.00            0        1.18
#
# [999 rows x 10 columns]

# %% [markdown]
# ### **1. Define and Evaluate Parameters**

# %%
# Define the prompt
prompt = ("Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. "
          "In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. "
          "In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. "
          "Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. "
          "Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. "
          "There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. "
          "The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context.")

# %%
# Define model
model = "gpt-3.5-turbo-0125"

# Set sample size
sample_size = 15

# Delay between individual API calls
delay = 10.0

# Define number of sublists
n_sublists = 50

# %%
# Split the list
chunks = split_into_n_lists(tuples_list, n_sublists)

# Count the number of lists
print(len(chunks))
# Out:
# 50

# %%
# Print the prompts for each chunk
print_prompts(chunks, prompt)
# Out:
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('old', 'new'), ('smart', 'intelligent'), ('hard', 'difficult'), ('happy', 'cheerful'), ('hard', 'easy'), ('fast', 'rapid'), ('happy', 'glad'), ('short', 'long'), ('stupid', 'dumb'), ('weird', 'strange'), ('wide', 'narrow'), ('bad', 'awful'), ('easy', 'difficult'), ('bad', 'terrible'), ('hard', 'simple'), ('smart', 'dumb'), ('insane', 'crazy'), ('happy', 'mad'), ('large', 'huge'), ('hard', 'tough')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('new', 'fresh'), ('sharp', 'dull'), ('quick', 'rapid'), ('dumb', 'foolish'), ('wonderful', 'terrific'), ('strange', 'odd'), ('happy', 'angry'), ('narrow', 'broad'), ('simple', 'easy'), ('old', 'fresh'), ('apparent', 'obvious'), ('inexpensive', 'cheap'), ('nice', 'generous'), ('weird', 'normal'), ('weird', 'odd'), ('bad', 'immoral'), ('sad', 'funny'), ('wonderful', 'great'), ('guilty', 'ashamed'), ('beautiful', 'wonderful')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('confident', 'sure'), ('dumb', 'dense'), ('large', 'big'), ('nice', 'cruel'), ('impatient', 'anxious'), ('big', 'broad'), ('strong', 'proud'), ('unnecessary', 'necessary'), ('restless', 'young'), ('dumb', 'intelligent'), ('bad', 'great'), ('difficult', 'simple'), ('necessary', 'important'), ('bad', 'terrific'), ('mad', 'glad'), ('honest', 'guilty'), ('easy', 'tough'), ('easy', 'flexible'), ('certain', 'sure'), ('essential', 'necessary')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('different', 'normal'), ('sly', 'clever'), ('crucial', 'important'), ('harsh', 'cruel'), ('childish', 'foolish'), ('scarce', 'rare'), ('friendly', 'generous'), ('fragile', 'frigid'), ('long', 'narrow'), ('big', 'heavy'), ('rough', 'frigid'), ('bizarre', 'strange'), ('illegal', 'immoral'), ('bad', 'guilty'), ('modern', 'ancient'), ('new', 'ancient'), ('dull', 'funny'), ('happy', 'young'), ('easy', 'big'), ('great', 'awful')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('tiny', 'huge'), ('polite', 'proper'), ('modest', 'ashamed'), ('exotic', 'rare'), ('dumb', 'clever'), ('delightful', 'wonderful'), ('noticeable', 'obvious'), ('afraid', 'anxious'), ('formal', 'proper'), ('dreary', 'dull'), ('delightful', 'cheerful'), ('unhappy', 'mad'), ('sad', 'terrible'), ('sick', 'crazy'), ('violent', 'angry'), ('laden', 'heavy'), ('dirty', 'cheap'), ('elastic', 'flexible'), ('hard', 'dense'), ('recent', 'new')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('bold', 'proud'), ('sly', 'strange'), ('strange', 'sly'), ('dumb', 'rare'), ('sly', 'tough'), ('terrific', 'mad'), ('modest', 'flexible'), ('fresh', 'wide'), ('huge', 'dumb'), ('large', 'flexible'), ('dirty', 'narrow'), ('wife', 'husband'), ('book', 'text'), ('groom', 'bride'), ('night', 'day'), ('south', 'north'), ('plane', 'airport'), ('uncle', 'aunt'), ('horse', 'mare'), ('bottom', 'top')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('friend', 'buddy'), ('student', 'pupil'), ('world', 'globe'), ('leg', 'arm'), ('plane', 'jet'), ('woman', 'man'), ('horse', 'colt'), ('actress', 'actor'), ('teacher', 'instructor'), ('movie', 'film'), ('bird', 'hawk'), ('word', 'dictionary'), ('money', 'salary'), ('dog', 'cat'), ('area', 'region'), ('navy', 'army'), ('book', 'literature'), ('clothes', 'closet'), ('sunset', 'sunrise'), ('child', 'adult')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('cow', 'cattle'), ('book', 'story'), ('winter', 'summer'), ('taxi', 'cab'), ('tree', 'maple'), ('bed', 'bedroom'), ('roof', 'ceiling'), ('disease', 'infection'), ('arm', 'shoulder'), ('sheep', 'lamb'), ('lady', 'gentleman'), ('boat', 'anchor'), ('priest', 'monk'), ('toe', 'finger'), ('river', 'stream'), ('anger', 'fury'), ('date', 'calendar'), ('sea', 'ocean'), ('second', 'minute'), ('hand', 'thumb')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('wood', 'log'), ('mud', 'dirt'), ('hallway', 'corridor'), ('way', 'manner'), ('mouse', 'cat'), ('cop', 'sheriff'), ('death', 'burial'), ('music', 'melody'), ('beer', 'alcohol'), ('mouth', 'lip'), ('storm', 'hurricane'), ('tax', 'income'), ('flower', 'violet'), ('paper', 'cardboard'), ('floor', 'ceiling'), ('beach', 'seashore'), ('rod', 'curtain'), ('hound', 'fox'), ('street', 'alley'), ('boat', 'deck')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('car', 'horn'), ('friend', 'guest'), ('employer', 'employee'), ('hand', 'wrist'), ('ball', 'cannon'), ('alcohol', 'brandy'), ('victory', 'triumph'), ('telephone', 'booth'), ('door', 'doorway'), ('motel', 'inn'), ('clothes', 'cloth'), ('steak', 'meat'), ('nail', 'thumb'), ('band', 'orchestra'), ('book', 'bible'), ('business', 'industry'), ('winter', 'season'), ('decade', 'century'), ('alcohol', 'gin'), ('hat', 'coat')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('window', 'door'), ('arm', 'wrist'), ('house', 'apartment'), ('glass', 'crystal'), ('wine', 'brandy'), ('creator', 'maker'), ('dinner', 'breakfast'), ('arm', 'muscle'), ('bubble', 'suds'), ('bread', 'flour'), ('death', 'tragedy'), ('absence', 'presence'), ('gun', 'cannon'), ('grass', 'blade'), ('ball', 'basket'), ('hose', 'garden'), ('boy', 'kid'), ('church', 'choir'), ('clothes', 'drawer'), ('tower', 'bell')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('father', 'parent'), ('school', 'grade'), ('parent', 'adult'), ('bar', 'jail'), ('car', 'highway'), ('dictionary', 'definition'), ('door', 'cellar'), ('army', 'legion'), ('metal', 'aluminum'), ('chair', 'bench'), ('cloud', 'fog'), ('boy', 'son'), ('water', 'ice'), ('bed', 'blanket'), ('attorney', 'lawyer'), ('area', 'zone'), ('business', 'company'), ('clothes', 'fabric'), ('sweater', 'jacket'), ('money', 'capital')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('hand', 'foot'), ('alcohol', 'cocktail'), ('yard', 'inch'), ('molecule', 'atom'), ('lens', 'camera'), ('meal', 'dinner'), ('eye', 'tear'), ('god', 'devil'), ('loop', 'belt'), ('rat', 'mouse'), ('motor', 'engine'), ('car', 'cab'), ('cat', 'lion'), ('size', 'magnitude'), ('reality', 'fantasy'), ('door', 'gate'), ('cat', 'pet'), ('tin', 'aluminum'), ('bone', 'jaw'), ('cereal', 'wheat')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('house', 'key'), ('blood', 'flesh'), ('door', 'corridor'), ('god', 'spirit'), ('capability', 'competence'), ('abundance', 'plenty'), ('sofa', 'chair'), ('wall', 'brick'), ('horn', 'drum'), ('organ', 'liver'), ('strength', 'might'), ('phrase', 'word'), ('band', 'parade'), ('stomach', 'waist'), ('cloud', 'storm'), ('joy', 'pride'), ('noise', 'rattle'), ('rain', 'mist'), ('beer', 'beverage'), ('man', 'uncle')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('apple', 'juice'), ('intelligence', 'logic'), ('communication', 'language'), ('mink', 'fur'), ('mob', 'crowd'), ('shore', 'coast'), ('wire', 'cord'), ('bird', 'turkey'), ('bed', 'crib'), ('competence', 'ability'), ('cloud', 'haze'), ('supper', 'meal'), ('bar', 'cage'), ('water', 'salt'), ('sense', 'intuition'), ('situation', 'condition'), ('crime', 'theft'), ('style', 'fashion'), ('boundary', 'border'), ('arm', 'body')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('boat', 'car'), ('sandwich', 'lunch'), ('bride', 'princess'), ('heroine', 'hero'), ('car', 'gauge'), ('insect', 'bee'), ('crib', 'cradle'), ('animal', 'person'), ('marijuana', 'herb'), ('bed', 'hospital'), ('cheek', 'tongue'), ('disc', 'computer'), ('curve', 'angle'), ('grass', 'moss'), ('school', 'law'), ('foot', 'head'), ('mother', 'guardian'), ('orthodontist', 'dentist'), ('alcohol', 'whiskey'), ('mouth', 'tooth')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('breakfast', 'bacon'), ('bathroom', 'bedroom'), ('plate', 'bowl'), ('meat', 'bacon'), ('air', 'helium'), ('worker', 'employer'), ('body', 'chest'), ('son', 'father'), ('heart', 'surgery'), ('woman', 'secretary'), ('man', 'father'), ('beach', 'island'), ('story', 'topic'), ('game', 'fun'), ('weekend', 'week'), ('couple', 'pair'), ('woman', 'wife'), ('sheep', 'cattle'), ('purse', 'bag'), ('ceiling', 'cathedral')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('bean', 'coffee'), ('wood', 'paper'), ('top', 'side'), ('crime', 'fraud'), ('pain', 'harm'), ('lover', 'companion'), ('evening', 'dusk'), ('father', 'daughter'), ('wine', 'liquor'), ('cow', 'goat'), ('belief', 'opinion'), ('reality', 'illusion'), ('pact', 'agreement'), ('wealth', 'poverty'), ('accident', 'emergency'), ('battle', 'conquest'), ('friend', 'teacher'), ('illness', 'infection'), ('game', 'trick'), ('brother', 'son')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('aunt', 'nephew'), ('worker', 'mechanic'), ('doctor', 'orthodontist'), ('oak', 'maple'), ('bee', 'queen'), ('car', 'bicycle'), ('goal', 'quest'), ('august', 'month'), ('army', 'squad'), ('cloud', 'weather'), ('physician', 'doctor'), ('canyon', 'valley'), ('river', 'valley'), ('sun', 'sky'), ('target', 'arrow'), ('chocolate', 'pie'), ('circumstance', 'situation'), ('opinion', 'choice'), ('rhythm', 'melody'), ('gut', 'nerve')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('day', 'dawn'), ('cattle', 'beef'), ('doctor', 'professor'), ('arm', 'vein'), ('room', 'bath'), ('corporation', 'business'), ('fun', 'football'), ('hill', 'cliff'), ('bone', 'ankle'), ('apple', 'candy'), ('helper', 'maid'), ('leader', 'manager'), ('lemon', 'tea'), ('bee', 'ant'), ('basketball', 'baseball'), ('rice', 'bean'), ('bed', 'furniture'), ('emotion', 'passion'), ('anarchy', 'chaos'), ('crime', 'violation')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('machine', 'engine'), ('beach', 'sea'), ('alley', 'bowl'), ('jar', 'bottle'), ('strength', 'capability'), ('seed', 'mustard'), ('guitar', 'drum'), ('opinion', 'idea'), ('north', 'west'), ('diet', 'salad'), ('mother', 'wife'), ('dad', 'mother'), ('captain', 'sailor'), ('meter', 'yard'), ('beer', 'champagne'), ('motor', 'boat'), ('card', 'bridge'), ('science', 'psychology'), ('sinner', 'saint'), ('destruction', 'construction')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('crowd', 'bunch'), ('beach', 'reef'), ('man', 'child'), ('bread', 'cheese'), ('champion', 'winner'), ('celebration', 'ceremony'), ('menu', 'order'), ('king', 'princess'), ('wealth', 'prestige'), ('endurance', 'strength'), ('danger', 'threat'), ('god', 'priest'), ('men', 'fraternity'), ('buddy', 'companion'), ('teacher', 'helper'), ('body', 'stomach'), ('tongue', 'throat'), ('house', 'carpet'), ('intelligence', 'skill'), ('journey', 'conquest')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('god', 'prey'), ('brother', 'soul'), ('adversary', 'opponent'), ('death', 'catastrophe'), ('monster', 'demon'), ('day', 'morning'), ('man', 'victor'), ('friend', 'guy'), ('song', 'story'), ('ray', 'sunshine'), ('guy', 'stud'), ('chicken', 'rice'), ('box', 'elevator'), ('butter', 'potato'), ('apartment', 'furniture'), ('lake', 'swamp'), ('salad', 'vinegar'), ('flower', 'bulb'), ('cloud', 'mist'), ('driver', 'pilot')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('sugar', 'honey'), ('body', 'shoulder'), ('idea', 'image'), ('father', 'brother'), ('moon', 'planet'), ('ball', 'costume'), ('rail', 'fence'), ('room', 'bed'), ('flower', 'bush'), ('bone', 'knee'), ('arm', 'knee'), ('bottom', 'side'), ('vessel', 'vein'), ('cat', 'rabbit'), ('meat', 'sandwich'), ('belief', 'concept'), ('intelligence', 'insight'), ('attention', 'interest'), ('attitude', 'confidence'), ('right', 'justice')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('argument', 'agreement'), ('depth', 'magnitude'), ('medium', 'news'), ('winner', 'candidate'), ('birthday', 'date'), ('fee', 'payment'), ('bible', 'hymn'), ('exit', 'doorway'), ('man', 'sentry'), ('aisle', 'hall'), ('whiskey', 'gin'), ('blood', 'marrow'), ('oil', 'mink'), ('floor', 'deck'), ('roof', 'floor'), ('door', 'floor'), ('shoulder', 'head'), ('wagon', 'carriage'), ('car', 'carriage'), ('elbow', 'ankle')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('wealth', 'fame'), ('sorrow', 'shame'), ('administration', 'management'), ('communication', 'conversation'), ('pollution', 'atmosphere'), ('anatomy', 'biology'), ('college', 'profession'), ('book', 'topic'), ('formula', 'equation'), ('book', 'information'), ('boy', 'partner'), ('sky', 'universe'), ('population', 'people'), ('college', 'class'), ('chief', 'mayor'), ('rabbi', 'minister'), ('meter', 'inch'), ('polyester', 'cotton'), ('lawyer', 'banker'), ('violin', 'instrument')"]
# ...
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('participate', 'join'), ('leave', 'remain'), ('go', 'enter'), ('take', 'carry'), ('forget', 'learn'), ('appoint', 'elect'), ('engage', 'marry'), ('ask', 'pray'), ('go', 'send'), ('take', 'deliver'), ('speak', 'hear'), ('analyze', 'evaluate'), ('argue', 'rationalize'), ('lose', 'keep'), ('compare', 'analyze'), ('disorganize', 'organize'), ('go', 'allow'), ('take', 'possess'), ('learn', 'listen'), ('destroy', 'construct')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('create', 'build'), ('steal', 'buy'), ('kill', 'hang'), ('forget', 'know'), ('create', 'imagine'), ('do', 'happen'), ('win', 'accomplish'), ('give', 'deny'), ('deserve', 'earn'), ('get', 'put'), ('locate', 'find'), ('appear', 'attend'), ('know', 'comprehend'), ('pretend', 'imagine'), ('satisfy', 'please'), ('cherish', 'keep'), ('argue', 'differ'), ('overcome', 'dominate'), ('behave', 'obey'), ('cooperate', 'participate')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('achieve', 'try'), ('fail', 'discourage'), ('begin', 'quit'), ('say', 'participate'), ('come', 'bring'), ('declare', 'announce'), ('read', 'comprehend'), ('take', 'leave'), ('proclaim', 'announce'), ('acquire', 'obtain'), ('conclude', 'decide'), ('please', 'plead'), ('argue', 'prove'), ('ask', 'plead'), ('find', 'disappear'), ('inspect', 'examine'), ('verify', 'justify'), ('assume', 'predict'), ('learn', 'evaluate'), ('argue', 'justify')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('make', 'become'), ('discover', 'originate'), ('achieve', 'succeed'), ('give', 'put'), ('understand', 'listen'), ('expand', 'grow'), ('borrow', 'sell'), ('keep', 'protect'), ('explain', 'prove'), ('assume', 'pretend'), ('agree', 'please'), ('forgive', 'forget'), ('clarify', 'explain'), ('understand', 'forgive'), ('remind', 'forget'), ('get', 'remain'), ('realize', 'discover'), ('require', 'inquire'), ('ignore', 'ask'), ('think', 'inquire')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('reject', 'avoid'), ('argue', 'persuade'), ('pursue', 'persuade'), ('accept', 'forgive'), ('do', 'quit'), ('investigate', 'examine'), ('discuss', 'explain'), ('owe', 'lend'), ('explore', 'discover'), ('complain', 'argue'), ('withdraw', 'reject'), ('keep', 'borrow'), ('beg', 'ask'), ('arrange', 'organize'), ('reduce', 'shrink'), ('speak', 'acknowledge'), ('give', 'borrow'), ('kill', 'defend'), ('disappear', 'shrink'), ('deliver', 'carry')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('breathe', 'choke'), ('acknowledge', 'notify'), ('become', 'seem'), ('pretend', 'seem'), ('accomplish', 'become'), ('contemplate', 'think'), ('determine', 'predict'), ('please', 'entertain'), ('remain', 'retain'), ('pretend', 'portray'), ('forget', 'retain'), ('want', 'choose'), ('lose', 'get'), ('try', 'think'), ('become', 'appear'), ('leave', 'ignore'), ('accept', 'recommend'), ('leave', 'wander'), ('keep', 'give'), ('give', 'allow')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('bring', 'send'), ('absorb', 'learn'), ('acquire', 'find'), ('leave', 'appear'), ('create', 'destroy'), ('begin', 'go'), ('get', 'buy'), ('collect', 'save'), ('replace', 'restore'), ('join', 'add'), ('join', 'marry'), ('accept', 'deliver'), ('attach', 'join'), ('put', 'hang'), ('go', 'sell'), ('communicate', 'pray'), ('give', 'steal'), ('add', 'build'), ('bring', 'restore'), ('comprehend', 'satisfy')"]
# Two words are synonyms if they have very similar meanings. Synonyms represent the same type or category of thing. Here are some examples of synonym pairs: cup/mug, glasses/spectacles, envy/jealousy. In practice, word pairs that are not exactly synonymous may still be very similar. Here are some very similar pairs - we could say they are nearly synonyms: alligator/crocodile, love/affection, frog/toad. In contrast, although the following word pairs are related, they are not very similar. The words represent entirely different types of things: car/tyre, car/motorway, car/crash. Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Remember, things that are related are not necessarily similar. If you are ever unsure, think back to the examples of synonymous pairs (glasses/spectacles), and consider how close the words are (or are not) to being synonymous. There is no right answer to these questions. It is perfectly reasonable to use your intuition or gut feeling as a native English speaker, especially when you are asked to rate word pairs that you think are not similar at all. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Use two decimals. Do not provide additional explanations or context. --- ["('portray', 'decide'), ('organize', 'become'), ('give', 'know'), ('say', 'verify'), ('cooperate', 'join'), ('arrange', 'require'), ('borrow', 'want'), ('investigate', 'pursue'), ('ignore', 'explore'), ('bring', 'complain'), ('enter', 'owe'), ('portray', 'notify'), ('remind', 'sell'), ('absorb', 'possess'), ('join', 'acquire'), ('send', 'attend'), ('gather', 'attend'), ('absorb', 'withdraw'), ('attend', 'arrive')"]

# %%
# Load the encoding
encoding = tiktoken.get_encoding("cl100k_base")

# Count the tokens per chunk
token_counts = count_tokens_with_tiktoken(chunks, prompt)
print("Token counts for each formatted prompt:", token_counts)
# Out:
# Token counts for each formatted prompt: [445, 454, 448, 454, 456, 448, 441, 446, 446, 448, 445, 442, 439, 444, 442, 451, 448, 446, 455, 447, 445, 452, 455, 443, 443, 445, 449, 437, 454, 446, 449, 448, 444, 450, 440, 444, 446, 447, 446, 443, 446, 439, 439, 450, 445, 442, 451, 446, 437, 440]

# %%
# Number of total tokens
tokens = [445, 454, 448, 454, 456, 448, 441, 446, 446, 448, 445, 442, 439, 444, 442, 451, 448, 446, 455, 447, 445, 452, 455, 443, 443, 445, 449, 437, 454, 446, 449, 448, 444, 450, 440, 444, 446, 447, 446, 443, 446, 439, 439, 450, 445, 442, 451, 446, 437, 440]
sum(tokens)

# Total compute time = 2 hours 45 mins
# Out:
# 22306

# %% [markdown]
# ### **2. Extract and Process Data**

# %%
# Process each chunk and get results using the OpenAI API
response = get_responses(chunks, prompt, model, sample_size, delay)
# Out:
# Processing:   0%|          | 0/750 [00:00<?, ?chunk/s]
# Processing: 100%|██████████| 750/750 [2:56:01<00:00, 14.08s/chunk]
# Total time taken: 10561.54 seconds

# %%
# Define filepath
file_path = '../../../data/response/en/gpt-3.5-turbo-0125/f7.json'

# Check if the file already exists
if not os.path.exists(file_path):
    with open(file_path, 'w') as f:
        json.dump(response, f)
        print("File saved successfully.")
else:
    print("File already exists. JSON was not saved to prevent overwriting.")
# Out:
# File saved successfully.

# %%
# Extract data with regular expressions into dictionary
data_dict = process_responses(response)

# Check for values higher/lower then sample size
higher_lower_samples = {key: value for key, value in data_dict.items() if len(value) < sample_size or len(value) > sample_size}
print(higher_lower_samples)
# Out:
# {('actress', 'actor'): [9.0, 8.0, 9.0, 6.0, 9.0, 8.0, 8.0, 8.5, 9.0, 8.0, 8.0, 9.0, 8.0, 8.0], ('actor', 'actress'): [8.0]}

# %%
# Process data and print duplicate word pairs
print_duplicate_word_pairs(en_simlex, data_dict)
# Out:
# Empty DataFrame
# Columns: [Combined_Columns]
# Index: []
# Empty DataFrame
# Columns: [Combined_Columns]
# Index: []

# %%
# Convert dict to Pandas DataFrame
df = create_dataframe(data_dict)

# Show results
df
# Out:
#       word1        word2  similarity_score_1  similarity_score_2  \
# 0       old          new                 0.1                 0.1
# 1     smart  intelligent                 0.9                 0.9
# 2      hard    difficult                 0.3                 0.8
# 3     happy     cheerful                 0.8                 0.7
# 4      hard         easy                 0.1                 0.1
# ..      ...          ...                 ...                 ...
# 995    join      acquire                 1.0                 9.0
# 996    send       attend                 0.0                 0.0
# 997  gather       attend                 1.0                 0.0
# 998  absorb     withdraw                 0.0                 0.0
# 999  attend       arrive                 0.5                 0.0
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                   1.0                 0.2                 0.1
# 1                   1.0                 0.9                 0.9
# 2                   0.5                 0.7                 0.8
# 3                   0.2                 0.6                 0.7
# 4                   0.2                 0.1                 0.1
# ..                  ...                 ...                 ...
# 995                 0.3                 0.1                 1.0
# 996                 0.1                 0.1                 0.0
# 997                 0.8                 0.1                 1.0
# 998                 0.2                 0.1                 0.0
# 999                 0.2                 0.1                 1.0
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                   2.0                 0.1                 0.2
# 1                   9.0                 0.9                 0.9
# 2                   7.0                 0.8                 0.7
# 3                   8.0                 0.8                 0.8
# 4                   3.0                 0.1                 0.4
# ..                  ...                 ...                 ...
# 995                 0.0                 0.0                 1.0
# 996                 0.0                 0.0                 0.0
# 997                 0.0                 0.0                 0.5
# 998                 0.0                 0.0                 0.0
# 999                 0.0                 0.0                 0.0
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                  0.10                  0.2                  0.1
# 1                  0.90                  0.9                  0.9
# 2                  0.20                  0.9                  0.2
# 3                  0.90                  0.8                  0.9
# 4                  0.10                  0.1                  0.1
# ..                  ...                  ...                  ...
# 995                0.20                  1.0                  0.0
# 996                0.05                  0.0                  0.0
# 997                0.10                  1.0                  0.0
# 998                0.10                  0.0                  0.0
# 999                0.05                  0.0                  0.0
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                    0.1                  0.1                  3.0
# 1                    0.9                  0.9                  9.0
# 2                    0.4                  0.9                  6.0
# 3                    0.8                  0.7                  6.0
# 4                    0.2                  0.1                  2.0
# ..                   ...                  ...                  ...
# 995                  0.1                  0.0                  1.0
# 996                  0.1                  0.0                  0.0
# 997                  0.1                  0.0                  0.0
# 998                  0.1                  0.0                  0.0
# 999                  0.1                  0.0                  0.0
#
#      similarity_score_15
# 0                    1.0
# 1                    0.9
# 2                    0.8
# 3                    0.7
# 4                    0.1
# ..                   ...
# 995                  0.7
# 996                  0.1
# 997                  0.7
# 998                  0.3
# 999                  0.6
#
# [1000 rows x 17 columns]

# %%
# Count null values
count_null_values = df.isnull().sum()
print("Null value counts per column:", count_null_values)
# Out:
# Null value counts per column: word1                  0
# word2                  0
# similarity_score_1     0
# similarity_score_2     1
# similarity_score_3     1
# similarity_score_4     1
# similarity_score_5     1
# similarity_score_6     1
# similarity_score_7     1
# similarity_score_8     1
# similarity_score_9     1
# similarity_score_10    1
# similarity_score_11    1
# similarity_score_12    1
# similarity_score_13    1
# similarity_score_14    1
# similarity_score_15    2
# dtype: int64

# %%
# Check for rows with at least one null value
rows_with_null = df[df.isnull().any(axis=1)]
rows_with_null
# Out:
#        word1    word2  similarity_score_1  similarity_score_2  \
# 127  actress    actor                 9.0                 8.0
# 140    actor  actress                 8.0                 NaN
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 127                 9.0                 6.0                 9.0
# 140                 NaN                 NaN                 NaN
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 127                 8.0                 8.0                 8.5
# 140                 NaN                 NaN                 NaN
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 127                 9.0                  8.0                  8.0
# 140                 NaN                  NaN                  NaN
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 127                  9.0                  8.0                  8.0
# 140                  NaN                  NaN                  NaN
#
#      similarity_score_15
# 127                  NaN
# 140                  NaN

# %%
# Manually fix inconsistencies
df.loc[(df['word1'] == 'actress') & (df['word2'] == 'actor'), 'similarity_score_15'] = 8.00

# Check value
df.loc[(df['word1'] == 'actress') & (df['word2'] == 'actor')]
# Out:
#        word1  word2  similarity_score_1  similarity_score_2  \
# 127  actress  actor                 9.0                 8.0
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 127                 9.0                 6.0                 9.0
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 127                 8.0                 8.0                 8.5
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 127                 9.0                  8.0                  8.0
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 127                  9.0                  8.0                  8.0
#
#      similarity_score_15
# 127                  8.0

# %%
# Drop faulty row
df = df[~((df['word1'] == 'actor') & (df['word2'] == 'actress'))]
df
# Out:
#       word1        word2  similarity_score_1  similarity_score_2  \
# 0       old          new                 0.1                 0.1
# 1     smart  intelligent                 0.9                 0.9
# 2      hard    difficult                 0.3                 0.8
# 3     happy     cheerful                 0.8                 0.7
# 4      hard         easy                 0.1                 0.1
# ..      ...          ...                 ...                 ...
# 995    join      acquire                 1.0                 9.0
# 996    send       attend                 0.0                 0.0
# 997  gather       attend                 1.0                 0.0
# 998  absorb     withdraw                 0.0                 0.0
# 999  attend       arrive                 0.5                 0.0
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                   1.0                 0.2                 0.1
# 1                   1.0                 0.9                 0.9
# 2                   0.5                 0.7                 0.8
# 3                   0.2                 0.6                 0.7
# 4                   0.2                 0.1                 0.1
# ..                  ...                 ...                 ...
# 995                 0.3                 0.1                 1.0
# 996                 0.1                 0.1                 0.0
# 997                 0.8                 0.1                 1.0
# 998                 0.2                 0.1                 0.0
# 999                 0.2                 0.1                 1.0
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                   2.0                 0.1                 0.2
# 1                   9.0                 0.9                 0.9
# 2                   7.0                 0.8                 0.7
# 3                   8.0                 0.8                 0.8
# 4                   3.0                 0.1                 0.4
# ..                  ...                 ...                 ...
# 995                 0.0                 0.0                 1.0
# 996                 0.0                 0.0                 0.0
# 997                 0.0                 0.0                 0.5
# 998                 0.0                 0.0                 0.0
# 999                 0.0                 0.0                 0.0
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                  0.10                  0.2                  0.1
# 1                  0.90                  0.9                  0.9
# 2                  0.20                  0.9                  0.2
# 3                  0.90                  0.8                  0.9
# 4                  0.10                  0.1                  0.1
# ..                  ...                  ...                  ...
# 995                0.20                  1.0                  0.0
# 996                0.05                  0.0                  0.0
# 997                0.10                  1.0                  0.0
# 998                0.10                  0.0                  0.0
# 999                0.05                  0.0                  0.0
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                    0.1                  0.1                  3.0
# 1                    0.9                  0.9                  9.0
# 2                    0.4                  0.9                  6.0
# 3                    0.8                  0.7                  6.0
# 4                    0.2                  0.1                  2.0
# ..                   ...                  ...                  ...
# 995                  0.1                  0.0                  1.0
# 996                  0.1                  0.0                  0.0
# 997                  0.1                  0.0                  0.0
# 998                  0.1                  0.0                  0.0
# 999                  0.1                  0.0                  0.0
#
#      similarity_score_15
# 0                    1.0
# 1                    0.9
# 2                    0.8
# 3                    0.7
# 4                    0.1
# ..                   ...
# 995                  0.7
# 996                  0.1
# 997                  0.7
# 998                  0.3
# 999                  0.6
#
# [999 rows x 17 columns]

# %%
# Check for rows with at least one null value
rows_with_null = df[df.isnull().any(axis=1)]
rows_with_null
# Out:
# Empty DataFrame
# Columns: [word1, word2, similarity_score_1, similarity_score_2, similarity_score_3, similarity_score_4, similarity_score_5, similarity_score_6, similarity_score_7, similarity_score_8, similarity_score_9, similarity_score_10, similarity_score_11, similarity_score_12, similarity_score_13, similarity_score_14, similarity_score_15]
# Index: []

# %%
df
# Out:
#            word1        word2  similarity_score_1  similarity_score_2  \
# 0           slim  intelligent                8.76                9.50
# 1           hard     moeilijk                3.01                5.00
# 2       gelukkig      vrolijk                6.54                7.50
# 3           hard        stoer                2.56                3.00
# 4           snel   razendsnel                9.43                9.00
# ..           ...          ...                 ...                 ...
# 992  samenvoegen    verwerven                0.41                0.55
# 993       sturen     bijwonen                0.05                0.03
# 994   verzamelen     bijwonen                0.17                0.46
# 995      opnemen    intrekken                0.22                0.21
# 996     bijwonen     aankomen                0.20                0.11
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                  9.50                9.60                9.50
# 1                  6.00                2.00                6.00
# 2                  8.00                8.50                9.00
# 3                  3.00                1.00                5.00
# 4                  9.50                9.50                8.00
# ..                  ...                 ...                 ...
# 992                3.88                0.69                0.14
# 993                0.00                0.06                0.03
# 994                0.00                0.29                0.14
# 995                0.00                0.31                0.12
# 996                0.00                0.23                0.04
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                  8.50                7.84                7.50
# 1                  3.00                4.83                2.50
# 2                  7.00                7.39                7.50
# 3                  6.00                2.35                3.00
# 4                  9.00                9.17                8.50
# ..                  ...                 ...                 ...
# 992                0.51                4.00                0.47
# 993                0.06                0.00                0.00
# 994                0.30                2.62                0.57
# 995                0.50                1.67                0.18
# 996                0.19                2.00                0.12
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                  9.50                 6.00                 7.50
# 1                  3.00                 3.00                 4.00
# 2                  7.50                 7.00                 8.50
# 3                  4.00                 4.00                 4.00
# 4                  8.50                 9.00                 8.50
# ..                  ...                  ...                  ...
# 992                3.36                 1.70                 2.76
# 993                0.42                 0.06                 0.30
# 994                0.78                 1.06                 0.11
# 995                1.05                 0.22                 0.30
# 996                0.55                 2.02                 0.16
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                   8.50                 9.00                 9.50
# 1                   2.50                 6.00                 5.00
# 2                   7.50                 8.00                 8.50
# 3                   4.50                 7.00                 6.50
# 4                   8.50                 9.00                 8.75
# ..                   ...                  ...                  ...
# 992                 0.20                 4.69                 1.90
# 993                 0.00                 0.05                 0.04
# 994                 0.25                 0.09                 0.75
# 995                 0.05                 0.64                 1.28
# 996                 0.20                 1.91                 2.02
#
#      similarity_score_15
# 0                   9.20
# 1                   2.00
# 2                   7.50
# 3                   2.00
# 4                   9.30
# ..                   ...
# 992                 0.69
# 993                 0.00
# 994                 0.11
# 995                 0.09
# 996                 0.09
#
# [996 rows x 17 columns]

# %%
# Define file_path
file_path = '../../../data/prompt/en/gpt-3.5-turbo-0125/f7.csv'

# Check if the file already exists
if not os.path.exists(file_path):
    df.to_csv(file_path, index=False)
    print("File saved successfully.")
else:
    print("File already exists. Dataframe was not saved to prevent overwriting.")
# Out:
# File saved successfully.
