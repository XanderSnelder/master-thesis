# %% [markdown]
# ### **0. Set-up**

# %%
# Import libraries and utils
# %run '../../utils.ipynb'

# %%
# Get api key
load_dotenv()
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

# Set client
client = OpenAI()

# %%
# Load dataframe
en_simlex = pd.read_csv("../../../data/dataset/cleaned-en-simlex-999.csv")

# Remove first word pair
en_simlex = en_simlex.iloc[1:]

# Select subset
# en_simlex = en_simlex.head(100)

# Convert to tuple
tuples_list = list(zip(en_simlex['word1'], en_simlex['word2']))

# %%
# Show results
tuples_list
# Out:
# [('smart', 'intelligent'),
#  ('hard', 'difficult'),
#  ('happy', 'cheerful'),
#  ('hard', 'easy'),
#  ('fast', 'rapid'),
#  ('happy', 'glad'),
#  ('short', 'long'),
#  ('stupid', 'dumb'),
#  ('weird', 'strange'),
#  ('wide', 'narrow'),
#  ('bad', 'awful'),
#  ('easy', 'difficult'),
#  ('bad', 'terrible'),
#  ('hard', 'simple'),
#  ('smart', 'dumb'),
#  ('insane', 'crazy'),
#  ('happy', 'mad'),
#  ('large', 'huge'),
#  ('hard', 'tough'),
#  ('new', 'fresh'),
#  ('sharp', 'dull'),
#  ('quick', 'rapid'),
#  ('dumb', 'foolish'),
#  ('wonderful', 'terrific'),
#  ('strange', 'odd'),
#  ('happy', 'angry'),
#  ('narrow', 'broad'),
#  ('simple', 'easy'),
#  ('old', 'fresh'),
#  ('apparent', 'obvious'),
#  ('inexpensive', 'cheap'),
#  ('nice', 'generous'),
#  ('weird', 'normal'),
#  ('weird', 'odd'),
#  ('bad', 'immoral'),
#  ('sad', 'funny'),
#  ('wonderful', 'great'),
#  ('guilty', 'ashamed'),
#  ('beautiful', 'wonderful'),
#  ('confident', 'sure'),
#  ('dumb', 'dense'),
#  ('large', 'big'),
#  ('nice', 'cruel'),
#  ('impatient', 'anxious'),
#  ('big', 'broad'),
#  ('strong', 'proud'),
#  ('unnecessary', 'necessary'),
#  ('restless', 'young'),
#  ('dumb', 'intelligent'),
#  ('bad', 'great'),
#  ('difficult', 'simple'),
#  ('necessary', 'important'),
#  ('bad', 'terrific'),
#  ('mad', 'glad'),
#  ('honest', 'guilty'),
#  ('easy', 'tough'),
#  ('easy', 'flexible'),
#  ('certain', 'sure'),
#  ('essential', 'necessary'),
#  ('different', 'normal'),
#  ('sly', 'clever'),
#  ('crucial', 'important'),
#  ('harsh', 'cruel'),
#  ('childish', 'foolish'),
#  ('scarce', 'rare'),
#  ('friendly', 'generous'),
#  ('fragile', 'frigid'),
#  ('long', 'narrow'),
#  ('big', 'heavy'),
#  ('rough', 'frigid'),
#  ('bizarre', 'strange'),
#  ('illegal', 'immoral'),
#  ('bad', 'guilty'),
#  ('modern', 'ancient'),
#  ('new', 'ancient'),
#  ('dull', 'funny'),
#  ('happy', 'young'),
#  ('easy', 'big'),
#  ('great', 'awful'),
#  ('tiny', 'huge'),
#  ('polite', 'proper'),
#  ('modest', 'ashamed'),
#  ('exotic', 'rare'),
#  ('dumb', 'clever'),
#  ('delightful', 'wonderful'),
#  ('noticeable', 'obvious'),
#  ('afraid', 'anxious'),
#  ('formal', 'proper'),
#  ('dreary', 'dull'),
#  ('delightful', 'cheerful'),
#  ('unhappy', 'mad'),
#  ('sad', 'terrible'),
#  ('sick', 'crazy'),
#  ('violent', 'angry'),
#  ('laden', 'heavy'),
#  ('dirty', 'cheap'),
#  ('elastic', 'flexible'),
#  ('hard', 'dense'),
#  ('recent', 'new'),
#  ('bold', 'proud'),
#  ('sly', 'strange'),
#  ('strange', 'sly'),
#  ('dumb', 'rare'),
#  ('sly', 'tough'),
#  ('terrific', 'mad'),
#  ('modest', 'flexible'),
#  ('fresh', 'wide'),
#  ('huge', 'dumb'),
#  ('large', 'flexible'),
#  ('dirty', 'narrow'),
#  ('wife', 'husband'),
#  ('book', 'text'),
#  ('groom', 'bride'),
#  ('night', 'day'),
#  ('south', 'north'),
#  ('plane', 'airport'),
#  ('uncle', 'aunt'),
#  ('horse', 'mare'),
#  ('bottom', 'top'),
#  ('friend', 'buddy'),
#  ('student', 'pupil'),
#  ('world', 'globe'),
#  ('leg', 'arm'),
#  ('plane', 'jet'),
#  ('woman', 'man'),
#  ('horse', 'colt'),
#  ('actress', 'actor'),
#  ('teacher', 'instructor'),
#  ('movie', 'film'),
#  ('bird', 'hawk'),
#  ('word', 'dictionary'),
#  ('money', 'salary'),
#  ('dog', 'cat'),
#  ('area', 'region'),
#  ('navy', 'army'),
#  ('book', 'literature'),
#  ('clothes', 'closet'),
#  ('sunset', 'sunrise'),
#  ('child', 'adult'),
#  ('cow', 'cattle'),
#  ('book', 'story'),
#  ('winter', 'summer'),
#  ('taxi', 'cab'),
#  ('tree', 'maple'),
#  ('bed', 'bedroom'),
#  ('roof', 'ceiling'),
#  ('disease', 'infection'),
#  ('arm', 'shoulder'),
#  ('sheep', 'lamb'),
#  ('lady', 'gentleman'),
#  ('boat', 'anchor'),
#  ('priest', 'monk'),
#  ('toe', 'finger'),
#  ('river', 'stream'),
#  ('anger', 'fury'),
#  ('date', 'calendar'),
#  ('sea', 'ocean'),
#  ('second', 'minute'),
#  ('hand', 'thumb'),
#  ('wood', 'log'),
#  ('mud', 'dirt'),
#  ('hallway', 'corridor'),
#  ('way', 'manner'),
#  ('mouse', 'cat'),
#  ('cop', 'sheriff'),
#  ('death', 'burial'),
#  ('music', 'melody'),
#  ('beer', 'alcohol'),
#  ('mouth', 'lip'),
#  ('storm', 'hurricane'),
#  ('tax', 'income'),
#  ('flower', 'violet'),
#  ('paper', 'cardboard'),
#  ('floor', 'ceiling'),
#  ('beach', 'seashore'),
#  ('rod', 'curtain'),
#  ('hound', 'fox'),
#  ('street', 'alley'),
#  ('boat', 'deck'),
#  ('car', 'horn'),
#  ('friend', 'guest'),
#  ('employer', 'employee'),
#  ('hand', 'wrist'),
#  ('ball', 'cannon'),
#  ('alcohol', 'brandy'),
#  ('victory', 'triumph'),
#  ('telephone', 'booth'),
#  ('door', 'doorway'),
#  ('motel', 'inn'),
#  ('clothes', 'cloth'),
#  ('steak', 'meat'),
#  ('nail', 'thumb'),
#  ('band', 'orchestra'),
#  ('book', 'bible'),
#  ('business', 'industry'),
#  ('winter', 'season'),
#  ('decade', 'century'),
#  ('alcohol', 'gin'),
#  ('hat', 'coat'),
#  ('window', 'door'),
#  ('arm', 'wrist'),
#  ('house', 'apartment'),
#  ('glass', 'crystal'),
#  ('wine', 'brandy'),
#  ('creator', 'maker'),
#  ('dinner', 'breakfast'),
#  ('arm', 'muscle'),
#  ('bubble', 'suds'),
#  ('bread', 'flour'),
#  ('death', 'tragedy'),
#  ('absence', 'presence'),
#  ('gun', 'cannon'),
#  ('grass', 'blade'),
#  ('ball', 'basket'),
#  ('hose', 'garden'),
#  ('boy', 'kid'),
#  ('church', 'choir'),
#  ('clothes', 'drawer'),
#  ('tower', 'bell'),
#  ('father', 'parent'),
#  ('school', 'grade'),
#  ('parent', 'adult'),
#  ('bar', 'jail'),
#  ('car', 'highway'),
#  ('dictionary', 'definition'),
#  ('door', 'cellar'),
#  ('army', 'legion'),
#  ('metal', 'aluminum'),
#  ('chair', 'bench'),
#  ('cloud', 'fog'),
#  ('boy', 'son'),
#  ('water', 'ice'),
#  ('bed', 'blanket'),
#  ('attorney', 'lawyer'),
#  ('area', 'zone'),
#  ('business', 'company'),
#  ('clothes', 'fabric'),
#  ('sweater', 'jacket'),
#  ('money', 'capital'),
#  ('hand', 'foot'),
#  ('alcohol', 'cocktail'),
#  ('yard', 'inch'),
#  ('molecule', 'atom'),
#  ('lens', 'camera'),
#  ('meal', 'dinner'),
#  ('eye', 'tear'),
#  ('god', 'devil'),
#  ('loop', 'belt'),
#  ('rat', 'mouse'),
#  ('motor', 'engine'),
#  ('car', 'cab'),
#  ('cat', 'lion'),
#  ('size', 'magnitude'),
#  ('reality', 'fantasy'),
#  ('door', 'gate'),
#  ('cat', 'pet'),
#  ('tin', 'aluminum'),
#  ('bone', 'jaw'),
#  ('cereal', 'wheat'),
#  ('house', 'key'),
#  ('blood', 'flesh'),
#  ('door', 'corridor'),
#  ('god', 'spirit'),
#  ('capability', 'competence'),
#  ('abundance', 'plenty'),
#  ('sofa', 'chair'),
#  ('wall', 'brick'),
#  ('horn', 'drum'),
#  ('organ', 'liver'),
#  ('strength', 'might'),
#  ('phrase', 'word'),
#  ('band', 'parade'),
#  ('stomach', 'waist'),
#  ('cloud', 'storm'),
#  ('joy', 'pride'),
#  ('noise', 'rattle'),
#  ('rain', 'mist'),
#  ('beer', 'beverage'),
#  ('man', 'uncle'),
#  ('apple', 'juice'),
#  ('intelligence', 'logic'),
#  ('communication', 'language'),
#  ('mink', 'fur'),
#  ('mob', 'crowd'),
#  ('shore', 'coast'),
#  ('wire', 'cord'),
#  ('bird', 'turkey'),
#  ('bed', 'crib'),
#  ('competence', 'ability'),
#  ('cloud', 'haze'),
#  ('supper', 'meal'),
#  ('bar', 'cage'),
#  ('water', 'salt'),
#  ('sense', 'intuition'),
#  ('situation', 'condition'),
#  ('crime', 'theft'),
#  ('style', 'fashion'),
#  ('boundary', 'border'),
#  ('arm', 'body'),
#  ('boat', 'car'),
#  ('sandwich', 'lunch'),
#  ('bride', 'princess'),
#  ('heroine', 'hero'),
#  ('car', 'gauge'),
#  ('insect', 'bee'),
#  ('crib', 'cradle'),
#  ('animal', 'person'),
#  ('marijuana', 'herb'),
#  ('bed', 'hospital'),
#  ('cheek', 'tongue'),
#  ('disc', 'computer'),
#  ('curve', 'angle'),
#  ('grass', 'moss'),
#  ('school', 'law'),
#  ('foot', 'head'),
#  ('mother', 'guardian'),
#  ('orthodontist', 'dentist'),
#  ('alcohol', 'whiskey'),
#  ('mouth', 'tooth'),
#  ('breakfast', 'bacon'),
#  ('bathroom', 'bedroom'),
#  ('plate', 'bowl'),
#  ('meat', 'bacon'),
#  ('air', 'helium'),
#  ('worker', 'employer'),
#  ('body', 'chest'),
#  ('son', 'father'),
#  ('heart', 'surgery'),
#  ('woman', 'secretary'),
#  ('man', 'father'),
#  ('beach', 'island'),
#  ('story', 'topic'),
#  ('game', 'fun'),
#  ('weekend', 'week'),
#  ('couple', 'pair'),
#  ('woman', 'wife'),
#  ('sheep', 'cattle'),
#  ('purse', 'bag'),
#  ('ceiling', 'cathedral'),
#  ('bean', 'coffee'),
#  ('wood', 'paper'),
#  ('top', 'side'),
#  ('crime', 'fraud'),
#  ('pain', 'harm'),
#  ('lover', 'companion'),
#  ('evening', 'dusk'),
#  ('father', 'daughter'),
#  ('wine', 'liquor'),
#  ('cow', 'goat'),
#  ('belief', 'opinion'),
#  ('reality', 'illusion'),
#  ('pact', 'agreement'),
#  ('wealth', 'poverty'),
#  ('accident', 'emergency'),
#  ('battle', 'conquest'),
#  ('friend', 'teacher'),
#  ('illness', 'infection'),
#  ('game', 'trick'),
#  ('brother', 'son'),
#  ('aunt', 'nephew'),
#  ('worker', 'mechanic'),
#  ('doctor', 'orthodontist'),
#  ('oak', 'maple'),
#  ('bee', 'queen'),
#  ('car', 'bicycle'),
#  ('goal', 'quest'),
#  ('august', 'month'),
#  ('army', 'squad'),
#  ('cloud', 'weather'),
#  ('physician', 'doctor'),
#  ('canyon', 'valley'),
#  ('river', 'valley'),
#  ('sun', 'sky'),
#  ('target', 'arrow'),
#  ('chocolate', 'pie'),
#  ('circumstance', 'situation'),
#  ('opinion', 'choice'),
#  ('rhythm', 'melody'),
#  ('gut', 'nerve'),
#  ('day', 'dawn'),
#  ('cattle', 'beef'),
#  ('doctor', 'professor'),
#  ('arm', 'vein'),
#  ('room', 'bath'),
#  ('corporation', 'business'),
#  ('fun', 'football'),
#  ('hill', 'cliff'),
#  ('bone', 'ankle'),
#  ('apple', 'candy'),
#  ('helper', 'maid'),
#  ('leader', 'manager'),
#  ('lemon', 'tea'),
#  ('bee', 'ant'),
#  ('basketball', 'baseball'),
#  ('rice', 'bean'),
#  ('bed', 'furniture'),
#  ('emotion', 'passion'),
#  ('anarchy', 'chaos'),
#  ('crime', 'violation'),
#  ('machine', 'engine'),
#  ('beach', 'sea'),
#  ('alley', 'bowl'),
#  ('jar', 'bottle'),
#  ('strength', 'capability'),
#  ('seed', 'mustard'),
#  ('guitar', 'drum'),
#  ('opinion', 'idea'),
#  ('north', 'west'),
#  ('diet', 'salad'),
#  ('mother', 'wife'),
#  ('dad', 'mother'),
#  ('captain', 'sailor'),
#  ('meter', 'yard'),
#  ('beer', 'champagne'),
#  ('motor', 'boat'),
#  ('card', 'bridge'),
#  ('science', 'psychology'),
#  ('sinner', 'saint'),
#  ('destruction', 'construction'),
#  ('crowd', 'bunch'),
#  ('beach', 'reef'),
#  ('man', 'child'),
#  ('bread', 'cheese'),
#  ('champion', 'winner'),
#  ('celebration', 'ceremony'),
#  ('menu', 'order'),
#  ('king', 'princess'),
#  ('wealth', 'prestige'),
#  ('endurance', 'strength'),
#  ('danger', 'threat'),
#  ('god', 'priest'),
#  ('men', 'fraternity'),
#  ('buddy', 'companion'),
#  ('teacher', 'helper'),
#  ('body', 'stomach'),
#  ('tongue', 'throat'),
#  ('house', 'carpet'),
#  ('intelligence', 'skill'),
#  ('journey', 'conquest'),
#  ('god', 'prey'),
#  ('brother', 'soul'),
#  ('adversary', 'opponent'),
#  ('death', 'catastrophe'),
#  ('monster', 'demon'),
#  ('day', 'morning'),
#  ('man', 'victor'),
#  ('friend', 'guy'),
#  ('song', 'story'),
#  ('ray', 'sunshine'),
#  ('guy', 'stud'),
#  ('chicken', 'rice'),
#  ('box', 'elevator'),
#  ('butter', 'potato'),
#  ('apartment', 'furniture'),
#  ('lake', 'swamp'),
#  ('salad', 'vinegar'),
#  ('flower', 'bulb'),
#  ('cloud', 'mist'),
#  ('driver', 'pilot'),
#  ('sugar', 'honey'),
#  ('body', 'shoulder'),
#  ('idea', 'image'),
#  ('father', 'brother'),
#  ('moon', 'planet'),
#  ('ball', 'costume'),
#  ('rail', 'fence'),
#  ('room', 'bed'),
#  ('flower', 'bush'),
#  ('bone', 'knee'),
#  ('arm', 'knee'),
#  ('bottom', 'side'),
#  ('vessel', 'vein'),
#  ('cat', 'rabbit'),
#  ('meat', 'sandwich'),
#  ('belief', 'concept'),
#  ('intelligence', 'insight'),
#  ('attention', 'interest'),
#  ('attitude', 'confidence'),
#  ('right', 'justice'),
#  ('argument', 'agreement'),
#  ('depth', 'magnitude'),
#  ('medium', 'news'),
#  ('winner', 'candidate'),
#  ('birthday', 'date'),
#  ('fee', 'payment'),
#  ('bible', 'hymn'),
#  ('exit', 'doorway'),
#  ('man', 'sentry'),
#  ('aisle', 'hall'),
#  ('whiskey', 'gin'),
#  ('blood', 'marrow'),
#  ('oil', 'mink'),
#  ('floor', 'deck'),
#  ('roof', 'floor'),
#  ('door', 'floor'),
#  ('shoulder', 'head'),
#  ('wagon', 'carriage'),
#  ('car', 'carriage'),
#  ('elbow', 'ankle'),
#  ('wealth', 'fame'),
#  ('sorrow', 'shame'),
#  ('administration', 'management'),
#  ('communication', 'conversation'),
#  ('pollution', 'atmosphere'),
#  ('anatomy', 'biology'),
#  ('college', 'profession'),
#  ('book', 'topic'),
#  ('formula', 'equation'),
#  ('book', 'information'),
#  ('boy', 'partner'),
#  ('sky', 'universe'),
#  ('population', 'people'),
#  ('college', 'class'),
#  ('chief', 'mayor'),
#  ('rabbi', 'minister'),
#  ('meter', 'inch'),
#  ('polyester', 'cotton'),
#  ('lawyer', 'banker'),
#  ('violin', 'instrument'),
#  ('camp', 'cabin'),
#  ('pot', 'appliance'),
#  ('linen', 'fabric'),
#  ('whiskey', 'champagne'),
#  ('girl', 'child'),
#  ('cottage', 'cabin'),
#  ('bird', 'hen'),
#  ('racket', 'noise'),
#  ('sunset', 'evening'),
#  ('drizzle', 'rain'),
#  ('adult', 'baby'),
#  ('charcoal', 'coal'),
#  ('body', 'spine'),
#  ('head', 'nail'),
#  ('log', 'timber'),
#  ('spoon', 'cup'),
#  ('body', 'nerve'),
#  ('man', 'husband'),
#  ('bone', 'neck'),
#  ('frustration', 'anger'),
#  ('river', 'sea'),
#  ('task', 'job'),
#  ('club', 'society'),
#  ('reflection', 'image'),
#  ('prince', 'king'),
#  ('snow', 'weather'),
#  ('people', 'party'),
#  ('boy', 'brother'),
#  ('root', 'grass'),
#  ('brow', 'eye'),
#  ('money', 'pearl'),
#  ('money', 'diamond'),
#  ('vehicle', 'bus'),
#  ('cab', 'bus'),
#  ('house', 'barn'),
#  ('finger', 'palm'),
#  ('car', 'bridge'),
#  ('effort', 'difficulty'),
#  ('fact', 'insight'),
#  ('job', 'management'),
#  ('cancer', 'sickness'),
#  ('word', 'newspaper'),
#  ('composer', 'writer'),
#  ('actor', 'singer'),
#  ('shelter', 'hut'),
#  ('bathroom', 'kitchen'),
#  ('cabin', 'hut'),
#  ('door', 'kitchen'),
#  ('value', 'belief'),
#  ('wisdom', 'intelligence'),
#  ('ignorance', 'intelligence'),
#  ('happiness', 'luck'),
#  ('idea', 'scheme'),
#  ('mood', 'emotion'),
#  ('happiness', 'peace'),
#  ('despair', 'misery'),
#  ('logic', 'arithmetic'),
#  ('denial', 'confession'),
#  ('argument', 'criticism'),
#  ('aggression', 'hostility'),
#  ('hysteria', 'confusion'),
#  ('chemistry', 'theory'),
#  ('trial', 'verdict'),
#  ('comfort', 'safety'),
#  ('confidence', 'self'),
#  ('vision', 'perception'),
#  ('era', 'decade'),
#  ('biography', 'fiction'),
#  ('discussion', 'argument'),
#  ('code', 'symbol'),
#  ('danger', 'disease'),
#  ('accident', 'catastrophe'),
#  ('journey', 'trip'),
#  ('activity', 'movement'),
#  ('gossip', 'news'),
#  ('father', 'god'),
#  ('action', 'course'),
#  ('fever', 'illness'),
#  ('aviation', 'flight'),
#  ('game', 'action'),
#  ('molecule', 'air'),
#  ('home', 'state'),
#  ('word', 'literature'),
#  ('adult', 'guardian'),
#  ('newspaper', 'information'),
#  ('communication', 'television'),
#  ('cousin', 'uncle'),
#  ('author', 'reader'),
#  ('guy', 'partner'),
#  ('area', 'corner'),
#  ('ballad', 'song'),
#  ('wall', 'decoration'),
#  ('word', 'page'),
#  ('nurse', 'scientist'),
#  ('politician', 'president'),
#  ('president', 'mayor'),
#  ('book', 'essay'),
#  ('man', 'warrior'),
#  ('article', 'journal'),
#  ('breakfast', 'supper'),
#  ('crowd', 'parade'),
#  ('aisle', 'hallway'),
#  ('teacher', 'rabbi'),
#  ('hip', 'lip'),
#  ('book', 'article'),
#  ('room', 'cell'),
#  ('box', 'booth'),
#  ('daughter', 'kid'),
#  ('limb', 'leg'),
#  ('liver', 'lung'),
#  ('classroom', 'hallway'),
#  ('mountain', 'ledge'),
#  ('car', 'elevator'),
#  ('bed', 'couch'),
#  ('clothes', 'button'),
#  ('clothes', 'coat'),
#  ('kidney', 'organ'),
#  ('apple', 'sauce'),
#  ('chicken', 'steak'),
#  ('car', 'hose'),
#  ('tobacco', 'cigarette'),
#  ('student', 'professor'),
#  ('baby', 'daughter'),
#  ('pipe', 'cigar'),
#  ('milk', 'juice'),
#  ('box', 'cigar'),
#  ('apartment', 'hotel'),
#  ('cup', 'cone'),
#  ('horse', 'ox'),
#  ('throat', 'nose'),
#  ('bone', 'teeth'),
#  ('bone', 'elbow'),
#  ('bacon', 'bean'),
#  ('cup', 'jar'),
#  ('proof', 'fact'),
#  ('appointment', 'engagement'),
#  ('birthday', 'year'),
#  ('word', 'clue'),
#  ('author', 'creator'),
#  ('atom', 'carbon'),
#  ('archbishop', 'bishop'),
#  ('letter', 'paragraph'),
#  ('page', 'paragraph'),
#  ('steeple', 'chapel'),
#  ('muscle', 'bone'),
#  ('muscle', 'tongue'),
#  ('boy', 'soldier'),
#  ('belly', 'abdomen'),
#  ('guy', 'girl'),
#  ('bed', 'chair'),
#  ('clothes', 'jacket'),
#  ('gun', 'knife'),
#  ('tin', 'metal'),
#  ('bottle', 'container'),
#  ('hen', 'turkey'),
#  ('meat', 'bread'),
#  ('arm', 'bone'),
#  ('neck', 'spine'),
#  ('apple', 'lemon'),
#  ('agony', 'grief'),
#  ('assignment', 'task'),
#  ('night', 'dawn'),
#  ('dinner', 'soup'),
#  ('calf', 'bull'),
#  ('snow', 'storm'),
#  ('nail', 'hand'),
#  ('dog', 'horse'),
#  ('arm', 'neck'),
#  ('ball', 'glove'),
#  ('flu', 'fever'),
#  ('fee', 'salary'),
#  ('nerve', 'brain'),
#  ('beast', 'animal'),
#  ('dinner', 'chicken'),
#  ('girl', 'maid'),
#  ('child', 'boy'),
#  ('alcohol', 'wine'),
#  ('nose', 'mouth'),
#  ('street', 'car'),
#  ('bell', 'door'),
#  ('box', 'hat'),
#  ('belief', 'impression'),
#  ('bias', 'opinion'),
#  ('attention', 'awareness'),
#  ('anger', 'mood'),
#  ('elegance', 'style'),
#  ('beauty', 'age'),
#  ('book', 'theme'),
#  ('friend', 'mother'),
#  ('vitamin', 'iron'),
#  ('car', 'factory'),
#  ('pact', 'condition'),
#  ('chapter', 'choice'),
#  ('arithmetic', 'rhythm'),
#  ('winner', 'presence'),
#  ('belief', 'flower'),
#  ('winner', 'goal'),
#  ('trick', 'size'),
#  ('choice', 'vein'),
#  ('hymn', 'conquest'),
#  ('endurance', 'band'),
#  ('jail', 'choice'),
#  ('condition', 'boy'),
#  ('flower', 'endurance'),
#  ('hole', 'agreement'),
#  ('doctor', 'temper'),
#  ('fraternity', 'door'),
#  ('task', 'woman'),
#  ('fraternity', 'baseball'),
#  ('cent', 'size'),
#  ('presence', 'door'),
#  ('mouse', 'management'),
#  ('task', 'highway'),
#  ('liquor', 'century'),
#  ('task', 'straw'),
#  ('island', 'task'),
#  ('night', 'chapter'),
#  ('pollution', 'president'),
#  ('gun', 'trick'),
#  ('bath', 'trick'),
#  ('diet', 'apple'),
#  ('cent', 'wife'),
#  ('chapter', 'tail'),
#  ('course', 'stomach'),
#  ('hymn', 'straw'),
#  ('dentist', 'colonel'),
#  ('wife', 'straw'),
#  ('hole', 'wife'),
#  ('pupil', 'president'),
#  ('bath', 'wife'),
#  ('people', 'cent'),
#  ('formula', 'log'),
#  ('woman', 'fur'),
#  ('apple', 'sunshine'),
#  ('gun', 'dawn'),
#  ('meal', 'waist'),
#  ('camera', 'president'),
#  ('liquor', 'band'),
#  ('stomach', 'vein'),
#  ('gun', 'fur'),
#  ('couch', 'baseball'),
#  ('worker', 'camera'),
#  ('deck', 'mouse'),
#  ('rice', 'boy'),
#  ('people', 'gun'),
#  ('cliff', 'tail'),
#  ('ankle', 'window'),
#  ('princess', 'island'),
#  ('container', 'mouse'),
#  ('wagon', 'container'),
#  ('people', 'balloon'),
#  ('dollar', 'people'),
#  ('bath', 'balloon'),
#  ('stomach', 'bedroom'),
#  ('bicycle', 'bedroom'),
#  ('log', 'bath'),
#  ('bowl', 'tail'),
#  ('go', 'come'),
#  ('take', 'steal'),
#  ('listen', 'hear'),
#  ('think', 'rationalize'),
#  ('occur', 'happen'),
#  ('vanish', 'disappear'),
#  ('multiply', 'divide'),
#  ('plead', 'beg'),
#  ('begin', 'originate'),
#  ('protect', 'defend'),
#  ('kill', 'destroy'),
#  ('create', 'make'),
#  ('accept', 'reject'),
#  ('ignore', 'avoid'),
#  ('carry', 'bring'),
#  ('leave', 'enter'),
#  ('choose', 'elect'),
#  ('lose', 'fail'),
#  ('encourage', 'discourage'),
#  ('achieve', 'accomplish'),
#  ('make', 'construct'),
#  ('listen', 'obey'),
#  ('inform', 'notify'),
#  ('receive', 'give'),
#  ('borrow', 'beg'),
#  ('take', 'obtain'),
#  ('advise', 'recommend'),
#  ('imitate', 'portray'),
#  ('win', 'succeed'),
#  ('think', 'decide'),
#  ('greet', 'meet'),
#  ('agree', 'argue'),
#  ('enjoy', 'entertain'),
#  ('destroy', 'make'),
#  ('save', 'protect'),
#  ('give', 'lend'),
#  ('understand', 'know'),
#  ('take', 'receive'),
#  ('accept', 'acknowledge'),
#  ('decide', 'choose'),
#  ('accept', 'believe'),
#  ('keep', 'possess'),
#  ('roam', 'wander'),
#  ('succeed', 'fail'),
#  ('spend', 'save'),
#  ('leave', 'go'),
#  ('come', 'attend'),
#  ('know', 'believe'),
#  ('gather', 'meet'),
#  ('make', 'earn'),
#  ('forget', 'ignore'),
#  ('multiply', 'add'),
#  ('shrink', 'grow'),
#  ('arrive', 'leave'),
#  ('succeed', 'try'),
#  ('accept', 'deny'),
#  ('arrive', 'come'),
#  ('agree', 'differ'),
#  ('send', 'receive'),
#  ('win', 'dominate'),
#  ('add', 'divide'),
#  ('kill', 'choke'),
#  ('acquire', 'get'),
#  ('participate', 'join'),
#  ('leave', 'remain'),
#  ('go', 'enter'),
#  ('take', 'carry'),
#  ('forget', 'learn'),
#  ('appoint', 'elect'),
#  ('engage', 'marry'),
#  ('ask', 'pray'),
#  ('go', 'send'),
#  ('take', 'deliver'),
#  ('speak', 'hear'),
#  ('analyze', 'evaluate'),
#  ('argue', 'rationalize'),
#  ('lose', 'keep'),
#  ('compare', 'analyze'),
#  ('disorganize', 'organize'),
#  ('go', 'allow'),
#  ('take', 'possess'),
#  ('learn', 'listen'),
#  ('destroy', 'construct'),
#  ('create', 'build'),
#  ('steal', 'buy'),
#  ('kill', 'hang'),
#  ('forget', 'know'),
#  ('create', 'imagine'),
#  ('do', 'happen'),
#  ('win', 'accomplish'),
#  ('give', 'deny'),
#  ('deserve', 'earn'),
#  ('get', 'put'),
#  ('locate', 'find'),
#  ('appear', 'attend'),
#  ('know', 'comprehend'),
#  ('pretend', 'imagine'),
#  ('satisfy', 'please'),
#  ('cherish', 'keep'),
#  ('argue', 'differ'),
#  ('overcome', 'dominate'),
#  ('behave', 'obey'),
#  ('cooperate', 'participate'),
#  ('achieve', 'try'),
#  ('fail', 'discourage'),
#  ('begin', 'quit'),
#  ('say', 'participate'),
#  ('come', 'bring'),
#  ('declare', 'announce'),
#  ('read', 'comprehend'),
#  ('take', 'leave'),
#  ('proclaim', 'announce'),
#  ('acquire', 'obtain'),
#  ('conclude', 'decide'),
#  ('please', 'plead'),
#  ('argue', 'prove'),
#  ('ask', 'plead'),
#  ('find', 'disappear'),
#  ('inspect', 'examine'),
#  ('verify', 'justify'),
#  ('assume', 'predict'),
#  ('learn', 'evaluate'),
#  ('argue', 'justify'),
#  ('make', 'become'),
#  ('discover', 'originate'),
#  ('achieve', 'succeed'),
#  ('give', 'put'),
#  ('understand', 'listen'),
#  ('expand', 'grow'),
#  ('borrow', 'sell'),
#  ('keep', 'protect'),
#  ('explain', 'prove'),
#  ('assume', 'pretend'),
#  ('agree', 'please'),
#  ('forgive', 'forget'),
#  ('clarify', 'explain'),
#  ('understand', 'forgive'),
#  ('remind', 'forget'),
#  ('get', 'remain'),
#  ('realize', 'discover'),
#  ('require', 'inquire'),
#  ('ignore', 'ask'),
#  ('think', 'inquire'),
#  ('reject', 'avoid'),
#  ('argue', 'persuade'),
#  ('pursue', 'persuade'),
#  ('accept', 'forgive'),
#  ('do', 'quit'),
#  ('investigate', 'examine'),
#  ('discuss', 'explain'),
#  ('owe', 'lend'),
#  ('explore', 'discover'),
#  ('complain', 'argue'),
#  ('withdraw', 'reject'),
#  ('keep', 'borrow'),
#  ('beg', 'ask'),
#  ('arrange', 'organize'),
#  ('reduce', 'shrink'),
#  ('speak', 'acknowledge'),
#  ('give', 'borrow'),
#  ('kill', 'defend'),
#  ('disappear', 'shrink'),
#  ('deliver', 'carry'),
#  ('breathe', 'choke'),
#  ('acknowledge', 'notify'),
#  ('become', 'seem'),
#  ('pretend', 'seem'),
#  ('accomplish', 'become'),
#  ('contemplate', 'think'),
#  ('determine', 'predict'),
#  ('please', 'entertain'),
#  ('remain', 'retain'),
#  ('pretend', 'portray'),
#  ('forget', 'retain'),
#  ('want', 'choose'),
#  ('lose', 'get'),
#  ('try', 'think'),
#  ('become', 'appear'),
#  ('leave', 'ignore'),
#  ('accept', 'recommend'),
#  ('leave', 'wander'),
#  ('keep', 'give'),
#  ('give', 'allow'),
#  ('bring', 'send'),
#  ('absorb', 'learn'),
#  ('acquire', 'find'),
#  ('leave', 'appear'),
#  ('create', 'destroy'),
#  ('begin', 'go'),
#  ('get', 'buy'),
#  ('collect', 'save'),
#  ('replace', 'restore'),
#  ('join', 'add'),
#  ('join', 'marry'),
#  ('accept', 'deliver'),
#  ('attach', 'join'),
#  ('put', 'hang'),
#  ('go', 'sell'),
#  ('communicate', 'pray'),
#  ('give', 'steal'),
#  ('add', 'build'),
#  ('bring', 'restore'),
#  ('comprehend', 'satisfy'),
#  ('portray', 'decide'),
#  ('organize', 'become'),
#  ('give', 'know'),
#  ('say', 'verify'),
#  ('cooperate', 'join'),
#  ('arrange', 'require'),
#  ('borrow', 'want'),
#  ('investigate', 'pursue'),
#  ('ignore', 'explore'),
#  ('bring', 'complain'),
#  ('enter', 'owe'),
#  ('portray', 'notify'),
#  ('remind', 'sell'),
#  ('absorb', 'possess'),
#  ('join', 'acquire'),
#  ('send', 'attend'),
#  ('gather', 'attend'),
#  ('absorb', 'withdraw'),
#  ('attend', 'arrive')]

# %% [markdown]
# ### **1. Define and Evaluate Parameters**

# %%
# Define prompt
prompt = ("Rate the semantic similarity of each word pair on a scale from 0 to 10, "
          "where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. "
          "Use two decimals. The response should strictly adhere to the structure: "
          "[('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. "
          "Do not provide additional explanations or context. "
          "An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)]")

# %%
# Define model
model = "gpt-3.5-turbo-0125"

# Set sample size
sample_size = 15

# Delay between individual API calls
delay = 15.0

# Define number of sublists
n_sublists = 25

# %%
# Split list
chunks = split_into_n_lists(tuples_list, n_sublists)

# Count the number of lists
print(len(chunks))
# Out:
# 25

# %%
# Print prompts for each chunk
print_prompts(chunks, prompt)
# Out:
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('smart', 'intelligent'), ('hard', 'difficult'), ('happy', 'cheerful'), ('hard', 'easy'), ('fast', 'rapid'), ('happy', 'glad'), ('short', 'long'), ('stupid', 'dumb'), ('weird', 'strange'), ('wide', 'narrow'), ('bad', 'awful'), ('easy', 'difficult'), ('bad', 'terrible'), ('hard', 'simple'), ('smart', 'dumb'), ('insane', 'crazy'), ('happy', 'mad'), ('large', 'huge'), ('hard', 'tough'), ('new', 'fresh'), ('sharp', 'dull'), ('quick', 'rapid'), ('dumb', 'foolish'), ('wonderful', 'terrific'), ('strange', 'odd'), ('happy', 'angry'), ('narrow', 'broad'), ('simple', 'easy'), ('old', 'fresh'), ('apparent', 'obvious'), ('inexpensive', 'cheap'), ('nice', 'generous'), ('weird', 'normal'), ('weird', 'odd'), ('bad', 'immoral'), ('sad', 'funny'), ('wonderful', 'great'), ('guilty', 'ashamed'), ('beautiful', 'wonderful'), ('confident', 'sure')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('dumb', 'dense'), ('large', 'big'), ('nice', 'cruel'), ('impatient', 'anxious'), ('big', 'broad'), ('strong', 'proud'), ('unnecessary', 'necessary'), ('restless', 'young'), ('dumb', 'intelligent'), ('bad', 'great'), ('difficult', 'simple'), ('necessary', 'important'), ('bad', 'terrific'), ('mad', 'glad'), ('honest', 'guilty'), ('easy', 'tough'), ('easy', 'flexible'), ('certain', 'sure'), ('essential', 'necessary'), ('different', 'normal'), ('sly', 'clever'), ('crucial', 'important'), ('harsh', 'cruel'), ('childish', 'foolish'), ('scarce', 'rare'), ('friendly', 'generous'), ('fragile', 'frigid'), ('long', 'narrow'), ('big', 'heavy'), ('rough', 'frigid'), ('bizarre', 'strange'), ('illegal', 'immoral'), ('bad', 'guilty'), ('modern', 'ancient'), ('new', 'ancient'), ('dull', 'funny'), ('happy', 'young'), ('easy', 'big'), ('great', 'awful'), ('tiny', 'huge')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('polite', 'proper'), ('modest', 'ashamed'), ('exotic', 'rare'), ('dumb', 'clever'), ('delightful', 'wonderful'), ('noticeable', 'obvious'), ('afraid', 'anxious'), ('formal', 'proper'), ('dreary', 'dull'), ('delightful', 'cheerful'), ('unhappy', 'mad'), ('sad', 'terrible'), ('sick', 'crazy'), ('violent', 'angry'), ('laden', 'heavy'), ('dirty', 'cheap'), ('elastic', 'flexible'), ('hard', 'dense'), ('recent', 'new'), ('bold', 'proud'), ('sly', 'strange'), ('strange', 'sly'), ('dumb', 'rare'), ('sly', 'tough'), ('terrific', 'mad'), ('modest', 'flexible'), ('fresh', 'wide'), ('huge', 'dumb'), ('large', 'flexible'), ('dirty', 'narrow'), ('wife', 'husband'), ('book', 'text'), ('groom', 'bride'), ('night', 'day'), ('south', 'north'), ('plane', 'airport'), ('uncle', 'aunt'), ('horse', 'mare'), ('bottom', 'top'), ('friend', 'buddy')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('student', 'pupil'), ('world', 'globe'), ('leg', 'arm'), ('plane', 'jet'), ('woman', 'man'), ('horse', 'colt'), ('actress', 'actor'), ('teacher', 'instructor'), ('movie', 'film'), ('bird', 'hawk'), ('word', 'dictionary'), ('money', 'salary'), ('dog', 'cat'), ('area', 'region'), ('navy', 'army'), ('book', 'literature'), ('clothes', 'closet'), ('sunset', 'sunrise'), ('child', 'adult'), ('cow', 'cattle'), ('book', 'story'), ('winter', 'summer'), ('taxi', 'cab'), ('tree', 'maple'), ('bed', 'bedroom'), ('roof', 'ceiling'), ('disease', 'infection'), ('arm', 'shoulder'), ('sheep', 'lamb'), ('lady', 'gentleman'), ('boat', 'anchor'), ('priest', 'monk'), ('toe', 'finger'), ('river', 'stream'), ('anger', 'fury'), ('date', 'calendar'), ('sea', 'ocean'), ('second', 'minute'), ('hand', 'thumb'), ('wood', 'log')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('mud', 'dirt'), ('hallway', 'corridor'), ('way', 'manner'), ('mouse', 'cat'), ('cop', 'sheriff'), ('death', 'burial'), ('music', 'melody'), ('beer', 'alcohol'), ('mouth', 'lip'), ('storm', 'hurricane'), ('tax', 'income'), ('flower', 'violet'), ('paper', 'cardboard'), ('floor', 'ceiling'), ('beach', 'seashore'), ('rod', 'curtain'), ('hound', 'fox'), ('street', 'alley'), ('boat', 'deck'), ('car', 'horn'), ('friend', 'guest'), ('employer', 'employee'), ('hand', 'wrist'), ('ball', 'cannon'), ('alcohol', 'brandy'), ('victory', 'triumph'), ('telephone', 'booth'), ('door', 'doorway'), ('motel', 'inn'), ('clothes', 'cloth'), ('steak', 'meat'), ('nail', 'thumb'), ('band', 'orchestra'), ('book', 'bible'), ('business', 'industry'), ('winter', 'season'), ('decade', 'century'), ('alcohol', 'gin'), ('hat', 'coat'), ('window', 'door')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('arm', 'wrist'), ('house', 'apartment'), ('glass', 'crystal'), ('wine', 'brandy'), ('creator', 'maker'), ('dinner', 'breakfast'), ('arm', 'muscle'), ('bubble', 'suds'), ('bread', 'flour'), ('death', 'tragedy'), ('absence', 'presence'), ('gun', 'cannon'), ('grass', 'blade'), ('ball', 'basket'), ('hose', 'garden'), ('boy', 'kid'), ('church', 'choir'), ('clothes', 'drawer'), ('tower', 'bell'), ('father', 'parent'), ('school', 'grade'), ('parent', 'adult'), ('bar', 'jail'), ('car', 'highway'), ('dictionary', 'definition'), ('door', 'cellar'), ('army', 'legion'), ('metal', 'aluminum'), ('chair', 'bench'), ('cloud', 'fog'), ('boy', 'son'), ('water', 'ice'), ('bed', 'blanket'), ('attorney', 'lawyer'), ('area', 'zone'), ('business', 'company'), ('clothes', 'fabric'), ('sweater', 'jacket'), ('money', 'capital'), ('hand', 'foot')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('alcohol', 'cocktail'), ('yard', 'inch'), ('molecule', 'atom'), ('lens', 'camera'), ('meal', 'dinner'), ('eye', 'tear'), ('god', 'devil'), ('loop', 'belt'), ('rat', 'mouse'), ('motor', 'engine'), ('car', 'cab'), ('cat', 'lion'), ('size', 'magnitude'), ('reality', 'fantasy'), ('door', 'gate'), ('cat', 'pet'), ('tin', 'aluminum'), ('bone', 'jaw'), ('cereal', 'wheat'), ('house', 'key'), ('blood', 'flesh'), ('door', 'corridor'), ('god', 'spirit'), ('capability', 'competence'), ('abundance', 'plenty'), ('sofa', 'chair'), ('wall', 'brick'), ('horn', 'drum'), ('organ', 'liver'), ('strength', 'might'), ('phrase', 'word'), ('band', 'parade'), ('stomach', 'waist'), ('cloud', 'storm'), ('joy', 'pride'), ('noise', 'rattle'), ('rain', 'mist'), ('beer', 'beverage'), ('man', 'uncle'), ('apple', 'juice')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('intelligence', 'logic'), ('communication', 'language'), ('mink', 'fur'), ('mob', 'crowd'), ('shore', 'coast'), ('wire', 'cord'), ('bird', 'turkey'), ('bed', 'crib'), ('competence', 'ability'), ('cloud', 'haze'), ('supper', 'meal'), ('bar', 'cage'), ('water', 'salt'), ('sense', 'intuition'), ('situation', 'condition'), ('crime', 'theft'), ('style', 'fashion'), ('boundary', 'border'), ('arm', 'body'), ('boat', 'car'), ('sandwich', 'lunch'), ('bride', 'princess'), ('heroine', 'hero'), ('car', 'gauge'), ('insect', 'bee'), ('crib', 'cradle'), ('animal', 'person'), ('marijuana', 'herb'), ('bed', 'hospital'), ('cheek', 'tongue'), ('disc', 'computer'), ('curve', 'angle'), ('grass', 'moss'), ('school', 'law'), ('foot', 'head'), ('mother', 'guardian'), ('orthodontist', 'dentist'), ('alcohol', 'whiskey'), ('mouth', 'tooth'), ('breakfast', 'bacon')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('bathroom', 'bedroom'), ('plate', 'bowl'), ('meat', 'bacon'), ('air', 'helium'), ('worker', 'employer'), ('body', 'chest'), ('son', 'father'), ('heart', 'surgery'), ('woman', 'secretary'), ('man', 'father'), ('beach', 'island'), ('story', 'topic'), ('game', 'fun'), ('weekend', 'week'), ('couple', 'pair'), ('woman', 'wife'), ('sheep', 'cattle'), ('purse', 'bag'), ('ceiling', 'cathedral'), ('bean', 'coffee'), ('wood', 'paper'), ('top', 'side'), ('crime', 'fraud'), ('pain', 'harm'), ('lover', 'companion'), ('evening', 'dusk'), ('father', 'daughter'), ('wine', 'liquor'), ('cow', 'goat'), ('belief', 'opinion'), ('reality', 'illusion'), ('pact', 'agreement'), ('wealth', 'poverty'), ('accident', 'emergency'), ('battle', 'conquest'), ('friend', 'teacher'), ('illness', 'infection'), ('game', 'trick'), ('brother', 'son'), ('aunt', 'nephew')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('worker', 'mechanic'), ('doctor', 'orthodontist'), ('oak', 'maple'), ('bee', 'queen'), ('car', 'bicycle'), ('goal', 'quest'), ('august', 'month'), ('army', 'squad'), ('cloud', 'weather'), ('physician', 'doctor'), ('canyon', 'valley'), ('river', 'valley'), ('sun', 'sky'), ('target', 'arrow'), ('chocolate', 'pie'), ('circumstance', 'situation'), ('opinion', 'choice'), ('rhythm', 'melody'), ('gut', 'nerve'), ('day', 'dawn'), ('cattle', 'beef'), ('doctor', 'professor'), ('arm', 'vein'), ('room', 'bath'), ('corporation', 'business'), ('fun', 'football'), ('hill', 'cliff'), ('bone', 'ankle'), ('apple', 'candy'), ('helper', 'maid'), ('leader', 'manager'), ('lemon', 'tea'), ('bee', 'ant'), ('basketball', 'baseball'), ('rice', 'bean'), ('bed', 'furniture'), ('emotion', 'passion'), ('anarchy', 'chaos'), ('crime', 'violation'), ('machine', 'engine')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('beach', 'sea'), ('alley', 'bowl'), ('jar', 'bottle'), ('strength', 'capability'), ('seed', 'mustard'), ('guitar', 'drum'), ('opinion', 'idea'), ('north', 'west'), ('diet', 'salad'), ('mother', 'wife'), ('dad', 'mother'), ('captain', 'sailor'), ('meter', 'yard'), ('beer', 'champagne'), ('motor', 'boat'), ('card', 'bridge'), ('science', 'psychology'), ('sinner', 'saint'), ('destruction', 'construction'), ('crowd', 'bunch'), ('beach', 'reef'), ('man', 'child'), ('bread', 'cheese'), ('champion', 'winner'), ('celebration', 'ceremony'), ('menu', 'order'), ('king', 'princess'), ('wealth', 'prestige'), ('endurance', 'strength'), ('danger', 'threat'), ('god', 'priest'), ('men', 'fraternity'), ('buddy', 'companion'), ('teacher', 'helper'), ('body', 'stomach'), ('tongue', 'throat'), ('house', 'carpet'), ('intelligence', 'skill'), ('journey', 'conquest'), ('god', 'prey')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('brother', 'soul'), ('adversary', 'opponent'), ('death', 'catastrophe'), ('monster', 'demon'), ('day', 'morning'), ('man', 'victor'), ('friend', 'guy'), ('song', 'story'), ('ray', 'sunshine'), ('guy', 'stud'), ('chicken', 'rice'), ('box', 'elevator'), ('butter', 'potato'), ('apartment', 'furniture'), ('lake', 'swamp'), ('salad', 'vinegar'), ('flower', 'bulb'), ('cloud', 'mist'), ('driver', 'pilot'), ('sugar', 'honey'), ('body', 'shoulder'), ('idea', 'image'), ('father', 'brother'), ('moon', 'planet'), ('ball', 'costume'), ('rail', 'fence'), ('room', 'bed'), ('flower', 'bush'), ('bone', 'knee'), ('arm', 'knee'), ('bottom', 'side'), ('vessel', 'vein'), ('cat', 'rabbit'), ('meat', 'sandwich'), ('belief', 'concept'), ('intelligence', 'insight'), ('attention', 'interest'), ('attitude', 'confidence'), ('right', 'justice'), ('argument', 'agreement')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('depth', 'magnitude'), ('medium', 'news'), ('winner', 'candidate'), ('birthday', 'date'), ('fee', 'payment'), ('bible', 'hymn'), ('exit', 'doorway'), ('man', 'sentry'), ('aisle', 'hall'), ('whiskey', 'gin'), ('blood', 'marrow'), ('oil', 'mink'), ('floor', 'deck'), ('roof', 'floor'), ('door', 'floor'), ('shoulder', 'head'), ('wagon', 'carriage'), ('car', 'carriage'), ('elbow', 'ankle'), ('wealth', 'fame'), ('sorrow', 'shame'), ('administration', 'management'), ('communication', 'conversation'), ('pollution', 'atmosphere'), ('anatomy', 'biology'), ('college', 'profession'), ('book', 'topic'), ('formula', 'equation'), ('book', 'information'), ('boy', 'partner'), ('sky', 'universe'), ('population', 'people'), ('college', 'class'), ('chief', 'mayor'), ('rabbi', 'minister'), ('meter', 'inch'), ('polyester', 'cotton'), ('lawyer', 'banker'), ('violin', 'instrument'), ('camp', 'cabin')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('pot', 'appliance'), ('linen', 'fabric'), ('whiskey', 'champagne'), ('girl', 'child'), ('cottage', 'cabin'), ('bird', 'hen'), ('racket', 'noise'), ('sunset', 'evening'), ('drizzle', 'rain'), ('adult', 'baby'), ('charcoal', 'coal'), ('body', 'spine'), ('head', 'nail'), ('log', 'timber'), ('spoon', 'cup'), ('body', 'nerve'), ('man', 'husband'), ('bone', 'neck'), ('frustration', 'anger'), ('river', 'sea'), ('task', 'job'), ('club', 'society'), ('reflection', 'image'), ('prince', 'king'), ('snow', 'weather'), ('people', 'party'), ('boy', 'brother'), ('root', 'grass'), ('brow', 'eye'), ('money', 'pearl'), ('money', 'diamond'), ('vehicle', 'bus'), ('cab', 'bus'), ('house', 'barn'), ('finger', 'palm'), ('car', 'bridge'), ('effort', 'difficulty'), ('fact', 'insight'), ('job', 'management'), ('cancer', 'sickness')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('word', 'newspaper'), ('composer', 'writer'), ('actor', 'singer'), ('shelter', 'hut'), ('bathroom', 'kitchen'), ('cabin', 'hut'), ('door', 'kitchen'), ('value', 'belief'), ('wisdom', 'intelligence'), ('ignorance', 'intelligence'), ('happiness', 'luck'), ('idea', 'scheme'), ('mood', 'emotion'), ('happiness', 'peace'), ('despair', 'misery'), ('logic', 'arithmetic'), ('denial', 'confession'), ('argument', 'criticism'), ('aggression', 'hostility'), ('hysteria', 'confusion'), ('chemistry', 'theory'), ('trial', 'verdict'), ('comfort', 'safety'), ('confidence', 'self'), ('vision', 'perception'), ('era', 'decade'), ('biography', 'fiction'), ('discussion', 'argument'), ('code', 'symbol'), ('danger', 'disease'), ('accident', 'catastrophe'), ('journey', 'trip'), ('activity', 'movement'), ('gossip', 'news'), ('father', 'god'), ('action', 'course'), ('fever', 'illness'), ('aviation', 'flight'), ('game', 'action'), ('molecule', 'air')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('home', 'state'), ('word', 'literature'), ('adult', 'guardian'), ('newspaper', 'information'), ('communication', 'television'), ('cousin', 'uncle'), ('author', 'reader'), ('guy', 'partner'), ('area', 'corner'), ('ballad', 'song'), ('wall', 'decoration'), ('word', 'page'), ('nurse', 'scientist'), ('politician', 'president'), ('president', 'mayor'), ('book', 'essay'), ('man', 'warrior'), ('article', 'journal'), ('breakfast', 'supper'), ('crowd', 'parade'), ('aisle', 'hallway'), ('teacher', 'rabbi'), ('hip', 'lip'), ('book', 'article'), ('room', 'cell'), ('box', 'booth'), ('daughter', 'kid'), ('limb', 'leg'), ('liver', 'lung'), ('classroom', 'hallway'), ('mountain', 'ledge'), ('car', 'elevator'), ('bed', 'couch'), ('clothes', 'button'), ('clothes', 'coat'), ('kidney', 'organ'), ('apple', 'sauce'), ('chicken', 'steak'), ('car', 'hose'), ('tobacco', 'cigarette')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('student', 'professor'), ('baby', 'daughter'), ('pipe', 'cigar'), ('milk', 'juice'), ('box', 'cigar'), ('apartment', 'hotel'), ('cup', 'cone'), ('horse', 'ox'), ('throat', 'nose'), ('bone', 'teeth'), ('bone', 'elbow'), ('bacon', 'bean'), ('cup', 'jar'), ('proof', 'fact'), ('appointment', 'engagement'), ('birthday', 'year'), ('word', 'clue'), ('author', 'creator'), ('atom', 'carbon'), ('archbishop', 'bishop'), ('letter', 'paragraph'), ('page', 'paragraph'), ('steeple', 'chapel'), ('muscle', 'bone'), ('muscle', 'tongue'), ('boy', 'soldier'), ('belly', 'abdomen'), ('guy', 'girl'), ('bed', 'chair'), ('clothes', 'jacket'), ('gun', 'knife'), ('tin', 'metal'), ('bottle', 'container'), ('hen', 'turkey'), ('meat', 'bread'), ('arm', 'bone'), ('neck', 'spine'), ('apple', 'lemon'), ('agony', 'grief'), ('assignment', 'task')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('night', 'dawn'), ('dinner', 'soup'), ('calf', 'bull'), ('snow', 'storm'), ('nail', 'hand'), ('dog', 'horse'), ('arm', 'neck'), ('ball', 'glove'), ('flu', 'fever'), ('fee', 'salary'), ('nerve', 'brain'), ('beast', 'animal'), ('dinner', 'chicken'), ('girl', 'maid'), ('child', 'boy'), ('alcohol', 'wine'), ('nose', 'mouth'), ('street', 'car'), ('bell', 'door'), ('box', 'hat'), ('belief', 'impression'), ('bias', 'opinion'), ('attention', 'awareness'), ('anger', 'mood'), ('elegance', 'style'), ('beauty', 'age'), ('book', 'theme'), ('friend', 'mother'), ('vitamin', 'iron'), ('car', 'factory'), ('pact', 'condition'), ('chapter', 'choice'), ('arithmetic', 'rhythm'), ('winner', 'presence'), ('belief', 'flower'), ('winner', 'goal'), ('trick', 'size'), ('choice', 'vein'), ('hymn', 'conquest'), ('endurance', 'band')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('jail', 'choice'), ('condition', 'boy'), ('flower', 'endurance'), ('hole', 'agreement'), ('doctor', 'temper'), ('fraternity', 'door'), ('task', 'woman'), ('fraternity', 'baseball'), ('cent', 'size'), ('presence', 'door'), ('mouse', 'management'), ('task', 'highway'), ('liquor', 'century'), ('task', 'straw'), ('island', 'task'), ('night', 'chapter'), ('pollution', 'president'), ('gun', 'trick'), ('bath', 'trick'), ('diet', 'apple'), ('cent', 'wife'), ('chapter', 'tail'), ('course', 'stomach'), ('hymn', 'straw'), ('dentist', 'colonel'), ('wife', 'straw'), ('hole', 'wife'), ('pupil', 'president'), ('bath', 'wife'), ('people', 'cent'), ('formula', 'log'), ('woman', 'fur'), ('apple', 'sunshine'), ('gun', 'dawn'), ('meal', 'waist'), ('camera', 'president'), ('liquor', 'band'), ('stomach', 'vein'), ('gun', 'fur'), ('couch', 'baseball')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('worker', 'camera'), ('deck', 'mouse'), ('rice', 'boy'), ('people', 'gun'), ('cliff', 'tail'), ('ankle', 'window'), ('princess', 'island'), ('container', 'mouse'), ('wagon', 'container'), ('people', 'balloon'), ('dollar', 'people'), ('bath', 'balloon'), ('stomach', 'bedroom'), ('bicycle', 'bedroom'), ('log', 'bath'), ('bowl', 'tail'), ('go', 'come'), ('take', 'steal'), ('listen', 'hear'), ('think', 'rationalize'), ('occur', 'happen'), ('vanish', 'disappear'), ('multiply', 'divide'), ('plead', 'beg'), ('begin', 'originate'), ('protect', 'defend'), ('kill', 'destroy'), ('create', 'make'), ('accept', 'reject'), ('ignore', 'avoid'), ('carry', 'bring'), ('leave', 'enter'), ('choose', 'elect'), ('lose', 'fail'), ('encourage', 'discourage'), ('achieve', 'accomplish'), ('make', 'construct'), ('listen', 'obey'), ('inform', 'notify'), ('receive', 'give')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('borrow', 'beg'), ('take', 'obtain'), ('advise', 'recommend'), ('imitate', 'portray'), ('win', 'succeed'), ('think', 'decide'), ('greet', 'meet'), ('agree', 'argue'), ('enjoy', 'entertain'), ('destroy', 'make'), ('save', 'protect'), ('give', 'lend'), ('understand', 'know'), ('take', 'receive'), ('accept', 'acknowledge'), ('decide', 'choose'), ('accept', 'believe'), ('keep', 'possess'), ('roam', 'wander'), ('succeed', 'fail'), ('spend', 'save'), ('leave', 'go'), ('come', 'attend'), ('know', 'believe'), ('gather', 'meet'), ('make', 'earn'), ('forget', 'ignore'), ('multiply', 'add'), ('shrink', 'grow'), ('arrive', 'leave'), ('succeed', 'try'), ('accept', 'deny'), ('arrive', 'come'), ('agree', 'differ'), ('send', 'receive'), ('win', 'dominate'), ('add', 'divide'), ('kill', 'choke'), ('acquire', 'get'), ('participate', 'join')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('leave', 'remain'), ('go', 'enter'), ('take', 'carry'), ('forget', 'learn'), ('appoint', 'elect'), ('engage', 'marry'), ('ask', 'pray'), ('go', 'send'), ('take', 'deliver'), ('speak', 'hear'), ('analyze', 'evaluate'), ('argue', 'rationalize'), ('lose', 'keep'), ('compare', 'analyze'), ('disorganize', 'organize'), ('go', 'allow'), ('take', 'possess'), ('learn', 'listen'), ('destroy', 'construct'), ('create', 'build'), ('steal', 'buy'), ('kill', 'hang'), ('forget', 'know'), ('create', 'imagine'), ('do', 'happen'), ('win', 'accomplish'), ('give', 'deny'), ('deserve', 'earn'), ('get', 'put'), ('locate', 'find'), ('appear', 'attend'), ('know', 'comprehend'), ('pretend', 'imagine'), ('satisfy', 'please'), ('cherish', 'keep'), ('argue', 'differ'), ('overcome', 'dominate'), ('behave', 'obey'), ('cooperate', 'participate'), ('achieve', 'try')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('fail', 'discourage'), ('begin', 'quit'), ('say', 'participate'), ('come', 'bring'), ('declare', 'announce'), ('read', 'comprehend'), ('take', 'leave'), ('proclaim', 'announce'), ('acquire', 'obtain'), ('conclude', 'decide'), ('please', 'plead'), ('argue', 'prove'), ('ask', 'plead'), ('find', 'disappear'), ('inspect', 'examine'), ('verify', 'justify'), ('assume', 'predict'), ('learn', 'evaluate'), ('argue', 'justify'), ('make', 'become'), ('discover', 'originate'), ('achieve', 'succeed'), ('give', 'put'), ('understand', 'listen'), ('expand', 'grow'), ('borrow', 'sell'), ('keep', 'protect'), ('explain', 'prove'), ('assume', 'pretend'), ('agree', 'please'), ('forgive', 'forget'), ('clarify', 'explain'), ('understand', 'forgive'), ('remind', 'forget'), ('get', 'remain'), ('realize', 'discover'), ('require', 'inquire'), ('ignore', 'ask'), ('think', 'inquire'), ('reject', 'avoid')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('argue', 'persuade'), ('pursue', 'persuade'), ('accept', 'forgive'), ('do', 'quit'), ('investigate', 'examine'), ('discuss', 'explain'), ('owe', 'lend'), ('explore', 'discover'), ('complain', 'argue'), ('withdraw', 'reject'), ('keep', 'borrow'), ('beg', 'ask'), ('arrange', 'organize'), ('reduce', 'shrink'), ('speak', 'acknowledge'), ('give', 'borrow'), ('kill', 'defend'), ('disappear', 'shrink'), ('deliver', 'carry'), ('breathe', 'choke'), ('acknowledge', 'notify'), ('become', 'seem'), ('pretend', 'seem'), ('accomplish', 'become'), ('contemplate', 'think'), ('determine', 'predict'), ('please', 'entertain'), ('remain', 'retain'), ('pretend', 'portray'), ('forget', 'retain'), ('want', 'choose'), ('lose', 'get'), ('try', 'think'), ('become', 'appear'), ('leave', 'ignore'), ('accept', 'recommend'), ('leave', 'wander'), ('keep', 'give'), ('give', 'allow')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)] --- ["('bring', 'send'), ('absorb', 'learn'), ('acquire', 'find'), ('leave', 'appear'), ('create', 'destroy'), ('begin', 'go'), ('get', 'buy'), ('collect', 'save'), ('replace', 'restore'), ('join', 'add'), ('join', 'marry'), ('accept', 'deliver'), ('attach', 'join'), ('put', 'hang'), ('go', 'sell'), ('communicate', 'pray'), ('give', 'steal'), ('add', 'build'), ('bring', 'restore'), ('comprehend', 'satisfy'), ('portray', 'decide'), ('organize', 'become'), ('give', 'know'), ('say', 'verify'), ('cooperate', 'join'), ('arrange', 'require'), ('borrow', 'want'), ('investigate', 'pursue'), ('ignore', 'explore'), ('bring', 'complain'), ('enter', 'owe'), ('portray', 'notify'), ('remind', 'sell'), ('absorb', 'possess'), ('join', 'acquire'), ('send', 'attend'), ('gather', 'attend'), ('absorb', 'withdraw'), ('attend', 'arrive')"]

# %%
# Load encoding
encoding = tiktoken.get_encoding("cl100k_base")

# Count tokens per chunk
token_counts = count_tokens_with_tiktoken(chunks, prompt)

# Show results
print("Token counts for each formatted prompt:", token_counts)
# Out:
# Token counts for each formatted prompt: [392, 393, 397, 378, 386, 379, 376, 386, 387, 391, 390, 390, 380, 379, 391, 392, 382, 377, 386, 379, 379, 380, 378, 383, 369]

# %% [markdown]
# ### **2. Extract and Process Data**

# %%
# Get results from API
# response = get_responses(chunks, prompt, model, sample_size, delay)
# Out:
# Processing: 100%|██████████| 375/375 [2:30:55<00:00, 24.15s/chunk]
# Total time taken: 9055.70 seconds

# %%
# Define filepath
file_path = '../../../data/response/en/gpt-3.5-turbo-0125/f2.json'

# Check if file already exists
if not os.path.exists(file_path):
    with open(file_path, 'w') as f:
        json.dump(response, f)
        print("File saved successfully.")
else:
    print("File already exists. JSON was not saved to prevent overwriting.")
# Out:
# File saved successfully.

# %%
# Process data into dictionary
data_dict = process_responses(response)

# Check for values higher/lower then sample size
higher_lower_samples = {key: value for key, value in data_dict.items() if len(value) < sample_size or len(value) > sample_size}

# Show results
print(higher_lower_samples)
# Out:
# {('large', 'huge'): [8.0, 8.5, 9.0, 8.0, 8.0, 8.0, 9.0, 9.5, 9.0, 8.5, 9.0, 9.0, 8.5, 8.0], ('hard', 'tough'): [7.0, 8.0, 8.0, 7.5, 7.5, 7.0, 8.5, 8.0, 8.75, 8.0, 8.0, 8.0, 8.0, 8.0], ('new', 'fresh'): [8.0, 8.5, 8.5, 8.5, 7.5, 6.0, 8.5, 7.5, 9.0, 8.5, 8.5, 8.0, 7.5, 8.0], ('sharp', 'dull'): [6.5, 6.5, 7.5, 6.5, 7.0, 7.5, 7.0, 7.5, 8.5, 7.5, 7.5, 7.5, 7.5, 6.5], ('quick', 'rapid'): [8.0, 9.0, 9.0, 9.0, 8.5, 8.0, 9.5, 9.5, 9.5, 9.0, 9.0, 9.0, 8.5, 8.0], ('dumb', 'foolish'): [8.25, 8.0, 7.0, 8.5, 7.5, 7.5, 8.0, 8.0, 9.0, 8.5, 8.0, 8.5, 8.0, 7.5], ('wonderful', 'terrific'): [8.25, 9.5, 8.5, 9.5, 8.5, 8.5, 8.0, 9.0, 9.5, 9.0, 8.5, 8.0, 8.5, 8.5], ('strange', 'odd'): [8.0, 8.5, 8.5, 8.5, 8.5, 8.0, 9.0, 9.0, 9.25, 8.5, 8.5, 8.5, 8.0, 8.5], ('happy', 'angry'): [6.0, 4.0, 5.0, 4.0, 6.0, 4.5, 5.5, 5.5, 6.5, 6.0, 7.5, 6.0, 5.5, 4.5], ('narrow', 'broad'): [6.5, 6.0, 7.0, 7.5, 7.0, 7.0, 7.5, 6.0, 7.75, 6.0, 7.5, 6.5, 6.0, 7.0], ('simple', 'easy'): [6.75, 6.0, 7.5, 7.5, 6.5, 7.0, 8.0, 8.0, 9.0, 8.5, 8.0, 8.0, 8.0, 6.5], ('old', 'fresh'): [5.75, 5.5, 6.5, 5.0, 6.0, 6.5, 6.5, 7.0, 5.5, 6.5, 5.0, 7.0, 6.5, 5.5], ('apparent', 'obvious'): [8.5, 9.5, 9.5, 9.0, 8.0, 9.0, 8.0, 8.5, 9.5, 9.0, 9.0, 9.0, 8.5, 8.5], ('inexpensive', 'cheap'): [8.75, 8.5, 9.0, 9.0, 8.5, 8.5, 9.5, 9.0, 9.5, 8.5, 9.0, 9.0, 8.5, 8.5], ('nice', 'generous'): [7.0, 7.0, 8.0, 7.5, 7.0, 7.5, 7.5, 7.0, 6.75, 7.5, 8.5, 7.5, 7.0, 7.5], ('weird', 'normal'): [6.25, 7.5, 7.5, 7.5, 6.5, 7.5, 7.5, 6.5, 6.75, 7.5, 7.5, 6.5, 5.0, 7.5], ('weird', 'odd'): [7.75, 9.0, 8.5, 8.5, 8.0, 8.5, 6.5, 8.0, 8.75, 9.0, 8.5, 9.0, 8.0, 8.5], ('bad', 'immoral'): [6.25, 6.5, 6.0, 6.5, 7.0, 5.0, 5.5, 8.0, 8.25, 6.5, 8.0, 7.0, 5.5, 6.5], ('sad', 'funny'): [5.5, 3.0, 6.0, 4.0, 5.5, 4.0, 4.0, 3.0, 7.5, 4.0, 5.0, 5.5, 3.5, 4.5], ('wonderful', 'great'): [8.25, 8.5, 8.5, 9.0, 8.0, 8.0, 9.0, 9.0, 9.5, 9.0, 8.5, 9.0, 8.5, 9.0], ('guilty', 'ashamed'): [7.75, 8.0, 8.0, 8.5, 7.0, 7.0, 7.5, 7.0, 8.75, 8.0, 8.5, 7.0, 5.0, 7.5], ('beautiful', 'wonderful'): [8.5, 8.5, 8.5, 9.0, 8.5, 9.0, 8.0, 9.0, 9.25, 9.0, 8.5, 8.5, 8.5, 8.5], ('confident', 'sure'): [7.5, 7.5, 8.5, 8.5, 8.0, 8.5, 8.0, 7.5, 8.75, 8.0, 8.5, 8.5, 8.5, 8.0], ('school', 'grade'): [3.0, 1.75, 3.8, 2.0, 3.0, 2.0, 2.0, 2.34, 3.0, 1.5, 3.5, 1.58, 2.0, 1.67], ('parent', 'adult'): [4.0, 4.0, 5.6, 4.5, 5.5, 4.5, 4.0, 4.21, 5.5, 6.0, 3.75, 4.36, 4.0, 3.33], ('bar', 'jail'): [4.5, 3.5, 5.0, 4.5, 2.5, 4.0, 3.0, 2.1, 4.5, 2.0, 2.75, 1.0, 4.0, 3.33], ('car', 'highway'): [4.5, 3.0, 5.6, 3.5, 4.5, 3.0, 3.0, 1.98, 4.0, 4.0, 2.5, 2.38, 3.0, 2.5], ('dictionary', 'definition'): [6.5, 6.75, 8.4, 7.5, 7.0, 7.5, 8.0, 6.45, 6.5, 6.0, 7.5, 4.36, 8.0, 5.0], ('door', 'cellar'): [4.0, 4.0, 4.2, 4.0, 2.5, 2.5, 4.0, 2.89, 5.0, 4.5, 3.75, 2.38, 5.0, 2.5], ('army', 'legion'): [5.5, 5.75, 8.0, 5.5, 4.0, 6.0, 6.5, 5.76, 7.5, 7.0, 6.5, 2.38, 6.0, 5.0], ('metal', 'aluminum'): [7.5, 7.5, 7.8, 7.0, 7.5, 8.5, 7.0, 6.98, 7.5, 7.0, 8.5, 4.36, 4.0, 6.67], ('chair', 'bench'): [6.0, 6.5, 7.4, 5.0, 4.5, 6.0, 6.5, 4.32, 6.0, 6.5, 6.0, 3.0, 5.0, 3.33], ('cloud', 'fog'): [6.0, 6.0, 6.4, 4.5, 4.0, 4.0, 5.0, 5.67, 6.0, 5.5, 5.5, 3.78, 4.0, 5.0], ('boy', 'son'): [6.0, 5.5, 7.4, 5.5, 7.0, 5.5, 6.0, 6.75, 6.5, 6.0, 6.5, 3.0, 6.0, 3.33], ('water', 'ice'): [4.5, 3.5, 6.6, 3.5, 4.5, 4.0, 4.0, 3.21, 4.5, 3.5, 3.75, 2.38, 4.0, 3.33], ('bed', 'blanket'): [5.0, 4.75, 6.4, 4.0, 4.0, 3.0, 4.0, 4.89, 5.5, 3.0, 5.75, 3.0, 6.0, 2.5], ('attorney', 'lawyer'): [8.0, 8.75, 9.2, 7.5, 7.5, 7.5, 8.5, 7.36, 8.5, 8.0, 9.0, 4.36, 8.0, 8.33], ('area', 'zone'): [5.0, 3.75, 7.2, 5.0, 6.5, 5.0, 6.0, 4.15, 6.0, 5.5, 6.25, 3.0, 5.0, 3.33], ('business', 'company'): [6.5, 6.25, 7.8, 6.0, 5.5, 6.5, 7.0, 3.67, 7.0, 6.5, 6.5, 3.78, 7.0, 3.33], ('clothes', 'fabric'): [5.5, 4.75, 6.8, 4.0, 5.0, 3.0, 4.0, 5.43, 4.5, 4.0, 5.25, 4.36, 5.0, 3.33], ('sweater', 'jacket'): [7.0, 5.5, 8.2, 6.0, 6.5, 5.5, 7.0, 6.21, 6.5, 6.5, 7.0, 4.36, 7.0, 5.0], ('money', 'capital'): [4.5, 5.5, 6.6, 5.0, 4.5, 3.0, 5.0, 4.37, 6.0, 5.0, 4.5, 2.38, 6.0, 3.33], ('hand' ...

# %%
# Print duplicate word pairs
print_duplicate_word_pairs(en_simlex, data_dict)
# Out:
# Empty DataFrame
# Columns: [Combined_Columns]
# Index: []
# Empty DataFrame
# Columns: [Combined_Columns]
# Index: []

# %%
# Convert dict to Pandas DataFrame
df = create_dataframe(data_dict)

# Show results
df
# Out:
#       word1        word2  similarity_score_1  similarity_score_2  \
# 0     smart  intelligent                8.50                7.00
# 1      hard    difficult                7.50                6.00
# 2     happy     cheerful                6.75                8.50
# 3      hard         easy                2.00                2.00
# 4      fast        rapid                8.50                9.00
# ..      ...          ...                 ...                 ...
# 993    join      acquire                2.33                0.60
# 994    send       attend                1.51                0.35
# 995  gather       attend                2.00                0.48
# 996  absorb     withdraw                1.52                0.17
# 997  attend       arrive                1.75                0.53
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                  8.50                8.50                8.50
# 1                  8.00                8.00                7.00
# 2                  9.00                8.00                8.50
# 3                  3.00                2.00                4.00
# 4                  9.50                9.50                9.00
# ..                  ...                 ...                 ...
# 993                0.41                0.45                0.81
# 994                0.38                0.43                0.93
# 995                0.44                0.39                0.85
# 996                0.10                0.09                0.77
# 997                0.54                0.32                0.73
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                  8.50                9.50                 9.5
# 1                  6.50                7.00                 8.5
# 2                  7.50                8.50                 7.5
# 3                  2.50                4.00                 1.0
# 4                  9.00                9.50                 9.5
# ..                  ...                 ...                 ...
# 993                0.22                2.18                 1.9
# 994                0.16                0.88                 1.0
# 995                0.17                1.65                 1.5
# 996                0.15                0.45                 0.2
# 997                0.26                0.65                 1.5
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                  9.00                 8.75                 9.50
# 1                  8.50                 8.25                 8.00
# 2                  8.00                 8.50                 8.50
# 3                  1.50                 1.50                 4.00
# 4                  9.50                 9.00                 9.50
# ..                  ...                  ...                  ...
# 993                3.64                 2.30                 2.00
# 994                2.63                 1.58                 1.57
# 995                2.60                 1.75                 1.64
# 996                1.87                 0.85                 1.07
# 997                1.74                 2.10                 1.36
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                   8.50                 9.50                 9.50
# 1                   8.60                 8.00                 7.50
# 2                   8.70                 7.00                 8.50
# 3                   2.00                 2.00                 3.00
# 4                   9.00                 9.50                 8.00
# ..                   ...                  ...                  ...
# 993                 0.52                 1.66                 0.49
# 994                 0.51                 1.62                 0.17
# 995                 0.44                 1.42                 0.46
# 996                 0.29                 1.52                 0.14
# 997                 0.52                 1.56                 0.34
#
#      similarity_score_15
# 0                   8.50
# 1                   7.50
# 2                   7.50
# 3                   1.50
# 4                   9.00
# ..                   ...
# 993                 5.14
# 994                 2.00
# 995                 2.00
# 996                 1.14
# 997                 2.00
#
# [998 rows x 17 columns]

# %%
# Show results
response
# Out:
# ["[('smart', 'intelligent', 8.50), ('hard', 'difficult', 7.50), ('happy', 'cheerful', 6.75), ('hard', 'easy', 2.00), ('fast', 'rapid', 8.50), ('happy', 'glad', 7.25), ('short', 'long', 6.00), ('stupid', 'dumb', 8.00), ('weird', 'strange', 7.50), ('wide', 'narrow', 6.75), ('bad', 'awful', 4.50), ('easy', 'difficult', 5.75), ('bad', 'terrible', 4.75), ('hard', 'simple', 2.75), ('smart', 'dumb', 7.25), ('insane', 'crazy', 8.50), ('happy', 'mad', 5.75), ('large', 'huge', 8.00), ('hard', 'tough', 7.00), ('new', 'fresh', 8.00), ('sharp', 'dull', 6.50), ('quick', 'rapid', 8.00), ('dumb', 'foolish', 8.25), ('wonderful', 'terrific', 8.25), ('strange', 'odd', 8.00), ('happy', 'angry', 6.00), ('narrow', 'broad', 6.50), ('simple', 'easy', 6.75), ('old', 'fresh', 5.75), ('apparent', 'obvious', 8.50), ('inexpensive', 'cheap', 8.75), ('nice', 'generous', 7.00), ('weird', 'normal', 6.25), ('weird', 'odd', 7.75), ('bad', 'immoral', 6.25), ('sad', 'funny', 5.50), ('wonderful', 'great', 8.25), ('guilty', 'ashamed', 7.75), ('beautiful', 'wonderful', 8.50), ('confident', 'sure', 7.50)]",
#  "[('smart', 'intelligent', 7.00), ('hard', 'difficult', 6.00), ('happy', 'cheerful', 8.50), ('hard', 'easy', 2.00), ('fast', 'rapid', 9.00), ('happy', 'glad', 7.50), ('short', 'long', 5.00), ('stupid', 'dumb', 8.50), ('weird', 'strange', 9.00), ('wide', 'narrow', 4.00), ('bad', 'awful', 7.00), ('easy', 'difficult', 3.00), ('bad', 'terrible', 7.50), ('hard', 'simple', 2.00), ('smart', 'dumb', 6.00), ('insane', 'crazy', 9.50), ('happy', 'mad', 6.00), ('large', 'huge', 8.50), ('hard', 'tough', 8.00), ('new', 'fresh', 8.50), ('sharp', 'dull', 6.50), ('quick', 'rapid', 9.00), ('dumb', 'foolish', 8.00), ('wonderful', 'terrific', 9.50), ('strange', 'odd', 8.50), ('happy', 'angry', 4.00), ('narrow', 'broad', 6.00), ('simple', 'easy', 6.00), ('old', 'fresh', 5.50), ('apparent', 'obvious', 9.50), ('inexpensive', 'cheap', 8.50), ('nice', 'generous', 7.00), ('weird', 'normal', 7.50), ('weird', 'odd', 9.00), ('bad', 'immoral', 6.50), ('sad', 'funny', 3.00), ('wonderful', 'great', 8.50), ('guilty', 'ashamed', 8.00), ('beautiful', 'wonderful', 8.50), ('confident', 'sure', 7.50)]",
#  "[('smart', 'intelligent', 8.50), ('hard', 'difficult', 8.00), ('happy', 'cheerful', 9.00), ('hard', 'easy', 3.00), ('fast', 'rapid', 9.50), ('happy', 'glad', 8.50), ('short', 'long', 7.50), ('stupid', 'dumb', 8.50), ('weird', 'strange', 9.00), ('wide', 'narrow', 7.00), ('bad', 'awful', 8.00), ('easy', 'difficult', 6.00), ('bad', 'terrible', 7.50), ('hard', 'simple', 5.50), ('smart', 'dumb', 4.50), ('insane', 'crazy', 9.00), ('happy', 'mad', 7.50), ('large', 'huge', 9.00), ('hard', 'tough', 8.00), ('new', 'fresh', 8.50), ('sharp', 'dull', 7.50), ('quick', 'rapid', 9.00), ('dumb', 'foolish', 7.00), ('wonderful', 'terrific', 8.50), ('strange', 'odd', 8.50), ('happy', 'angry', 5.00), ('narrow', 'broad', 7.00), ('simple', 'easy', 7.50), ('old', 'fresh', 6.50), ('apparent', 'obvious', 9.50), ('inexpensive', 'cheap', 9.00), ('nice', 'generous', 8.00), ('weird', 'normal', 7.50), ('weird', 'odd', 8.50), ('bad', 'immoral', 6.00), ('sad', 'funny', 6.00), ('wonderful', 'great', 8.50), ('guilty', 'ashamed', 8.00), ('beautiful', 'wonderful', 8.50), ('confident', 'sure', 8.50)]",
#  "[('smart', 'intelligent', 8.50), ('hard', 'difficult', 8.00), ('happy', 'cheerful', 8.00), ('hard', 'easy', 2.00), ('fast', 'rapid', 9.50), ('happy', 'glad', 8.00), ('short', 'long', 5.00), ('stupid', 'dumb', 8.50), ('weird', 'strange', 9.00), ('wide', 'narrow', 7.00), ('bad', 'awful', 7.00), ('easy', 'difficult', 2.50), ('bad', 'terrible', 8.00), ('hard', 'simple', 5.50), ('smart', 'dumb', 6.50), ('insane', 'crazy', 9.00), ('happy', 'mad', 5.00), ('large', 'huge', 8.00), ('hard', 'tough', 7.50), ('new', 'fresh', 8.50), ('sharp', 'dull', 6.50), ('quick', 'rapid', 9.00), ('dumb', 'foolish', 8.50), ('wonderful', 'terrific', 9.50), ('strange', 'odd', 8.50), ('happy', 'angry', 4.00), ('narrow', 'broad', 7.50), ('simple', 'easy', 7.50), ('old', 'fresh', 5.00), ('apparent', 'obvious', 9.00), ('inexpensive', 'cheap', 9.00), ('nice', 'generous', 7.50), ('weird', 'normal', 7.50), ('weird', 'odd', 8.50), ('bad', 'immoral', 6.50), ('sad', 'funny', 4.00), ('wonderful', 'great', 9.00), ('guilty', 'ashamed', 8.50), ('beautiful', 'wonderful', 9.00), ('confident', 'sure', 8.50)]",
#  "[('smart', 'intelligent', 8.50), ('hard', 'difficult', 7.00), ('happy', 'cheerful', 8.50), ('hard', 'easy', 4.00), ('fast', 'rapid', 9.00), ('happy', 'glad', 7.50), ('short', 'long', 7.00), ('stupid', 'dumb', 7.50), ('weird', 'strange', 8.00), ('wide', 'narrow', 6.00), ('bad', 'awful', 6.50), ('easy', 'difficult', 4.00), ('bad', 'terrible', 7.50), ('hard', 'simple', 4.50), ('smart', 'dumb', 6.50), ('insane', 'crazy', 8.50), ('happy', 'mad', 6.50), ('large', 'huge', 8.00), ('hard', 'tough', 7.50), ('new', 'fresh', 7.50), ('sharp', 'dull', 7.00), ('quick', 'rapid', 8.50), ('dumb', 'foolish', 7.50), ('wonderful', 'terrific', 8.50), ('strange', 'odd', 8.50), ('happy', 'angry', 6.00), ('narrow', 'broad', 7.00), ('simple', 'easy', 6.50), ('old', 'fresh', 6.00), ('apparent', 'obvious', 8.00), ('inexpensive', 'cheap', 8.50), ('nice', 'generous', 7.00), ('weird', 'normal', 6.50), ('weird', 'odd', 8.00), ('bad', 'immoral', 7.00), ('sad', 'funny', 5.50), ('wonderful', 'great', 8.00), ('guilty', 'ashamed', 7.00), ('beautiful', 'wonderful', 8.50), ('confident', 'sure', 8.00)]",
#  "[('smart', 'intelligent', 8.50), ('hard', 'difficult', 6.50), ('happy', 'cheerful', 7.50), ('hard', 'easy', 2.50), ('fast', 'rapid', 9.00), ('happy', 'glad', 7.00), ('short', 'long', 5.50), ('stupid', 'dumb', 8.50), ('weird', 'strange', 8.00), ('wide', 'narrow', 6.00), ('bad', 'awful', 7.00), ('easy', 'difficult', 6.00), ('bad', 'terrible', 7.50), ('hard', 'simple', 4.00), ('smart', 'dumb', 5.50), ('insane', 'crazy', 9.00), ('happy', 'mad', 6.00), ('large', 'huge', 8.00), ('hard', 'tough', 7.00), ('new', 'fresh', 6.00), ('sharp', 'dull', 7.50), ('quick', 'rapid', 8.00), ('dumb', 'foolish', 7.50), ('wonderful', 'terrific', 8.50), ('strange', 'odd', 8.00), ('happy', 'angry', 4.50), ('narrow', 'broad', 7.00), ('simple', 'easy', 7.00), ('old', 'fresh', 6.50), ('apparent', 'obvious', 9.00), ('inexpensive', 'cheap', 8.50), ('nice', 'generous', 7.50), ('weird', 'normal', 7.50), ('weird', 'odd', 8.50), ('bad', 'immoral', 5.00), ('sad', 'funny', 4.00), ('wonderful', 'great', 8.00), ('guilty', 'ashamed', 7.00), ('beautiful', 'wonderful', 9.00), ('confident', 'sure', 8.50)]",
#  "[('smart', 'intelligent', 9.50), ('hard', 'difficult', 7.00), ('happy', 'cheerful', 8.50), ('hard', 'easy', 4.00), ('fast', 'rapid', 9.50), ('happy', 'glad', 7.50), ('short', 'long', 6.50), ('stupid', 'dumb', 8.50), ('weird', 'strange', 8.00), ('wide', 'narrow', 7.50), ('bad', 'awful', 7.00), ('easy', 'difficult', 4.50), ('bad', 'terrible', 7.50), ('hard', 'simple', 4.00), ('smart', 'dumb', 6.00), ('insane', 'crazy', 8.50), ('happy', 'mad', 6.00), ('large', 'huge', 9.00), ('hard', 'tough', 8.50), ('new', 'fresh', 8.50), ('sharp', 'dull', 7.00), ('quick', 'rapid', 9.50), ('dumb', 'foolish', 8.00), ('wonderful', 'terrific', 8.00), ('strange', 'odd', 9.00), ('happy', 'angry', 5.50), ('narrow', 'broad', 7.50), ('simple', 'easy', 8.00), ('old', 'fresh', 6.50), ('apparent', 'obvious', 8.00), ('inexpensive', 'cheap', 9.50), ('nice', 'generous', 7.50), ('weird', 'normal', 7.50), ('weird', 'odd', 6.50), ('bad', 'immoral', 5.50), ('sad', 'funny', 4.00), ('wonderful', 'great', 9.00), ('guilty', 'ashamed', 7.50), ('beautiful', 'wonderful', 8.00), ('confident', 'sure', 8.00)]",
#  "[('smart', 'intelligent', 9.50), ('hard', 'difficult', 8.50), ('happy', 'cheerful', 7.50), ('hard', 'easy', 1.00), ('fast', 'rapid', 9.50), ('happy', 'glad', 8.00), ('short', 'long', 8.50), ('stupid', 'dumb', 8.00), ('weird', 'strange', 9.00), ('wide', 'narrow', 7.50), ('bad', 'awful', 7.50), ('easy', 'difficult', 7.00), ('bad', 'terrible', 8.50), ('hard', 'simple', 3.00), ('smart', 'dumb', 5.50), ('insane', 'crazy', 8.00), ('happy', 'mad', 5.00)]",
#  "[('smart', 'intelligent', 9.00), ('hard', 'difficult', 8.50), ('happy', 'cheerful', 8.00), ('hard', 'easy', 1.50), ('fast', 'rapid', 9.50), ('happy', 'glad', 7.50), ('short', 'long', 7.00), ('stupid', 'dumb', 8.50), ('weird', 'strange', 9.50), ('wide', 'narrow', 5.00), ('bad', 'awful', 8.00), ('easy', 'difficult', 2.00), ('bad', 'terrible', 8.50), ('hard', 'simple', 2.00), ('smart', 'dumb', 6.50), ('insane', 'crazy', 9.00), ('happy', 'mad', 7.00), ('large', 'huge', 9.50), ('hard', 'tough', 8.00), ('new', 'fresh', 7.50), ('sharp', 'dull', 7.50), ('quick', 'rapid', 9.50), ('dumb', 'foolish', 8.00), ('wonderful', 'terrific', 9.00), ('strange', 'odd', 9.00), ('happy', 'angry', 5.50), ('narrow', 'broad', 6.00), ('simple', 'easy', 8.00), ('old', 'fresh', 7.00), ('apparent', 'obvious', 8.50), ('inexpensive', 'cheap', 9.00), ('nice', 'generous', 7.00), ('weird', 'normal', 6.50), ('weird', 'odd', 8.00), ('bad', 'immoral', 8.00), ('sad', 'funny', 3.00), ('wonderful', 'great', 9.00), ('guilty', 'ashamed', 7.00), ('beautiful', 'wonderful', 9.00), ('confident', 'sure', 7.50)]",
#  "[('smart', 'intelligent', 8.75), ('hard', 'difficult', 8.25), ('happy', 'cheerful', 8.50), ('hard', 'easy', 1.50), ('fast', 'rapid', 9.00), ('happy', 'glad', 8.25), ('short', 'long', 7.00), ('stupid', 'dumb', 9.25), ('weird', 'strange', 8.75), ('wide', 'narrow', 7.00), ('bad', 'awful', 8.75), ('easy', 'difficult', 6.25), ('bad', 'terrible', 8.75), ('hard', 'simple', 3.75), ('smart', 'dumb', 6.75), ('insane', 'crazy', 9.50), ('happy', 'mad', 7.50), ('large', 'huge', 9.00), ('hard', 'tough', 8.75), ('new', 'fresh', 9.00), ('sharp', 'dull', 8.50), ('quick', 'rapid', 9.50), ('dumb', 'foolish', 9.00), ('wonderful', 'terrific', 9.50), ('strange', 'odd', 9.25), ('happy', 'angry', 6.50), ('narrow', 'broad', 7.75), ('simple', 'easy', 9.00), ('old', 'fresh', 5.50), ('apparent', 'obvious', 9.50), ('inexpensive', 'cheap', 9.50), ('nice', 'generous', 6.75), ('weird', 'normal', 6.75), ('weird', 'odd', 8.75), ('bad', 'immoral', 8.25), ('sad', 'funny', 7.50), ('wonderful', 'great', 9.50), ('guilty', 'ashamed', 8.75), ('beautiful', 'wonderful', 9.25), ('confident', 'sure', 8.75)]",
#  "[('smart', 'intelligent', 9.50), ('hard', 'difficult', 8.00), ('happy', 'cheerful', 8.50), ('hard', 'easy', 4.00), ('fast', 'rapid', 9.50), ('happy', 'glad', 7.00), ('short', 'long', 8.50), ('stupid', 'dumb', 9.00), ('weird', 'strange', 8.00), ('wide', 'narrow', 6.00), ('bad', 'awful', 7.50), ('easy', 'difficult', 7.50), ('bad', 'terrible', 8.00), ('hard', 'simple', 3.00), ('smart', 'dumb', 6.00), ('insane', 'crazy', 8.00), ('happy', 'mad', 6.00), ('large', 'huge', 8.50), ('hard', 'tough', 8.00), ('new', 'fresh', 8.50), ('sharp', 'dull', 7.50), ('quick', 'rapid', 9.00), ('dumb', 'foolish', 8.50), ('wonderful', 'terrific', 9.00), ('strange', 'odd', 8.50), ('happy', 'angry', 6.00), ('narrow', 'broad', 6.00), ('simple', 'easy', 8.50), ('old', 'fresh', 6.50), ('apparent', 'obvious', 9.00), ('inexpensive', 'cheap', 8.50), ('nice', 'generous', 7.50), ('weird', 'normal', 7.50), ('weird', 'odd', 9.00), ('bad', 'immoral', 6.50), ('sad', 'funny', 4.00), ('wonderful', 'great', 9.00), ('guilty', 'ashamed', 8.00), ('beautiful', 'wonderful', 9.00), ('confident', 'sure', 8.00)]",
#  "[('smart', 'intelligent', 8.50), ('hard', 'difficult', 8.60), ('happy', 'cheerful', 8.70), ('hard', 'easy', 2.00), ('fast', 'rapid', 9.00), ('happy', 'glad', 8.50), ('short', 'long', 7.50), ('stupid', 'dumb', 8.80), ('weird', 'strange', 9.00), ('wide', 'narrow', 7.00), ('bad', 'awful', 8.00), ('easy', 'difficult', 2.00), ('bad', 'terrible', 7.50), ('hard', 'simple', 5.00), ('smart', 'dumb', 7.50), ('insane', 'crazy', 8.50), ('happy', 'mad', 7.50), ('large', 'huge', 9.00), ('hard', 'tough', 8.00), ('new', 'fresh', 8.50), ('sharp', 'dull', 7.50), ('quick', 'rapid', 9.00), ('dumb', 'foolish', 8.00), ('wonderful', 'terrific', 8.50), ('strange', 'odd', 8.50), ('happy', 'angry', 7.50), ('narrow', 'broad', 7.50), ('simple', 'easy', 8.00), ('old', 'fresh', 5.00), ('apparent', 'obvious', 9.00), ('inexpensive', 'cheap', 9.00), ('nice', 'generous', 8.50), ('weird', 'normal', 7.50), ('weird', 'odd', 8.50), ('bad', 'immoral', 8.00), ('sad', 'funny', 5.00), ('wonderful', 'great', 8.50), ('guilty', 'ashamed', 8.50), ('beautiful', 'wonderful', 8.50), ('confident', 'sure', 8.50)]",
#  "[('smart', 'intelligent', 9.50), ('hard', 'difficult', 8.00), ('happy', 'cheerful', 7.00), ('hard', 'easy', 2.00), ('fast', 'rapid', 9.50), ('happy', 'glad', 6.00), ('short', 'long', 7.00), ('stupid', 'dumb', 9.00), ('weird', 'strange', 7.50), ('wide', 'narrow', 6.50), ('bad', 'awful', 8.00), ('easy', 'difficult', 7.00), ('bad', 'terrible', 8.00), ('hard', 'simple', 6.00), ('smart', 'dumb', 7.00), ('insane', 'crazy', 9.00), ('happy', 'mad', 5.00), ('large', 'huge', 9.00), ('hard', 'tough', 8.00), ('new', 'fresh', 8.00), ('sharp', 'dull', 7.50), ('quick', 'rapid', 9.00), ('dumb', 'foolish', 8.50), ('wonderful', 'terrific', 8.00), ('strange', 'odd', 8.50), ('happy', 'angry', 6.00), ('narrow', 'broad', 6.50), ('simple', 'easy', 8.00), ('old', 'fresh', 7.00), ('apparent', 'obvious', 9.00), ('inexpensive', 'cheap', 9.00), ('nice', 'generous', 7.50), ('weird', 'normal', 6.50), ('weird', 'odd', 9.00), ('bad', 'immoral', 7.00), ('sad', 'funny', 5.50), ('wonderful', 'great', 9.00), ('guilty', 'ashamed', 7.00), ('beautiful', 'wonderful', 8.50), ('confident', 'sure', 8.50)]",
#  "[('smart', 'intelligent', 9.50), ('hard', 'difficult', 7.50), ('happy', 'cheerful', 8.50), ('hard', 'easy', 3.00), ('fast', 'rapid', 8.00), ('happy', 'glad', 7.50), ('short', 'long', 7.00), ('stupid', 'dumb', 9.00), ('weird', 'strange', 8.00), ('wide', 'narrow', 4.50), ('bad', 'awful', 7.00), ('easy', 'difficult', 5.00), ('bad', 'terrible', 7.50), ('hard', 'simple', 4.00), ('smart', 'dumb', 6.50), ('insane', 'crazy', 8.50), ('happy', 'mad', 6.50), ('large', 'huge', 8.50), ('hard', 'tough', 8.00), ('new', 'fresh', 7.50), ('sharp', 'dull', 7.50), ('quick', 'rapid', 8.50), ('dumb', 'foolish', 8.00), ('wonderful', 'terrific', 8.50), ('strange', 'odd', 8.00), ('happy', 'angry', 5.50), ('narrow', 'broad', 6.00), ('simple', 'easy', 8.00), ('old', 'fresh', 6.50), ('apparent', 'obvious', 8.50), ('inexpensive', 'cheap', 8.50), ('nice', 'generous', 7.00), ('weird', 'normal', 5.00), ('weird', 'odd', 8.00), ('bad', 'immoral', 5.50), ('sad', 'funny', 3.50), ('wonderful', 'great', 8.50), ('guilty', 'ashamed', 5.00), ('beautiful', 'wonderful', 8.50), ('confident', 'sure', 8.50)]",
#  "[('smart', 'intelligent', 8.50), ('hard', 'difficult', 7.50), ('happy', 'cheerful', 7.50), ('hard', 'easy', 1.50), ('fast', 'rapid', 9.00), ('happy', 'glad', 8.00), ('short', 'long', 6.50), ('stupid', 'dumb', 8.50), ('weird', 'strange', 8.50), ('wide', 'narrow', 5.50), ('bad', 'awful', 7.00), ('easy', 'difficult', 5.50), ('bad', 'terrible', 7.50), ('hard', 'simple', 4.00), ('smart', 'dumb', 3.00), ('insane', 'crazy', 8.50), ('happy', 'mad', 5.00), ('large', 'huge', 8.00), ('hard', 'tough', 8.00), ('new', 'fresh', 8.00), ('sharp', 'dull', 6.50), ('quick', 'rapid', 8.00), ('dumb', 'foolish', 7.50), ('wonderful', 'terrific', 8.50), ('strange', 'odd', 8.50), ('happy', 'angry', 4.50), ('narrow', 'broad', 7.00), ('simple', 'easy', 6.50), ('old', 'fresh', 5.50), ('apparent', 'obvious', 8.50), ('inexpensive', 'cheap', 8.50), ('nice', 'generous', 7.50), ('weird', 'normal', 7.50), ('weird', 'odd', 8.50), ('bad', 'immoral', 6.50), ('sad', 'funny', 4.50), ('wonderful', 'great', 9.00), ('guilty', 'ashamed', 7.50), ('beautiful', 'wonderful', 8.50), ('confident', 'sure', 8.00)]",
#  "[('dumb', 'dense', 0.33), ('large', 'big', 0.95), ('nice', 'cruel', 0.22), ('impatient', 'anxious', 0.83), ('big', 'broad', 0.78), ('strong', 'proud', 0.23), ('unnecessary', 'necessary', 0.45), ('restless', 'young', 0.57), ('dumb', 'intelligent', 0.14), ('bad', 'great', 0.20), ('difficult', 'simple', 0.68), ('necessary', 'important', 0.65), ('bad', 'terrific', 0.12), ('mad', 'glad', 0.35), ('honest', 'guilty', 0.42), ('easy', 'tough', 0.50), ('easy', 'flexible', 0.40), ('certain', 'sure', 0.85), ('essential', 'necessary', 0.72), ('different', 'normal', 0.40), ('sly', 'clever', 0.65), ('crucial', 'important', 0.90), ('harsh', 'cruel', 0.75), ('childish', 'foolish', 0.78), ('scarce', 'rare', 0.72), ('friendly', 'generous', 0.55), ('fragile', 'frigid', 0.24), ('long', 'narrow', 0.78), ('big', 'heavy', 0.60), ('rough', 'frigid', 0.27), ('bizarre', 'strange', 0.85), ('illegal', 'immoral', 0.75), ('bad', 'guilty', 0.33), ('modern', 'ancient', 0.05), ('new', 'ancient', 0.14), ('dull', 'funny', 0.42), ('happy', 'young', 0.43), ('easy', 'big', 0.68), ('great', 'awful', 0.15), ('tiny', 'huge', 0.20)]",
#  "[('dumb', 'dense', 1.00), ('large', 'big', 9.21), ('nice', 'cruel', 0.00), ('impatient', 'anxious', 7.07), ('big', 'broad', 8.66), ('strong', 'proud', 4.24), ('unnecessary', 'necessary', 6.71), ('restless', 'young', 4.47), ('dumb', 'intelligent', 2.65), ('bad', 'great', 0.00), ('difficult', 'simple', 3.16), ('necessary', 'important', 6.71), ('bad', 'terrific', 0.00), ('mad', 'glad', 5.48), ('honest', 'guilty', 0.00), ('easy', 'tough', 3.16), ('easy', 'flexible', 3.16), ('certain', 'sure', 9.90), ('essential', 'necessary', 8.37), ('different', 'normal', 2.65), ('sly', 'clever', 4.24), ('crucial', 'important', 7.81), ('harsh', 'cruel', 4.71), ('childish', 'foolish', 6.08), ('scarce', 'rare', 7.75), ('friendly', 'generous', 2.65), ('fragile', 'frigid', 0.00), ('long', 'narrow', 6.08), ('big', 'heavy', 4.47), ('rough', 'frigid', 0.00), ('bizarre', 'strange', 9.11), ('illegal', 'immoral', 7.75), ('bad', 'guilty', 0.00), ('modern', 'ancient', 1.00), ('new', 'ancient', 1.00), ('dull', 'funny', 1.58), ('happy', 'young', 3.87), ('easy', 'big', 6.32), ('great', 'awful', 3.16), ('tiny', 'huge', 7.81)]",
#  "[('dumb', 'dense', 1.00), ('large', 'big', 8.00), ('nice', 'cruel', 3.00), ('impatient', 'anxious', 6.00), ('big', 'broad', 6.00), ('strong', 'proud', 3.00), ('unnecessary', 'necessary', 6.00), ('restless', 'young', 3.00), ('dumb', 'intelligent', 1.00), ('bad', 'great', 2.00), ('difficult', 'simple', 6.00), ('necessary', 'important', 4.00), ('bad', 'terrific', 2.00), ('mad', 'glad', 3.00), ('honest', 'guilty', 1.00), ('easy', 'tough', 4.00), ('easy', 'flexible', 3.00), ('certain', 'sure', 7.00), ('essential', 'necessary', 6.00), ('different', 'normal', 2.00), ('sly', 'clever', 5.00), ('crucial', 'important', 7.00), ('harsh', 'cruel', 7.00), ('childish', 'foolish', 6.00), ('scarce', 'rare', 5.00), ('friendly', 'generous', 6.00), ('fragile', 'frigid', 1.00), ('long', 'narrow', 6.00), ('big', 'heavy', 4.00), ('rough', 'frigid', 2.00), ('bizarre', 'strange', 8.00), ('illegal', 'immoral', 4.00), ('bad', 'guilty', 2.00), ('modern', 'ancient', 3.00), ('new', 'ancient', 2.00), ('dull', 'funny', 3.00), ('happy', 'young', 3.00), ('easy', 'big', 6.00), ('great', 'awful', 2.00), ('tiny', 'huge', 5.00)]",
#  "[('dumb', 'dense', 1.25), ('large', 'big', 9.00), ('nice', 'cruel', 1.75), ('impatient', 'anxious', 8.50), ('big', 'broad', 7.75), ('strong', 'proud', 1.75), ('unnecessary', 'necessary', 1.25), ('restless', 'young', 1.50), ('dumb', 'intelligent', 1.50), ('bad', 'great', 1.75), ('difficult', 'simple', 7.00), ('necessary', 'important', 7.50), ('bad', 'terrific', 1.50), ('mad', 'glad', 1.75), ('honest', 'guilty', 1.50), ('easy', 'tough', 6.75), ('easy', 'flexible', 5.50), ('certain', 'sure', 8.50), ('essential', 'necessary', 8.50), ('different', 'normal', 5.75), ('sly', 'clever', 5.50), ('crucial', 'important', 8.25), ('harsh', 'cruel', 6.75), ('childish', 'foolish', 8.00), ('scarce', 'rare', 7.50), ('friendly', 'generous', 6.50), ('fragile', 'frigid', 1.25), ('long', 'narrow', 6.50), ('big', 'heavy', 5.75), ('rough', 'frigid', 1.50), ('bizarre', 'strange', 8.25), ('illegal', 'immoral', 7.00), ('bad', 'guilty', 1.50), ('modern', 'ancient', 1.50), ('new', 'ancient', 1.50), ('dull', 'funny', 1.50), ('happy', 'young', 6.50), ('easy', 'big', 7.50), ('great', 'awful', 1.75), ('tiny', 'huge', 5.75)]",
#  "[('dumb', 'dense', 2.50), ('large', 'big', 8.00), ('nice', 'cruel', 1.50), ('impatient', 'anxious', 6.50), ('big', 'broad', 6.00), ('strong', 'proud', 3.50), ('unnecessary', 'necessary', 4.00), ('restless', 'young', 3.50), ('dumb', 'intelligent', 4.50), ('bad', 'great', 3.00), ('difficult', 'simple', 5.50), ('necessary', 'important', 7.00), ('bad', 'terrific', 2.50), ('mad', 'glad', 4.00), ('honest', 'guilty', 2.50), ('easy', 'tough', 4.00), ('easy', 'flexible', 2.00), ('certain', 'sure', 7.50), ('essential', 'necessary', 8.00), ('different', 'normal', 3.50), ('sly', 'clever', 4.00), ('crucial', 'important', 6.50), ('harsh', 'cruel', 6.00), ('childish', 'foolish', 6.00), ('scarce', 'rare', 6.50), ('friendly', 'generous', 6.00), ('fragile', 'frigid', 3.00), ('long', 'narrow', 5.50), ('big', 'heavy', 5.50), ('rough', 'frigid', 2.50), ('bizarre', 'strange', 7.00), ('illegal', 'immoral', 4.00), ('bad', 'guilty', 3.00), ('modern', 'ancient', 3.00), ('new', 'ancient', 2.50), ('dull', 'funny', 3.50), ('happy', 'young', 5.50), ('easy', 'big', 6.00), ('great', 'awful', 2.00), ('tiny', 'huge', 6.00)]",
#  "[('dumb', 'dense', 1.00), ('large', 'big', 1.00), ('nice', 'cruel', 0.75), ('impatient', 'anxious', 0.75), ('big', 'broad', 0.75), ('strong', 'proud', 0.25), ('unnecessary', 'necessary', 1.00), ('restless', 'young', 0.25), ('dumb', 'intelligent', 0.50), ('bad', 'great', 0.25), ('difficult', 'simple', 0.50), ('necessary', 'important', 0.75), ('bad', 'terrific', 0.25), ('mad', 'glad', 0.50), ('honest', 'guilty', 0.25), ('easy', 'tough', 0.25), ('easy', 'flexible', 0.50), ('certain', 'sure', 1.00), ('essential', 'necessary', 0.75), ('different', 'normal', 0.75), ('sly', 'clever', 0.75), ('crucial', 'important', 0.75), ('harsh', 'cruel', 0.50), ('childish', 'foolish', 0.75), ('scarce', 'rare', 0.75), ('friendly', 'generous', 0.75), ('fragile', 'frigid', 0.50), ('long', 'narrow', 0.50), ('big', 'heavy', 0.50), ('rough', 'frigid', 0.50), ('bizarre', 'strange', 0.75), ('illegal', 'immoral', 1.00), ('bad', 'guilty', 0.25), ('modern', 'ancient', 0.25), ('new', 'ancient', 0.25), ('dull', 'funny', 0.75), ('happy', 'young', 0.50), ('easy', 'big', 0.25), ('great', 'awful', 0.25), ('tiny', 'huge', 0.50)]",
#  "[('dumb', 'dense', 1.00), ('large', 'big', 0.95), ('nice', 'cruel', 0.12), ('impatient', 'anxious', 0.60), ('big', 'broad', 0.78), ('strong', 'proud', 0.28), ('unnecessary', 'necessary', 0.76), ('restless', 'young', 0.53), ('dumb', 'intelligent', 0.06), ('bad', 'great', 0.10), ('difficult', 'simple', 0.63), ('necessary', 'important', 0.73), ('bad', 'terrific', 0.15), ('mad', 'glad', 0.40), ('honest', 'guilty', 0.25), ('easy', 'tough', 0.53), ('easy', 'flexible', 0.40), ('certain', 'sure', 0.78), ('essential', 'necessary', 0.90), ('different', 'normal', 0.41), ('sly', 'clever', 0.60), ('crucial', 'important', 0.85), ('harsh', 'cruel', 0.46), ('childish', 'foolish', 0.90), ('scarce', 'rare', 0.84), ('friendly', 'generous', 0.70), ('fragile', 'frigid', 0.30), ('long', 'narrow', 0.59), ('big', 'heavy', 0.60), ('rough', 'frigid', 0.20), ('bizarre', 'strange', 0.84), ('illegal', 'immoral', 0.82), ('bad', 'guilty', 0.35), ('modern', 'ancient', 0.10), ('new', 'ancient', 0.20), ('dull', 'funny', 0.45), ('happy', 'young', 0.42), ('easy', 'big', 0.52), ('great', 'awful', 0.25), ('tiny', 'huge', 0.65)]",
#  "[('dumb', 'dense', 6.67), ('large', 'big', 8.33), ('nice', 'cruel', 3.33), ('impatient', 'anxious', 8.33), ('big', 'broad', 7.67), ('strong', 'proud', 5.00), ('unnecessary', 'necessary', 3.33), ('restless', 'young', 2.00), ('dumb', 'intelligent', 4.00), ('bad', 'great', 1.67), ('difficult', 'simple', 5.33), ('necessary', 'important', 6.67), ('bad', 'terrific', 3.33), ('mad', 'glad', 4.67), ('honest', 'guilty', 3.00), ('easy', 'tough', 6.33), ('easy', 'flexible', 3.33), ('certain', 'sure', 8.33), ('essential', 'necessary', 8.00), ('different', 'normal', 3.67), ('sly', 'clever', 6.00), ('crucial', 'important', 7.33), ('harsh', 'cruel', 6.33), ('childish', 'foolish', 6.00), ('scarce', 'rare', 7.33), ('friendly', 'generous', 5.67), ('fragile', 'frigid', 1.67), ('long', 'narrow', 3.67), ('big', 'heavy', 6.67), ('rough', 'frigid', 2.67), ('bizarre', 'strange', 7.33), ('illegal', 'immoral', 8.33), ('bad', 'guilty', 4.33), ('modern', 'ancient', 2.67), ('new', 'ancient', 2.33), ('dull', 'funny', 3.67), ('happy', 'young', 3.67), ('easy', 'big', 6.67), ('great', 'awful', 1.67), ('tiny', 'huge', 6.33)]",
#  "[('dumb', 'dense', 0.92), ('large', 'big', 8.00), ('nice', 'cruel', 0.85), ('impatient', 'anxious', 7.25), ('big', 'broad', 7.50), ('strong', 'proud', 5.00), ('unnecessary', 'necessary', 4.50), ('restless', 'young', 3.50), ('dumb', 'intelligent', 0.96), ('bad', 'great', 0.75), ('difficult', 'simple', 6.50), ('necessary', 'important', 8.00), ('bad', 'terrific', 0.55), ('mad', 'glad', 5.25), ('honest', 'guilty', 0.85), ('easy', 'tough', 5.50), ('easy', 'flexible', 7.25), ('certain', 'sure', 7.50), ('essential', 'necessary', 8.50), ('different', 'normal', 6.00), ('sly', 'clever', 7.25), ('crucial', 'important', 8.50), ('harsh', 'cruel', 6.75), ('childish', 'foolish', 7.75), ('scarce', 'rare', 6.75), ('friendly', 'generous', 5.75), ('fragile', 'frigid', 2.50), ('long', 'narrow', 7.25), ('big', 'heavy', 7.00), ('rough', 'frigid', 2.75), ('bizarre', 'strange', 8.50), ('illegal', 'immoral', 8.00), ('bad', 'guilty', 2.75), ('modern', 'ancient', 3.50), ('new', 'ancient', 3.50), ('dull', 'funny', 2.50), ('happy', 'young', 5.00), ('easy', 'big', 7.25), ('great', 'awful', 3.50), ('tiny', 'huge', 6.00)]",
#  "[('dumb', 'dense', 2.50), ('large', 'big', 9.00), ('nice', 'cruel', 1.50), ('impatient', 'anxious', 6.50), ('big', 'broad', 7.50), ('strong', 'proud', 3.50), ('unnecessary', 'necessary', 1.00), ('restless', 'young', 5.00), ('dumb', 'intelligent', 2.00), ('bad', 'great', 2.00), ('difficult', 'simple', 6.50), ('necessary', 'important', 4.00), ('bad', 'terrific', 3.00), ('mad', 'glad', 4.00), ('honest', 'guilty', 1.50), ('easy', 'tough', 4.50), ('easy', 'flexible', 3.00), ('certain', 'sure', 8.00), ('essential', 'necessary', 6.00), ('different', 'normal', 5.00), ('sly', 'clever', 6.00), ('crucial', 'important', 7.00), ('harsh', 'cruel', 6.50), ('childish', 'foolish', 7.00), ('scarce', 'rare', 8.00), ('friendly', 'generous', 7.00), ('fragile', 'frigid', 2.00), ('long', 'narrow', 7.00), ('big', 'heavy', 7.00), ('rough', 'frigid', 2.00), ('bizarre', 'strange', 8.00), ('illegal', 'immoral', 7.00), ('bad', 'guilty', 2.00), ('modern', 'ancient', 2.00), ('new', 'ancient', 2.00), ('dull', 'funny', 4.50), ('happy', 'young', 4.00), ('easy', 'big', 5.50), ('great', 'awful', 3.50), ('tiny', 'huge', 3.50)]",
#  "[('dumb', 'dense', 0.88), ('large', 'big', 9.00), ('nice', 'cruel', 0.11), ('impatient', 'anxious', 9.00), ('big', 'broad', 7.21), ('strong', 'proud', 2.46), ('unnecessary', 'necessary', 0.88), ('restless', 'young', 1.58), ('dumb', 'intelligent', 1.58), ('bad', 'great', 0.11), ('difficult', 'simple', 5.29), ('necessary', 'important', 3.00), ('bad', 'terrific', 0.11), ('mad', 'glad', 1.58), ('honest', 'guilty', 0.11), ('easy', 'tough', 5.29), ('easy', 'flexible', 0.11), ('certain', 'sure', 7.21), ('essential', 'necessary', 7.21), ('different', 'normal', 1.58), ('sly', 'clever', 4.00), ('crucial', 'important', 5.29), ('harsh', 'cruel', 5.29), ('childish', 'foolish', 7.21), ('scarce', 'rare', 2.46), ('friendly', 'generous', 7.21), ('fragile', 'frigid', 0.11), ('long', 'narrow', 5.29), ('big', 'heavy', 2.46), ('rough', 'frigid', 1.58), ('bizarre', 'strange', 7.21), ('illegal', 'immoral', 5.29), ('bad', 'guilty', 0.88), ('modern', 'ancient', 1.58), ('new', 'ancient', 0.11), ('dull', 'funny', 1.58), ('happy', 'young', 0.11), ('easy', 'big', 5.29), ('great', 'awful', 2.46), ('tiny', 'huge', 2.46)]",
#  "[('dumb', 'dense', 2.00), ('large', 'big', 9.50), ('nice', 'cruel', 1.50), ('impatient', 'anxious', 6.50), ('big', 'broad', 8.50), ('strong', 'proud', 4.00), ('unnecessary', 'necessary', 6.00), ('restless', 'young', 2.00), ('dumb', 'intelligent', 1.50), ('bad', 'great', 3.00), ('difficult', 'simple', 6.50), ('necessary', 'important', 7.00), ('bad', 'terrific', 1.50), ('mad', 'glad', 3.00), ('honest', 'guilty', 2.00), ('easy', 'tough', 2.50), ('easy', 'flexible', 2.50), ('certain', 'sure', 7.50), ('essential', 'necessary', 8.00), ('different', 'normal', 3.50), ('sly', 'clever', 5.00), ('crucial', 'important', 8.50), ('harsh', 'cruel', 5.00), ('childish', 'foolish', 5.50), ('scarce', 'rare', 7.50), ('friendly', 'generous', 4.50), ('fragile', 'frigid', 2.00), ('long', 'narrow', 6.50), ('big', 'heavy', 8.50), ('rough', 'frigid', 2.50), ('bizarre', 'strange', 6.50), ('illegal', 'immoral', 4.50), ('bad', 'guilty', 3.00), ('modern', 'ancient', 2.50), ('new', 'ancient', 3.00), ('dull', 'funny', 3.50), ('happy', 'young', 3.50), ('easy', 'big', 4.00), ('great', 'awful', 3.00), ('tiny', 'huge', 4.00)]",
#  "[('dumb', 'dense', 2.00), ('large', 'big', 9.50), ('nice', 'cruel', 1.00), ('impatient', 'anxious', 7.50), ('big', 'broad', 8.50), ('strong', 'proud', 3.00), ('unnecessary', 'necessary', 7.50), ('restless', 'young', 2.00), ('dumb', 'intelligent', 3.00), ('bad', 'great', 1.00), ('difficult', 'simple', 6.00), ('necessary', 'important', 6.50), ('bad', 'terrific', 2.00), ('mad', 'glad', 2.50), ('honest', 'guilty', 1.50), ('easy', 'tough', 6.00), ('easy', 'flexible', 5.50), ('certain', 'sure', 8.50), ('essential', 'necessary', 8.00), ('different', 'normal', 4.00), ('sly', 'clever', 7.50), ('crucial', 'important', 7.00), ('harsh', 'cruel', 5.00), ('childish', 'foolish', 6.00), ('scarce', 'rare', 7.50), ('friendly', 'generous', 6.00), ('fragile', 'frigid', 2.00), ('long', 'narrow', 7.00), ('big', 'heavy', 6.00), ('rough', 'frigid', 3.50), ('bizarre', 'strange', 8.00), ('illegal', 'immoral', 5.50), ('bad', 'guilty', 2.00), ('modern', 'ancient', 4.00), ('new', 'ancient', 2.00), ('dull', 'funny', 3.00), ('happy', 'young', 4.50), ('easy', 'big', 6.00), ('great', 'awful', 1.00), ('tiny', 'huge', 6.00)]",
#  "[('dumb', 'dense', 1.80), ('large', 'big', 8.79), ('nice', 'cruel', 1.54), ('impatient', 'anxious', 6.22), ('big', 'broad', 7.95), ('strong', 'proud', 3.84), ('unnecessary', 'necessary', 5.32), ('restless', 'young', 1.70), ('dumb', 'intelligent', 1.79), ('bad', 'great', 2.37), ('difficult', 'simple', 2.74), ('necessary', 'important', 7.11), ('bad', 'terrific', 1.84), ('mad', 'glad', 3.70), ('honest', 'guilty', 1.48), ('easy', 'tough', 2.84), ('easy', 'flexible', 1.93), ('certain', 'sure', 8.83), ('essential', 'necessary', 8.44), ('different', 'normal', 3.72), ('sly', 'clever', 5.86), ('crucial', 'important', 7.44), ('harsh', 'cruel', 6.53), ('childish', 'foolish', 5.16), ('scarce', 'rare', 7.28), ('friendly', 'generous', 6.55), ('fragile', 'frigid', 1.71), ('long', 'narrow', 5.76), ('big', 'heavy', 5.86), ('rough', 'frigid', 1.43), ('bizarre', 'strange', 8.39), ('illegal', 'immoral', 5.58), ('bad', 'guilty', 1.72), ('modern', 'ancient', 2.00), ('new', 'ancient', 1.65), ('dull', 'funny', 1.69), ('happy', 'young', 2.46), ('easy', 'big', 3.42), ('great', 'awful', 1.74), ('tiny', 'huge', 3.68)]",
#  "[('dumb', 'dense', 2.50), ('large', 'big', 9.50), ('nice', 'cruel', 2.00), ('impatient', 'anxious', 5.50), ('big', 'broad', 8.00), ('strong', 'proud', 2.50), ('unnecessary', 'necessary', 1.50), ('restless', 'young', 1.50), ('dumb', 'intelligent', 2.00), ('bad', 'great', 3.00), ('difficult', 'simple', 3.00), ('necessary', 'important', 5.00), ('bad', 'terrific', 1.50), ('mad', 'glad', 4.00), ('honest', 'guilty', 1.50), ('easy', 'tough', 3.50), ('easy', 'flexible', 3.00), ('certain', 'sure', 8.00), ('essential', 'necessary', 7.00), ('different', 'normal', 3.00), ('sly', 'clever', 6.50), ('crucial', 'important', 7.50), ('harsh', 'cruel', 6.00), ('childish', 'foolish', 6.00), ('scarce', 'rare', 8.50), ('friendly', 'generous', 9.00), ('fragile', 'frigid', 2.00), ('long', 'narrow', 6.50), ('big', 'heavy', 6.50), ('rough', 'frigid', 2.00), ('bizarre', 'strange', 9.00), ('illegal', 'immoral', 5.50), ('bad', 'guilty', 3.00), ('modern', 'ancient', 2.00), ('new', 'ancient', 2.00), ('dull', 'funny', 4.00), ('happy', 'young', 2.50), ('easy', 'big', 5.50), ('great', 'awful', 3.00), ('tiny', 'huge', 4.50)]",
#  "[('polite', 'proper', 0.26), ('modest', 'ashamed', 1.48), ('exotic', 'rare', 2.58), ('dumb', 'clever', 1.54), ('delightful', 'wonderful', 5.02), ('noticeable', 'obvious', 6.63), ('afraid', 'anxious', 4.16), ('formal', 'proper', 6.22), ('dreary', 'dull', 5.58), ('delightful', 'cheerful', 3.77), ('unhappy', 'mad', 2.18), ('sad', 'terrible', 2.40), ('sick', 'crazy', 3.70), ('violent', 'angry', 6.07), ('laden', 'heavy', 4.06), ('dirty', 'cheap', 1.57), ('elastic', 'flexible', 7.13), ('hard', 'dense', 3.20), ('recent', 'new', 7.97), ('bold', 'proud', 3.20), ('sly', 'strange', 2.38), ('strange', 'sly', 2.38), ('dumb', 'rare', 1.75), ('sly', 'tough', 1.16), ('terrific', 'mad', 2.77), ('modest', 'flexible', 0.99), ('fresh', 'wide', 2.91), ('huge', 'dumb', 1.50), ('large', 'flexible', 5.81), ('dirty', 'narrow', 2.24), ('wife', 'husband', 8.43), ('book', 'text', 4.53), ('groom', 'bride', 7.74), ('night', 'day', 6.08), ('south', 'north', 7.54), ('plane', 'airport', 4.50), ('uncle', 'aunt', 8.74), ('horse', 'mare', 7.70), ('bottom', 'top', 7.14), ('friend', 'buddy', 6.81)]",
#  "[('polite', 'proper', 1.44), ('modest', 'ashamed', 3.00), ('exotic', 'rare', 4.19), ('dumb', 'clever', 2.87), ('delightful', 'wonderful', 8.99), ('noticeable', 'obvious', 7.39), ('afraid', 'anxious', 6.51), ('formal', 'proper', 6.04), ('dreary', 'dull', 8.41), ('delightful', 'cheerful', 7.88), ('unhappy', 'mad', 3.24), ('sad', 'terrible', 2.36), ('sick', 'crazy', 2.26), ('violent', 'angry', 7.15), ('laden', 'heavy', 3.65), ('dirty', 'cheap', 3.12), ('elastic', 'flexible', 8.07), ('hard', 'dense', 5.80), ('recent', 'new', 6.91), ('bold', 'proud', 4.46), ('sly', 'strange', 3.67), ('strange', 'sly', 3.67), ('dumb', 'rare', 2.87), ('sly', 'tough', 3.52), ('terrific', 'mad', 2.22), ('modest', 'flexible', 2.53), ('fresh', 'wide', 2.99), ('huge', 'dumb', 1.21), ('large', 'flexible', 5.14), ('dirty', 'narrow', 3.37), ('wife', 'husband', 5.32), ('book', 'text', 6.19), ('groom', 'bride', 6.06), ('night', 'day', 3.37), ('south', 'north', 7.75), ('plane', 'airport', 7.42), ('uncle', 'aunt', 6.39), ('horse', 'mare', 6.80), ('bottom', 'top', 6.54), ('friend', 'buddy', 8.56)]",
#  "[('polite', 'proper', 2.59), ('modest', 'ashamed', 7.32), ('exotic', 'rare', 6.08), ('dumb', 'clever', 1.02), ('delightful', 'wonderful', 8.95), ('noticeable', 'obvious', 6.80), ('afraid', 'anxious', 6.47), ('formal', 'proper', 7.97), ('dreary', 'dull', 7.24), ('delightful', 'cheerful', 7.14), ('unhappy', 'mad', 3.68), ('sad', 'terrible', 5.56), ('sick', 'crazy', 3.35), ('violent', 'angry', 6.68), ('laden', 'heavy', 7.88), ('dirty', 'cheap', 4.17), ('elastic', 'flexible', 7.90), ('hard', 'dense', 6.15), ('recent', 'new', 7.94), ('bold', 'proud', 3.56), ('sly', 'strange', 3.34), ('strange', 'sly', 3.34), ('dumb', 'rare', 1.32), ('sly', 'tough', 2.49), ('terrific', 'mad', 3.38), ('modest', 'flexible', 3.88), ('fresh', 'wide', 5.12), ('huge', 'dumb', 5.33), ('large', 'flexible', 6.40), ('dirty', 'narrow', 4.82), ('wife', 'husband', 9.95), ('book', 'text', 5.28), ('groom', 'bride', 9.84), ('night', 'day', 5.22), ('south', 'north', 9.75), ('plane', 'airport', 4.43), ('uncle', 'aunt', 9.95), ('horse', 'mare', 8.77), ('bottom', 'top', 7.73), ('friend', 'buddy', 8.64)]",
#  "[('polite', 'proper', 3.00), ('modest', 'ashamed', 1.50), ('exotic', 'rare', 6.50), ('dumb', 'clever', 1.00), ('delightful', 'wonderful', 8.00), ('noticeable', 'obvious', 7.00), ('afraid', 'anxious', 5.00), ('formal', 'proper', 7.00), ('dreary', 'dull', 6.00), ('delightful', 'cheerful', 6.50), ('unhappy', 'mad', 2.00), ('sad', 'terrible', 2.00), ('sick', 'crazy', 3.00), ('violent', 'angry', 6.00), ('laden', 'heavy', 7.00), ('dirty', 'cheap', 5.00), ('elastic', 'flexible', 7.00), ('hard', 'dense', 4.00), ('recent', 'new', 8.00), ('bold', 'proud', 5.00), ('sly', 'strange', 3.00), ('strange', 'sly', 3.00), ('dumb', 'rare', 1.00), ('sly', 'tough', 2.00), ('terrific', 'mad', 3.00), ('modest', 'flexible', 2.50), ('fresh', 'wide', 5.50), ('huge', 'dumb', 2.00), ('large', 'flexible', 6.50), ('dirty', 'narrow', 4.00), ('wife', 'husband', 7.50), ('book', 'text', 7.50), ('groom', 'bride', 8.00), ('night', 'day', 5.00), ('south', 'north', 7.50), ('plane', 'airport', 5.00), ('uncle', 'aunt', 8.00), ('horse', 'mare', 5.00), ('bottom', 'top', 6.50), ('friend', 'buddy', 7.00)]",
#  "[('polite', 'proper', 1.00), ('modest', 'ashamed', 0.45), ('exotic', 'rare', 0.75), ('dumb', 'clever', 0.20), ('delightful', 'wonderful', 0.90), ('noticeable', 'obvious', 0.80), ('afraid', 'anxious', 0.70), ('formal', 'proper', 0.80), ('dreary', 'dull', 0.70), ('delightful', 'cheerful', 0.80), ('unhappy', 'mad', 0.40), ('sad', 'terrible', 0.30), ('sick', 'crazy', 0.40), ('violent', 'angry', 0.70), ('laden', 'heavy', 0.80), ('dirty', 'cheap', 0.30), ('elastic', 'flexible', 0.70), ('hard', 'dense', 0.50), ('recent', 'new', 0.90), ('bold', 'proud', 0.40), ('sly', 'strange', 0.20), ('strange', 'sly', 0.20), ('dumb', 'rare', 0.30), ('sly', 'tough', 0.30), ('terrific', 'mad', 0.50), ('modest', 'flexible', 0.40), ('fresh', 'wide', 0.50), ('huge', 'dumb', 0.30), ('large', 'flexible', 0.70), ('dirty', 'narrow', 0.30), ('wife', 'husband', 0.90), ('book', 'text', 0.70), ('groom', 'bride', 0.90), ('night', 'day', 0.60), ('south', 'north', 0.70), ('plane', 'airport', 0.60), ('uncle', 'aunt', 0.90), ('horse', 'mare', 0.85), ('bottom', 'top', 0.80), ('friend', 'buddy', 0.90)]",
#  "[('polite', 'proper', 1.00), ('modest', 'ashamed', 3.50), ('exotic', 'rare', 3.50), ('dumb', 'clever', 1.00), ('delightful', 'wonderful', 9.00), ('noticeable', 'obvious', 8.00), ('afraid', 'anxious', 7.00), ('formal', 'proper', 7.00), ('dreary', 'dull', 7.00), ('delightful', 'cheerful', 7.50), ('unhappy', 'mad', 1.00), ('sad', 'terrible', 3.00), ('sick', 'crazy', 4.00), ('violent', 'angry', 5.50), ('laden', 'heavy', 7.00), ('dirty', 'cheap', 4.00), ('elastic', 'flexible', 8.50), ('hard', 'dense', 3.00), ('recent', 'new', 6.50), ('bold', 'proud', 4.00), ('sly', 'strange', 2.00), ('strange', 'sly', 2.00), ('dumb', 'rare', 1.00), ('sly', 'tough', 1.00), ('terrific', 'mad', 2.50), ('modest', 'flexible', 2.50), ('fresh', 'wide', 2.50), ('huge', 'dumb', 1.00), ('large', 'flexible', 3.00), ('dirty', 'narrow', 3.00), ('wife', 'husband', 8.50), ('book', 'text', 6.50), ('groom', 'bride', 8.50), ('night', 'day', 5.00), ('south', 'north', 7.00), ('plane', 'airport', 6.00), ('uncle', 'aunt', 8.00), ('horse', 'mare', 6.50), ('bottom', 'top', 7.50), ('friend', 'buddy', 8.50)]",
#  "[('polite', 'proper', 2.30), ('modest', 'ashamed', 3.20), ('exotic', 'rare', 6.10), ('dumb', 'clever', 1.50), ('delightful', 'wonderful', 7.80), ('noticeable', 'obvious', 7.80), ('afraid', 'anxious', 3.90), ('formal', 'proper', 6.50), ('dreary', 'dull', 7.20), ('delightful', 'cheerful', 6.70), ('unhappy', 'mad', 2.90), ('sad', 'terrible', 5.20), ('sick', 'crazy', 4.70), ('violent', 'angry', 6.40), ('laden', 'heavy', 6.60), ('dirty', 'cheap', 2.50), ('elastic', 'flexible', 6.90), ('hard', 'dense', 6.40), ('recent', 'new', 6.20), ('bold', 'proud', 5.30), ('sly', 'strange', 3.80), ('strange', 'sly', 3.80), ('dumb', 'rare', 1.80), ('sly', 'tough', 1.80), ('terrific', 'mad', 3.00), ('modest', 'flexible', 3.90), ('fresh', 'wide', 6.10), ('huge', 'dumb', 2.80), ('large', 'flexible', 6.00), ('dirty', 'narrow', 2.70), ('wife', 'husband', 7.90), ('book', 'text', 6.90), ('groom', 'bride', 7.40), ('night', 'day', 5.20), ('south', 'north', 7.00), ('plane', 'airport', 3.00), ('uncle', 'aunt', 8.40), ('horse', 'mare', 8.10), ('bottom', 'top', 7.70), ('friend', 'buddy', 6.90)]",
#  "[('polite', 'proper', 0.54), ('modest', 'ashamed', 2.31), ('exotic', 'rare', 3.92), ('dumb', 'clever', 0.46), ('delightful', 'wonderful', 6.54), ('noticeable', 'obvious', 6.23), ('afraid', 'anxious', 5.31), ('formal', 'proper', 6.69), ('dreary', 'dull', 4.23), ('delightful', 'cheerful', 7.77), ('unhappy', 'mad', 2.54), ('sad', 'terrible', 3.69), ('sick', 'crazy', 2.08), ('violent', 'angry', 6.15), ('laden', 'heavy', 6.23), ('dirty', 'cheap', 1.46), ('elastic', 'flexible', 6.46), ('hard', 'dense', 5.23), ('recent', 'new', 7.92), ('bold', 'proud', 3.08), ('sly', 'strange', 1.85), ('strange', 'sly', 1.85), ('dumb', 'rare', 2.08), ('sly', 'tough', 0.77), ('terrific', 'mad', 2.23), ('modest', 'flexible', 2.54), ('fresh', 'wide', 5.77), ('huge', 'dumb', 1.15), ('large', 'flexible', 5.69), ('dirty', 'narrow', 1.69), ('wife', 'husband', 8.54), ('book', 'text', 7.15), ('groom', 'bride', 7.77), ('night', 'day', 5.85), ('south', 'north', 7.69), ('plane', 'airport', 6.46), ('uncle', 'aunt', 8.38), ('horse', 'mare', 5.54), ('bottom', 'top', 6.31), ('friend', 'buddy', 7.46)]",
#  "[('polite', 'proper', 1.89), ('modest', 'ashamed', 2.10), ('exotic', 'rare', 3.67), ('dumb', 'clever', 1.10), ('delightful', 'wonderful', 7.00), ('noticeable', 'obvious', 5.56), ('afraid', 'anxious', 5.78), ('formal', 'proper', 7.78), ('dreary', 'dull', 7.00), ('delightful', 'cheerful', 6.67), ('unhappy', 'mad', 1.56), ('sad', 'terrible', 3.67), ('sick', 'crazy', 3.00), ('violent', 'angry', 6.56), ('laden', 'heavy', 7.44), ('dirty', 'cheap', 3.33), ('elastic', 'flexible', 7.56), ('hard', 'dense', 5.56), ('recent', 'new', 7.33), ('bold', 'proud', 4.11), ('sly', 'strange', 2.11), ('strange', 'sly', 2.11), ('dumb', 'rare', 1.78), ('sly', 'tough', 1.44), ('terrific', 'mad', 1.89), ('modest', 'flexible', 2.44), ('fresh', 'wide', 5.00), ('huge', 'dumb', 1.67), ('large', 'flexible', 6.11), ('dirty', 'narrow', 3.22), ('wife', 'husband', 7.67), ('book', 'text', 5.67), ('groom', 'bride', 7.67), ('night', 'day', 5.56), ('south', 'north', 5.67), ('plane', 'airport', 2.89), ('uncle', 'aunt', 7.00), ('horse', 'mare', 7.67), ('bottom', 'top', 5.78), ('friend', 'buddy', 8.00)]",
#  "[('polite', 'proper', 0.30), ('modest', 'ashamed', 0.19), ('exotic', 'rare', 0.70), ('dumb', 'clever', 0.11), ('delightful', 'wonderful', 0.85), ('noticeable', 'obvious', 0.62), ('afraid', 'anxious', 0.57), ('formal', 'proper', 0.65), ('dreary', 'dull', 0.77), ('delightful', 'cheerful', 0.62), ('unhappy', 'mad', 0.38), ('sad', 'terrible', 0.30), ('sick', 'crazy', 0.30), ('violent', 'angry', 0.60), ('laden', 'heavy', 0.65), ('dirty', 'cheap', 0.35), ('elastic', 'flexible', 0.75), ('hard', 'dense', 0.55), ('recent', 'new', 0.60), ('bold', 'proud', 0.25), ('sly', 'strange', 0.16), ('strange', 'sly', 0.16), ('dumb', 'rare', 0.11), ('sly', 'tough', 0.12), ('terrific', 'mad', 0.36), ('modest', 'flexible', 0.22), ('fresh', 'wide', 0.43), ('huge', 'dumb', 0.25), ('large', 'flexible', 0.50), ('dirty', 'narrow', 0.35), ('wife', 'husband', 0.85), ('book', 'text', 0.75), ('groom', 'bride', 0.80), ('night', 'day', 0.40), ('south', 'north', 0.80), ('plane', 'airport', 0.52), ('uncle', 'aunt', 0.80), ('horse', 'mare', 0.85), ('bottom', 'top', 0.70), ('friend', 'buddy', 0.90)]",
#  "[('polite', 'proper', 2.00), ('modest', 'ashamed', 3.00), ('exotic', 'rare', 6.00), ('dumb', 'clever', 1.00), ('delightful', 'wonderful', 8.00), ('noticeable', 'obvious', 7.00), ('afraid', 'anxious', 6.00), ('formal', 'proper', 7.00), ('dreary', 'dull', 8.00), ('delightful', 'cheerful', 7.00), ('unhappy', 'mad', 2.00), ('sad', 'terrible', 4.00), ('sick', 'crazy', 2.00), ('violent', 'angry', 7.00), ('laden', 'heavy', 4.00), ('dirty', 'cheap', 3.00), ('elastic', 'flexible', 7.00), ('hard', 'dense', 7.00), ('recent', 'new', 8.00), ('bold', 'proud', 3.00), ('sly', 'strange', 3.00), ('strange', 'sly', 3.00), ('dumb', 'rare', 1.00), ('sly', 'tough', 2.00), ('terrific', 'mad', 3.00), ('modest', 'flexible', 2.00), ('fresh', 'wide', 5.00), ('huge', 'dumb', 2.00), ('large', 'flexible', 6.00), ('dirty', 'narrow', 3.00), ('wife', 'husband', 8.00), ('book', 'text', 5.00), ('groom', 'bride', 8.00), ('night', 'day', 5.00), ('south', 'north', 8.00), ('plane', 'airport', 5.00), ('uncle', 'aunt', 8.00), ('horse', 'mare', 5.00), ('bottom', 'top', 6.00), ('friend', 'buddy', 9.00)]",
#  "[('polite', 'proper', 3.47), ('modest', 'ashamed', 4.29), ('exotic', 'rare', 6.67), ('dumb', 'clever', 1.54), ('delightful', 'wonderful', 8.33), ('noticeable', 'obvious', 7.67), ('afraid', 'anxious', 5.15), ('formal', 'proper', 6.98), ('dreary', 'dull', 8.06), ('delightful', 'cheerful', 7.85), ('unhappy', 'mad', 3.10), ('sad', 'terrible', 2.38), ('sick', 'crazy', 4.52), ('violent', 'angry', 6.46), ('laden', 'heavy', 6.25), ('dirty', 'cheap', 4.05), ('elastic', 'flexible', 6.25), ('hard', 'dense', 5.78), ('recent', 'new', 6.98), ('bold', 'proud', 3.08), ('sly', 'strange', 2.17), ('strange', 'sly', 2.17), ('dumb', 'rare', 1.54), ('sly', 'tough', 1.87), ('terrific', 'mad', 3.06), ('modest', 'flexible', 2.73), ('fresh', 'wide', 4.45), ('huge', 'dumb', 1.92), ('large', 'flexible', 5.00), ('dirty', 'narrow', 3.23), ('wife', 'husband', 7.69), ('book', 'text', 4.46), ('groom', 'bride', 7.92), ('night', 'day', 6.81), ('south', 'north', 6.44), ('plane', 'airport', 5.44), ('uncle', 'aunt', 7.50), ('horse', 'mare', 4.76), ('bottom', 'top', 7.90), ('friend', 'buddy', 8.73)]",
#  "[('polite', 'proper', 1.00), ('modest', 'ashamed', 0.50), ('exotic', 'rare', 0.75), ('dumb', 'clever', 0.25), ('delightful', 'wonderful', 0.75), ('noticeable', 'obvious', 0.75), ('afraid', 'anxious', 0.50), ('formal', 'proper', 0.75), ('dreary', 'dull', 0.75), ('delightful', 'cheerful', 0.50), ('unhappy', 'mad', 0.25), ('sad', 'terrible', 0.25), ('sick', 'crazy', 0.50), ('violent', 'angry', 0.75), ('laden', 'heavy', 0.75), ('dirty', 'cheap', 0.25), ('elastic', 'flexible', 1.00), ('hard', 'dense', 0.75), ('recent', 'new', 0.75), ('bold', 'proud', 0.25), ('sly', 'strange', 0.25), ('strange', 'sly', 0.25), ('dumb', 'rare', 0.50), ('sly', 'tough', 0.25), ('terrific', 'mad', 0.25), ('modest', 'flexible', 0.25), ('fresh', 'wide', 0.25), ('huge', 'dumb', 0.25), ('large', 'flexible', 0.25), ('dirty', 'narrow', 0.25), ('wife', 'husband', 1.00), ('book', 'text', 0.75), ('groom', 'bride', 1.00), ('night', 'day', 0.25), ('south', 'north', 0.25), ('plane', 'airport', 0.50), ('uncle', 'aunt', 1.00), ('horse', 'mare', 0.50), ('bottom', 'top', 0.50), ('friend', 'buddy', 0.75)]",
#  "[('polite', 'proper', 4.50), ('modest', 'ashamed', 3.00), ('exotic', 'rare', 6.00), ('dumb', 'clever', 2.50), ('delightful', 'wonderful', 8.50), ('noticeable', 'obvious', 7.00), ('afraid', 'anxious', 6.00), ('formal', 'proper', 7.00), ('dreary', 'dull', 7.50), ('delightful', 'cheerful', 5.00), ('unhappy', 'mad', 2.00), ('sad', 'terrible', 3.50), ('sick', 'crazy', 3.00), ('violent', 'angry', 6.50), ('laden', 'heavy', 7.50), ('dirty', 'cheap', 4.00), ('elastic', 'flexible', 8.00), ('hard', 'dense', 6.50), ('recent', 'new', 8.50), ('bold', 'proud', 3.50), ('sly', 'strange', 2.50), ('strange', 'sly', 2.50), ('dumb', 'rare', 3.00), ('sly', 'tough', 2.50), ('terrific', 'mad', 2.00), ('modest', 'flexible', 4.50), ('fresh', 'wide', 4.00), ('huge', 'dumb', 3.00), ('large', 'flexible', 6.50), ('dirty', 'narrow', 4.00), ('wife', 'husband', 8.50), ('book', 'text', 6.50), ('groom', 'bride', 7.00), ('night', 'day', 6.50), ('south', 'north', 8.00), ('plane', 'airport', 6.00), ('uncle', 'aunt', 6.50), ('horse', 'mare', 7.00), ('bottom', 'top', 5.00), ('friend', 'buddy', 8.00)]",
# ...
#  "[('bring', 'send', 1.24), ('absorb', 'learn', 2.53), ('acquire', 'find', 1.88), ('leave', 'appear', 1.05), ('create', 'destroy', 1.33), ('begin', 'go', 1.47), ('get', 'buy', 1.54), ('collect', 'save', 1.95), ('replace', 'restore', 1.71), ('join', 'add', 2.67), ('join', 'marry', 1.59), ('accept', 'deliver', 1.15), ('attach', 'join', 2.19), ('put', 'hang', 1.11), ('go', 'sell', 1.06), ('communicate', 'pray', 1.32), ('give', 'steal', 1.08), ('add', 'build', 2.36), ('bring', 'restore', 1.60), ('comprehend', 'satisfy', 1.98), ('portray', 'decide', 1.08), ('organize', 'become', 1.42), ('give', 'know', 1.50), ('say', 'verify', 1.07), ('cooperate', 'join', 1.74), ('arrange', 'require', 1.23), ('borrow', 'want', 1.28), ('investigate', 'pursue', 1.52), ('ignore', 'explore', 1.43), ('bring', 'complain', 1.21), ('enter', 'owe', 1.31), ('portray', 'notify', 1.07), ('remind', 'sell', 1.07), ('absorb', 'possess', 1.92), ('join', 'acquire', 2.33), ('send', 'attend', 1.51), ('gather', 'attend', 2.00), ('absorb', 'withdraw', 1.52), ('attend', 'arrive', 1.75)]",
#  "[('bring', 'send', 0.85), ('absorb', 'learn', 0.41), ('acquire', 'find', 0.20), ('leave', 'appear', 0.12), ('create', 'destroy', 0.11), ('begin', 'go', 0.23), ('get', 'buy', 0.65), ('collect', 'save', 0.22), ('replace', 'restore', 0.15), ('join', 'add', 0.38), ('join', 'marry', 0.67), ('accept', 'deliver', 0.14), ('attach', 'join', 0.46), ('put', 'hang', 0.40), ('go', 'sell', 0.16), ('communicate', 'pray', 0.05), ('give', 'steal', 0.12), ('add', 'build', 0.57), ('bring', 'restore', 0.33), ('comprehend', 'satisfy', 0.13), ('portray', 'decide', 0.10), ('organize', 'become', 0.15), ('give', 'know', 0.41), ('say', 'verify', 0.19), ('cooperate', 'join', 0.46), ('arrange', 'require', 0.16), ('borrow', 'want', 0.17), ('investigate', 'pursue', 0.38), ('ignore', 'explore', 0.19), ('bring', 'complain', 0.22), ('enter', 'owe', 0.12), ('portray', 'notify', 0.06), ('remind', 'sell', 0.08), ('absorb', 'possess', 0.36), ('join', 'acquire', 0.60), ('send', 'attend', 0.35), ('gather', 'attend', 0.48), ('absorb', 'withdraw', 0.17), ('attend', 'arrive', 0.53)]",
#  "[('bring', 'send', 0.81), ('absorb', 'learn', 0.02), ('acquire', 'find', 0.47), ('leave', 'appear', 0.21), ('create', 'destroy', 0.12), ('begin', 'go', 0.45), ('get', 'buy', 0.28), ('collect', 'save', 0.13), ('replace', 'restore', 0.34), ('join', 'add', 0.49), ('join', 'marry', 0.06), ('accept', 'deliver', 0.15), ('attach', 'join', 0.30), ('put', 'hang', 0.33), ('go', 'sell', 0.11), ('communicate', 'pray', 0.08), ('give', 'steal', 0.04), ('add', 'build', 0.60), ('bring', 'restore', 0.38), ('comprehend', 'satisfy', 0.31), ('portray', 'decide', 0.13), ('organize', 'become', 0.26), ('give', 'know', 0.34), ('say', 'verify', 0.41), ('cooperate', 'join', 0.35), ('arrange', 'require', 0.25), ('borrow', 'want', 0.27), ('investigate', 'pursue', 0.50), ('ignore', 'explore', 0.16), ('bring', 'complain', 0.35), ('enter', 'owe', 0.06), ('portray', 'notify', 0.11), ('remind', 'sell', 0.12), ('absorb', 'possess', 0.09), ('join', 'acquire', 0.41), ('send', 'attend', 0.38), ('gather', 'attend', 0.44), ('absorb', 'withdraw', 0.10), ('attend', 'arrive', 0.54)]",
#  "[('bring', 'send', 0.85), ('absorb', 'learn', 0.23), ('acquire', 'find', 0.14), ('leave', 'appear', 0.12), ('create', 'destroy', 0.11), ('begin', 'go', 0.09), ('get', 'buy', 0.64), ('collect', 'save', 0.18), ('replace', 'restore', 0.46), ('join', 'add', 0.27), ('join', 'marry', 0.56), ('accept', 'deliver', 0.12), ('attach', 'join', 0.34), ('put', 'hang', 0.34), ('go', 'sell', 0.14), ('communicate', 'pray', 0.21), ('give', 'steal', 0.09), ('add', 'build', 0.46), ('bring', 'restore', 0.27), ('comprehend', 'satisfy', 0.15), ('portray', 'decide', 0.07), ('organize', 'become', 0.13), ('give', 'know', 0.13), ('say', 'verify', 0.17), ('cooperate', 'join', 0.36), ('arrange', 'require', 0.16), ('borrow', 'want', 0.21), ('investigate', 'pursue', 0.45), ('ignore', 'explore', 0.18), ('bring', 'complain', 0.25), ('enter', 'owe', 0.08), ('portray', 'notify', 0.15), ('remind', 'sell', 0.10), ('absorb', 'possess', 0.31), ('join', 'acquire', 0.45), ('send', 'attend', 0.43), ('gather', 'attend', 0.39), ('absorb', 'withdraw', 0.09), ('attend', 'arrive', 0.32)]",
#  "[('bring', 'send', 1.04), ('absorb', 'learn', 1.16), ('acquire', 'find', 0.73), ('leave', 'appear', 0.54), ('create', 'destroy', 0.46), ('begin', 'go', 0.36), ('get', 'buy', 0.61), ('collect', 'save', 0.54), ('replace', 'restore', 0.61), ('join', 'add', 0.73), ('join', 'marry', 0.73), ('accept', 'deliver', 0.54), ('attach', 'join', 0.46), ('put', 'hang', 0.39), ('go', 'sell', 0.26), ('communicate', 'pray', 0.35), ('give', 'steal', 0.46), ('add', 'build', 0.54), ('bring', 'restore', 0.53), ('comprehend', 'satisfy', 0.38), ('portray', 'decide', 0.31), ('organize', 'become', 0.39), ('give', 'know', 0.31), ('say', 'verify', 0.31), ('cooperate', 'join', 0.69), ('arrange', 'require', 0.31), ('borrow', 'want', 0.46), ('investigate', 'pursue', 0.62), ('ignore', 'explore', 0.31), ('bring', 'complain', 0.38), ('enter', 'owe', 0.31), ('portray', 'notify', 0.31), ('remind', 'sell', 0.38), ('absorb', 'possess', 0.62), ('join', 'acquire', 0.81), ('send', 'attend', 0.93), ('gather', 'attend', 0.85), ('absorb', 'withdraw', 0.77), ('attend', 'arrive', 0.73)]",
#  "[('bring', 'send', 0.19), ('absorb', 'learn', 0.17), ('acquire', 'find', 0.08), ('leave', 'appear', 0.05), ('create', 'destroy', 0.02), ('begin', 'go', 0.08), ('get', 'buy', 0.32), ('collect', 'save', 0.04), ('replace', 'restore', 0.18), ('join', 'add', 0.29), ('join', 'marry', 0.21), ('accept', 'deliver', 0.12), ('attach', 'join', 0.20), ('put', 'hang', 0.15), ('go', 'sell', 0.09), ('communicate', 'pray', 0.06), ('give', 'steal', 0.12), ('add', 'build', 0.14), ('bring', 'restore', 0.23), ('comprehend', 'satisfy', 0.12), ('portray', 'decide', 0.11), ('organize', 'become', 0.12), ('give', 'know', 0.29), ('say', 'verify', 0.05), ('cooperate', 'join', 0.17), ('arrange', 'require', 0.11), ('borrow', 'want', 0.27), ('investigate', 'pursue', 0.16), ('ignore', 'explore', 0.06), ('bring', 'complain', 0.16), ('enter', 'owe', 0.01), ('portray', 'notify', 0.14), ('remind', 'sell', 0.05), ('absorb', 'possess', 0.24), ('join', 'acquire', 0.22), ('send', 'attend', 0.16), ('gather', 'attend', 0.17), ('absorb', 'withdraw', 0.15), ('attend', 'arrive', 0.26)]",
#  "[('bring', 'send', 1.18), ('absorb', 'learn', 2.18), ('acquire', 'find', 0.52), ('leave', 'appear', 0.24), ('create', 'destroy', 1.78), ('begin', 'go', 0.12), ('get', 'buy', 2.32), ('collect', 'save', 1.45), ('replace', 'restore', 2.78), ('join', 'add', 1.15), ('join', 'marry', 0.85), ('accept', 'deliver', 0.78), ('attach', 'join', 1.65), ('put', 'hang', 1.75), ('go', 'sell', 0.42), ('communicate', 'pray', 0.65), ('give', 'steal', 0.35), ('add', 'build', 1.85), ('bring', 'restore', 2.58), ('comprehend', 'satisfy', 0.75), ('portray', 'decide', 0.35), ('organize', 'become', 0.18), ('give', 'know', 0.65), ('say', 'verify', 0.42), ('cooperate', 'join', 1.25), ('arrange', 'require', 0.58), ('borrow', 'want', 0.85), ('investigate', 'pursue', 1.48), ('ignore', 'explore', 1.25), ('bring', 'complain', 1.15), ('enter', 'owe', 0.25), ('portray', 'notify', 0.35), ('remind', 'sell', 0.15), ('absorb', 'possess', 0.52), ('join', 'acquire', 2.18), ('send', 'attend', 0.88), ('gather', 'attend', 1.65), ('absorb', 'withdraw', 0.45), ('attend', 'arrive', 0.65)]",
#  "[('bring', 'send', 2.50), ('absorb', 'learn', 1.15), ('acquire', 'find', 1.10), ('leave', 'appear', 0.50), ('create', 'destroy', 0.75), ('begin', 'go', 1.25), ('get', 'buy', 1.60), ('collect', 'save', 0.80), ('replace', 'restore', 1.20), ('join', 'add', 1.90), ('join', 'marry', 1.50), ('accept', 'deliver', 0.90), ('attach', 'join', 1.15), ('put', 'hang', 0.75), ('go', 'sell', 0.75), ('communicate', 'pray', 0.20), ('give', 'steal', 0.40), ('add', 'build', 1.00), ('bring', 'restore', 1.00), ('comprehend', 'satisfy', 0.35), ('portray', 'decide', 0.60), ('organize', 'become', 0.40), ('give', 'know', 0.75), ('say', 'verify', 0.90), ('cooperate', 'join', 1.75), ('arrange', 'require', 0.50), ('borrow', 'want', 0.90), ('investigate', 'pursue', 1.75), ('ignore', 'explore', 0.70), ('bring', 'complain', 0.75), ('enter', 'owe', 0.20), ('portray', 'notify', 0.30), ('remind', 'sell', 0.40), ('absorb', 'possess', 0.60), ('join', 'acquire', 1.90), ('send', 'attend', 1.00), ('gather', 'attend', 1.50), ('absorb', 'withdraw', 0.20), ('attend', 'arrive', 1.50)]",
#  "[('bring', 'send', 3.80), ('absorb', 'learn', 2.36), ('acquire', 'find', 1.80), ('leave', 'appear', 1.50), ('create', 'destroy', 2.08), ('begin', 'go', 1.64), ('get', 'buy', 1.55), ('collect', 'save', 1.50), ('replace', 'restore', 1.65), ('join', 'add', 3.55), ('join', 'marry', 2.38), ('accept', 'deliver', 1.66), ('attach', 'join', 2.36), ('put', 'hang', 2.52), ('go', 'sell', 1.63), ('communicate', 'pray', 1.21), ('give', 'steal', 1.20), ('add', 'build', 2.58), ('bring', 'restore', 2.36), ('comprehend', 'satisfy', 1.66), ('portray', 'decide', 1.15), ('organize', 'become', 1.36), ('give', 'know', 1.68), ('say', 'verify', 1.25), ('cooperate', 'join', 2.38), ('arrange', 'require', 1.58), ('borrow', 'want', 2.93), ('investigate', 'pursue', 3.20), ('ignore', 'explore', 2.30), ('bring', 'complain', 1.14), ('enter', 'owe', 1.40), ('portray', 'notify', 1.13), ('remind', 'sell', 1.60), ('absorb', 'possess', 2.28), ('join', 'acquire', 3.64), ('send', 'attend', 2.63), ('gather', 'attend', 2.60), ('absorb', 'withdraw', 1.87), ('attend', 'arrive', 1.74)]",
#  "[('bring', 'send', 1.58), ('absorb', 'learn', 1.98), ('acquire', 'find', 2.12), ('leave', 'appear', 0.42), ('create', 'destroy', 1.25), ('begin', 'go', 0.77), ('get', 'buy', 2.65), ('collect', 'save', 1.32), ('replace', 'restore', 1.15), ('join', 'add', 2.30), ('join', 'marry', 2.54), ('accept', 'deliver', 0.84), ('attach', 'join', 2.12), ('put', 'hang', 1.10), ('go', 'sell', 0.77), ('communicate', 'pray', 0.65), ('give', 'steal', 1.12), ('add', 'build', 2.12), ('bring', 'restore', 1.65), ('comprehend', 'satisfy', 0.58), ('portray', 'decide', 0.25), ('organize', 'become', 0.45), ('give', 'know', 1.20), ('say', 'verify', 0.10), ('cooperate', 'join', 1.98), ('arrange', 'require', 0.65), ('borrow', 'want', 1.25), ('investigate', 'pursue', 2.02), ('ignore', 'explore', 0.65), ('bring', 'complain', 0.75), ('enter', 'owe', 0.25), ('portray', 'notify', 0.15), ('remind', 'sell', 0.85), ('absorb', 'possess', 1.85), ('join', 'acquire', 2.30), ('send', 'attend', 1.58), ('gather', 'attend', 1.75), ('absorb', 'withdraw', 0.85), ('attend', 'arrive', 2.10)]",
#  "[('bring', 'send', 2.00), ('absorb', 'learn', 1.07), ('acquire', 'find', 1.79), ('leave', 'appear', 1.29), ('create', 'destroy', 1.79), ('begin', 'go', 1.50), ('get', 'buy', 1.86), ('collect', 'save', 1.21), ('replace', 'restore', 1.79), ('join', 'add', 1.79), ('join', 'marry', 1.21), ('accept', 'deliver', 1.07), ('attach', 'join', 1.64), ('put', 'hang', 1.36), ('go', 'sell', 1.29), ('communicate', 'pray', 1.07), ('give', 'steal', 1.07), ('add', 'build', 1.57), ('bring', 'restore', 1.64), ('comprehend', 'satisfy', 1.14), ('portray', 'decide', 1.00), ('organize', 'become', 1.29), ('give', 'know', 1.50), ('say', 'verify', 1.00), ('cooperate', 'join', 1.43), ('arrange', 'require', 1.14), ('borrow', 'want', 1.79), ('investigate', 'pursue', 1.57), ('ignore', 'explore', 1.00), ('bring', 'complain', 1.29), ('enter', 'owe', 1.29), ('portray', 'notify', 1.00), ('remind', 'sell', 1.00), ('absorb', 'possess', 1.36), ('join', 'acquire', 2.00), ('send', 'attend', 1.57), ('gather', 'attend', 1.64), ('absorb', 'withdraw', 1.07), ('attend', 'arrive', 1.36)]",
#  "[('bring', 'send', 0.81), ('absorb', 'learn', 0.31), ('acquire', 'find', 0.46), ('leave', 'appear', 0.20), ('create', 'destroy', 0.17), ('begin', 'go', 0.29), ('get', 'buy', 0.23), ('collect', 'save', 0.39), ('replace', 'restore', 0.42), ('join', 'add', 0.50), ('join', 'marry', 0.60), ('accept', 'deliver', 0.28), ('attach', 'join', 0.51), ('put', 'hang', 0.46), ('go', 'sell', 0.31), ('communicate', 'pray', 0.22), ('give', 'steal', 0.19), ('add', 'build', 0.45), ('bring', 'restore', 0.44), ('comprehend', 'satisfy', 0.39), ('portray', 'decide', 0.30), ('organize', 'become', 0.25), ('give', 'know', 0.29), ('say', 'verify', 0.25), ('cooperate', 'join', 0.50), ('arrange', 'require', 0.33), ('borrow', 'want', 0.34), ('investigate', 'pursue', 0.26), ('ignore', 'explore', 0.21), ('bring', 'complain', 0.24), ('enter', 'owe', 0.25), ('portray', 'notify', 0.33), ('remind', 'sell', 0.25), ('absorb', 'possess', 0.33), ('join', 'acquire', 0.52), ('send', 'attend', 0.51), ('gather', 'attend', 0.44), ('absorb', 'withdraw', 0.29), ('attend', 'arrive', 0.52)]",
#  "[('bring', 'send', 1.62), ('absorb', 'learn', 1.56), ('acquire', 'find', 1.72), ('leave', 'appear', 1.20), ('create', 'destroy', 1.84), ('begin', 'go', 1.26), ('get', 'buy', 1.15), ('collect', 'save', 1.38), ('replace', 'restore', 1.74), ('join', 'add', 1.66), ('join', 'marry', 1.30), ('accept', 'deliver', 1.38), ('attach', 'join', 1.46), ('put', 'hang', 1.64), ('go', 'sell', 1.30), ('communicate', 'pray', 1.15), ('give', 'steal', 1.08), ('add', 'build', 1.56), ('bring', 'restore', 1.68), ('comprehend', 'satisfy', 1.52), ('portray', 'decide', 1.42), ('organize', 'become', 1.18), ('give', 'know', 1.10), ('say', 'verify', 1.54), ('cooperate', 'join', 1.62), ('arrange', 'require', 1.48), ('borrow', 'want', 1.54), ('investigate', 'pursue', 1.58), ('ignore', 'explore', 1.64), ('bring', 'complain', 1.48), ('enter', 'owe', 1.20), ('portray', 'notify', 1.46), ('remind', 'sell', 1.32), ('absorb', 'possess', 1.60), ('join', 'acquire', 1.66), ('send', 'attend', 1.62), ('gather', 'attend', 1.42), ('absorb', 'withdraw', 1.52), ('attend', 'arrive', 1.56)]",
#  "[('bring', 'send', 0.33), ('absorb', 'learn', 0.31), ('acquire', 'find', 0.20), ('leave', 'appear', 0.21), ('create', 'destroy', 0.15), ('begin', 'go', 0.10), ('get', 'buy', 0.29), ('collect', 'save', 0.34), ('replace', 'restore', 0.34), ('join', 'add', 0.42), ('join', 'marry', 0.60), ('accept', 'deliver', 0.13), ('attach', 'join', 0.48), ('put', 'hang', 0.30), ('go', 'sell', 0.11), ('communicate', 'pray', 0.07), ('give', 'steal', 0.11), ('add', 'build', 0.46), ('bring', 'restore', 0.35), ('comprehend', 'satisfy', 0.23), ('portray', 'decide', 0.15), ('organize', 'become', 0.11), ('give', 'know', 0.29), ('say', 'verify', 0.09), ('cooperate', 'join', 0.48), ('arrange', 'require', 0.29), ('borrow', 'want', 0.18), ('investigate', 'pursue', 0.19), ('ignore', 'explore', 0.27), ('bring', 'complain', 0.16), ('enter', 'owe', 0.14), ('portray', 'notify', 0.23), ('remind', 'sell', 0.15), ('absorb', 'possess', 0.31), ('join', 'acquire', 0.49), ('send', 'attend', 0.17), ('gather', 'attend', 0.46), ('absorb', 'withdraw', 0.14), ('attend', 'arrive', 0.34)]",
#  "[('bring', 'send', 3.31), ('absorb', 'learn', 1.86), ('acquire', 'find', 2.65), ('leave', 'appear', 1.50), ('create', 'destroy', 2.42), ('begin', 'go', 1.71), ('get', 'buy', 3.00), ('collect', 'save', 2.00), ('replace', 'restore', 4.50), ('join', 'add', 4.14), ('join', 'marry', 2.12), ('accept', 'deliver', 1.86), ('attach', 'join', 4.14), ('put', 'hang', 2.00), ('go', 'sell', 1.57), ('communicate', 'pray', 1.71), ('give', 'steal', 1.43), ('add', 'build', 3.00), ('bring', 'restore', 4.00), ('comprehend', 'satisfy', 2.00), ('portray', 'decide', 1.57), ('organize', 'become', 1.43), ('give', 'know', 1.29), ('say', 'verify', 1.43), ('cooperate', 'join', 3.57), ('arrange', 'require', 1.29), ('borrow', 'want', 2.00), ('investigate', 'pursue', 3.00), ('ignore', 'explore', 1.57), ('bring', 'complain', 1.86), ('enter', 'owe', 1.14), ('portray', 'notify', 1.00), ('remind', 'sell', 1.00), ('absorb', 'possess', 1.14), ('join', 'acquire', 5.14), ('send', 'attend', 2.00), ('gather', 'attend', 2.00), ('absorb', 'withdraw', 1.14), ('attend', 'arrive', 2.00)]"]

# %%
# Count null values
count_null_values = df.isnull().sum()

# Show results
print("Null value counts per column:", count_null_values)
# Out:
# Null value counts per column: word1                   0
# word2                   0
# similarity_score_1      0
# similarity_score_2      0
# similarity_score_3      0
# similarity_score_4      0
# similarity_score_5      0
# similarity_score_6      0
# similarity_score_7      0
# similarity_score_8      0
# similarity_score_9      0
# similarity_score_10     0
# similarity_score_11     1
# similarity_score_12     1
# similarity_score_13     1
# similarity_score_14     1
# similarity_score_15    81
# dtype: int64

# %%
# Check for rows with at least one null value
rows_with_null = df[df.isnull().any(axis=1)]

# Show results
rows_with_null
# Out:
#           word1   word2  similarity_score_1  similarity_score_2  \
# 17        large    huge                8.00                8.50
# 18         hard   tough                7.00                8.00
# 19          new   fresh                8.00                8.50
# 20        sharp    dull                6.50                6.50
# 21        quick   rapid                8.00                9.00
# ..          ...     ...                 ...                 ...
# 678       agony   grief                4.77                4.50
# 679  assignment    task                5.52                4.50
# 956       leave  wander                1.97                2.13
# 957        keep    give                1.83                1.14
# 958        give   allow                1.40                1.52
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 17                 9.00                8.00                8.00
# 18                 8.00                7.50                7.50
# 19                 8.50                8.50                7.50
# 20                 7.50                6.50                7.00
# 21                 9.00                9.00                8.50
# ..                  ...                 ...                 ...
# 678                3.00                2.73                4.00
# 679                1.25                3.45                4.67
# 956                2.06                1.00                0.75
# 957                3.46                2.00                1.08
# 958                2.90                1.67                2.27
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 17                 8.00                9.00                9.50
# 18                 7.00                8.50                8.00
# 19                 6.00                8.50                7.50
# 20                 7.50                7.00                7.50
# 21                 8.00                9.50                9.50
# ..                  ...                 ...                 ...
# 678                3.75                4.25                5.43
# 679                4.25                5.50                7.65
# 956                1.00                1.50                1.49
# 957                1.67                2.50                2.33
# 958                5.69                0.25                2.41
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 17                 9.00                 8.50                 9.00
# 18                 8.75                 8.00                 8.00
# 19                 9.00                 8.50                 8.50
# 20                 8.50                 7.50                 7.50
# 21                 9.50                 9.00                 9.00
# ..                  ...                  ...                  ...
# 678                5.25                 3.50                 0.80
# 679                6.84                 7.00                 0.68
# 956                1.50                 4.03                 0.35
# 957                2.40                 2.05                 0.22
# 958                0.34                 0.58                  NaN
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 17                  9.00                 8.50                 8.00
# 18                  8.00                 8.00                 8.00
# 19                  8.00                 7.50                 8.00
# 20                  7.50                 7.50                 6.50
# 21                  9.00                 8.50                 8.00
# ..                   ...                  ...                  ...
# 678                 3.33                 0.75                 5.00
# 679                 3.33                 0.90                 5.38
# 956                 2.75                 0.52                 0.36
# 957                 2.07                 0.19                 0.58
# 958                  NaN                  NaN                  NaN
#
#      similarity_score_15
# 17                   NaN
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# ..                   ...
# 678                  NaN
# 679                  NaN
# 956                  NaN
# 957                  NaN
# 958                  NaN
#
# [81 rows x 17 columns]

# %%
# Custom prompt
custom_prompt = ("Rate the semantic similarity of the word pair [('give', 'allow')] on a scale from 0 to 10, "
                 "where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. "
                 "Use two decimals. The response should strictly adhere to the structure: "
                 "[('word1', 'word2', <score>)]. "
                 "Do not provide additional explanations or context. "
                 "An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)]")

# for _ in range(4):
#     messages = [{"role": "user", "content": custom_prompt}]
#     completion = client.chat.completions.create(
#         model=model,
#         messages=messages,
#         n=1)

    # # Show results
    # print(completion.choices[0].message.content)
# Out:
# [('give', 'allow', 1.21)]
# [('give', 'allow', 5.00)]
# [('give', 'allow', 0.75)]
# [('give', 'allow', 8.50)]

# %%
# Manually fix inconsistencies
df.loc[(df['word1'] == 'give') & (df['word2'] == 'allow'), 'similarity_score_11'] = 1.21

# Manually fix inconsistencies
df.loc[(df['word1'] == 'give') & (df['word2'] == 'allow'), 'similarity_score_12'] = 5.00

# Manually fix inconsistencies
df.loc[(df['word1'] == 'give') & (df['word2'] == 'allow'), 'similarity_score_13'] = 0.75

# Manually fix inconsistencies
df.loc[(df['word1'] == 'give') & (df['word2'] == 'allow'), 'similarity_score_14'] = 8.50

# Show results
df.loc[(df['word1'] == 'give') & (df['word2'] == 'allow')]
# Out:
#     word1  word2  similarity_score_1  similarity_score_2  similarity_score_3  \
# 958  give  allow                 1.4                1.52                 2.9
#
#      similarity_score_4  similarity_score_5  similarity_score_6  \
# 958                1.67                2.27                5.69
#
#      similarity_score_7  similarity_score_8  similarity_score_9  \
# 958                0.25                2.41                0.34
#
#      similarity_score_10  similarity_score_11  similarity_score_12  \
# 958                 0.58                 1.21                  5.0
#
#      similarity_score_13  similarity_score_14  similarity_score_15
# 958                 0.75                  8.5                  NaN

# %%
# Check for rows with at least one null value
rows_with_null = df[df.isnull().any(axis=1)]

# Show results
rows_with_null
# Out:
#           word1   word2  similarity_score_1  similarity_score_2  \
# 17        large    huge                8.00                8.50
# 18         hard   tough                7.00                8.00
# 19          new   fresh                8.00                8.50
# 20        sharp    dull                6.50                6.50
# 21        quick   rapid                8.00                9.00
# ..          ...     ...                 ...                 ...
# 678       agony   grief                4.77                4.50
# 679  assignment    task                5.52                4.50
# 956       leave  wander                1.97                2.13
# 957        keep    give                1.83                1.14
# 958        give   allow                1.40                1.52
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 17                 9.00                8.00                8.00
# 18                 8.00                7.50                7.50
# 19                 8.50                8.50                7.50
# 20                 7.50                6.50                7.00
# 21                 9.00                9.00                8.50
# ..                  ...                 ...                 ...
# 678                3.00                2.73                4.00
# 679                1.25                3.45                4.67
# 956                2.06                1.00                0.75
# 957                3.46                2.00                1.08
# 958                2.90                1.67                2.27
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 17                 8.00                9.00                9.50
# 18                 7.00                8.50                8.00
# 19                 6.00                8.50                7.50
# 20                 7.50                7.00                7.50
# 21                 8.00                9.50                9.50
# ..                  ...                 ...                 ...
# 678                3.75                4.25                5.43
# 679                4.25                5.50                7.65
# 956                1.00                1.50                1.49
# 957                1.67                2.50                2.33
# 958                5.69                0.25                2.41
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 17                 9.00                 8.50                 9.00
# 18                 8.75                 8.00                 8.00
# 19                 9.00                 8.50                 8.50
# 20                 8.50                 7.50                 7.50
# 21                 9.50                 9.00                 9.00
# ..                  ...                  ...                  ...
# 678                5.25                 3.50                 0.80
# 679                6.84                 7.00                 0.68
# 956                1.50                 4.03                 0.35
# 957                2.40                 2.05                 0.22
# 958                0.34                 0.58                 1.21
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 17                  9.00                 8.50                 8.00
# 18                  8.00                 8.00                 8.00
# 19                  8.00                 7.50                 8.00
# 20                  7.50                 7.50                 6.50
# 21                  9.00                 8.50                 8.00
# ..                   ...                  ...                  ...
# 678                 3.33                 0.75                 5.00
# 679                 3.33                 0.90                 5.38
# 956                 2.75                 0.52                 0.36
# 957                 2.07                 0.19                 0.58
# 958                 5.00                 0.75                 8.50
#
#      similarity_score_15
# 17                   NaN
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# ..                   ...
# 678                  NaN
# 679                  NaN
# 956                  NaN
# 957                  NaN
# 958                  NaN
#
# [81 rows x 17 columns]

# %%
# Extract missing word pairs
missing_word_pair_list = list(zip(rows_with_null['word1'], rows_with_null['word2']))

# Show results
missing_word_pair_list
# Out:
# [('large', 'huge'),
#  ('hard', 'tough'),
#  ('new', 'fresh'),
#  ('sharp', 'dull'),
#  ('quick', 'rapid'),
#  ('dumb', 'foolish'),
#  ('wonderful', 'terrific'),
#  ('strange', 'odd'),
#  ('happy', 'angry'),
#  ('narrow', 'broad'),
#  ('simple', 'easy'),
#  ('old', 'fresh'),
#  ('apparent', 'obvious'),
#  ('inexpensive', 'cheap'),
#  ('nice', 'generous'),
#  ('weird', 'normal'),
#  ('weird', 'odd'),
#  ('bad', 'immoral'),
#  ('sad', 'funny'),
#  ('wonderful', 'great'),
#  ('guilty', 'ashamed'),
#  ('beautiful', 'wonderful'),
#  ('confident', 'sure'),
#  ('school', 'grade'),
#  ('parent', 'adult'),
#  ('bar', 'jail'),
#  ('car', 'highway'),
#  ('dictionary', 'definition'),
#  ('door', 'cellar'),
#  ('army', 'legion'),
#  ('metal', 'aluminum'),
#  ('chair', 'bench'),
#  ('cloud', 'fog'),
#  ('boy', 'son'),
#  ('water', 'ice'),
#  ('bed', 'blanket'),
#  ('attorney', 'lawyer'),
#  ('area', 'zone'),
#  ('business', 'company'),
#  ('clothes', 'fabric'),
#  ('sweater', 'jacket'),
#  ('money', 'capital'),
#  ('hand', 'foot'),
#  ('apartment', 'hotel'),
#  ('cup', 'cone'),
#  ('horse', 'ox'),
#  ('throat', 'nose'),
#  ('bone', 'teeth'),
#  ('bone', 'elbow'),
#  ('bacon', 'bean'),
#  ('cup', 'jar'),
#  ('proof', 'fact'),
#  ('appointment', 'engagement'),
#  ('birthday', 'year'),
#  ('word', 'clue'),
#  ('author', 'creator'),
#  ('atom', 'carbon'),
#  ('archbishop', 'bishop'),
#  ('letter', 'paragraph'),
#  ('page', 'paragraph'),
#  ('steeple', 'chapel'),
#  ('muscle', 'bone'),
#  ('muscle', 'tongue'),
#  ('boy', 'soldier'),
#  ('belly', 'abdomen'),
#  ('guy', 'girl'),
#  ('bed', 'chair'),
#  ('clothes', 'jacket'),
#  ('gun', 'knife'),
#  ('tin', 'metal'),
#  ('bottle', 'container'),
#  ('hen', 'turkey'),
#  ('meat', 'bread'),
#  ('arm', 'bone'),
#  ('neck', 'spine'),
#  ('apple', 'lemon'),
#  ('agony', 'grief'),
#  ('assignment', 'task'),
#  ('leave', 'wander'),
#  ('keep', 'give'),
#  ('give', 'allow')]

# %%
# Format message
formatted_prompt = format_prompt(missing_word_pair_list, prompt)
messages = [{"role": "user", "content": formatted_prompt}]

# Call the API
# completion = client.chat.completions.create(
#     model=model,
#     messages=messages,
#     n=1)

# Store the response content
missing_word_pairs_response = [completion.choices[0].message.content]

# %%
# Extract data with regular expressions into dictionary
missing_word_pairs_dict = process_responses(missing_word_pairs_response)

# Show results
missing_word_pairs_dict
# Out:
# {('large', 'huge'): [8.0],
#  ('hard', 'tough'): [9.5],
#  ('new', 'fresh'): [6.75],
#  ('sharp', 'dull'): [6.75],
#  ('quick', 'rapid'): [8.5],
#  ('dumb', 'foolish'): [7.5],
#  ('wonderful', 'terrific'): [9.0],
#  ('strange', 'odd'): [8.5],
#  ('happy', 'angry'): [5.25],
#  ('narrow', 'broad'): [7.75],
#  ('simple', 'easy'): [8.0],
#  ('old', 'fresh'): [4.5],
#  ('apparent', 'obvious'): [9.5],
#  ('inexpensive', 'cheap'): [8.75],
#  ('nice', 'generous'): [6.0],
#  ('weird', 'normal'): [3.5],
#  ('weird', 'odd'): [8.75],
#  ('bad', 'immoral'): [7.0],
#  ('sad', 'funny'): [2.5],
#  ('wonderful', 'great'): [8.0],
#  ('guilty', 'ashamed'): [5.5],
#  ('beautiful', 'wonderful'): [8.25],
#  ('confident', 'sure'): [9.0],
#  ('school', 'grade'): [2.5],
#  ('parent', 'adult'): [5.5],
#  ('bar', 'jail'): [6.0],
#  ('car', 'highway'): [4.0],
#  ('dictionary', 'definition'): [9.0],
#  ('door', 'cellar'): [4.5],
#  ('army', 'legion'): [7.0],
#  ('metal', 'aluminum'): [8.5],
#  ('chair', 'bench'): [7.5],
#  ('cloud', 'fog'): [6.5],
#  ('boy', 'son'): [5.0],
#  ('water', 'ice'): [5.0],
#  ('bed', 'blanket'): [4.25],
#  ('attorney', 'lawyer'): [9.5],
#  ('area', 'zone'): [8.5],
#  ('business', 'company'): [8.0],
#  ('clothes', 'fabric'): [7.0],
#  ('sweater', 'jacket'): [8.5],
#  ('money', 'capital'): [6.25],
#  ('hand', 'foot'): [3.5],
#  ('apartment', 'hotel'): [7.5],
#  ('cup', 'cone'): [3.5],
#  ('horse', 'ox'): [5.5],
#  ('throat', 'nose'): [4.5],
#  ('bone', 'teeth'): [6.5],
#  ('bone', 'elbow'): [5.0],
#  ('bacon', 'bean'): [3.0],
#  ('cup', 'jar'): [4.0],
#  ('proof', 'fact'): [8.0],
#  ('appointment', 'engagement'): [7.5],
#  ('birthday', 'year'): [1.5],
#  ('word', 'clue'): [6.0],
#  ('author', 'creator'): [9.0],
#  ('atom', 'carbon'): [7.0],
#  ('archbishop', 'bishop'): [9.0],
#  ('letter', 'paragraph'): [2.5],
#  ('page', 'paragraph'): [3.5],
#  ('steeple', 'chapel'): [6.75],
#  ('muscle', 'bone'): [5.75],
#  ('muscle', 'tongue'): [4.5],
#  ('boy', 'soldier'): [5.5],
#  ('belly', 'abdomen'): [8.5],
#  ('guy', 'girl'): [6.5],
#  ('bed', 'chair'): [4.5],
#  ('clothes', 'jacket'): [8.0],
#  ('gun', 'knife'): [6.5],
#  ('tin', 'metal'): [8.0],
#  ('bottle', 'container'): [7.0],
#  ('hen', 'turkey'): [4.0],
#  ('meat', 'bread'): [6.25],
#  ('arm', 'bone'): [6.5],
#  ('neck', 'spine'): [7.0],
#  ('apple', 'lemon'): [4.0],
#  ('agony', 'grief'): [7.0],
#  ('assignment', 'task'): [8.0],
#  ('leave', 'wander'): [7.0],
#  ('keep', 'give'): [6.0],
#  ('give', 'allow'): [6.75]}

# %%
# Iterate over DataFrame and replace missing values
for index, row in df.iterrows():
    word_pair = (row['word1'], row['word2'])

    # Check if current value is NaN
    if pd.isna(row['similarity_score_15']):
        if word_pair in missing_word_pairs_dict:

            # Extract first element from list
            df.at[index, 'similarity_score_15'] = missing_word_pairs_dict[word_pair][0]

# Check if are any NaN values left
print(df[df['similarity_score_15'].isna()])
# Out:
# Empty DataFrame
# Columns: [word1, word2, similarity_score_1, similarity_score_2, similarity_score_3, similarity_score_4, similarity_score_5, similarity_score_6, similarity_score_7, similarity_score_8, similarity_score_9, similarity_score_10, similarity_score_11, similarity_score_12, similarity_score_13, similarity_score_14, similarity_score_15]
# Index: []

# %%
# Filter the DataFrame based on pairs
filtered_df = df[df.apply(lambda row: (row['word1'], row['word2']) in missing_word_pair_list, axis=1)]

# Select column
result = filtered_df[['word1', 'word2', 'similarity_score_15']]

# Show results
print(result)
# Out:
#           word1   word2  similarity_score_15
# 17        large    huge                 8.00
# 18         hard   tough                 9.50
# 19          new   fresh                 6.75
# 20        sharp    dull                 6.75
# 21        quick   rapid                 8.50
# ..          ...     ...                  ...
# 678       agony   grief                 7.00
# 679  assignment    task                 8.00
# 956       leave  wander                 7.00
# 957        keep    give                 6.00
# 958        give   allow                 6.75
#
# [81 rows x 3 columns]

# %%
# Check for rows with at least one null value
rows_with_null = df[df.isnull().any(axis=1)]

# Show results
rows_with_null
# Out:
# Empty DataFrame
# Columns: [word1, word2, similarity_score_1, similarity_score_2, similarity_score_3, similarity_score_4, similarity_score_5, similarity_score_6, similarity_score_7, similarity_score_8, similarity_score_9, similarity_score_10, similarity_score_11, similarity_score_12, similarity_score_13, similarity_score_14, similarity_score_15]
# Index: []

# %%
# Show results
df
# Out:
#       word1        word2  similarity_score_1  similarity_score_2  \
# 0     smart  intelligent                8.50                7.00
# 1      hard    difficult                7.50                6.00
# 2     happy     cheerful                6.75                8.50
# 3      hard         easy                2.00                2.00
# 4      fast        rapid                8.50                9.00
# ..      ...          ...                 ...                 ...
# 993    join      acquire                2.33                0.60
# 994    send       attend                1.51                0.35
# 995  gather       attend                2.00                0.48
# 996  absorb     withdraw                1.52                0.17
# 997  attend       arrive                1.75                0.53
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                  8.50                8.50                8.50
# 1                  8.00                8.00                7.00
# 2                  9.00                8.00                8.50
# 3                  3.00                2.00                4.00
# 4                  9.50                9.50                9.00
# ..                  ...                 ...                 ...
# 993                0.41                0.45                0.81
# 994                0.38                0.43                0.93
# 995                0.44                0.39                0.85
# 996                0.10                0.09                0.77
# 997                0.54                0.32                0.73
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                  8.50                9.50                 9.5
# 1                  6.50                7.00                 8.5
# 2                  7.50                8.50                 7.5
# 3                  2.50                4.00                 1.0
# 4                  9.00                9.50                 9.5
# ..                  ...                 ...                 ...
# 993                0.22                2.18                 1.9
# 994                0.16                0.88                 1.0
# 995                0.17                1.65                 1.5
# 996                0.15                0.45                 0.2
# 997                0.26                0.65                 1.5
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                  9.00                 8.75                 9.50
# 1                  8.50                 8.25                 8.00
# 2                  8.00                 8.50                 8.50
# 3                  1.50                 1.50                 4.00
# 4                  9.50                 9.00                 9.50
# ..                  ...                  ...                  ...
# 993                3.64                 2.30                 2.00
# 994                2.63                 1.58                 1.57
# 995                2.60                 1.75                 1.64
# 996                1.87                 0.85                 1.07
# 997                1.74                 2.10                 1.36
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                   8.50                 9.50                 9.50
# 1                   8.60                 8.00                 7.50
# 2                   8.70                 7.00                 8.50
# 3                   2.00                 2.00                 3.00
# 4                   9.00                 9.50                 8.00
# ..                   ...                  ...                  ...
# 993                 0.52                 1.66                 0.49
# 994                 0.51                 1.62                 0.17
# 995                 0.44                 1.42                 0.46
# 996                 0.29                 1.52                 0.14
# 997                 0.52                 1.56                 0.34
#
#      similarity_score_15
# 0                   8.50
# 1                   7.50
# 2                   7.50
# 3                   1.50
# 4                   9.00
# ..                   ...
# 993                 5.14
# 994                 2.00
# 995                 2.00
# 996                 1.14
# 997                 2.00
#
# [998 rows x 17 columns]

# %%
# Define file_path
file_path = '../../../data/prompt/en/gpt-3.5-turbo-0125/f2.csv'

# Check if file already exists
if not os.path.exists(file_path):
    df.to_csv(file_path, index=False)
    print("File saved successfully.")
else:
    print("File already exists. Dataframe was not saved to prevent overwriting.")
# Out:
# File saved successfully.
