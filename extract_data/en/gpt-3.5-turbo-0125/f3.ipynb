# %% [markdown]
# ### **0. Set-up**

# %%
# Import libraries and utils
# %run '../../utils.ipynb'

# %%
#  Get api key
load_dotenv()
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

# Set client
client = OpenAI()

# %%
# Load dataframe
en_simlex = pd.read_csv("../../../data/dataset/en-simlex-999.txt", delimiter='\t')

# Remove first three word pairs
en_simlex = en_simlex.iloc[3:]

# Select subset
# en_simlex = en_simlex.head(160)

# Convert to tuple
tuples_list = list(zip(en_simlex['word1'], en_simlex['word2']))

# %%
# Show results
en_simlex
# Out:
#       word1     word2 POS  SimLex999  conc(w1)  conc(w2)  concQ  Assoc(USF)  \
# 3     happy  cheerful   A       9.55      2.56      2.34      1        5.85
# 4      hard      easy   A       0.95      3.76      2.07      2        5.82
# 5      fast     rapid   A       8.75      3.32      3.07      2        5.66
# 6     happy      glad   A       9.17      2.56      2.36      1        5.49
# 7     short      long   A       1.23      3.61      3.18      2        5.36
# ..      ...       ...  ..        ...       ...       ...    ...         ...
# 994    join   acquire   V       2.85      2.86      2.93      2        0.00
# 995    send    attend   V       1.67      2.70      3.17      2        0.00
# 996  gather    attend   V       4.80      2.75      3.17      2        0.00
# 997  absorb  withdraw   V       2.97      3.11      3.04      2        0.00
# 998  attend    arrive   V       6.08      3.17      3.22      2        0.00
#
#      SimAssoc333  SD(SimLex)
# 3              1        2.18
# 4              1        0.93
# 5              1        1.68
# 6              1        1.59
# 7              1        1.58
# ..           ...         ...
# 994            0        0.99
# 995            0        1.44
# 996            0        1.97
# 997            0        1.75
# 998            0        1.18
#
# [996 rows x 10 columns]

# %% [markdown]
# ### **1. Define and Evaluate Parameters**

# %%
# Define the prompt
prompt = ("Rate the semantic similarity of each word pair on a scale from 0 to 10, "
          "where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. "
          "Use two decimals. The response should strictly adhere to the structure: "
          "[('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. "
          "Do not provide additional explanations or context. "
          "Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)].")

# %%
# Define model
model = "gpt-3.5-turbo-0125"

# Set sample size
sample_size = 15

# Delay between individual API calls
delay = 15.0

# Define number of sublists
n_sublists = 25

# %%
# Split the list
chunks = split_into_n_lists(tuples_list, n_sublists)

# Count the number of lists
print(len(chunks))
# Out:
# 25

# %%
# Print the prompts for each chunk
print_prompts(chunks, prompt)
# Out:
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('happy', 'cheerful'), ('hard', 'easy'), ('fast', 'rapid'), ('happy', 'glad'), ('short', 'long'), ('stupid', 'dumb'), ('weird', 'strange'), ('wide', 'narrow'), ('bad', 'awful'), ('easy', 'difficult'), ('bad', 'terrible'), ('hard', 'simple'), ('smart', 'dumb'), ('insane', 'crazy'), ('happy', 'mad'), ('large', 'huge'), ('hard', 'tough'), ('new', 'fresh'), ('sharp', 'dull'), ('quick', 'rapid'), ('dumb', 'foolish'), ('wonderful', 'terrific'), ('strange', 'odd'), ('happy', 'angry'), ('narrow', 'broad'), ('simple', 'easy'), ('old', 'fresh'), ('apparent', 'obvious'), ('inexpensive', 'cheap'), ('nice', 'generous'), ('weird', 'normal'), ('weird', 'odd'), ('bad', 'immoral'), ('sad', 'funny'), ('wonderful', 'great'), ('guilty', 'ashamed'), ('beautiful', 'wonderful'), ('confident', 'sure'), ('dumb', 'dense'), ('large', 'big')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('nice', 'cruel'), ('impatient', 'anxious'), ('big', 'broad'), ('strong', 'proud'), ('unnecessary', 'necessary'), ('restless', 'young'), ('dumb', 'intelligent'), ('bad', 'great'), ('difficult', 'simple'), ('necessary', 'important'), ('bad', 'terrific'), ('mad', 'glad'), ('honest', 'guilty'), ('easy', 'tough'), ('easy', 'flexible'), ('certain', 'sure'), ('essential', 'necessary'), ('different', 'normal'), ('sly', 'clever'), ('crucial', 'important'), ('harsh', 'cruel'), ('childish', 'foolish'), ('scarce', 'rare'), ('friendly', 'generous'), ('fragile', 'frigid'), ('long', 'narrow'), ('big', 'heavy'), ('rough', 'frigid'), ('bizarre', 'strange'), ('illegal', 'immoral'), ('bad', 'guilty'), ('modern', 'ancient'), ('new', 'ancient'), ('dull', 'funny'), ('happy', 'young'), ('easy', 'big'), ('great', 'awful'), ('tiny', 'huge'), ('polite', 'proper'), ('modest', 'ashamed')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('exotic', 'rare'), ('dumb', 'clever'), ('delightful', 'wonderful'), ('noticeable', 'obvious'), ('afraid', 'anxious'), ('formal', 'proper'), ('dreary', 'dull'), ('delightful', 'cheerful'), ('unhappy', 'mad'), ('sad', 'terrible'), ('sick', 'crazy'), ('violent', 'angry'), ('laden', 'heavy'), ('dirty', 'cheap'), ('elastic', 'flexible'), ('hard', 'dense'), ('recent', 'new'), ('bold', 'proud'), ('sly', 'strange'), ('strange', 'sly'), ('dumb', 'rare'), ('sly', 'tough'), ('terrific', 'mad'), ('modest', 'flexible'), ('fresh', 'wide'), ('huge', 'dumb'), ('large', 'flexible'), ('dirty', 'narrow'), ('wife', 'husband'), ('book', 'text'), ('groom', 'bride'), ('night', 'day'), ('south', 'north'), ('plane', 'airport'), ('uncle', 'aunt'), ('horse', 'mare'), ('bottom', 'top'), ('friend', 'buddy'), ('student', 'pupil'), ('world', 'globe')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('leg', 'arm'), ('plane', 'jet'), ('woman', 'man'), ('horse', 'colt'), ('actress', 'actor'), ('teacher', 'instructor'), ('movie', 'film'), ('bird', 'hawk'), ('word', 'dictionary'), ('money', 'salary'), ('dog', 'cat'), ('area', 'region'), ('navy', 'army'), ('book', 'literature'), ('clothes', 'closet'), ('sunset', 'sunrise'), ('child', 'adult'), ('cow', 'cattle'), ('book', 'story'), ('winter', 'summer'), ('taxi', 'cab'), ('tree', 'maple'), ('bed', 'bedroom'), ('roof', 'ceiling'), ('disease', 'infection'), ('arm', 'shoulder'), ('sheep', 'lamb'), ('lady', 'gentleman'), ('boat', 'anchor'), ('priest', 'monk'), ('toe', 'finger'), ('river', 'stream'), ('anger', 'fury'), ('date', 'calendar'), ('sea', 'ocean'), ('second', 'minute'), ('hand', 'thumb'), ('wood', 'log'), ('mud', 'dirt'), ('hallway', 'corridor')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('way', 'manner'), ('mouse', 'cat'), ('cop', 'sheriff'), ('death', 'burial'), ('music', 'melody'), ('beer', 'alcohol'), ('mouth', 'lip'), ('storm', 'hurricane'), ('tax', 'income'), ('flower', 'violet'), ('paper', 'cardboard'), ('floor', 'ceiling'), ('beach', 'seashore'), ('rod', 'curtain'), ('hound', 'fox'), ('street', 'alley'), ('boat', 'deck'), ('car', 'horn'), ('friend', 'guest'), ('employer', 'employee'), ('hand', 'wrist'), ('ball', 'cannon'), ('alcohol', 'brandy'), ('victory', 'triumph'), ('telephone', 'booth'), ('door', 'doorway'), ('motel', 'inn'), ('clothes', 'cloth'), ('steak', 'meat'), ('nail', 'thumb'), ('band', 'orchestra'), ('book', 'bible'), ('business', 'industry'), ('winter', 'season'), ('decade', 'century'), ('alcohol', 'gin'), ('hat', 'coat'), ('window', 'door'), ('arm', 'wrist'), ('house', 'apartment')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('glass', 'crystal'), ('wine', 'brandy'), ('creator', 'maker'), ('dinner', 'breakfast'), ('arm', 'muscle'), ('bubble', 'suds'), ('bread', 'flour'), ('death', 'tragedy'), ('absence', 'presence'), ('gun', 'cannon'), ('grass', 'blade'), ('ball', 'basket'), ('hose', 'garden'), ('boy', 'kid'), ('church', 'choir'), ('clothes', 'drawer'), ('tower', 'bell'), ('father', 'parent'), ('school', 'grade'), ('parent', 'adult'), ('bar', 'jail'), ('car', 'highway'), ('dictionary', 'definition'), ('door', 'cellar'), ('army', 'legion'), ('metal', 'aluminum'), ('chair', 'bench'), ('cloud', 'fog'), ('boy', 'son'), ('water', 'ice'), ('bed', 'blanket'), ('attorney', 'lawyer'), ('area', 'zone'), ('business', 'company'), ('clothes', 'fabric'), ('sweater', 'jacket'), ('money', 'capital'), ('hand', 'foot'), ('alcohol', 'cocktail'), ('yard', 'inch')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('molecule', 'atom'), ('lens', 'camera'), ('meal', 'dinner'), ('eye', 'tear'), ('god', 'devil'), ('loop', 'belt'), ('rat', 'mouse'), ('motor', 'engine'), ('car', 'cab'), ('cat', 'lion'), ('size', 'magnitude'), ('reality', 'fantasy'), ('door', 'gate'), ('cat', 'pet'), ('tin', 'aluminum'), ('bone', 'jaw'), ('cereal', 'wheat'), ('house', 'key'), ('blood', 'flesh'), ('door', 'corridor'), ('god', 'spirit'), ('capability', 'competence'), ('abundance', 'plenty'), ('sofa', 'chair'), ('wall', 'brick'), ('horn', 'drum'), ('organ', 'liver'), ('strength', 'might'), ('phrase', 'word'), ('band', 'parade'), ('stomach', 'waist'), ('cloud', 'storm'), ('joy', 'pride'), ('noise', 'rattle'), ('rain', 'mist'), ('beer', 'beverage'), ('man', 'uncle'), ('apple', 'juice'), ('intelligence', 'logic'), ('communication', 'language')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('mink', 'fur'), ('mob', 'crowd'), ('shore', 'coast'), ('wire', 'cord'), ('bird', 'turkey'), ('bed', 'crib'), ('competence', 'ability'), ('cloud', 'haze'), ('supper', 'meal'), ('bar', 'cage'), ('water', 'salt'), ('sense', 'intuition'), ('situation', 'condition'), ('crime', 'theft'), ('style', 'fashion'), ('boundary', 'border'), ('arm', 'body'), ('boat', 'car'), ('sandwich', 'lunch'), ('bride', 'princess'), ('heroine', 'hero'), ('car', 'gauge'), ('insect', 'bee'), ('crib', 'cradle'), ('animal', 'person'), ('marijuana', 'herb'), ('bed', 'hospital'), ('cheek', 'tongue'), ('disc', 'computer'), ('curve', 'angle'), ('grass', 'moss'), ('school', 'law'), ('foot', 'head'), ('mother', 'guardian'), ('orthodontist', 'dentist'), ('alcohol', 'whiskey'), ('mouth', 'tooth'), ('breakfast', 'bacon'), ('bathroom', 'bedroom'), ('plate', 'bowl')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('meat', 'bacon'), ('air', 'helium'), ('worker', 'employer'), ('body', 'chest'), ('son', 'father'), ('heart', 'surgery'), ('woman', 'secretary'), ('man', 'father'), ('beach', 'island'), ('story', 'topic'), ('game', 'fun'), ('weekend', 'week'), ('couple', 'pair'), ('woman', 'wife'), ('sheep', 'cattle'), ('purse', 'bag'), ('ceiling', 'cathedral'), ('bean', 'coffee'), ('wood', 'paper'), ('top', 'side'), ('crime', 'fraud'), ('pain', 'harm'), ('lover', 'companion'), ('evening', 'dusk'), ('father', 'daughter'), ('wine', 'liquor'), ('cow', 'goat'), ('belief', 'opinion'), ('reality', 'illusion'), ('pact', 'agreement'), ('wealth', 'poverty'), ('accident', 'emergency'), ('battle', 'conquest'), ('friend', 'teacher'), ('illness', 'infection'), ('game', 'trick'), ('brother', 'son'), ('aunt', 'nephew'), ('worker', 'mechanic'), ('doctor', 'orthodontist')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('oak', 'maple'), ('bee', 'queen'), ('car', 'bicycle'), ('goal', 'quest'), ('august', 'month'), ('army', 'squad'), ('cloud', 'weather'), ('physician', 'doctor'), ('canyon', 'valley'), ('river', 'valley'), ('sun', 'sky'), ('target', 'arrow'), ('chocolate', 'pie'), ('circumstance', 'situation'), ('opinion', 'choice'), ('rhythm', 'melody'), ('gut', 'nerve'), ('day', 'dawn'), ('cattle', 'beef'), ('doctor', 'professor'), ('arm', 'vein'), ('room', 'bath'), ('corporation', 'business'), ('fun', 'football'), ('hill', 'cliff'), ('bone', 'ankle'), ('apple', 'candy'), ('helper', 'maid'), ('leader', 'manager'), ('lemon', 'tea'), ('bee', 'ant'), ('basketball', 'baseball'), ('rice', 'bean'), ('bed', 'furniture'), ('emotion', 'passion'), ('anarchy', 'chaos'), ('crime', 'violation'), ('machine', 'engine'), ('beach', 'sea'), ('alley', 'bowl')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('jar', 'bottle'), ('strength', 'capability'), ('seed', 'mustard'), ('guitar', 'drum'), ('opinion', 'idea'), ('north', 'west'), ('diet', 'salad'), ('mother', 'wife'), ('dad', 'mother'), ('captain', 'sailor'), ('meter', 'yard'), ('beer', 'champagne'), ('motor', 'boat'), ('card', 'bridge'), ('science', 'psychology'), ('sinner', 'saint'), ('destruction', 'construction'), ('crowd', 'bunch'), ('beach', 'reef'), ('man', 'child'), ('bread', 'cheese'), ('champion', 'winner'), ('celebration', 'ceremony'), ('menu', 'order'), ('king', 'princess'), ('wealth', 'prestige'), ('endurance', 'strength'), ('danger', 'threat'), ('god', 'priest'), ('men', 'fraternity'), ('buddy', 'companion'), ('teacher', 'helper'), ('body', 'stomach'), ('tongue', 'throat'), ('house', 'carpet'), ('intelligence', 'skill'), ('journey', 'conquest'), ('god', 'prey'), ('brother', 'soul'), ('adversary', 'opponent')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('death', 'catastrophe'), ('monster', 'demon'), ('day', 'morning'), ('man', 'victor'), ('friend', 'guy'), ('song', 'story'), ('ray', 'sunshine'), ('guy', 'stud'), ('chicken', 'rice'), ('box', 'elevator'), ('butter', 'potato'), ('apartment', 'furniture'), ('lake', 'swamp'), ('salad', 'vinegar'), ('flower', 'bulb'), ('cloud', 'mist'), ('driver', 'pilot'), ('sugar', 'honey'), ('body', 'shoulder'), ('idea', 'image'), ('father', 'brother'), ('moon', 'planet'), ('ball', 'costume'), ('rail', 'fence'), ('room', 'bed'), ('flower', 'bush'), ('bone', 'knee'), ('arm', 'knee'), ('bottom', 'side'), ('vessel', 'vein'), ('cat', 'rabbit'), ('meat', 'sandwich'), ('belief', 'concept'), ('intelligence', 'insight'), ('attention', 'interest'), ('attitude', 'confidence'), ('right', 'justice'), ('argument', 'agreement'), ('depth', 'magnitude'), ('medium', 'news')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('winner', 'candidate'), ('birthday', 'date'), ('fee', 'payment'), ('bible', 'hymn'), ('exit', 'doorway'), ('man', 'sentry'), ('aisle', 'hall'), ('whiskey', 'gin'), ('blood', 'marrow'), ('oil', 'mink'), ('floor', 'deck'), ('roof', 'floor'), ('door', 'floor'), ('shoulder', 'head'), ('wagon', 'carriage'), ('car', 'carriage'), ('elbow', 'ankle'), ('wealth', 'fame'), ('sorrow', 'shame'), ('administration', 'management'), ('communication', 'conversation'), ('pollution', 'atmosphere'), ('anatomy', 'biology'), ('college', 'profession'), ('book', 'topic'), ('formula', 'equation'), ('book', 'information'), ('boy', 'partner'), ('sky', 'universe'), ('population', 'people'), ('college', 'class'), ('chief', 'mayor'), ('rabbi', 'minister'), ('meter', 'inch'), ('polyester', 'cotton'), ('lawyer', 'banker'), ('violin', 'instrument'), ('camp', 'cabin'), ('pot', 'appliance'), ('linen', 'fabric')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('whiskey', 'champagne'), ('girl', 'child'), ('cottage', 'cabin'), ('bird', 'hen'), ('racket', 'noise'), ('sunset', 'evening'), ('drizzle', 'rain'), ('adult', 'baby'), ('charcoal', 'coal'), ('body', 'spine'), ('head', 'nail'), ('log', 'timber'), ('spoon', 'cup'), ('body', 'nerve'), ('man', 'husband'), ('bone', 'neck'), ('frustration', 'anger'), ('river', 'sea'), ('task', 'job'), ('club', 'society'), ('reflection', 'image'), ('prince', 'king'), ('snow', 'weather'), ('people', 'party'), ('boy', 'brother'), ('root', 'grass'), ('brow', 'eye'), ('money', 'pearl'), ('money', 'diamond'), ('vehicle', 'bus'), ('cab', 'bus'), ('house', 'barn'), ('finger', 'palm'), ('car', 'bridge'), ('effort', 'difficulty'), ('fact', 'insight'), ('job', 'management'), ('cancer', 'sickness'), ('word', 'newspaper'), ('composer', 'writer')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('actor', 'singer'), ('shelter', 'hut'), ('bathroom', 'kitchen'), ('cabin', 'hut'), ('door', 'kitchen'), ('value', 'belief'), ('wisdom', 'intelligence'), ('ignorance', 'intelligence'), ('happiness', 'luck'), ('idea', 'scheme'), ('mood', 'emotion'), ('happiness', 'peace'), ('despair', 'misery'), ('logic', 'arithmetic'), ('denial', 'confession'), ('argument', 'criticism'), ('aggression', 'hostility'), ('hysteria', 'confusion'), ('chemistry', 'theory'), ('trial', 'verdict'), ('comfort', 'safety'), ('confidence', 'self'), ('vision', 'perception'), ('era', 'decade'), ('biography', 'fiction'), ('discussion', 'argument'), ('code', 'symbol'), ('danger', 'disease'), ('accident', 'catastrophe'), ('journey', 'trip'), ('activity', 'movement'), ('gossip', 'news'), ('father', 'god'), ('action', 'course'), ('fever', 'illness'), ('aviation', 'flight'), ('game', 'action'), ('molecule', 'air'), ('home', 'state'), ('word', 'literature')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('adult', 'guardian'), ('newspaper', 'information'), ('communication', 'television'), ('cousin', 'uncle'), ('author', 'reader'), ('guy', 'partner'), ('area', 'corner'), ('ballad', 'song'), ('wall', 'decoration'), ('word', 'page'), ('nurse', 'scientist'), ('politician', 'president'), ('president', 'mayor'), ('book', 'essay'), ('man', 'warrior'), ('article', 'journal'), ('breakfast', 'supper'), ('crowd', 'parade'), ('aisle', 'hallway'), ('teacher', 'rabbi'), ('hip', 'lip'), ('book', 'article'), ('room', 'cell'), ('box', 'booth'), ('daughter', 'kid'), ('limb', 'leg'), ('liver', 'lung'), ('classroom', 'hallway'), ('mountain', 'ledge'), ('car', 'elevator'), ('bed', 'couch'), ('clothes', 'button'), ('clothes', 'coat'), ('kidney', 'organ'), ('apple', 'sauce'), ('chicken', 'steak'), ('car', 'hose'), ('tobacco', 'cigarette'), ('student', 'professor'), ('baby', 'daughter')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('pipe', 'cigar'), ('milk', 'juice'), ('box', 'cigar'), ('apartment', 'hotel'), ('cup', 'cone'), ('horse', 'ox'), ('throat', 'nose'), ('bone', 'teeth'), ('bone', 'elbow'), ('bacon', 'bean'), ('cup', 'jar'), ('proof', 'fact'), ('appointment', 'engagement'), ('birthday', 'year'), ('word', 'clue'), ('author', 'creator'), ('atom', 'carbon'), ('archbishop', 'bishop'), ('letter', 'paragraph'), ('page', 'paragraph'), ('steeple', 'chapel'), ('muscle', 'bone'), ('muscle', 'tongue'), ('boy', 'soldier'), ('belly', 'abdomen'), ('guy', 'girl'), ('bed', 'chair'), ('clothes', 'jacket'), ('gun', 'knife'), ('tin', 'metal'), ('bottle', 'container'), ('hen', 'turkey'), ('meat', 'bread'), ('arm', 'bone'), ('neck', 'spine'), ('apple', 'lemon'), ('agony', 'grief'), ('assignment', 'task'), ('night', 'dawn'), ('dinner', 'soup')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('calf', 'bull'), ('snow', 'storm'), ('nail', 'hand'), ('dog', 'horse'), ('arm', 'neck'), ('ball', 'glove'), ('flu', 'fever'), ('fee', 'salary'), ('nerve', 'brain'), ('beast', 'animal'), ('dinner', 'chicken'), ('girl', 'maid'), ('child', 'boy'), ('alcohol', 'wine'), ('nose', 'mouth'), ('street', 'car'), ('bell', 'door'), ('box', 'hat'), ('belief', 'impression'), ('bias', 'opinion'), ('attention', 'awareness'), ('anger', 'mood'), ('elegance', 'style'), ('beauty', 'age'), ('book', 'theme'), ('friend', 'mother'), ('vitamin', 'iron'), ('car', 'factory'), ('pact', 'condition'), ('chapter', 'choice'), ('arithmetic', 'rhythm'), ('winner', 'presence'), ('belief', 'flower'), ('winner', 'goal'), ('trick', 'size'), ('choice', 'vein'), ('hymn', 'conquest'), ('endurance', 'band'), ('jail', 'choice'), ('condition', 'boy')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('flower', 'endurance'), ('hole', 'agreement'), ('doctor', 'temper'), ('fraternity', 'door'), ('task', 'woman'), ('fraternity', 'baseball'), ('cent', 'size'), ('presence', 'door'), ('mouse', 'management'), ('task', 'highway'), ('liquor', 'century'), ('task', 'straw'), ('island', 'task'), ('night', 'chapter'), ('pollution', 'president'), ('gun', 'trick'), ('bath', 'trick'), ('diet', 'apple'), ('cent', 'wife'), ('chapter', 'tail'), ('course', 'stomach'), ('hymn', 'straw'), ('dentist', 'colonel'), ('wife', 'straw'), ('hole', 'wife'), ('pupil', 'president'), ('bath', 'wife'), ('people', 'cent'), ('formula', 'log'), ('woman', 'fur'), ('apple', 'sunshine'), ('gun', 'dawn'), ('meal', 'waist'), ('camera', 'president'), ('liquor', 'band'), ('stomach', 'vein'), ('gun', 'fur'), ('couch', 'baseball'), ('worker', 'camera'), ('deck', 'mouse')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('rice', 'boy'), ('people', 'gun'), ('cliff', 'tail'), ('ankle', 'window'), ('princess', 'island'), ('container', 'mouse'), ('wagon', 'container'), ('people', 'balloon'), ('dollar', 'people'), ('bath', 'balloon'), ('stomach', 'bedroom'), ('bicycle', 'bedroom'), ('log', 'bath'), ('bowl', 'tail'), ('go', 'come'), ('take', 'steal'), ('listen', 'hear'), ('think', 'rationalize'), ('occur', 'happen'), ('vanish', 'disappear'), ('multiply', 'divide'), ('plead', 'beg'), ('begin', 'originate'), ('protect', 'defend'), ('kill', 'destroy'), ('create', 'make'), ('accept', 'reject'), ('ignore', 'avoid'), ('carry', 'bring'), ('leave', 'enter'), ('choose', 'elect'), ('lose', 'fail'), ('encourage', 'discourage'), ('achieve', 'accomplish'), ('make', 'construct'), ('listen', 'obey'), ('inform', 'notify'), ('receive', 'give'), ('borrow', 'beg'), ('take', 'obtain')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('advise', 'recommend'), ('imitate', 'portray'), ('win', 'succeed'), ('think', 'decide'), ('greet', 'meet'), ('agree', 'argue'), ('enjoy', 'entertain'), ('destroy', 'make'), ('save', 'protect'), ('give', 'lend'), ('understand', 'know'), ('take', 'receive'), ('accept', 'acknowledge'), ('decide', 'choose'), ('accept', 'believe'), ('keep', 'possess'), ('roam', 'wander'), ('succeed', 'fail'), ('spend', 'save'), ('leave', 'go'), ('come', 'attend'), ('know', 'believe'), ('gather', 'meet'), ('make', 'earn'), ('forget', 'ignore'), ('multiply', 'add'), ('shrink', 'grow'), ('arrive', 'leave'), ('succeed', 'try'), ('accept', 'deny'), ('arrive', 'come'), ('agree', 'differ'), ('send', 'receive'), ('win', 'dominate'), ('add', 'divide'), ('kill', 'choke'), ('acquire', 'get'), ('participate', 'join'), ('leave', 'remain'), ('go', 'enter')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('take', 'carry'), ('forget', 'learn'), ('appoint', 'elect'), ('engage', 'marry'), ('ask', 'pray'), ('go', 'send'), ('take', 'deliver'), ('speak', 'hear'), ('analyze', 'evaluate'), ('argue', 'rationalize'), ('lose', 'keep'), ('compare', 'analyze'), ('disorganize', 'organize'), ('go', 'allow'), ('take', 'possess'), ('learn', 'listen'), ('destroy', 'construct'), ('create', 'build'), ('steal', 'buy'), ('kill', 'hang'), ('forget', 'know'), ('create', 'imagine'), ('do', 'happen'), ('win', 'accomplish'), ('give', 'deny'), ('deserve', 'earn'), ('get', 'put'), ('locate', 'find'), ('appear', 'attend'), ('know', 'comprehend'), ('pretend', 'imagine'), ('satisfy', 'please'), ('cherish', 'keep'), ('argue', 'differ'), ('overcome', 'dominate'), ('behave', 'obey'), ('cooperate', 'participate'), ('achieve', 'try'), ('fail', 'discourage')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('begin', 'quit'), ('say', 'participate'), ('come', 'bring'), ('declare', 'announce'), ('read', 'comprehend'), ('take', 'leave'), ('proclaim', 'announce'), ('acquire', 'obtain'), ('conclude', 'decide'), ('please', 'plead'), ('argue', 'prove'), ('ask', 'plead'), ('find', 'disappear'), ('inspect', 'examine'), ('verify', 'justify'), ('assume', 'predict'), ('learn', 'evaluate'), ('argue', 'justify'), ('make', 'become'), ('discover', 'originate'), ('achieve', 'succeed'), ('give', 'put'), ('understand', 'listen'), ('expand', 'grow'), ('borrow', 'sell'), ('keep', 'protect'), ('explain', 'prove'), ('assume', 'pretend'), ('agree', 'please'), ('forgive', 'forget'), ('clarify', 'explain'), ('understand', 'forgive'), ('remind', 'forget'), ('get', 'remain'), ('realize', 'discover'), ('require', 'inquire'), ('ignore', 'ask'), ('think', 'inquire'), ('reject', 'avoid')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('argue', 'persuade'), ('pursue', 'persuade'), ('accept', 'forgive'), ('do', 'quit'), ('investigate', 'examine'), ('discuss', 'explain'), ('owe', 'lend'), ('explore', 'discover'), ('complain', 'argue'), ('withdraw', 'reject'), ('keep', 'borrow'), ('beg', 'ask'), ('arrange', 'organize'), ('reduce', 'shrink'), ('speak', 'acknowledge'), ('give', 'borrow'), ('kill', 'defend'), ('disappear', 'shrink'), ('deliver', 'carry'), ('breathe', 'choke'), ('acknowledge', 'notify'), ('become', 'seem'), ('pretend', 'seem'), ('accomplish', 'become'), ('contemplate', 'think'), ('determine', 'predict'), ('please', 'entertain'), ('remain', 'retain'), ('pretend', 'portray'), ('forget', 'retain'), ('want', 'choose'), ('lose', 'get'), ('try', 'think'), ('become', 'appear'), ('leave', 'ignore'), ('accept', 'recommend'), ('leave', 'wander'), ('keep', 'give'), ('give', 'allow')"]
# Rate the semantic similarity of each word pair on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>), ('word3', 'word4', <score>), ...]. Do not provide additional explanations or context. Examples of word pairs and their semantic similarity scores are: [('old', 'new', 1.58), ('smart', 'intelligent', 9.20), ('hard', 'difficult', 8.77)]. --- ["('bring', 'send'), ('absorb', 'learn'), ('acquire', 'find'), ('leave', 'appear'), ('create', 'destroy'), ('begin', 'go'), ('get', 'buy'), ('collect', 'save'), ('replace', 'restore'), ('join', 'add'), ('join', 'marry'), ('accept', 'deliver'), ('attach', 'join'), ('put', 'hang'), ('go', 'sell'), ('communicate', 'pray'), ('give', 'steal'), ('add', 'build'), ('bring', 'restore'), ('comprehend', 'satisfy'), ('portray', 'decide'), ('organize', 'become'), ('give', 'know'), ('say', 'verify'), ('cooperate', 'join'), ('arrange', 'require'), ('borrow', 'want'), ('investigate', 'pursue'), ('ignore', 'explore'), ('bring', 'complain'), ('enter', 'owe'), ('portray', 'notify'), ('remind', 'sell'), ('absorb', 'possess'), ('join', 'acquire'), ('send', 'attend'), ('gather', 'attend'), ('absorb', 'withdraw'), ('attend', 'arrive')"]

# %%
# Load the encoding
encoding = tiktoken.get_encoding("cl100k_base")

# Count the tokens per chunk
token_counts = count_tokens_with_tiktoken(chunks, prompt)
print("Token counts for each formatted prompt:", token_counts)
# Out:
# Token counts for each formatted prompt: [413, 417, 418, 402, 406, 401, 396, 411, 410, 411, 415, 407, 404, 401, 412, 414, 405, 398, 407, 402, 400, 397, 393, 405, 391]

# %% [markdown]
# ### **2. Extract and Process Data**

# %%
# Process each chunk and get results using the OpenAI API
# response = get_responses(chunks, prompt, model, sample_size, delay)
# Out:
# Processing:   0%|          | 0/375 [00:00<?, ?chunk/s]
# Processing: 100%|██████████| 375/375 [2:31:43<00:00, 24.28s/chunk]
# Total time taken: 9103.87 seconds

# %%
# Define filepath
file_path = '../../../data/response/en/gpt-3.5-turbo-0125/f3.json'

# Check if the file already exists
if not os.path.exists(file_path):
    with open(file_path, 'w') as f:
        json.dump(response, f)
        print("File saved successfully.")
else:
    print("File already exists. JSON was not saved to prevent overwriting.")
# Out:
# File saved successfully.

# %%
# Extract data with regular expressions into dictionary
data_dict = process_responses(response)

# Check for values higher/lower then sample size
higher_lower_samples = {key: value for key, value in data_dict.items() if len(value) < sample_size or len(value) > sample_size}
print(higher_lower_samples)
# Out:
# {('give', 'allow'): [4.65, 2.01, 4.21, 5.14, 4.33, 3.08, 3.89, 5.68]}

# %%
# Process data and print duplicate word pairs
print_duplicate_word_pairs(en_simlex, data_dict)
# Out:
# Empty DataFrame
# Columns: [Combined_Columns]
# Index: []
# Empty DataFrame
# Columns: [Combined_Columns]
# Index: []

# %%
# Convert dict to Pandas DataFrame
df = create_dataframe(data_dict)

# Show results
df
# Out:
#       word1     word2  similarity_score_1  similarity_score_2  \
# 0     happy  cheerful                9.30                8.60
# 1      hard      easy                1.20                3.44
# 2      fast     rapid                9.80                9.80
# 3     happy      glad                8.90                9.20
# 4     short      long                3.40                2.00
# ..      ...       ...                 ...                 ...
# 991    join   acquire                3.40                3.16
# 992    send    attend                2.92                1.41
# 993  gather    attend                2.96                1.41
# 994  absorb  withdraw                1.63                1.00
# 995  attend    arrive                4.40                1.41
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                  9.50                9.20                9.50
# 1                  2.00                0.36                2.50
# 2                  9.50                9.20                9.80
# 3                  8.50                9.20                8.50
# 4                  2.00                8.77                1.50
# ..                  ...                 ...                 ...
# 991                0.30                3.05                3.00
# 992                0.10                2.35                2.00
# 993                0.08                3.32                2.09
# 994                0.05                1.13                1.76
# 995                0.15                3.45                2.06
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                  8.40                8.00                9.40
# 1                  1.72                1.00                1.85
# 2                  9.40                9.50                9.90
# 3                  7.20                7.00                9.60
# 4                  3.12                3.00                8.92
# ..                  ...                 ...                 ...
# 991                5.78                2.88                3.08
# 992                2.00                2.05                0.77
# 993                3.00                2.25                1.58
# 994                2.00                1.68                0.77
# 995                1.73                2.45                1.06
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                  7.50                 8.84                 7.50
# 1                  2.50                 2.63                 3.00
# 2                  8.50                 9.58                 9.50
# 3                  8.00                 9.50                 8.00
# 4                  2.50                 5.69                 2.00
# ..                  ...                  ...                  ...
# 991                3.31                 2.69                 7.07
# 992                2.19                 1.78                 1.46
# 993                2.33                 2.46                 1.12
# 994                1.63                 2.04                 2.93
# 995                2.80                 2.62                 1.99
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                   7.50                 8.31                 8.82
# 1                   3.50                 2.59                 1.20
# 2                   9.00                 9.68                 9.20
# 3                   8.50                 8.14                 8.82
# 4                   5.00                 1.73                 7.00
# ..                   ...                  ...                  ...
# 991                 0.52                 2.40                 2.49
# 992                 0.20                 1.56                 2.51
# 993                 0.24                 1.77                 1.69
# 994                 0.13                 1.07                 1.39
# 995                 0.38                 1.82                 2.09
#
#      similarity_score_15
# 0                   3.33
# 1                   1.29
# 2                   9.68
# 3                   6.00
# 4                   5.67
# ..                   ...
# 991                 2.00
# 992                 0.00
# 993                 1.00
# 994                 1.00
# 995                 1.00
#
# [996 rows x 17 columns]

# %%
# Count null values
count_null_values = df.isnull().sum()
print("Null value counts per column:", count_null_values)
# Out:
# Null value counts per column: word1                  0
# word2                  0
# similarity_score_1     0
# similarity_score_2     0
# similarity_score_3     0
# similarity_score_4     0
# similarity_score_5     0
# similarity_score_6     0
# similarity_score_7     0
# similarity_score_8     0
# similarity_score_9     1
# similarity_score_10    1
# similarity_score_11    1
# similarity_score_12    1
# similarity_score_13    1
# similarity_score_14    1
# similarity_score_15    1
# dtype: int64

# %%
# Check for rows with at least one null value
rows_with_null = df[df.isnull().any(axis=1)]
rows_with_null
# Out:
#     word1  word2  similarity_score_1  similarity_score_2  similarity_score_3  \
# 956  give  allow                4.65                2.01                4.21
#
#      similarity_score_4  similarity_score_5  similarity_score_6  \
# 956                5.14                4.33                3.08
#
#      similarity_score_7  similarity_score_8  similarity_score_9  \
# 956                3.89                5.68                 NaN
#
#      similarity_score_10  similarity_score_11  similarity_score_12  \
# 956                  NaN                  NaN                  NaN
#
#      similarity_score_13  similarity_score_14  similarity_score_15
# 956                  NaN                  NaN                  NaN

# %%
# Custom prompt for wordpair
custom_prompt = ("Rate the semantic similarity of the word pair [('give', 'allow')] on a scale from 0 to 10, "
                 "where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. "
                 "Use two decimals. The response should strictly adhere to the structure: "
                 "[('word1', 'word2', <score>)]. "
                 "Do not provide additional explanations or context. "
                 "An example of a word pair and its semantic similarity score is: [('old', 'new', 1.58)]")

for _ in range(7):
    # Make extra API call for 'hysterie' 'verwardheid'
    messages = [{"role": "user", "content": custom_prompt}]
    completion = client.chat.completions.create(
        model=model,
        messages=messages,
        n=1)

    # Show results
    print(completion.choices[0].message.content)
# Out:
# [('give', 'allow', 2.50)]
# [('give', 'allow', 4.52)]
# [('give', 'allow', 0.75)]
# [('give', 'allow', 2.00)]
# [('give', 'allow', 2.25)]
# [('give', 'allow', 3.00)]
# [('give', 'allow', 4.12)]

# %%
# Manually fix inconsistencies
df.loc[(df['word1'] == 'give') & (df['word2'] == 'allow'), 'similarity_score_9'] = 2.50

# Manually fix inconsistencies
df.loc[(df['word1'] == 'give') & (df['word2'] == 'allow'), 'similarity_score_10'] = 4.52

# Manually fix inconsistencies
df.loc[(df['word1'] == 'give') & (df['word2'] == 'allow'), 'similarity_score_11'] = 0.75

# Manually fix inconsistencies
df.loc[(df['word1'] == 'give') & (df['word2'] == 'allow'), 'similarity_score_12'] = 2.00

# Manually fix inconsistencies
df.loc[(df['word1'] == 'give') & (df['word2'] == 'allow'), 'similarity_score_13'] = 2.25

# Manually fix inconsistencies
df.loc[(df['word1'] == 'give') & (df['word2'] == 'allow'), 'similarity_score_14'] = 3.00

# Manually fix inconsistencies
df.loc[(df['word1'] == 'give') & (df['word2'] == 'allow'), 'similarity_score_15'] = 4.12

# Check value
df.loc[(df['word1'] == 'give') & (df['word2'] == 'allow')]
# Out:
#     word1  word2  similarity_score_1  similarity_score_2  similarity_score_3  \
# 956  give  allow                4.65                2.01                4.21
#
#      similarity_score_4  similarity_score_5  similarity_score_6  \
# 956                5.14                4.33                3.08
#
#      similarity_score_7  similarity_score_8  similarity_score_9  \
# 956                3.89                5.68                 2.5
#
#      similarity_score_10  similarity_score_11  similarity_score_12  \
# 956                 4.52                 0.75                  2.0
#
#      similarity_score_13  similarity_score_14  similarity_score_15
# 956                 2.25                  3.0                 4.12

# %%
# Count null values
count_null_values = df.isnull().sum()
print("Null value counts per column:", count_null_values)
# Out:
# Null value counts per column: word1                  0
# word2                  0
# similarity_score_1     0
# similarity_score_2     0
# similarity_score_3     0
# similarity_score_4     0
# similarity_score_5     0
# similarity_score_6     0
# similarity_score_7     0
# similarity_score_8     0
# similarity_score_9     0
# similarity_score_10    0
# similarity_score_11    0
# similarity_score_12    0
# similarity_score_13    0
# similarity_score_14    0
# similarity_score_15    0
# dtype: int64

# %%
# Check for rows with at least one null value
rows_with_null = df[df.isnull().any(axis=1)]
rows_with_null
# Out:
# Empty DataFrame
# Columns: [word1, word2, similarity_score_1, similarity_score_2, similarity_score_3, similarity_score_4, similarity_score_5, similarity_score_6, similarity_score_7, similarity_score_8, similarity_score_9, similarity_score_10, similarity_score_11, similarity_score_12, similarity_score_13, similarity_score_14, similarity_score_15]
# Index: []

# %%
df
# Out:
#       word1     word2  similarity_score_1  similarity_score_2  \
# 0     happy  cheerful                9.30                8.60
# 1      hard      easy                1.20                3.44
# 2      fast     rapid                9.80                9.80
# 3     happy      glad                8.90                9.20
# 4     short      long                3.40                2.00
# ..      ...       ...                 ...                 ...
# 991    join   acquire                3.40                3.16
# 992    send    attend                2.92                1.41
# 993  gather    attend                2.96                1.41
# 994  absorb  withdraw                1.63                1.00
# 995  attend    arrive                4.40                1.41
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                  9.50                9.20                9.50
# 1                  2.00                0.36                2.50
# 2                  9.50                9.20                9.80
# 3                  8.50                9.20                8.50
# 4                  2.00                8.77                1.50
# ..                  ...                 ...                 ...
# 991                0.30                3.05                3.00
# 992                0.10                2.35                2.00
# 993                0.08                3.32                2.09
# 994                0.05                1.13                1.76
# 995                0.15                3.45                2.06
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                  8.40                8.00                9.40
# 1                  1.72                1.00                1.85
# 2                  9.40                9.50                9.90
# 3                  7.20                7.00                9.60
# 4                  3.12                3.00                8.92
# ..                  ...                 ...                 ...
# 991                5.78                2.88                3.08
# 992                2.00                2.05                0.77
# 993                3.00                2.25                1.58
# 994                2.00                1.68                0.77
# 995                1.73                2.45                1.06
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                  7.50                 8.84                 7.50
# 1                  2.50                 2.63                 3.00
# 2                  8.50                 9.58                 9.50
# 3                  8.00                 9.50                 8.00
# 4                  2.50                 5.69                 2.00
# ..                  ...                  ...                  ...
# 991                3.31                 2.69                 7.07
# 992                2.19                 1.78                 1.46
# 993                2.33                 2.46                 1.12
# 994                1.63                 2.04                 2.93
# 995                2.80                 2.62                 1.99
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                   7.50                 8.31                 8.82
# 1                   3.50                 2.59                 1.20
# 2                   9.00                 9.68                 9.20
# 3                   8.50                 8.14                 8.82
# 4                   5.00                 1.73                 7.00
# ..                   ...                  ...                  ...
# 991                 0.52                 2.40                 2.49
# 992                 0.20                 1.56                 2.51
# 993                 0.24                 1.77                 1.69
# 994                 0.13                 1.07                 1.39
# 995                 0.38                 1.82                 2.09
#
#      similarity_score_15
# 0                   3.33
# 1                   1.29
# 2                   9.68
# 3                   6.00
# 4                   5.67
# ..                   ...
# 991                 2.00
# 992                 0.00
# 993                 1.00
# 994                 1.00
# 995                 1.00
#
# [996 rows x 17 columns]

# %%
# Define file_path
file_path = '../../../data/prompt/en/gpt-3.5-turbo-0125/f3.csv'

# Check if the file already exists
if not os.path.exists(file_path):
    df.to_csv(file_path, index=False)
    print("File saved successfully.")
else:
    print("File already exists. Dataframe was not saved to prevent overwriting.")
# Out:
# File saved successfully.
