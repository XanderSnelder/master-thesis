# %% [markdown]
# ### **0. Set-up**

# %%
# Import libraries and utils
# %run '../../utils.ipynb'

# %%
#  Get api key
load_dotenv()
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

# Set client
client = OpenAI()

# %%
# Load dataframe
en_simlex = pd.read_csv("../../../data/dataset/en-simlex-999.txt", delimiter='\t')

# Select subset
en_simlex = en_simlex.iloc[0:333]
# en_simlex = en_simlex.iloc[333:666]
# en_simlex = en_simlex.iloc[666:999]

# Convert to tuple
tuples_list = list(zip(en_simlex['word1'], en_simlex['word2']))

# %%
en_simlex
# Out:
#      word1        word2 POS  SimLex999  conc(w1)  conc(w2)  concQ  Assoc(USF)  \
# 0      old          new   A       1.58      2.72      2.81      2        7.25
# 1    smart  intelligent   A       9.20      1.75      2.46      1        7.11
# 2     hard    difficult   A       8.77      3.76      2.21      2        5.94
# 3    happy     cheerful   A       9.55      2.56      2.34      1        5.85
# 4     hard         easy   A       0.95      3.76      2.07      2        5.82
# ..     ...          ...  ..        ...       ...       ...    ...         ...
# 328  heart      surgery   N       1.08      4.52      4.34      3        0.48
# 329  woman    secretary   N       1.98      4.46      4.54      3        0.48
# 330    man       father   N       4.83      4.79      4.52      3        0.48
# 331  beach       island   N       5.60      4.79      4.96      4        0.48
# 332  story        topic   N       5.00      3.30      2.59      2        0.47
#
#      SimAssoc333  SD(SimLex)
# 0              1        0.41
# 1              1        0.67
# 2              1        1.19
# 3              1        2.18
# 4              1        0.93
# ..           ...         ...
# 328            1        1.07
# 329            1        1.60
# 330            1        1.62
# 331            1        0.39
# 332            1        1.70
#
# [333 rows x 10 columns]

# %% [markdown]
# ### **1. Define and Evaluate Parameters**

# %%
# Define the prompt
prompt = ("Rate the semantic similarity of the word pair: [('{word1}'), ('{word2}')] on a scale from 0 to 10, "
          "where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. "
          "Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. "
          "Do not provide additional explanations or context.")

# %%
# Define model
model = "gpt-3.5-turbo-0125"

# Set sample size
# sample_size = 5
sample_size = 15

# Delay between individual API calls
delay = 3.0

# Define number of sublists
# n_sublists = 999
n_sublists = 333

# %%
# Split the list
chunks = split_into_n_lists(tuples_list, n_sublists)

# Count the number of lists
print(len(chunks))
# Out:
# 333

# %%
# Print the prompts for each chunk
print_prompts_single(chunks, sample_size, prompt)
# Out:
# Rate the semantic similarity of the word pair: [('old'), ('new')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('old'), ('new')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('old'), ('new')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('old'), ('new')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('old'), ('new')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('old'), ('new')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('old'), ('new')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('old'), ('new')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('old'), ('new')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('old'), ('new')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('old'), ('new')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('old'), ('new')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('old'), ('new')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('old'), ('new')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('old'), ('new')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('smart'), ('intelligent')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('smart'), ('intelligent')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('smart'), ('intelligent')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('smart'), ('intelligent')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('smart'), ('intelligent')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('smart'), ('intelligent')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('smart'), ('intelligent')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('smart'), ('intelligent')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('smart'), ('intelligent')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('smart'), ('intelligent')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('smart'), ('intelligent')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('smart'), ('intelligent')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('smart'), ('intelligent')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('smart'), ('intelligent')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('smart'), ('intelligent')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('difficult')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('difficult')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('difficult')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('difficult')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('difficult')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('difficult')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('difficult')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('difficult')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('difficult')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('difficult')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('difficult')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('difficult')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('difficult')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('difficult')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('difficult')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('cheerful')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('cheerful')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('cheerful')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('cheerful')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('cheerful')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('cheerful')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('cheerful')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('cheerful')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('cheerful')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('cheerful')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('cheerful')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('cheerful')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('cheerful')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('cheerful')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('cheerful')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('easy')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('easy')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('easy')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('easy')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('easy')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('easy')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('easy')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('easy')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('easy')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('easy')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('easy')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('easy')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('easy')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('easy')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('hard'), ('easy')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('fast'), ('rapid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('fast'), ('rapid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('fast'), ('rapid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('fast'), ('rapid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('fast'), ('rapid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('fast'), ('rapid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('fast'), ('rapid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('fast'), ('rapid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('fast'), ('rapid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('fast'), ('rapid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('fast'), ('rapid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('fast'), ('rapid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('fast'), ('rapid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('fast'), ('rapid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('fast'), ('rapid')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('glad')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('glad')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('glad')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('glad')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('glad')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('glad')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('glad')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('glad')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('glad')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('glad')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('glad')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('glad')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('glad')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('glad')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('happy'), ('glad')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('short'), ('long')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('short'), ('long')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('short'), ('long')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('short'), ('long')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('short'), ('long')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('short'), ('long')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('short'), ('long')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('short'), ('long')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('short'), ('long')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('short'), ('long')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('short'), ('long')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('short'), ('long')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('short'), ('long')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('short'), ('long')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('short'), ('long')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('stupid'), ('dumb')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('stupid'), ('dumb')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('stupid'), ('dumb')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('stupid'), ('dumb')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('stupid'), ('dumb')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('stupid'), ('dumb')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('stupid'), ('dumb')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('stupid'), ('dumb')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('stupid'), ('dumb')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('stupid'), ('dumb')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('stupid'), ('dumb')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('stupid'), ('dumb')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('stupid'), ('dumb')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('stupid'), ('dumb')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('stupid'), ('dumb')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('weird'), ('strange')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('weird'), ('strange')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('weird'), ('strange')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('weird'), ('strange')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('weird'), ('strange')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('weird'), ('strange')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# ...
# Rate the semantic similarity of the word pair: [('woman'), ('secretary')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('woman'), ('secretary')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('man'), ('father')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('man'), ('father')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('man'), ('father')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('man'), ('father')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('man'), ('father')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('man'), ('father')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('man'), ('father')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('man'), ('father')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('man'), ('father')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('man'), ('father')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('man'), ('father')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('man'), ('father')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('man'), ('father')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('man'), ('father')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('man'), ('father')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('beach'), ('island')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('beach'), ('island')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('beach'), ('island')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('beach'), ('island')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('beach'), ('island')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('beach'), ('island')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('beach'), ('island')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('beach'), ('island')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('beach'), ('island')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('beach'), ('island')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('beach'), ('island')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('beach'), ('island')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('beach'), ('island')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('beach'), ('island')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('beach'), ('island')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('story'), ('topic')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('story'), ('topic')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('story'), ('topic')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('story'), ('topic')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('story'), ('topic')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('story'), ('topic')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('story'), ('topic')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('story'), ('topic')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('story'), ('topic')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('story'), ('topic')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('story'), ('topic')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('story'), ('topic')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('story'), ('topic')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('story'), ('topic')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.
# Rate the semantic similarity of the word pair: [('story'), ('topic')] on a scale from 0 to 10, where 0 represents no semantic similarity, and 10 represents perfect semantic similarity. Use two decimals. The response should strictly adhere to the structure: [('word1', 'word2', <score>)]. Do not provide additional explanations or context.

# %%
# Load the encoding
encoding = tiktoken.get_encoding("cl100k_base")

# Count the tokens per chunk
token_counts = count_tokens_with_tiktoken_single(chunks, prompt)
print("Token counts for each formatted prompt:", token_counts)
# Out:
# Token counts for each formatted prompt: [74, 75, 75, 76, 74, 74, 75, 74, 76, 76, 75, 75, 75, 75, 74, 75, 76, 74, 74, 75, 74, 75, 74, 77, 77, 75, 75, 76, 74, 74, 76, 76, 75, 75, 75, 75, 75, 76, 76, 76, 75, 75, 74, 76, 76, 75, 75, 75, 75, 76, 74, 75, 74, 75, 75, 76, 75, 75, 75, 74, 74, 76, 76, 77, 77, 76, 75, 76, 75, 74, 75, 76, 75, 75, 75, 75, 76, 74, 74, 75, 74, 75, 76, 76, 76, 78, 76, 76, 75, 76, 78, 75, 75, 76, 75, 74, 74, 75, 74, 74, 75, 76, 76, 76, 76, 75, 76, 74, 75, 75, 75, 75, 74, 76, 74, 74, 74, 76, 74, 74, 75, 75, 75, 74, 74, 74, 75, 75, 75, 74, 74, 74, 74, 74, 74, 76, 75, 76, 76, 74, 75, 74, 74, 75, 75, 75, 75, 76, 75, 76, 77, 74, 76, 75, 74, 75, 74, 75, 74, 74, 74, 76, 76, 75, 74, 75, 75, 75, 75, 74, 76, 74, 75, 75, 75, 77, 75, 74, 74, 74, 74, 74, 74, 75, 75, 76, 77, 75, 75, 75, 75, 76, 75, 76, 75, 74, 74, 76, 75, 74, 74, 75, 75, 75, 75, 74, 76, 75, 75, 75, 76, 75, 75, 74, 74, 76, 74, 75, 75, 74, 74, 74, 74, 75, 75, 74, 75, 76, 75, 74, 75, 74, 74, 75, 76, 74, 74, 75, 77, 74, 74, 76, 74, 75, 75, 75, 75, 74, 74, 74, 74, 74, 74, 74, 76, 74, 74, 75, 74, 76, 74, 75, 75, 74, 75, 76, 75, 74, 75, 75, 74, 74, 75, 77, 74, 75, 75, 74, 75, 75, 75, 74, 74, 75, 75, 75, 74, 75, 75, 75, 75, 75, 75, 74, 75, 75, 75, 75, 74, 74, 74, 76, 76, 75, 75, 75, 76, 74, 77, 74, 77, 74, 74, 75, 74, 74, 75, 77, 76, 75, 76, 76, 75, 76, 75, 74, 74, 74, 75, 75, 74, 76, 74]

# %%
# Max RPD = 10.000
len(token_counts*15)
# Out:
# 4995

# %%
# Number of total tokens
print(sum(token_counts))

# Runtime = 6.5 hours with 5 seconds delay
# Out:
# 24955

# %% [markdown]
# ### **2. Extract and Process Data**

# %%
# Process each chunk and get results using the OpenAI API
# response = get_responses_single(prompt, chunks, model, sample_size, delay)

# %%
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo-0125 in organization org-n1XNQqWDo5G9Gym9DwHfeBHM on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit

# %%
# Define filepath
file_path = '../../../data/response/en/gpt-3.5-turbo-0125/f9-1.json'

# Check if the file already exists
if not os.path.exists(file_path):
    with open(file_path, 'w') as f:
        json.dump(response, f)
        print("File saved successfully.")
else:
    print("File already exists. JSON was not saved to prevent overwriting.")
# Out:
# File saved successfully.

# %%
# Extract data with regular expressions into dictionary
data_dict = process_responses(response)

# Check for values higher/lower then sample size
higher_lower_samples = {key: value for key, value in data_dict.items() if len(value) < sample_size or len(value) > sample_size}
print(higher_lower_samples)
# Out:
# {('old', 'new'): [0.0, 0.0, 1.0, 1.14, 2.0], ('smart', 'intelligent'): [9.5, 9.0, 9.2, 9.0, 9.5], ('hard', 'difficult'): [9.0, 9.0, 9.0, 9.0, 9.0], ('happy', 'cheerful'): [9.8, 8.75, 9.5, 8.5, 0.88], ('hard', 'easy'): [1.19, 1.0, 1.0, 2.5, 1.0], ('fast', 'rapid'): [9.0, 9.5, 9.0, 8.5, 9.5], ('happy', 'glad'): [9.5, 9.5, 9.0, 9.5, 8.5], ('short', 'long'): [1.0, 1.0, 1.0, 1.0, 2.5], ('stupid', 'dumb'): [9.0, 9.65, 8.5, 9.0, 8.5], ('weird', 'strange'): [8.5, 8.5, 8.0, 9.75, 8.5], ('wide', 'narrow'): [1.0, 1.0, 1.0, 1.0, 2.0], ('bad', 'awful'): [9.0, 8.5, 9.0, 9.5, 9.0], ('easy', 'difficult'): [1.0, 1.0, 1.0, 1.17, 1.0], ('bad', 'terrible'): [9.5, 8.5, 9.0, 8.5, 9.2], ('hard', 'simple'): [1.5, 2.0, 2.5, 1.5, 1.8], ('smart', 'dumb'): [1.0, 2.0, 1.0, 2.0, 2.5], ('insane', 'crazy'): [8.5, 8.0, 8.0, 8.5, 8.5], ('happy', 'mad'): [0.19, 1.9, 0.14, 2.75, 2.33], ('large', 'huge'): [9.0, 9.0, 8.0, 8.5, 8.8], ('hard', 'tough'): [7.0, 8.5, 6.5, 8.5, 8.0], ('new', 'fresh'): [7.5, 7.8, 6.0, 7.5, 6.0], ('sharp', 'dull'): [1.5, 1.0, 2.0, 0.1, 0.14], ('quick', 'rapid'): [9.0, 8.5, 9.5, 9.5, 9.0], ('dumb', 'foolish'): [6.25, 7.5, 6.67, 7.5, 6.0], ('wonderful', 'terrific'): [8.7, 8.9, 0.8, 7.5, 8.5], ('strange', 'odd'): [8.5, 8.5, 7.0, 8.5, 8.5], ('happy', 'angry'): [0.12, 1.14, 1.55, 2.0, 0.1], ('narrow', 'broad'): [1.0, 3.33, 2.14, 1.0, 1.0], ('simple', 'easy'): [6.0, 6.5, 6.0, 8.0, 7.5], ('old', 'fresh'): [1.0, 0.1, 2.13, 1.13, 1.0], ('apparent', 'obvious'): [8.0, 8.6, 8.5, 8.5, 8.5], ('inexpensive', 'cheap'): [8.0, 9.0, 9.5, 9.0, 8.5], ('nice', 'generous'): [7.33, 6.0, 0.61, 7.31, 5.75], ('weird', 'normal'): [1.55, 1.5, 1.23, 0.15, 1.18], ('weird', 'odd'): [7.5, 8.5, 8.5, 8.0, 8.0], ('bad', 'immoral'): [8.5, 7.6, 8.0, 7.5, 8.0], ('sad', 'funny'): [1.0, 0.2, 1.5, 1.5, 2.0], ('wonderful', 'great'): [8.33, 7.0, 8.5, 7.5, 8.5], ('guilty', 'ashamed'): [7.0, 8.0, 7.5, 7.5, 7.5], ('beautiful', 'wonderful'): [0.8, 0.85, 7.5, 8.5, 7.5], ('confident', 'sure'): [8.5, 8.5, 8.0, 9.0, 8.5], ('dumb', 'dense'): [3.0, 4.0, 2.0, 2.5, 3.45], ('large', 'big'): [9.0, 9.0, 8.5, 9.5, 9.0], ('nice', 'cruel'): [1.5, 1.2, 0.1, 1.25, 0.1], ('impatient', 'anxious'): [7.0, 7.75, 6.67, 6.5, 7.0], ('big', 'broad'): [3.0, 6.0, 5.5, 3.0, 3.0], ('strong', 'proud'): [0.15, 1.35, 0.22, 2.0, 0.1], ('unnecessary', 'necessary'): [3.33, 3.33, 3.33, 2.0, 3.33], ('restless', 'young'): [2.5, 2.45, 2.45, 2.15, 0.0], ('dumb', 'intelligent'): [1.23, 1.0, 1.0, 2.5, 0.14]}

# %%
# Process data and print duplicate word pairs
print_duplicate_word_pairs(en_simlex, data_dict)
# Out:
#         Combined_Columns
# 50             bad_great
# 51      difficult_simple
# 52   necessary_important
# 53          bad_terrific
# 54              mad_glad
# ..                   ...
# 994         join_acquire
# 995          send_attend
# 996        gather_attend
# 997      absorb_withdraw
# 998        attend_arrive
#
# [949 rows x 1 columns]
# Empty DataFrame
# Columns: [Combined_Columns]
# Index: []

# %%
# Convert dict to Pandas DataFrame
df = create_dataframe(data_dict)

# Show results
df
# Out:
#           word1        word2  similarity_score_1  similarity_score_2  \
# 0           old          new                0.00                0.00
# 1         smart  intelligent                9.50                9.00
# 2          hard    difficult                9.00                9.00
# 3         happy     cheerful                9.80                8.75
# 4          hard         easy                1.19                1.00
# 5          fast        rapid                9.00                9.50
# 6         happy         glad                9.50                9.50
# 7         short         long                1.00                1.00
# 8        stupid         dumb                9.00                9.65
# 9         weird      strange                8.50                8.50
# 10         wide       narrow                1.00                1.00
# 11          bad        awful                9.00                8.50
# 12         easy    difficult                1.00                1.00
# 13          bad     terrible                9.50                8.50
# 14         hard       simple                1.50                2.00
# 15        smart         dumb                1.00                2.00
# 16       insane        crazy                8.50                8.00
# 17        happy          mad                0.19                1.90
# 18        large         huge                9.00                9.00
# 19         hard        tough                7.00                8.50
# 20          new        fresh                7.50                7.80
# 21        sharp         dull                1.50                1.00
# 22        quick        rapid                9.00                8.50
# 23         dumb      foolish                6.25                7.50
# 24    wonderful     terrific                8.70                8.90
# 25      strange          odd                8.50                8.50
# 26        happy        angry                0.12                1.14
# 27       narrow        broad                1.00                3.33
# 28       simple         easy                6.00                6.50
# 29          old        fresh                1.00                0.10
# 30     apparent      obvious                8.00                8.60
# 31  inexpensive        cheap                8.00                9.00
# 32         nice     generous                7.33                6.00
# 33        weird       normal                1.55                1.50
# 34        weird          odd                7.50                8.50
# 35          bad      immoral                8.50                7.60
# 36          sad        funny                1.00                0.20
# 37    wonderful        great                8.33                7.00
# 38       guilty      ashamed                7.00                8.00
# 39    beautiful    wonderful                0.80                0.85
# 40    confident         sure                8.50                8.50
# 41         dumb        dense                3.00                4.00
# 42        large          big                9.00                9.00
# 43         nice        cruel                1.50                1.20
# 44    impatient      anxious                7.00                7.75
# 45          big        broad                3.00                6.00
# 46       strong        proud                0.15                1.35
# 47  unnecessary    necessary                3.33                3.33
# 48     restless        young                2.50                2.45
# 49         dumb  intelligent                1.23                1.00
#
#     similarity_score_3  similarity_score_4  similarity_score_5
# 0                 1.00                1.14                2.00
# 1                 9.20                9.00                9.50
# 2                 9.00                9.00                9.00
# 3                 9.50                8.50                0.88
# 4                 1.00                2.50                1.00
# 5                 9.00                8.50                9.50
# 6                 9.00                9.50                8.50
# 7                 1.00                1.00                2.50
# 8                 8.50                9.00                8.50
# 9                 8.00                9.75                8.50
# 10                1.00                1.00                2.00
# 11                9.00                9.50                9.00
# 12                1.00                1.17                1.00
# 13                9.00                8.50                9.20
# 14                2.50                1.50                1.80
# 15                1.00                2.00                2.50
# 16                8.00                8.50                8.50
# 17                0.14                2.75                2.33
# 18                8.00                8.50                8.80
# 19                6.50                8.50                8.00
# 20                6.00                7.50                6.00
# 21                2.00                0.10                0.14
# 22                9.50                9.50                9.00
# 23                6.67                7.50                6.00
# 24                0.80                7.50                8.50
# 25                7.00                8.50                8.50
# 26                1.55                2.00                0.10
# 27                2.14                1.00                1.00
# 28                6.00                8.00                7.50
# 29                2.13                1.13                1.00
# 30                8.50                8.50                8.50
# 31                9.50                9.00                8.50
# 32                0.61                7.31                5.75
# 33                1.23                0.15                1.18
# 34                8.50                8.00                8.00
# 35                8.00                7.50                8.00
# 36                1.50                1.50                2.00
# 37                8.50                7.50                8.50
# 38                7.50                7.50                7.50
# 39                7.50                8.50                7.50
# 40                8.00                9.00                8.50
# 41                2.00                2.50                3.45
# 42                8.50                9.50                9.00
# 43                0.10                1.25                0.10
# 44                6.67                6.50                7.00
# 45                5.50                3.00                3.00
# 46                0.22                2.00                0.10
# 47                3.33                2.00                3.33
# 48                2.45                2.15                0.00
# 49                1.00                2.50                0.14

# %%
# Count null values
count_null_values = df.isnull().sum()
print("Null value counts per column:", count_null_values)
# Out:
# Null value counts per column: word1                 0
# word2                 0
# similarity_score_1    0
# similarity_score_2    0
# similarity_score_3    0
# similarity_score_4    0
# similarity_score_5    0
# dtype: int64

# %%
# Check for rows with at least one null value
rows_with_null = df[df.isnull().any(axis=1)]
rows_with_null
# Out:
# Empty DataFrame
# Columns: [word1, word2, similarity_score_1, similarity_score_2, similarity_score_3, similarity_score_4, similarity_score_5]
# Index: []

# %%
# Manually fix inconsistencies
df.loc[(df['word1'] == 'winter') & (df['word2'] == 'season'), 'similarity_score_15'] = 8.00

# Check value
df.loc[(df['word1'] == 'winter') & (df['word2'] == 'season')]
# Out:
# Empty DataFrame
# Columns: [word1, word2, similarity_score_1, similarity_score_2, similarity_score_3, similarity_score_4, similarity_score_5, similarity_score_15]
# Index: []

# %%
# Drop faulty row
df = df[~((df['word1'] == 'winter') & (df['word2'] == 'seaso'))]
df
# Out:
#           word1        word2  similarity_score_1  similarity_score_2  \
# 0           old          new                0.00                0.00
# 1         smart  intelligent                9.50                9.00
# 2          hard    difficult                9.00                9.00
# 3         happy     cheerful                9.80                8.75
# 4          hard         easy                1.19                1.00
# 5          fast        rapid                9.00                9.50
# 6         happy         glad                9.50                9.50
# 7         short         long                1.00                1.00
# 8        stupid         dumb                9.00                9.65
# 9         weird      strange                8.50                8.50
# 10         wide       narrow                1.00                1.00
# 11          bad        awful                9.00                8.50
# 12         easy    difficult                1.00                1.00
# 13          bad     terrible                9.50                8.50
# 14         hard       simple                1.50                2.00
# 15        smart         dumb                1.00                2.00
# 16       insane        crazy                8.50                8.00
# 17        happy          mad                0.19                1.90
# 18        large         huge                9.00                9.00
# 19         hard        tough                7.00                8.50
# 20          new        fresh                7.50                7.80
# 21        sharp         dull                1.50                1.00
# 22        quick        rapid                9.00                8.50
# 23         dumb      foolish                6.25                7.50
# 24    wonderful     terrific                8.70                8.90
# 25      strange          odd                8.50                8.50
# 26        happy        angry                0.12                1.14
# 27       narrow        broad                1.00                3.33
# 28       simple         easy                6.00                6.50
# 29          old        fresh                1.00                0.10
# 30     apparent      obvious                8.00                8.60
# 31  inexpensive        cheap                8.00                9.00
# 32         nice     generous                7.33                6.00
# 33        weird       normal                1.55                1.50
# 34        weird          odd                7.50                8.50
# 35          bad      immoral                8.50                7.60
# 36          sad        funny                1.00                0.20
# 37    wonderful        great                8.33                7.00
# 38       guilty      ashamed                7.00                8.00
# 39    beautiful    wonderful                0.80                0.85
# 40    confident         sure                8.50                8.50
# 41         dumb        dense                3.00                4.00
# 42        large          big                9.00                9.00
# 43         nice        cruel                1.50                1.20
# 44    impatient      anxious                7.00                7.75
# 45          big        broad                3.00                6.00
# 46       strong        proud                0.15                1.35
# 47  unnecessary    necessary                3.33                3.33
# 48     restless        young                2.50                2.45
# 49         dumb  intelligent                1.23                1.00
#
#     similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                 1.00                1.14                2.00
# 1                 9.20                9.00                9.50
# 2                 9.00                9.00                9.00
# 3                 9.50                8.50                0.88
# 4                 1.00                2.50                1.00
# 5                 9.00                8.50                9.50
# 6                 9.00                9.50                8.50
# 7                 1.00                1.00                2.50
# 8                 8.50                9.00                8.50
# 9                 8.00                9.75                8.50
# 10                1.00                1.00                2.00
# 11                9.00                9.50                9.00
# 12                1.00                1.17                1.00
# 13                9.00                8.50                9.20
# 14                2.50                1.50                1.80
# 15                1.00                2.00                2.50
# 16                8.00                8.50                8.50
# 17                0.14                2.75                2.33
# 18                8.00                8.50                8.80
# 19                6.50                8.50                8.00
# 20                6.00                7.50                6.00
# 21                2.00                0.10                0.14
# 22                9.50                9.50                9.00
# 23                6.67                7.50                6.00
# 24                0.80                7.50                8.50
# 25                7.00                8.50                8.50
# 26                1.55                2.00                0.10
# 27                2.14                1.00                1.00
# 28                6.00                8.00                7.50
# 29                2.13                1.13                1.00
# 30                8.50                8.50                8.50
# 31                9.50                9.00                8.50
# 32                0.61                7.31                5.75
# 33                1.23                0.15                1.18
# 34                8.50                8.00                8.00
# 35                8.00                7.50                8.00
# 36                1.50                1.50                2.00
# 37                8.50                7.50                8.50
# 38                7.50                7.50                7.50
# 39                7.50                8.50                7.50
# 40                8.00                9.00                8.50
# 41                2.00                2.50                3.45
# 42                8.50                9.50                9.00
# 43                0.10                1.25                0.10
# 44                6.67                6.50                7.00
# 45                5.50                3.00                3.00
# 46                0.22                2.00                0.10
# 47                3.33                2.00                3.33
# 48                2.45                2.15                0.00
# 49                1.00                2.50                0.14
#
#     similarity_score_15
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
# 30                  NaN
# 31                  NaN
# 32                  NaN
# 33                  NaN
# 34                  NaN
# 35                  NaN
# 36                  NaN
# 37                  NaN
# 38                  NaN
# 39                  NaN
# 40                  NaN
# 41                  NaN
# 42                  NaN
# 43                  NaN
# 44                  NaN
# 45                  NaN
# 46                  NaN
# 47                  NaN
# 48                  NaN
# 49                  NaN

# %%
# Check for rows with at least one null value
rows_with_null = df[df.isnull().any(axis=1)]
rows_with_null
# Out:
#           word1        word2  similarity_score_1  similarity_score_2  \
# 0           old          new                0.00                0.00
# 1         smart  intelligent                9.50                9.00
# 2          hard    difficult                9.00                9.00
# 3         happy     cheerful                9.80                8.75
# 4          hard         easy                1.19                1.00
# 5          fast        rapid                9.00                9.50
# 6         happy         glad                9.50                9.50
# 7         short         long                1.00                1.00
# 8        stupid         dumb                9.00                9.65
# 9         weird      strange                8.50                8.50
# 10         wide       narrow                1.00                1.00
# 11          bad        awful                9.00                8.50
# 12         easy    difficult                1.00                1.00
# 13          bad     terrible                9.50                8.50
# 14         hard       simple                1.50                2.00
# 15        smart         dumb                1.00                2.00
# 16       insane        crazy                8.50                8.00
# 17        happy          mad                0.19                1.90
# 18        large         huge                9.00                9.00
# 19         hard        tough                7.00                8.50
# 20          new        fresh                7.50                7.80
# 21        sharp         dull                1.50                1.00
# 22        quick        rapid                9.00                8.50
# 23         dumb      foolish                6.25                7.50
# 24    wonderful     terrific                8.70                8.90
# 25      strange          odd                8.50                8.50
# 26        happy        angry                0.12                1.14
# 27       narrow        broad                1.00                3.33
# 28       simple         easy                6.00                6.50
# 29          old        fresh                1.00                0.10
# 30     apparent      obvious                8.00                8.60
# 31  inexpensive        cheap                8.00                9.00
# 32         nice     generous                7.33                6.00
# 33        weird       normal                1.55                1.50
# 34        weird          odd                7.50                8.50
# 35          bad      immoral                8.50                7.60
# 36          sad        funny                1.00                0.20
# 37    wonderful        great                8.33                7.00
# 38       guilty      ashamed                7.00                8.00
# 39    beautiful    wonderful                0.80                0.85
# 40    confident         sure                8.50                8.50
# 41         dumb        dense                3.00                4.00
# 42        large          big                9.00                9.00
# 43         nice        cruel                1.50                1.20
# 44    impatient      anxious                7.00                7.75
# 45          big        broad                3.00                6.00
# 46       strong        proud                0.15                1.35
# 47  unnecessary    necessary                3.33                3.33
# 48     restless        young                2.50                2.45
# 49         dumb  intelligent                1.23                1.00
#
#     similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                 1.00                1.14                2.00
# 1                 9.20                9.00                9.50
# 2                 9.00                9.00                9.00
# 3                 9.50                8.50                0.88
# 4                 1.00                2.50                1.00
# 5                 9.00                8.50                9.50
# 6                 9.00                9.50                8.50
# 7                 1.00                1.00                2.50
# 8                 8.50                9.00                8.50
# 9                 8.00                9.75                8.50
# 10                1.00                1.00                2.00
# 11                9.00                9.50                9.00
# 12                1.00                1.17                1.00
# 13                9.00                8.50                9.20
# 14                2.50                1.50                1.80
# 15                1.00                2.00                2.50
# 16                8.00                8.50                8.50
# 17                0.14                2.75                2.33
# 18                8.00                8.50                8.80
# 19                6.50                8.50                8.00
# 20                6.00                7.50                6.00
# 21                2.00                0.10                0.14
# 22                9.50                9.50                9.00
# 23                6.67                7.50                6.00
# 24                0.80                7.50                8.50
# 25                7.00                8.50                8.50
# 26                1.55                2.00                0.10
# 27                2.14                1.00                1.00
# 28                6.00                8.00                7.50
# 29                2.13                1.13                1.00
# 30                8.50                8.50                8.50
# 31                9.50                9.00                8.50
# 32                0.61                7.31                5.75
# 33                1.23                0.15                1.18
# 34                8.50                8.00                8.00
# 35                8.00                7.50                8.00
# 36                1.50                1.50                2.00
# 37                8.50                7.50                8.50
# 38                7.50                7.50                7.50
# 39                7.50                8.50                7.50
# 40                8.00                9.00                8.50
# 41                2.00                2.50                3.45
# 42                8.50                9.50                9.00
# 43                0.10                1.25                0.10
# 44                6.67                6.50                7.00
# 45                5.50                3.00                3.00
# 46                0.22                2.00                0.10
# 47                3.33                2.00                3.33
# 48                2.45                2.15                0.00
# 49                1.00                2.50                0.14
#
#     similarity_score_15
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
# 30                  NaN
# 31                  NaN
# 32                  NaN
# 33                  NaN
# 34                  NaN
# 35                  NaN
# 36                  NaN
# 37                  NaN
# 38                  NaN
# 39                  NaN
# 40                  NaN
# 41                  NaN
# 42                  NaN
# 43                  NaN
# 44                  NaN
# 45                  NaN
# 46                  NaN
# 47                  NaN
# 48                  NaN
# 49                  NaN

# %%
# Extract missing word pairs
missing_word_pair_list = list(zip(rows_with_null['word1'], rows_with_null['word2']))
missing_word_pair_list
# Out:
# [('old', 'new'),
#  ('smart', 'intelligent'),
#  ('hard', 'difficult'),
#  ('happy', 'cheerful'),
#  ('hard', 'easy'),
#  ('fast', 'rapid'),
#  ('happy', 'glad'),
#  ('short', 'long'),
#  ('stupid', 'dumb'),
#  ('weird', 'strange'),
#  ('wide', 'narrow'),
#  ('bad', 'awful'),
#  ('easy', 'difficult'),
#  ('bad', 'terrible'),
#  ('hard', 'simple'),
#  ('smart', 'dumb'),
#  ('insane', 'crazy'),
#  ('happy', 'mad'),
#  ('large', 'huge'),
#  ('hard', 'tough'),
#  ('new', 'fresh'),
#  ('sharp', 'dull'),
#  ('quick', 'rapid'),
#  ('dumb', 'foolish'),
#  ('wonderful', 'terrific'),
#  ('strange', 'odd'),
#  ('happy', 'angry'),
#  ('narrow', 'broad'),
#  ('simple', 'easy'),
#  ('old', 'fresh'),
#  ('apparent', 'obvious'),
#  ('inexpensive', 'cheap'),
#  ('nice', 'generous'),
#  ('weird', 'normal'),
#  ('weird', 'odd'),
#  ('bad', 'immoral'),
#  ('sad', 'funny'),
#  ('wonderful', 'great'),
#  ('guilty', 'ashamed'),
#  ('beautiful', 'wonderful'),
#  ('confident', 'sure'),
#  ('dumb', 'dense'),
#  ('large', 'big'),
#  ('nice', 'cruel'),
#  ('impatient', 'anxious'),
#  ('big', 'broad'),
#  ('strong', 'proud'),
#  ('unnecessary', 'necessary'),
#  ('restless', 'young'),
#  ('dumb', 'intelligent')]

# %%
# Make extra API call
formatted_prompt = format_prompt(missing_word_pair_list, prompt)
messages = [{"role": "user", "content": formatted_prompt}]

# Call the OpenAI API
# completion = client.chat.completions.create(
#     model=model,
#     messages=messages,
#     n=1)

# Store the response content
missing_word_pairs_response = [completion.choices[0].message.content]

# %%
# Extract data with regular expressions into dictionary
missing_word_pairs_dict = process_responses(missing_word_pairs_response)
missing_word_pairs_dict
# Out:
# {('fee', 'payment'): [9.0],
#  ('bible', 'hymn'): [2.0],
#  ('exit', 'doorway'): [1.0],
#  ('man', 'sentry'): [1.0],
#  ('aisle', 'hall'): [5.0],
#  ('whiskey', 'gin'): [4.0],
#  ('blood', 'marrow'): [1.0],
#  ('oil', 'mink'): [1.0],
#  ('floor', 'deck'): [2.0],
#  ('roof', 'floor'): [1.0],
#  ('door', 'floor'): [1.0],
#  ('shoulder', 'head'): [2.0],
#  ('wagon', 'carriage'): [8.0],
#  ('car', 'carriage'): [8.0],
#  ('elbow', 'ankle'): [1.0]}

# %%
# Iterate over the DataFrame and replace missing values
for index, row in df.iterrows():
    word_pair = (row['word1'], row['word2'])
    # Check if the current value is NaN
    if pd.isna(row['similarity_score_15']):
        if word_pair in missing_word_pairs_dict:
            # Extract the first element from the list to get the scalar value
            df.at[index, 'similarity_score_15'] = missing_word_pairs_dict[word_pair][0]

# Print to check if there are any NaN values left in 'similarity_score_15'
print(df[df['similarity_score_15'].isna()])
# Out:
# Empty DataFrame
# Columns: [word1, word2, similarity_score_1, similarity_score_2, similarity_score_3, similarity_score_4, similarity_score_5, similarity_score_6, similarity_score_7, similarity_score_8, similarity_score_9, similarity_score_10, similarity_score_11, similarity_score_12, similarity_score_13, similarity_score_14, similarity_score_15]
# Index: []

# %%
# Filter the DataFrame based on pairs
filtered_df = df[df.apply(lambda row: (row['word1'], row['word2']) in missing_word_pair_list, axis=1)]

# Select only the similarity_score_15 column
result = filtered_df[['word1', 'word2', 'similarity_score_15']]

# Print or output the result
print(result)
# Out:
#         word1     word2  similarity_score_15
# 486       fee   payment                  9.0
# 487     bible      hymn                  2.0
# 488      exit   doorway                  1.0
# 489       man    sentry                  1.0
# 490     aisle      hall                  5.0
# 491   whiskey       gin                  4.0
# 492     blood    marrow                  1.0
# 493       oil      mink                  1.0
# 494     floor      deck                  2.0
# 495      roof     floor                  1.0
# 496      door     floor                  1.0
# 497  shoulder      head                  2.0
# 498     wagon  carriage                  8.0
# 499       car  carriage                  8.0
# 500     elbow     ankle                  1.0

# %%
# Check for rows with at least one null value
rows_with_null = df[df.isnull().any(axis=1)]
rows_with_null
# Out:
# Empty DataFrame
# Columns: [word1, word2, similarity_score_1, similarity_score_2, similarity_score_3, similarity_score_4, similarity_score_5, similarity_score_6, similarity_score_7, similarity_score_8, similarity_score_9, similarity_score_10, similarity_score_11, similarity_score_12, similarity_score_13, similarity_score_14, similarity_score_15]
# Index: []

# %%
df
# Out:
#       word1        word2  similarity_score_1  similarity_score_2  \
# 0       old          new                0.05                0.10
# 1     smart  intelligent                0.90                0.95
# 2      hard    difficult                0.90                0.80
# 3     happy     cheerful                0.80                0.80
# 4      hard         easy                0.10                0.10
# ..      ...          ...                 ...                 ...
# 995    join      acquire                2.00                4.00
# 996    send       attend                1.00                1.00
# 997  gather       attend                2.00                2.00
# 998  absorb     withdraw                1.00                1.00
# 999  attend       arrive                2.00                2.00
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                  1.00                 1.0                0.20
# 1                  1.00                 1.0                0.96
# 2                  0.71                 1.0                0.92
# 3                  0.90                 0.0                0.70
# 4                  0.10                 0.0                0.16
# ..                  ...                 ...                 ...
# 995                3.50                 0.3                0.60
# 996                1.00                 0.2                0.30
# 997                2.00                 0.3                0.45
# 998                1.50                 0.1                0.20
# 999                2.00                 0.3                0.60
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                  0.10                0.15                 1.5
# 1                  0.95                0.95                 9.5
# 2                  0.90                0.90                 8.0
# 3                  0.75                0.80                 8.5
# 4                  0.05                0.20                 2.0
# ..                  ...                 ...                 ...
# 995                0.75                3.00                 2.5
# 996                0.00                2.00                 2.0
# 997                0.50                2.00                 3.0
# 998                0.00                1.00                 1.5
# 999                0.25                3.00                 1.5
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                  0.10                 0.15                 3.50
# 1                  0.95                 0.90                 9.50
# 2                  0.85                 0.80                 7.00
# 3                  0.85                 0.80                 8.00
# 4                  0.20                 0.20                 2.00
# ..                  ...                  ...                  ...
# 995                4.50                 0.50                 0.45
# 996                3.50                 0.00                 0.21
# 997                3.00                 0.00                 0.32
# 998                1.50                 0.00                 0.20
# 999                2.00                 0.00                 0.38
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                   0.01                 0.20                 1.00
# 1                   0.93                 0.95                 0.94
# 2                   0.85                 0.85                 0.97
# 3                   0.81                 0.70                 0.86
# 4                   0.15                 0.10                 0.22
# ..                   ...                  ...                  ...
# 995                 0.70                 5.00                 0.50
# 996                 0.40                 3.00                 0.20
# 997                 0.70                 4.00                 0.30
# 998                 0.30                 2.00                 0.10
# 999                 0.70                 5.00                 0.30
#
#      similarity_score_15
# 0                   0.10
# 1                   1.00
# 2                   0.85
# 3                   0.90
# 4                   0.10
# ..                   ...
# 995                 0.31
# 996                 0.29
# 997                 0.37
# 998                 0.16
# 999                 0.56
#
# [999 rows x 17 columns]

# %%
# Define file_path
file_path = '../../../data/prompt/en/gpt-3.5-turbo-0125/f9-1.csv'

# Check if the file already exists
if not os.path.exists(file_path):
    df.to_csv(file_path, index=False)
    print("File saved successfully.")
else:
    print("File already exists. Dataframe was not saved to prevent overwriting.")
# Out:
# File saved successfully.
