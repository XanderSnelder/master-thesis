# %% [markdown]
# ### **0. Set-up**

# %%
# Import libraries and utils
# %run '../../utils.ipynb'

# %%
# Load predicted
raw_predicted = pd.read_csv("../../../data/gpt-3.5-turbo-0125/processed/en/f8.csv")

# Load actual
raw_actual = pd.read_csv("../../../data/dataset/cleaned-en-simlex-999.csv")

# Drop first three word pairs
raw_actual = raw_actual.iloc[3:].reset_index(drop=True)

# %%
# Show results
raw_predicted
# Out:
#       word1     word2  similarity_score_1  similarity_score_2  \
# 0     happy  cheerful                8.75                9.20
# 1      hard      easy                4.10                1.73
# 2      fast     rapid                9.50                9.60
# 3     happy      glad                8.50                8.60
# 4     short      long                7.25                7.50
# ..      ...       ...                 ...                 ...
# 991    join   acquire                7.35                6.60
# 992    send    attend                5.30                6.60
# 993  gather    attend                6.97                6.00
# 994  absorb  withdraw                3.41                3.20
# 995  attend    arrive                6.33                7.60
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                  7.76                5.26                9.50
# 1                  0.81                3.00                1.67
# 2                  9.34                9.75                9.80
# 3                  8.47                7.50                9.40
# 4                  0.71                5.50                9.60
# ..                  ...                 ...                 ...
# 991                4.00                3.00                5.12
# 992                2.40                1.00                3.44
# 993                3.00                1.00                4.20
# 994                1.80                1.00                2.60
# 995                4.00                1.00                5.60
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                  9.60                8.66                8.50
# 1                  3.50                4.52                1.14
# 2                  8.50                9.68                9.21
# 3                  8.80                7.90                8.09
# 4                  5.50                6.42                7.80
# ..                  ...                 ...                 ...
# 991                0.25                6.27                4.38
# 992                0.25                4.44                3.33
# 993                0.25                5.36                3.33
# 994                0.25                3.37                2.08
# 995                0.25                4.17                2.87
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                  9.15                 8.57                 8.90
# 1                  1.98                 2.14                 5.65
# 2                  8.90                 9.29                 9.50
# 3                  8.00                 8.57                 7.80
# 4                  7.34                 8.57                 8.20
# ..                  ...                  ...                  ...
# 991                6.23                 6.12                 3.93
# 992                4.28                 4.65                 4.44
# 993                4.56                 4.94                 4.21
# 994                2.67                 3.12                 2.19
# 995                4.78                 6.03                 4.16
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                   8.20                 9.80                 8.90
# 1                   3.20                 6.00                 2.33
# 2                   9.80                 9.70                 8.20
# 3                   7.60                 9.70                 8.50
# 4                   8.80                 9.20                 7.50
# ..                   ...                  ...                  ...
# 991                 4.30                 3.44                 4.00
# 992                 4.35                 2.09                 2.17
# 993                 3.90                 2.53                 3.52
# 994                 3.40                 1.36                 5.75
# 995                 4.50                 2.18                 6.20
#
#      similarity_score_15
# 0                   8.89
# 1                   5.00
# 2                   9.17
# 3                   8.89
# 4                   6.33
# ..                   ...
# 991                 4.00
# 992                 3.00
# 993                 2.50
# 994                 3.00
# 995                 3.50
#
# [996 rows x 17 columns]

# %% [markdown]
# ### **1. Data Quality**

# %%
# Basic info
raw_predicted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   word1                996 non-null    object
#  1   word2                996 non-null    object
#  2   similarity_score_1   996 non-null    float64
#  3   similarity_score_2   996 non-null    float64
#  4   similarity_score_3   996 non-null    float64
#  5   similarity_score_4   996 non-null    float64
#  6   similarity_score_5   996 non-null    float64
#  7   similarity_score_6   996 non-null    float64
#  8   similarity_score_7   996 non-null    float64
#  9   similarity_score_8   996 non-null    float64
#  10  similarity_score_9   996 non-null    float64
#  11  similarity_score_10  996 non-null    float64
#  12  similarity_score_11  996 non-null    float64
#  13  similarity_score_12  996 non-null    float64
#  14  similarity_score_13  996 non-null    float64
#  15  similarity_score_14  996 non-null    float64
#  16  similarity_score_15  996 non-null    float64
# dtypes: float64(15), object(2)
# memory usage: 132.4+ KB

# %%
# Missing values per column
raw_predicted.isnull().sum()
# Out:
# word1                  0
# word2                  0
# similarity_score_1     0
# similarity_score_2     0
# similarity_score_3     0
# similarity_score_4     0
# similarity_score_5     0
# similarity_score_6     0
# similarity_score_7     0
# similarity_score_8     0
# similarity_score_9     0
# similarity_score_10    0
# similarity_score_11    0
# similarity_score_12    0
# similarity_score_13    0
# similarity_score_14    0
# similarity_score_15    0
# dtype: int64

# %%
# Select word pairs and copy
wordpairs_predicted = raw_predicted[['word1', 'word2']].copy()
wordpairs_actual = raw_actual[['word1', 'word2']].copy()

# Remove whitespace
wordpairs_actual['word1'] = wordpairs_actual['word1'].replace(" ", "", regex=True)
wordpairs_actual['word2'] = wordpairs_actual['word2'].replace(" ", "", regex=True)

# Check if actual is identical to predicted
are_identical = wordpairs_actual.equals(wordpairs_predicted)
print("Word pairs in Actual are identical to Predicted:", are_identical)

# If not identical, show the differences
differences = None
if not are_identical:
    differences = wordpairs_actual.compare(wordpairs_predicted)
    differences.columns = ['Word1 Actual', 'Word2 Actual', 'Word1 Predicted', 'Word2 Predicted']

# Show results
differences if differences is not None else print("No differences found")
# Out:
# Word pairs in Actual are identical to Predicted: False
#    Word1 Actual Word2 Actual Word1 Predicted Word2 Predicted
# 70          bad       modern          guilty         ancient
# 71       modern          new             NaN             NaN
# 72          new         dull         ancient           funny
# 73         dull        happy           funny           young
# 74        happy         easy           young             big
# 75         easy        great             big           awful
# 76        great         tiny           awful            huge
# 77         tiny       polite            huge          proper
# 78       polite       modest          proper         ashamed
# 79       modest       exotic         ashamed            rare
# 80       exotic         dumb            rare          clever
# 81         dumb   delightful          clever       wonderful
# 82   delightful   noticeable       wonderful         obvious
# 83   noticeable       afraid         obvious         anxious
# 84       afraid       formal         anxious          proper
# 85       formal       dreary          proper            dull
# 86       dreary   delightful            dull        cheerful
# 87   delightful      unhappy        cheerful             mad
# 88      unhappy          sad             mad        terrible
# 89          sad         sick        terrible           crazy
# 90         sick      violent           crazy           angry
# 91      violent        laden           angry           heavy
# 92        laden        dirty           heavy           cheap
# 93        dirty      elastic           cheap        flexible
# 94      elastic         hard        flexible           dense
# 95         hard       recent           dense             new
# 96       recent         bold             new           proud
# 97         bold          sly           proud         strange
# 98          sly      strange         strange             sly
# 99      strange          bad             sly          guilty

# %%
raw_predicted.iloc[69:100]
# raw_predicted.tail(10)
# Out:
#          word1      word2  similarity_score_1  similarity_score_2  \
# 69     illegal    immoral                 7.8                6.50
# 70      modern    ancient                 0.5                2.50
# 71         new    ancient                 1.9                1.00
# 72        dull      funny                 2.5                2.00
# 73       happy      young                 2.0                2.50
# 74        easy        big                 2.2                2.00
# 75       great      awful                 1.0                1.00
# 76        tiny       huge                 2.5                2.50
# 77      polite     proper                 6.9                7.50
# 78      modest    ashamed                 1.5                3.00
# 79      exotic       rare                 3.5                6.50
# 80        dumb     clever                 4.0                3.50
# 81  delightful  wonderful                 6.6                9.00
# 82  noticeable    obvious                 6.8                7.50
# 83      afraid    anxious                 5.8                7.50
# 84      formal     proper                 6.6                7.00
# 85      dreary       dull                 4.5                5.00
# 86  delightful   cheerful                 3.0                8.00
# 87     unhappy        mad                 1.0                2.50
# 88         sad   terrible                 1.5                2.50
# 89        sick      crazy                 3.0                2.50
# 90     violent      angry                 6.3                5.50
# 91       laden      heavy                 6.0                6.00
# 92       dirty      cheap                 1.0                6.00
# 93     elastic   flexible                 8.5                7.50
# 94        hard      dense                 5.5                6.50
# 95      recent        new                 7.7                6.00
# 96        bold      proud                 5.6                4.50
# 97         sly    strange                 6.2                7.00
# 98     strange        sly                 6.2                7.00
# 99         bad     guilty                 3.0                2.55
#
#     similarity_score_3  similarity_score_4  similarity_score_5  \
# 69                6.48                 5.5                4.77
# 70                3.74                 2.5                1.22
# 71                2.55                 1.5                0.33
# 72                2.24                 3.0                1.41
# 73                1.94                 3.0                1.15
# 74                3.87                 2.5                1.48
# 75                1.12                 3.0                1.61
# 76                7.07                 4.0                3.08
# 77                7.54                 7.0                2.65
# 78                2.55                 1.0                2.34
# 79                5.39                 6.5                4.07
# 80                2.84                 7.5                1.63
# 81                8.54                 8.0                4.88
# 82                7.00                 7.5                4.32
# 83                4.33                 4.5                2.28
# 84                7.54                 6.5                4.11
# 85                5.15                 2.0                4.64
# 86                6.20                 6.5                4.81
# 87                1.58                 1.0                1.09
# 88                2.84                 2.5                2.56
# 89                2.24                 2.5                2.99
# 90                6.32                 3.0                3.88
# 91                5.09                 6.0                3.24
# 92                2.24                 2.5                2.80
# 93                7.07                 7.0                6.14
# 94                5.09                 6.0                4.60
# 95                6.74                 6.5                4.63
# 96                2.55                 6.5                2.26
# 97                3.07                 5.5                2.85
# 98                3.07                 5.5                3.07
# 99                3.00                 2.0                4.00
#
#     similarity_score_6  similarity_score_7  similarity_score_8  \
# 69                6.00                6.04                5.13
# 70                3.50                5.28                2.55
# 71                1.00                4.60                2.75
# 72                2.50                4.13                4.33
# 73                2.50                5.18                2.60
# 74                3.50                2.45                1.40
# 75                2.50                4.65                4.27
# 76                3.00                6.08                4.78
# 77                4.50                6.52                6.59
# 78                5.00                3.73                2.00
# 79                6.50                6.41                6.53
# 80                4.00                1.91                4.35
# 81                8.00                8.38                6.57
# 82                8.00                7.03                6.65
# 83                4.50                5.67                7.40
# 84                4.50                6.07                8.25
# 85                5.00                4.26                5.27
# 86                7.00                7.12                6.68
# 87                3.00                3.72                4.55
# 88                2.50                4.53                4.33
# 89                6.00                4.24                5.20
# 90                4.00                6.17                5.40
# 91                5.50                6.52                6.45
# 92                4.50                3.54                4.55
# 93                8.50                7.77                6.95
# 94                4.00                6.29                5.27
# 95                6.00                6.14                5.13
# 96                2.50                6.32                4.55
# 97                6.00                4.58                4.35
# 98                6.00                4.58                4.35
# 99                2.76                2.10                2.00
#
#     similarity_score_9  similarity_score_10  similarity_score_11  \
# 69                6.20                 9.70                 7.00
# 70                1.38                 0.60                 2.00
# 71                1.58                 0.60                 1.00
# 72                3.69                 1.00                 2.75
# 73                2.77                 2.00                 2.50
# 74                3.14                 1.50                 1.00
# 75                4.69                 4.00                 2.50
# 76                5.87                 8.00                 6.50
# 77                4.12                 9.20                 4.50
# 78                4.12                 0.10                 3.00
# 79                6.60                 8.80                 5.00
# 80                3.14                 0.33                 5.00
# 81                8.60                 8.20                 7.00
# 82                7.47                 8.80                 7.50
# 83                7.87                 8.60                 7.50
# 84                6.40                 7.20                 6.50
# 85                5.20                 8.00                 3.00
# 86                5.47                 8.20                 6.50
# 87                5.20                 0.20                 2.50
# 88                2.85                 0.20                 1.75
# 89                5.47                 0.40                 6.00
# 90                7.27                 8.60                 4.50
# 91                5.07                 3.00                 6.50
# 92                3.38                 3.00                 3.00
# 93                8.07                 9.20                 7.25
# 94                6.40                 9.40                 6.00
# 95                6.87                 9.40                 5.00
# 96                5.20                 8.40                 3.00
# 97                5.07                 8.00                 3.50
# 98                5.07                 8.00                 3.50
# 99                0.58                 1.00                 0.00
#
#     similarity_score_12  similarity_score_13  similarity_score_14  \
# 69                 1.00                 7.00                 4.80
# 70                 1.00                 1.00                 2.11
# 71                 1.00                 1.00                 1.71
# 72                 1.00                 2.00                 2.00
# 73                 1.00                 1.00                 1.00
# 74                 1.00                 2.00                 2.00
# 75                 1.00                 1.00                 2.86
# 76                 1.00                 6.00                 2.71
# 77                 1.00                 8.00                 3.29
# 78                 1.00                 2.00                 3.00
# 79                 1.00                 6.00                 5.00
# 80                 1.00                 2.00                 2.00
# 81                 1.00                 9.00                 6.80
# 82                 1.00                 9.00                 5.71
# 83                 1.75                 7.00                 4.86
# 84                 1.00                 8.00                 3.46
# 85                 1.00                 2.00                 2.00
# 86                 1.00                 6.00                 4.29
# 87                 1.00                 1.00                 2.29
# 88                 1.00                 1.00                 2.00
# 89                 1.00                 4.00                 4.33
# 90                 1.00                 8.00                 6.14
# 91                 1.00                 5.00                 4.67
# 92                 1.00                 1.00                 1.50
# 93                 1.00                10.00                 6.00
# 94                 1.00                 5.00                 3.00
# 95                 1.00                 5.00                 6.57
# 96                 1.00                 5.00                 2.57
# 97                 1.70                 4.00                 3.86
# 98                 1.70                 4.00                 3.86
# 99                 0.93                 3.21                 2.60
#
#     similarity_score_15
# 69                 4.29
# 70                 1.50
# 71                 1.50
# 72                 1.50
# 73                 1.50
# 74                 2.00
# 75                 1.64
# 76                 5.57
# 77                 6.43
# 78                 4.00
# 79                 6.57
# 80                 6.00
# 81                 8.86
# 82                 8.29
# 83                 6.14
# 84                 6.14
# 85                 5.50
# 86                 7.71
# 87                 1.86
# 88                 2.93
# 89                 2.93
# 90                 8.00
# 91                 5.14
# 92                 4.36
# 93                 7.29
# 94                 6.43
# 95                 6.57
# 96                 4.36
# 97                 7.86
# 98                 7.86
# 99                 2.83

# %%
raw_actual.iloc[69:100]
# raw_actual.tail(10)
# Out:
#          word1      word2  SimLex999  std_dev POS
# 69     illegal    immoral       4.28     1.57   A
# 70         bad     guilty       4.20     1.47   A
# 71      modern    ancient       0.73     0.71   A
# 72         new    ancient       0.23     0.46   A
# 73        dull      funny       0.55     1.76   A
# 74       happy      young       2.00     0.47   A
# 75        easy        big       1.12     1.22   A
# 76       great      awful       1.17     1.53   A
# 77        tiny       huge       0.60     0.59   A
# 78      polite     proper       7.63     1.42   A
# 79      modest    ashamed       2.65     1.00   A
# 80      exotic       rare       8.05     0.93   A
# 81        dumb     clever       1.17     1.30   A
# 82  delightful  wonderful       8.65     1.29   A
# 83  noticeable    obvious       8.48     1.69   A
# 84      afraid    anxious       5.07     1.28   A
# 85      formal     proper       8.02     1.31   A
# 86      dreary       dull       8.25     1.85   A
# 87  delightful   cheerful       6.58     1.56   A
# 88     unhappy        mad       5.95     1.36   A
# 89         sad   terrible       5.40     0.44   A
# 90        sick      crazy       3.57     0.95   A
# 91     violent      angry       6.98     1.55   A
# 92       laden      heavy       5.90     1.28   A
# 93       dirty      cheap       1.60     1.10   A
# 94     elastic   flexible       7.78     1.09   A
# 95        hard      dense       5.90     1.00   A
# 96      recent        new       7.05     1.05   A
# 97        bold      proud       3.97     1.36   A
# 98         sly    strange       1.97     1.07   A
# 99     strange        sly       2.07     0.51   A

# %%
# Define index
row_to_move = 99
new_position = 70 

# Extract the row to move
row = raw_predicted.iloc[row_to_move].copy()

# Drop the row to move
raw_predicted = raw_predicted.drop(index=row_to_move).reset_index(drop=True)

# Insert the row at the new position
raw_predicted = pd.concat([raw_predicted.iloc[:new_position], pd.DataFrame([row]), raw_predicted.iloc[new_position:]]).reset_index(drop=True)

# Show results
raw_predicted.iloc[69:100]
# Out:
#          word1      word2  similarity_score_1  similarity_score_2  \
# 69     illegal    immoral                 7.8                6.50
# 70         bad     guilty                 3.0                2.55
# 71      modern    ancient                 0.5                2.50
# 72         new    ancient                 1.9                1.00
# 73        dull      funny                 2.5                2.00
# 74       happy      young                 2.0                2.50
# 75        easy        big                 2.2                2.00
# 76       great      awful                 1.0                1.00
# 77        tiny       huge                 2.5                2.50
# 78      polite     proper                 6.9                7.50
# 79      modest    ashamed                 1.5                3.00
# 80      exotic       rare                 3.5                6.50
# 81        dumb     clever                 4.0                3.50
# 82  delightful  wonderful                 6.6                9.00
# 83  noticeable    obvious                 6.8                7.50
# 84      afraid    anxious                 5.8                7.50
# 85      formal     proper                 6.6                7.00
# 86      dreary       dull                 4.5                5.00
# 87  delightful   cheerful                 3.0                8.00
# 88     unhappy        mad                 1.0                2.50
# 89         sad   terrible                 1.5                2.50
# 90        sick      crazy                 3.0                2.50
# 91     violent      angry                 6.3                5.50
# 92       laden      heavy                 6.0                6.00
# 93       dirty      cheap                 1.0                6.00
# 94     elastic   flexible                 8.5                7.50
# 95        hard      dense                 5.5                6.50
# 96      recent        new                 7.7                6.00
# 97        bold      proud                 5.6                4.50
# 98         sly    strange                 6.2                7.00
# 99     strange        sly                 6.2                7.00
#
#     similarity_score_3  similarity_score_4  similarity_score_5  \
# 69                6.48                 5.5                4.77
# 70                3.00                 2.0                4.00
# 71                3.74                 2.5                1.22
# 72                2.55                 1.5                0.33
# 73                2.24                 3.0                1.41
# 74                1.94                 3.0                1.15
# 75                3.87                 2.5                1.48
# 76                1.12                 3.0                1.61
# 77                7.07                 4.0                3.08
# 78                7.54                 7.0                2.65
# 79                2.55                 1.0                2.34
# 80                5.39                 6.5                4.07
# 81                2.84                 7.5                1.63
# 82                8.54                 8.0                4.88
# 83                7.00                 7.5                4.32
# 84                4.33                 4.5                2.28
# 85                7.54                 6.5                4.11
# 86                5.15                 2.0                4.64
# 87                6.20                 6.5                4.81
# 88                1.58                 1.0                1.09
# 89                2.84                 2.5                2.56
# 90                2.24                 2.5                2.99
# 91                6.32                 3.0                3.88
# 92                5.09                 6.0                3.24
# 93                2.24                 2.5                2.80
# 94                7.07                 7.0                6.14
# 95                5.09                 6.0                4.60
# 96                6.74                 6.5                4.63
# 97                2.55                 6.5                2.26
# 98                3.07                 5.5                2.85
# 99                3.07                 5.5                3.07
#
#     similarity_score_6  similarity_score_7  similarity_score_8  \
# 69                6.00                6.04                5.13
# 70                2.76                2.10                2.00
# 71                3.50                5.28                2.55
# 72                1.00                4.60                2.75
# 73                2.50                4.13                4.33
# 74                2.50                5.18                2.60
# 75                3.50                2.45                1.40
# 76                2.50                4.65                4.27
# 77                3.00                6.08                4.78
# 78                4.50                6.52                6.59
# 79                5.00                3.73                2.00
# 80                6.50                6.41                6.53
# 81                4.00                1.91                4.35
# 82                8.00                8.38                6.57
# 83                8.00                7.03                6.65
# 84                4.50                5.67                7.40
# 85                4.50                6.07                8.25
# 86                5.00                4.26                5.27
# 87                7.00                7.12                6.68
# 88                3.00                3.72                4.55
# 89                2.50                4.53                4.33
# 90                6.00                4.24                5.20
# 91                4.00                6.17                5.40
# 92                5.50                6.52                6.45
# 93                4.50                3.54                4.55
# 94                8.50                7.77                6.95
# 95                4.00                6.29                5.27
# 96                6.00                6.14                5.13
# 97                2.50                6.32                4.55
# 98                6.00                4.58                4.35
# 99                6.00                4.58                4.35
#
#     similarity_score_9  similarity_score_10  similarity_score_11  \
# 69                6.20                 9.70                 7.00
# 70                0.58                 1.00                 0.00
# 71                1.38                 0.60                 2.00
# 72                1.58                 0.60                 1.00
# 73                3.69                 1.00                 2.75
# 74                2.77                 2.00                 2.50
# 75                3.14                 1.50                 1.00
# 76                4.69                 4.00                 2.50
# 77                5.87                 8.00                 6.50
# 78                4.12                 9.20                 4.50
# 79                4.12                 0.10                 3.00
# 80                6.60                 8.80                 5.00
# 81                3.14                 0.33                 5.00
# 82                8.60                 8.20                 7.00
# 83                7.47                 8.80                 7.50
# 84                7.87                 8.60                 7.50
# 85                6.40                 7.20                 6.50
# 86                5.20                 8.00                 3.00
# 87                5.47                 8.20                 6.50
# 88                5.20                 0.20                 2.50
# 89                2.85                 0.20                 1.75
# 90                5.47                 0.40                 6.00
# 91                7.27                 8.60                 4.50
# 92                5.07                 3.00                 6.50
# 93                3.38                 3.00                 3.00
# 94                8.07                 9.20                 7.25
# 95                6.40                 9.40                 6.00
# 96                6.87                 9.40                 5.00
# 97                5.20                 8.40                 3.00
# 98                5.07                 8.00                 3.50
# 99                5.07                 8.00                 3.50
#
#     similarity_score_12  similarity_score_13  similarity_score_14  \
# 69                 1.00                 7.00                 4.80
# 70                 0.93                 3.21                 2.60
# 71                 1.00                 1.00                 2.11
# 72                 1.00                 1.00                 1.71
# 73                 1.00                 2.00                 2.00
# 74                 1.00                 1.00                 1.00
# 75                 1.00                 2.00                 2.00
# 76                 1.00                 1.00                 2.86
# 77                 1.00                 6.00                 2.71
# 78                 1.00                 8.00                 3.29
# 79                 1.00                 2.00                 3.00
# 80                 1.00                 6.00                 5.00
# 81                 1.00                 2.00                 2.00
# 82                 1.00                 9.00                 6.80
# 83                 1.00                 9.00                 5.71
# 84                 1.75                 7.00                 4.86
# 85                 1.00                 8.00                 3.46
# 86                 1.00                 2.00                 2.00
# 87                 1.00                 6.00                 4.29
# 88                 1.00                 1.00                 2.29
# 89                 1.00                 1.00                 2.00
# 90                 1.00                 4.00                 4.33
# 91                 1.00                 8.00                 6.14
# 92                 1.00                 5.00                 4.67
# 93                 1.00                 1.00                 1.50
# 94                 1.00                10.00                 6.00
# 95                 1.00                 5.00                 3.00
# 96                 1.00                 5.00                 6.57
# 97                 1.00                 5.00                 2.57
# 98                 1.70                 4.00                 3.86
# 99                 1.70                 4.00                 3.86
#
#     similarity_score_15
# 69                 4.29
# 70                 2.83
# 71                 1.50
# 72                 1.50
# 73                 1.50
# 74                 1.50
# 75                 2.00
# 76                 1.64
# 77                 5.57
# 78                 6.43
# 79                 4.00
# 80                 6.57
# 81                 6.00
# 82                 8.86
# 83                 8.29
# 84                 6.14
# 85                 6.14
# 86                 5.50
# 87                 7.71
# 88                 1.86
# 89                 2.93
# 90                 2.93
# 91                 8.00
# 92                 5.14
# 93                 4.36
# 94                 7.29
# 95                 6.43
# 96                 6.57
# 97                 4.36
# 98                 7.86
# 99                 7.86

# %%
# Select word pairs and copy
wordpairs_predicted = raw_predicted[['word1', 'word2']].copy()
wordpairs_actual = raw_actual[['word1', 'word2']].copy()

# Remove whitespace
wordpairs_actual['word1'] = wordpairs_actual['word1'].replace(" ", "", regex=True)
wordpairs_actual['word2'] = wordpairs_actual['word2'].replace(" ", "", regex=True)

# Check if actual is identical to predicted
are_identical = wordpairs_actual.equals(wordpairs_predicted)
print("Word pairs in Actual are identical to Predicted:", are_identical)

# If not identical, show the differences
differences = None
if not are_identical:
    differences = wordpairs_actual.compare(wordpairs_predicted)
    differences.columns = ['Word1 Actual', 'Word2 Actual', 'Word1 Predicted', 'Word2 Predicted']

# Show results
differences if differences is not None else print("No differences found")
# Out:
# Word pairs in Actual are identical to Predicted: True
# No differences found

# %% [markdown]
# ### **2. Data Processing**

# %%
# Copy dataframe
predicted = raw_predicted.copy()

# List of columns to calculate mean SimLex-999
similarity_cols = [f"similarity_score_{i}" for i in range(1, 16)]

# Calculate the mean SimLex-999
predicted['pred_sl'] = predicted[similarity_cols].mean(axis=1).round(2)

# Calculate the standard deviation SimLex-999
predicted['pred_sd'] = predicted[similarity_cols].std(axis=1).round(2)

# Select columns
predicted = predicted[['word1', 'word2', 'pred_sl', 'pred_sd']]

# Show results
predicted
# Out:
#       word1     word2  pred_sl  pred_sd
# 0     happy  cheerful     8.64     1.08
# 1      hard      easy     3.12     1.64
# 2      fast     rapid     9.33     0.48
# 3     happy      glad     8.42     0.63
# 4     short      long     7.08     2.15
# ..      ...       ...      ...      ...
# 991    join   acquire     4.60     1.77
# 992    send    attend     3.45     1.68
# 993  gather    attend     3.75     1.78
# 994  absorb  withdraw     2.61     1.29
# 995  attend    arrive     4.21     2.04
#
# [996 rows x 4 columns]

# %%
# Copy dataframe
actual = raw_actual.copy()

# Rename columns
actual = actual.rename(columns={'SimLex999': 'act_sl', 'std_dev': 'act_sd'})

# Select columns
actual = actual[['word1', 'word2', 'act_sl', 'act_sd']]

# Show results
actual
# Out:
#       word1     word2  act_sl  act_sd
# 0     happy  cheerful    9.55    2.18
# 1      hard      easy    0.95    0.93
# 2      fast     rapid    8.75    1.68
# 3     happy      glad    9.17    1.59
# 4     short      long    1.23    1.58
# ..      ...       ...     ...     ...
# 991    join   acquire    2.85    0.99
# 992    send    attend    1.67    1.44
# 993  gather    attend    4.80    1.97
# 994  absorb  withdraw    2.97    1.75
# 995  attend    arrive    6.08    1.18
#
# [996 rows x 4 columns]

# %%
# Merge predicted and actual DataFrames
merged = pd.merge(predicted, actual, on=['word1', 'word2'])

# Show results
merged
# Out:
#       word1     word2  pred_sl  pred_sd  act_sl  act_sd
# 0     happy  cheerful     8.64     1.08    9.55    2.18
# 1      hard      easy     3.12     1.64    0.95    0.93
# 2      fast     rapid     9.33     0.48    8.75    1.68
# 3     happy      glad     8.42     0.63    9.17    1.59
# 4     short      long     7.08     2.15    1.23    1.58
# ..      ...       ...      ...      ...     ...     ...
# 991    join   acquire     4.60     1.77    2.85    0.99
# 992    send    attend     3.45     1.68    1.67    1.44
# 993  gather    attend     3.75     1.78    4.80    1.97
# 994  absorb  withdraw     2.61     1.29    2.97    1.75
# 995  attend    arrive     4.21     2.04    6.08    1.18
#
# [996 rows x 6 columns]

# %% [markdown]
# ### **3. Descriptive Statistics**

# %%
# Summary statistics SimLex-999
pred_sl_summary = round(predicted['pred_sl'].describe(), 2)
act_sl_summary = round(actual['act_sl'].describe(), 2)

# Add median SimLex-999
pred_sl_summary['median'] = round(predicted['pred_sl'].median(), 2)
act_sl_summary['median'] = round(actual['act_sl'].median(), 2)

# Summary statistics standard deviations
pred_sd_summary = round(predicted['pred_sd'].describe(), 2)
act_sd_summary = round(actual['act_sd'].describe(), 2)

# Add median standard deviation
pred_sd_summary['median'] = round(predicted['pred_sd'].median(), 2)
act_sd_summary['median'] = round(actual['act_sd'].median(), 2)

# Create pandas DataFrame
summary_df = pd.DataFrame({
    "pred_sl": pred_sl_summary,
    "act_sl": act_sl_summary,
    "pred_sd": pred_sd_summary,
    "act_sd": act_sd_summary
})

# Show results
summary_df
# Out:
#         pred_sl  act_sl  pred_sd  act_sd
# count    996.00  996.00   996.00  996.00
# mean       4.77    4.56     1.44    1.28
# std        2.12    2.61     0.59    0.37
# min        0.01    0.23     0.04    0.34
# 25%        3.14    2.38     1.06    1.08
# 50%        4.81    4.66     1.43    1.32
# 75%        6.47    6.74     1.76    1.54
# max        9.42    9.80     3.43    2.18
# median     4.81    4.66     1.43    1.31

# %% [markdown]
# #### **3.1. SimLex-999**

# %%
# Rename columns and copy
renamed_pred_sl = predicted.rename(columns={"pred_sl": "SimLex-999"}).copy()
renamed_act_sl = actual.rename(columns={"act_sl": "SimLex-999"}).copy()

# Create dummy label
renamed_pred_sl['Score'] = 'Predicted'
renamed_act_sl['Score'] = 'Actual'

# Combine DataFrames
combined_data = pd.concat([renamed_pred_sl, renamed_act_sl])

# Create boxplot
plt.figure(figsize=(6, 6))
sns.boxplot(
    x='Score',
    y='SimLex-999',
    data=combined_data,
    palette=['skyblue', 'lightgreen'],
    boxprops={'edgecolor': 'black'},
    whiskerprops={'color': 'black'},
    flierprops={'marker': 'o', 'color': 'black', 'markerfacecolor': 'black'},
    capprops={'color': 'black'},
    medianprops={'color': 'black'}
)

# Set labels and title
plt.ylabel('SimLex-999')
# plt.title('Comparison of SimLex-999')

# Customize y-axis ticks
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(integer=True))
plt.ylim(0, 10)  # Setting y-axis limits from 0 to 10

# Remove x-axis label
plt.xlabel('')

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# #### **3.2. Standard Deviation**

# %%
# Rename columns and copy
renamed_predicted_sd = predicted.rename(columns={"pred_sd": "Standard Deviation"}).copy()
renamed_actual_sd = actual.rename(columns={"act_sd": "Standard Deviation"}).copy()

# Create dummy label
renamed_predicted_sd['Score'] = 'Predicted'
renamed_actual_sd['Score'] = 'Actual'

# Combine DataFrames
combined_data = pd.concat([renamed_predicted_sd, renamed_actual_sd])

# Create boxplot
plt.figure(figsize=(6, 6))
sns.boxplot(
    x='Score',
    y='Standard Deviation',
    data=combined_data,
    palette=['skyblue', 'lightgreen'],
    boxprops={'edgecolor': 'black'},
    whiskerprops={'color': 'black'},
    flierprops={'marker': 'o', 'color': 'black', 'markerfacecolor': 'black'},
    capprops={'color': 'black'},
    medianprops={'color': 'black'}
)

# Set labels and title
plt.ylabel('Standard Deviation')
# plt.title('Comparison of Standard Deviation')

# Customizing y-axis ticks
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(integer=True))
plt.ylim(0, 5)  # Setting y-axis limits from 0 to 5

# Remove x-axis label
plt.xlabel('')

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# ### **4. Distributions**

# %% [markdown]
# #### **4.1. SimLex-999**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 10

# Define bins
bins = 10

# Plot predicted histogram
axes[0].hist(renamed_pred_sl['SimLex-999'], bins=bins, edgecolor='black', color='skyblue')
axes[0].set_title('Predicted')
axes[0].set_xlabel('SimLex-999')
axes[0].set_ylabel('Frequency')
axes[0].set_xlim(x_min, x_max)
axes[0].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[0].grid(False) # Remove grid

# Plot actual histogram
axes[1].hist(renamed_act_sl['SimLex-999'], bins=bins, edgecolor='black', color='lightgreen')
axes[1].set_title('Actual')
axes[1].set_xlabel('SimLex-999')
axes[1].set_ylabel('Frequency')
axes[1].set_xlim(x_min, x_max)
axes[1].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[1].grid(False) # Remove grid

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# #### **4.2. Standard Deviation**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 5

# Define bins
bins = 5

# Plot predicted histogram
axes[0].hist(renamed_predicted_sd['Standard Deviation'], bins=bins, edgecolor='black', color='skyblue')
axes[0].set_title('Predicted')
axes[0].set_xlabel('Standard Deviation')
axes[0].set_ylabel('Frequency')
axes[0].set_xlim(x_min, x_max)
axes[0].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[0].grid(False) # Remove grid

# Plot actual histogram
axes[1].hist(renamed_actual_sd['Standard Deviation'], bins=bins, edgecolor='black', color='lightgreen')
axes[1].set_title('Actual')
axes[1].set_xlabel('Standard Deviation')
axes[1].set_ylabel('Frequency')
axes[1].set_xlim(x_min, x_max)
axes[1].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[1].grid(False) # Remove grid

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# ### **5. Outliers**

# %% [markdown]
# #### **5.1. Predicted**

# %%
# Count outliers
print_outlier_counts(predicted)
# Out:
# Outliers in pred_sd: 34
# No outliers found in columns: pred_sl

# %%
# Row outliers
print_outlier_data(predicted, 'pred_sd')
# Out:
# Outliers in pred_sd:
#           word1       word2  pred_sl  pred_sd
# 108        wife     husband     6.83     3.08
# 110       groom       bride     6.08     3.43
# 112       south       north     6.68     2.95
# 114       uncle        aunt     7.12     3.04
# 115       horse        mare     5.67     2.93
# 116      bottom         top     7.11     3.01
# 117      friend       buddy     7.44     2.95
# 118     student       pupil     7.27     2.96
# 122       woman         man     7.61     3.04
# 124     actress       actor     7.82     3.05
# 125     teacher  instructor     6.77     2.85
# 126       movie        film     7.05     2.98
# 135      sunset     sunrise     5.99     3.02
# 137         cow      cattle     5.90     2.82
# 144     disease   infection     4.67     2.83
# 147        lady   gentleman     6.84     3.33
# 149      priest        monk     6.15     2.96
# 611  politician   president     5.64     2.85
# 651       proof        fact     6.03     3.03
# 776      listen        hear     6.42     2.97
# 778       occur      happen     7.23     2.99
# 779      vanish   disappear     8.14     3.20
# 781       plead         beg     6.88     3.04
# 783     protect      defend     7.41     2.99
# 784        kill     destroy     6.20     3.21
# 786      accept      reject     5.06     3.41
# 787      ignore       avoid     6.49     2.82
# 789       leave       enter     4.65     2.88
# 790      choose       elect     6.78     2.82
# 792   encourage  discourage     6.78     2.85
# 793     achieve  accomplish     7.59     3.00
# 796      inform      notify     6.95     2.99
# 797     receive        give     5.30     3.02
# 798      borrow         beg     5.52     3.21

# %% [markdown]
# #### **5.2. Actual**

# %%
# Count outliers
print_outlier_counts(actual)
# Out:
# Outliers in act_sd: 13
# No outliers found in columns: act_sl

# %%
# Row outliers
print_outlier_data(actual, 'act_sd')
# Out:
# Outliers in act_sd:
#            word1      word2  act_sl  act_sd
# 9           easy  difficult    0.58    0.36
# 173          rod    curtain    3.03    0.39
# 186        motel        inn    8.17    0.39
# 280         mink        fur    6.83    0.39
# 328        beach     island    5.60    0.39
# 360          oak      maple    6.03    0.39
# 492         door      floor    1.67    0.39
# 526      drizzle       rain    9.17    0.39
# 527        adult       baby    2.22    0.39
# 536  frustration      anger    6.50    0.39
# 537        river        sea    5.72    0.39
# 724         task      woman    0.68    0.34
# 981    cooperate       join    5.18    0.36

# %% [markdown]
# #### **5.3. Add to Summary**

# %%
# Calculate outliers
outliers_pred_sl = calculate_outliers(predicted, 'pred_sl')
outliers_pred_sd = calculate_outliers(predicted, 'pred_sd')
outliers_act_sl = calculate_outliers(actual, 'act_sl')
outliers_act_sd = calculate_outliers(actual, 'act_sd')

# Count outliers
count_outliers_pred_sl = outliers_pred_sl.shape[0]
count_outliers_pred_sd = outliers_pred_sd.shape[0]
count_outliers_act_sl = outliers_act_sl.shape[0]
count_outliers_act_sd = outliers_act_sd.shape[0]

# Add outliers count to summary
outliers_row = pd.Series([count_outliers_pred_sl, count_outliers_act_sl, count_outliers_pred_sd, count_outliers_act_sd], 
    index=summary_df.columns,
    name='outliers'
)
summary_df = pd.concat([summary_df, outliers_row.to_frame().T])

# Show results
summary_df
# Out:
#           pred_sl  act_sl  pred_sd  act_sd
# count      996.00  996.00   996.00  996.00
# mean         4.77    4.56     1.44    1.28
# std          2.12    2.61     0.59    0.37
# min          0.01    0.23     0.04    0.34
# 25%          3.14    2.38     1.06    1.08
# 50%          4.81    4.66     1.43    1.32
# 75%          6.47    6.74     1.76    1.54
# max          9.42    9.80     3.43    2.18
# median       4.81    4.66     1.43    1.31
# outliers     0.00    0.00    34.00   13.00

# %% [markdown]
# ### **6. Correlation**

# %% [markdown]
# #### **6.1. SimLex-999 vs Standard Deviation**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 10
y_min = 0
y_max = 5

# Create scatter plot
sns.scatterplot(x='pred_sl', y='pred_sd', data=predicted, ax=axes[0], color='skyblue', edgecolor='black')

# Plot diagonal line
axes[0].plot([x_min, x_max], [y_min, y_max], color='red', linestyle='--')

# Set axis limits
axes[0].set_xlim(x_min, x_max)
axes[0].set_ylim(y_min, y_max)

# Set labels and title
axes[0].set_xlabel('SimLex-999')
axes[0].set_ylabel('Standard Deviation')
axes[0].set_title('Predicted')

# Remove grid
axes[0].grid(False)

# Create scatter plot
sns.scatterplot(x='act_sl', y='act_sd', data=actual, ax=axes[1], color='lightgreen', edgecolor='black')

# Plot diagonal line
axes[1].plot([x_min, x_max], [y_min, y_max], color='red', linestyle='--')

# Set axis limits
axes[1].set_xlim(x_min, x_max)
axes[1].set_ylim(y_min, y_max)

# Set labels and title
axes[1].set_xlabel('SimLex-999')
axes[1].set_ylabel('Standard Deviation')
axes[1].set_title('Actual')

# Remove grid
axes[1].grid(False)

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %%
# List to store correlations
correlations_list = []

# Append correlations to list
correlations_list.append(calculate_correlation_and_pvalue(merged, 'pred_sl', 'pred_sd'))
correlations_list.append(calculate_correlation_and_pvalue(merged, 'act_sl', 'act_sd'))

# Convert list into Pandas DataFrame
correlation_df = pd.DataFrame(correlations_list)

# Show results
correlation_df
# Out:
#   simlex999 standard_deviation  correlation   p_value     significance
# 0   pred_sl            pred_sd     -0.05042  0.111781  not significant
# 1    act_sl             act_sd     -0.04759  0.133376  not significant

# %% [markdown]
# ### **7. Evaluation Metrics**

# %% [markdown]
# #### **7.1. Spearmans's Rank Correlation**

# %% [markdown]
# ##### **7.1.1. Actual SimLex-999 vs Predicted SimLex-999**

# %%
# Scatter plot
plot_scatter_plot(merged, 'pred_sl', 'act_sl', 'Predicted SimLex-999', 'Actual SimLex-999', 0, 10, 0, 10)

# %%
# Correlation and pvalue
print_correlation_and_pvalue(merged, 'pred_sl', 'act_sl')
# Out:
# Spearman's Rank correlation: 0.57393
# P-value: 2.5013804699216474e-88
# The correlation is statistically significant.

# %% [markdown]
# ##### **7.1.2. Actual Standard Deviation vs Predicted Standard Deviation**

# %%
# Scatter plot
plot_scatter_plot(merged, 'pred_sd', 'act_sd', 'Predicted Standard Deviation', 'Actual Standard Deviation', 0, 5, 0, 3)

# %%
# Correlation and p-value
print_correlation_and_pvalue(merged, 'pred_sd', 'act_sd')
# Out:
# Spearman's Rank correlation: -0.02938
# P-value: 0.35425800129030127
# The correlation is not statistically significant.

# %% [markdown]
# #### **7.2. Mean Square Error (MSE)**

# %%
# Calculate Mean Squared Error
mse = mean_squared_error(merged['pred_sl'], merged['act_sl'])

# Show results
print(f"Mean Squared Error (MSE): {mse:.2f}")
# Out:
# Mean Squared Error (MSE): 4.85

# %% [markdown]
# #### **7.3. Mean Absolute Error (MAE)**

# %%
# Calculate Mean Absolute Error
mae = mean_absolute_error(merged['pred_sl'], merged['act_sl'])

# Show results
print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
# Mean Absolute Error (MAE): 1.74
