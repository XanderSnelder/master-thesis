# %% [markdown]
# ### **0. Set-up**

# %%
# Import libraries and utils
# %run '../../../utils.ipynb'

# %%
# Load NL predicted
raw_nl_pred = pd.read_csv("../../../../data/gpt-3.5-turbo-0125/processed/nl/f8.csv")

# %%
# Load EN predicted
raw_en_pred = pd.read_csv("../../../../data/gpt-3.5-turbo-0125/processed/en/f8.csv")

# Drop rows in EN SimLex that are missing in NL SimLex
raw_en_pred = raw_en_pred.drop(raw_en_pred[(raw_en_pred['word1'] == 'bad') & (raw_en_pred['word2'] == 'awful')].index)
raw_en_pred = raw_en_pred.drop(raw_en_pred[(raw_en_pred['word1'] == 'bad') & (raw_en_pred['word2'] == 'terrible')].index)

# Reset index
raw_en_pred = raw_en_pred.reset_index(drop=True)

# %%
# Select first 25 word pairs
raw_nl_pred = raw_nl_pred.head(25)
raw_en_pred = raw_en_pred.head(25)

# %%
# Show results
raw_nl_pred
# Out:
#           word1        word2  similarity_score_1  similarity_score_2  \
# 0      gelukkig      vrolijk                7.69                7.94
# 1          hard        stoer                4.31                6.04
# 2          snel   razendsnel                8.77                8.30
# 3      gelukkig         blij                6.62                7.43
# 4          kort         lang                2.31                4.32
# 5           dom         stom                6.46                3.56
# 6        vreemd  eigenaardig                8.77                8.14
# 7         breed         smal                1.15                4.73
# 8     makkelijk     moeilijk                1.46                2.96
# 9      moeilijk  gemakkelijk                7.15                5.31
# 10         slim          dom                2.54                2.88
# 11  krankzinnig          gek                9.23                8.47
# 12     gelukkig        kwaad                3.38                2.71
# 13   uitgebreid        groot                5.00                7.85
# 14     moeilijk       simpel                6.62                5.04
# 15        nieuw         vers                3.08                4.24
# 16       scherp         saai                3.46                1.96
# 17         vlug         snel                9.23                7.95
# 18          dom        dwaas                7.31                6.28
# 19     prachtig  fantastisch                8.08                8.20
# 20  eigenaardig       vreemd                8.77                8.15
# 21     gelukkig         boos                3.85                2.97
# 22         smal        breed                1.15                5.05
# 23    eenvoudig  gemakkelijk                9.23                7.11
# 24          oud         vers                3.08                3.45
#
#     similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                 6.78                7.69                6.88
# 1                 5.30                5.08                5.43
# 2                 7.93                9.84                9.42
# 3                 7.81                6.73                8.43
# 4                 4.98                5.22                2.38
# 5                 7.08                6.77                5.84
# 6                 7.99                7.99                9.41
# 7                 4.26                5.36                3.52
# 8                 3.33                3.73                3.14
# 9                 6.33                5.16                8.07
# 10                3.56                2.70                1.91
# 11                8.27                8.69                8.36
# 12                2.18                3.22                1.62
# 13                5.47                7.89                6.69
# 14                5.22                5.63                6.46
# 15                5.75                3.57                6.94
# 16                3.88                2.15                1.21
# 17                8.32                8.84                7.26
# 18                7.67                7.21                6.76
# 19                8.63                7.65                9.39
# 20                7.99                8.73                9.41
# 21                3.10                2.69                1.23
# 22                4.26                5.36                3.52
# 23                7.13                7.24                7.82
# 24                2.27                3.19                2.50
#
#     similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                 7.14                7.48                6.87
# 1                 6.00                6.05                3.75
# 2                 9.00                8.84                8.50
# 3                 7.14                8.02                6.07
# 4                 3.13                4.47                3.80
# 5                 7.50                5.16                4.67
# 6                 8.75                8.08                8.04
# 7                 1.88                3.71                3.75
# 8                 2.38                2.64                3.65
# 9                 6.25                3.82                8.15
# 10                2.75                3.10                3.45
# 11                9.00                8.59                7.80
# 12                1.25                3.39                2.88
# 13                6.00                7.26                3.86
# 14                3.63                2.61                6.03
# 15                5.63                7.10                3.32
# 16                2.75                3.71                1.91
# 17                8.75                8.08                8.84
# 18                6.50                6.28                7.92
# 19                8.25                9.42                8.54
# 20                8.75                8.08                9.44
# 21                2.38                3.26                3.05
# 22                2.50                4.84                3.75
# 23                8.13                7.06                6.50
# 24                2.63                4.05                3.32
#
#     similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                 8.25                 8.27                 7.56
# 1                 4.04                 7.36                 6.38
# 2                 9.52                 9.09                 8.24
# 3                 8.68                 7.64                 7.16
# 4                 2.08                 4.09                 0.24
# 5                 5.16                 6.73                 6.88
# 6                 8.25                 9.09                 8.93
# 7                 2.08                 2.64                 2.93
# 8                 4.95                 3.00                 2.91
# 9                 4.95                 5.18                 6.07
# 10                3.10                 2.73                 5.28
# 11                8.95                 8.73                 9.44
# 12                2.60                 2.64                 2.81
# 13                6.84                 6.64                 2.83
# 14                4.67                 3.82                 5.51
# 15                4.52                 4.82                 2.02
# 16                2.08                 2.00                 1.86
# 17                7.04                 7.73                 8.29
# 18                5.16                 8.00                 6.47
# 19                7.94                 8.91                 7.93
# 20                8.25                 9.82                 9.44
# 21                2.60                 2.45                 1.87
# 22                2.08                 2.45                 2.93
# 23                7.46                 8.91                 7.52
# 24                3.98                 2.91                 1.90
#
#     similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                  7.84                 5.81                 5.78
# 1                  6.12                 4.23                 5.04
# 2                  8.82                 8.93                 8.42
# 3                  6.76                 8.68                 7.73
# 4                  5.18                 5.72                 3.00
# 5                  6.53                 6.64                 5.00
# 6                  9.16                 9.38                 9.35
# 7                  6.47                 4.73                 1.10
# 8                  4.08                 2.50                 3.00
# 9                  4.08                 4.82                 4.28
# 10                 2.03                 2.95                 2.96
# 11                 8.48                 9.35                 9.89
# 12                 4.02                 2.33                 1.64
# 13                 6.35                 5.33                 6.25
# 14                 7.07                 4.36                 3.60
# 15                 4.73                 3.65                 4.23
# 16                 2.57                 2.45                 1.56
# 17                 8.35                 7.84                 6.48
# 18                 8.24                 6.06                 3.50
# 19                 8.46                 9.11                 8.17
# 20                 9.16                 9.38                 9.86
# 21                 3.96                 1.93                 1.98
# 22                 6.47                 4.73                 1.10
# 23                 7.95                 8.60                 7.48
# 24                 2.36                 1.72                 2.01
#
#     similarity_score_15
# 0                   7.5
# 1                   7.5
# 2                   9.5
# 3                   8.5
# 4                   4.0
# 5                   7.5
# 6                   9.0
# 7                   2.0
# 8                   1.5
# 9                   6.5
# 10                  3.0
# 11                  9.5
# 12                  1.5
# 13                  6.5
# 14                  6.0
# 15                  7.0
# 16                  2.5
# 17                  9.0
# 18                  7.0
# 19                  9.0
# 20                 10.0
# 21                  2.0
# 22                  2.0
# 23                  8.0
# 24                  4.0

# %%
# Show results
raw_en_pred
# Out:
#         word1      word2  similarity_score_1  similarity_score_2  \
# 0       happy   cheerful                8.75                9.20
# 1        hard       easy                4.10                1.73
# 2        fast      rapid                9.50                9.60
# 3       happy       glad                8.50                8.60
# 4       short       long                7.25                7.50
# 5      stupid       dumb                9.00                8.90
# 6       weird    strange                9.00                9.70
# 7        wide     narrow                8.50                6.10
# 8        easy  difficult                4.25                1.86
# 9        hard     simple                4.50                3.65
# 10      smart       dumb                6.00                6.78
# 11     insane      crazy                9.25                9.40
# 12      happy        mad                6.75                6.10
# 13      large       huge                8.75                9.70
# 14       hard      tough                8.50                7.80
# 15        new      fresh                8.00                8.70
# 16      sharp       dull                8.25                8.20
# 17      quick      rapid                9.50                9.60
# 18       dumb    foolish                9.50                8.70
# 19  wonderful   terrific                9.25                9.50
# 20    strange        odd                8.50                9.20
# 21      happy      angry                6.25                6.80
# 22     narrow      broad                7.00                7.40
# 23     simple       easy                8.50                7.00
# 24        old      fresh                6.00                7.00
#
#     similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                 7.76                5.26                9.50
# 1                 0.81                3.00                1.67
# 2                 9.34                9.75                9.80
# 3                 8.47                7.50                9.40
# 4                 0.71                5.50                9.60
# 5                 8.66                9.75                9.20
# 6                 9.15                9.50                9.80
# 7                 5.56                8.75                9.20
# 8                 0.63                3.25                4.70
# 9                 2.81                3.00                2.60
# 10                6.98                9.75                7.50
# 11                8.64                9.50                9.70
# 12                6.67                6.25                9.00
# 13                9.85                9.00                9.60
# 14                9.15                8.75                9.10
# 15                8.73                9.50                8.20
# 16                6.93                8.75                8.60
# 17                9.07                9.75                8.60
# 18                9.00                9.50                9.20
# 19                9.45                9.75                9.50
# 20                9.45                9.75                9.70
# 21                4.64                6.25                7.30
# 22                7.34                6.00                8.00
# 23                7.36                8.50                9.60
# 24                5.47                7.25                5.20
#
#     similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                  9.6                8.66                8.50
# 1                  3.5                4.52                1.14
# 2                  8.5                9.68                9.21
# 3                  8.8                7.90                8.09
# 4                  5.5                6.42                7.80
# 5                  9.0                8.79                9.21
# 6                  9.2                9.24                8.62
# 7                  6.0                7.10                7.05
# 8                  3.2                3.50                1.75
# 9                  3.8                4.91                1.25
# 10                 9.4                5.12                8.65
# 11                 9.6                8.46                9.15
# 12                 8.7                5.82                7.05
# 13                 8.3                9.07                9.32
# 14                 8.0                8.85                9.02
# 15                 8.4                8.28                8.81
# 16                 7.5                7.87                8.73
# 17                 8.8                9.21                9.18
# 18                 9.4                8.70                9.10
# 19                 9.5                9.40                8.90
# 20                 8.9                8.99                8.91
# 21                 7.3                6.13                8.00
# 22                 6.2                7.04                7.91
# 23                 8.8                8.11                8.92
# 24                 5.0                6.71                8.61
#
#     similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                 9.15                 8.57                 8.90
# 1                 1.98                 2.14                 5.65
# 2                 8.90                 9.29                 9.50
# 3                 8.00                 8.57                 7.80
# 4                 7.34                 8.57                 8.20
# 5                 9.40                 8.10                 7.00
# 6                 9.85                 9.29                 9.30
# 7                 3.65                 8.57                 7.00
# 8                 2.18                 2.86                 4.00
# 9                 1.84                 4.29                 5.50
# 10                7.88                 4.29                 4.50
# 11                9.50                 8.57                 8.50
# 12                7.82                 7.14                 7.80
# 13                8.90                 9.29                 9.00
# 14                8.80                 8.57                 8.50
# 15                6.50                 9.29                 7.50
# 16                8.30                 8.57                 7.50
# 17                8.80                 8.57                 9.20
# 18                9.60                 8.10                 8.00
# 19                9.50                 8.57                 9.00
# 20                9.90                 9.29                 8.50
# 21                7.25                 2.86                 7.00
# 22                3.25                 8.57                 7.00
# 23                9.35                 9.29                 5.00
# 24                5.00                 3.57                 2.80
#
#     similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                   8.2                  9.8                 8.90
# 1                   3.2                  6.0                 2.33
# 2                   9.8                  9.7                 8.20
# 3                   7.6                  9.7                 8.50
# 4                   8.8                  9.2                 7.50
# 5                   9.7                  8.5                 9.50
# 6                   9.8                  9.9                 9.30
# 7                   8.7                  7.5                 8.50
# 8                   2.5                  6.5                 2.50
# 9                   3.5                  7.5                 3.67
# 10                  3.2                  7.8                 7.00
# 11                  9.6                  9.7                 9.50
# 12                  6.8                  8.0                 7.70
# 13                  9.0                  9.5                 8.70
# 14                  8.5                  9.2                 8.00
# 15                  9.7                  8.5                 9.00
# 16                  8.9                  9.3                 7.50
# 17                  9.6                  9.4                 9.00
# 18                  9.5                  8.5                 9.30
# 19                  9.8                  9.8                 9.50
# 20                  9.4                  9.5                 9.30
# 21                  5.4                  8.5                 7.20
# 22                  8.2                  7.5                 7.80
# 23                  9.2                  9.2                 2.50
# 24                  6.4                  7.0                 7.40
#
#     similarity_score_15
# 0                  8.89
# 1                  5.00
# 2                  9.17
# 3                  8.89
# 4                  6.33
# 5                  8.67
# 6                  9.68
# 7                  8.44
# 8                  3.56
# 9                  3.78
# 10                 7.00
# 11                 9.67
# 12                 5.56
# 13                 9.44
# 14                 8.00
# 15                 7.33
# 16                 8.33
# 17                 9.33
# 18                 8.22
# 19                 9.56
# 20                 9.78
# 21                 5.56
# 22                 7.33
# 23                 8.44
# 24                 5.56

# %% [markdown]
# ### **1. Data Processing**

# %%
# Copy dataframe
nl_pred = raw_nl_pred.copy()

# List of columns to calculate mean SimLex-999
similarity_cols = [f"similarity_score_{i}" for i in range(1, 16)]

# Calculate the mean SimLex-999
nl_pred['nl_pred_sl'] = nl_pred[similarity_cols].mean(axis=1).round(2)

# Calculate the standard deviation SimLex-999
nl_pred['nl_pred_sd'] = nl_pred[similarity_cols].std(axis=1).round(2)

# Select columns
nl_pred = nl_pred[['word1', 'word2', 'nl_pred_sl', 'nl_pred_sd']]

# Show results
nl_pred
# Out:
#           word1        word2  nl_pred_sl  nl_pred_sd
# 0      gelukkig      vrolijk        7.30        0.76
# 1          hard        stoer        5.51        1.14
# 2          snel   razendsnel        8.87        0.54
# 3      gelukkig         blij        7.56        0.81
# 4          kort         lang        3.66        1.48
# 5           dom         stom        6.10        1.15
# 6        vreemd  eigenaardig        8.69        0.55
# 7         breed         smal        3.35        1.58
# 8     makkelijk     moeilijk        3.02        0.90
# 9      moeilijk  gemakkelijk        5.74        1.35
# 10         slim          dom        3.00        0.77
# 11  krankzinnig          gek        8.85        0.56
# 12     gelukkig        kwaad        2.54        0.80
# 13   uitgebreid        groot        6.05        1.39
# 14     moeilijk       simpel        5.08        1.29
# 15        nieuw         vers        4.71        1.53
# 16       scherp         saai        2.40        0.77
# 17         vlug         snel        8.13        0.78
# 18          dom        dwaas        6.69        1.22
# 19     prachtig  fantastisch        8.51        0.55
# 20  eigenaardig       vreemd        9.02        0.68
# 21     gelukkig         boos        2.62        0.76
# 22         smal        breed        3.48        1.62
# 23    eenvoudig  gemakkelijk        7.74        0.75
# 24          oud         vers        2.89        0.77

# %%
# Copy dataframe
en_pred = raw_en_pred.copy()

# List of columns to calculate mean SimLex-999
similarity_cols = [f"similarity_score_{i}" for i in range(1, 16)]

# Calculate the mean SimLex-999
en_pred['en_pred_sl'] = en_pred[similarity_cols].mean(axis=1).round(2)

# Calculate the standard deviation SimLex-999
en_pred['en_pred_sd'] = en_pred[similarity_cols].std(axis=1).round(2)

# Select columns
en_pred = en_pred[['word1', 'word2', 'en_pred_sl', 'en_pred_sd']]

# Show results
en_pred
# Out:
#         word1      word2  en_pred_sl  en_pred_sd
# 0       happy   cheerful        8.64        1.08
# 1        hard       easy        3.12        1.64
# 2        fast      rapid        9.33        0.48
# 3       happy       glad        8.42        0.63
# 4       short       long        7.08        2.15
# 5      stupid       dumb        8.89        0.69
# 6       weird    strange        9.42        0.37
# 7        wide     narrow        7.37        1.54
# 8        easy  difficult        3.15        1.41
# 9        hard     simple        3.77        1.51
# 10      smart       dumb        6.79        1.88
# 11     insane      crazy        9.25        0.47
# 12      happy        mad        7.14        1.02
# 13      large       huge        9.16        0.42
# 14       hard      tough        8.58        0.46
# 15        new      fresh        8.43        0.85
# 16      sharp       dull        8.22        0.64
# 17      quick      rapid        9.17        0.37
# 18       dumb    foolish        8.95        0.55
# 19  wonderful   terrific        9.40        0.34
# 20    strange        odd        9.27        0.44
# 21      happy      angry        6.43        1.41
# 22     narrow      broad        7.10        1.27
# 23     simple       easy        7.98        1.92
# 24        old      fresh        5.93        1.52

# %%
# Concatenate NL and EN DataFrames
conc = pd.concat([nl_pred, en_pred], axis=1)

# Show results
conc
# Out:
#           word1        word2  nl_pred_sl  nl_pred_sd      word1      word2  \
# 0      gelukkig      vrolijk        7.30        0.76      happy   cheerful
# 1          hard        stoer        5.51        1.14       hard       easy
# 2          snel   razendsnel        8.87        0.54       fast      rapid
# 3      gelukkig         blij        7.56        0.81      happy       glad
# 4          kort         lang        3.66        1.48      short       long
# 5           dom         stom        6.10        1.15     stupid       dumb
# 6        vreemd  eigenaardig        8.69        0.55      weird    strange
# 7         breed         smal        3.35        1.58       wide     narrow
# 8     makkelijk     moeilijk        3.02        0.90       easy  difficult
# 9      moeilijk  gemakkelijk        5.74        1.35       hard     simple
# 10         slim          dom        3.00        0.77      smart       dumb
# 11  krankzinnig          gek        8.85        0.56     insane      crazy
# 12     gelukkig        kwaad        2.54        0.80      happy        mad
# 13   uitgebreid        groot        6.05        1.39      large       huge
# 14     moeilijk       simpel        5.08        1.29       hard      tough
# 15        nieuw         vers        4.71        1.53        new      fresh
# 16       scherp         saai        2.40        0.77      sharp       dull
# 17         vlug         snel        8.13        0.78      quick      rapid
# 18          dom        dwaas        6.69        1.22       dumb    foolish
# 19     prachtig  fantastisch        8.51        0.55  wonderful   terrific
# 20  eigenaardig       vreemd        9.02        0.68    strange        odd
# 21     gelukkig         boos        2.62        0.76      happy      angry
# 22         smal        breed        3.48        1.62     narrow      broad
# 23    eenvoudig  gemakkelijk        7.74        0.75     simple       easy
# 24          oud         vers        2.89        0.77        old      fresh
#
#     en_pred_sl  en_pred_sd
# 0         8.64        1.08
# 1         3.12        1.64
# 2         9.33        0.48
# 3         8.42        0.63
# 4         7.08        2.15
# 5         8.89        0.69
# 6         9.42        0.37
# 7         7.37        1.54
# 8         3.15        1.41
# 9         3.77        1.51
# 10        6.79        1.88
# 11        9.25        0.47
# 12        7.14        1.02
# 13        9.16        0.42
# 14        8.58        0.46
# 15        8.43        0.85
# 16        8.22        0.64
# 17        9.17        0.37
# 18        8.95        0.55
# 19        9.40        0.34
# 20        9.27        0.44
# 21        6.43        1.41
# 22        7.10        1.27
# 23        7.98        1.92
# 24        5.93        1.52

# %% [markdown]
# ### **2. Descriptive Statistics**

# %%
# Summary statistics SimLex-999
nl_pred_sl_summary = round(nl_pred['nl_pred_sl'].describe(), 2)
en_pred_sl_summary = round(en_pred['en_pred_sl'].describe(), 2)

# Add median SimLex-999
nl_pred_sl_summary['median'] = round(nl_pred['nl_pred_sl'].median(), 2)
en_pred_sl_summary['median'] = round(en_pred['en_pred_sl'].median(), 2)

# Summary statistics standard deviations
nl_pred_sd_summary = round(nl_pred['nl_pred_sd'].describe(), 2)
en_pred_sd_summary = round(en_pred['en_pred_sd'].describe(), 2)

# Add median standard deviation
nl_pred_sd_summary['median'] = round(nl_pred['nl_pred_sd'].median(), 2)
en_pred_sd_summary['median'] = round(en_pred['en_pred_sd'].median(), 2)

# Create pandas DataFrame
summary_df = pd.DataFrame({
    "nl_pred_sl": nl_pred_sl_summary,
    "en_pred_sl": en_pred_sl_summary,
    "nl_pred_sd": nl_pred_sd_summary,
    "en_pred_sd": en_pred_sd_summary
})

# Show results
summary_df
# Out:
#         nl_pred_sl  en_pred_sl  nl_pred_sd  en_pred_sd
# count        25.00       25.00       25.00       25.00
# mean          5.66        7.64        0.98        1.00
# std           2.36        1.91        0.36        0.57
# min           2.40        3.12        0.54        0.34
# 25%           3.35        7.08        0.76        0.47
# 50%           5.74        8.42        0.80        0.85
# 75%           7.74        9.16        1.29        1.51
# max           9.02        9.42        1.62        2.15
# median        5.74        8.42        0.80        0.85

# %% [markdown]
# #### **2.1. SimLex-999**

# %%
# Rename columns and copy
renamed_nl_pred_sl = nl_pred.rename(columns={"nl_pred_sl": "SimLex-999"}).copy()
renamed_en_pred_sl = en_pred.rename(columns={"en_pred_sl": "SimLex-999"}).copy()

# Create dummy label
renamed_nl_pred_sl['Score'] = 'NL'
renamed_en_pred_sl['Score'] = 'EN'

# Combine DataFrames
combined_data = pd.concat([renamed_nl_pred_sl, renamed_en_pred_sl])

# Create boxplot
plt.figure(figsize=(6, 6))
sns.boxplot(
    x='Score',
    y='SimLex-999',
    data=combined_data,
    palette=['skyblue', 'lightgreen'],
    boxprops={'edgecolor': 'black'},
    whiskerprops={'color': 'black'},
    flierprops={'marker': 'o', 'color': 'black', 'markerfacecolor': 'black'},
    capprops={'color': 'black'},
    medianprops={'color': 'black'}
)

# Set labels and title
plt.ylabel('SimLex-999')
# plt.title('Comparison of SimLex-999')

# Customize y-axis ticks
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(integer=True))
plt.ylim(0, 10)  # Setting y-axis limits from 0 to 10

# Remove x-axis label
plt.xlabel('')

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# #### **2.2. Standard Deviation**

# %%
# Rename columns and copy
renamed_nl_pred_sd = nl_pred.rename(columns={"nl_pred_sd": "Standard Deviation"}).copy()
renamed_en_pred_sd = en_pred.rename(columns={"en_pred_sd": "Standard Deviation"}).copy()

# Create dummy label
renamed_nl_pred_sd['Score'] = 'NL'
renamed_en_pred_sd['Score'] = 'EN'

# Combine DataFrames
combined_data = pd.concat([renamed_nl_pred_sd, renamed_en_pred_sd])

# Create boxplot
plt.figure(figsize=(6, 6))
sns.boxplot(
    x='Score',
    y='Standard Deviation',
    data=combined_data,
    palette=['skyblue', 'lightgreen'],
    boxprops={'edgecolor': 'black'},
    whiskerprops={'color': 'black'},
    flierprops={'marker': 'o', 'color': 'black', 'markerfacecolor': 'black'},
    capprops={'color': 'black'},
    medianprops={'color': 'black'}
)

# Set labels and title
plt.ylabel('Standard Deviation')
# plt.title('Comparison of Standard Deviation')

# Customizing y-axis ticks
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(integer=True))
plt.ylim(0, 5)  # Setting y-axis limits from 0 to 5

# Remove x-axis label
plt.xlabel('')

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# ### **3. Distributions**

# %% [markdown]
# #### **3.1. SimLex-999**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 10

# Define bins
bins = 10

# Plot NL predicted histogram
axes[0].hist(renamed_nl_pred_sl['SimLex-999'], bins=bins, edgecolor='black', color='skyblue')
axes[0].set_title('NL')
axes[0].set_xlabel('SimLex-999')
axes[0].set_ylabel('Frequency')
axes[0].set_xlim(x_min, x_max)
axes[0].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[0].grid(False) # Remove grid

# Plot EN predicted histogram
axes[1].hist(renamed_en_pred_sl['SimLex-999'], bins=bins, edgecolor='black', color='lightgreen')
axes[1].set_title('EN')
axes[1].set_xlabel('SimLex-999')
axes[1].set_ylabel('Frequency')
axes[1].set_xlim(x_min, x_max)
axes[1].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[1].grid(False) # Remove grid

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# #### **3.2. Standard Deviation**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 5

# Define bins
bins = 5

# Plot NL predicted histogram
axes[0].hist(renamed_nl_pred_sd['Standard Deviation'], bins=bins, edgecolor='black', color='skyblue')
axes[0].set_title('NL')
axes[0].set_xlabel('Standard Deviation')
axes[0].set_ylabel('Frequency')
axes[0].set_xlim(x_min, x_max)
axes[0].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[0].grid(False) # Remove grid

# Plot EN predicted histogram
axes[1].hist(renamed_en_pred_sd['Standard Deviation'], bins=bins, edgecolor='black', color='lightgreen')
axes[1].set_title('EN')
axes[1].set_xlabel('Standard Deviation')
axes[1].set_ylabel('Frequency')
axes[1].set_xlim(x_min, x_max)
axes[1].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[1].grid(False) # Remove grid

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# ### **4. Outliers**

# %% [markdown]
# #### **4.1. NL**

# %%
# Count outliers
print_outlier_counts(nl_pred)
# Out:
# No outliers found in columns: nl_pred_sl, nl_pred_sd

# %%
# Row outliers
print_outlier_data(nl_pred, 'nl_pred_sd')
# Out:
# No outliers found in nl_pred_sd

# %% [markdown]
# #### **4.2. EN**

# %%
# Count outliers
print_outlier_counts(en_pred)
# Out:
# Outliers in en_pred_sl: 3
# No outliers found in columns: en_pred_sd

# %%
# Row outliers
print_outlier_data(en_pred, 'en_pred_sd')
# Out:
# No outliers found in en_pred_sd

# %% [markdown]
# #### **4.3. Add to Summary**

# %%
# Calculate outliers
outliers_nl_pred_sl = calculate_outliers(nl_pred, 'nl_pred_sl')
outliers_nl_pred_sd = calculate_outliers(nl_pred, 'nl_pred_sd')
outliers_en_pred_sl = calculate_outliers(en_pred, 'en_pred_sl')
outliers_en_pred_sd = calculate_outliers(en_pred, 'en_pred_sd')

# Count outliers
count_outliers_nl_pred_sl = outliers_nl_pred_sl.shape[0]
count_outliers_nl_pred_sd = outliers_nl_pred_sd.shape[0]
count_outliers_en_pred_sl = outliers_en_pred_sl.shape[0]
count_outliers_en_pred_sd = outliers_en_pred_sd.shape[0]

# Add outliers count to summary
outliers_row = pd.Series([count_outliers_nl_pred_sl, count_outliers_en_pred_sl, count_outliers_nl_pred_sd, count_outliers_en_pred_sd], 
    index=summary_df.columns,
    name='outliers'
)
summary_df = pd.concat([summary_df, outliers_row.to_frame().T])

# Show results
summary_df
# Out:
#           nl_pred_sl  en_pred_sl  nl_pred_sd  en_pred_sd
# count          25.00       25.00       25.00       25.00
# mean            5.66        7.64        0.98        1.00
# std             2.36        1.91        0.36        0.57
# min             2.40        3.12        0.54        0.34
# 25%             3.35        7.08        0.76        0.47
# 50%             5.74        8.42        0.80        0.85
# 75%             7.74        9.16        1.29        1.51
# max             9.02        9.42        1.62        2.15
# median          5.74        8.42        0.80        0.85
# outliers        0.00        3.00        0.00        0.00

# %% [markdown]
# ### **5. Correlation**

# %% [markdown]
# #### **5.1. SimLex-999 vs Standard Deviation**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 10
y_min = 0
y_max = 5

# Create scatter plot
sns.scatterplot(x='nl_pred_sl', y='nl_pred_sd', data=nl_pred, ax=axes[0], color='skyblue', edgecolor='black')

# Plot diagonal line
axes[0].plot([x_min, x_max], [y_min, y_max], color='red', linestyle='--')

# Set axis limits
axes[0].set_xlim(x_min, x_max)
axes[0].set_ylim(y_min, y_max)

# Set labels and title
axes[0].set_xlabel('SimLex-999')
axes[0].set_ylabel('Standard Deviation')
axes[0].set_title('NL')

# Remove grid
axes[0].grid(False)

# Create scatter plot
sns.scatterplot(x='en_pred_sl', y='en_pred_sd', data=en_pred, ax=axes[1], color='lightgreen', edgecolor='black')

# Plot diagonal line
axes[1].plot([x_min, x_max], [y_min, y_max], color='red', linestyle='--')

# Set axis limits
axes[1].set_xlim(x_min, x_max)
axes[1].set_ylim(y_min, y_max)

# Set labels and title
axes[1].set_xlabel('SimLex-999')
axes[1].set_ylabel('Standard Deviation')
axes[1].set_title('EN')

# Remove grid
axes[1].grid(False)

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %%
# List to store correlations
correlations_list = []

# Append correlations to list
correlations_list.append(calculate_correlation_and_pvalue(conc, 'nl_pred_sl', 'nl_pred_sd'))
correlations_list.append(calculate_correlation_and_pvalue(conc, 'en_pred_sl', 'en_pred_sd'))

# Convert list into Pandas DataFrame
correlation_df = pd.DataFrame(correlations_list)

# Show results
correlation_df
# Out:
#     simlex999 standard_deviation  correlation       p_value significance
# 0  nl_pred_sl         nl_pred_sd     -0.47016  1.770977e-02  significant
# 1  en_pred_sl         en_pred_sd     -0.85341  5.901343e-08  significant

# %% [markdown]
# ### **6. Evaluation Metrics**

# %% [markdown]
# #### **6.1. Spearmans's Rank Correlation**

# %% [markdown]
# ##### **6.1.1. NL SimLex-999 vs EN SimLex-999**

# %%
# Scatter plot
plot_scatter_plot(conc, 'nl_pred_sl', 'en_pred_sl', 'SimLex-999 (NL)', 'SimLex-999 (EN)', 0, 10, 0, 10)

# %%
# Correlation and pvalue
print_correlation_and_pvalue(conc, 'nl_pred_sl', 'en_pred_sl')
# Out:
# Spearman's Rank correlation: 0.76462
# P-value: 8.574570332971608e-06
# The correlation is statistically significant.

# %% [markdown]
# ##### **6.1.2. NL Standard Deviation vs EN Standard Deviation**

# %%
# Scatter plot
plot_scatter_plot(conc, 'nl_pred_sd', 'en_pred_sd', 'Standard Deviation (NL)', 'Standard Deviation (EN)', 0, 5, 0, 3)

# %%
# Correlation and p-value
print_correlation_and_pvalue(conc, 'nl_pred_sd', 'en_pred_sd')
# Out:
# Spearman's Rank correlation: 0.3359
# P-value: 0.10066817978911756
# The correlation is not statistically significant.

# %% [markdown]
# #### **7.2. Mean Square Error (MSE)**

# %%
# Calculate Mean Squared Error
mse = mean_squared_error(conc['nl_pred_sl'], conc['en_pred_sl'])

# Show results
print(f"Mean Squared Error (MSE): {mse:.2f}")
# Out:
# Mean Squared Error (MSE): 7.91

# %% [markdown]
# #### **7.3. Mean Absolute Error (MAE)**

# %%
# Calculate Mean Absolute Error
mae = mean_absolute_error(conc['nl_pred_sl'], conc['en_pred_sl'])

# Show results
print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
# Mean Absolute Error (MAE): 2.33
