# %% [markdown]
# ### **0. Set-up**

# %%
# Import libraries and utils
# %run '../../../utils.ipynb'

# %%
# Load NL predicted
raw_nl_pred = pd.read_csv("../../../../data/gpt-3.5-turbo-0125/processed/nl/f7.csv")

# %%
# Load EN predicted
raw_en_pred = pd.read_csv("../../../../data/gpt-3.5-turbo-0125/processed/en/f7.csv")

# Drop rows in EN SimLex that are missing in NL SimLex
raw_en_pred = raw_en_pred.drop(raw_en_pred[(raw_en_pred['word1'] == 'bad') & (raw_en_pred['word2'] == 'awful')].index)
raw_en_pred = raw_en_pred.drop(raw_en_pred[(raw_en_pred['word1'] == 'bad') & (raw_en_pred['word2'] == 'terrible')].index)

# Reset index
raw_en_pred = raw_en_pred.reset_index(drop=True)

# %%
# Select first 25 word pairs
raw_nl_pred = raw_nl_pred.head(25)
raw_en_pred = raw_en_pred.head(25)

# %%
# Show results
raw_nl_pred
# Out:
#           word1        word2  similarity_score_1  similarity_score_2  \
# 0           oud        nieuw                 1.0                 0.1
# 1          slim  intelligent                 1.0                 0.9
# 2          hard     moeilijk                 0.0                 0.2
# 3      gelukkig      vrolijk                 0.5                 0.8
# 4          hard        stoer                 0.2                 0.5
# 5          snel   razendsnel                 0.9                 1.0
# 6      gelukkig         blij                 0.7                 0.9
# 7          kort         lang                 0.0                 0.1
# 8           dom         stom                 0.7                 0.8
# 9        vreemd  eigenaardig                 0.9                 0.9
# 10        breed         smal                 0.3                 0.1
# 11    makkelijk     moeilijk                 0.0                 0.2
# 12     moeilijk  gemakkelijk                 0.8                 0.7
# 13         slim          dom                 0.1                 0.2
# 14  krankzinnig          gek                 1.0                 0.9
# 15     gelukkig        kwaad                 0.1                 0.1
# 16   uitgebreid        groot                 0.2                 0.2
# 17     moeilijk       simpel                 1.0                 0.2
# 18        nieuw         vers                 0.9                 0.9
# 19       scherp         saai                 0.2                 0.1
# 20         vlug         snel                 0.8                 0.9
# 21          dom        dwaas                 0.7                 0.8
# 22     prachtig  fantastisch                 0.9                 0.8
# 23  eigenaardig       vreemd                 0.8                 0.7
# 24     gelukkig         boos                 0.1                 0.1
#
#     similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                  1.0                0.10                 1.0
# 1                  0.8                0.95                 0.9
# 2                  0.2                0.30                 0.2
# 3                  0.6                0.80                 0.8
# 4                  0.3                0.50                 0.4
# 5                  0.9                0.90                 1.0
# 6                  0.7                0.70                 0.8
# 7                  0.2                0.20                 0.1
# 8                  0.7                0.90                 0.9
# 9                  0.9                0.80                 1.0
# 10                 0.1                0.40                 0.2
# 11                 0.8                0.10                 0.1
# 12                 0.8                0.90                 0.1
# 13                 0.1                0.20                 0.8
# 14                 0.9                0.90                 1.0
# 15                 0.1                0.10                 0.1
# 16                 0.4                0.10                 0.3
# 17                 2.0                0.10                 0.1
# 18                 8.0                0.90                 0.8
# 19                 1.0                0.10                 0.1
# 20                 8.0                0.80                 0.9
# 21                 7.0                0.70                 0.6
# 22                 9.0                0.90                 0.9
# 23                 9.0                0.90                 0.7
# 24                 1.0                0.10                 0.1
#
#     similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                  1.0                 2.0                 0.1
# 1                  0.9                 8.0                 0.9
# 2                  0.2                 4.0                 0.2
# 3                  0.7                 6.0                 0.8
# 4                  0.4                 4.0                 0.5
# 5                  0.9                 9.0                 0.9
# 6                  0.8                 8.0                 0.7
# 7                  0.1                 2.0                 0.1
# 8                  0.7                 7.0                 0.7
# 9                  0.9                 9.0                 0.8
# 10                 0.1                 3.0                 0.7
# 11                 0.1                 4.0                 0.2
# 12                 0.9                 8.0                 0.8
# 13                 0.2                 3.0                 0.4
# 14                 0.9                 9.0                 0.8
# 15                 0.1                 1.0                 0.1
# 16                 0.5                 5.0                 0.3
# 17                 0.2                 0.2                 0.1
# 18                 0.9                 0.9                 0.9
# 19                 0.1                 0.1                 0.2
# 20                 0.9                 0.9                 0.9
# 21                 0.7                 0.8                 0.8
# 22                 0.8                 0.9                 0.8
# 23                 0.7                 0.8                 0.9
# 24                 0.1                 0.1                 0.1
#
#     similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                  2.0                 2.00                  0.1
# 1                  7.0                 8.00                  0.9
# 2                  2.0                 3.00                  0.2
# 3                  6.5                 8.00                  0.7
# 4                  4.0                 4.00                  0.5
# 5                  9.0                 9.00                  0.9
# 6                  8.0                 9.00                  0.8
# 7                  3.0                 2.00                  0.2
# 8                  8.0                 8.00                  0.9
# 9                  8.5                 9.00                  0.8
# 10                 3.0                 3.00                  0.1
# 11                 1.0                 4.00                  0.2
# 12                 8.0                 6.00                  0.7
# 13                 1.5                 2.00                  0.1
# 14                 9.0                 9.00                  0.9
# 15                 1.0                 2.00                  0.1
# 16                 4.5                 5.00                  0.1
# 17                 1.0                 0.10                  0.2
# 18                 0.9                 0.90                  0.8
# 19                 0.2                 0.10                  0.1
# 20                 0.8                 0.90                  0.9
# 21                 1.0                 0.80                  0.7
# 22                 0.8                 0.95                  0.6
# 23                 0.9                 0.90                  0.9
# 24                 0.3                 0.10                  0.1
#
#     similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                   0.1                 0.10                  0.2
# 1                   0.9                 0.95                  0.9
# 2                   0.2                 0.20                  0.4
# 3                   0.7                 0.80                  0.8
# 4                   0.4                 0.60                  0.6
# 5                   1.0                 0.90                  0.9
# 6                   0.8                 0.70                  0.8
# 7                   0.1                 0.10                  0.4
# 8                   0.9                 0.80                  0.8
# 9                   0.8                 0.90                  0.9
# 10                  0.2                 0.20                  0.4
# 11                  0.1                 0.20                  0.1
# 12                  0.7                 0.90                  0.8
# 13                  0.1                 0.10                  0.6
# 14                  0.9                 0.90                  0.9
# 15                  0.1                 0.10                  0.3
# 16                  0.3                 0.20                  0.6
# 17                  1.0                 0.10                  0.1
# 18                  1.0                 0.90                  0.9
# 19                  0.0                 0.10                  0.1
# 20                  0.8                 0.90                  0.9
# 21                  0.8                 0.70                  0.8
# 22                  0.9                 0.90                  0.9
# 23                  0.7                 0.80                  0.8
# 24                  0.0                 0.10                  0.1
#
#     similarity_score_15
# 0                   1.0
# 1                   0.9
# 2                   0.3
# 3                   0.8
# 4                   0.5
# 5                   0.9
# 6                   0.8
# 7                   0.1
# 8                   0.8
# 9                   0.9
# 10                  0.1
# 11                  0.2
# 12                  0.2
# 13                  0.2
# 14                  0.9
# 15                  0.1
# 16                  0.4
# 17                  1.0
# 18                  0.8
# 19                  0.2
# 20                  0.9
# 21                  0.7
# 22                  0.9
# 23                  0.7
# 24                  0.1

# %%
# Show results
raw_en_pred
# Out:
#         word1        word2  similarity_score_1  similarity_score_2  \
# 0         old          new                 0.1                 0.1
# 1       smart  intelligent                 0.9                 0.9
# 2        hard    difficult                 0.3                 0.8
# 3       happy     cheerful                 0.8                 0.7
# 4        hard         easy                 0.1                 0.1
# 5        fast        rapid                 0.9                 0.9
# 6       happy         glad                 0.7                 0.7
# 7       short         long                 0.2                 0.5
# 8      stupid         dumb                 0.8                 0.7
# 9       weird      strange                 0.9                 0.9
# 10       wide       narrow                 0.7                 0.8
# 11       easy    difficult                 0.1                 0.4
# 12       hard       simple                 0.4                 0.4
# 13      smart         dumb                 0.7                 0.1
# 14     insane        crazy                 0.8                 0.9
# 15      happy          mad                 0.5                 0.7
# 16      large         huge                 0.8                 0.8
# 17       hard        tough                 0.7                 0.8
# 18        new        fresh                 8.0                 8.0
# 19      sharp         dull                 1.0                 4.0
# 20      quick        rapid                 9.0                 9.0
# 21       dumb      foolish                 7.0                 4.0
# 22  wonderful     terrific                 9.0                 9.0
# 23    strange          odd                 8.0                 7.0
# 24      happy        angry                 1.0                 2.0
#
#     similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                  1.0                 0.2                 0.1
# 1                  1.0                 0.9                 0.9
# 2                  0.5                 0.7                 0.8
# 3                  0.2                 0.6                 0.7
# 4                  0.2                 0.1                 0.1
# 5                  1.0                 0.9                 0.9
# 6                  0.5                 0.7                 0.8
# 7                  0.3                 0.2                 0.1
# 8                  0.8                 0.8                 0.9
# 9                  1.0                 0.9                 0.9
# 10                 0.6                 0.8                 0.8
# 11                 0.2                 0.1                 0.5
# 12                 0.2                 0.1                 0.4
# 13                 0.4                 0.7                 0.8
# 14                 0.9                 0.9                 0.9
# 15                 0.5                 0.5                 0.7
# 16                 0.7                 0.8                 0.8
# 17                 0.7                 0.8                 0.8
# 18                 9.0                 8.0                 8.0
# 19                 1.0                 0.0                 2.0
# 20                10.0                 9.0                 9.0
# 21                 5.0                 5.0                 6.0
# 22                 9.0                 9.0                 8.0
# 23                 7.0                 7.0                 7.0
# 24                 1.0                 2.0                 1.0
#
#     similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                  2.0                 0.1                 0.2
# 1                  9.0                 0.9                 0.9
# 2                  7.0                 0.8                 0.7
# 3                  8.0                 0.8                 0.8
# 4                  3.0                 0.1                 0.4
# 5                  9.0                 0.9                 0.9
# 6                  8.0                 0.7                 0.7
# 7                  5.0                 0.8                 0.5
# 8                  8.0                 0.8                 0.8
# 9                  9.0                 0.9                 0.9
# 10                 7.0                 0.8                 0.8
# 11                 7.0                 0.1                 0.4
# 12                 3.0                 0.2                 0.5
# 13                 6.0                 0.2                 0.7
# 14                 8.0                 0.9                 0.9
# 15                 7.0                 0.7                 0.6
# 16                 9.0                 0.8                 0.8
# 17                 8.0                 0.8                 0.7
# 18                 8.0                 8.0                 9.0
# 19                 1.0                 1.0                 1.0
# 20                 9.0                 9.0                 9.0
# 21                 3.0                 5.0                 6.0
# 22                 7.0                 9.0                 9.0
# 23                 7.0                 6.0                 8.0
# 24                 1.0                 1.0                 0.0
#
#     similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                  0.1                  0.2                  0.1
# 1                  0.9                  0.9                  0.9
# 2                  0.2                  0.9                  0.2
# 3                  0.9                  0.8                  0.9
# 4                  0.1                  0.1                  0.1
# 5                  0.9                  0.9                  0.9
# 6                  0.8                  0.8                  0.8
# 7                  0.1                  0.7                  0.2
# 8                  0.8                  0.9                  0.9
# 9                  0.9                  0.9                  0.9
# 10                 0.9                  0.8                  0.8
# 11                 0.1                  0.3                  0.4
# 12                 0.1                  0.5                  0.2
# 13                 0.1                  0.8                  0.1
# 14                 0.9                  0.9                  0.9
# 15                 0.9                  0.6                  0.1
# 16                 0.9                  0.8                  0.8
# 17                 0.8                  0.7                  0.6
# 18                 8.0                  8.5                  8.0
# 19                 0.0                  2.0                  3.0
# 20                 9.0                  9.0                  9.0
# 21                 7.0                  4.0                  6.0
# 22                 9.0                  9.0                  9.0
# 23                 8.0                  7.5                  7.0
# 24                 0.0                  2.0                  1.0
#
#     similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                   0.1                  0.1                  3.0
# 1                   0.9                  0.9                  9.0
# 2                   0.4                  0.9                  6.0
# 3                   0.8                  0.7                  6.0
# 4                   0.2                  0.1                  2.0
# 5                   0.9                  0.9                  9.0
# 6                   0.7                  0.7                  7.0
# 7                   0.2                  0.6                  5.0
# 8                   0.9                  0.9                  8.0
# 9                   0.9                  0.9                  9.0
# 10                  0.7                  0.9                  6.0
# 11                  0.3                  0.7                  6.0
# 12                  0.2                  0.3                  4.0
# 13                  0.7                  0.1                  4.0
# 14                  0.8                  0.9                  9.0
# 15                  0.6                  0.5                  6.0
# 16                  0.8                  0.7                  8.0
# 17                  0.7                  0.8                  8.0
# 18                  8.0                  8.0                  8.0
# 19                  1.0                  2.0                  0.0
# 20                  8.0                  9.0                  8.0
# 21                  4.0                  6.0                  4.0
# 22                  9.0                  9.0                  8.0
# 23                  7.0                  8.0                  8.0
# 24                  1.0                  2.0                  0.0
#
#     similarity_score_15
# 0                   1.0
# 1                   0.9
# 2                   0.8
# 3                   0.7
# 4                   0.1
# 5                   0.9
# 6                   0.7
# 7                   0.2
# 8                   0.8
# 9                   0.9
# 10                  0.8
# 11                  0.1
# 12                  0.2
# 13                  0.7
# 14                  0.9
# 15                  0.7
# 16                  0.9
# 17                  0.8
# 18                  7.5
# 19                  1.0
# 20                  9.0
# 21                  4.0
# 22                  8.5
# 23                  6.5
# 24                  1.0

# %% [markdown]
# ### **1. Data Processing**

# %%
# Copy dataframe
nl_pred = raw_nl_pred.copy()

# List of columns to calculate mean SimLex-999
similarity_cols = [f"similarity_score_{i}" for i in range(1, 16)]

# Calculate the mean SimLex-999
nl_pred['nl_pred_sl'] = nl_pred[similarity_cols].mean(axis=1).round(2)

# Calculate the standard deviation SimLex-999
nl_pred['nl_pred_sd'] = nl_pred[similarity_cols].std(axis=1).round(2)

# Select columns
nl_pred = nl_pred[['word1', 'word2', 'nl_pred_sl', 'nl_pred_sd']]

# Show results
nl_pred
# Out:
#           word1        word2  nl_pred_sl  nl_pred_sd
# 0           oud        nieuw        0.79        0.75
# 1          slim  intelligent        2.26        2.81
# 2          hard     moeilijk        0.77        1.22
# 3      gelukkig      vrolijk        1.95        2.56
# 4          hard        stoer        1.16        1.47
# 5          snel   razendsnel        2.54        3.34
# 6      gelukkig         blij        2.28        3.14
# 7          kort         lang        0.58        0.94
# 8           dom         stom        2.17        2.85
# 9        vreemd  eigenaardig        2.47        3.30
# 10        breed         smal        0.79        1.15
# 11    makkelijk     moeilijk        0.75        1.35
# 12     moeilijk  gemakkelijk        2.02        2.79
# 13         slim          dom        0.64        0.87
# 14  krankzinnig          gek        2.53        3.35
# 15     gelukkig        kwaad        0.36        0.55
# 16   uitgebreid        groot        1.21        1.89
# 17     moeilijk       simpel        0.49        0.57
# 18        nieuw         vers        1.36        1.84
# 19       scherp         saai        0.18        0.23
# 20         vlug         snel        1.35        1.84
# 21          dom        dwaas        1.17        1.61
# 22     prachtig  fantastisch        1.40        2.11
# 23  eigenaardig       vreemd        1.35        2.12
# 24     gelukkig         boos        0.17        0.24

# %%
# Copy dataframe
en_pred = raw_en_pred.copy()

# List of columns to calculate mean SimLex-999
similarity_cols = [f"similarity_score_{i}" for i in range(1, 16)]

# Calculate the mean SimLex-999
en_pred['en_pred_sl'] = en_pred[similarity_cols].mean(axis=1).round(2)

# Calculate the standard deviation SimLex-999
en_pred['en_pred_sd'] = en_pred[similarity_cols].std(axis=1).round(2)

# Select columns
en_pred = en_pred[['word1', 'word2', 'en_pred_sl', 'en_pred_sd']]

# Show results
en_pred
# Out:
#         word1        word2  en_pred_sl  en_pred_sd
# 0         old          new        0.56        0.87
# 1       smart  intelligent        1.99        2.85
# 2        hard    difficult        1.40        2.09
# 3       happy     cheerful        1.56        2.25
# 4        hard         easy        0.45        0.86
# 5        fast        rapid        1.99        2.85
# 6       happy         glad        1.62        2.40
# 7       short         long        0.97        1.65
# 8      stupid         dumb        1.79        2.52
# 9       weird      strange        1.99        2.85
# 10       wide       narrow        1.55        2.02
# 11       easy    difficult        1.11        2.20
# 12       hard       simple        0.71        1.15
# 13      smart         dumb        1.07        1.66
# 14     insane        crazy        1.90        2.69
# 15      happy          mad        1.37        2.10
# 16      large         huge        1.83        2.72
# 17       hard        tough        1.71        2.55
# 18        new        fresh        8.13        0.40
# 19      sharp         dull        1.33        1.11
# 20      quick        rapid        8.93        0.46
# 21       dumb      foolish        5.07        1.22
# 22  wonderful     terrific        8.70        0.59
# 23    strange          odd        7.27        0.62
# 24      happy        angry        1.07        0.70

# %%
# Concatenate NL and EN DataFrames
conc = pd.concat([nl_pred, en_pred], axis=1)

# Show results
conc
# Out:
#           word1        word2  nl_pred_sl  nl_pred_sd      word1        word2  \
# 0           oud        nieuw        0.79        0.75        old          new
# 1          slim  intelligent        2.26        2.81      smart  intelligent
# 2          hard     moeilijk        0.77        1.22       hard    difficult
# 3      gelukkig      vrolijk        1.95        2.56      happy     cheerful
# 4          hard        stoer        1.16        1.47       hard         easy
# 5          snel   razendsnel        2.54        3.34       fast        rapid
# 6      gelukkig         blij        2.28        3.14      happy         glad
# 7          kort         lang        0.58        0.94      short         long
# 8           dom         stom        2.17        2.85     stupid         dumb
# 9        vreemd  eigenaardig        2.47        3.30      weird      strange
# 10        breed         smal        0.79        1.15       wide       narrow
# 11    makkelijk     moeilijk        0.75        1.35       easy    difficult
# 12     moeilijk  gemakkelijk        2.02        2.79       hard       simple
# 13         slim          dom        0.64        0.87      smart         dumb
# 14  krankzinnig          gek        2.53        3.35     insane        crazy
# 15     gelukkig        kwaad        0.36        0.55      happy          mad
# 16   uitgebreid        groot        1.21        1.89      large         huge
# 17     moeilijk       simpel        0.49        0.57       hard        tough
# 18        nieuw         vers        1.36        1.84        new        fresh
# 19       scherp         saai        0.18        0.23      sharp         dull
# 20         vlug         snel        1.35        1.84      quick        rapid
# 21          dom        dwaas        1.17        1.61       dumb      foolish
# 22     prachtig  fantastisch        1.40        2.11  wonderful     terrific
# 23  eigenaardig       vreemd        1.35        2.12    strange          odd
# 24     gelukkig         boos        0.17        0.24      happy        angry
#
#     en_pred_sl  en_pred_sd
# 0         0.56        0.87
# 1         1.99        2.85
# 2         1.40        2.09
# 3         1.56        2.25
# 4         0.45        0.86
# 5         1.99        2.85
# 6         1.62        2.40
# 7         0.97        1.65
# 8         1.79        2.52
# 9         1.99        2.85
# 10        1.55        2.02
# 11        1.11        2.20
# 12        0.71        1.15
# 13        1.07        1.66
# 14        1.90        2.69
# 15        1.37        2.10
# 16        1.83        2.72
# 17        1.71        2.55
# 18        8.13        0.40
# 19        1.33        1.11
# 20        8.93        0.46
# 21        5.07        1.22
# 22        8.70        0.59
# 23        7.27        0.62
# 24        1.07        0.70

# %% [markdown]
# ### **2. Descriptive Statistics**

# %%
# Summary statistics SimLex-999
nl_pred_sl_summary = round(nl_pred['nl_pred_sl'].describe(), 2)
en_pred_sl_summary = round(en_pred['en_pred_sl'].describe(), 2)

# Add median SimLex-999
nl_pred_sl_summary['median'] = round(nl_pred['nl_pred_sl'].median(), 2)
en_pred_sl_summary['median'] = round(en_pred['en_pred_sl'].median(), 2)

# Summary statistics standard deviations
nl_pred_sd_summary = round(nl_pred['nl_pred_sd'].describe(), 2)
en_pred_sd_summary = round(en_pred['en_pred_sd'].describe(), 2)

# Add median standard deviation
nl_pred_sd_summary['median'] = round(nl_pred['nl_pred_sd'].median(), 2)
en_pred_sd_summary['median'] = round(en_pred['en_pred_sd'].median(), 2)

# Create pandas DataFrame
summary_df = pd.DataFrame({
    "nl_pred_sl": nl_pred_sl_summary,
    "en_pred_sl": en_pred_sl_summary,
    "nl_pred_sd": nl_pred_sd_summary,
    "en_pred_sd": en_pred_sd_summary
})

# Show results
summary_df
# Out:
#         nl_pred_sl  en_pred_sl  nl_pred_sd  en_pred_sd
# count        25.00       25.00       25.00       25.00
# mean          1.31        2.64        1.80        1.74
# std           0.77        2.65        1.01        0.86
# min           0.17        0.45        0.23        0.40
# 25%           0.75        1.11        0.94        0.87
# 50%           1.21        1.62        1.84        2.02
# 75%           2.02        1.99        2.79        2.52
# max           2.54        8.93        3.35        2.85
# median        1.21        1.62        1.84        2.02

# %% [markdown]
# #### **2.1. SimLex-999**

# %%
# Rename columns and copy
renamed_nl_pred_sl = nl_pred.rename(columns={"nl_pred_sl": "SimLex-999"}).copy()
renamed_en_pred_sl = en_pred.rename(columns={"en_pred_sl": "SimLex-999"}).copy()

# Create dummy label
renamed_nl_pred_sl['Score'] = 'NL'
renamed_en_pred_sl['Score'] = 'EN'

# Combine DataFrames
combined_data = pd.concat([renamed_nl_pred_sl, renamed_en_pred_sl])

# Create boxplot
plt.figure(figsize=(6, 6))
sns.boxplot(
    x='Score',
    y='SimLex-999',
    data=combined_data,
    palette=['skyblue', 'lightgreen'],
    boxprops={'edgecolor': 'black'},
    whiskerprops={'color': 'black'},
    flierprops={'marker': 'o', 'color': 'black', 'markerfacecolor': 'black'},
    capprops={'color': 'black'},
    medianprops={'color': 'black'}
)

# Set labels and title
plt.ylabel('SimLex-999')
# plt.title('Comparison of SimLex-999')

# Customize y-axis ticks
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(integer=True))
plt.ylim(0, 10)  # Setting y-axis limits from 0 to 10

# Remove x-axis label
plt.xlabel('')

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# #### **2.2. Standard Deviation**

# %%
# Rename columns and copy
renamed_nl_pred_sd = nl_pred.rename(columns={"nl_pred_sd": "Standard Deviation"}).copy()
renamed_en_pred_sd = en_pred.rename(columns={"en_pred_sd": "Standard Deviation"}).copy()

# Create dummy label
renamed_nl_pred_sd['Score'] = 'NL'
renamed_en_pred_sd['Score'] = 'EN'

# Combine DataFrames
combined_data = pd.concat([renamed_nl_pred_sd, renamed_en_pred_sd])

# Create boxplot
plt.figure(figsize=(6, 6))
sns.boxplot(
    x='Score',
    y='Standard Deviation',
    data=combined_data,
    palette=['skyblue', 'lightgreen'],
    boxprops={'edgecolor': 'black'},
    whiskerprops={'color': 'black'},
    flierprops={'marker': 'o', 'color': 'black', 'markerfacecolor': 'black'},
    capprops={'color': 'black'},
    medianprops={'color': 'black'}
)

# Set labels and title
plt.ylabel('Standard Deviation')
# plt.title('Comparison of Standard Deviation')

# Customizing y-axis ticks
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(integer=True))
plt.ylim(0, 5)  # Setting y-axis limits from 0 to 5

# Remove x-axis label
plt.xlabel('')

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# ### **3. Distributions**

# %% [markdown]
# #### **3.1. SimLex-999**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 10

# Define bins
bins = 10

# Plot NL predicted histogram
axes[0].hist(renamed_nl_pred_sl['SimLex-999'], bins=bins, edgecolor='black', color='skyblue')
axes[0].set_title('NL')
axes[0].set_xlabel('SimLex-999')
axes[0].set_ylabel('Frequency')
axes[0].set_xlim(x_min, x_max)
axes[0].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[0].grid(False) # Remove grid

# Plot EN predicted histogram
axes[1].hist(renamed_en_pred_sl['SimLex-999'], bins=bins, edgecolor='black', color='lightgreen')
axes[1].set_title('EN')
axes[1].set_xlabel('SimLex-999')
axes[1].set_ylabel('Frequency')
axes[1].set_xlim(x_min, x_max)
axes[1].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[1].grid(False) # Remove grid

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# #### **3.2. Standard Deviation**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 5

# Define bins
bins = 5

# Plot NL predicted histogram
axes[0].hist(renamed_nl_pred_sd['Standard Deviation'], bins=bins, edgecolor='black', color='skyblue')
axes[0].set_title('NL')
axes[0].set_xlabel('Standard Deviation')
axes[0].set_ylabel('Frequency')
axes[0].set_xlim(x_min, x_max)
axes[0].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[0].grid(False) # Remove grid

# Plot EN predicted histogram
axes[1].hist(renamed_en_pred_sd['Standard Deviation'], bins=bins, edgecolor='black', color='lightgreen')
axes[1].set_title('EN')
axes[1].set_xlabel('Standard Deviation')
axes[1].set_ylabel('Frequency')
axes[1].set_xlim(x_min, x_max)
axes[1].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[1].grid(False) # Remove grid

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# ### **4. Outliers**

# %% [markdown]
# #### **4.1. NL**

# %%
# Count outliers
print_outlier_counts(nl_pred)
# Out:
# No outliers found in columns: nl_pred_sl, nl_pred_sd

# %%
# Row outliers
print_outlier_data(nl_pred, 'nl_pred_sd')
# Out:
# No outliers found in nl_pred_sd

# %% [markdown]
# #### **4.2. EN**

# %%
# Count outliers
print_outlier_counts(en_pred)
# Out:
# Outliers in en_pred_sl: 5
# No outliers found in columns: en_pred_sd

# %%
# Row outliers
print_outlier_data(en_pred, 'en_pred_sd')
# Out:
# No outliers found in en_pred_sd

# %% [markdown]
# #### **4.3. Add to Summary**

# %%
# Calculate outliers
outliers_nl_pred_sl = calculate_outliers(nl_pred, 'nl_pred_sl')
outliers_nl_pred_sd = calculate_outliers(nl_pred, 'nl_pred_sd')
outliers_en_pred_sl = calculate_outliers(en_pred, 'en_pred_sl')
outliers_en_pred_sd = calculate_outliers(en_pred, 'en_pred_sd')

# Count outliers
count_outliers_nl_pred_sl = outliers_nl_pred_sl.shape[0]
count_outliers_nl_pred_sd = outliers_nl_pred_sd.shape[0]
count_outliers_en_pred_sl = outliers_en_pred_sl.shape[0]
count_outliers_en_pred_sd = outliers_en_pred_sd.shape[0]

# Add outliers count to summary
outliers_row = pd.Series([count_outliers_nl_pred_sl, count_outliers_en_pred_sl, count_outliers_nl_pred_sd, count_outliers_en_pred_sd], 
    index=summary_df.columns,
    name='outliers'
)
summary_df = pd.concat([summary_df, outliers_row.to_frame().T])

# Show results
summary_df
# Out:
#           nl_pred_sl  en_pred_sl  nl_pred_sd  en_pred_sd
# count          25.00       25.00       25.00       25.00
# mean            1.31        2.64        1.80        1.74
# std             0.77        2.65        1.01        0.86
# min             0.17        0.45        0.23        0.40
# 25%             0.75        1.11        0.94        0.87
# 50%             1.21        1.62        1.84        2.02
# 75%             2.02        1.99        2.79        2.52
# max             2.54        8.93        3.35        2.85
# median          1.21        1.62        1.84        2.02
# outliers        0.00        5.00        0.00        0.00

# %% [markdown]
# ### **5. Correlation**

# %% [markdown]
# #### **5.1. SimLex-999 vs Standard Deviation**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 10
y_min = 0
y_max = 5

# Create scatter plot
sns.scatterplot(x='nl_pred_sl', y='nl_pred_sd', data=nl_pred, ax=axes[0], color='skyblue', edgecolor='black')

# Plot diagonal line
axes[0].plot([x_min, x_max], [y_min, y_max], color='red', linestyle='--')

# Set axis limits
axes[0].set_xlim(x_min, x_max)
axes[0].set_ylim(y_min, y_max)

# Set labels and title
axes[0].set_xlabel('SimLex-999')
axes[0].set_ylabel('Standard Deviation')
axes[0].set_title('NL')

# Remove grid
axes[0].grid(False)

# Create scatter plot
sns.scatterplot(x='en_pred_sl', y='en_pred_sd', data=en_pred, ax=axes[1], color='lightgreen', edgecolor='black')

# Plot diagonal line
axes[1].plot([x_min, x_max], [y_min, y_max], color='red', linestyle='--')

# Set axis limits
axes[1].set_xlim(x_min, x_max)
axes[1].set_ylim(y_min, y_max)

# Set labels and title
axes[1].set_xlabel('SimLex-999')
axes[1].set_ylabel('Standard Deviation')
axes[1].set_title('EN')

# Remove grid
axes[1].grid(False)

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %%
# List to store correlations
correlations_list = []

# Append correlations to list
correlations_list.append(calculate_correlation_and_pvalue(conc, 'nl_pred_sl', 'nl_pred_sd'))
correlations_list.append(calculate_correlation_and_pvalue(conc, 'en_pred_sl', 'en_pred_sd'))

# Convert list into Pandas DataFrame
correlation_df = pd.DataFrame(correlations_list)

# Show results
correlation_df
# Out:
#     simlex999 standard_deviation  correlation       p_value     significance
# 0  nl_pred_sl         nl_pred_sd      0.97652  7.774752e-17      significant
# 1  en_pred_sl         en_pred_sd      0.05895  7.795584e-01  not significant

# %% [markdown]
# ### **6. Evaluation Metrics**

# %% [markdown]
# #### **6.1. Spearmans's Rank Correlation**

# %% [markdown]
# ##### **6.1.1. NL SimLex-999 vs EN SimLex-999**

# %%
# Scatter plot
plot_scatter_plot(conc, 'nl_pred_sl', 'en_pred_sl', 'SimLex-999 (NL)', 'SimLex-999 (EN)', 0, 10, 0, 10)

# %%
# Correlation and pvalue
print_correlation_and_pvalue(conc, 'nl_pred_sl', 'en_pred_sl')
# Out:
# Spearman's Rank correlation: 0.53264
# P-value: 0.0061224065973817495
# The correlation is statistically significant.

# %% [markdown]
# ##### **6.1.2. NL Standard Deviation vs EN Standard Deviation**

# %%
# Scatter plot
plot_scatter_plot(conc, 'nl_pred_sd', 'en_pred_sd', 'Standard Deviation (NL)', 'Standard Deviation (EN)', 0, 5, 0, 3)

# %%
# Correlation and p-value
print_correlation_and_pvalue(conc, 'nl_pred_sd', 'en_pred_sd')
# Out:
# Spearman's Rank correlation: 0.4385
# P-value: 0.028331904761907244
# The correlation is statistically significant.

# %% [markdown]
# #### **7.2. Mean Square Error (MSE)**

# %%
# Calculate Mean Squared Error
mse = mean_squared_error(conc['nl_pred_sl'], conc['en_pred_sl'])

# Show results
print(f"Mean Squared Error (MSE): {mse:.2f}")
# Out:
# Mean Squared Error (MSE): 8.69

# %% [markdown]
# #### **7.3. Mean Absolute Error (MAE)**

# %%
# Calculate Mean Absolute Error
mae = mean_absolute_error(conc['nl_pred_sl'], conc['en_pred_sl'])

# Show results
print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
# Mean Absolute Error (MAE): 1.78
