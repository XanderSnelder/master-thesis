# %% [markdown]
# ### **0. Set-up**

# %%
# Import libraries and utils
# %run '../../../utils.ipynb'

# %%
# Load NL predicted
raw_nl_pred = pd.read_csv("../../../../data/gpt-3.5-turbo-0125/processed/nl/f3.csv")

# %%
# Load EN predicted
raw_en_pred = pd.read_csv("../../../../data/gpt-3.5-turbo-0125/processed/en/f3.csv")

# Drop rows in EN SimLex that are missing in NL SimLex
raw_en_pred = raw_en_pred.drop(raw_en_pred[(raw_en_pred['word1'] == 'bad') & (raw_en_pred['word2'] == 'awful')].index)
raw_en_pred = raw_en_pred.drop(raw_en_pred[(raw_en_pred['word1'] == 'bad') & (raw_en_pred['word2'] == 'terrible')].index)

# Reset index
raw_en_pred = raw_en_pred.reset_index(drop=True)

# %%
# Select first 25 word pairs
raw_nl_pred = raw_nl_pred.head(25)
raw_en_pred = raw_en_pred.head(25)

# %%
# Show results
raw_nl_pred
# Out:
#           word1        word2  similarity_score_1  similarity_score_2  \
# 0      gelukkig      vrolijk                6.47                6.67
# 1          hard        stoer                1.45                3.33
# 2          snel   razendsnel                7.85               10.00
# 3      gelukkig         blij                8.10                8.33
# 4          kort         lang                1.78                0.00
# 5           dom         stom                6.89                8.33
# 6        vreemd  eigenaardig                9.12               10.00
# 7         breed         smal                1.56                0.00
# 8     makkelijk     moeilijk                3.23                0.00
# 9      moeilijk  gemakkelijk                3.23                0.00
# 10         slim          dom                2.14                0.00
# 11  krankzinnig          gek                8.67               10.00
# 12     gelukkig        kwaad                1.23                1.67
# 13   uitgebreid        groot                5.12                0.00
# 14     moeilijk       simpel                3.65                0.00
# 15        nieuw         vers                6.58               10.00
# 16       scherp         saai                1.25                0.00
# 17         vlug         snel                7.89               10.00
# 18          dom        dwaas                7.58                8.33
# 19     prachtig  fantastisch                7.88                8.33
# 20  eigenaardig       vreemd                8.56               10.00
# 21     gelukkig         boos                1.45                1.67
# 22         smal        breed                1.56                0.00
# 23    eenvoudig  gemakkelijk                8.43                8.33
# 24          oud         vers                1.89                0.00
#
#     similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                  5.0                7.82                 5.0
# 1                  3.0                3.58                 4.0
# 2                  8.0                9.53                 7.0
# 3                  6.0                7.76                 6.5
# 4                  1.0                1.17                 1.0
# 5                  7.0                7.64                 5.5
# 6                  9.0                9.80                 9.0
# 7                  2.0                2.34                 1.0
# 8                  1.0                2.02                 3.0
# 9                  1.0                2.15                 3.0
# 10                 2.0                3.84                 2.0
# 11                 9.0                8.56                 9.0
# 12                 1.0                2.64                 1.0
# 13                 2.0                6.01                 3.0
# 14                 7.0                8.03                 4.0
# 15                 8.0                7.40                 8.0
# 16                 1.0                1.83                 1.0
# 17                 7.0                8.06                 8.0
# 18                 8.0                6.28                 6.5
# 19                 7.0                8.92                 7.5
# 20                 9.0                9.80                 8.5
# 21                 1.0                2.22                 2.0
# 22                 2.0                2.34                 1.0
# 23                 8.0                6.78                 7.0
# 24                 1.0                2.98                 1.0
#
#     similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                 3.33                4.68                5.48
# 1                 4.12                3.00                6.23
# 2                 9.45                7.83                9.30
# 3                 7.16                7.27                8.70
# 4                 1.00                1.55                1.86
# 5                 5.92                7.20                7.48
# 6                 9.80                9.68                9.75
# 7                 1.00                1.55                1.73
# 8                 2.05                2.87                1.15
# 9                 2.05                2.00                1.15
# 10                1.00                2.00                1.25
# 11                9.39                9.69                8.97
# 12                1.52                1.82                1.94
# 13                5.50                2.57                4.63
# 14                6.35                7.45                6.69
# 15                4.90                7.88                8.95
# 16                1.00                2.10                1.06
# 17                7.77                7.03                7.25
# 18                6.06                6.33                9.35
# 19                8.42                7.43                7.91
# 20                9.80                9.68                9.75
# 21                1.52                1.82                2.05
# 22                1.00                1.55                1.73
# 23                8.55                8.38                8.72
# 24                1.00                1.90                2.89
#
#     similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                 3.57                 6.67                 4.23
# 1                 2.00                 5.00                 6.15
# 2                 8.00                10.00                 9.74
# 3                 7.50                 5.83                 7.55
# 4                 1.00                 1.67                 2.84
# 5                 8.00                 4.17                 7.21
# 6                 9.25                10.00                 9.28
# 7                 1.00                 1.67                 2.61
# 8                 1.00                 2.50                 2.76
# 9                 1.00                 2.50                 2.76
# 10                3.00                 0.00                 2.11
# 11                9.00                 9.17                 9.15
# 12                2.00                 2.50                 1.97
# 13                2.00                 3.33                 4.39
# 14                2.00                 1.67                 2.32
# 15                6.00                 8.33                 8.56
# 16                1.00                 0.00                 2.03
# 17                8.00                 8.33                 7.83
# 18                8.67                 8.33                 8.24
# 19                6.50                 8.33                 8.78
# 20                9.33                10.00                 9.64
# 21                1.00                 2.50                 1.97
# 22                1.00                 1.67                 2.61
# 23                6.00                 8.33                 8.74
# 24                1.00                 0.00                 2.50
#
#     similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                   5.0                 7.14                 6.67
# 1                   4.0                 2.67                 4.17
# 2                   9.0                 9.37                10.00
# 3                   7.0                 8.37                 8.33
# 4                   1.0                 1.00                 1.67
# 5                   8.0                 6.00                 8.33
# 6                   9.0                 9.00                 9.17
# 7                   2.0                 1.00                 2.50
# 8                   1.0                 1.00                 2.50
# 9                   1.0                 1.00                 2.50
# 10                  2.0                 2.33                 2.50
# 11                  9.0                 9.00                10.00
# 12                  1.0                 2.18                 2.50
# 13                  3.0                 5.33                 2.50
# 14                  8.0                 4.00                 2.50
# 15                  9.0                 8.00                 5.00
# 16                  1.0                 1.00                 1.67
# 17                  8.5                 8.50                 7.50
# 18                  8.5                 6.33                 8.33
# 19                  5.0                 7.50                 8.33
# 20                  8.5                 8.50                 8.33
# 21                  1.0                 2.38                 2.50
# 22                  2.0                 1.00                 2.50
# 23                  8.5                 8.00                 7.50
# 24                  3.0                 1.50                 1.67
#
#     similarity_score_15
# 0                  5.29
# 1                  2.13
# 2                  9.34
# 3                  7.41
# 4                  1.05
# 5                  8.50
# 6                  9.12
# 7                  1.07
# 8                  1.45
# 9                  6.22
# 10                 2.31
# 11                 8.84
# 12                 1.02
# 13                 2.06
# 14                 2.30
# 15                 7.07
# 16                 1.18
# 17                 7.54
# 18                 8.50
# 19                 7.60
# 20                 8.70
# 21                 1.02
# 22                 1.07
# 23                 6.55
# 24                 1.56

# %%
# Show results
raw_en_pred
# Out:
#         word1      word2  similarity_score_1  similarity_score_2  \
# 0       happy   cheerful                 9.3                8.60
# 1        hard       easy                 1.2                3.44
# 2        fast      rapid                 9.8                9.80
# 3       happy       glad                 8.9                9.20
# 4       short       long                 3.4                2.00
# 5      stupid       dumb                 9.7                8.88
# 6       weird    strange                 8.9                9.70
# 7        wide     narrow                 5.2                3.00
# 8        easy  difficult                 1.1                7.34
# 9        hard     simple                 3.2                3.56
# 10      smart       dumb                 7.6                7.11
# 11     insane      crazy                 9.5                9.60
# 12      happy        mad                 7.8                7.00
# 13      large       huge                 8.4                8.90
# 14       hard      tough                 9.5                8.00
# 15        new      fresh                 8.6                8.70
# 16      sharp       dull                 6.5                6.00
# 17      quick      rapid                 9.8                9.50
# 18       dumb    foolish                 9.6                9.10
# 19  wonderful   terrific                 9.5                9.50
# 20    strange        odd                 9.1                9.30
# 21      happy      angry                 6.1                6.60
# 22     narrow      broad                 7.4                6.00
# 23     simple       easy                 8.1                8.40
# 24        old      fresh                 7.2                3.50
#
#     similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                  9.5                9.20                 9.5
# 1                  2.0                0.36                 2.5
# 2                  9.5                9.20                 9.8
# 3                  8.5                9.20                 8.5
# 4                  2.0                8.77                 1.5
# 5                  9.0                9.20                 9.2
# 6                  9.5                9.57                 8.8
# 7                  2.0                8.13                 2.0
# 8                  2.0                0.36                 3.5
# 9                  3.0                8.13                 2.2
# 10                 8.5                8.13                 8.9
# 11                 9.5                9.57                 9.0
# 12                 7.5                9.20                 6.5
# 13                 8.5                9.20                 8.3
# 14                 8.5                9.20                 8.0
# 15                 8.5                9.57                 8.7
# 16                 8.0                8.13                 7.5
# 17                 9.0                9.57                 9.3
# 18                 9.0                9.20                 8.7
# 19                 9.0                9.20                 8.9
# 20                 9.5                9.57                 9.0
# 21                 6.5                0.36                 6.0
# 22                 2.0                8.13                 6.0
# 23                 9.0                8.77                 8.5
# 24                 6.5                9.20                 4.5
#
#     similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                 8.40                 8.0                9.40
# 1                 1.72                 1.0                1.85
# 2                 9.40                 9.5                9.90
# 3                 7.20                 7.0                9.60
# 4                 3.12                 3.0                8.92
# 5                 8.70                 9.0                9.50
# 6                 8.80                 8.0                9.20
# 7                 5.00                 3.0                7.80
# 8                 3.20                 2.0                2.30
# 9                 3.60                 2.0                4.55
# 10                7.50                 6.0                4.20
# 11                8.60                 9.0                8.80
# 12                5.50                 6.5                8.50
# 13                8.20                 8.0                9.70
# 14                7.00                 8.0                9.15
# 15                7.80                 8.0                8.40
# 16                6.10                 6.0                7.10
# 17                9.10                 9.5                9.80
# 18                7.80                 8.0                9.35
# 19                9.20                 8.5                9.55
# 20                8.70                 9.0                9.60
# 21                5.10                 5.0                7.05
# 22                5.60                 3.0                8.40
# 23                8.60                 9.0                8.95
# 24                5.80                 6.0                7.50
#
#     similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                  7.5                 8.84                  7.5
# 1                  2.5                 2.63                  3.0
# 2                  8.5                 9.58                  9.5
# 3                  8.0                 9.50                  8.0
# 4                  2.5                 5.69                  2.0
# 5                  8.0                 9.69                  9.0
# 6                  8.5                 9.21                  8.5
# 7                  3.0                 6.04                  2.0
# 8                  4.0                 8.11                  1.5
# 9                  2.5                 7.28                  2.5
# 10                 7.0                 8.88                  8.5
# 11                 8.5                 9.21                  9.2
# 12                 4.5                 8.47                  7.0
# 13                 8.5                 8.41                  8.0
# 14                 7.5                 8.68                  8.0
# 15                 7.0                 8.14                  6.5
# 16                 6.5                 8.58                  7.5
# 17                 8.5                 9.45                  9.5
# 18                 8.0                 9.49                  8.5
# 19                 8.5                 9.73                  9.5
# 20                 8.5                 9.31                  9.5
# 21                 4.5                 7.74                  5.0
# 22                 7.0                 6.69                  2.5
# 23                 7.0                 9.29                  8.0
# 24                 4.0                 7.55                  5.5
#
#     similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                   7.5                 8.31                 8.82
# 1                   3.5                 2.59                 1.20
# 2                   9.0                 9.68                 9.20
# 3                   8.5                 8.14                 8.82
# 4                   5.0                 1.73                 7.00
# 5                   9.5                 8.52                 9.80
# 6                   8.5                 8.94                 8.80
# 7                   4.0                 2.84                 6.00
# 8                   5.0                 3.16                 3.20
# 9                   3.0                 2.87                 4.50
# 10                  7.5                 5.79                 9.20
# 11                  9.5                 8.43                 8.80
# 12                  6.0                 7.29                 7.80
# 13                  9.5                 8.22                 8.00
# 14                  7.5                 7.15                 8.60
# 15                  8.5                 7.73                 8.60
# 16                  6.5                 6.00                 7.00
# 17                  9.5                 8.77                 9.20
# 18                  8.0                 8.07                 9.00
# 19                  9.0                 9.34                 8.80
# 20                  8.5                 8.80                 9.80
# 21                  6.0                 4.63                 5.00
# 22                  6.0                 4.29                 6.00
# 23                  7.5                 7.08                 7.20
# 24                  6.0                 5.37                 4.20
#
#     similarity_score_15
# 0                  3.33
# 1                  1.29
# 2                  9.68
# 3                  6.00
# 4                  5.67
# 5                  9.59
# 6                  8.51
# 7                  6.63
# 8                  5.10
# 9                  2.55
# 10                 9.59
# 11                 9.41
# 12                 3.67
# 13                 8.26
# 14                 6.96
# 15                 5.93
# 16                 6.69
# 17                 9.49
# 18                 8.04
# 19                 9.13
# 20                 9.17
# 21                 2.83
# 22                 5.94
# 23                 7.68
# 24                 4.66

# %% [markdown]
# ### **1. Data Processing**

# %%
# Copy dataframe
nl_pred = raw_nl_pred.copy()

# List of columns to calculate mean SimLex-999
similarity_cols = [f"similarity_score_{i}" for i in range(1, 16)]

# Calculate the mean SimLex-999
nl_pred['nl_pred_sl'] = nl_pred[similarity_cols].mean(axis=1).round(2)

# Calculate the standard deviation SimLex-999
nl_pred['nl_pred_sd'] = nl_pred[similarity_cols].std(axis=1).round(2)

# Select columns
nl_pred = nl_pred[['word1', 'word2', 'nl_pred_sl', 'nl_pred_sd']]

# Show results
nl_pred
# Out:
#           word1        word2  nl_pred_sl  nl_pred_sd
# 0      gelukkig      vrolijk        5.53        1.33
# 1          hard        stoer        3.66        1.40
# 2          snel   razendsnel        8.96        0.97
# 3      gelukkig         blij        7.45        0.86
# 4          kort         lang        1.31        0.63
# 5           dom         stom        7.08        1.22
# 6        vreemd  eigenaardig        9.40        0.39
# 7         breed         smal        1.54        0.70
# 8     makkelijk     moeilijk        1.84        0.96
# 9      moeilijk  gemakkelijk        2.10        1.46
# 10         slim          dom        1.90        1.01
# 11  krankzinnig          gek        9.16        0.43
# 12     gelukkig        kwaad        1.73        0.59
# 13   uitgebreid        groot        3.43        1.68
# 14     moeilijk       simpel        4.40        2.63
# 15        nieuw         vers        7.58        1.45
# 16       scherp         saai        1.14        0.61
# 17         vlug         snel        7.95        0.74
# 18          dom        dwaas        7.69        1.08
# 19     prachtig  fantastisch        7.70        0.99
# 20  eigenaardig       vreemd        9.21        0.64
# 21     gelukkig         boos        1.74        0.56
# 22         smal        breed        1.54        0.70
# 23    eenvoudig  gemakkelijk        7.85        0.87
# 24          oud         vers        1.59        0.97

# %%
# Copy dataframe
en_pred = raw_en_pred.copy()

# List of columns to calculate mean SimLex-999
similarity_cols = [f"similarity_score_{i}" for i in range(1, 16)]

# Calculate the mean SimLex-999
en_pred['en_pred_sl'] = en_pred[similarity_cols].mean(axis=1).round(2)

# Calculate the standard deviation SimLex-999
en_pred['en_pred_sd'] = en_pred[similarity_cols].std(axis=1).round(2)

# Select columns
en_pred = en_pred[['word1', 'word2', 'en_pred_sl', 'en_pred_sd']]

# Show results
en_pred
# Out:
#         word1      word2  en_pred_sl  en_pred_sd
# 0       happy   cheerful        8.25        1.54
# 1        hard       easy        2.05        0.93
# 2        fast      rapid        9.47        0.37
# 3       happy       glad        8.34        1.00
# 4       short       long        4.15        2.54
# 5      stupid       dumb        9.15        0.50
# 6       weird    strange        8.90        0.47
# 7        wide     narrow        4.44        2.11
# 8        easy  difficult        3.46        2.19
# 9        hard     simple        3.70        1.79
# 10      smart       dumb        7.63        1.46
# 11     insane      crazy        9.11        0.41
# 12      happy        mad        6.88        1.51
# 13      large       huge        8.54        0.54
# 14       hard      tough        8.12        0.81
# 15        new      fresh        8.04        0.94
# 16      sharp       dull        6.94        0.84
# 17      quick      rapid        9.33        0.36
# 18       dumb    foolish        8.66        0.63
# 19  wonderful   terrific        9.16        0.38
# 20    strange        odd        9.16        0.41
# 21      happy      angry        5.23        1.80
# 22     narrow      broad        5.66        1.93
# 23     simple       easy        8.20        0.76
# 24        old      fresh        5.83        1.57

# %%
# Concatenate NL and EN DataFrames
conc = pd.concat([nl_pred, en_pred], axis=1)

# Show results
conc
# Out:
#           word1        word2  nl_pred_sl  nl_pred_sd      word1      word2  \
# 0      gelukkig      vrolijk        5.53        1.33      happy   cheerful
# 1          hard        stoer        3.66        1.40       hard       easy
# 2          snel   razendsnel        8.96        0.97       fast      rapid
# 3      gelukkig         blij        7.45        0.86      happy       glad
# 4          kort         lang        1.31        0.63      short       long
# 5           dom         stom        7.08        1.22     stupid       dumb
# 6        vreemd  eigenaardig        9.40        0.39      weird    strange
# 7         breed         smal        1.54        0.70       wide     narrow
# 8     makkelijk     moeilijk        1.84        0.96       easy  difficult
# 9      moeilijk  gemakkelijk        2.10        1.46       hard     simple
# 10         slim          dom        1.90        1.01      smart       dumb
# 11  krankzinnig          gek        9.16        0.43     insane      crazy
# 12     gelukkig        kwaad        1.73        0.59      happy        mad
# 13   uitgebreid        groot        3.43        1.68      large       huge
# 14     moeilijk       simpel        4.40        2.63       hard      tough
# 15        nieuw         vers        7.58        1.45        new      fresh
# 16       scherp         saai        1.14        0.61      sharp       dull
# 17         vlug         snel        7.95        0.74      quick      rapid
# 18          dom        dwaas        7.69        1.08       dumb    foolish
# 19     prachtig  fantastisch        7.70        0.99  wonderful   terrific
# 20  eigenaardig       vreemd        9.21        0.64    strange        odd
# 21     gelukkig         boos        1.74        0.56      happy      angry
# 22         smal        breed        1.54        0.70     narrow      broad
# 23    eenvoudig  gemakkelijk        7.85        0.87     simple       easy
# 24          oud         vers        1.59        0.97        old      fresh
#
#     en_pred_sl  en_pred_sd
# 0         8.25        1.54
# 1         2.05        0.93
# 2         9.47        0.37
# 3         8.34        1.00
# 4         4.15        2.54
# 5         9.15        0.50
# 6         8.90        0.47
# 7         4.44        2.11
# 8         3.46        2.19
# 9         3.70        1.79
# 10        7.63        1.46
# 11        9.11        0.41
# 12        6.88        1.51
# 13        8.54        0.54
# 14        8.12        0.81
# 15        8.04        0.94
# 16        6.94        0.84
# 17        9.33        0.36
# 18        8.66        0.63
# 19        9.16        0.38
# 20        9.16        0.41
# 21        5.23        1.80
# 22        5.66        1.93
# 23        8.20        0.76
# 24        5.83        1.57

# %% [markdown]
# ### **2. Descriptive Statistics**

# %%
# Summary statistics SimLex-999
nl_pred_sl_summary = round(nl_pred['nl_pred_sl'].describe(), 2)
en_pred_sl_summary = round(en_pred['en_pred_sl'].describe(), 2)

# Add median SimLex-999
nl_pred_sl_summary['median'] = round(nl_pred['nl_pred_sl'].median(), 2)
en_pred_sl_summary['median'] = round(en_pred['en_pred_sl'].median(), 2)

# Summary statistics standard deviations
nl_pred_sd_summary = round(nl_pred['nl_pred_sd'].describe(), 2)
en_pred_sd_summary = round(en_pred['en_pred_sd'].describe(), 2)

# Add median standard deviation
nl_pred_sd_summary['median'] = round(nl_pred['nl_pred_sd'].median(), 2)
en_pred_sd_summary['median'] = round(en_pred['en_pred_sd'].median(), 2)

# Create pandas DataFrame
summary_df = pd.DataFrame({
    "nl_pred_sl": nl_pred_sl_summary,
    "en_pred_sl": en_pred_sl_summary,
    "nl_pred_sd": nl_pred_sd_summary,
    "en_pred_sd": en_pred_sd_summary
})

# Show results
summary_df
# Out:
#         nl_pred_sl  en_pred_sl  nl_pred_sd  en_pred_sd
# count        25.00       25.00       25.00       25.00
# mean          4.94        7.14        0.99        1.11
# std           3.14        2.19        0.48        0.67
# min           1.14        2.05        0.39        0.36
# 25%           1.74        5.66        0.64        0.50
# 50%           4.40        8.12        0.96        0.93
# 75%           7.70        8.90        1.22        1.57
# max           9.40        9.47        2.63        2.54
# median        4.40        8.12        0.96        0.93

# %% [markdown]
# #### **2.1. SimLex-999**

# %%
# Rename columns and copy
renamed_nl_pred_sl = nl_pred.rename(columns={"nl_pred_sl": "SimLex-999"}).copy()
renamed_en_pred_sl = en_pred.rename(columns={"en_pred_sl": "SimLex-999"}).copy()

# Create dummy label
renamed_nl_pred_sl['Score'] = 'NL'
renamed_en_pred_sl['Score'] = 'EN'

# Combine DataFrames
combined_data = pd.concat([renamed_nl_pred_sl, renamed_en_pred_sl])

# Create boxplot
plt.figure(figsize=(6, 6))
sns.boxplot(
    x='Score',
    y='SimLex-999',
    data=combined_data,
    palette=['skyblue', 'lightgreen'],
    boxprops={'edgecolor': 'black'},
    whiskerprops={'color': 'black'},
    flierprops={'marker': 'o', 'color': 'black', 'markerfacecolor': 'black'},
    capprops={'color': 'black'},
    medianprops={'color': 'black'}
)

# Set labels and title
plt.ylabel('SimLex-999')
# plt.title('Comparison of SimLex-999')

# Customize y-axis ticks
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(integer=True))
plt.ylim(0, 10)  # Setting y-axis limits from 0 to 10

# Remove x-axis label
plt.xlabel('')

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# #### **2.2. Standard Deviation**

# %%
# Rename columns and copy
renamed_nl_pred_sd = nl_pred.rename(columns={"nl_pred_sd": "Standard Deviation"}).copy()
renamed_en_pred_sd = en_pred.rename(columns={"en_pred_sd": "Standard Deviation"}).copy()

# Create dummy label
renamed_nl_pred_sd['Score'] = 'NL'
renamed_en_pred_sd['Score'] = 'EN'

# Combine DataFrames
combined_data = pd.concat([renamed_nl_pred_sd, renamed_en_pred_sd])

# Create boxplot
plt.figure(figsize=(6, 6))
sns.boxplot(
    x='Score',
    y='Standard Deviation',
    data=combined_data,
    palette=['skyblue', 'lightgreen'],
    boxprops={'edgecolor': 'black'},
    whiskerprops={'color': 'black'},
    flierprops={'marker': 'o', 'color': 'black', 'markerfacecolor': 'black'},
    capprops={'color': 'black'},
    medianprops={'color': 'black'}
)

# Set labels and title
plt.ylabel('Standard Deviation')
# plt.title('Comparison of Standard Deviation')

# Customizing y-axis ticks
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(integer=True))
plt.ylim(0, 5)  # Setting y-axis limits from 0 to 5

# Remove x-axis label
plt.xlabel('')

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# ### **3. Distributions**

# %% [markdown]
# #### **3.1. SimLex-999**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 10

# Define bins
bins = 10

# Plot NL predicted histogram
axes[0].hist(renamed_nl_pred_sl['SimLex-999'], bins=bins, edgecolor='black', color='skyblue')
axes[0].set_title('NL')
axes[0].set_xlabel('SimLex-999')
axes[0].set_ylabel('Frequency')
axes[0].set_xlim(x_min, x_max)
axes[0].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[0].grid(False) # Remove grid

# Plot EN predicted histogram
axes[1].hist(renamed_en_pred_sl['SimLex-999'], bins=bins, edgecolor='black', color='lightgreen')
axes[1].set_title('EN')
axes[1].set_xlabel('SimLex-999')
axes[1].set_ylabel('Frequency')
axes[1].set_xlim(x_min, x_max)
axes[1].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[1].grid(False) # Remove grid

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# #### **3.2. Standard Deviation**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 5

# Define bins
bins = 5

# Plot NL predicted histogram
axes[0].hist(renamed_nl_pred_sd['Standard Deviation'], bins=bins, edgecolor='black', color='skyblue')
axes[0].set_title('NL')
axes[0].set_xlabel('Standard Deviation')
axes[0].set_ylabel('Frequency')
axes[0].set_xlim(x_min, x_max)
axes[0].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[0].grid(False) # Remove grid

# Plot EN predicted histogram
axes[1].hist(renamed_en_pred_sd['Standard Deviation'], bins=bins, edgecolor='black', color='lightgreen')
axes[1].set_title('EN')
axes[1].set_xlabel('Standard Deviation')
axes[1].set_ylabel('Frequency')
axes[1].set_xlim(x_min, x_max)
axes[1].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[1].grid(False) # Remove grid

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# ### **4. Outliers**

# %% [markdown]
# #### **4.1. NL**

# %%
# Count outliers
print_outlier_counts(nl_pred)
# Out:
# Outliers in nl_pred_sd: 1
# No outliers found in columns: nl_pred_sl

# %%
# Row outliers
print_outlier_data(nl_pred, 'nl_pred_sd')
# Out:
# Outliers in nl_pred_sd:
#        word1   word2  nl_pred_sl  nl_pred_sd
# 14  moeilijk  simpel         4.4        2.63

# %% [markdown]
# #### **4.2. EN**

# %%
# Count outliers
print_outlier_counts(en_pred)
# Out:
# No outliers found in columns: en_pred_sl, en_pred_sd

# %%
# Row outliers
print_outlier_data(en_pred, 'en_pred_sd')
# Out:
# No outliers found in en_pred_sd

# %% [markdown]
# #### **4.3. Add to Summary**

# %%
# Calculate outliers
outliers_nl_pred_sl = calculate_outliers(nl_pred, 'nl_pred_sl')
outliers_nl_pred_sd = calculate_outliers(nl_pred, 'nl_pred_sd')
outliers_en_pred_sl = calculate_outliers(en_pred, 'en_pred_sl')
outliers_en_pred_sd = calculate_outliers(en_pred, 'en_pred_sd')

# Count outliers
count_outliers_nl_pred_sl = outliers_nl_pred_sl.shape[0]
count_outliers_nl_pred_sd = outliers_nl_pred_sd.shape[0]
count_outliers_en_pred_sl = outliers_en_pred_sl.shape[0]
count_outliers_en_pred_sd = outliers_en_pred_sd.shape[0]

# Add outliers count to summary
outliers_row = pd.Series([count_outliers_nl_pred_sl, count_outliers_en_pred_sl, count_outliers_nl_pred_sd, count_outliers_en_pred_sd], 
    index=summary_df.columns,
    name='outliers'
)
summary_df = pd.concat([summary_df, outliers_row.to_frame().T])

# Show results
summary_df
# Out:
#           nl_pred_sl  en_pred_sl  nl_pred_sd  en_pred_sd
# count          25.00       25.00       25.00       25.00
# mean            4.94        7.14        0.99        1.11
# std             3.14        2.19        0.48        0.67
# min             1.14        2.05        0.39        0.36
# 25%             1.74        5.66        0.64        0.50
# 50%             4.40        8.12        0.96        0.93
# 75%             7.70        8.90        1.22        1.57
# max             9.40        9.47        2.63        2.54
# median          4.40        8.12        0.96        0.93
# outliers        0.00        0.00        1.00        0.00

# %% [markdown]
# ### **5. Correlation**

# %% [markdown]
# #### **5.1. SimLex-999 vs Standard Deviation**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 10
y_min = 0
y_max = 5

# Create scatter plot
sns.scatterplot(x='nl_pred_sl', y='nl_pred_sd', data=nl_pred, ax=axes[0], color='skyblue', edgecolor='black')

# Plot diagonal line
axes[0].plot([x_min, x_max], [y_min, y_max], color='red', linestyle='--')

# Set axis limits
axes[0].set_xlim(x_min, x_max)
axes[0].set_ylim(y_min, y_max)

# Set labels and title
axes[0].set_xlabel('SimLex-999')
axes[0].set_ylabel('Standard Deviation')
axes[0].set_title('NL')

# Remove grid
axes[0].grid(False)

# Create scatter plot
sns.scatterplot(x='en_pred_sl', y='en_pred_sd', data=en_pred, ax=axes[1], color='lightgreen', edgecolor='black')

# Plot diagonal line
axes[1].plot([x_min, x_max], [y_min, y_max], color='red', linestyle='--')

# Set axis limits
axes[1].set_xlim(x_min, x_max)
axes[1].set_ylim(y_min, y_max)

# Set labels and title
axes[1].set_xlabel('SimLex-999')
axes[1].set_ylabel('Standard Deviation')
axes[1].set_title('EN')

# Remove grid
axes[1].grid(False)

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %%
# List to store correlations
correlations_list = []

# Append correlations to list
correlations_list.append(calculate_correlation_and_pvalue(conc, 'nl_pred_sl', 'nl_pred_sd'))
correlations_list.append(calculate_correlation_and_pvalue(conc, 'en_pred_sl', 'en_pred_sd'))

# Convert list into Pandas DataFrame
correlation_df = pd.DataFrame(correlations_list)

# Show results
correlation_df
# Out:
#     simlex999 standard_deviation  correlation       p_value     significance
# 0  nl_pred_sl         nl_pred_sd      0.03694  8.608248e-01  not significant
# 1  en_pred_sl         en_pred_sd     -0.88900  2.890786e-09      significant

# %% [markdown]
# ### **6. Evaluation Metrics**

# %% [markdown]
# #### **6.1. Spearmans's Rank Correlation**

# %% [markdown]
# ##### **6.1.1. NL SimLex-999 vs EN SimLex-999**

# %%
# Scatter plot
plot_scatter_plot(conc, 'nl_pred_sl', 'en_pred_sl', 'SimLex-999 (NL)', 'SimLex-999 (EN)', 0, 10, 0, 10)

# %%
# Correlation and pvalue
print_correlation_and_pvalue(conc, 'nl_pred_sl', 'en_pred_sl')
# Out:
# Spearman's Rank correlation: 0.79223
# P-value: 2.365845081360141e-06
# The correlation is statistically significant.

# %% [markdown]
# ##### **6.1.2. NL Standard Deviation vs EN Standard Deviation**

# %%
# Scatter plot
plot_scatter_plot(conc, 'nl_pred_sd', 'en_pred_sd', 'Standard Deviation (NL)', 'Standard Deviation (EN)', 0, 5, 0, 3)

# %%
# Correlation and p-value
print_correlation_and_pvalue(conc, 'nl_pred_sd', 'en_pred_sd')
# Out:
# Spearman's Rank correlation: -0.04657
# P-value: 0.8250719463567959
# The correlation is not statistically significant.

# %% [markdown]
# #### **7.2. Mean Square Error (MSE)**

# %%
# Calculate Mean Squared Error
mse = mean_squared_error(conc['nl_pred_sl'], conc['en_pred_sl'])

# Show results
print(f"Mean Squared Error (MSE): {mse:.2f}")
# Out:
# Mean Squared Error (MSE): 8.91

# %% [markdown]
# #### **7.3. Mean Absolute Error (MAE)**

# %%
# Calculate Mean Absolute Error
mae = mean_absolute_error(conc['nl_pred_sl'], conc['en_pred_sl'])

# Show results
print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
# Mean Absolute Error (MAE): 2.37
