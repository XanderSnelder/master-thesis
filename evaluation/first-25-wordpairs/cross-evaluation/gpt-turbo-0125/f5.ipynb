# %% [markdown]
# ### **0. Set-up**

# %%
# Import libraries and utils
# %run '../../../utils.ipynb'

# %%
# Load NL predicted
raw_nl_pred = pd.read_csv("../../../../data/gpt-3.5-turbo-0125/processed/nl/f5.csv")

# %%
# Load EN predicted
raw_en_pred = pd.read_csv("../../../../data/gpt-3.5-turbo-0125/processed/en/f5.csv")

# Drop rows in EN SimLex that are missing in NL SimLex
raw_en_pred = raw_en_pred.drop(raw_en_pred[(raw_en_pred['word1'] == 'bad') & (raw_en_pred['word2'] == 'awful')].index)
raw_en_pred = raw_en_pred.drop(raw_en_pred[(raw_en_pred['word1'] == 'bad') & (raw_en_pred['word2'] == 'terrible')].index)

# Reset index
raw_en_pred = raw_en_pred.reset_index(drop=True)

# %%
# Select first 25 word pairs
raw_nl_pred = raw_nl_pred.head(25)
raw_en_pred = raw_en_pred.head(25)

# %%
# Show results
raw_nl_pred
# Out:
#           word1        word2 similarity_score_1 similarity_score_2  \
# 0           oud        nieuw      zeer ongelijk      zeer ongelijk
# 1          slim  intelligent             gelijk             gelijk
# 2          hard     moeilijk           neutraal           ongelijk
# 3      gelukkig      vrolijk             gelijk             gelijk
# 4          hard        stoer           neutraal             gelijk
# 5          snel   razendsnel             gelijk             gelijk
# 6      gelukkig         blij             gelijk             gelijk
# 7          kort         lang      zeer ongelijk      zeer ongelijk
# 8           dom         stom             gelijk             gelijk
# 9        vreemd  eigenaardig             gelijk             gelijk
# 10        breed         smal      zeer ongelijk           ongelijk
# 11    makkelijk     moeilijk      zeer ongelijk           ongelijk
# 12     moeilijk  gemakkelijk      zeer ongelijk      zeer ongelijk
# 13         slim          dom      zeer ongelijk      zeer ongelijk
# 14  krankzinnig          gek             gelijk             gelijk
# 15     gelukkig        kwaad      zeer ongelijk      zeer ongelijk
# 16   uitgebreid        groot             gelijk           ongelijk
# 17     moeilijk       simpel           neutraal           ongelijk
# 18        nieuw         vers             gelijk             gelijk
# 19       scherp         saai      zeer ongelijk      zeer ongelijk
# 20         vlug         snel             gelijk             gelijk
# 21          dom        dwaas             gelijk             gelijk
# 22     prachtig  fantastisch             gelijk             gelijk
# 23  eigenaardig       vreemd             gelijk             gelijk
# 24     gelukkig         boos      zeer ongelijk      zeer ongelijk
#
#    similarity_score_3 similarity_score_4 similarity_score_5  \
# 0       zeer ongelijk      zeer ongelijk      zeer ongelijk
# 1              gelijk             gelijk             gelijk
# 2            neutraal           ongelijk           ongelijk
# 3            ongelijk             gelijk           ongelijk
# 4            ongelijk           ongelijk           ongelijk
# 5         zeer gelijk             gelijk             gelijk
# 6              gelijk             gelijk             gelijk
# 7       zeer ongelijk           ongelijk           ongelijk
# 8              gelijk             gelijk             gelijk
# 9              gelijk             gelijk             gelijk
# 10      zeer ongelijk           ongelijk           ongelijk
# 11           ongelijk           ongelijk      zeer ongelijk
# 12      zeer ongelijk           ongelijk      zeer ongelijk
# 13           ongelijk           ongelijk      zeer ongelijk
# 14             gelijk             gelijk             gelijk
# 15      zeer ongelijk      zeer ongelijk      zeer ongelijk
# 16      zeer ongelijk           ongelijk           ongelijk
# 17           neutraal           ongelijk           ongelijk
# 18             gelijk             gelijk             gelijk
# 19           ongelijk           ongelijk           ongelijk
# 20           ongelijk             gelijk             gelijk
# 21             gelijk             gelijk             gelijk
# 22           ongelijk             gelijk             gelijk
# 23             gelijk             gelijk             gelijk
# 24      zeer ongelijk      zeer ongelijk      zeer ongelijk
#
#    similarity_score_6 similarity_score_7 similarity_score_8  \
# 0       zeer ongelijk      zeer ongelijk      zeer ongelijk
# 1              gelijk             gelijk             gelijk
# 2            ongelijk           ongelijk           ongelijk
# 3            ongelijk           neutraal           ongelijk
# 4              gelijk      zeer ongelijk           ongelijk
# 5              gelijk           neutraal             gelijk
# 6            ongelijk           neutraal             gelijk
# 7            ongelijk      zeer ongelijk           ongelijk
# 8              gelijk             gelijk             gelijk
# 9              gelijk             gelijk             gelijk
# 10           ongelijk      zeer ongelijk           ongelijk
# 11           ongelijk           ongelijk      zeer ongelijk
# 12             gelijk           ongelijk      zeer ongelijk
# 13           ongelijk      zeer ongelijk      zeer ongelijk
# 14             gelijk             gelijk             gelijk
# 15           ongelijk      zeer ongelijk      zeer ongelijk
# 16           ongelijk           neutraal           ongelijk
# 17           ongelijk      zeer ongelijk           ongelijk
# 18             gelijk           neutraal             gelijk
# 19           ongelijk      zeer ongelijk           ongelijk
# 20             gelijk           neutraal             gelijk
# 21             gelijk             gelijk             gelijk
# 22             gelijk             gelijk           ongelijk
# 23             gelijk        zeer gelijk             gelijk
# 24           ongelijk      zeer ongelijk      zeer ongelijk
#
#    similarity_score_9 similarity_score_10 similarity_score_11  \
# 0       zeer ongelijk       zeer ongelijk       zeer ongelijk
# 1              gelijk              gelijk              gelijk
# 2            ongelijk            ongelijk              gelijk
# 3              gelijk              gelijk            neutraal
# 4            ongelijk            neutraal            ongelijk
# 5         zeer gelijk              gelijk         zeer gelijk
# 6              gelijk              gelijk              gelijk
# 7            ongelijk       zeer ongelijk       zeer ongelijk
# 8              gelijk              gelijk         zeer gelijk
# 9              gelijk              gelijk              gelijk
# 10           ongelijk            neutraal       zeer ongelijk
# 11           ongelijk       zeer ongelijk            ongelijk
# 12           ongelijk            ongelijk            ongelijk
# 13      zeer ongelijk       zeer ongelijk       zeer ongelijk
# 14             gelijk              gelijk              gelijk
# 15      zeer ongelijk       zeer ongelijk       zeer ongelijk
# 16           ongelijk            ongelijk            ongelijk
# 17           ongelijk            ongelijk            ongelijk
# 18             gelijk              gelijk            neutraal
# 19           ongelijk            ongelijk       zeer ongelijk
# 20           ongelijk              gelijk              gelijk
# 21             gelijk              gelijk         zeer gelijk
# 22             gelijk              gelijk              gelijk
# 23             gelijk              gelijk              gelijk
# 24      zeer ongelijk       zeer ongelijk       zeer ongelijk
#
#    similarity_score_12 similarity_score_13 similarity_score_14  \
# 0        zeer ongelijk       zeer ongelijk       zeer ongelijk
# 1               gelijk              gelijk              gelijk
# 2             neutraal            ongelijk            ongelijk
# 3               gelijk            neutraal              gelijk
# 4             ongelijk            ongelijk            ongelijk
# 5          zeer gelijk         zeer gelijk              gelijk
# 6               gelijk              gelijk              gelijk
# 7        zeer ongelijk       zeer ongelijk            ongelijk
# 8               gelijk              gelijk              gelijk
# 9               gelijk              gelijk              gelijk
# 10       zeer ongelijk       zeer ongelijk            ongelijk
# 11            ongelijk       zeer ongelijk       zeer ongelijk
# 12            ongelijk            ongelijk       zeer ongelijk
# 13       zeer ongelijk       zeer ongelijk       zeer ongelijk
# 14              gelijk              gelijk              gelijk
# 15       zeer ongelijk       zeer ongelijk       zeer ongelijk
# 16              gelijk       zeer ongelijk              gelijk
# 17            ongelijk       zeer ongelijk            ongelijk
# 18              gelijk              gelijk         zeer gelijk
# 19            ongelijk       zeer ongelijk            ongelijk
# 20            ongelijk            neutraal              gelijk
# 21              gelijk              gelijk              gelijk
# 22              gelijk         zeer gelijk              gelijk
# 23              gelijk              gelijk              gelijk
# 24       zeer ongelijk       zeer ongelijk       zeer ongelijk
#
#    similarity_score_15
# 0        zeer ongelijk
# 1               gelijk
# 2             ongelijk
# 3               gelijk
# 4             neutraal
# 5          zeer gelijk
# 6               gelijk
# 7        zeer ongelijk
# 8               gelijk
# 9               gelijk
# 10       zeer ongelijk
# 11            ongelijk
# 12            ongelijk
# 13            ongelijk
# 14              gelijk
# 15       zeer ongelijk
# 16            ongelijk
# 17            ongelijk
# 18            neutraal
# 19            ongelijk
# 20              gelijk
# 21              gelijk
# 22              gelijk
# 23              gelijk
# 24       zeer ongelijk

# %%
# Show results
raw_en_pred
# Out:
#         word1        word2 similarity_score_1 similarity_score_2  \
# 0         old          new    very dissimilar    very dissimilar
# 1       smart  intelligent       very similar       very similar
# 2        hard    difficult            similar            similar
# 3       happy     cheerful       very similar            similar
# 4        hard         easy         dissimilar         dissimilar
# 5        fast        rapid            similar            similar
# 6       happy         glad            similar            similar
# 7       short         long            similar         dissimilar
# 8      stupid         dumb       very similar            similar
# 9       weird      strange       very similar       very similar
# 10       wide       narrow         dissimilar         dissimilar
# 11       easy    difficult    very dissimilar         dissimilar
# 12       hard       simple    very dissimilar         dissimilar
# 13      smart         dumb    very dissimilar    very dissimilar
# 14     insane        crazy       very similar       very similar
# 15      happy          mad            similar            similar
# 16      large         huge       very similar       very similar
# 17       hard        tough            similar            similar
# 18        new        fresh            similar            similar
# 19      sharp         dull    very dissimilar         dissimilar
# 20      quick        rapid            similar            similar
# 21       dumb      foolish            similar            similar
# 22  wonderful     terrific       very similar       very similar
# 23    strange          odd       very similar       very similar
# 24      happy        angry            similar         dissimilar
#
#    similarity_score_3 similarity_score_4 similarity_score_5  \
# 0     very dissimilar    very dissimilar    very dissimilar
# 1        very similar       very similar       very similar
# 2             similar            similar            similar
# 3        very similar            similar            similar
# 4     very dissimilar    very dissimilar    very dissimilar
# 5             similar       very similar            similar
# 6             similar            similar            similar
# 7          dissimilar    very dissimilar         dissimilar
# 8        very similar       very similar            similar
# 9        very similar            similar            similar
# 10         dissimilar    very dissimilar         dissimilar
# 11    very dissimilar    very dissimilar    very dissimilar
# 12    very dissimilar    very dissimilar    very dissimilar
# 13    very dissimilar    very dissimilar    very dissimilar
# 14       very similar       very similar            similar
# 15            similar            similar            similar
# 16            similar       very similar            similar
# 17            similar            similar            similar
# 18            similar            similar            similar
# 19         dissimilar    very dissimilar         dissimilar
# 20            similar       very similar            similar
# 21            similar       very similar            similar
# 22       very similar       very similar            similar
# 23            similar       very similar            similar
# 24         dissimilar    very dissimilar         dissimilar
#
#    similarity_score_6 similarity_score_7 similarity_score_8  \
# 0     very dissimilar    very dissimilar    very dissimilar
# 1        very similar       very similar       very similar
# 2             similar            similar            similar
# 3        very similar            similar            similar
# 4          dissimilar         dissimilar    very dissimilar
# 5             similar            similar            similar
# 6        very similar            similar            similar
# 7             similar         dissimilar         dissimilar
# 8        very similar       very similar       very similar
# 9             similar            similar            similar
# 10            similar         dissimilar         dissimilar
# 11         dissimilar         dissimilar    very dissimilar
# 12         dissimilar         dissimilar    very dissimilar
# 13    very dissimilar    very dissimilar    very dissimilar
# 14       very similar       very similar            similar
# 15            similar            similar         dissimilar
# 16       very similar       very similar            similar
# 17            similar            similar            similar
# 18            similar            similar            similar
# 19            similar         dissimilar         dissimilar
# 20            similar            similar            similar
# 21       very similar       very similar            similar
# 22       very similar       very similar            similar
# 23       very similar            similar            similar
# 24            similar         dissimilar         dissimilar
#
#    similarity_score_9 similarity_score_10 similarity_score_11  \
# 0     very dissimilar     very dissimilar     very dissimilar
# 1        very similar        very similar        very similar
# 2             similar             similar             similar
# 3             similar             similar             similar
# 4          dissimilar     very dissimilar     very dissimilar
# 5             similar        very similar             similar
# 6             similar             similar             similar
# 7          dissimilar          dissimilar          dissimilar
# 8        very similar        very similar        very similar
# 9        very similar             similar        very similar
# 10         dissimilar     very dissimilar          dissimilar
# 11         dissimilar     very dissimilar     very dissimilar
# 12         dissimilar     very dissimilar          dissimilar
# 13    very dissimilar     very dissimilar     very dissimilar
# 14            similar        very similar        very similar
# 15            similar     very dissimilar             similar
# 16            similar             similar             similar
# 17            similar             similar             similar
# 18            similar             similar             similar
# 19         dissimilar     very dissimilar          dissimilar
# 20            similar             similar             similar
# 21            similar        very similar        very similar
# 22            similar        very similar        very similar
# 23       very similar        very similar        very similar
# 24    very dissimilar     very dissimilar     very dissimilar
#
#    similarity_score_12 similarity_score_13 similarity_score_14  \
# 0      very dissimilar          dissimilar     very dissimilar
# 1         very similar        very similar        very similar
# 2              similar             similar             similar
# 3              similar             similar             similar
# 4           dissimilar          dissimilar          dissimilar
# 5              similar             similar             similar
# 6              similar        very similar             similar
# 7           dissimilar             similar          dissimilar
# 8         very similar        very similar             similar
# 9              similar        very similar             similar
# 10          dissimilar          dissimilar          dissimilar
# 11          dissimilar          dissimilar          dissimilar
# 12          dissimilar          dissimilar          dissimilar
# 13     very dissimilar     very dissimilar     very dissimilar
# 14        very similar        very similar             similar
# 15             similar             similar             similar
# 16             similar             similar             similar
# 17             similar             similar             similar
# 18             similar             similar             similar
# 19          dissimilar          dissimilar          dissimilar
# 20             similar             similar             similar
# 21        very similar             similar             similar
# 22        very similar             similar        very similar
# 23        very similar        very similar             similar
# 24          dissimilar          dissimilar          dissimilar
#
#    similarity_score_15
# 0      very dissimilar
# 1         very similar
# 2              similar
# 3              similar
# 4      very dissimilar
# 5              similar
# 6              similar
# 7      very dissimilar
# 8              similar
# 9         very similar
# 10          dissimilar
# 11          dissimilar
# 12          dissimilar
# 13     very dissimilar
# 14        very similar
# 15             similar
# 16             similar
# 17             similar
# 18             similar
# 19          dissimilar
# 20             similar
# 21        very similar
# 22             similar
# 23        very similar
# 24          dissimilar

# %% [markdown]
# ### **1. Data Processing**

# %%
# Copy dataframe
nl_pred = raw_nl_pred.copy()

# List of columns to scale
similarity_cols = [f"similarity_score_{i}" for i in range(1, 16)]

# Mapping of categorical scale
categorical_mapping = {
    'zeer ongelijk': 0,
    'ongelijk': 2.5,
    'neutraal': 5,
    'gelijk': 7.5,
    'zeer gelijk': 10
}

# Apply mapping
for col in similarity_cols:
    nl_pred[col] = nl_pred[col].map(categorical_mapping)

# Calculate the mean SimLex-999
nl_pred['nl_pred_sl'] = nl_pred[similarity_cols].mean(axis=1).round(2)

# Calculate the standard deviation SimLex-999
nl_pred['nl_pred_sd'] = nl_pred[similarity_cols].std(axis=1).round(2)

# Select columns
nl_pred = nl_pred[['word1', 'word2', 'nl_pred_sl', 'nl_pred_sd']]

# Show results
nl_pred
# Out:
#           word1        word2  nl_pred_sl  nl_pred_sd
# 0           oud        nieuw        0.00        0.00
# 1          slim  intelligent        7.50        0.00
# 2          hard     moeilijk        3.33        1.54
# 3      gelukkig      vrolijk        5.67        2.21
# 4          hard        stoer        3.50        2.07
# 5          snel   razendsnel        8.33        1.54
# 6      gelukkig         blij        7.00        1.40
# 7          kort         lang        1.00        1.27
# 8           dom         stom        7.67        0.65
# 9        vreemd  eigenaardig        7.50        0.00
# 10        breed         smal        1.50        1.58
# 11    makkelijk     moeilijk        1.50        1.27
# 12     moeilijk  gemakkelijk        1.83        2.00
# 13         slim          dom        0.67        1.14
# 14  krankzinnig          gek        7.50        0.00
# 15     gelukkig        kwaad        0.17        0.65
# 16   uitgebreid        groot        3.33        2.44
# 17     moeilijk       simpel        2.50        1.34
# 18        nieuw         vers        7.17        1.29
# 19       scherp         saai        1.67        1.22
# 20         vlug         snel        6.17        2.08
# 21          dom        dwaas        7.67        0.65
# 22     prachtig  fantastisch        7.00        1.94
# 23  eigenaardig       vreemd        7.67        0.65
# 24     gelukkig         boos        0.17        0.65

# %%
# Copy dataframe
en_pred = raw_en_pred.copy()

# List of columns to scale
similarity_cols = [f"similarity_score_{i}" for i in range(1, 16)]

# Mapping of categorical scale
categorical_mapping = {
    'very dissimilar': 0,
    'dissimilar': 2.5,
    'neutral': 5,
    'similar': 7.5,
    'very similar': 10
}

# Apply mapping
for col in similarity_cols:
    en_pred[col] = en_pred[col].map(categorical_mapping)

# Calculate the mean SimLex-999
en_pred['en_pred_sl'] = en_pred[similarity_cols].mean(axis=1).round(2)

# Calculate the standard deviation SimLex-999
en_pred['en_pred_sd'] = en_pred[similarity_cols].std(axis=1).round(2)

# Select columns
en_pred = en_pred[['word1', 'word2', 'en_pred_sl', 'en_pred_sd']]

# Show results
en_pred
# Out:
#         word1        word2  en_pred_sl  en_pred_sd
# 0         old          new        0.17        0.65
# 1       smart  intelligent       10.00        0.00
# 2        hard    difficult        7.50        0.00
# 3       happy     cheerful        8.00        1.04
# 4        hard         easy        1.33        1.29
# 5        fast        rapid        7.83        0.88
# 6       happy         glad        7.83        0.88
# 7       short         long        3.17        2.40
# 8      stupid         dumb        9.33        1.14
# 9       weird      strange        8.67        1.29
# 10       wide       narrow        2.50        1.64
# 11       easy    difficult        1.33        1.29
# 12       hard       simple        1.50        1.27
# 13      smart         dumb        0.00        0.00
# 14     insane        crazy        9.33        1.14
# 15      happy          mad        6.67        2.25
# 16      large         huge        8.33        1.22
# 17       hard        tough        7.50        0.00
# 18        new        fresh        7.50        0.00
# 19      sharp         dull        2.33        1.76
# 20      quick        rapid        7.67        0.65
# 21       dumb      foolish        8.67        1.29
# 22  wonderful     terrific        9.17        1.22
# 23    strange          odd        9.17        1.22
# 24      happy        angry        2.50        2.31

# %%
# Concatenate NL and EN DataFrames
conc = pd.concat([nl_pred, en_pred], axis=1)

# Show results
conc
# Out:
#           word1        word2  nl_pred_sl  nl_pred_sd      word1        word2  \
# 0           oud        nieuw        0.00        0.00        old          new
# 1          slim  intelligent        7.50        0.00      smart  intelligent
# 2          hard     moeilijk        3.33        1.54       hard    difficult
# 3      gelukkig      vrolijk        5.67        2.21      happy     cheerful
# 4          hard        stoer        3.50        2.07       hard         easy
# 5          snel   razendsnel        8.33        1.54       fast        rapid
# 6      gelukkig         blij        7.00        1.40      happy         glad
# 7          kort         lang        1.00        1.27      short         long
# 8           dom         stom        7.67        0.65     stupid         dumb
# 9        vreemd  eigenaardig        7.50        0.00      weird      strange
# 10        breed         smal        1.50        1.58       wide       narrow
# 11    makkelijk     moeilijk        1.50        1.27       easy    difficult
# 12     moeilijk  gemakkelijk        1.83        2.00       hard       simple
# 13         slim          dom        0.67        1.14      smart         dumb
# 14  krankzinnig          gek        7.50        0.00     insane        crazy
# 15     gelukkig        kwaad        0.17        0.65      happy          mad
# 16   uitgebreid        groot        3.33        2.44      large         huge
# 17     moeilijk       simpel        2.50        1.34       hard        tough
# 18        nieuw         vers        7.17        1.29        new        fresh
# 19       scherp         saai        1.67        1.22      sharp         dull
# 20         vlug         snel        6.17        2.08      quick        rapid
# 21          dom        dwaas        7.67        0.65       dumb      foolish
# 22     prachtig  fantastisch        7.00        1.94  wonderful     terrific
# 23  eigenaardig       vreemd        7.67        0.65    strange          odd
# 24     gelukkig         boos        0.17        0.65      happy        angry
#
#     en_pred_sl  en_pred_sd
# 0         0.17        0.65
# 1        10.00        0.00
# 2         7.50        0.00
# 3         8.00        1.04
# 4         1.33        1.29
# 5         7.83        0.88
# 6         7.83        0.88
# 7         3.17        2.40
# 8         9.33        1.14
# 9         8.67        1.29
# 10        2.50        1.64
# 11        1.33        1.29
# 12        1.50        1.27
# 13        0.00        0.00
# 14        9.33        1.14
# 15        6.67        2.25
# 16        8.33        1.22
# 17        7.50        0.00
# 18        7.50        0.00
# 19        2.33        1.76
# 20        7.67        0.65
# 21        8.67        1.29
# 22        9.17        1.22
# 23        9.17        1.22
# 24        2.50        2.31

# %% [markdown]
# ### **2. Descriptive Statistics**

# %%
# Summary statistics SimLex-999
nl_pred_sl_summary = round(nl_pred['nl_pred_sl'].describe(), 2)
en_pred_sl_summary = round(en_pred['en_pred_sl'].describe(), 2)

# Add median SimLex-999
nl_pred_sl_summary['median'] = round(nl_pred['nl_pred_sl'].median(), 2)
en_pred_sl_summary['median'] = round(en_pred['en_pred_sl'].median(), 2)

# Summary statistics standard deviations
nl_pred_sd_summary = round(nl_pred['nl_pred_sd'].describe(), 2)
en_pred_sd_summary = round(en_pred['en_pred_sd'].describe(), 2)

# Add median standard deviation
nl_pred_sd_summary['median'] = round(nl_pred['nl_pred_sd'].median(), 2)
en_pred_sd_summary['median'] = round(en_pred['en_pred_sd'].median(), 2)

# Create pandas DataFrame
summary_df = pd.DataFrame({
    "nl_pred_sl": nl_pred_sl_summary,
    "en_pred_sl": en_pred_sl_summary,
    "nl_pred_sd": nl_pred_sd_summary,
    "en_pred_sd": en_pred_sd_summary
})

# Show results
summary_df
# Out:
#         nl_pred_sl  en_pred_sl  nl_pred_sd  en_pred_sd
# count        25.00       25.00       25.00       25.00
# mean          4.32        5.92        1.18        1.07
# std           3.03        3.41        0.74        0.71
# min           0.00        0.00        0.00        0.00
# 25%           1.50        2.50        0.65        0.65
# 50%           3.50        7.50        1.27        1.22
# 75%           7.50        8.67        1.58        1.29
# max           8.33       10.00        2.44        2.40
# median        3.50        7.50        1.27        1.22

# %% [markdown]
# #### **2.1. SimLex-999**

# %%
# Rename columns and copy
renamed_nl_pred_sl = nl_pred.rename(columns={"nl_pred_sl": "SimLex-999"}).copy()
renamed_en_pred_sl = en_pred.rename(columns={"en_pred_sl": "SimLex-999"}).copy()

# Create dummy label
renamed_nl_pred_sl['Score'] = 'NL'
renamed_en_pred_sl['Score'] = 'EN'

# Combine DataFrames
combined_data = pd.concat([renamed_nl_pred_sl, renamed_en_pred_sl])

# Create boxplot
plt.figure(figsize=(6, 6))
sns.boxplot(
    x='Score',
    y='SimLex-999',
    data=combined_data,
    palette=['skyblue', 'lightgreen'],
    boxprops={'edgecolor': 'black'},
    whiskerprops={'color': 'black'},
    flierprops={'marker': 'o', 'color': 'black', 'markerfacecolor': 'black'},
    capprops={'color': 'black'},
    medianprops={'color': 'black'}
)

# Set labels and title
plt.ylabel('SimLex-999')
# plt.title('Comparison of SimLex-999')

# Customize y-axis ticks
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(integer=True))
plt.ylim(0, 10.1)  # Setting y-axis limits from 0 to 10

# Remove x-axis label
plt.xlabel('')

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# #### **2.2. Standard Deviation**

# %%
# Rename columns and copy
renamed_nl_pred_sd = nl_pred.rename(columns={"nl_pred_sd": "Standard Deviation"}).copy()
renamed_en_pred_sd = en_pred.rename(columns={"en_pred_sd": "Standard Deviation"}).copy()

# Create dummy label
renamed_nl_pred_sd['Score'] = 'NL'
renamed_en_pred_sd['Score'] = 'EN'

# Combine DataFrames
combined_data = pd.concat([renamed_nl_pred_sd, renamed_en_pred_sd])

# Create boxplot
plt.figure(figsize=(6, 6))
sns.boxplot(
    x='Score',
    y='Standard Deviation',
    data=combined_data,
    palette=['skyblue', 'lightgreen'],
    boxprops={'edgecolor': 'black'},
    whiskerprops={'color': 'black'},
    flierprops={'marker': 'o', 'color': 'black', 'markerfacecolor': 'black'},
    capprops={'color': 'black'},
    medianprops={'color': 'black'}
)

# Set labels and title
plt.ylabel('Standard Deviation')
# plt.title('Comparison of Standard Deviation')

# Customizing y-axis ticks
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(integer=True))
plt.ylim(0, 5)  # Setting y-axis limits from 0 to 5

# Remove x-axis label
plt.xlabel('')

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# ### **3. Distributions**

# %% [markdown]
# #### **3.1. SimLex-999**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 10

# Define bins
bins = 10

# Plot NL predicted histogram
axes[0].hist(renamed_nl_pred_sl['SimLex-999'], bins=bins, edgecolor='black', color='skyblue')
axes[0].set_title('NL')
axes[0].set_xlabel('SimLex-999')
axes[0].set_ylabel('Frequency')
axes[0].set_xlim(x_min, x_max)
axes[0].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[0].grid(False) # Remove grid

# Plot EN predicted histogram
axes[1].hist(renamed_en_pred_sl['SimLex-999'], bins=bins, edgecolor='black', color='lightgreen')
axes[1].set_title('EN')
axes[1].set_xlabel('SimLex-999')
axes[1].set_ylabel('Frequency')
axes[1].set_xlim(x_min, x_max)
axes[1].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[1].grid(False) # Remove grid

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# #### **3.2. Standard Deviation**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 5

# Define bins
bins = 5

# Plot NL predicted histogram
axes[0].hist(renamed_nl_pred_sd['Standard Deviation'], bins=bins, edgecolor='black', color='skyblue')
axes[0].set_title('NL')
axes[0].set_xlabel('Standard Deviation')
axes[0].set_ylabel('Frequency')
axes[0].set_xlim(x_min, x_max)
axes[0].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[0].grid(False) # Remove grid

# Plot EN predicted histogram
axes[1].hist(renamed_en_pred_sd['Standard Deviation'], bins=bins, edgecolor='black', color='lightgreen')
axes[1].set_title('EN')
axes[1].set_xlabel('Standard Deviation')
axes[1].set_ylabel('Frequency')
axes[1].set_xlim(x_min, x_max)
axes[1].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[1].grid(False) # Remove grid

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# ### **4. Outliers**

# %% [markdown]
# #### **4.1. NL**

# %%
# Count outliers
print_outlier_counts(nl_pred)
# Out:
# No outliers found in columns: nl_pred_sl, nl_pred_sd

# %%
# Row outliers
print_outlier_data(nl_pred, 'nl_pred_sd')
# Out:
# No outliers found in nl_pred_sd

# %% [markdown]
# #### **4.2. EN**

# %%
# Count outliers
print_outlier_counts(en_pred)
# Out:
# Outliers in en_pred_sd: 2
# No outliers found in columns: en_pred_sl

# %%
# Row outliers
print_outlier_data(en_pred, 'en_pred_sl')
# Out:
# No outliers found in en_pred_sl

# %% [markdown]
# #### **4.3. Add to Summary**

# %%
# Calculate outliers
outliers_nl_pred_sl = calculate_outliers(nl_pred, 'nl_pred_sl')
outliers_nl_pred_sd = calculate_outliers(nl_pred, 'nl_pred_sd')
outliers_en_pred_sl = calculate_outliers(en_pred, 'en_pred_sl')
outliers_en_pred_sd = calculate_outliers(en_pred, 'en_pred_sd')

# Count outliers
count_outliers_nl_pred_sl = outliers_nl_pred_sl.shape[0]
count_outliers_nl_pred_sd = outliers_nl_pred_sd.shape[0]
count_outliers_en_pred_sl = outliers_en_pred_sl.shape[0]
count_outliers_en_pred_sd = outliers_en_pred_sd.shape[0]

# Add outliers count to summary
outliers_row = pd.Series([count_outliers_nl_pred_sl, count_outliers_en_pred_sl, count_outliers_nl_pred_sd, count_outliers_en_pred_sd], 
    index=summary_df.columns,
    name='outliers'
)
summary_df = pd.concat([summary_df, outliers_row.to_frame().T])

# Show results
summary_df
# Out:
#           nl_pred_sl  en_pred_sl  nl_pred_sd  en_pred_sd
# count          25.00       25.00       25.00       25.00
# mean            4.32        5.92        1.18        1.07
# std             3.03        3.41        0.74        0.71
# min             0.00        0.00        0.00        0.00
# 25%             1.50        2.50        0.65        0.65
# 50%             3.50        7.50        1.27        1.22
# 75%             7.50        8.67        1.58        1.29
# max             8.33       10.00        2.44        2.40
# median          3.50        7.50        1.27        1.22
# outliers        0.00        0.00        0.00        2.00

# %% [markdown]
# ### **5. Correlation**

# %% [markdown]
# #### **5.1. SimLex-999 vs Standard Deviation**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 10
y_min = 0
y_max = 5

# Create scatter plot
sns.scatterplot(x='nl_pred_sl', y='nl_pred_sd', data=nl_pred, ax=axes[0], color='skyblue', edgecolor='black')

# Plot diagonal line
axes[0].plot([x_min, x_max], [y_min, y_max], color='red', linestyle='--')

# Set axis limits
axes[0].set_xlim(x_min, x_max)
axes[0].set_ylim(y_min, y_max)

# Set labels and title
axes[0].set_xlabel('SimLex-999')
axes[0].set_ylabel('Standard Deviation')
axes[0].set_title('NL')

# Remove grid
axes[0].grid(False)

# Create scatter plot
sns.scatterplot(x='en_pred_sl', y='en_pred_sd', data=en_pred, ax=axes[1], color='lightgreen', edgecolor='black')

# Plot diagonal line
axes[1].plot([x_min, x_max], [y_min, y_max], color='red', linestyle='--')

# Set axis limits
axes[1].set_xlim(x_min, x_max)
axes[1].set_ylim(y_min, y_max)

# Set labels and title
axes[1].set_xlabel('SimLex-999')
axes[1].set_ylabel('Standard Deviation')
axes[1].set_title('EN')

# Remove grid
axes[1].grid(False)

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %%
# List to store correlations
correlations_list = []

# Append correlations to list
correlations_list.append(calculate_correlation_and_pvalue(conc, 'nl_pred_sl', 'nl_pred_sd'))
correlations_list.append(calculate_correlation_and_pvalue(conc, 'en_pred_sl', 'en_pred_sd'))

# Convert list into Pandas DataFrame
correlation_df = pd.DataFrame(correlations_list)

# Show results
correlation_df
# Out:
#     simlex999 standard_deviation  correlation   p_value     significance
# 0  nl_pred_sl         nl_pred_sd     -0.06284  0.765391  not significant
# 1  en_pred_sl         en_pred_sd     -0.19523  0.349679  not significant

# %% [markdown]
# ### **6. Evaluation Metrics**

# %% [markdown]
# #### **6.1. Spearmans's Rank Correlation**

# %% [markdown]
# ##### **6.1.1. NL SimLex-999 vs EN SimLex-999**

# %%
# Scatter plot
plot_scatter_plot(conc, 'nl_pred_sl', 'en_pred_sl', 'SimLex-999 (NL)', 'SimLex-999 (EN)', 0, 10, 0, 10)

# %%
# Correlation and pvalue
print_correlation_and_pvalue(conc, 'nl_pred_sl', 'en_pred_sl')
# Out:
# Spearman's Rank correlation: 0.81132
# P-value: 8.637723930885557e-07
# The correlation is statistically significant.

# %% [markdown]
# ##### **6.1.2. NL Standard Deviation vs EN Standard Deviation**

# %%
# Scatter plot
plot_scatter_plot(conc, 'nl_pred_sd', 'en_pred_sd', 'Standard Deviation (NL)', 'Standard Deviation (EN)', 0, 5, 0, 3)

# %%
# Correlation and p-value
print_correlation_and_pvalue(conc, 'nl_pred_sd', 'en_pred_sd')
# Out:
# Spearman's Rank correlation: -0.06841
# P-value: 0.7452503204628728
# The correlation is not statistically significant.

# %% [markdown]
# #### **7.2. Mean Square Error (MSE)**

# %%
# Calculate Mean Squared Error
mse = mean_squared_error(conc['nl_pred_sl'], conc['en_pred_sl'])

# Show results
print(f"Mean Squared Error (MSE): {mse:.2f}")
# Out:
# Mean Squared Error (MSE): 6.28

# %% [markdown]
# #### **7.3. Mean Absolute Error (MAE)**

# %%
# Calculate Mean Absolute Error
mae = mean_absolute_error(conc['nl_pred_sl'], conc['en_pred_sl'])

# Show results
print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
# Mean Absolute Error (MAE): 1.91

# %% [markdown]
# #### **7.4. Bland-Altman**

# %%
# SimLex-999
bland_altman_plot(data1=conc['nl_pred_sl'], data2=conc['en_pred_sl'])

# %%
# Standard Deviation
bland_altman_plot(data1=conc['nl_pred_sd'], data2=conc['en_pred_sd'])
