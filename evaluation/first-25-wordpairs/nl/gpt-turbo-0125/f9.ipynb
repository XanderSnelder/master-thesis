# %% [markdown]
# ### **0. Set-up**

# %%
# Import libraries and utils
# %run '../../../utils.ipynb'

# %%
# Load predicted
f9_1 = pd.read_csv("../../../../data/gpt-3.5-turbo-0125/processed/nl/f9-1.csv")
f9_2 = pd.read_csv("../../../../data/gpt-3.5-turbo-0125/processed/nl/f9-2.csv")
f9_3 = pd.read_csv("../../../../data/gpt-3.5-turbo-0125/processed/nl/f9-3.csv")

# Combine the dataframes
raw_predicted = pd.concat([f9_1, f9_2, f9_3], ignore_index=True)

# Load actual
raw_actual = pd.read_csv("../../../../data/dataset/cleaned-nl-simlex-999.csv")

# %%
# Select first 25 word pairs
raw_predicted = raw_predicted.head(25)
raw_actual = raw_actual.head(25)

# %%
# Show results
raw_predicted
# Out:
#           word1        word2  similarity_score_1  similarity_score_2  \
# 0           oud        nieuw                0.10                1.91
# 1          slim  intelligent                8.50                9.00
# 2          hard     moeilijk                7.50                7.20
# 3      gelukkig      vrolijk                5.80                6.50
# 4          hard        stoer                6.00                0.30
# 5          snel   razendsnel                9.50                8.50
# 6      gelukkig         blij                7.50                7.95
# 7          kort         lang                0.00                0.00
# 8           dom         stom                8.50                8.50
# 9        vreemd  eigenaardig                8.50                8.50
# 10        breed         smal                1.00                1.00
# 11    makkelijk     moeilijk                7.80                8.50
# 12     moeilijk  gemakkelijk                9.70                9.50
# 13         slim          dom                1.00                1.00
# 14  krankzinnig          gek                9.50                9.50
# 15     gelukkig        kwaad                2.67                0.10
# 16   uitgebreid        groot                2.15                2.50
# 17     moeilijk       simpel                1.00                0.10
# 18        nieuw         vers                8.50                8.50
# 19       scherp         saai                1.57                0.00
# 20         vlug         snel                9.50                9.00
# 21          dom        dwaas                7.50                8.50
# 22     prachtig  fantastisch                8.50                8.50
# 23  eigenaardig       vreemd                8.50                7.50
# 24     gelukkig         boos                0.10                0.10
#
#     similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                 1.00                0.14                2.00
# 1                 8.70                9.00                9.00
# 2                 7.50                8.00                9.50
# 3                 7.50                8.50                0.65
# 4                 6.00                6.50                7.50
# 5                 9.00                9.00                9.00
# 6                 7.80                8.60                7.50
# 7                 0.00                1.00                0.00
# 8                 8.00                9.00                9.00
# 9                 8.50                8.50                7.50
# 10                0.00                1.00                0.00
# 11                8.70                7.50                9.20
# 12                9.50                9.80                8.50
# 13                1.00                1.00                2.14
# 14                8.50                9.00                9.50
# 15                0.12                0.25                1.20
# 16                3.20                3.20                3.50
# 17                2.50                1.20                1.00
# 18                7.00                6.67                6.50
# 19                2.50                0.20                0.10
# 20                8.00                9.00                8.50
# 21                8.50                8.50                8.00
# 22                8.50                8.50                8.50
# 23                7.65                7.50                8.50
# 24                0.10                0.11                1.57
#
#     similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                 0.25                1.00                0.10
# 1                 9.50                8.50                9.00
# 2                 8.00                8.50                8.50
# 3                 7.50                7.50                9.00
# 4                 7.50                0.60                5.50
# 5                 9.50                9.00                8.50
# 6                 7.50                7.50                8.50
# 7                 0.10                0.10                0.10
# 8                 8.50                8.50                8.50
# 9                 8.50                8.50                8.50
# 10                1.00                0.00                1.00
# 11                9.50                8.50                9.75
# 12                8.50                8.50                9.80
# 13                1.00                1.00                0.10
# 14                9.50                9.00                9.50
# 15                0.20                1.20                0.05
# 16                0.15                0.12                2.53
# 17                1.00                1.50                1.20
# 18                6.33                6.00                7.50
# 19                1.20                0.21                1.50
# 20                9.00                8.80                9.00
# 21                9.00                8.50                7.50
# 22                8.50                8.50                8.50
# 23                7.50                7.00                7.50
# 24                0.10                0.10                1.20
#
#     similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                 1.00                 1.00                 1.00
# 1                 9.00                 9.50                 8.50
# 2                 8.50                 8.50                 8.50
# 3                 7.50                 7.50                 6.50
# 4                 5.65                 0.30                 6.50
# 5                 8.50                 9.00                 9.00
# 6                 8.80                 8.50                 6.75
# 7                 0.00                 0.10                 1.00
# 8                 9.50                 9.00                 9.00
# 9                 8.50                 8.50                 8.50
# 10                0.00                 2.75                 1.00
# 11                7.80                 9.20                 9.60
# 12                7.50                 9.00                 9.00
# 13                1.00                 1.00                 1.00
# 14                9.80                 8.00                 9.00
# 15                1.20                 1.20                 0.21
# 16                4.20                 3.64                 3.12
# 17                2.50                 1.50                 1.00
# 18                8.25                 5.00                 7.50
# 19                1.50                 1.20                 1.50
# 20                8.50                 8.50                 9.50
# 21                9.50                 8.50                 8.25
# 22                8.50                 8.50                 8.50
# 23                7.50                 8.50                 8.50
# 24                1.20                 0.10                 0.00
#
#     similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                  0.10                 1.00                 1.00
# 1                  8.50                 8.50                 8.50
# 2                  7.50                 6.50                 7.50
# 3                  7.50                 7.50                 7.50
# 4                  0.20                 5.00                 0.40
# 5                  8.50                 8.90                 9.00
# 6                  7.50                 7.50                 8.50
# 7                  0.00                 0.00                 0.00
# 8                  9.00                 8.50                 9.00
# 9                  8.50                 8.50                 7.50
# 10                 1.00                 1.00                 1.00
# 11                 9.50                 8.50                 9.45
# 12                 8.50                 9.50                 1.00
# 13                 1.00                 2.00                 1.67
# 14                 9.00                 9.50                 9.50
# 15                 0.00                 1.00                 0.10
# 16                 2.75                 3.21                 0.21
# 17                 1.50                 0.10                 1.90
# 18                 7.50                 5.67                 6.33
# 19                 0.12                 1.20                 1.50
# 20                 8.50                 9.00                 9.00
# 21                 9.00                 9.50                 9.00
# 22                 8.50                 9.00                 8.50
# 23                 8.50                 7.50                 7.50
# 24                 1.20                 1.20                 0.10
#
#     similarity_score_15
# 0                  0.20
# 1                  8.50
# 2                  9.00
# 3                  7.50
# 4                  6.00
# 5                  9.00
# 6                  7.50
# 7                  0.00
# 8                  9.50
# 9                  7.50
# 10                 1.00
# 11                 9.80
# 12                 9.00
# 13                 1.00
# 14                 9.80
# 15                 0.10
# 16                 2.56
# 17                 1.20
# 18                 7.50
# 19                 1.20
# 20                 9.00
# 21                 8.50
# 22                 8.50
# 23                 7.50
# 24                 0.20

# %% [markdown]
# ### **1. Data Quality**

# %%
# Basic info
raw_predicted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   word1                25 non-null     object
#  1   word2                25 non-null     object
#  2   similarity_score_1   25 non-null     float64
#  3   similarity_score_2   25 non-null     float64
#  4   similarity_score_3   25 non-null     float64
#  5   similarity_score_4   25 non-null     float64
#  6   similarity_score_5   25 non-null     float64
#  7   similarity_score_6   25 non-null     float64
#  8   similarity_score_7   25 non-null     float64
#  9   similarity_score_8   25 non-null     float64
#  10  similarity_score_9   25 non-null     float64
#  11  similarity_score_10  25 non-null     float64
#  12  similarity_score_11  25 non-null     float64
#  13  similarity_score_12  25 non-null     float64
#  14  similarity_score_13  25 non-null     float64
#  15  similarity_score_14  25 non-null     float64
#  16  similarity_score_15  25 non-null     float64
# dtypes: float64(15), object(2)
# memory usage: 3.4+ KB

# %%
# Missing values per column
raw_predicted.isnull().sum()
# Out:
# word1                  0
# word2                  0
# similarity_score_1     0
# similarity_score_2     0
# similarity_score_3     0
# similarity_score_4     0
# similarity_score_5     0
# similarity_score_6     0
# similarity_score_7     0
# similarity_score_8     0
# similarity_score_9     0
# similarity_score_10    0
# similarity_score_11    0
# similarity_score_12    0
# similarity_score_13    0
# similarity_score_14    0
# similarity_score_15    0
# dtype: int64

# %%
# Select word pairs and copy
wordpairs_predicted = raw_predicted[['word1', 'word2']].copy()
wordpairs_actual = raw_actual[['word1', 'word2']].copy()

# Remove whitespace
wordpairs_actual['word1'] = wordpairs_actual['word1'].replace(" ", "", regex=True)
wordpairs_actual['word2'] = wordpairs_actual['word2'].replace(" ", "", regex=True)

# Check if actual is identical to predicted
are_identical = wordpairs_actual.equals(wordpairs_predicted)
print("Word pairs in Actual are identical to Predicted:", are_identical)

# If not identical, show the differences
differences = None
if not are_identical:
    differences = wordpairs_actual.compare(wordpairs_predicted)
    differences.columns = ['Word1 Actual', 'Word1 Predicted', 'Word2 Actual', 'Word2 Predicted']

# Show results
differences if differences is not None else print("No differences found")
# Out:
# Word pairs in Actual are identical to Predicted: True
# No differences found

# %% [markdown]
# ### **2. Data Processing**

# %%
# Copy dataframe
predicted = raw_predicted.copy()

# List of columns to calculate mean SimLex-999
similarity_cols = [f"similarity_score_{i}" for i in range(1, 16)]

# Calculate the mean SimLex-999
predicted['pred_sl'] = predicted[similarity_cols].mean(axis=1).round(2)

# Calculate the standard deviation SimLex-999
predicted['pred_sd'] = predicted[similarity_cols].std(axis=1).round(2)

# Select columns
predicted = predicted[['word1', 'word2', 'pred_sl', 'pred_sd']]

# Show results
predicted
# Out:
#           word1        word2  pred_sl  pred_sd
# 0           oud        nieuw     0.79     0.63
# 1          slim  intelligent     8.81     0.36
# 2          hard     moeilijk     8.05     0.77
# 3      gelukkig      vrolijk     6.96     1.90
# 4          hard        stoer     4.26     2.93
# 5          snel   razendsnel     8.93     0.32
# 6      gelukkig         blij     7.86     0.59
# 7          kort         lang     0.16     0.34
# 8           dom         stom     8.80     0.41
# 9        vreemd  eigenaardig     8.30     0.41
# 10        breed         smal     0.85     0.69
# 11    makkelijk     moeilijk     8.89     0.76
# 12     moeilijk  gemakkelijk     8.49     2.17
# 13         slim          dom     1.13     0.49
# 14  krankzinnig          gek     9.24     0.49
# 15     gelukkig        kwaad     0.64     0.75
# 16   uitgebreid        groot     2.47     1.30
# 17     moeilijk       simpel     1.28     0.69
# 18        nieuw         vers     6.98     1.04
# 19       scherp         saai     1.03     0.74
# 20         vlug         snel     8.85     0.40
# 21          dom        dwaas     8.55     0.60
# 22     prachtig  fantastisch     8.53     0.13
# 23  eigenaardig       vreemd     7.81     0.52
# 24     gelukkig         boos     0.49     0.58

# %%
# Copy dataframe
actual = raw_actual.copy()

# Rename columns
actual = actual.rename(columns={'SimLex999': 'act_sl', 'std_dev': 'act_sd'})

# Select columns
actual = actual[['word1', 'word2', 'act_sl', 'act_sd']]

# Show results
actual
# Out:
#           word1        word2  act_sl  act_sd
# 0           oud        nieuw    1.94    2.42
# 1          slim  intelligent    8.19    1.54
# 2          hard     moeilijk    4.46    3.18
# 3      gelukkig      vrolijk    6.49    2.15
# 4          hard        stoer    5.69    2.94
# 5          snel   razendsnel    7.18    1.74
# 6      gelukkig         blij    7.09    2.21
# 7          kort         lang    1.78    2.52
# 8           dom         stom    4.67    3.22
# 9        vreemd  eigenaardig    7.41    2.90
# 10        breed         smal    1.79    2.28
# 11    makkelijk     moeilijk    2.17    3.03
# 12     moeilijk  gemakkelijk    1.92    2.58
# 13         slim          dom    2.72    3.12
# 14  krankzinnig          gek    8.02    2.06
# 15     gelukkig        kwaad    2.95    3.20
# 16   uitgebreid        groot    5.58    2.59
# 17     moeilijk       simpel    2.24    2.07
# 18        nieuw         vers    6.69    2.06
# 19       scherp         saai    0.95    1.47
# 20         vlug         snel    8.95    1.27
# 21          dom        dwaas    6.57    2.58
# 22     prachtig  fantastisch    6.30    2.14
# 23  eigenaardig       vreemd    8.56    1.30
# 24     gelukkig         boos    0.98    1.77

# %%
# Remove whitespace
predicted['word1'] = predicted['word1'].replace(" ", "", regex=True)
predicted['word2'] = predicted['word2'].replace(" ", "", regex=True)

# Remove whitespace
actual['word1'] = actual['word1'].replace(" ", "", regex=True)
actual['word2'] = actual['word2'].replace(" ", "", regex=True)

# %%
# Merge predicted and actual DataFrames
merged = pd.merge(predicted, actual, on=['word1', 'word2'])

# Show results
merged
# Out:
#           word1        word2  pred_sl  pred_sd  act_sl  act_sd
# 0           oud        nieuw     0.79     0.63    1.94    2.42
# 1          slim  intelligent     8.81     0.36    8.19    1.54
# 2          hard     moeilijk     8.05     0.77    4.46    3.18
# 3      gelukkig      vrolijk     6.96     1.90    6.49    2.15
# 4          hard        stoer     4.26     2.93    5.69    2.94
# 5          snel   razendsnel     8.93     0.32    7.18    1.74
# 6      gelukkig         blij     7.86     0.59    7.09    2.21
# 7          kort         lang     0.16     0.34    1.78    2.52
# 8           dom         stom     8.80     0.41    4.67    3.22
# 9        vreemd  eigenaardig     8.30     0.41    7.41    2.90
# 10        breed         smal     0.85     0.69    1.79    2.28
# 11    makkelijk     moeilijk     8.89     0.76    2.17    3.03
# 12     moeilijk  gemakkelijk     8.49     2.17    1.92    2.58
# 13         slim          dom     1.13     0.49    2.72    3.12
# 14  krankzinnig          gek     9.24     0.49    8.02    2.06
# 15     gelukkig        kwaad     0.64     0.75    2.95    3.20
# 16   uitgebreid        groot     2.47     1.30    5.58    2.59
# 17     moeilijk       simpel     1.28     0.69    2.24    2.07
# 18        nieuw         vers     6.98     1.04    6.69    2.06
# 19       scherp         saai     1.03     0.74    0.95    1.47
# 20         vlug         snel     8.85     0.40    8.95    1.27
# 21          dom        dwaas     8.55     0.60    6.57    2.58
# 22     prachtig  fantastisch     8.53     0.13    6.30    2.14
# 23  eigenaardig       vreemd     7.81     0.52    8.56    1.30
# 24     gelukkig         boos     0.49     0.58    0.98    1.77

# %% [markdown]
# ### **3. Descriptive Statistics**

# %%
# Summary statistics SimLex-999
pred_sl_summary = round(predicted['pred_sl'].describe(), 2)
act_sl_summary = round(actual['act_sl'].describe(), 2)

# Add median SimLex-999
pred_sl_summary['median'] = round(predicted['pred_sl'].median(), 2)
act_sl_summary['median'] = round(actual['act_sl'].median(), 2)

# Summary statistics standard deviations
pred_sd_summary = round(predicted['pred_sd'].describe(), 2)
act_sd_summary = round(actual['act_sd'].describe(), 2)

# Add median standard deviation
pred_sd_summary['median'] = round(predicted['pred_sd'].median(), 2)
act_sd_summary['median'] = round(actual['act_sd'].median(), 2)

# Create pandas DataFrame
summary_df = pd.DataFrame({
    "pred_sl": pred_sl_summary,
    "act_sl": act_sl_summary,
    "pred_sd": pred_sd_summary,
    "act_sd": act_sd_summary
})

# Show results
summary_df
# Out:
#         pred_sl  act_sl  pred_sd  act_sd
# count     25.00   25.00    25.00   25.00
# mean       5.53    4.85     0.80    2.33
# std        3.63    2.66     0.64    0.61
# min        0.16    0.95     0.13    1.27
# 25%        1.13    2.17     0.41    2.06
# 50%        7.81    5.58     0.60    2.28
# 75%        8.55    7.09     0.76    2.90
# max        9.24    8.95     2.93    3.22
# median     7.81    5.58     0.60    2.28

# %% [markdown]
# #### **3.1. SimLex-999**

# %%
# Rename columns and copy
renamed_pred_sl = predicted.rename(columns={"pred_sl": "SimLex-999"}).copy()
renamed_act_sl = actual.rename(columns={"act_sl": "SimLex-999"}).copy()

# Create dummy label
renamed_pred_sl['Score'] = 'Estimated (NL)'
renamed_act_sl['Score'] = 'Observed (NL)'

# Combine DataFrames
combined_data = pd.concat([renamed_pred_sl, renamed_act_sl])

# Create boxplot
plt.figure(figsize=(6, 6))
sns.boxplot(
    x='Score',
    y='SimLex-999',
    data=combined_data,
    palette=['skyblue', 'lightgreen'],
    boxprops={'edgecolor': 'black'},
    whiskerprops={'color': 'black'},
    flierprops={'marker': 'o', 'color': 'black', 'markerfacecolor': 'black'},
    capprops={'color': 'black'},
    medianprops={'color': 'black'}
)

# Set labels and title
plt.ylabel('SimLex-999')
# plt.title('Comparison of SimLex-999')

# Customize y-axis ticks
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(integer=True))
plt.ylim(0, 10)  # Setting y-axis limits from 0 to 10

# Remove x-axis label
plt.xlabel('')

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# #### **3.2. Standard Deviation**

# %%
# Rename columns and copy
renamed_predicted_sd = predicted.rename(columns={"pred_sd": "Standard Deviation"}).copy()
renamed_actual_sd = actual.rename(columns={"act_sd": "Standard Deviation"}).copy()

# Create dummy label
renamed_predicted_sd['Score'] = 'Estimated (NL)'
renamed_actual_sd['Score'] = 'Observed (NL)'

# Combine DataFrames
combined_data = pd.concat([renamed_predicted_sd, renamed_actual_sd])

# Create boxplot
plt.figure(figsize=(6, 6))
sns.boxplot(
    x='Score',
    y='Standard Deviation',
    data=combined_data,
    palette=['skyblue', 'lightgreen'],
    boxprops={'edgecolor': 'black'},
    whiskerprops={'color': 'black'},
    flierprops={'marker': 'o', 'color': 'black', 'markerfacecolor': 'black'},
    capprops={'color': 'black'},
    medianprops={'color': 'black'}
)

# Set labels and title
plt.ylabel('Standard Deviation')
# plt.title('Comparison of Standard Deviation')

# Customizing y-axis ticks
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(integer=True))
plt.ylim(0, 5)  # Setting y-axis limits from 0 to 5

# Remove x-axis label
plt.xlabel('')

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# ### **4. Distributions**

# %% [markdown]
# #### **4.1. SimLex-999**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 10

# Define bins
bins = 10

# Plot predicted histogram
axes[0].hist(renamed_pred_sl['SimLex-999'], bins=bins, edgecolor='black', color='skyblue')
axes[0].set_title('Estimated (NL)')
axes[0].set_xlabel('SimLex-999')
axes[0].set_ylabel('Frequency')
axes[0].set_xlim(x_min, x_max)
axes[0].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[0].grid(False) # Remove grid

# Plot actual histogram
axes[1].hist(renamed_act_sl['SimLex-999'], bins=bins, edgecolor='black', color='lightgreen')
axes[1].set_title('Observed (NL)')
axes[1].set_xlabel('SimLex-999')
axes[1].set_ylabel('Frequency')
axes[1].set_xlim(x_min, x_max)
axes[1].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[1].grid(False) # Remove grid

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# #### **4.2. Standard Deviation**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 5

# Define bins
bins = 5

# Plot predicted histogram
axes[0].hist(renamed_predicted_sd['Standard Deviation'], bins=bins, edgecolor='black', color='skyblue')
axes[0].set_title('Estimated (NL)')
axes[0].set_xlabel('Standard Deviation')
axes[0].set_ylabel('Frequency')
axes[0].set_xlim(x_min, x_max)
axes[0].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[0].grid(False) # Remove grid

# Plot actual histogram
axes[1].hist(renamed_actual_sd['Standard Deviation'], bins=bins, edgecolor='black', color='lightgreen')
axes[1].set_title('Observed (NL)')
axes[1].set_xlabel('Standard Deviation')
axes[1].set_ylabel('Frequency')
axes[1].set_xlim(x_min, x_max)
axes[1].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[1].grid(False) # Remove grid

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# ### **5. Outliers**

# %% [markdown]
# #### **5.1. Predicted**

# %%
# Count outliers
print_outlier_counts(predicted)
# Out:
# Outliers in pred_sd: 4
# No outliers found in columns: pred_sl

# %%
# Row outliers
print_outlier_data(predicted, 'pred_sd')
# Out:
# Outliers in pred_sd:
#          word1        word2  pred_sl  pred_sd
# 3     gelukkig      vrolijk     6.96     1.90
# 4         hard        stoer     4.26     2.93
# 12    moeilijk  gemakkelijk     8.49     2.17
# 16  uitgebreid        groot     2.47     1.30

# %% [markdown]
# #### **5.2. Actual**

# %%
# Count outliers
print_outlier_counts(actual)
# Out:
# No outliers found in columns: act_sl, act_sd

# %%
# Row outliers
print_outlier_data(actual, 'act_sd')
# Out:
# No outliers found in act_sd

# %% [markdown]
# #### **5.3. Add to Summary**

# %%
# Calculate outliers
outliers_pred_sl = calculate_outliers(predicted, 'pred_sl')
outliers_pred_sd = calculate_outliers(predicted, 'pred_sd')
outliers_act_sl = calculate_outliers(actual, 'act_sl')
outliers_act_sd = calculate_outliers(actual, 'act_sd')

# Count outliers
count_outliers_pred_sl = outliers_pred_sl.shape[0]
count_outliers_pred_sd = outliers_pred_sd.shape[0]
count_outliers_act_sl = outliers_act_sl.shape[0]
count_outliers_act_sd = outliers_act_sd.shape[0]

# Add outliers count to summary
outliers_row = pd.Series([count_outliers_pred_sl, count_outliers_act_sl, count_outliers_pred_sd, count_outliers_act_sd], 
    index=summary_df.columns,
    name='outliers'
)
summary_df = pd.concat([summary_df, outliers_row.to_frame().T])

# Show results
summary_df
# Out:
#           pred_sl  act_sl  pred_sd  act_sd
# count       25.00   25.00    25.00   25.00
# mean         5.53    4.85     0.80    2.33
# std          3.63    2.66     0.64    0.61
# min          0.16    0.95     0.13    1.27
# 25%          1.13    2.17     0.41    2.06
# 50%          7.81    5.58     0.60    2.28
# 75%          8.55    7.09     0.76    2.90
# max          9.24    8.95     2.93    3.22
# median       7.81    5.58     0.60    2.28
# outliers     0.00    0.00     4.00    0.00

# %% [markdown]
# ### **6. Correlation**

# %% [markdown]
# #### **6.1. SimLex-999 vs Standard Deviation**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 10
y_min = 0
y_max = 5

# Create scatter plot
sns.scatterplot(x='pred_sl', y='pred_sd', data=predicted, ax=axes[0], color='skyblue', edgecolor='black')

# Plot diagonal line
axes[0].plot([x_min, x_max], [y_min, y_max], color='red', linestyle='--')

# Set axis limits
axes[0].set_xlim(x_min, x_max)
axes[0].set_ylim(y_min, y_max)

# Set labels and title
axes[0].set_xlabel('SimLex-999')
axes[0].set_ylabel('Standard Deviation')
axes[0].set_title('Estimated (NL)')

# Remove grid
axes[0].grid(False)

# Create scatter plot
sns.scatterplot(x='act_sl', y='act_sd', data=actual, ax=axes[1], color='lightgreen', edgecolor='black')

# Plot diagonal line
axes[1].plot([x_min, x_max], [y_min, y_max], color='red', linestyle='--')

# Set axis limits
axes[1].set_xlim(x_min, x_max)
axes[1].set_ylim(y_min, y_max)

# Set labels and title
axes[1].set_xlabel('SimLex-999')
axes[1].set_ylabel('Standard Deviation')
axes[1].set_title('Observed (NL)')

# Remove grid
axes[1].grid(False)

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %%
# List to store correlations
correlations_list = []

# Append correlations to list
correlations_list.append(calculate_correlation_and_pvalue(merged, 'pred_sl', 'pred_sd'))
correlations_list.append(calculate_correlation_and_pvalue(merged, 'act_sl', 'act_sd'))

# Convert list into Pandas DataFrame
correlation_df = pd.DataFrame(correlations_list)

# Show results
correlation_df
# Out:
#   simlex999 standard_deviation  correlation   p_value     significance
# 0   pred_sl            pred_sd     -0.29055  0.158836  not significant
# 1    act_sl             act_sd     -0.32628  0.111431  not significant

# %% [markdown]
# ### **7. Evaluation Metrics**

# %% [markdown]
# #### **7.1. Spearmans's Rank Correlation**

# %% [markdown]
# ##### **7.1.1. Actual SimLex-999 vs Predicted SimLex-999**

# %%
# Scatter plot
plot_scatter_plot(merged, 'pred_sl', 'act_sl', 'Estimated SimLex-999 (NL)', 'Observed SimLex-999 (NL)', 0, 10, 0, 10)

# %%
# Correlation and pvalue
print_correlation_and_pvalue(merged, 'pred_sl', 'act_sl')
# Out:
# Spearman's Rank correlation: 0.66077
# P-value: 0.00032384296928943487
# The correlation is statistically significant.

# %% [markdown]
# ##### **7.1.2. Actual Standard Deviation vs Predicted Standard Deviation**

# %%
# Scatter plot
plot_scatter_plot(merged, 'pred_sd', 'act_sd', 'Estimated Standard Deviation (NL)', 'Observed Standard Deviation (NL)', 0, 5, 0, 3)

# %%
# Correlation and p-value
print_correlation_and_pvalue(merged, 'pred_sd', 'act_sd')
# Out:
# Spearman's Rank correlation: 0.32628
# P-value: 0.11143624213384763
# The correlation is not statistically significant.

# %% [markdown]
# #### **7.2. Mean Square Error (MSE)**

# %%
# Calculate Mean Squared Error
mse = mean_squared_error(merged['pred_sl'], merged['act_sl'])

# Show results
print(f"Mean Squared Error (MSE): {mse:.2f}")
# Out:
# Mean Squared Error (MSE): 6.40

# %% [markdown]
# #### **7.3. Mean Absolute Error (MAE)**

# %%
# Calculate Mean Absolute Error
mae = mean_absolute_error(merged['pred_sl'], merged['act_sl'])

# Show results
print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
# Mean Absolute Error (MAE): 1.83
