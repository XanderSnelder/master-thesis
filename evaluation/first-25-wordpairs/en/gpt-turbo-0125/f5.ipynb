# %% [markdown]
# ### **0. Set-up**

# %%
# Import libraries and utils
# %run '../../../utils.ipynb'

# %%
# Load predicted
raw_predicted = pd.read_csv("../../../../data/gpt-3.5-turbo-0125/processed/en/f5.csv")

# Load actual
raw_actual = pd.read_csv("../../../../data/dataset/cleaned-en-simlex-999.csv")

# %%
# Select first 25 word pairs
raw_predicted = raw_predicted.head(25)
raw_actual = raw_actual.head(25)

# %%
# Show results
raw_predicted
# Out:
#         word1        word2 similarity_score_1 similarity_score_2  \
# 0         old          new    very dissimilar    very dissimilar
# 1       smart  intelligent       very similar       very similar
# 2        hard    difficult            similar            similar
# 3       happy     cheerful       very similar            similar
# 4        hard         easy         dissimilar         dissimilar
# 5        fast        rapid            similar            similar
# 6       happy         glad            similar            similar
# 7       short         long            similar         dissimilar
# 8      stupid         dumb       very similar            similar
# 9       weird      strange       very similar       very similar
# 10       wide       narrow         dissimilar         dissimilar
# 11        bad        awful       very similar       very similar
# 12       easy    difficult    very dissimilar         dissimilar
# 13        bad     terrible       very similar       very similar
# 14       hard       simple    very dissimilar         dissimilar
# 15      smart         dumb    very dissimilar    very dissimilar
# 16     insane        crazy       very similar       very similar
# 17      happy          mad            similar            similar
# 18      large         huge       very similar       very similar
# 19       hard        tough            similar            similar
# 20        new        fresh            similar            similar
# 21      sharp         dull    very dissimilar         dissimilar
# 22      quick        rapid            similar            similar
# 23       dumb      foolish            similar            similar
# 24  wonderful     terrific       very similar       very similar
#
#    similarity_score_3 similarity_score_4 similarity_score_5  \
# 0     very dissimilar    very dissimilar    very dissimilar
# 1        very similar       very similar       very similar
# 2             similar            similar            similar
# 3        very similar            similar            similar
# 4     very dissimilar    very dissimilar    very dissimilar
# 5             similar       very similar            similar
# 6             similar            similar            similar
# 7          dissimilar    very dissimilar         dissimilar
# 8        very similar       very similar            similar
# 9        very similar            similar            similar
# 10         dissimilar    very dissimilar         dissimilar
# 11            similar       very similar            similar
# 12    very dissimilar    very dissimilar    very dissimilar
# 13            similar       very similar            similar
# 14    very dissimilar    very dissimilar    very dissimilar
# 15    very dissimilar    very dissimilar    very dissimilar
# 16       very similar       very similar            similar
# 17            similar            similar            similar
# 18            similar       very similar            similar
# 19            similar            similar            similar
# 20            similar            similar            similar
# 21         dissimilar    very dissimilar         dissimilar
# 22            similar       very similar            similar
# 23            similar       very similar            similar
# 24       very similar       very similar            similar
#
#    similarity_score_6 similarity_score_7 similarity_score_8  \
# 0     very dissimilar    very dissimilar    very dissimilar
# 1        very similar       very similar       very similar
# 2             similar            similar            similar
# 3        very similar            similar            similar
# 4          dissimilar         dissimilar    very dissimilar
# 5             similar            similar            similar
# 6        very similar            similar            similar
# 7             similar         dissimilar         dissimilar
# 8        very similar       very similar       very similar
# 9             similar            similar            similar
# 10            similar         dissimilar         dissimilar
# 11            similar       very similar            similar
# 12         dissimilar         dissimilar    very dissimilar
# 13            similar            similar            similar
# 14         dissimilar         dissimilar    very dissimilar
# 15    very dissimilar    very dissimilar    very dissimilar
# 16       very similar       very similar            similar
# 17            similar            similar         dissimilar
# 18       very similar       very similar            similar
# 19            similar            similar            similar
# 20            similar            similar            similar
# 21            similar         dissimilar         dissimilar
# 22            similar            similar            similar
# 23       very similar       very similar            similar
# 24       very similar       very similar            similar
#
#    similarity_score_9 similarity_score_10 similarity_score_11  \
# 0     very dissimilar     very dissimilar     very dissimilar
# 1        very similar        very similar        very similar
# 2             similar             similar             similar
# 3             similar             similar             similar
# 4          dissimilar     very dissimilar     very dissimilar
# 5             similar        very similar             similar
# 6             similar             similar             similar
# 7          dissimilar          dissimilar          dissimilar
# 8        very similar        very similar        very similar
# 9        very similar             similar        very similar
# 10         dissimilar     very dissimilar          dissimilar
# 11            similar        very similar             similar
# 12         dissimilar     very dissimilar     very dissimilar
# 13            similar        very similar             similar
# 14         dissimilar     very dissimilar          dissimilar
# 15    very dissimilar     very dissimilar     very dissimilar
# 16            similar        very similar        very similar
# 17            similar     very dissimilar             similar
# 18            similar             similar             similar
# 19            similar             similar             similar
# 20            similar             similar             similar
# 21         dissimilar     very dissimilar          dissimilar
# 22            similar             similar             similar
# 23            similar        very similar        very similar
# 24            similar        very similar        very similar
#
#    similarity_score_12 similarity_score_13 similarity_score_14  \
# 0      very dissimilar          dissimilar     very dissimilar
# 1         very similar        very similar        very similar
# 2              similar             similar             similar
# 3              similar             similar             similar
# 4           dissimilar          dissimilar          dissimilar
# 5              similar             similar             similar
# 6              similar        very similar             similar
# 7           dissimilar             similar          dissimilar
# 8         very similar        very similar             similar
# 9              similar        very similar             similar
# 10          dissimilar          dissimilar          dissimilar
# 11             similar        very similar        very similar
# 12          dissimilar          dissimilar          dissimilar
# 13             similar        very similar        very similar
# 14          dissimilar          dissimilar          dissimilar
# 15     very dissimilar     very dissimilar     very dissimilar
# 16        very similar        very similar             similar
# 17             similar             similar             similar
# 18             similar             similar             similar
# 19             similar             similar             similar
# 20             similar             similar             similar
# 21          dissimilar          dissimilar          dissimilar
# 22             similar             similar             similar
# 23        very similar             similar             similar
# 24        very similar             similar        very similar
#
#    similarity_score_15
# 0      very dissimilar
# 1         very similar
# 2              similar
# 3              similar
# 4      very dissimilar
# 5              similar
# 6              similar
# 7      very dissimilar
# 8              similar
# 9         very similar
# 10          dissimilar
# 11             similar
# 12          dissimilar
# 13             similar
# 14          dissimilar
# 15     very dissimilar
# 16        very similar
# 17             similar
# 18             similar
# 19             similar
# 20             similar
# 21          dissimilar
# 22             similar
# 23        very similar
# 24             similar

# %% [markdown]
# ### **1. Data Quality**

# %%
# Basic info
raw_predicted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   word1                25 non-null     object
#  1   word2                25 non-null     object
#  2   similarity_score_1   25 non-null     object
#  3   similarity_score_2   25 non-null     object
#  4   similarity_score_3   25 non-null     object
#  5   similarity_score_4   25 non-null     object
#  6   similarity_score_5   25 non-null     object
#  7   similarity_score_6   25 non-null     object
#  8   similarity_score_7   25 non-null     object
#  9   similarity_score_8   25 non-null     object
#  10  similarity_score_9   25 non-null     object
#  11  similarity_score_10  25 non-null     object
#  12  similarity_score_11  25 non-null     object
#  13  similarity_score_12  25 non-null     object
#  14  similarity_score_13  25 non-null     object
#  15  similarity_score_14  25 non-null     object
#  16  similarity_score_15  25 non-null     object
# dtypes: object(17)
# memory usage: 3.4+ KB

# %%
# Missing values per column
raw_predicted.isnull().sum()
# Out:
# word1                  0
# word2                  0
# similarity_score_1     0
# similarity_score_2     0
# similarity_score_3     0
# similarity_score_4     0
# similarity_score_5     0
# similarity_score_6     0
# similarity_score_7     0
# similarity_score_8     0
# similarity_score_9     0
# similarity_score_10    0
# similarity_score_11    0
# similarity_score_12    0
# similarity_score_13    0
# similarity_score_14    0
# similarity_score_15    0
# dtype: int64

# %%
# Select word pairs and copy
wordpairs_predicted = raw_predicted[['word1', 'word2']].copy()
wordpairs_actual = raw_actual[['word1', 'word2']].copy()

# Remove whitespace
wordpairs_actual['word1'] = wordpairs_actual['word1'].replace(" ", "", regex=True)
wordpairs_actual['word2'] = wordpairs_actual['word2'].replace(" ", "", regex=True)

# Check if actual is identical to predicted
are_identical = wordpairs_actual.equals(wordpairs_predicted)
print("Word pairs in Actual are identical to Predicted:", are_identical)

# If not identical, show the differences
differences = None
if not are_identical:
    differences = wordpairs_actual.compare(wordpairs_predicted)
    differences.columns = ['Word1 Actual', 'Word1 Predicted', 'Word2 Actual', 'Word2 Predicted']

# Show results
differences if differences is not None else print("No differences found")
# Out:
# Word pairs in Actual are identical to Predicted: True
# No differences found

# %% [markdown]
# ### **2. Data Processing**

# %%
# Copy dataframe
scaled_raw_predicted = raw_predicted.copy()

# List of columns to scale
similarity_cols = [f"similarity_score_{i}" for i in range(1, 16)]

# Mapping of categorical scale
categorical_mapping = {
    'very dissimilar': 0,
    'dissimilar': 2.5,
    'neutral': 5,
    'similar': 7.5,
    'very similar': 10
}

# Apply mapping
for col in similarity_cols:
    scaled_raw_predicted[col] = scaled_raw_predicted[col].map(categorical_mapping)

# Show results
scaled_raw_predicted
# Out:
#         word1        word2  similarity_score_1  similarity_score_2  \
# 0         old          new                 0.0                 0.0
# 1       smart  intelligent                10.0                10.0
# 2        hard    difficult                 7.5                 7.5
# 3       happy     cheerful                10.0                 7.5
# 4        hard         easy                 2.5                 2.5
# 5        fast        rapid                 7.5                 7.5
# 6       happy         glad                 7.5                 7.5
# 7       short         long                 7.5                 2.5
# 8      stupid         dumb                10.0                 7.5
# 9       weird      strange                10.0                10.0
# 10       wide       narrow                 2.5                 2.5
# 11        bad        awful                10.0                10.0
# 12       easy    difficult                 0.0                 2.5
# 13        bad     terrible                10.0                10.0
# 14       hard       simple                 0.0                 2.5
# 15      smart         dumb                 0.0                 0.0
# 16     insane        crazy                10.0                10.0
# 17      happy          mad                 7.5                 7.5
# 18      large         huge                10.0                10.0
# 19       hard        tough                 7.5                 7.5
# 20        new        fresh                 7.5                 7.5
# 21      sharp         dull                 0.0                 2.5
# 22      quick        rapid                 7.5                 7.5
# 23       dumb      foolish                 7.5                 7.5
# 24  wonderful     terrific                10.0                10.0
#
#     similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                  0.0                 0.0                 0.0
# 1                 10.0                10.0                10.0
# 2                  7.5                 7.5                 7.5
# 3                 10.0                 7.5                 7.5
# 4                  0.0                 0.0                 0.0
# 5                  7.5                10.0                 7.5
# 6                  7.5                 7.5                 7.5
# 7                  2.5                 0.0                 2.5
# 8                 10.0                10.0                 7.5
# 9                 10.0                 7.5                 7.5
# 10                 2.5                 0.0                 2.5
# 11                 7.5                10.0                 7.5
# 12                 0.0                 0.0                 0.0
# 13                 7.5                10.0                 7.5
# 14                 0.0                 0.0                 0.0
# 15                 0.0                 0.0                 0.0
# 16                10.0                10.0                 7.5
# 17                 7.5                 7.5                 7.5
# 18                 7.5                10.0                 7.5
# 19                 7.5                 7.5                 7.5
# 20                 7.5                 7.5                 7.5
# 21                 2.5                 0.0                 2.5
# 22                 7.5                10.0                 7.5
# 23                 7.5                10.0                 7.5
# 24                10.0                10.0                 7.5
#
#     similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                  0.0                 0.0                 0.0
# 1                 10.0                10.0                10.0
# 2                  7.5                 7.5                 7.5
# 3                 10.0                 7.5                 7.5
# 4                  2.5                 2.5                 0.0
# 5                  7.5                 7.5                 7.5
# 6                 10.0                 7.5                 7.5
# 7                  7.5                 2.5                 2.5
# 8                 10.0                10.0                10.0
# 9                  7.5                 7.5                 7.5
# 10                 7.5                 2.5                 2.5
# 11                 7.5                10.0                 7.5
# 12                 2.5                 2.5                 0.0
# 13                 7.5                 7.5                 7.5
# 14                 2.5                 2.5                 0.0
# 15                 0.0                 0.0                 0.0
# 16                10.0                10.0                 7.5
# 17                 7.5                 7.5                 2.5
# 18                10.0                10.0                 7.5
# 19                 7.5                 7.5                 7.5
# 20                 7.5                 7.5                 7.5
# 21                 7.5                 2.5                 2.5
# 22                 7.5                 7.5                 7.5
# 23                10.0                10.0                 7.5
# 24                10.0                10.0                 7.5
#
#     similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                  0.0                  0.0                  0.0
# 1                 10.0                 10.0                 10.0
# 2                  7.5                  7.5                  7.5
# 3                  7.5                  7.5                  7.5
# 4                  2.5                  0.0                  0.0
# 5                  7.5                 10.0                  7.5
# 6                  7.5                  7.5                  7.5
# 7                  2.5                  2.5                  2.5
# 8                 10.0                 10.0                 10.0
# 9                 10.0                  7.5                 10.0
# 10                 2.5                  0.0                  2.5
# 11                 7.5                 10.0                  7.5
# 12                 2.5                  0.0                  0.0
# 13                 7.5                 10.0                  7.5
# 14                 2.5                  0.0                  2.5
# 15                 0.0                  0.0                  0.0
# 16                 7.5                 10.0                 10.0
# 17                 7.5                  0.0                  7.5
# 18                 7.5                  7.5                  7.5
# 19                 7.5                  7.5                  7.5
# 20                 7.5                  7.5                  7.5
# 21                 2.5                  0.0                  2.5
# 22                 7.5                  7.5                  7.5
# 23                 7.5                 10.0                 10.0
# 24                 7.5                 10.0                 10.0
#
#     similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                   0.0                  2.5                  0.0
# 1                  10.0                 10.0                 10.0
# 2                   7.5                  7.5                  7.5
# 3                   7.5                  7.5                  7.5
# 4                   2.5                  2.5                  2.5
# 5                   7.5                  7.5                  7.5
# 6                   7.5                 10.0                  7.5
# 7                   2.5                  7.5                  2.5
# 8                  10.0                 10.0                  7.5
# 9                   7.5                 10.0                  7.5
# 10                  2.5                  2.5                  2.5
# 11                  7.5                 10.0                 10.0
# 12                  2.5                  2.5                  2.5
# 13                  7.5                 10.0                 10.0
# 14                  2.5                  2.5                  2.5
# 15                  0.0                  0.0                  0.0
# 16                 10.0                 10.0                  7.5
# 17                  7.5                  7.5                  7.5
# 18                  7.5                  7.5                  7.5
# 19                  7.5                  7.5                  7.5
# 20                  7.5                  7.5                  7.5
# 21                  2.5                  2.5                  2.5
# 22                  7.5                  7.5                  7.5
# 23                 10.0                  7.5                  7.5
# 24                 10.0                  7.5                 10.0
#
#     similarity_score_15
# 0                   0.0
# 1                  10.0
# 2                   7.5
# 3                   7.5
# 4                   0.0
# 5                   7.5
# 6                   7.5
# 7                   0.0
# 8                   7.5
# 9                  10.0
# 10                  2.5
# 11                  7.5
# 12                  2.5
# 13                  7.5
# 14                  2.5
# 15                  0.0
# 16                 10.0
# 17                  7.5
# 18                  7.5
# 19                  7.5
# 20                  7.5
# 21                  2.5
# 22                  7.5
# 23                 10.0
# 24                  7.5

# %%
# Copy dataframe
predicted = scaled_raw_predicted.copy()

# List of columns to calculate mean SimLex-999
similarity_cols = [f"similarity_score_{i}" for i in range(1, 16)]

# Calculate the mean SimLex-999
predicted['pred_sl'] = predicted[similarity_cols].mean(axis=1).round(2)

# Calculate the standard deviation SimLex-999
predicted['pred_sd'] = predicted[similarity_cols].std(axis=1).round(2)

# Select columns
predicted = predicted[['word1', 'word2', 'pred_sl', 'pred_sd']]

# Show results
predicted
# Out:
#         word1        word2  pred_sl  pred_sd
# 0         old          new     0.17     0.65
# 1       smart  intelligent    10.00     0.00
# 2        hard    difficult     7.50     0.00
# 3       happy     cheerful     8.00     1.04
# 4        hard         easy     1.33     1.29
# 5        fast        rapid     7.83     0.88
# 6       happy         glad     7.83     0.88
# 7       short         long     3.17     2.40
# 8      stupid         dumb     9.33     1.14
# 9       weird      strange     8.67     1.29
# 10       wide       narrow     2.50     1.64
# 11        bad        awful     8.67     1.29
# 12       easy    difficult     1.33     1.29
# 13        bad     terrible     8.50     1.27
# 14       hard       simple     1.50     1.27
# 15      smart         dumb     0.00     0.00
# 16     insane        crazy     9.33     1.14
# 17      happy          mad     6.67     2.25
# 18      large         huge     8.33     1.22
# 19       hard        tough     7.50     0.00
# 20        new        fresh     7.50     0.00
# 21      sharp         dull     2.33     1.76
# 22      quick        rapid     7.67     0.65
# 23       dumb      foolish     8.67     1.29
# 24  wonderful     terrific     9.17     1.22

# %%
# Copy dataframe
actual = raw_actual.copy()

# Rename columns
actual = actual.rename(columns={'SimLex999': 'act_sl', 'std_dev': 'act_sd'})

# Select columns
actual = actual[['word1', 'word2', 'act_sl', 'act_sd']]

# Show results
actual
# Out:
#         word1        word2  act_sl  act_sd
# 0         old          new    1.58    0.41
# 1       smart  intelligent    9.20    0.67
# 2        hard    difficult    8.77    1.19
# 3       happy     cheerful    9.55    2.18
# 4        hard         easy    0.95    0.93
# 5        fast        rapid    8.75    1.68
# 6       happy         glad    9.17    1.59
# 7       short         long    1.23    1.58
# 8      stupid         dumb    9.58    1.48
# 9       weird      strange    8.93    1.30
# 10       wide       narrow    1.03    0.58
# 11        bad        awful    8.42    1.74
# 12       easy    difficult    0.58    0.36
# 13        bad     terrible    7.78    1.43
# 14       hard       simple    1.38    1.03
# 15      smart         dumb    0.55    0.47
# 16     insane        crazy    9.57    0.92
# 17      happy          mad    0.95    1.40
# 18      large         huge    9.47    1.27
# 19       hard        tough    8.05    1.18
# 20        new        fresh    6.83    1.20
# 21      sharp         dull    0.60    1.39
# 22      quick        rapid    9.70    1.14
# 23       dumb      foolish    6.67    1.36
# 24  wonderful     terrific    8.63    1.63

# %%
# Merge predicted and actual DataFrames
merged = pd.merge(predicted, actual, on=['word1', 'word2'])

# Show results
merged
# Out:
#         word1        word2  pred_sl  pred_sd  act_sl  act_sd
# 0         old          new     0.17     0.65    1.58    0.41
# 1       smart  intelligent    10.00     0.00    9.20    0.67
# 2        hard    difficult     7.50     0.00    8.77    1.19
# 3       happy     cheerful     8.00     1.04    9.55    2.18
# 4        hard         easy     1.33     1.29    0.95    0.93
# 5        fast        rapid     7.83     0.88    8.75    1.68
# 6       happy         glad     7.83     0.88    9.17    1.59
# 7       short         long     3.17     2.40    1.23    1.58
# 8      stupid         dumb     9.33     1.14    9.58    1.48
# 9       weird      strange     8.67     1.29    8.93    1.30
# 10       wide       narrow     2.50     1.64    1.03    0.58
# 11        bad        awful     8.67     1.29    8.42    1.74
# 12       easy    difficult     1.33     1.29    0.58    0.36
# 13        bad     terrible     8.50     1.27    7.78    1.43
# 14       hard       simple     1.50     1.27    1.38    1.03
# 15      smart         dumb     0.00     0.00    0.55    0.47
# 16     insane        crazy     9.33     1.14    9.57    0.92
# 17      happy          mad     6.67     2.25    0.95    1.40
# 18      large         huge     8.33     1.22    9.47    1.27
# 19       hard        tough     7.50     0.00    8.05    1.18
# 20        new        fresh     7.50     0.00    6.83    1.20
# 21      sharp         dull     2.33     1.76    0.60    1.39
# 22      quick        rapid     7.67     0.65    9.70    1.14
# 23       dumb      foolish     8.67     1.29    6.67    1.36
# 24  wonderful     terrific     9.17     1.22    8.63    1.63

# %% [markdown]
# ### **3. Descriptive Statistics**

# %%
# Summary statistics SimLex-999
pred_sl_summary = round(predicted['pred_sl'].describe(), 2)
act_sl_summary = round(actual['act_sl'].describe(), 2)

# Add median SimLex-999
pred_sl_summary['median'] = round(predicted['pred_sl'].median(), 2)
act_sl_summary['median'] = round(actual['act_sl'].median(), 2)

# Summary statistics standard deviations
pred_sd_summary = round(predicted['pred_sd'].describe(), 2)
act_sd_summary = round(actual['act_sd'].describe(), 2)

# Add median standard deviation
pred_sd_summary['median'] = round(predicted['pred_sd'].median(), 2)
act_sd_summary['median'] = round(actual['act_sd'].median(), 2)

# Create pandas DataFrame
summary_df = pd.DataFrame({
    "pred_sl": pred_sl_summary,
    "act_sl": act_sl_summary,
    "pred_sd": pred_sd_summary,
    "act_sd": act_sd_summary
})

# Show results
summary_df
# Out:
#         pred_sl  act_sl  pred_sd  act_sd
# count     25.00   25.00    25.00   25.00
# mean       6.14    5.92     1.03    1.20
# std        3.35    3.86     0.66    0.45
# min        0.00    0.55     0.00    0.36
# 25%        2.50    1.23     0.65    0.93
# 50%        7.67    8.05     1.22    1.27
# 75%        8.67    9.17     1.29    1.48
# max       10.00    9.70     2.40    2.18
# median     7.67    8.05     1.22    1.27

# %% [markdown]
# #### **3.1. SimLex-999**

# %%
# Rename columns and copy
renamed_pred_sl = predicted.rename(columns={"pred_sl": "SimLex-999"}).copy()
renamed_act_sl = actual.rename(columns={"act_sl": "SimLex-999"}).copy()

# Create dummy label
renamed_pred_sl['Score'] = 'Predicted'
renamed_act_sl['Score'] = 'Actual'

# Combine DataFrames
combined_data = pd.concat([renamed_pred_sl, renamed_act_sl])

# Create boxplot
plt.figure(figsize=(6, 6))
sns.boxplot(
    x='Score',
    y='SimLex-999',
    data=combined_data,
    palette=['skyblue', 'lightgreen'],
    boxprops={'edgecolor': 'black'},
    whiskerprops={'color': 'black'},
    flierprops={'marker': 'o', 'color': 'black', 'markerfacecolor': 'black'},
    capprops={'color': 'black'},
    medianprops={'color': 'black'}
)

# Set labels and title
plt.ylabel('SimLex-999')
# plt.title('Comparison of SimLex-999')

# Customize y-axis ticks
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(integer=True))
plt.ylim(0, 10.1)  # Setting y-axis limits from 0 to 10

# Remove x-axis label
plt.xlabel('')

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# #### **3.2. Standard Deviation**

# %%
# Rename columns and copy
renamed_predicted_sd = predicted.rename(columns={"pred_sd": "Standard Deviation"}).copy()
renamed_actual_sd = actual.rename(columns={"act_sd": "Standard Deviation"}).copy()

# Create dummy label
renamed_predicted_sd['Score'] = 'Predicted'
renamed_actual_sd['Score'] = 'Actual'

# Combine DataFrames
combined_data = pd.concat([renamed_predicted_sd, renamed_actual_sd])

# Create boxplot
plt.figure(figsize=(6, 6))
sns.boxplot(
    x='Score',
    y='Standard Deviation',
    data=combined_data,
    palette=['skyblue', 'lightgreen'],
    boxprops={'edgecolor': 'black'},
    whiskerprops={'color': 'black'},
    flierprops={'marker': 'o', 'color': 'black', 'markerfacecolor': 'black'},
    capprops={'color': 'black'},
    medianprops={'color': 'black'}
)

# Set labels and title
plt.ylabel('Standard Deviation')
# plt.title('Comparison of Standard Deviation')

# Customizing y-axis ticks
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(integer=True))
plt.ylim(0, 5)  # Setting y-axis limits from 0 to 5

# Remove x-axis label
plt.xlabel('')

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# ### **4. Distributions**

# %% [markdown]
# #### **4.1. SimLex-999**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 10

# Define bins
bins = 10

# Plot predicted histogram
axes[0].hist(renamed_pred_sl['SimLex-999'], bins=bins, edgecolor='black', color='skyblue')
axes[0].set_title('Predicted')
axes[0].set_xlabel('SimLex-999')
axes[0].set_ylabel('Frequency')
axes[0].set_xlim(x_min, x_max)
axes[0].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[0].grid(False) # Remove grid

# Plot actual histogram
axes[1].hist(renamed_act_sl['SimLex-999'], bins=bins, edgecolor='black', color='lightgreen')
axes[1].set_title('Actual')
axes[1].set_xlabel('SimLex-999')
axes[1].set_ylabel('Frequency')
axes[1].set_xlim(x_min, x_max)
axes[1].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[1].grid(False) # Remove grid

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# #### **4.2. Standard Deviation**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 5

# Define bins
bins = 5

# Plot predicted histogram
axes[0].hist(renamed_predicted_sd['Standard Deviation'], bins=bins, edgecolor='black', color='skyblue')
axes[0].set_title('Predicted')
axes[0].set_xlabel('Standard Deviation')
axes[0].set_ylabel('Frequency')
axes[0].set_xlim(x_min, x_max)
axes[0].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[0].grid(False) # Remove grid

# Plot actual histogram
axes[1].hist(renamed_actual_sd['Standard Deviation'], bins=bins, edgecolor='black', color='lightgreen')
axes[1].set_title('Actual')
axes[1].set_xlabel('Standard Deviation')
axes[1].set_ylabel('Frequency')
axes[1].set_xlim(x_min, x_max)
axes[1].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[1].grid(False) # Remove grid

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# ### **5. Outliers**

# %% [markdown]
# #### **5.1. Predicted**

# %%
# Count outliers
print_outlier_counts(predicted)
# Out:
# Outliers in pred_sd: 1
# No outliers found in columns: pred_sl

# %%
# Row outliers
print_outlier_data(predicted, 'pred_sl')
# Out:
# No outliers found in pred_sl

# %% [markdown]
# #### **5.2. Actual**

# %%
# Count outliers
print_outlier_counts(actual)
# Out:
# No outliers found in columns: act_sl, act_sd

# %%
# Row outliers
print_outlier_data(actual, 'act_sd')
# Out:
# No outliers found in act_sd

# %% [markdown]
# #### **5.3. Add to Summary**

# %%
# Calculate outliers
outliers_pred_sl = calculate_outliers(predicted, 'pred_sl')
outliers_pred_sd = calculate_outliers(predicted, 'pred_sd')
outliers_act_sl = calculate_outliers(actual, 'act_sl')
outliers_act_sd = calculate_outliers(actual, 'act_sd')

# Count outliers
count_outliers_pred_sl = outliers_pred_sl.shape[0]
count_outliers_pred_sd = outliers_pred_sd.shape[0]
count_outliers_act_sl = outliers_act_sl.shape[0]
count_outliers_act_sd = outliers_act_sd.shape[0]

# Add outliers count to summary
outliers_row = pd.Series([count_outliers_pred_sl, count_outliers_act_sl, count_outliers_pred_sd, count_outliers_act_sd], 
    index=summary_df.columns,
    name='outliers'
)
summary_df = pd.concat([summary_df, outliers_row.to_frame().T])

# Show results
summary_df
# Out:
#           pred_sl  act_sl  pred_sd  act_sd
# count       25.00   25.00    25.00   25.00
# mean         6.14    5.92     1.03    1.20
# std          3.35    3.86     0.66    0.45
# min          0.00    0.55     0.00    0.36
# 25%          2.50    1.23     0.65    0.93
# 50%          7.67    8.05     1.22    1.27
# 75%          8.67    9.17     1.29    1.48
# max         10.00    9.70     2.40    2.18
# median       7.67    8.05     1.22    1.27
# outliers     0.00    0.00     1.00    0.00

# %% [markdown]
# ### **6. Correlation**

# %% [markdown]
# #### **6.1. SimLex-999 vs Standard Deviation**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 10
y_min = 0
y_max = 5.0

# Create scatter plot
sns.scatterplot(x='pred_sl', y='pred_sd', data=predicted, ax=axes[0], color='skyblue', edgecolor='black')

# Plot diagonal line
axes[0].plot([x_min, x_max], [y_min, y_max], color='red', linestyle='--')

# Set axis limits
axes[0].set_xlim(x_min, x_max)
axes[0].set_ylim(y_min, y_max)

# Set labels and title
axes[0].set_xlabel('SimLex-999')
axes[0].set_ylabel('Standard Deviation')
axes[0].set_title('Predicted')

# Remove grid
axes[0].grid(False)

# Create scatter plot
sns.scatterplot(x='act_sl', y='act_sd', data=actual, ax=axes[1], color='lightgreen', edgecolor='black')

# Plot diagonal line
axes[1].plot([x_min, x_max], [y_min, y_max], color='red', linestyle='--')

# Set axis limits
axes[1].set_xlim(x_min, x_max)
axes[1].set_ylim(y_min, y_max)

# Set labels and title
axes[1].set_xlabel('SimLex-999')
axes[1].set_ylabel('Standard Deviation')
axes[1].set_title('Actual')

# Remove grid
axes[1].grid(False)

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %%
# List to store correlations
correlations_list = []

# Append correlations to list
correlations_list.append(calculate_correlation_and_pvalue(merged, 'pred_sl', 'pred_sd'))
correlations_list.append(calculate_correlation_and_pvalue(merged, 'act_sl', 'act_sd'))

# Convert list into Pandas DataFrame
correlation_df = pd.DataFrame(correlations_list)

# Show results
correlation_df
# Out:
#   simlex999 standard_deviation  correlation   p_value     significance
# 0   pred_sl            pred_sd     -0.10848  0.605749  not significant
# 1    act_sl             act_sd      0.32622  0.111504  not significant

# %% [markdown]
# ### **7. Evaluation Metrics**

# %% [markdown]
# #### **7.1. Spearmans's Rank Correlation**

# %% [markdown]
# ##### **7.1.1. Actual SimLex-999 vs Predicted SimLex-999**

# %%
# Scatter plot
plot_scatter_plot(merged, 'pred_sl', 'act_sl', 'Predicted SimLex-999', 'Actual SimLex-999', 0, 10, 0, 10)

# %%
# Correlation and pvalue
print_correlation_and_pvalue(merged, 'pred_sl', 'act_sl')
# Out:
# Spearman's Rank correlation: 0.76812
# P-value: 7.352811231200357e-06
# The correlation is statistically significant.

# %% [markdown]
# ##### **7.1.2. Actual Standard Deviation vs Predicted Standard Deviation**

# %%
# Scatter plot
plot_scatter_plot(merged, 'pred_sd', 'act_sd', 'Predicted Standard Deviation', 'Actual Standard Deviation', 0, 5, 0, 3)

# %%
# Correlation and p-value
print_correlation_and_pvalue(merged, 'pred_sd', 'act_sd')
# Out:
# Spearman's Rank correlation: 0.21689
# P-value: 0.2977049623643594
# The correlation is not statistically significant.

# %% [markdown]
# #### **7.2. Mean Square Error (MSE)**

# %%
# Calculate Mean Squared Error
mse = mean_squared_error(merged['pred_sl'], merged['act_sl'])

# Show results
print(f"Mean Squared Error (MSE): {mse:.2f}")
# Out:
# Mean Squared Error (MSE): 2.53

# %% [markdown]
# #### **7.3. Mean Absolute Error (MAE)**

# %%
# Calculate Mean Absolute Error
mae = mean_absolute_error(merged['pred_sl'], merged['act_sl'])

# Show results
print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
# Mean Absolute Error (MAE): 1.14

# %% [markdown]
# #### **7.4. Bland-Altman**

# %%
# SimLex-999
bland_altman_plot(data1=merged['pred_sl'], data2=merged['act_sl'])

# %%
# Standard Deviation
bland_altman_plot(data1=merged['pred_sd'], data2=merged['act_sd'])
