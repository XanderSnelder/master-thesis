# %% [markdown]
# ### **0. Set-up**

# %%
# Import libraries and utils
# %run '../../utils.ipynb'

# %%
# Load predicted
f9_1 = pd.read_csv("../../../data/gpt-3.5-turbo-0125/processed/nl/f9-1.csv")
f9_2 = pd.read_csv("../../../data/gpt-3.5-turbo-0125/processed/nl/f9-2.csv")
f9_3 = pd.read_csv("../../../data/gpt-3.5-turbo-0125/processed/nl/f9-3.csv")

# Combine the dataframes
raw_predicted = pd.concat([f9_1, f9_2, f9_3], ignore_index=True)

# Load actual
raw_actual = pd.read_csv("../../../data/dataset/cleaned-nl-simlex-999.csv")

# %%
# Show results
raw_predicted
# Out:
#            word1        word2  similarity_score_1  similarity_score_2  \
# 0            oud        nieuw                 0.1                1.91
# 1           slim  intelligent                 8.5                9.00
# 2           hard     moeilijk                 7.5                7.20
# 3       gelukkig      vrolijk                 5.8                6.50
# 4           hard        stoer                 6.0                0.30
# ..           ...          ...                 ...                 ...
# 992  samenvoegen    verwerven                 1.2                0.00
# 993       sturen     bijwonen                 0.0                1.20
# 994   verzamelen     bijwonen                 0.0                0.10
# 995      opnemen    intrekken                 0.1                2.50
# 996     bijwonen     aankomen                 0.0                2.00
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                  1.00                0.14                2.00
# 1                  8.70                9.00                9.00
# 2                  7.50                8.00                9.50
# 3                  7.50                8.50                0.65
# 4                  6.00                6.50                7.50
# ..                  ...                 ...                 ...
# 992                2.50                2.00                0.00
# 993                0.00                0.00                0.00
# 994                0.00                0.00                0.00
# 995                2.33                2.50                3.45
# 996                0.00                0.10                0.00
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                  0.25                1.00                 0.1
# 1                  9.50                8.50                 9.0
# 2                  8.00                8.50                 8.5
# 3                  7.50                7.50                 9.0
# 4                  7.50                0.60                 5.5
# ..                  ...                 ...                 ...
# 992                0.10                0.20                 0.0
# 993                1.23                2.27                 0.0
# 994                0.00                0.00                 0.0
# 995                1.50                0.00                 2.5
# 996                0.00                1.50                 0.0
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                  1.00                 1.00                 1.00
# 1                  9.00                 9.50                 8.50
# 2                  8.50                 8.50                 8.50
# 3                  7.50                 7.50                 6.50
# 4                  5.65                 0.30                 6.50
# ..                  ...                  ...                  ...
# 992                0.00                 2.50                 0.20
# 993                0.00                 0.10                 0.00
# 994                1.20                 0.00                 0.00
# 995                2.14                 1.25                 1.67
# 996                0.00                 2.75                 0.00
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                    0.1                  1.0                  1.0
# 1                    8.5                  8.5                  8.5
# 2                    7.5                  6.5                  7.5
# 3                    7.5                  7.5                  7.5
# 4                    0.2                  5.0                  0.4
# ..                   ...                  ...                  ...
# 992                  0.0                  2.5                  0.0
# 993                  0.0                  0.0                  0.0
# 994                  0.0                  0.0                  0.0
# 995                  2.5                  2.5                  0.2
# 996                  0.0                  0.0                  1.5
#
#      similarity_score_15
# 0                    0.2
# 1                    8.5
# 2                    9.0
# 3                    7.5
# 4                    6.0
# ..                   ...
# 992                  0.0
# 993                  0.0
# 994                  0.0
# 995                  2.5
# 996                  0.0
#
# [997 rows x 17 columns]

# %% [markdown]
# ### **1. Data Quality**

# %%
# Basic info
raw_predicted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 997 entries, 0 to 996
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   word1                997 non-null    object
#  1   word2                997 non-null    object
#  2   similarity_score_1   997 non-null    float64
#  3   similarity_score_2   997 non-null    float64
#  4   similarity_score_3   997 non-null    float64
#  5   similarity_score_4   997 non-null    float64
#  6   similarity_score_5   997 non-null    float64
#  7   similarity_score_6   997 non-null    float64
#  8   similarity_score_7   997 non-null    float64
#  9   similarity_score_8   997 non-null    float64
#  10  similarity_score_9   997 non-null    float64
#  11  similarity_score_10  997 non-null    float64
#  12  similarity_score_11  997 non-null    float64
#  13  similarity_score_12  997 non-null    float64
#  14  similarity_score_13  997 non-null    float64
#  15  similarity_score_14  997 non-null    float64
#  16  similarity_score_15  997 non-null    float64
# dtypes: float64(15), object(2)
# memory usage: 132.5+ KB

# %%
# Missing values per column
raw_predicted.isnull().sum()
# Out:
# word1                  0
# word2                  0
# similarity_score_1     0
# similarity_score_2     0
# similarity_score_3     0
# similarity_score_4     0
# similarity_score_5     0
# similarity_score_6     0
# similarity_score_7     0
# similarity_score_8     0
# similarity_score_9     0
# similarity_score_10    0
# similarity_score_11    0
# similarity_score_12    0
# similarity_score_13    0
# similarity_score_14    0
# similarity_score_15    0
# dtype: int64

# %%
# Select word pairs and copy
wordpairs_predicted = raw_predicted[['word1', 'word2']].copy()
wordpairs_actual = raw_actual[['word1', 'word2']].copy()

# Remove whitespace
wordpairs_actual['word1'] = wordpairs_actual['word1'].replace(" ", "", regex=True)
wordpairs_actual['word2'] = wordpairs_actual['word2'].replace(" ", "", regex=True)

# Check if actual is identical to predicted
are_identical = wordpairs_actual.equals(wordpairs_predicted)
print("Word pairs in Actual are identical to Predicted:", are_identical)

# If not identical, show the differences
differences = None
if not are_identical:
    differences = wordpairs_actual.compare(wordpairs_predicted)
    differences.columns = ['Word1 Actual', 'Word1 Predicted', 'Word2 Actual', 'Word2 Predicted']

# Show results
differences if differences is not None else print("No differences found")
# Out:
# Word pairs in Actual are identical to Predicted: True
# No differences found

# %% [markdown]
# ### **2. Data Processing**

# %%
# Copy dataframe
predicted = raw_predicted.copy()

# List of columns to calculate mean SimLex-999
similarity_cols = [f"similarity_score_{i}" for i in range(1, 16)]

# Calculate the mean SimLex-999
predicted['pred_sl'] = predicted[similarity_cols].mean(axis=1).round(2)

# Calculate the standard deviation SimLex-999
predicted['pred_sd'] = predicted[similarity_cols].std(axis=1).round(2)

# Select columns
predicted = predicted[['word1', 'word2', 'pred_sl', 'pred_sd']]

# Show results
predicted
# Out:
#            word1        word2  pred_sl  pred_sd
# 0            oud        nieuw     0.79     0.63
# 1           slim  intelligent     8.81     0.36
# 2           hard     moeilijk     8.05     0.77
# 3       gelukkig      vrolijk     6.96     1.90
# 4           hard        stoer     4.26     2.93
# ..           ...          ...      ...      ...
# 992  samenvoegen    verwerven     0.75     1.07
# 993       sturen     bijwonen     0.32     0.69
# 994   verzamelen     bijwonen     0.09     0.31
# 995      opnemen    intrekken     1.84     1.04
# 996     bijwonen     aankomen     0.52     0.92
#
# [997 rows x 4 columns]

# %%
# Copy dataframe
actual = raw_actual.copy()

# Rename columns
actual = actual.rename(columns={'SimLex999': 'act_sl', 'std_dev': 'act_sd'})

# Select columns
actual = actual[['word1', 'word2', 'act_sl', 'act_sd']]

# Show results
actual
# Out:
#            word1        word2  act_sl  act_sd
# 0            oud        nieuw    1.94    2.42
# 1           slim  intelligent    8.19    1.54
# 2           hard     moeilijk    4.46    3.18
# 3       gelukkig      vrolijk    6.49    2.15
# 4           hard        stoer    5.69    2.94
# ..           ...          ...     ...     ...
# 992  samenvoegen    verwerven    3.89    3.11
# 993       sturen     bijwonen    1.85    1.95
# 994   verzamelen     bijwonen    1.06    1.71
# 995      opnemen    intrekken    2.29    2.67
# 996     bijwonen     aankomen    1.32    1.05
#
# [997 rows x 4 columns]

# %%
# Remove whitespace
predicted['word1'] = predicted['word1'].replace(" ", "", regex=True)
predicted['word2'] = predicted['word2'].replace(" ", "", regex=True)

# Remove whitespace
actual['word1'] = actual['word1'].replace(" ", "", regex=True)
actual['word2'] = actual['word2'].replace(" ", "", regex=True)

# %%
# Merge predicted and actual DataFrames
merged = pd.merge(predicted, actual, on=['word1', 'word2'])

# Show results
merged
# Out:
#            word1        word2  pred_sl  pred_sd  act_sl  act_sd
# 0            oud        nieuw     0.79     0.63    1.94    2.42
# 1           slim  intelligent     8.81     0.36    8.19    1.54
# 2           hard     moeilijk     8.05     0.77    4.46    3.18
# 3       gelukkig      vrolijk     6.96     1.90    6.49    2.15
# 4           hard        stoer     4.26     2.93    5.69    2.94
# ..           ...          ...      ...      ...     ...     ...
# 992  samenvoegen    verwerven     0.75     1.07    3.89    3.11
# 993       sturen     bijwonen     0.32     0.69    1.85    1.95
# 994   verzamelen     bijwonen     0.09     0.31    1.06    1.71
# 995      opnemen    intrekken     1.84     1.04    2.29    2.67
# 996     bijwonen     aankomen     0.52     0.92    1.32    1.05
#
# [997 rows x 6 columns]

# %% [markdown]
# ### **3. Descriptive Statistics**

# %%
# Summary statistics SimLex-999
pred_sl_summary = round(predicted['pred_sl'].describe(), 2)
act_sl_summary = round(actual['act_sl'].describe(), 2)

# Add median SimLex-999
pred_sl_summary['median'] = round(predicted['pred_sl'].median(), 2)
act_sl_summary['median'] = round(actual['act_sl'].median(), 2)

# Summary statistics standard deviations
pred_sd_summary = round(predicted['pred_sd'].describe(), 2)
act_sd_summary = round(actual['act_sd'].describe(), 2)

# Add median standard deviation
pred_sd_summary['median'] = round(predicted['pred_sd'].median(), 2)
act_sd_summary['median'] = round(actual['act_sd'].median(), 2)

# Create pandas DataFrame
summary_df = pd.DataFrame({
    "pred_sl": pred_sl_summary,
    "act_sl": act_sl_summary,
    "pred_sd": pred_sd_summary,
    "act_sd": act_sd_summary
})

# Show results
summary_df
# Out:
#         pred_sl  act_sl  pred_sd  act_sd
# count    997.00  997.00   997.00  997.00
# mean       4.08    3.64     1.02    2.37
# std        3.01    1.99     0.63    0.64
# min        0.00    0.49     0.00    0.48
# 25%        1.37    1.99     0.59    2.00
# 50%        3.08    3.27     0.90    2.46
# 75%        7.08    5.08     1.26    2.84
# max        9.67    9.28     4.42    4.13
# median     3.08    3.27     0.90    2.46

# %% [markdown]
# #### **3.1. SimLex-999**

# %%
# Rename columns and copy
renamed_pred_sl = predicted.rename(columns={"pred_sl": "SimLex-999"}).copy()
renamed_act_sl = actual.rename(columns={"act_sl": "SimLex-999"}).copy()

# Create dummy label
renamed_pred_sl['Score'] = 'Predicted'
renamed_act_sl['Score'] = 'Actual'

# Combine DataFrames
combined_data = pd.concat([renamed_pred_sl, renamed_act_sl])

# Create boxplot
plt.figure(figsize=(6, 6))
sns.boxplot(
    x='Score',
    y='SimLex-999',
    data=combined_data,
    palette=['skyblue', 'lightgreen'],
    boxprops={'edgecolor': 'black'},
    whiskerprops={'color': 'black'},
    flierprops={'marker': 'o', 'color': 'black', 'markerfacecolor': 'black'},
    capprops={'color': 'black'},
    medianprops={'color': 'black'}
)

# Set labels and title
plt.ylabel('SimLex-999')
# plt.title('Comparison of SimLex-999')

# Customize y-axis ticks
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(integer=True))
plt.ylim(0, 10)  # Setting y-axis limits from 0 to 10

# Remove x-axis label
plt.xlabel('')

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# #### **3.2. Standard Deviation**

# %%
# Rename columns and copy
renamed_predicted_sd = predicted.rename(columns={"pred_sd": "Standard Deviation"}).copy()
renamed_actual_sd = actual.rename(columns={"act_sd": "Standard Deviation"}).copy()

# Create dummy label
renamed_predicted_sd['Score'] = 'Predicted'
renamed_actual_sd['Score'] = 'Actual'

# Combine DataFrames
combined_data = pd.concat([renamed_predicted_sd, renamed_actual_sd])

# Create boxplot
plt.figure(figsize=(6, 6))
sns.boxplot(
    x='Score',
    y='Standard Deviation',
    data=combined_data,
    palette=['skyblue', 'lightgreen'],
    boxprops={'edgecolor': 'black'},
    whiskerprops={'color': 'black'},
    flierprops={'marker': 'o', 'color': 'black', 'markerfacecolor': 'black'},
    capprops={'color': 'black'},
    medianprops={'color': 'black'}
)

# Set labels and title
plt.ylabel('Standard Deviation')
# plt.title('Comparison of Standard Deviation')

# Customizing y-axis ticks
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(integer=True))
plt.ylim(0, 5)  # Setting y-axis limits from 0 to 5

# Remove x-axis label
plt.xlabel('')

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# ### **4. Distributions**

# %% [markdown]
# #### **4.1. SimLex-999**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 10

# Define bins
bins = 10

# Plot predicted histogram
axes[0].hist(renamed_pred_sl['SimLex-999'], bins=bins, edgecolor='black', color='skyblue')
axes[0].set_title('Predicted')
axes[0].set_xlabel('SimLex-999')
axes[0].set_ylabel('Frequency')
axes[0].set_xlim(x_min, x_max)
axes[0].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[0].grid(False) # Remove grid

# Plot actual histogram
axes[1].hist(renamed_act_sl['SimLex-999'], bins=bins, edgecolor='black', color='lightgreen')
axes[1].set_title('Actual')
axes[1].set_xlabel('SimLex-999')
axes[1].set_ylabel('Frequency')
axes[1].set_xlim(x_min, x_max)
axes[1].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[1].grid(False) # Remove grid

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# #### **4.2. Standard Deviation**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 5

# Define bins
bins = 5

# Plot predicted histogram
axes[0].hist(renamed_predicted_sd['Standard Deviation'], bins=bins, edgecolor='black', color='skyblue')
axes[0].set_title('Predicted')
axes[0].set_xlabel('Standard Deviation')
axes[0].set_ylabel('Frequency')
axes[0].set_xlim(x_min, x_max)
axes[0].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[0].grid(False) # Remove grid

# Plot actual histogram
axes[1].hist(renamed_actual_sd['Standard Deviation'], bins=bins, edgecolor='black', color='lightgreen')
axes[1].set_title('Actual')
axes[1].set_xlabel('Standard Deviation')
axes[1].set_ylabel('Frequency')
axes[1].set_xlim(x_min, x_max)
axes[1].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[1].grid(False) # Remove grid

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# ### **5. Outliers**

# %% [markdown]
# #### **5.1. Predicted**

# %%
# Count outliers
print_outlier_counts(predicted)
# Out:
# Outliers in pred_sd: 51
# No outliers found in columns: pred_sl

# %%
# Row outliers
print_outlier_data(predicted, 'pred_sd')
# Out:
# Outliers in pred_sd:
#              word1            word2  pred_sl  pred_sd
# 4             hard            stoer     4.26     2.93
# 36        schuldig        beschaamd     5.21     2.29
# 51          slecht  verschrikkelijk     6.51     3.58
# 63          zelden         zeldzaam     6.47     2.87
# 64     vriendelijk        vrijgevig     5.84     2.31
# 83        heerlijk         prachtig     3.05     2.69
# 87          somber             saai     5.33     2.65
# 91            ziek              gek     3.95     2.49
# 113           zuid            noord     7.80     3.20
# 115            oom            tante     6.06     3.08
# 122      vliegtuig  straalvliegtuig     6.48     3.55
# 140         winter            zomer     2.07     3.44
# 148           dame           meneer     4.27     3.33
# 156        seconde           minuut     1.97     2.27
# 202           wijn       brandewijn     6.76     3.11
# 204          diner          ontbijt     4.80     3.16
# 210        pistool            kanon     7.21     2.66
# 211           gras             stro     3.66     2.30
# 222           auto          snelweg     3.48     2.30
# 228           wolk             mist     3.98     2.44
# 241       molecuul            atoom     6.07     2.33
# 245            god           duivel     2.07     2.87
# 250            kat            leeuw     2.70     3.01
# 261            god            geest     4.57     2.40
# 263  uitbundigheid        overvloed     4.44     2.47
# 299        broodje            lunch     3.74     2.30
# 319       badkamer       slaapkamer     6.80     2.53
# 323       arbeider        werkgever     3.65     2.60
# 345          vader          dochter     5.37     3.14
# 391            bij             mier     6.42     2.36
# 404         gitaar         drumstel     3.02     2.92
# 429            god         priester     4.68     2.28
# 474  intelligentie          inzicht     3.04     2.94
# 484         bijbel            psalm     4.19     2.38
# 489          bloed             merg     3.59     2.55
# 494       schouder            hoofd     3.22     2.40
# 497       elleboog            enkel     3.96     3.10
# 499       verdriet         schaamte     2.40     2.88
# 515      polyester           katoen     3.05     2.71
# 641           pijp           sigaar     3.40     2.52
# 648         botten           tanden     4.15     2.38
# 681           kalf            stier     5.50     2.57
# 787     accepteren         weigeren     4.91     4.42
# 803         winnen           slagen     3.34     2.59
# 818         slagen            falen     7.20     3.74
# 833         sturen        ontvangen     2.20     2.77
# 879          falen      ontmoedigen     2.65     2.72
# 880       beginnen          stoppen     2.86     3.19
# 900       bereiken           slagen     4.98     2.48
# 938         ademen       verstikken     4.38     2.46
# 943   overnadenken           denken     2.65     3.41

# %% [markdown]
# #### **5.2. Actual**

# %%
# Count outliers
print_outlier_counts(actual)
# Out:
# Outliers in act_sd: 13
# No outliers found in columns: act_sl

# %%
# Row outliers
print_outlier_data(actual, 'act_sd')
# Out:
# Outliers in act_sd:
#          word1        word2  act_sl  act_sd
# 123      vrouw          man    5.08    4.13
# 153   boosheid        woede    8.87    0.59
# 176     straat         auto    0.89    0.72
# 291      water         zout    0.87    0.64
# 450       doos         lift    0.79    0.73
# 729       muis       beheer    0.82    0.67
# 732       taak       rietje    0.83    0.60
# 742  volkslied       rietje    0.87    0.71
# 753   maaltijd       staart    0.49    0.48
# 755     likeur  muziekgroep    0.85    0.49
# 757    pistool         bont    0.99    0.64
# 865      geven     weigeren    0.90    0.67
# 916    negeren       vragen    0.76    0.60

# %% [markdown]
# #### **5.3. Add to Summary**

# %%
# Calculate outliers
outliers_pred_sl = calculate_outliers(predicted, 'pred_sl')
outliers_pred_sd = calculate_outliers(predicted, 'pred_sd')
outliers_act_sl = calculate_outliers(actual, 'act_sl')
outliers_act_sd = calculate_outliers(actual, 'act_sd')

# Count outliers
count_outliers_pred_sl = outliers_pred_sl.shape[0]
count_outliers_pred_sd = outliers_pred_sd.shape[0]
count_outliers_act_sl = outliers_act_sl.shape[0]
count_outliers_act_sd = outliers_act_sd.shape[0]

# Add outliers count to summary
outliers_row = pd.Series([count_outliers_pred_sl, count_outliers_act_sl, count_outliers_pred_sd, count_outliers_act_sd], 
    index=summary_df.columns,
    name='outliers'
)
summary_df = pd.concat([summary_df, outliers_row.to_frame().T])

# Show results
summary_df
# Out:
#           pred_sl  act_sl  pred_sd  act_sd
# count      997.00  997.00   997.00  997.00
# mean         4.08    3.64     1.02    2.37
# std          3.01    1.99     0.63    0.64
# min          0.00    0.49     0.00    0.48
# 25%          1.37    1.99     0.59    2.00
# 50%          3.08    3.27     0.90    2.46
# 75%          7.08    5.08     1.26    2.84
# max          9.67    9.28     4.42    4.13
# median       3.08    3.27     0.90    2.46
# outliers     0.00    0.00    51.00   13.00

# %% [markdown]
# ### **6. Correlation**

# %% [markdown]
# #### **6.1. SimLex-999 vs Standard Deviation**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 10
y_min = 0
y_max = 5

# Create scatter plot
sns.scatterplot(x='pred_sl', y='pred_sd', data=predicted, ax=axes[0], color='skyblue', edgecolor='black')

# Plot diagonal line
axes[0].plot([x_min, x_max], [y_min, y_max], color='red', linestyle='--')

# Set axis limits
axes[0].set_xlim(x_min, x_max)
axes[0].set_ylim(y_min, y_max)

# Set labels and title
axes[0].set_xlabel('SimLex-999')
axes[0].set_ylabel('Standard Deviation')
axes[0].set_title('Predicted')

# Remove grid
axes[0].grid(False)

# Create scatter plot
sns.scatterplot(x='act_sl', y='act_sd', data=actual, ax=axes[1], color='lightgreen', edgecolor='black')

# Plot diagonal line
axes[1].plot([x_min, x_max], [y_min, y_max], color='red', linestyle='--')

# Set axis limits
axes[1].set_xlim(x_min, x_max)
axes[1].set_ylim(y_min, y_max)

# Set labels and title
axes[1].set_xlabel('SimLex-999')
axes[1].set_ylabel('Standard Deviation')
axes[1].set_title('Actual')

# Remove grid
axes[1].grid(False)

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %%
# List to store correlations
correlations_list = []

# Append correlations to list
correlations_list.append(calculate_correlation_and_pvalue(merged, 'pred_sl', 'pred_sd'))
correlations_list.append(calculate_correlation_and_pvalue(merged, 'act_sl', 'act_sd'))

# Convert list into Pandas DataFrame
correlation_df = pd.DataFrame(correlations_list)

# Show results
correlation_df
# Out:
#   simlex999 standard_deviation  correlation       p_value     significance
# 0   pred_sl            pred_sd     -0.05696  7.220680e-02  not significant
# 1    act_sl             act_sd      0.37773  3.653714e-35      significant

# %% [markdown]
# ### **7. Evaluation Metrics**

# %% [markdown]
# #### **7.1. Spearmans's Rank Correlation**

# %% [markdown]
# ##### **7.1.1. Actual SimLex-999 vs Predicted SimLex-999**

# %%
# Scatter plot
plot_scatter_plot(merged, 'pred_sl', 'act_sl', 'Predicted SimLex-999', 'Actual SimLex-999', 0, 10, 0, 10)

# %%
# Correlation and pvalue
print_correlation_and_pvalue(merged, 'pred_sl', 'act_sl')
# Out:
# Spearman's Rank correlation: 0.71864
# P-value: 3.603391689602347e-159
# The correlation is statistically significant.

# %% [markdown]
# ##### **7.1.2. Actual Standard Deviation vs Predicted Standard Deviation**

# %%
# Scatter plot
plot_scatter_plot(merged, 'pred_sd', 'act_sd', 'Predicted Standard Deviation', 'Actual Standard Deviation', 0, 5, 0, 3)

# %%
# Correlation and p-value
print_correlation_and_pvalue(merged, 'pred_sd', 'act_sd')
# Out:
# Spearman's Rank correlation: 0.21005
# P-value: 2.0984728924029688e-11
# The correlation is statistically significant.

# %% [markdown]
# #### **7.2. Mean Square Error (MSE)**

# %%
# Calculate Mean Squared Error
mse = mean_squared_error(merged['pred_sl'], merged['act_sl'])

# Show results
print(f"Mean Squared Error (MSE): {mse:.2f}")
# Out:
# Mean Squared Error (MSE): 4.75

# %% [markdown]
# #### **7.3. Mean Absolute Error (MAE)**

# %%
# Calculate Mean Absolute Error
mae = mean_absolute_error(merged['pred_sl'], merged['act_sl'])

# Show results
print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
# Mean Absolute Error (MAE): 1.68

# %% [markdown]
# #### **7.4. Bland-Altman**

# %%
# SimLex-999
bland_altman_plot(data1=merged['pred_sl'], data2=merged['act_sl'])

# %%
# Standard Deviation
bland_altman_plot(data1=merged['pred_sd'], data2=merged['act_sd'])
