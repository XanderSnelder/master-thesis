# %% [markdown]
# ### **0. Set-up**

# %%
# Import libraries and utils
# %run '../../../utils.ipynb'

# %%
# Load NL predicted gpt-3.5-turbo-0125
raw_gpt_pred = pd.read_csv("../../../../data/gpt-3.5-turbo-0125/processed/en/f5.csv")

# Load NL predicted text-embedding-3-small
raw_emb_pred = pd.read_csv("../../../../data/text-embedding-3-small/en.csv")

# %%
# Show results
raw_gpt_pred
# Out:
#       word1        word2 similarity_score_1 similarity_score_2  \
# 0       old          new    very dissimilar    very dissimilar
# 1     smart  intelligent       very similar       very similar
# 2      hard    difficult            similar            similar
# 3     happy     cheerful       very similar            similar
# 4      hard         easy         dissimilar         dissimilar
# ..      ...          ...                ...                ...
# 994    join      acquire            similar            similar
# 995    send       attend            similar         dissimilar
# 996  gather       attend            similar            similar
# 997  absorb     withdraw            similar         dissimilar
# 998  attend       arrive            similar         dissimilar
#
#     similarity_score_3 similarity_score_4 similarity_score_5  \
# 0      very dissimilar    very dissimilar    very dissimilar
# 1         very similar       very similar       very similar
# 2              similar            similar            similar
# 3         very similar            similar            similar
# 4      very dissimilar    very dissimilar    very dissimilar
# ..                 ...                ...                ...
# 994            similar            similar            similar
# 995            similar            similar            similar
# 996            similar            similar            similar
# 997         dissimilar         dissimilar         dissimilar
# 998            similar            similar            similar
#
#     similarity_score_6 similarity_score_7 similarity_score_8  \
# 0      very dissimilar    very dissimilar    very dissimilar
# 1         very similar       very similar       very similar
# 2              similar            similar            similar
# 3         very similar            similar            similar
# 4           dissimilar         dissimilar    very dissimilar
# ..                 ...                ...                ...
# 994            similar            similar            similar
# 995            similar         dissimilar            neutral
# 996            similar            similar            similar
# 997            similar         dissimilar         dissimilar
# 998         dissimilar            similar            similar
#
#     similarity_score_9 similarity_score_10 similarity_score_11  \
# 0      very dissimilar     very dissimilar     very dissimilar
# 1         very similar        very similar        very similar
# 2              similar             similar             similar
# 3              similar             similar             similar
# 4           dissimilar     very dissimilar     very dissimilar
# ..                 ...                 ...                 ...
# 994            similar             similar             similar
# 995            similar          dissimilar             similar
# 996            similar             similar             similar
# 997         dissimilar          dissimilar          dissimilar
# 998            similar          dissimilar             similar
#
#     similarity_score_12 similarity_score_13 similarity_score_14  \
# 0       very dissimilar          dissimilar     very dissimilar
# 1          very similar        very similar        very similar
# 2               similar             similar             similar
# 3               similar             similar             similar
# 4            dissimilar          dissimilar          dissimilar
# ..                  ...                 ...                 ...
# 994             similar             similar             similar
# 995             similar          dissimilar             neutral
# 996             similar             similar             similar
# 997          dissimilar          dissimilar          dissimilar
# 998             neutral             similar             similar
#
#     similarity_score_15
# 0       very dissimilar
# 1          very similar
# 2               similar
# 3               similar
# 4       very dissimilar
# ..                  ...
# 994             similar
# 995             similar
# 996             similar
# 997          dissimilar
# 998             similar
#
# [999 rows x 17 columns]

# %%
# Show results
raw_emb_pred
# Out:
#       word1        word2  similarity_score
# 0       old          new              0.51
# 1     smart  intelligent              0.57
# 2      hard    difficult              0.58
# 3     happy     cheerful              0.60
# 4      hard         easy              0.45
# ..      ...          ...               ...
# 994    join      acquire              0.32
# 995    send       attend              0.47
# 996  gather       attend              0.59
# 997  absorb     withdraw              0.43
# 998  attend       arrive              0.50
#
# [999 rows x 3 columns]

# %% [markdown]
# ### **1. Data Processing**

# %%
# Copy dataframe
gpt_pred = raw_gpt_pred.copy()

# List of columns to scale
similarity_cols = [f"similarity_score_{i}" for i in range(1, 16)]

# Mapping of categorical scale
categorical_mapping = {
    'very dissimilar': 0,
    'dissimilar': 2.5,
    'neutral': 5,
    'similar': 7.5,
    'very similar': 10
}

# Apply mapping
for col in similarity_cols:
    gpt_pred[col] = gpt_pred[col].map(categorical_mapping)

# Calculate the mean SimLex-999
gpt_pred['gpt_pred_sl'] = gpt_pred[similarity_cols].mean(axis=1).round(2)

# Select columns
gpt_pred = gpt_pred[['word1', 'word2', 'gpt_pred_sl']]

# Show results
gpt_pred
# Out:
#       word1        word2  gpt_pred_sl
# 0       old          new         0.17
# 1     smart  intelligent        10.00
# 2      hard    difficult         7.50
# 3     happy     cheerful         8.00
# 4      hard         easy         1.33
# ..      ...          ...          ...
# 994    join      acquire         7.50
# 995    send       attend         5.83
# 996  gather       attend         7.50
# 997  absorb     withdraw         3.17
# 998  attend       arrive         6.33
#
# [999 rows x 3 columns]

# %%
# Copy dataframe
emb_pred = raw_emb_pred.copy()

# Normalize cosine similarity to to 0-10 scale
emb_pred['scaled_similarity_score'] = 5 * (emb_pred['similarity_score'] + 1)

# Rename columns
emb_pred = emb_pred.rename(columns={'scaled_similarity_score': 'emb_pred_sl'})

# Select columns
emb_pred = emb_pred[['word1', 'word2', 'emb_pred_sl']]

# Show results
emb_pred
# Out:
#       word1        word2  emb_pred_sl
# 0       old          new         7.55
# 1     smart  intelligent         7.85
# 2      hard    difficult         7.90
# 3     happy     cheerful         8.00
# 4      hard         easy         7.25
# ..      ...          ...          ...
# 994    join      acquire         6.60
# 995    send       attend         7.35
# 996  gather       attend         7.95
# 997  absorb     withdraw         7.15
# 998  attend       arrive         7.50
#
# [999 rows x 3 columns]

# %%
# Concatenate DataFrames
conc = pd.concat([gpt_pred, emb_pred], axis=1)

# Show results
conc
# Out:
#       word1        word2  gpt_pred_sl   word1        word2  emb_pred_sl
# 0       old          new         0.17     old          new         7.55
# 1     smart  intelligent        10.00   smart  intelligent         7.85
# 2      hard    difficult         7.50    hard    difficult         7.90
# 3     happy     cheerful         8.00   happy     cheerful         8.00
# 4      hard         easy         1.33    hard         easy         7.25
# ..      ...          ...          ...     ...          ...          ...
# 994    join      acquire         7.50    join      acquire         6.60
# 995    send       attend         5.83    send       attend         7.35
# 996  gather       attend         7.50  gather       attend         7.95
# 997  absorb     withdraw         3.17  absorb     withdraw         7.15
# 998  attend       arrive         6.33  attend       arrive         7.50
#
# [999 rows x 6 columns]

# %% [markdown]
# ### **2. Descriptive Statistics**

# %%
# Summary statistics SimLex-999
gpt_pred_sl_summary = round(gpt_pred['gpt_pred_sl'].describe(), 2)
emb_pred_sl_summary = round(emb_pred['emb_pred_sl'].describe(), 2)

# Add median SimLex-999
gpt_pred_sl_summary['median'] = round(gpt_pred['gpt_pred_sl'].median(), 2)
emb_pred_sl_summary['median'] = round(emb_pred['emb_pred_sl'].median(), 2)

# Create pandas DataFrame
summary_df = pd.DataFrame({
    "gpt_pred_sl": gpt_pred_sl_summary,
    "emb_pred_sl": emb_pred_sl_summary,
})

# Show results
summary_df
# Out:
#         gpt_pred_sl  emb_pred_sl
# count        999.00       999.00
# mean           5.99         7.31
# std            2.04         0.58
# min            0.00         5.60
# 25%            4.67         6.90
# 50%            6.83         7.25
# 75%            7.50         7.65
# max           10.00         9.15
# median         6.83         7.25

# %%
# Rename columns and copy
renamed_gpt_pred_sl = gpt_pred.rename(columns={"gpt_pred_sl": "SimLex-999"}).copy()
renamed_emb_pred_sl = emb_pred.rename(columns={"emb_pred_sl": "SimLex-999"}).copy()

# Create dummy label
renamed_gpt_pred_sl['Score'] = 'GPT-3.5'
renamed_emb_pred_sl['Score'] = 'EMB-SML'

# Combine DataFrames
combined_data = pd.concat([renamed_gpt_pred_sl, renamed_emb_pred_sl])

# Create boxplot
plt.figure(figsize=(6, 6))
sns.boxplot(
    x='Score',
    y='SimLex-999',
    data=combined_data,
    palette=['skyblue', 'lightgreen'],
    boxprops={'edgecolor': 'black'},
    whiskerprops={'color': 'black'},
    flierprops={'marker': 'o', 'color': 'black', 'markerfacecolor': 'black'},
    capprops={'color': 'black'},
    medianprops={'color': 'black'}
)

# Set labels and title
plt.ylabel('SimLex-999')
# plt.title('Comparison of SimLex-999')

# Customize y-axis ticks
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(integer=True))
plt.ylim(0, 10)  # Setting y-axis limits from 0 to 10

# Remove x-axis label
plt.xlabel('')

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# ### **3. Distributions**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 10

# Define bins
bins = 10

# Plot NL predicted histogram
axes[0].hist(renamed_gpt_pred_sl['SimLex-999'], bins=bins, edgecolor='black', color='skyblue')
axes[0].set_title('GPT-3.5')
axes[0].set_xlabel('SimLex-999')
axes[0].set_ylabel('Frequency')
axes[0].set_xlim(x_min, x_max)
axes[0].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[0].grid(False) # Remove grid

# Plot EN predicted histogram
axes[1].hist(renamed_emb_pred_sl['SimLex-999'], bins=bins, edgecolor='black', color='lightgreen')
axes[1].set_title('EMB-SML')
axes[1].set_xlabel('SimLex-999')
axes[1].set_ylabel('Frequency')
axes[1].set_xlim(x_min, x_max)
axes[1].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[1].grid(False) # Remove grid

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# ### **4. Outliers**

# %% [markdown]
# #### **4.1. GPT**

# %%
# Count outliers
print_outlier_counts(gpt_pred)
# Out:
# Outliers in gpt_pred_sl: 11

# %%
# Row outliers
print_outlier_data(gpt_pred, 'gpt_pred_sl')
# Out:
# Outliers in gpt_pred_sl:
#            word1        word2  gpt_pred_sl
# 0            old          new         0.17
# 15         smart         dumb         0.00
# 49          dumb  intelligent         0.00
# 50           bad        great         0.00
# 51     difficult       simple         0.00
# 254      reality      fantasy         0.17
# 550        money        pearl         0.17
# 600     molecule          air         0.00
# 750       people         cent         0.00
# 855  disorganize     organize         0.33
# 859      destroy    construct         0.17

# %% [markdown]
# #### **4.2. EMB**

# %%
# Count outliers
print_outlier_counts(emb_pred)
# Out:
# Outliers in emb_pred_sl: 10

# %%
# Row outliers
print_outlier_data(emb_pred, 'emb_pred_sl')
# Out:
# Outliers in emb_pred_sl:
#               word1       word2  emb_pred_sl
# 9             weird     strange         8.95
# 18            large        huge         8.80
# 129           movie        film         9.05
# 298        boundary      border         8.80
# 502  administration  management         8.85
# 723          flower   endurance         5.75
# 733          liquor     century         5.70
# 741            cent        wife         5.60
# 782          vanish   disappear         9.00
# 796         achieve  accomplish         9.15

# %% [markdown]
# #### **4.3. Add to Summary**

# %%
# Calculate outliers
outliers_gpt_pred_sl = calculate_outliers(gpt_pred, 'gpt_pred_sl')
outliers_emb_pred_sl = calculate_outliers(emb_pred, 'emb_pred_sl')

# Count outliers
count_outliers_gpt_pred_sl = outliers_gpt_pred_sl.shape[0]
count_outliers_emb_pred_sl = outliers_emb_pred_sl.shape[0]

# Add outliers count to summary
outliers_row = pd.Series([count_outliers_gpt_pred_sl, count_outliers_emb_pred_sl], 
    index=summary_df.columns,
    name='outliers'
)
summary_df = pd.concat([summary_df, outliers_row.to_frame().T])

# Show results
summary_df
# Out:
#           gpt_pred_sl  emb_pred_sl
# count          999.00       999.00
# mean             5.99         7.31
# std              2.04         0.58
# min              0.00         5.60
# 25%              4.67         6.90
# 50%              6.83         7.25
# 75%              7.50         7.65
# max             10.00         9.15
# median           6.83         7.25
# outliers        11.00        10.00

# %% [markdown]
# ### **5. Evaluation Metrics**

# %% [markdown]
# #### **5.1. Spearmans's Rank Correlation**

# %%
# Scatter plot
plot_scatter_plot(conc, 'gpt_pred_sl', 'emb_pred_sl', 'GPT-3.5', 'EMB-SML', 0, 10, 0, 10)

# %%
# Correlation and pvalue
print_correlation_and_pvalue(conc, 'gpt_pred_sl', 'emb_pred_sl')
# Out:
# Spearman's Rank correlation: 0.46155
# P-value: 7.460789731341406e-54
# The correlation is statistically significant.

# %% [markdown]
# #### **5.2. Mean Square Error (MSE)**

# %%
# Calculate Mean Squared Error
mse = mean_squared_error(conc['gpt_pred_sl'], conc['emb_pred_sl'])

# Show results
print(f"Mean Squared Error (MSE): {mse:.2f}")
# Out:
# Mean Squared Error (MSE): 5.17

# %% [markdown]
# #### **5.3. Mean Absolute Error (MAE)**

# %%
# Calculate Mean Absolute Error
mae = mean_absolute_error(conc['gpt_pred_sl'], conc['emb_pred_sl'])

# Show results
print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
# Mean Absolute Error (MAE): 1.59
