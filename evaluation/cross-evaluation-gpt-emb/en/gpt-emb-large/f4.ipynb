# %% [markdown]
# ### **0. Set-up**

# %%
# Import libraries and utils
# %run '../../../utils.ipynb'

# %%
# Load NL predicted gpt-3.5-turbo-0125
raw_gpt_pred = pd.read_csv("../../../../data/gpt-3.5-turbo-0125/processed/en/f4.csv")

# Load NL predicted text-embedding-3-large
raw_emb_pred = pd.read_csv("../../../../data/text-embedding-3-large/en.csv")

# %%
# Show results
raw_gpt_pred
# Out:
#       word1        word2  similarity_score_1  similarity_score_2  \
# 0       old          new                0.05                 2.0
# 1     smart  intelligent                4.50                 5.0
# 2      hard    difficult                4.50                 4.0
# 3     happy     cheerful                4.00                 4.0
# 4      hard         easy                1.00                 1.0
# ..      ...          ...                 ...                 ...
# 994    join      acquire                0.40                 0.5
# 995    send       attend                0.20                 0.3
# 996  gather       attend                0.40                 0.3
# 997  absorb     withdraw                0.20                 0.1
# 998  attend       arrive                0.60                 0.4
#
#      similarity_score_3  similarity_score_4  similarity_score_5  \
# 0                  0.05                0.01                0.19
# 1                  0.95                0.95                0.83
# 2                  0.85                0.80                0.70
# 3                  0.85                0.80                0.84
# 4                  0.15                0.03                0.26
# ..                  ...                 ...                 ...
# 994                0.60                0.33                0.32
# 995                0.20                0.17                0.32
# 996                0.30                0.17                0.32
# 997                0.20                0.17                0.16
# 998                0.30                0.17                0.58
#
#      similarity_score_6  similarity_score_7  similarity_score_8  \
# 0                  0.08                1.00                0.08
# 1                  1.00                0.90                1.00
# 2                  0.95                0.90                0.96
# 3                  0.95                0.80                0.75
# 4                  0.08                0.10                0.23
# ..                  ...                 ...                 ...
# 994                0.40                0.53                0.70
# 995                0.20                0.33                0.40
# 996                0.20                0.42                0.50
# 997                0.20                0.09                0.10
# 998                0.20                0.67                0.40
#
#      similarity_score_9  similarity_score_10  similarity_score_11  \
# 0                  0.15                 0.15                 0.50
# 1                  1.00                 0.87                 0.95
# 2                  0.85                 0.78                 0.90
# 3                  0.70                 0.85                 0.85
# 4                  0.25                 0.23                 0.20
# ..                  ...                  ...                  ...
# 994                0.55                 0.50                 0.40
# 995                0.35                 0.30                 0.40
# 996                0.45                 0.40                 0.50
# 997                0.10                 0.10                 0.25
# 998                0.50                 0.40                 0.60
#
#      similarity_score_12  similarity_score_13  similarity_score_14  \
# 0                   0.05                 0.27                 1.13
# 1                   0.95                 1.00                 4.00
# 2                   0.95                 0.82                 3.00
# 3                   0.80                 0.90                 3.00
# 4                   0.10                 0.37                 1.00
# ..                   ...                  ...                  ...
# 994                 0.55                 0.50                 0.41
# 995                 0.25                 0.25                 0.36
# 996                 0.35                 0.50                 0.37
# 997                 0.25                 0.50                 0.33
# 998                 0.40                 0.50                 0.40
#
#      similarity_score_15
# 0                   0.05
# 1                   0.95
# 2                   0.95
# 3                   0.85
# 4                   0.10
# ..                   ...
# 994                 0.40
# 995                 0.00
# 996                 0.25
# 997                 0.00
# 998                 0.20
#
# [999 rows x 17 columns]

# %%
# Show results
raw_emb_pred
# Out:
#       word1        word2  similarity_score
# 0       old          new              0.57
# 1     smart  intelligent              0.61
# 2      hard    difficult              0.52
# 3     happy     cheerful              0.57
# 4      hard         easy              0.52
# ..      ...          ...               ...
# 994    join      acquire              0.30
# 995    send       attend              0.38
# 996  gather       attend              0.52
# 997  absorb     withdraw              0.34
# 998  attend       arrive              0.41
#
# [999 rows x 3 columns]

# %% [markdown]
# ### **1. Data Processing**

# %%
# Copy dataframe
gpt_pred = raw_gpt_pred.copy()

# List of columns to scale
similarity_cols = [f"similarity_score_{i}" for i in range(1, 16)]

# Scale the similarity scores from 0-5 to 0-10
gpt_pred[similarity_cols] = gpt_pred[similarity_cols] * 2

# Calculate the mean SimLex-999
gpt_pred['gpt_pred_sl'] = gpt_pred[similarity_cols].mean(axis=1).round(2)

# Select columns
gpt_pred = gpt_pred[['word1', 'word2', 'gpt_pred_sl']]

# Show results
gpt_pred
# Out:
#       word1        word2  gpt_pred_sl
# 0       old          new         0.77
# 1     smart  intelligent         3.31
# 2      hard    difficult         2.92
# 3     happy     cheerful         2.79
# 4      hard         easy         0.68
# ..      ...          ...          ...
# 994    join      acquire         0.95
# 995    send       attend         0.54
# 996  gather       attend         0.72
# 997  absorb     withdraw         0.37
# 998  attend       arrive         0.84
#
# [999 rows x 3 columns]

# %%
# Copy dataframe
emb_pred = raw_emb_pred.copy()

# Normalize cosine similarity to to 0-10 scale
emb_pred['scaled_similarity_score'] = 5 * (emb_pred['similarity_score'] + 1)

# Rename columns
emb_pred = emb_pred.rename(columns={'scaled_similarity_score': 'emb_pred_sl'})

# Select columns
emb_pred = emb_pred[['word1', 'word2', 'emb_pred_sl']]

# Show results
emb_pred
# Out:
#       word1        word2  emb_pred_sl
# 0       old          new         7.85
# 1     smart  intelligent         8.05
# 2      hard    difficult         7.60
# 3     happy     cheerful         7.85
# 4      hard         easy         7.60
# ..      ...          ...          ...
# 994    join      acquire         6.50
# 995    send       attend         6.90
# 996  gather       attend         7.60
# 997  absorb     withdraw         6.70
# 998  attend       arrive         7.05
#
# [999 rows x 3 columns]

# %%
# Concatenate DataFrames
conc = pd.concat([gpt_pred, emb_pred], axis=1)

# Show results
conc
# Out:
#       word1        word2  gpt_pred_sl   word1        word2  emb_pred_sl
# 0       old          new         0.77     old          new         7.85
# 1     smart  intelligent         3.31   smart  intelligent         8.05
# 2      hard    difficult         2.92    hard    difficult         7.60
# 3     happy     cheerful         2.79   happy     cheerful         7.85
# 4      hard         easy         0.68    hard         easy         7.60
# ..      ...          ...          ...     ...          ...          ...
# 994    join      acquire         0.95    join      acquire         6.50
# 995    send       attend         0.54    send       attend         6.90
# 996  gather       attend         0.72  gather       attend         7.60
# 997  absorb     withdraw         0.37  absorb     withdraw         6.70
# 998  attend       arrive         0.84  attend       arrive         7.05
#
# [999 rows x 6 columns]

# %% [markdown]
# ### **2. Descriptive Statistics**

# %%
# Summary statistics SimLex-999
gpt_pred_sl_summary = round(gpt_pred['gpt_pred_sl'].describe(), 2)
emb_pred_sl_summary = round(emb_pred['emb_pred_sl'].describe(), 2)

# Add median SimLex-999
gpt_pred_sl_summary['median'] = round(gpt_pred['gpt_pred_sl'].median(), 2)
emb_pred_sl_summary['median'] = round(emb_pred['emb_pred_sl'].median(), 2)

# Create pandas DataFrame
summary_df = pd.DataFrame({
    "gpt_pred_sl": gpt_pred_sl_summary,
    "emb_pred_sl": emb_pred_sl_summary,
})

# Show results
summary_df
# Out:
#         gpt_pred_sl  emb_pred_sl
# count        999.00       999.00
# mean           2.72         7.25
# std            2.07         0.55
# min            0.02         5.85
# 25%            1.06         6.90
# 50%            2.10         7.20
# 75%            4.00         7.60
# max            9.17         9.25
# median         2.10         7.20

# %%
# Rename columns and copy
renamed_gpt_pred_sl = gpt_pred.rename(columns={"gpt_pred_sl": "SimLex-999"}).copy()
renamed_emb_pred_sl = emb_pred.rename(columns={"emb_pred_sl": "SimLex-999"}).copy()

# Create dummy label
renamed_gpt_pred_sl['Score'] = 'GPT-3.5'
renamed_emb_pred_sl['Score'] = 'EMB-LRG'

# Combine DataFrames
combined_data = pd.concat([renamed_gpt_pred_sl, renamed_emb_pred_sl])

# Create boxplot
plt.figure(figsize=(6, 6))
sns.boxplot(
    x='Score',
    y='SimLex-999',
    data=combined_data,
    palette=['skyblue', 'lightgreen'],
    boxprops={'edgecolor': 'black'},
    whiskerprops={'color': 'black'},
    flierprops={'marker': 'o', 'color': 'black', 'markerfacecolor': 'black'},
    capprops={'color': 'black'},
    medianprops={'color': 'black'}
)

# Set labels and title
plt.ylabel('SimLex-999')
# plt.title('Comparison of SimLex-999')

# Customize y-axis ticks
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(integer=True))
plt.ylim(0, 10)  # Setting y-axis limits from 0 to 10

# Remove x-axis label
plt.xlabel('')

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# ### **3. Distributions**

# %%
# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Define x-axis limits
x_min = 0
x_max = 10

# Define bins
bins = 10

# Plot NL predicted histogram
axes[0].hist(renamed_gpt_pred_sl['SimLex-999'], bins=bins, edgecolor='black', color='skyblue')
axes[0].set_title('GPT-3.5')
axes[0].set_xlabel('SimLex-999')
axes[0].set_ylabel('Frequency')
axes[0].set_xlim(x_min, x_max)
axes[0].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[0].grid(False) # Remove grid

# Plot EN predicted histogram
axes[1].hist(renamed_emb_pred_sl['SimLex-999'], bins=bins, edgecolor='black', color='lightgreen')
axes[1].set_title('EMB-LRG')
axes[1].set_xlabel('SimLex-999')
axes[1].set_ylabel('Frequency')
axes[1].set_xlim(x_min, x_max)
axes[1].xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
axes[1].grid(False) # Remove grid

# Adjust layout
plt.tight_layout()

# Show results
plt.show()

# %% [markdown]
# ### **4. Outliers**

# %% [markdown]
# #### **4.1. GPT**

# %%
# Count outliers
print_outlier_counts(gpt_pred)
# Out:
# Outliers in gpt_pred_sl: 5

# %%
# Row outliers
print_outlier_data(gpt_pred, 'gpt_pred_sl')
# Out:
# Outliers in gpt_pred_sl:
#              word1       word2  gpt_pred_sl
# 250          motor      engine         9.17
# 264     capability  competence         8.48
# 265      abundance      plenty         8.54
# 282  communication    language         8.47
# 289     competence     ability         8.81

# %% [markdown]
# #### **4.2. EMB**

# %%
# Count outliers
print_outlier_counts(emb_pred)
# Out:
# Outliers in emb_pred_sl: 10

# %%
# Row outliers
print_outlier_data(emb_pred, 'emb_pred_sl')
# Out:
# Outliers in emb_pred_sl:
#         word1       word2  emb_pred_sl
# 8      stupid        dumb         8.75
# 9       weird     strange         8.95
# 16     insane       crazy         9.05
# 28     simple        easy         8.75
# 42      large         big         8.75
# 129     movie        film         8.85
# 138    sunset     sunrise         8.80
# 182  employer    employee         8.90
# 782    vanish   disappear         9.25
# 796   achieve  accomplish         8.95

# %% [markdown]
# #### **4.3. Add to Summary**

# %%
# Calculate outliers
outliers_gpt_pred_sl = calculate_outliers(gpt_pred, 'gpt_pred_sl')
outliers_emb_pred_sl = calculate_outliers(emb_pred, 'emb_pred_sl')

# Count outliers
count_outliers_gpt_pred_sl = outliers_gpt_pred_sl.shape[0]
count_outliers_emb_pred_sl = outliers_emb_pred_sl.shape[0]

# Add outliers count to summary
outliers_row = pd.Series([count_outliers_gpt_pred_sl, count_outliers_emb_pred_sl], 
    index=summary_df.columns,
    name='outliers'
)
summary_df = pd.concat([summary_df, outliers_row.to_frame().T])

# Show results
summary_df
# Out:
#           gpt_pred_sl  emb_pred_sl
# count          999.00       999.00
# mean             2.72         7.25
# std              2.07         0.55
# min              0.02         5.85
# 25%              1.06         6.90
# 50%              2.10         7.20
# 75%              4.00         7.60
# max              9.17         9.25
# median           2.10         7.20
# outliers         5.00        10.00

# %% [markdown]
# ### **5. Evaluation Metrics**

# %% [markdown]
# #### **5.1. Spearmans's Rank Correlation**

# %%
# Scatter plot
plot_scatter_plot(conc, 'gpt_pred_sl', 'emb_pred_sl', 'GPT-3.5', 'EMB-LRG', 0, 10, 0, 10)

# %%
# Correlation and pvalue
print_correlation_and_pvalue(conc, 'gpt_pred_sl', 'emb_pred_sl')
# Out:
# Spearman's Rank correlation: 0.4806
# P-value: 7.263915270215563e-59
# The correlation is statistically significant.

# %% [markdown]
# #### **5.2. Mean Square Error (MSE)**

# %%
# Calculate Mean Squared Error
mse = mean_squared_error(conc['gpt_pred_sl'], conc['emb_pred_sl'])

# Show results
print(f"Mean Squared Error (MSE): {mse:.2f}")
# Out:
# Mean Squared Error (MSE): 24.19

# %% [markdown]
# #### **5.3. Mean Absolute Error (MAE)**

# %%
# Calculate Mean Absolute Error
mae = mean_absolute_error(conc['gpt_pred_sl'], conc['emb_pred_sl'])

# Show results
print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
# Mean Absolute Error (MAE): 4.55
